# %% [markdown]
# # ex010
# fixed epochs_

# %%
import gc
import os
import random
import time
import math

import cv2
import numpy as np
import matplotlib.pyplot as plt

# model
import torch
import torchvision
import torch.nn as nn
import timm
from torchvision.models.feature_extraction import create_feature_extractor
import torchvision.transforms.functional as TF

# data loader
import albumentations as A
from albumentations.pytorch import ToTensorV2
from torch.utils.data import DataLoader, Dataset

# training
from torch.optim import SGD, Adam, AdamW
from torch.optim.lr_scheduler import CosineAnnealingLR, CosineAnnealingWarmRestarts, ReduceLROnPlateau

# metric
from sklearn.metrics import fbeta_score, roc_auc_score

import wandb

# %% [markdown]
# # config

# %%
BASE_DIR = "/working/"
INPUT_DIR = os.path.join(BASE_DIR, "input", "vesuvius-challenge-ink-detection")
TRAIN_DIR = os.path.join(INPUT_DIR, "train")
TEST_DIR = os.path.join(INPUT_DIR, "test")
IMG_SIZE = [256, 256]
SURFACE_LIST = [
                range(26, 36, 3),
                range(27, 37, 3),                
                range(25, 35, 3),
                ]
print(len(SURFACE_LIST[0]))
print(SURFACE_LIST)

SURFACE_NUM = len(SURFACE_LIST[0])
# print("Start surface idx =",START_SURFACE)

# SLIDE_POS_LIST = [[idx*(IMG_SIZE[0]//6), idx*(IMG_SIZE[1]//6)] for idx in range(0, 3)]
SLIDE_POS_LIST = [[0,0], [IMG_SIZE[0]//2, 0], [0, IMG_SIZE[1]//2], [IMG_SIZE[0]//2, IMG_SIZE[1]//2]]
print("SLIDE_POS_LIST =", SLIDE_POS_LIST)
CFG = {
    "DEBUG" : False,
    # exp setting
    "EXP_CATEGORY" : "makebase",
    "EXP_NAME" : "exp010",
    "folds" : [0, 1, 2],

    # model
    # "model_name" : "tf_efficientnet_b0",
    "model_name" : "tf_efficientnet_b6",
    "inp_channels" : SURFACE_NUM,
    "out_channels" : 1,
    "pretrained" : True,
    "out_indices" : [0,1,2,3,4],
 
    # data   
    "img_size": IMG_SIZE,
    # "batch_size": 64,
    "batch_size": 16,#batch normの関係か？16の方が64より安定してそう？？
    "INPUT_DIR": INPUT_DIR,
    "TRAIN_DIR": TRAIN_DIR,
    "TEST_DIR": TEST_DIR,
    "surface_num": SURFACE_NUM,
    "surface_list": SURFACE_LIST,
    "slide_pos_list": SLIDE_POS_LIST,
#     "surface_start_idx": START_SURFACE,
    "TRAIN_DIR_LIST": [["1", "2"], ["1", "3"], ["2", "3"]],
#     "TRAIN_IDX_LIST" : ["1"],
    "VALID_DIR_LIST": [["3"],["2"],["1"]],
    "TEST_DIR_LIST": ["a", "b"],

    # learning
    "n_epoch" : 10,
    "lr" : 1e-3,
    "T_max" : 5,
    "min_lr" : 1e-8,
    "weight_decay" : 1e-6,

    # etc
    "print_freq" : 1000,
    "random_seed" : 21,
    "num_workers": 2,
}


if CFG["model_name"]=="tf_efficientnet_b0":
    CFG["channel_nums"] = [320, 112, 40, 24, 16]
elif CFG["model_name"]=="tf_efficientnet_b4":
    CFG["channel_nums"] = [448, 160, 56, 32, 24]
elif CFG["model_name"]=="tf_efficientnet_b6":
    CFG["channel_nums"] = [576, 200, 72, 40, 32]


if CFG["DEBUG"]:
    CFG["n_epoch"] = 1
    CFG["EXP_NAME"] = "DEBUG"
    

CFG["OUTPUT_DIR"] = os.path.join(BASE_DIR, "output", CFG["EXP_NAME"])
# Out:
# 4
# [range(26, 36, 3), range(27, 37, 3), range(25, 35, 3)]
# SLIDE_POS_LIST = [[0, 0], [128, 0], [0, 128], [128, 128]]

# %%
if not CFG["DEBUG"]:
    os.makedirs(CFG["OUTPUT_DIR"])
    os.makedirs(os.path.join(CFG["OUTPUT_DIR"], "imgs"))

# %%
if not CFG["DEBUG"]:
    WANDB_CONFIG = {'competition': 'vcid', '_wandb_kernel': 'taro'}
    os.environ["WANDB_SILENT"] = "true"
    wandb.init(project=WANDB_CONFIG["competition"], config=CFG, group=CFG["EXP_CATEGORY"], name=CFG["EXP_NAME"], reinit=True)
# Out:
# 2023-04-16 15:15:57.272660: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-16 15:15:57.349731: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-16 15:15:57.936556: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-16 15:15:57.936633: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-16 15:15:57.936639: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# # utils

# %%
def logging_metrics_epoch(CFG, fold, epoch, slice_idx,train_loss_avg, valid_loss_avg, score, threshold, auc_score):
    wandb.log({f"train/fold{fold}": train_loss_avg,
                f"valid/fold{fold}": valid_loss_avg,
                f"score/fold{fold}":score,
                f"score threshold/fold{fold}":threshold,
                f"auc/fold{fold}":auc_score,
                f"epoch/fold{fold}":epoch+slice_idx*CFG["n_epoch"],
                })

#     wandb.log({f"train/fold{fold}": train_loss_avg,
#             f"valid/fold{fold}": valid_loss_avg}, step=epoch+slice_idx*CFG["n_epoch"])
#     wandb.log({f"score/fold{fold}":score,
#                 f"score threshold/fold{fold}":threshold,
#                 f"auc/fold{fold}":auc_score,
#                 }, step=epoch+slice_idx*CFG["n_epoch"])

    # wandb.log({"loss avg":{f"train/fold{fold}": train_loss_avg,
    #                         f"valid/fold{fold}": valid_loss_avg}}, step=epoch+slice_idx*CFG["n_epoch"])
    # wandb.log({"Metircs" : {f"score/fold{fold}":score,
    #                         f"score threshold/fold{fold}":threshold,
    #                         f"auc/fold{fold}":auc_score,
    #                         }}, step=epoch+slice_idx*CFG["n_epoch"])

# %%
def seed_everything(seed=CFG["random_seed"]):
    #os.environ['PYTHONSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic =True
    torch.backends.cudnn.benchmark = False
seed_everything()

# device optimization
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
def asMinutes(s):
    """Convert Seconds to Minutes."""
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    """Accessing and Converting Time Data."""
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))

class AverageMeter(object):
    """Computes and stores the average and current value."""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# # metric

# %%
def fbeta_numpy(targets, preds, beta=0.5, smooth=1e-5):
    y_true_count = targets.sum()
    ctp = preds[targets==1].sum()
    cfp = preds[targets==0].sum()
    beta_squared = beta * beta

    c_precision = ctp / (ctp + cfp + smooth)
    c_recall = ctp / (y_true_count + smooth)
    dice = (1 + beta_squared) * (c_precision * c_recall) / (beta_squared * c_precision + c_recall + smooth)

    return dice

def calc_fbeta_auc(mask, mask_pred):
    mask = mask.astype(int).flatten()
    mask_pred = mask_pred.flatten()

    best_th = 0
    best_dice = 0
    dice_list = [] 
    # for th in np.array(range(10, 50+1, 5)) / 100:
    for th in np.array(range(10, 100+1, 5)) / 100:
        # dice = fbeta_score(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice = fbeta_numpy(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice_list.append(dice)
        # print(f'\t th: {th}, fbeta: {dice}')
        if dice > best_dice:
            best_dice = dice
            best_th = th
    
    auc = roc_auc_score(mask, mask_pred)
    # Logger.info(f'best_th: {best_th}, fbeta: {best_dice}')
    return best_dice, best_th, auc, dice_list


def calc_cv(mask_gt, mask_pred):
    best_dice, best_th, auc, dice_list = calc_fbeta_auc(mask_gt, mask_pred)

    return best_dice, best_th, auc, dice_list

# %% [markdown]
# # model

# %%
class Encoder(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = timm.create_model(CFG["model_name"], in_chans=CFG["inp_channels"], features_only=True, out_indices=CFG["out_indices"], pretrained=CFG["pretrained"])
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        return skip_connection_list

class UpConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.bn1 = nn.BatchNorm2d(in_channels)
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size = 2, padding="same")
        self.bn2 = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        x = self.up(x)
        x = self.bn1(x)
        x = self.conv(x)
        x = self.bn2(x)
        return x


class Decoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.UpConv_0 = UpConv(CFG["channel_nums"][0], CFG["channel_nums"][1])
        self.UpConv_1 = UpConv(CFG["channel_nums"][1]*2, CFG["channel_nums"][2])
        self.UpConv_2 = UpConv(CFG["channel_nums"][2]*2, CFG["channel_nums"][3])
        self.UpConv_3 = UpConv(CFG["channel_nums"][3]*2, CFG["channel_nums"][4])
        self.UpConv_4 = UpConv(CFG["channel_nums"][4]*2, CFG["channel_nums"][4])
    
    def forward(self, skip_connection_list):
        emb = self.UpConv_0(skip_connection_list[4]) # emb.shape = (None, 160, 14, 14)
        emb_cat = torch.cat([skip_connection_list[3], emb], dim = 1)
        
        emb = self.UpConv_1(emb_cat)
        emb_cat = torch.cat([skip_connection_list[2], emb], dim = 1)
        
        emb = self.UpConv_2(emb_cat)
        emb_cat = torch.cat([skip_connection_list[1], emb], dim = 1)
        
        emb = self.UpConv_3(emb_cat)
        emb_cat = torch.cat([skip_connection_list[0], emb], dim = 1)

        emb_cat = self.UpConv_4(emb_cat)
        
        return emb_cat

class SegModel(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = Encoder(CFG)
        self.decoder = Decoder()
        self.head = nn.Sequential(
            nn.Conv2d(CFG["channel_nums"][-1], CFG["out_channels"], kernel_size=1, stride=1, padding=0),
            nn.Sigmoid()
        )
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        emb = self.decoder(skip_connection_list)
        output = self.head(emb)
        return output

# %% [markdown]
# # Dataset

# %%
train_transforms = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.RandomCrop(int(CFG["img_size"][0]*0.8), int(CFG["img_size"][1]*0.8), p=0.5),
    A.Blur(blur_limit=3, p=0.3),
    A.Resize(CFG["img_size"][0], CFG["img_size"][1]),
    ToTensorV2(),
])

valid_transforms = A.Compose([
    ToTensorV2(),
])

# %%
def fft_transform(img):
    eps = 1e-7
    f = np.fft.fft2(img)
    fshift = np.fft.fftshift(f)
    fshift = np.nan_to_num(fshift)+eps#nanを0埋め
    magnitude_spectrum = 20*np.log(np.abs(fshift))
    return magnitude_spectrum

def highpass_filter(img):
    frange = 1
    dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
    dft_shift = np.fft.fftshift(dft)

    rows, cols = img.shape
    crow,ccol = rows//2 , cols//2

    # create a mask first, center square is 1, remaining all zeros
    mask = np.ones((rows,cols,2),np.uint8)
    mask[crow-frange:crow+frange, ccol-frange:ccol+frange] = 0

    # apply mask and inverse DFT
    fshift = dft_shift*mask
    f_ishift = np.fft.ifftshift(fshift)
    img_back = cv2.idft(f_ishift)
    img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

    return img_back

def lowpass_filter(img):
    frange = 5
    dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
    dft_shift = np.fft.fftshift(dft)

    rows, cols = img.shape
    crow,ccol = rows//2 , cols//2

    # create a mask first, center square is 1, remaining all zeros
    mask = np.zeros((rows,cols,2),np.uint8)
    mask[crow-frange:crow+frange, ccol-frange:ccol+frange] = 1

    # apply mask and inverse DFT
    fshift = dft_shift*mask
    f_ishift = np.fft.ifftshift(fshift)
    img_back = cv2.idft(f_ishift)
    img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

    return img_back

# %%
class VCID_Dataset(Dataset):
    def __init__(self, CFG, data_dir_list, surface_list, surface_volumes=None, slide_pos=[0,0], mode="train", transform=None):
        # get config
        self.mode = mode
        self.img_size = CFG["img_size"]
        if self.mode=="train":  self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode=="valid":    self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode == "test":   self.DATADIR = CFG["TEST_DIR"]
        self.data_dir_list = data_dir_list
        self.surface_list = surface_list
        self.slide_pos = slide_pos
        self.transform = transform
        
        # get imgs
        # print("initializing dataset...")
        self.imgs = []
        for data_dir in self.data_dir_list:
            img_path = os.path.join(self.DATADIR, data_dir, "mask.png")
            # print(img_path)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            img = img.reshape(img.shape[0], img.shape[1], 1) # (h, w, channel=1)
            self.imgs.append(img)
        
        # check imgs
        for img in self.imgs:
            assert img is not None, "img is None. data path is wrong"
        # get and split surface
        if surface_volumes is None:
            self.surface_vols = self.read_surfacevols()
        else:
            # print("using loaded surface_vols")
            self.surface_vols = surface_volumes
        for surface_vol in self.surface_vols:
            assert surface_vol is not None, "surface_vol is None. data path is wrong"
       
        # split grid
        self.get_all_grid()
        self.fileter_grid()
        self.get_flatten_grid()
        # print("split grid done.") 
       
        # get label imgs
        if self.mode == "train" or self.mode == "valid":
            self.labels = []
            for data_dir in self.data_dir_list:
                label_path = os.path.join(self.DATADIR, data_dir, "inklabels.png")
                assert os.path.exists(label_path), f"{label_path} is not exist."
                
                # read label
                label = cv2.imread(label_path, cv2.IMREAD_GRAYSCALE)
                # mask erosion
                kernel_size = (img.shape[0]+img.shape[1])//2//100
                kernel = np.ones((kernel_size, kernel_size), np.uint8)
                img = cv2.erode(img, kernel,iterations = 3)
                
                label = label.reshape(label.shape[0], label.shape[1], 1) # (h, w, channel=1)
                self.labels.append(label)# 画像サイズがそれぞれ違うので単純にconcatできずlist化しているs
        # print("initializing dataset done.")

    def get_surface_volumes(self):
        return self.surface_vols

    def read_surfacevols(self):
        """ read surface volume by data_dir_list and surface_list 
            Returns:surface_vuls (list): surface volume list [array(h,w,channel=surface_num), array(), ...]
        """
        surface_vols = []
        # print("reading surface volume...")
        for data_dir in self.data_dir_list:
            surface_vol_ = None
            for read_idx, surface_idx in enumerate(self.surface_list):
                # print("\r", f"reading idx : {read_idx+1}/{len(self.surface_list)}", end="")
                surface_path = os.path.join(self.DATADIR, data_dir, "surface_volume", f"{surface_idx:02}.tif")
                surface_vol = cv2.imread(surface_path, cv2.IMREAD_GRAYSCALE)
                surface_vol = surface_vol.reshape(surface_vol.shape[0], surface_vol.shape[1], 1) # (h, w, channel=1)
                if surface_vol_ is None:
                    surface_vol_ = surface_vol
                else:
                    surface_vol_ = np.concatenate([surface_vol_, surface_vol], axis=2) # (h, w, channel=surface_num)
            surface_vols.append(surface_vol_)
            # print(f"  => read surface volume done. [{data_dir}]")
        return surface_vols


    def get_grid_img(self, img, grid_idx):
        """ crop grid img from original img"""
        img_grid = img[grid_idx[0]*self.img_size[0] + self.slide_pos[0] : (grid_idx[0]+1)*self.img_size[0] + self.slide_pos[0],
                        grid_idx[1]*self.img_size[1] + self.slide_pos[1] : (grid_idx[1]+1)*self.img_size[1] + self.slide_pos[1]]
        return img_grid
    
    
    def get_masked_img(self, img, mask):
        """ multiply mask to surface_volumes """
        masked_img = None
        for channel in range(img.shape[2]):
            img_channel = img[:,:,channel].reshape(img.shape[0], img.shape[1],1)
            masked = img_channel*mask
            if masked_img is None:
                masked_img = masked.reshape(masked.shape[0], masked.shape[1], 1)
            else:
                masked = masked.reshape(masked.shape[0], masked.shape[1], 1)
                masked_img = np.concatenate([masked_img, masked], axis=2)
        return masked_img
    
    def get_grid_hpfimg(self, img, grid_idx):
        """ crop grid img from original img and hpf filter """
        img_grid = self.get_grid_img(img, grid_idx)
        img_transformed = None
        for channel in range(img_grid.shape[2]):
            img_grid_trans = highpass_filter(img_grid[:,:,channel])
            if img_transformed is None:
                img_transformed = img_grid_trans.reshape(img_grid_trans.shape[0], img_grid_trans.shape[1], 1)
            else:
                img_transformed = np.concatenate([img_transformed, img_grid_trans.reshape(img_grid_trans.shape[0], img_grid_trans.shape[1], 1)], axis=2)
        return img_transformed
    
    def get_all_grid(self):
        """ get all grid indices by img size and grid size
        """
        self.grid_indices = []
        for img in self.imgs:
            self.x_grid_size = (img.shape[0] - self.slide_pos[0]) // self.img_size[0]
            self.y_grid_size = (img.shape[1] - self.slide_pos[1]) // self.img_size[1]
            grid_img = []
            for i in range(self.x_grid_size):
                for j in range(self.y_grid_size):
                    grid_img.append([i, j])
            self.grid_indices.append(grid_img)
        return self.grid_indices
          
    def fileter_grid(self):
        """ get grid indices which mask is not 0 by all grid indices"""
        grid_indices_all = []
        for img, grid_indices in zip(self.imgs, self.grid_indices):
            grid_indices_copy = grid_indices.copy()
            for grid_idx in grid_indices:
                img_grid = self.get_grid_img(img, grid_idx)
                if img_grid.sum() == 0:
                    grid_indices_copy.remove(grid_idx)
            grid_indices_all.append(grid_indices_copy)
        self.grid_indices = grid_indices_all
        return self.grid_indices

    def get_flatten_grid(self):
        """ get flatten index list by grid indices
            Returns:flatten_grid (list): flatten index list [[img_idx, grid_idx], [img_idx, grid_idx], ...]
        """
        flatten_grid = []
        for img_idx, grid_indices in enumerate(self.grid_indices):
            for grid_idx in grid_indices:
                grid_imgidx_list = [img_idx]
                grid_imgidx_list.extend(grid_idx)
                flatten_grid.append(grid_imgidx_list)
        self.flatten_grid = flatten_grid
        return self.flatten_grid

    def __len__(self):
        return len(self.flatten_grid)

    def __getitem__(self, idx):
        # get indices
        img_grid_idx = self.flatten_grid[idx]
        img_idx = img_grid_idx[0]
        grid_idx = img_grid_idx[1:]
        # get img & surface_vol
        img = self.imgs[img_idx]
        surface_vol = self.surface_vols[img_idx]
        img = self.get_grid_img(img, grid_idx)/255.
        surface_vol = self.get_grid_img(surface_vol, grid_idx)/255.
        
        # multiple small mask 
        surface_vol = self.get_masked_img(surface_vol, img)
        assert surface_vol.shape[0]==img.shape[0] and surface_vol.shape[1]==img.shape[1] , "surface_vol_list shape is not same as img shape"
        img = surface_vol

        # transform
        if self.mode == "test":
            if self.transform:
                img = self.transform(image=img)["image"]
            else:
                img = img.transpose(2, 0, 1)
                img = torch.tensor(img, dtype=torch.float32)
            return img, grid_idx
        elif self.mode == "train" or self.mode=="valid":
            # get label(segmentation mask)
            label = self.labels[img_idx]
            label = self.get_grid_img(label, grid_idx)
            if self.transform:
                transformed = self.transform(image=img, mask=label)
                img = transformed["image"]
                label = transformed["mask"]
                label = label.permute(2, 0, 1)/255. # (channel, h, w)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            else:
                img = img.transpose(2, 0, 1) # (channel, h, w)
                label = label.transpose(2, 0, 1)/255. # (channel, h, w){}
                img = torch.tensor(img, dtype=torch.float32)
                label = torch.tensor(label, dtype=torch.float32)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            return img, label, grid_idx

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train")
# surface_volumes = dataset_notrans.surface_vols
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 1:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos=[0,50],mode="train")
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 1:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train", transform=train_transforms)
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)


# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 0:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %% [markdown]
# # train valid fn

# %%
def train_fn(train_loader, model, criterion, epoch ,optimizer, scheduler):
    model.train()
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, _) in enumerate(train_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()     
        preds = model(images)
        
        # preds = torch.sigmoid(preds)
        loss = criterion(preds, targets)
        
        losses.update(loss.item(), CFG["batch_size"]) 
        targets = targets.detach().cpu().numpy().ravel().tolist()
        preds = preds.detach().cpu().numpy().ravel().tolist()
        loss.backward() # パラメータの勾配を計算
        optimizer.step() # モデル更新
        optimizer.zero_grad() # 勾配の初期化
                
        batch_time.update(time.time() - end)
        end = time.time()
        if batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(train_loader)-1):
            print('Epoch: [{0}][{1}/{2}] '
                    'Elapsed {remain:s} '
                    'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                    .format(
                        epoch, batch_idx, len(train_loader), batch_time=batch_time, loss=losses,
                        remain=timeSince(start, float(batch_idx+1)/len(train_loader)),
            ))
        del preds, images, targets
    gc.collect()
    torch.cuda.empty_cache()
    return losses.avg

# %%
def valid_fn(model, valid_loader, criterion=None):
    model.eval()# モデルを検証モードに設定
    test_targets = []
    test_preds = []
    test_grid_idx = []
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, grid_idx) in enumerate(valid_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()
        with torch.no_grad():
            preds = model(images)
            if not criterion is None:
                loss = criterion(preds, targets)
        if not criterion is None:
            losses.update(loss.item(), CFG["batch_size"])
        batch_time.update(time.time() - end)

        targets = targets.detach().cpu().numpy()
        preds = preds.detach().cpu().numpy()
        
        test_preds.extend([preds[idx, :,:,:].transpose(1,2,0) for idx in range(preds.shape[0])])
        test_targets.extend([targets[idx, :,:,:].transpose(1,2,0) for idx in range(targets.shape[0])])
        test_grid_idx.extend([[x_idx, y_idx] for x_idx, y_idx in zip(grid_idx[0].tolist(), grid_idx[1].tolist())])

        if (batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(valid_loader)-1)) and (not criterion is None):
            print('EVAL: [{0}/{1}] '
                'Elapsed {remain:s} '
                'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                .format(
                    batch_idx, len(valid_loader), batch_time=batch_time, loss=losses,
                    remain=timeSince(start, float(batch_idx+1)/len(valid_loader)),
                ))
        del preds, images, targets
        gc.collect()
        torch.cuda.empty_cache()
    if criterion is None:
        return test_targets, test_preds, test_grid_idx
    else:
        return test_targets, test_preds, test_grid_idx, losses.avg

# %% [markdown]
# # training loop

# %%
# def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list):
#     # concat pred img and label to original size
#     img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
#     img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
#     img = img.reshape(img.shape[0], img.shape[1], 1)
#     pred_img = np.zeros_like(img).astype(np.float32)
#     label_img = np.zeros_like(img).astype(np.float32)
#     for img_idx, grid_idx in enumerate(grid_idx_list):
#         pred_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += img_list[img_idx]
        
#         label_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += label_list[img_idx]
#     return pred_img, label_img

# %%
def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list, slide_pos=[0,0]):
    # concat pred img and label to original size
    img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    img = img.reshape(img.shape[0], img.shape[1], 1)
    pred_img = np.zeros_like(img).astype(np.float32)
    label_img = np.zeros_like(img).astype(np.float32)
    for img_idx, grid_idx in enumerate(grid_idx_list):
        pred_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += img_list[img_idx]
        
        label_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += label_list[img_idx]
    return pred_img, label_img

# %%
def save_and_plot_oof(mode, fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary):
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_pred_img.png"), valid_preds_img*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_predbin_img.png"), valid_preds_binary*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_targets_img.png"), valid_targets_img*255)
    
    # plot preds & binary preds
    # plt.figure(dpi=100)
    # plt.subplot(1,3,1)
    # plt.imshow(valid_preds_img)
    # plt.subplot(1,3,2)
    # plt.imshow(valid_preds_binary)
    # plt.subplot(1,3,3)
    # plt.imshow(valid_targets_img)
    # plt.show()

# %%
def training_loop(CFG):
    best_score_list = []
    best_threshold_list = []
    best_epoch_list = []
    slice_ave_score_list = []
    slice_ave_auc_list = []
    slice_ave_score_threshold_list = []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} training start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        model = model.to(device)
        valid_img_slice = []
        criterion = nn.BCELoss()
        optimizer = AdamW(model.parameters(), lr=CFG["lr"], weight_decay=CFG["weight_decay"], amsgrad=False)
        scheduler = CosineAnnealingLR(optimizer, T_max=CFG["T_max"], eta_min=CFG["min_lr"], last_epoch=-1)
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            # separate train/valid data 
            train_dirs = CFG["TRAIN_DIR_LIST"][fold]
            valid_dirs = CFG["VALID_DIR_LIST"][fold]
            train_dataset = VCID_Dataset(CFG, train_dirs, surface_list, mode="train", transform=train_transforms)
            valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, mode="valid", transform=valid_transforms)
            train_loader = DataLoader(train_dataset, batch_size=CFG["batch_size"], shuffle = True,
                                        num_workers = CFG["num_workers"], pin_memory = True)
            valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                        num_workers = CFG["num_workers"], pin_memory = True)

            # training
            best_score = -np.inf
            best_auc = -np.inf
            best_valloss = np.inf
            best_auc_valloss = np.inf
            best_threshold = -1
            start_time = time.time()
            best_epoch = -1
            best_auc_epoch = -1
            for epoch in range(1, CFG["n_epoch"] + 1):
                epochs_ = epoch + CFG["n_epoch"] * slice_idx
                print(f'- epoch:{epochs_} -')
                train_loss_avg = train_fn(train_loader, model, criterion, epochs_ ,optimizer, scheduler)
                valid_targets, valid_preds, valid_grid_idx, valid_loss_avg = valid_fn(model, valid_loader, criterion)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                
                elapsed = time.time() - start_time
                print(f"\t epoch:{epochs_}, avg train loss:{train_loss_avg:.4f}, avg valid loss:{valid_loss_avg:.4f}")
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                if not CFG["DEBUG"]:
                    logging_metrics_epoch(CFG, fold, epoch, slice_idx, train_loss_avg, valid_loss_avg, valid_score, valid_threshold, auc)
                scheduler.step()
                # validationスコアがbestを更新したらモデルを保存する
                if valid_score > best_score:
                    best_epoch = epochs_
                    best_valloss = valid_loss_avg
                    best_score = valid_score
                    best_threshold = valid_threshold
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epochs_} - Save Best Score: {best_score:.4f}. Model is saved.')
                    print("dice_list: ", dice_list)
                    # save oof
                    save_and_plot_oof("score", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
                
                if auc > best_auc:
                    best_auc = auc
                    best_auc_epoch = epochs_
                    best_auc_valloss = valid_loss_avg
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_auc_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epochs_} - Save Best AUC: {best_auc:.4f}. Model is saved.')
                    # save oof
                    save_and_plot_oof("auc", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
            valid_img_slice.append(valid_preds_img)
        valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        for idx in range(len(SURFACE_LIST)):
            valid_pred_slice = valid_img_slice[idx]
            valid_slice_ave += valid_pred_slice
        valid_slice_ave /= len(CFG["folds"])
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_slice_ave)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)
 
        valid_slice_binary = (valid_slice_ave > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 999, valid_slice_ave, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
        
        print(f'[fold{fold}] BEST Epoch {best_epoch} - Save Best Score:{best_score:.4f}. Best loss:{best_valloss:.4f}')
        print(f'[fold{fold}] BEST AUC Epoch {best_auc_epoch} - Save Best Score:{best_auc:.4f}. Best loss:{best_auc_valloss:.4f}')
            
        best_score_list.append(best_score)
        best_threshold_list.append(best_threshold)
        best_epoch_list.append(best_epoch)
        del model, train_loader, train_dataset, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
        
    for fold, (best_score, best_threshold, best_epoch) in enumerate(zip(best_score_list, best_threshold_list, best_epoch_list)):
        print(f"fold[{fold}] BEST SCORE = {best_score:.4f} thr={best_threshold} (epoch={best_epoch})")
        print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    return best_score_list, best_threshold_list, best_epoch_list

# %% [markdown]
# # slice inference

# %%
def slide_inference(CFG):
    start_time = time.time()
    slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list = [], [], []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} slide inference start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        # model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_fold{fold}.pth')
        model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_auc_fold{fold}.pth')
        model.load_state_dict(torch.load(model_path))
        model = model.to(device)
        valid_img_slice = []
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            surface_volumes = None
            for slide_pos in CFG["slide_pos_list"]:
                print("slide pos:", slide_pos)
                valid_dirs = CFG["VALID_DIR_LIST"][fold]
                valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos, mode="valid", transform=valid_transforms)
                surface_volumes = valid_dataset.get_surface_volumes()
                valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                            num_workers = CFG["num_workers"], pin_memory = True)

                valid_targets, valid_preds, valid_grid_idx = valid_fn(model, valid_loader)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs, slide_pos)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                save_and_plot_oof("slide", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary) 
                
                elapsed = time.time() - start_time
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                valid_img_slice.append(valid_preds_img)
            valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        for idx in range(len(SURFACE_LIST)*len(CFG["slide_pos_list"])):
            valid_pred_slice = valid_img_slice[idx]
            valid_slice_ave += valid_pred_slice
        valid_slice_ave /= len(SURFACE_LIST)*len(CFG["slide_pos_list"])
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_slice_ave)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)

        valid_slice_binary = (valid_slice_ave > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 555, valid_slice_ave, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
         
        del model, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
    return slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list

# %% [markdown]
# # main

# %%
# %%time
best_score_list, best_threshold_list, best_epoch_list = training_loop(CFG)
# Out:
# -- fold0 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/conv.py:444: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at  ../aten/src/ATen/native/Convolution.cpp:744.)
#   self.padding, self.dilation, self.groups)
# Epoch: [1][0/130] Elapsed 0m 0s (remain 2m 0s) Loss: 0.7242(0.7242)
# Epoch: [1][129/130] Elapsed 0m 37s (remain 0m 0s) Loss: 0.4761(0.5917)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.3802(0.3802)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2967(0.4492)
# 	 epoch:1, avg train loss:0.5917, avg valid loss:0.4492
# 	 score:0.3704(th=0.700000), auc=0.828709::: time:54.10s
# Epoch 1 - Save Best Score: 0.3704. Model is saved.
# dice_list:  [0.15889547561542094, 0.1675611075950757, 0.1814412973978439, 0.19619397572465713, 0.21390116538682052, 0.23425253880878366, 0.2557137084708653, 0.27875044861747666, 0.3029380564304187, 0.32629795845335835, 0.3458408758880135, 0.36093298342328756, 0.37043940008772624, 0.36185056818123196, 0.3317047730635702, 0.2709567249685853, 0.15354069441210458, 0.03670419158141035, 0.0]
# Epoch 1 - Save Best AUC: 0.8287. Model is saved.
# - epoch:2 -
# Epoch: [2][0/130] Elapsed 0m 0s (remain 2m 0s) Loss: 0.5053(0.5053)
# Epoch: [2][129/130] Elapsed 0m 37s (remain 0m 0s) Loss: 0.5864(0.4374)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1838(0.1838)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2587(0.3665)
# 	 epoch:2, avg train loss:0.4374, avg valid loss:0.3665
# 	 score:0.3944(th=0.600000), auc=0.848771::: time:110.58s
# Epoch 2 - Save Best Score: 0.3944. Model is saved.
# dice_list:  [0.16230356655049913, 0.20585294092457543, 0.27850286333031127, 0.32528990489102644, 0.35230780092336644, 0.3706818380606264, 0.3832792531643074, 0.3892887750449609, 0.3913625790928669, 0.3938355791312127, 0.3943802943533332, 0.3895985838826199, 0.38078165168415157, 0.3711418725257884, 0.3600221078462418, 0.34207978505882586, 0.3135767794545411, 0.2593036595849684, 0.0]
# Epoch 2 - Save Best AUC: 0.8488. Model is saved.
# - epoch:3 -
# Epoch: [3][0/130] Elapsed 0m 0s (remain 2m 1s) Loss: 0.3436(0.3436)
# Epoch: [3][129/130] Elapsed 0m 37s (remain 0m 0s) Loss: 0.2522(0.3785)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1409(0.1409)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2366(0.2886)
# 	 epoch:3, avg train loss:0.3785, avg valid loss:0.2886
# 	 score:0.4577(th=0.450000), auc=0.873347::: time:167.24s
# Epoch 3 - Save Best Score: 0.4577. Model is saved.
# dice_list:  [0.22543980917466372, 0.29998897143751735, 0.3556402574654522, 0.40257515070194533, 0.4341294489763616, 0.44901393571808157, 0.45551793625399695, 0.4576749538498782, 0.43899064554608475, 0.4012237891077764, 0.3278130763703518, 0.22694671116604678, 0.12845876791565444, 0.05953554357652156, 0.02613103966056592, 0.010326190631100813, 0.001064762174421626, 0.0, 0.0]
# Epoch 3 - Save Best AUC: 0.8733. Model is saved.
# - epoch:4 -
# Epoch: [4][0/130] Elapsed 0m 0s (remain 1m 59s) Loss: 0.4335(0.4335)
# Epoch: [4][129/130] Elapsed 0m 37s (remain 0m 0s) Loss: 0.2154(0.3502)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.2881(0.2881)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1953(0.3357)
# 	 epoch:4, avg train loss:0.3502, avg valid loss:0.3357
# 	 score:0.4870(th=0.750000), auc=0.875894::: time:224.41s
# Epoch 4 - Save Best Score: 0.4870. Model is saved.
# dice_list:  [0.2135519373076553, 0.24821964107386243, 0.27582788954035226, 0.3011437620636488, 0.32363989953489425, 0.34538766633373824, 0.36600891297056093, 0.3868013799418282, 0.40688160306331617, 0.4276973047048413, 0.44796198279113436, 0.46509412970269814, 0.4771289464161629, 0.4869595018817419, 0.47446469438841, 0.42920715253867653, 0.339289296296094, 0.16085049540425822, 0.0]
# Epoch 4 - Save Best AUC: 0.8759. Model is saved.
# - epoch:5 -
# Epoch: [5][0/130] Elapsed 0m 0s (remain 1m 52s) Loss: 0.2258(0.2258)
# Epoch: [5][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.4797(0.3278)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.3071(0.3071)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1970(0.3492)
# 	 epoch:5, avg train loss:0.3278, avg valid loss:0.3492
# 	 score:0.4935(th=0.850000), auc=0.880656::: time:279.49s
# Epoch 5 - Save Best Score: 0.4935. Model is saved.
# dice_list:  [0.22452802298127103, 0.2600928437486641, 0.28838483459924313, 0.31275977765808416, 0.3320341254053773, 0.3484903456726812, 0.36389135642386516, 0.3803585115045883, 0.3977206232415066, 0.41409411148319625, 0.4301593921188834, 0.44413223926826556, 0.45969678148420456, 0.4775197397771044, 0.49160398717398907, 0.4934737547256077, 0.4539375639672958, 0.31180365361320345, 0.0]
# Epoch 5 - Save Best AUC: 0.8807. Model is saved.
# - epoch:6 -
# Epoch: [6][0/130] Elapsed 0m 0s (remain 1m 50s) Loss: 0.3755(0.3755)
# Epoch: [6][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2323(0.3170)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.3017(0.3017)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1970(0.3451)
# 	 epoch:6, avg train loss:0.3170, avg valid loss:0.3451
# 	 score:0.4935(th=0.800000), auc=0.881139::: time:334.44s
# Epoch 6 - Save Best Score: 0.4935. Model is saved.
# dice_list:  [0.22745069518501776, 0.26265343497847893, 0.2906308154559048, 0.3141618899106625, 0.33274049326878474, 0.3476369230533084, 0.3627709044300888, 0.3799516347004831, 0.3986721414491284, 0.4158363225590118, 0.4327306195717605, 0.448364840638147, 0.464635854387315, 0.48195787880148805, 0.49353955251486353, 0.49248769928509517, 0.44539350899768093, 0.29311114589898063, 0.0]
# Epoch 6 - Save Best AUC: 0.8811. Model is saved.
# - epoch:7 -
# Epoch: [7][0/130] Elapsed 0m 1s (remain 2m 10s) Loss: 0.4388(0.4388)
# Epoch: [7][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2517(0.3159)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2539(0.2539)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1909(0.3192)
# 	 epoch:7, avg train loss:0.3159, avg valid loss:0.3192
# 	 score:0.5030(th=0.750000), auc=0.890094::: time:389.49s
# Epoch 7 - Save Best Score: 0.5030. Model is saved.
# dice_list:  [0.23014342269763627, 0.27205692719724694, 0.3041950065850358, 0.3298839648364241, 0.3533069006135831, 0.3723882989743728, 0.39318994155446874, 0.41509257545424566, 0.4361095215636468, 0.4560974159406001, 0.4750306961585642, 0.49040085357522, 0.5005650655699213, 0.5029998751016045, 0.49995536469010093, 0.4775213853999382, 0.4117832549890021, 0.2528424245203533, 0.0]
# Epoch 7 - Save Best AUC: 0.8901. Model is saved.
# - epoch:8 -
# Epoch: [8][0/130] Elapsed 0m 0s (remain 2m 6s) Loss: 0.2831(0.2831)
# Epoch: [8][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2738(0.3196)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1251(0.1251)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2070(0.2702)
# 	 epoch:8, avg train loss:0.3196, avg valid loss:0.2702
# 	 score:0.5039(th=0.500000), auc=0.883085::: time:444.47s
# Epoch 8 - Save Best Score: 0.5039. Model is saved.
# dice_list:  [0.30012118388124054, 0.3596592232877168, 0.4066002041593919, 0.44164086269303005, 0.4664931248906681, 0.4865953045224019, 0.4986433074953668, 0.5029905387041856, 0.5038893559268874, 0.496271546190377, 0.4780072280935134, 0.44846415959001223, 0.40259871575962286, 0.3379625308186258, 0.25633916768665094, 0.174063227291699, 0.10494329444991224, 0.03397773793618353, 0.0]
# - epoch:9 -
# Epoch: [9][0/130] Elapsed 0m 0s (remain 1m 59s) Loss: 0.3152(0.3152)
# Epoch: [9][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2295(0.3279)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2175(0.2175)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2180(0.2988)
# 	 epoch:9, avg train loss:0.3279, avg valid loss:0.2988
# 	 score:0.5234(th=0.650000), auc=0.871492::: time:498.34s
# Epoch 9 - Save Best Score: 0.5234. Model is saved.
# dice_list:  [0.23770038791305792, 0.276504515566776, 0.3118310747097296, 0.343782646248335, 0.3747406604023388, 0.40323674970465867, 0.4297398166474458, 0.4559709680743416, 0.4807518308470336, 0.5007274544451097, 0.5165388759732414, 0.5234020539685647, 0.5118849122710093, 0.47616633780087886, 0.4131814565680413, 0.3119688987918939, 0.16630596085481722, 0.03542368823905799, 0.0]
# - epoch:10 -
# Epoch: [10][0/130] Elapsed 0m 0s (remain 1m 57s) Loss: 0.4157(0.4157)
# Epoch: [10][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.1979(0.3352)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2033(0.2033)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2086(0.3156)
# 	 epoch:10, avg train loss:0.3352, avg valid loss:0.3156
# 	 score:0.5020(th=0.750000), auc=0.872744::: time:552.68s
# surface_list:  range(27, 37, 3)
# - epoch:11 -
# Epoch: [11][0/130] Elapsed 0m 0s (remain 2m 1s) Loss: 0.2692(0.2692)
# Epoch: [11][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2128(0.3275)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.3494(0.3494)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2515(0.4299)
# 	 epoch:11, avg train loss:0.3275, avg valid loss:0.4299
# 	 score:0.4500(th=0.900000), auc=0.859352::: time:51.75s
# Epoch 11 - Save Best Score: 0.4500. Model is saved.
# dice_list:  [0.22155510759019645, 0.24675134551401484, 0.2676744915514591, 0.28391627205580283, 0.29706940118653813, 0.3091674874320267, 0.32057715023295785, 0.33151531663064226, 0.3418925002656395, 0.35343906108084094, 0.36535405998070297, 0.37720846734098884, 0.39221528748049894, 0.40625584013467814, 0.42116267623463854, 0.4387152984029159, 0.4499771495832991, 0.4282463211865406, 0.0]
# Epoch 11 - Save Best AUC: 0.8594. Model is saved.
# - epoch:12 -
# Epoch: [12][0/130] Elapsed 0m 0s (remain 2m 7s) Loss: 0.3218(0.3218)
# Epoch: [12][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3864(0.3214)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1273(0.1273)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2249(0.2747)
# 	 epoch:12, avg train loss:0.3214, avg valid loss:0.2747
# 	 score:0.5075(th=0.550000), auc=0.880682::: time:106.98s
# Epoch 12 - Save Best Score: 0.5075. Model is saved.
# dice_list:  [0.269000575985448, 0.32169852857455944, 0.3657452503510974, 0.4027946088376441, 0.43443192352663845, 0.4624398851259393, 0.48247898394708055, 0.4959781974876762, 0.5049651045805094, 0.5075438444486228, 0.5023107618161243, 0.4894384323331578, 0.46745210386009184, 0.4290639740999836, 0.3604488239736462, 0.2647805591036655, 0.15477800222262825, 0.04316054674786763, 0.0]
# Epoch 12 - Save Best AUC: 0.8807. Model is saved.
# - epoch:13 -
# Epoch: [13][0/130] Elapsed 0m 0s (remain 2m 4s) Loss: 0.2262(0.2262)
# Epoch: [13][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.5560(0.3020)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1054(0.1054)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1929(0.2709)
# 	 epoch:13, avg train loss:0.3020, avg valid loss:0.2709
# 	 score:0.5365(th=0.650000), auc=0.891192::: time:161.65s
# Epoch 13 - Save Best Score: 0.5365. Model is saved.
# dice_list:  [0.29333130968935, 0.34473889607808134, 0.3834230245234463, 0.4154013642666223, 0.4402557773637126, 0.4632475834246992, 0.4862922322569308, 0.5071883766204098, 0.5228012166107642, 0.5304913172965271, 0.5345331502086547, 0.536519974051057, 0.5320892426722947, 0.5218244832525739, 0.5015023695768587, 0.46627981424138865, 0.40675017598473584, 0.2854353938334789, 0.0]
# Epoch 13 - Save Best AUC: 0.8912. Model is saved.
# - epoch:14 -
# Epoch: [14][0/130] Elapsed 0m 0s (remain 1m 55s) Loss: 0.2638(0.2638)
# Epoch: [14][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2519(0.2864)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1738(0.1738)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1908(0.2892)
# 	 epoch:14, avg train loss:0.2864, avg valid loss:0.2892
# 	 score:0.5566(th=0.700000), auc=0.889247::: time:216.82s
# Epoch 14 - Save Best Score: 0.5566. Model is saved.
# dice_list:  [0.24759656892537055, 0.2921861447025053, 0.3317578736203235, 0.3668984771312964, 0.3994916195719571, 0.42921807355440333, 0.4569409602169374, 0.4810595718638475, 0.5008996238662383, 0.5163694935202852, 0.5306578322605202, 0.5456721625334608, 0.5565870106542873, 0.555197579908953, 0.5434667601776539, 0.5190148772519797, 0.45620466692121087, 0.3100753949220336, 0.0]
# - epoch:15 -
# Epoch: [15][0/130] Elapsed 0m 0s (remain 1m 58s) Loss: 0.1838(0.1838)
# Epoch: [15][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.6003(0.2590)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2048(0.2048)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1969(0.3204)
# 	 epoch:15, avg train loss:0.2590, avg valid loss:0.3204
# 	 score:0.5474(th=0.850000), auc=0.888666::: time:270.35s
# - epoch:16 -
# Epoch: [16][0/130] Elapsed 0m 0s (remain 1m 53s) Loss: 0.2764(0.2764)
# Epoch: [16][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.8554(0.2622)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1472(0.1472)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1916(0.2932)
# 	 epoch:16, avg train loss:0.2622, avg valid loss:0.2932
# 	 score:0.5511(th=0.800000), auc=0.886082::: time:323.02s
# - epoch:17 -
# Epoch: [17][0/130] Elapsed 0m 0s (remain 2m 5s) Loss: 0.2985(0.2985)
# Epoch: [17][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3034(0.2631)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.2227(0.2227)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1887(0.3197)
# 	 epoch:17, avg train loss:0.2631, avg valid loss:0.3197
# 	 score:0.5433(th=0.850000), auc=0.890227::: time:375.38s
# - epoch:18 -
# Epoch: [18][0/130] Elapsed 0m 0s (remain 1m 46s) Loss: 0.2413(0.2413)
# Epoch: [18][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.4213(0.2671)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1537(0.1537)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1730(0.2807)
# 	 epoch:18, avg train loss:0.2671, avg valid loss:0.2807
# 	 score:0.5607(th=0.700000), auc=0.888604::: time:427.27s
# Epoch 18 - Save Best Score: 0.5607. Model is saved.
# dice_list:  [0.282036545664847, 0.3206387231071655, 0.3506069774633877, 0.3806266021073872, 0.4083527634936073, 0.4337666593807211, 0.4594502573333072, 0.4819545751040579, 0.5024982339218493, 0.5214987552014424, 0.5372531964417191, 0.5520062188604504, 0.5606971340034098, 0.5565470433385926, 0.5385653427542977, 0.4884215808949052, 0.3907529533083285, 0.2391390948427118, 0.0]
# - epoch:19 -
# Epoch: [19][0/130] Elapsed 0m 0s (remain 1m 58s) Loss: 0.1879(0.1879)
# Epoch: [19][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2838(0.2764)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2350(0.2350)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1820(0.3435)
# 	 epoch:19, avg train loss:0.2764, avg valid loss:0.3435
# 	 score:0.5140(th=0.750000), auc=0.883543::: time:480.51s
# - epoch:20 -
# Epoch: [20][0/130] Elapsed 0m 0s (remain 1m 51s) Loss: 0.2062(0.2062)
# Epoch: [20][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3300(0.2846)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2863(0.2863)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1599(0.3484)
# 	 epoch:20, avg train loss:0.2846, avg valid loss:0.3484
# 	 score:0.5196(th=0.800000), auc=0.883843::: time:532.63s
# surface_list:  range(25, 35, 3)
# - epoch:21 -
# Epoch: [21][0/130] Elapsed 0m 0s (remain 2m 4s) Loss: 0.2439(0.2439)
# Epoch: [21][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2242(0.3141)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.0610(0.0610)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2108(0.2593)
# 	 epoch:21, avg train loss:0.3141, avg valid loss:0.2593
# 	 score:0.5492(th=0.500000), auc=0.892627::: time:52.84s
# Epoch 21 - Save Best Score: 0.5492. Model is saved.
# dice_list:  [0.3316713783704651, 0.39208417228077125, 0.43267837748278226, 0.4644074581488145, 0.4935184796647405, 0.5160226230287878, 0.5357262071132495, 0.5466175618604512, 0.5492306225981421, 0.5439378730086752, 0.5312950251902246, 0.5051917515536244, 0.4682160721223399, 0.4199148923587833, 0.3456050002621777, 0.23218406999674276, 0.11041042664158093, 0.020769183726737906, 0.0]
# Epoch 21 - Save Best AUC: 0.8926. Model is saved.
# - epoch:22 -
# Epoch: [22][0/130] Elapsed 0m 1s (remain 2m 9s) Loss: 0.2024(0.2024)
# Epoch: [22][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2647(0.2936)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.0953(0.0953)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1841(0.2757)
# 	 epoch:22, avg train loss:0.2936, avg valid loss:0.2757
# 	 score:0.5469(th=0.650000), auc=0.881906::: time:107.93s
# - epoch:23 -
# Epoch: [23][0/130] Elapsed 0m 1s (remain 2m 13s) Loss: 0.2244(0.2244)
# Epoch: [23][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.8905(0.2703)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2751(0.2751)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3688(0.3495)
# 	 epoch:23, avg train loss:0.2703, avg valid loss:0.3495
# 	 score:0.4361(th=0.400000), auc=0.862557::: time:159.99s
# - epoch:24 -
# Epoch: [24][0/130] Elapsed 0m 0s (remain 1m 59s) Loss: 0.2503(0.2503)
# Epoch: [24][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.1900(0.2573)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.0664(0.0664)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2075(0.2602)
# 	 epoch:24, avg train loss:0.2573, avg valid loss:0.2602
# 	 score:0.5553(th=0.550000), auc=0.890381::: time:211.99s
# Epoch 24 - Save Best Score: 0.5553. Model is saved.
# dice_list:  [0.33212486594099255, 0.39539702396904114, 0.43937171655978574, 0.46975596125058894, 0.4935328961810189, 0.5142724433474724, 0.5318346290264716, 0.5444989394817379, 0.5532416775185068, 0.5553133924542215, 0.5515846365687408, 0.5396475070275536, 0.5244645977777538, 0.5008848427973451, 0.4628520682304344, 0.41191517977037845, 0.3270504542565562, 0.2150433349030797, 0.0]
# - epoch:25 -
# Epoch: [25][0/130] Elapsed 0m 0s (remain 2m 3s) Loss: 0.2478(0.2478)
# Epoch: [25][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3238(0.2255)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1226(0.1226)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2032(0.3010)
# 	 epoch:25, avg train loss:0.2255, avg valid loss:0.3010
# 	 score:0.5604(th=0.850000), auc=0.890427::: time:265.02s
# Epoch 25 - Save Best Score: 0.5604. Model is saved.
# dice_list:  [0.2913938757634648, 0.33279537046504465, 0.3639698798509606, 0.38900141486830175, 0.41076905912492834, 0.43028168594986826, 0.44836390171949214, 0.4669302437234603, 0.4838169264068068, 0.4983960411684172, 0.5120723510444526, 0.5278697323767914, 0.5433924445274343, 0.5530388695188289, 0.5603199541912699, 0.5604022515086496, 0.5468672037712649, 0.4859368119197132, 0.0]
# - epoch:26 -
# Epoch: [26][0/130] Elapsed 0m 0s (remain 1m 48s) Loss: 0.2281(0.2281)
# Epoch: [26][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2748(0.2300)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1497(0.1497)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2033(0.3202)
# 	 epoch:26, avg train loss:0.2300, avg valid loss:0.3202
# 	 score:0.5575(th=0.850000), auc=0.889896::: time:318.54s
# - epoch:27 -
# Epoch: [27][0/130] Elapsed 0m 0s (remain 1m 57s) Loss: 0.1635(0.1635)
# Epoch: [27][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.3251(0.2278)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1053(0.1053)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2004(0.2849)
# 	 epoch:27, avg train loss:0.2278, avg valid loss:0.2849
# 	 score:0.5618(th=0.750000), auc=0.888994::: time:371.72s
# Epoch 27 - Save Best Score: 0.5618. Model is saved.
# dice_list:  [0.3109238259141661, 0.3536569112329475, 0.3851912479304714, 0.4118993166970554, 0.43470038548914774, 0.45425940645893376, 0.4708381183020907, 0.488096306293438, 0.5048107011418822, 0.5201271959538092, 0.5351394081304774, 0.5450433239250969, 0.5549383543968792, 0.561800843681887, 0.5595255803714122, 0.5476666343213275, 0.5123738434630638, 0.3968324484443884, 0.0]
# - epoch:28 -
# Epoch: [28][0/130] Elapsed 0m 0s (remain 2m 2s) Loss: 0.1930(0.1930)
# Epoch: [28][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.4548(0.2409)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1127(0.1127)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1884(0.2993)
# 	 epoch:28, avg train loss:0.2409, avg valid loss:0.2993
# 	 score:0.5599(th=0.750000), auc=0.887825::: time:424.98s
# - epoch:29 -
# Epoch: [29][0/130] Elapsed 0m 0s (remain 1m 50s) Loss: 0.2031(0.2031)
# Epoch: [29][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2539(0.2461)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.2186(0.2186)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1671(0.3454)
# 	 epoch:29, avg train loss:0.2461, avg valid loss:0.3454
# 	 score:0.5045(th=0.800000), auc=0.886858::: time:477.33s
# - epoch:30 -
# Epoch: [30][0/130] Elapsed 0m 0s (remain 1m 51s) Loss: 0.3002(0.3002)
# Epoch: [30][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.4652(0.2555)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.0554(0.0554)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1854(0.2740)
# 	 epoch:30, avg train loss:0.2555, avg valid loss:0.2740
# 	 score:0.5785(th=0.700000), auc=0.888234::: time:529.69s
# Epoch 30 - Save Best Score: 0.5785. Model is saved.
# dice_list:  [0.29103229966020827, 0.3340541025058879, 0.3738957647207561, 0.4090902917445583, 0.4421655409359756, 0.4737867403801347, 0.5002531539921848, 0.5236703672671323, 0.5442437215822079, 0.5599915947972492, 0.570596108901367, 0.5783933920131514, 0.578547876083305, 0.5667544350119464, 0.5366816027142588, 0.47706909456867613, 0.3694331587909068, 0.2068271269593613, 0.0]
# [fold0] slice ave score:0.5783(th=0.700000), auc=0.889078
# [fold0] BEST Epoch 30 - Save Best Score:0.5785. Best loss:0.2740
# [fold0] BEST AUC Epoch 21 - Save Best Score:0.8926. Best loss:0.2593
# -- fold1 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# Epoch: [1][0/58] Elapsed 0m 0s (remain 0m 49s) Loss: 0.7661(0.7661)
# Epoch: [1][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.5464(0.6684)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.3727(0.3727)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3756(0.6565)
# 	 epoch:1, avg train loss:0.6684, avg valid loss:0.6565
# 	 score:0.3916(th=0.750000), auc=0.798052::: time:77.86s
# Epoch 1 - Save Best Score: 0.3916. Model is saved.
# dice_list:  [0.19682020310492132, 0.19682415021024133, 0.19687297950492225, 0.19901120043314283, 0.2172735790312324, 0.24049192786889803, 0.265185254492776, 0.28935165990632106, 0.31283615282365146, 0.3353545576930029, 0.35644307532479835, 0.3736138284486542, 0.38556649219423134, 0.39158523217809843, 0.38902328685900134, 0.37350792832520446, 0.3307807359777147, 0.21743939174279017, 0.0]
# Epoch 1 - Save Best AUC: 0.7981. Model is saved.
# - epoch:2 -
# Epoch: [2][0/58] Elapsed 0m 0s (remain 0m 48s) Loss: 0.6494(0.6494)
# Epoch: [2][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.4814(0.5639)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 26s) Loss: 0.2304(0.2304)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2302(0.4755)
# 	 epoch:2, avg train loss:0.5639, avg valid loss:0.4755
# 	 score:0.3415(th=0.450000), auc=0.779911::: time:163.60s
# - epoch:3 -
# Epoch: [3][0/58] Elapsed 0m 0s (remain 0m 56s) Loss: 0.5320(0.5320)
# Epoch: [3][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.4646(0.4646)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.2278(0.2278)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2279(0.4436)
# 	 epoch:3, avg train loss:0.4646, avg valid loss:0.4436
# 	 score:0.3885(th=0.400000), auc=0.790247::: time:243.35s
# - epoch:4 -
# Epoch: [4][0/58] Elapsed 0m 1s (remain 0m 57s) Loss: 0.3541(0.3541)
# Epoch: [4][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.3557(0.3954)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1507(0.1507)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1495(0.4146)
# 	 epoch:4, avg train loss:0.3954, avg valid loss:0.4146
# 	 score:0.4018(th=0.300000), auc=0.796129::: time:322.43s
# Epoch 4 - Save Best Score: 0.4018. Model is saved.
# dice_list:  [0.1971484824339752, 0.22342480473445733, 0.28485059844513905, 0.3599631802502562, 0.40183600939885405, 0.3947932731079871, 0.36462938085703356, 0.32338953808344495, 0.2796803608300552, 0.23706767566123646, 0.19585099388673072, 0.1586945279011087, 0.12520330511926286, 0.09728531962395165, 0.07255601273155522, 0.049698847033330454, 0.02988295752338163, 0.015654204968870166, 0.0]
# - epoch:5 -
# Epoch: [5][0/58] Elapsed 0m 0s (remain 0m 52s) Loss: 0.3864(0.3864)
# Epoch: [5][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.3175(0.3675)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 27s) Loss: 0.1613(0.1613)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1514(0.4079)
# 	 epoch:5, avg train loss:0.3675, avg valid loss:0.4079
# 	 score:0.4169(th=0.300000), auc=0.798376::: time:404.39s
# Epoch 5 - Save Best Score: 0.4169. Model is saved.
# dice_list:  [0.19735999967286974, 0.24373240420713435, 0.319115177214918, 0.37956806355606953, 0.41687019567270694, 0.4153916253303685, 0.3948895354372508, 0.36419931460958016, 0.3302901415349705, 0.2908762510701129, 0.24797031029028238, 0.20371674148432092, 0.16424381625989215, 0.12784862135745842, 0.09529134238855398, 0.0663006771903849, 0.04066501924394133, 0.016463217686456373, 0.0]
# Epoch 5 - Save Best AUC: 0.7984. Model is saved.
# - epoch:6 -
# Epoch: [6][0/58] Elapsed 0m 0s (remain 0m 48s) Loss: 0.3236(0.3236)
# Epoch: [6][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.5740(0.3521)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.1477(0.1477)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1412(0.4062)
# 	 epoch:6, avg train loss:0.3521, avg valid loss:0.4062
# 	 score:0.4169(th=0.300000), auc=0.799447::: time:489.15s
# Epoch 6 - Save Best Score: 0.4169. Model is saved.
# dice_list:  [0.19782411680863357, 0.2530797144781476, 0.33091237790600736, 0.39083797552574073, 0.41691454011089735, 0.40407850205284784, 0.3764096520796181, 0.34392084854600224, 0.30683465885665473, 0.26597190906771173, 0.22529020851502363, 0.18636402473906116, 0.15061547302978606, 0.11830722644099258, 0.0900391404525814, 0.06431056158106424, 0.04049006282625259, 0.01810924114311192, 0.0]
# Epoch 6 - Save Best AUC: 0.7994. Model is saved.
# - epoch:7 -
# Epoch: [7][0/58] Elapsed 0m 0s (remain 0m 56s) Loss: 0.3366(0.3366)
# Epoch: [7][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.4054(0.3455)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1807(0.1807)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1610(0.4105)
# 	 epoch:7, avg train loss:0.3455, avg valid loss:0.4105
# 	 score:0.4096(th=0.350000), auc=0.795057::: time:575.14s
# - epoch:8 -
# Epoch: [8][0/58] Elapsed 0m 0s (remain 0m 55s) Loss: 0.3211(0.3211)
# Epoch: [8][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.3428(0.3405)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1284(0.1284)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.1273(0.4092)
# 	 epoch:8, avg train loss:0.3405, avg valid loss:0.4092
# 	 score:0.4052(th=0.250000), auc=0.793314::: time:654.93s
# - epoch:9 -
# Epoch: [9][0/58] Elapsed 0m 0s (remain 0m 50s) Loss: 0.2503(0.2503)
# Epoch: [9][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3219(0.3249)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0792(0.0792)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0820(0.4134)
# 	 epoch:9, avg train loss:0.3249, avg valid loss:0.4134
# 	 score:0.3873(th=0.200000), auc=0.785649::: time:733.94s
# - epoch:10 -
# Epoch: [10][0/58] Elapsed 0m 1s (remain 0m 57s) Loss: 0.3403(0.3403)
# Epoch: [10][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3154(0.3045)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0351(0.0351)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0404(0.4364)
# 	 epoch:10, avg train loss:0.3045, avg valid loss:0.4364
# 	 score:0.3845(th=0.150000), auc=0.799261::: time:812.17s
# surface_list:  range(27, 37, 3)
# - epoch:11 -
# Epoch: [11][0/58] Elapsed 0m 0s (remain 0m 54s) Loss: 0.2294(0.2294)
# Epoch: [11][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2289(0.2922)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0261(0.0261)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0272(0.4432)
# 	 epoch:11, avg train loss:0.2922, avg valid loss:0.4432
# 	 score:0.3956(th=0.200000), auc=0.797502::: time:77.76s
# Epoch 11 - Save Best Score: 0.3956. Model is saved.
# dice_list:  [0.35452371847000885, 0.3947783016177279, 0.3955738916401371, 0.36736737123396285, 0.32715710980399376, 0.283561133696812, 0.23916527111806543, 0.19774807108118767, 0.16146868715650264, 0.13019871038520703, 0.10168400957822284, 0.07804008516448113, 0.05788294707441331, 0.04097563652405902, 0.02709570259542636, 0.017310937007744113, 0.00899052943119083, 0.002143444879502593, 0.0]
# Epoch 11 - Save Best AUC: 0.7975. Model is saved.
# - epoch:12 -
# Epoch: [12][0/58] Elapsed 0m 0s (remain 0m 51s) Loss: 0.4407(0.4407)
# Epoch: [12][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1477(0.2724)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0376(0.0376)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0422(0.4363)
# 	 epoch:12, avg train loss:0.2724, avg valid loss:0.4363
# 	 score:0.3839(th=0.200000), auc=0.790107::: time:162.09s
# - epoch:13 -
# Epoch: [13][0/58] Elapsed 0m 1s (remain 0m 58s) Loss: 0.1779(0.1779)
# Epoch: [13][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1403(0.2564)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0330(0.0330)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0389(0.5078)
# 	 epoch:13, avg train loss:0.2564, avg valid loss:0.5078
# 	 score:0.3990(th=0.150000), auc=0.771193::: time:240.26s
# Epoch 13 - Save Best Score: 0.3990. Model is saved.
# dice_list:  [0.3948898224128942, 0.39902331098548893, 0.37146753436066154, 0.3342726773175918, 0.2944194734739289, 0.25318891708221114, 0.21243708103906303, 0.1746863640451317, 0.14503264594766038, 0.12111335640063074, 0.09970276367471638, 0.08055837704998163, 0.06263614281396335, 0.0473925776968392, 0.033814953326798604, 0.020625266209875526, 0.009966246421684158, 0.0023609529255663978, 0.0]
# - epoch:14 -
# Epoch: [14][0/58] Elapsed 0m 1s (remain 0m 59s) Loss: 0.1556(0.1556)
# Epoch: [14][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3144(0.2398)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.0252(0.0252)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0311(0.5030)
# 	 epoch:14, avg train loss:0.2398, avg valid loss:0.5030
# 	 score:0.4027(th=0.100000), auc=0.787796::: time:320.69s
# Epoch 14 - Save Best Score: 0.4027. Model is saved.
# dice_list:  [0.40271708739341555, 0.395325988240585, 0.36849660047084287, 0.33394016578959745, 0.30029395459645575, 0.2704389862567325, 0.24624618620915542, 0.2227142690098597, 0.19907566545369784, 0.1784878072853793, 0.15807381399426762, 0.1378768063794511, 0.11845875759594039, 0.0989321099619849, 0.07880940903045794, 0.057203457228101245, 0.035977482955499095, 0.016170717881764784, 0.0]
# - epoch:15 -
# Epoch: [15][0/58] Elapsed 0m 1s (remain 0m 58s) Loss: 0.1832(0.1832)
# Epoch: [15][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3166(0.2311)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0217(0.0217)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0237(0.5169)
# 	 epoch:15, avg train loss:0.2311, avg valid loss:0.5169
# 	 score:0.4073(th=0.100000), auc=0.789849::: time:401.33s
# Epoch 15 - Save Best Score: 0.4073. Model is saved.
# dice_list:  [0.40728779880606597, 0.39340473046530444, 0.3647381080117242, 0.32811106177186405, 0.29191680631220224, 0.25719608222948426, 0.22596016185252807, 0.19678638670306575, 0.16842078874786415, 0.14202333596267228, 0.11841588082765622, 0.0974760239759877, 0.07764090106808397, 0.05987248160538568, 0.04480132418585767, 0.029547506524906012, 0.016010801633219118, 0.004736107027736799, 0.0]
# - epoch:16 -
# Epoch: [16][0/58] Elapsed 0m 1s (remain 0m 57s) Loss: 0.2592(0.2592)
# Epoch: [16][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2559(0.2186)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0206(0.0206)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0225(0.5392)
# 	 epoch:16, avg train loss:0.2186, avg valid loss:0.5392
# 	 score:0.3968(th=0.100000), auc=0.783020::: time:481.27s
# - epoch:17 -
# Epoch: [17][0/58] Elapsed 0m 1s (remain 0m 57s) Loss: 0.2330(0.2330)
# Epoch: [17][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1820(0.2164)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.0253(0.0253)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0287(0.5283)
# 	 epoch:17, avg train loss:0.2164, avg valid loss:0.5283
# 	 score:0.3930(th=0.100000), auc=0.773755::: time:559.79s
# - epoch:18 -
# Epoch: [18][0/58] Elapsed 0m 0s (remain 0m 55s) Loss: 0.3679(0.3679)
# Epoch: [18][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2201(0.2158)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0181(0.0181)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0241(0.5595)
# 	 epoch:18, avg train loss:0.2158, avg valid loss:0.5595
# 	 score:0.3759(th=0.100000), auc=0.759804::: time:638.59s
# - epoch:19 -
# Epoch: [19][0/58] Elapsed 0m 0s (remain 0m 56s) Loss: 0.1761(0.1761)
# Epoch: [19][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2694(0.2258)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0146(0.0146)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0171(0.5094)
# 	 epoch:19, avg train loss:0.2258, avg valid loss:0.5094
# 	 score:0.3730(th=0.150000), auc=0.786338::: time:717.11s
# - epoch:20 -
# Epoch: [20][0/58] Elapsed 0m 1s (remain 0m 57s) Loss: 0.2312(0.2312)
# Epoch: [20][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2269(0.2296)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0234(0.0234)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0238(0.5260)
# 	 epoch:20, avg train loss:0.2296, avg valid loss:0.5260
# 	 score:0.3793(th=0.150000), auc=0.778081::: time:795.81s
# surface_list:  range(25, 35, 3)
# - epoch:21 -
# Epoch: [21][0/58] Elapsed 0m 0s (remain 0m 56s) Loss: 0.2467(0.2467)
# Epoch: [21][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1993(0.2727)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0122(0.0122)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0171(0.4427)
# 	 epoch:21, avg train loss:0.2727, avg valid loss:0.4427
# 	 score:0.4112(th=0.450000), auc=0.805836::: time:77.67s
# Epoch 21 - Save Best Score: 0.4112. Model is saved.
# dice_list:  [0.3211498152771749, 0.3485972948149683, 0.3689797311002251, 0.3847117319830211, 0.3968383113851549, 0.4051863747374892, 0.4097625113727022, 0.4112192663295503, 0.4085156421866894, 0.40127531070573175, 0.3888691202744515, 0.370552438999142, 0.34830181048020525, 0.32028764082795025, 0.28192910048164815, 0.23023931563145303, 0.16465682423608236, 0.08790567647470941, 0.0]
# Epoch 21 - Save Best AUC: 0.8058. Model is saved.
# - epoch:22 -
# Epoch: [22][0/58] Elapsed 0m 1s (remain 0m 57s) Loss: 0.1690(0.1690)
# Epoch: [22][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1954(0.2391)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 39s) Loss: 0.0115(0.0115)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0082(0.5037)
# 	 epoch:22, avg train loss:0.2391, avg valid loss:0.5037
# 	 score:0.3841(th=0.150000), auc=0.790030::: time:162.23s
# - epoch:23 -
# Epoch: [23][0/58] Elapsed 0m 0s (remain 0m 51s) Loss: 0.2701(0.2701)
# Epoch: [23][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.6012(0.2350)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.0184(0.0184)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0065(0.6160)
# 	 epoch:23, avg train loss:0.2350, avg valid loss:0.6160
# 	 score:0.3867(th=0.100000), auc=0.781369::: time:239.71s
# - epoch:24 -
# Epoch: [24][0/58] Elapsed 0m 0s (remain 0m 55s) Loss: 0.1504(0.1504)
# Epoch: [24][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1816(0.2051)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0173(0.0173)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0138(0.5974)
# 	 epoch:24, avg train loss:0.2051, avg valid loss:0.5974
# 	 score:0.3711(th=0.100000), auc=0.776017::: time:316.49s
# - epoch:25 -
# Epoch: [25][0/58] Elapsed 0m 0s (remain 0m 56s) Loss: 0.2184(0.2184)
# Epoch: [25][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2809(0.2005)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0182(0.0182)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0119(0.6102)
# 	 epoch:25, avg train loss:0.2005, avg valid loss:0.6102
# 	 score:0.3817(th=0.100000), auc=0.779110::: time:394.87s
# - epoch:26 -
# Epoch: [26][0/58] Elapsed 0m 0s (remain 0m 54s) Loss: 0.1616(0.1616)
# Epoch: [26][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1812(0.1830)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.0205(0.0205)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0123(0.5909)
# 	 epoch:26, avg train loss:0.1830, avg valid loss:0.5909
# 	 score:0.3933(th=0.100000), auc=0.783036::: time:472.87s
# - epoch:27 -
# Epoch: [27][0/58] Elapsed 0m 0s (remain 0m 53s) Loss: 0.1763(0.1763)
# Epoch: [27][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1661(0.1981)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0278(0.0278)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0122(0.5704)
# 	 epoch:27, avg train loss:0.1981, avg valid loss:0.5704
# 	 score:0.3975(th=0.100000), auc=0.787286::: time:549.90s
# - epoch:28 -
# Epoch: [28][0/58] Elapsed 0m 0s (remain 0m 50s) Loss: 0.1743(0.1743)
# Epoch: [28][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1436(0.1858)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.0149(0.0149)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0102(0.6218)
# 	 epoch:28, avg train loss:0.1858, avg valid loss:0.6218
# 	 score:0.3765(th=0.100000), auc=0.771100::: time:627.20s
# - epoch:29 -
# Epoch: [29][0/58] Elapsed 0m 0s (remain 0m 53s) Loss: 0.2247(0.2247)
# Epoch: [29][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2809(0.1953)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.0279(0.0279)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0245(0.5414)
# 	 epoch:29, avg train loss:0.1953, avg valid loss:0.5414
# 	 score:0.3941(th=0.150000), auc=0.791344::: time:706.02s
# - epoch:30 -
# Epoch: [30][0/58] Elapsed 0m 0s (remain 0m 56s) Loss: 0.1973(0.1973)
# Epoch: [30][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3552(0.1973)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0096(0.0096)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0176(0.6220)
# 	 epoch:30, avg train loss:0.1973, avg valid loss:0.6220
# 	 score:0.3651(th=0.150000), auc=0.768587::: time:784.09s
# [fold1] slice ave score:0.4267(th=0.150000), auc=0.809144
# [fold1] BEST Epoch 21 - Save Best Score:0.4112. Best loss:0.4427
# [fold1] BEST AUC Epoch 21 - Save Best Score:0.8058. Best loss:0.4427
# -- fold2 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# Epoch: [1][0/125] Elapsed 0m 1s (remain 2m 7s) Loss: 0.7180(0.7180)
# Epoch: [1][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.4564(0.5677)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.3225(0.3225)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.3114(0.4827)
# 	 epoch:1, avg train loss:0.5677, avg valid loss:0.4827
# 	 score:0.3921(th=0.450000), auc=0.857430::: time:56.07s
# Epoch 1 - Save Best Score: 0.3921. Model is saved.
# dice_list:  [0.1985037673071646, 0.19899745729667154, 0.21922636699764353, 0.23875247520147455, 0.2761271475856764, 0.33809542225098316, 0.37405979752609014, 0.39205357221498166, 0.3742511852427723, 0.30469916020984344, 0.2070426035315909, 0.11397319343801351, 0.054549723641438154, 0.01889172174215904, 0.004909135657724692, 0.0010516206847223384, 0.0, 0.0, 0.0]
# Epoch 1 - Save Best AUC: 0.8574. Model is saved.
# - epoch:2 -
# Epoch: [2][0/125] Elapsed 0m 1s (remain 2m 7s) Loss: 0.4559(0.4559)
# Epoch: [2][124/125] Elapsed 0m 36s (remain 0m 0s) Loss: 0.3462(0.4234)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1887(0.1887)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1564(0.3891)
# 	 epoch:2, avg train loss:0.4234, avg valid loss:0.3891
# 	 score:0.4332(th=0.300000), auc=0.861049::: time:115.85s
# Epoch 2 - Save Best Score: 0.4332. Model is saved.
# dice_list:  [0.23407984008874844, 0.29520196455194386, 0.38371775650417045, 0.4309505614621473, 0.433188584147858, 0.42517347429443875, 0.4107204212537034, 0.39113820539176264, 0.36837738029740397, 0.3446907147394947, 0.3217585215556715, 0.2948591891424146, 0.26506941861521294, 0.23138345965645568, 0.19503630053725451, 0.1569991321733009, 0.10541923902000241, 0.04926525669597743, 0.0]
# Epoch 2 - Save Best AUC: 0.8610. Model is saved.
# - epoch:3 -
# Epoch: [3][0/125] Elapsed 0m 1s (remain 2m 8s) Loss: 0.3295(0.3295)
# Epoch: [3][124/125] Elapsed 0m 36s (remain 0m 0s) Loss: 0.3834(0.3645)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1693(0.1693)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1550(0.3754)
# 	 epoch:3, avg train loss:0.3645, avg valid loss:0.3754
# 	 score:0.4791(th=0.500000), auc=0.877743::: time:175.46s
# Epoch 3 - Save Best Score: 0.4791. Model is saved.
# dice_list:  [0.2517639182852863, 0.2895032168230174, 0.3370825956369731, 0.385369469455768, 0.4261214309296698, 0.4547971525833432, 0.4695860459436804, 0.47700119895043, 0.47913106453690424, 0.4767149931402704, 0.46777750615735647, 0.4518802730161575, 0.42696333329022895, 0.3930832608285537, 0.3444618550755766, 0.2625020270635906, 0.1528193607797527, 0.03800613591173385, 0.0]
# Epoch 3 - Save Best AUC: 0.8777. Model is saved.
# - epoch:4 -
# Epoch: [4][0/125] Elapsed 0m 0s (remain 1m 56s) Loss: 0.2769(0.2769)
# Epoch: [4][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2947(0.3346)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2186(0.2186)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1542(0.4014)
# 	 epoch:4, avg train loss:0.3346, avg valid loss:0.4014
# 	 score:0.4927(th=0.650000), auc=0.880399::: time:234.51s
# Epoch 4 - Save Best Score: 0.4927. Model is saved.
# dice_list:  [0.2605014247504025, 0.289719980937758, 0.31637481231308034, 0.338108489539398, 0.3581177589262801, 0.3804107531516911, 0.40488875102890554, 0.4305970020133872, 0.4551166771937407, 0.4755904006109666, 0.48845922005307635, 0.4927445889260721, 0.48386747607482666, 0.4612723366791715, 0.42114222385002065, 0.3524967310160717, 0.25518256509956017, 0.11505159740658591, 0.0]
# Epoch 4 - Save Best AUC: 0.8804. Model is saved.
# - epoch:5 -
# Epoch: [5][0/125] Elapsed 0m 0s (remain 2m 1s) Loss: 0.3954(0.3954)
# Epoch: [5][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3242(0.3116)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1894(0.1894)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1412(0.3763)
# 	 epoch:5, avg train loss:0.3116, avg valid loss:0.3763
# 	 score:0.4642(th=0.550000), auc=0.878025::: time:293.09s
# - epoch:6 -
# Epoch: [6][0/125] Elapsed 0m 1s (remain 2m 7s) Loss: 0.3215(0.3215)
# Epoch: [6][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2633(0.3126)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2314(0.2314)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1650(0.4005)
# 	 epoch:6, avg train loss:0.3126, avg valid loss:0.4005
# 	 score:0.4667(th=0.650000), auc=0.878030::: time:347.96s
# - epoch:7 -
# Epoch: [7][0/125] Elapsed 0m 0s (remain 2m 2s) Loss: 0.3119(0.3119)
# Epoch: [7][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3460(0.3079)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2314(0.2314)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1619(0.4017)
# 	 epoch:7, avg train loss:0.3079, avg valid loss:0.4017
# 	 score:0.5184(th=0.700000), auc=0.888039::: time:402.61s
# Epoch 7 - Save Best Score: 0.5184. Model is saved.
# dice_list:  [0.26697457414507614, 0.29590866345618316, 0.3225277859122648, 0.34499742478480844, 0.3665852487001331, 0.3893184547528147, 0.41115915209698745, 0.43543613443059365, 0.45962730227151766, 0.48323032094034735, 0.5018182208613691, 0.513556964417105, 0.518383595494101, 0.5095637952858301, 0.47488390393495195, 0.4151757695103369, 0.3153674606068415, 0.15379226725572928, 0.0]
# Epoch 7 - Save Best AUC: 0.8880. Model is saved.
# - epoch:8 -
# Epoch: [8][0/125] Elapsed 0m 0s (remain 1m 59s) Loss: 0.3735(0.3735)
# Epoch: [8][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2901(0.3170)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1704(0.1704)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1177(0.3696)
# 	 epoch:8, avg train loss:0.3170, avg valid loss:0.3696
# 	 score:0.4674(th=0.500000), auc=0.878342::: time:460.68s
# - epoch:9 -
# Epoch: [9][0/125] Elapsed 0m 1s (remain 2m 8s) Loss: 0.3923(0.3923)
# Epoch: [9][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2285(0.3187)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1197(0.1197)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1030(0.3628)
# 	 epoch:9, avg train loss:0.3187, avg valid loss:0.3628
# 	 score:0.4968(th=0.400000), auc=0.881846::: time:515.40s
# - epoch:10 -
# Epoch: [10][0/125] Elapsed 0m 0s (remain 1m 50s) Loss: 0.3023(0.3023)
# Epoch: [10][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3939(0.3246)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 10s) Loss: 0.1804(0.1804)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1825(0.3878)
# 	 epoch:10, avg train loss:0.3246, avg valid loss:0.3878
# 	 score:0.4334(th=0.500000), auc=0.869084::: time:570.71s
# surface_list:  range(27, 37, 3)
# - epoch:11 -
# Epoch: [11][0/125] Elapsed 0m 0s (remain 2m 2s) Loss: 0.3807(0.3807)
# Epoch: [11][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3175(0.3169)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1616(0.1616)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0870(0.3820)
# 	 epoch:11, avg train loss:0.3169, avg valid loss:0.3820
# 	 score:0.4481(th=0.500000), auc=0.875779::: time:54.64s
# Epoch 11 - Save Best Score: 0.4481. Model is saved.
# dice_list:  [0.3196684559196115, 0.3502467998769862, 0.37738791320184917, 0.39947661083924424, 0.4163948782336856, 0.4284941785145743, 0.4371978099716915, 0.4438112964122637, 0.4480704039850721, 0.4478232524433238, 0.4407630370129522, 0.4246204143727767, 0.3951047530966039, 0.3519088950546355, 0.28552015803851866, 0.19457086595537204, 0.0942124879309056, 0.0149016436935111, 0.0]
# Epoch 11 - Save Best AUC: 0.8758. Model is saved.
# - epoch:12 -
# Epoch: [12][0/125] Elapsed 0m 1s (remain 2m 5s) Loss: 0.3180(0.3180)
# Epoch: [12][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2664(0.3085)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1732(0.1732)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1147(0.4200)
# 	 epoch:12, avg train loss:0.3085, avg valid loss:0.4200
# 	 score:0.4795(th=0.700000), auc=0.874856::: time:112.80s
# Epoch 12 - Save Best Score: 0.4795. Model is saved.
# dice_list:  [0.31427817115638507, 0.3489335221285798, 0.37377484469066485, 0.3921164386181127, 0.40793325540819947, 0.42352745922968416, 0.4373726487596746, 0.44884515109377165, 0.45754454496949554, 0.4630716725862408, 0.4676865077680202, 0.47382007743508797, 0.4794802310080265, 0.47893123852452213, 0.47188025017646834, 0.453198624705399, 0.40633494032924505, 0.2969354801018934, 0.0]
# - epoch:13 -
# Epoch: [13][0/125] Elapsed 0m 0s (remain 1m 51s) Loss: 0.3117(0.3117)
# Epoch: [13][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2063(0.2905)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2074(0.2074)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1236(0.3970)
# 	 epoch:13, avg train loss:0.2905, avg valid loss:0.3970
# 	 score:0.4939(th=0.650000), auc=0.882019::: time:169.45s
# Epoch 13 - Save Best Score: 0.4939. Model is saved.
# dice_list:  [0.28169874091195735, 0.30814894221456496, 0.33267454121665946, 0.3548604883658821, 0.37713893479647953, 0.4000859788492818, 0.420355700215607, 0.43803686942213105, 0.4547784777967429, 0.4707507789102707, 0.48529557353055663, 0.4938551946469677, 0.49162252729613987, 0.470091216015299, 0.42641684486983433, 0.3492809967475344, 0.22831677556869717, 0.09537711317128601, 0.0]
# Epoch 13 - Save Best AUC: 0.8820. Model is saved.
# - epoch:14 -
# Epoch: [14][0/125] Elapsed 0m 1s (remain 2m 10s) Loss: 0.3430(0.3430)
# Epoch: [14][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.1686(0.2671)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1633(0.1633)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0923(0.3720)
# 	 epoch:14, avg train loss:0.2671, avg valid loss:0.3720
# 	 score:0.5047(th=0.600000), auc=0.887965::: time:227.14s
# Epoch 14 - Save Best Score: 0.5047. Model is saved.
# dice_list:  [0.33092669499206673, 0.3698268965074104, 0.4002482708109924, 0.4254369529052401, 0.4455045325596885, 0.46081067530556025, 0.4738000190874579, 0.484845604782997, 0.4940566936514274, 0.5002275127966375, 0.504679527315229, 0.5036000609831087, 0.49328533054467355, 0.47609126110454286, 0.4431688249493912, 0.38387456168353595, 0.29179965639207434, 0.16461142235776807, 0.0]
# Epoch 14 - Save Best AUC: 0.8880. Model is saved.
# - epoch:15 -
# Epoch: [15][0/125] Elapsed 0m 0s (remain 2m 0s) Loss: 0.3148(0.3148)
# Epoch: [15][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2592(0.2608)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1627(0.1627)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0895(0.3595)
# 	 epoch:15, avg train loss:0.2608, avg valid loss:0.3595
# 	 score:0.5112(th=0.600000), auc=0.893786::: time:285.57s
# Epoch 15 - Save Best Score: 0.5112. Model is saved.
# dice_list:  [0.33359528603519395, 0.3769446926634096, 0.4084398403286258, 0.43426028618194545, 0.45547628615822183, 0.47222947572801394, 0.4866212090881871, 0.49841096105494165, 0.5070719682289084, 0.5110407511432776, 0.5111904318248525, 0.5063022609393258, 0.4907252579032658, 0.45714331023036936, 0.404345254001472, 0.3310652786330591, 0.23075752965657517, 0.08853969872751088, 0.0]
# Epoch 15 - Save Best AUC: 0.8938. Model is saved.
# - epoch:16 -
# Epoch: [16][0/125] Elapsed 0m 1s (remain 2m 12s) Loss: 0.2685(0.2685)
# Epoch: [16][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2438(0.2509)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 8s) Loss: 0.1746(0.1746)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0937(0.3676)
# 	 epoch:16, avg train loss:0.2509, avg valid loss:0.3676
# 	 score:0.5112(th=0.600000), auc=0.892910::: time:343.76s
# - epoch:17 -
# Epoch: [17][0/125] Elapsed 0m 0s (remain 1m 56s) Loss: 0.3143(0.3143)
# Epoch: [17][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.1824(0.2530)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1931(0.1931)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0935(0.3782)
# 	 epoch:17, avg train loss:0.2530, avg valid loss:0.3782
# 	 score:0.5082(th=0.650000), auc=0.890779::: time:398.52s
# - epoch:18 -
# Epoch: [18][0/125] Elapsed 0m 0s (remain 2m 0s) Loss: 0.3673(0.3673)
# Epoch: [18][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2591(0.2551)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2888(0.2888)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1909(0.4562)
# 	 epoch:18, avg train loss:0.2551, avg valid loss:0.4562
# 	 score:0.4706(th=0.750000), auc=0.879969::: time:453.61s
# - epoch:19 -
# Epoch: [19][0/125] Elapsed 0m 1s (remain 2m 8s) Loss: 0.2578(0.2578)
# Epoch: [19][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2841(0.2634)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2066(0.2066)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1173(0.4055)
# 	 epoch:19, avg train loss:0.2634, avg valid loss:0.4055
# 	 score:0.5075(th=0.800000), auc=0.895361::: time:508.71s
# Epoch 19 - Save Best AUC: 0.8954. Model is saved.
# - epoch:20 -
# Epoch: [20][0/125] Elapsed 0m 1s (remain 2m 9s) Loss: 0.2202(0.2202)
# Epoch: [20][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2788(0.2795)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.5159(0.5159)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2890(0.6439)
# 	 epoch:20, avg train loss:0.2795, avg valid loss:0.6439
# 	 score:0.4382(th=0.850000), auc=0.878703::: time:565.67s
# surface_list:  range(25, 35, 3)
# - epoch:21 -
# Epoch: [21][0/125] Elapsed 0m 0s (remain 1m 51s) Loss: 0.2977(0.2977)
# Epoch: [21][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3665(0.2976)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 8s) Loss: 0.1196(0.1196)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1166(0.4045)
# 	 epoch:21, avg train loss:0.2976, avg valid loss:0.4045
# 	 score:0.4118(th=0.350000), auc=0.854418::: time:54.76s
# Epoch 21 - Save Best Score: 0.4118. Model is saved.
# dice_list:  [0.32483839971904144, 0.35365811623347637, 0.3746437985925251, 0.39489595629751634, 0.40884430454916765, 0.4117824013176446, 0.40278878573255217, 0.3817232313423099, 0.3464370348312585, 0.30423038168550864, 0.25764512000139517, 0.20538189168184062, 0.15443773570106187, 0.1070574180536837, 0.06907552142191623, 0.03380584538459249, 0.006347971127494707, 0.0, 0.0]
# Epoch 21 - Save Best AUC: 0.8544. Model is saved.
# - epoch:22 -
# Epoch: [22][0/125] Elapsed 0m 0s (remain 1m 54s) Loss: 0.2896(0.2896)
# Epoch: [22][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2788(0.2857)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1375(0.1375)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1364(0.4132)
# 	 epoch:22, avg train loss:0.2857, avg valid loss:0.4132
# 	 score:0.3801(th=0.450000), auc=0.844254::: time:112.56s
# - epoch:23 -
# Epoch: [23][0/125] Elapsed 0m 0s (remain 1m 52s) Loss: 0.3500(0.3500)
# Epoch: [23][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2160(0.2673)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2087(0.2087)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1106(0.3974)
# 	 epoch:23, avg train loss:0.2673, avg valid loss:0.3974
# 	 score:0.4262(th=0.550000), auc=0.864412::: time:167.33s
# Epoch 23 - Save Best Score: 0.4262. Model is saved.
# dice_list:  [0.296998343795394, 0.321489112787367, 0.3424070029086058, 0.36402421277911956, 0.38333998432158806, 0.39770497606155963, 0.4056431930496413, 0.4133570861899588, 0.42211680597660206, 0.4262019492100188, 0.42309805519489435, 0.41607599451936883, 0.4043124639202119, 0.38672345620163995, 0.3527536428036296, 0.2961657140012756, 0.2185364617092437, 0.12331837642156038, 0.0]
# Epoch 23 - Save Best AUC: 0.8644. Model is saved.
# - epoch:24 -
# Epoch: [24][0/125] Elapsed 0m 0s (remain 1m 59s) Loss: 0.1992(0.1992)
# Epoch: [24][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2492(0.2452)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2329(0.2329)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1223(0.4386)
# 	 epoch:24, avg train loss:0.2452, avg valid loss:0.4386
# 	 score:0.4674(th=0.700000), auc=0.879441::: time:224.95s
# Epoch 24 - Save Best Score: 0.4674. Model is saved.
# dice_list:  [0.2897587931238574, 0.3097677016041648, 0.32892003770375067, 0.3467878891662548, 0.3627679317719427, 0.3770603012216481, 0.3936811691770644, 0.4088477012677672, 0.42270622021409904, 0.4357508871854594, 0.4479325419109993, 0.46007617697543257, 0.4673689351388143, 0.4642283038242419, 0.4479473806307198, 0.4163383873592333, 0.356486024093974, 0.21797897999744514, 0.0]
# Epoch 24 - Save Best AUC: 0.8794. Model is saved.
# - epoch:25 -
# Epoch: [25][0/125] Elapsed 0m 0s (remain 1m 56s) Loss: 0.2590(0.2590)
# Epoch: [25][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.1473(0.2261)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1632(0.1632)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0987(0.3851)
# 	 epoch:25, avg train loss:0.2261, avg valid loss:0.3851
# 	 score:0.4850(th=0.600000), auc=0.878294::: time:282.70s
# Epoch 25 - Save Best Score: 0.4850. Model is saved.
# dice_list:  [0.3255052777056814, 0.3551774059321072, 0.3799997362502825, 0.4038271371602561, 0.42467039728616135, 0.44015394327341695, 0.45287061098722386, 0.4631028280342562, 0.4719773534634658, 0.4810183559413854, 0.4849869784582957, 0.4840491061206412, 0.47442161283473555, 0.4540865958615637, 0.4243541432368572, 0.37348689603396995, 0.2971459821273482, 0.17404708853751927, 0.0]
# - epoch:26 -
# Epoch: [26][0/125] Elapsed 0m 0s (remain 1m 57s) Loss: 0.1873(0.1873)
# Epoch: [26][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2054(0.2238)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1593(0.1593)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0994(0.3833)
# 	 epoch:26, avg train loss:0.2238, avg valid loss:0.3833
# 	 score:0.4745(th=0.600000), auc=0.876306::: time:338.82s
# - epoch:27 -
# Epoch: [27][0/125] Elapsed 0m 0s (remain 1m 57s) Loss: 0.2231(0.2231)
# Epoch: [27][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.1956(0.2225)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 8s) Loss: 0.1600(0.1600)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0960(0.3803)
# 	 epoch:27, avg train loss:0.2225, avg valid loss:0.3803
# 	 score:0.4830(th=0.550000), auc=0.877146::: time:393.63s
# - epoch:28 -
# Epoch: [28][0/125] Elapsed 0m 0s (remain 1m 57s) Loss: 0.1603(0.1603)
# Epoch: [28][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2028(0.2187)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1794(0.1794)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0886(0.3917)
# 	 epoch:28, avg train loss:0.2187, avg valid loss:0.3917
# 	 score:0.4919(th=0.600000), auc=0.879774::: time:448.68s
# Epoch 28 - Save Best Score: 0.4919. Model is saved.
# dice_list:  [0.3255265651810547, 0.35986573106519576, 0.3897204599693673, 0.41295368218782325, 0.4321408576161357, 0.44892814176136764, 0.4629027107051975, 0.47311420652008684, 0.48246271737871116, 0.4886574667935976, 0.49193485483185945, 0.4912457544199321, 0.48669931665897426, 0.47883650255391463, 0.4657241165073676, 0.4425529158340287, 0.40453484560031905, 0.3289037994889253, 0.0]
# Epoch 28 - Save Best AUC: 0.8798. Model is saved.
# - epoch:29 -
# Epoch: [29][0/125] Elapsed 0m 0s (remain 2m 3s) Loss: 0.1707(0.1707)
# Epoch: [29][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.1738(0.2368)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2488(0.2488)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0917(0.3976)
# 	 epoch:29, avg train loss:0.2368, avg valid loss:0.3976
# 	 score:0.4865(th=0.700000), auc=0.880372::: time:506.30s
# Epoch 29 - Save Best AUC: 0.8804. Model is saved.
# - epoch:30 -
# Epoch: [30][0/125] Elapsed 0m 0s (remain 2m 3s) Loss: 0.2297(0.2297)
# Epoch: [30][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2683(0.2445)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.5354(0.5354)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2098(0.6014)
# 	 epoch:30, avg train loss:0.2445, avg valid loss:0.6014
# 	 score:0.4728(th=0.900000), auc=0.871295::: time:562.47s
# [fold2] slice ave score:0.4801(th=0.750000), auc=0.884648
# [fold2] BEST Epoch 28 - Save Best Score:0.4919. Best loss:0.3917
# [fold2] BEST AUC Epoch 29 - Save Best Score:0.8804. Best loss:0.3976
# fold[0] BEST SCORE = 0.5785 thr=0.7 (epoch=30)
# fold[0] slice ave score:0.5783(th=0.700000), auc=0.889078
# fold[1] BEST SCORE = 0.4112 thr=0.45 (epoch=21)
# fold[1] slice ave score:0.4267(th=0.150000), auc=0.809144
# fold[2] BEST SCORE = 0.4919 thr=0.6 (epoch=28)
# fold[2] slice ave score:0.4801(th=0.750000), auc=0.884648
# CPU times: user 1h 16min 10s, sys: 20min 16s, total: 1h 36min 26s
# Wall time: 1h 42min 43s

# %%
# %%time
best_score_list, best_threshold_list, best_epoch_list = training_loop(CFG)
# Out:
# -- fold0 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/conv.py:444: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at  ../aten/src/ATen/native/Convolution.cpp:744.)
#   self.padding, self.dilation, self.groups)
# Epoch: [1][0/130] Elapsed 0m 0s (remain 2m 0s) Loss: 0.7242(0.7242)
# Epoch: [1][129/130] Elapsed 0m 37s (remain 0m 0s) Loss: 0.4761(0.5917)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.3802(0.3802)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2967(0.4492)
# 	 epoch:1, avg train loss:0.5917, avg valid loss:0.4492
# 	 score:0.3704(th=0.700000), auc=0.828709::: time:54.10s
# Epoch 1 - Save Best Score: 0.3704. Model is saved.
# dice_list:  [0.15889547561542094, 0.1675611075950757, 0.1814412973978439, 0.19619397572465713, 0.21390116538682052, 0.23425253880878366, 0.2557137084708653, 0.27875044861747666, 0.3029380564304187, 0.32629795845335835, 0.3458408758880135, 0.36093298342328756, 0.37043940008772624, 0.36185056818123196, 0.3317047730635702, 0.2709567249685853, 0.15354069441210458, 0.03670419158141035, 0.0]
# Epoch 1 - Save Best AUC: 0.8287. Model is saved.
# - epoch:2 -
# Epoch: [2][0/130] Elapsed 0m 0s (remain 2m 0s) Loss: 0.5053(0.5053)
# Epoch: [2][129/130] Elapsed 0m 37s (remain 0m 0s) Loss: 0.5864(0.4374)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1838(0.1838)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2587(0.3665)
# 	 epoch:2, avg train loss:0.4374, avg valid loss:0.3665
# 	 score:0.3944(th=0.600000), auc=0.848771::: time:110.58s
# Epoch 2 - Save Best Score: 0.3944. Model is saved.
# dice_list:  [0.16230356655049913, 0.20585294092457543, 0.27850286333031127, 0.32528990489102644, 0.35230780092336644, 0.3706818380606264, 0.3832792531643074, 0.3892887750449609, 0.3913625790928669, 0.3938355791312127, 0.3943802943533332, 0.3895985838826199, 0.38078165168415157, 0.3711418725257884, 0.3600221078462418, 0.34207978505882586, 0.3135767794545411, 0.2593036595849684, 0.0]
# Epoch 2 - Save Best AUC: 0.8488. Model is saved.
# - epoch:3 -
# Epoch: [3][0/130] Elapsed 0m 0s (remain 2m 1s) Loss: 0.3436(0.3436)
# Epoch: [3][129/130] Elapsed 0m 37s (remain 0m 0s) Loss: 0.2522(0.3785)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1409(0.1409)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2366(0.2886)
# 	 epoch:3, avg train loss:0.3785, avg valid loss:0.2886
# 	 score:0.4577(th=0.450000), auc=0.873347::: time:167.24s
# Epoch 3 - Save Best Score: 0.4577. Model is saved.
# dice_list:  [0.22543980917466372, 0.29998897143751735, 0.3556402574654522, 0.40257515070194533, 0.4341294489763616, 0.44901393571808157, 0.45551793625399695, 0.4576749538498782, 0.43899064554608475, 0.4012237891077764, 0.3278130763703518, 0.22694671116604678, 0.12845876791565444, 0.05953554357652156, 0.02613103966056592, 0.010326190631100813, 0.001064762174421626, 0.0, 0.0]
# Epoch 3 - Save Best AUC: 0.8733. Model is saved.
# - epoch:4 -
# Epoch: [4][0/130] Elapsed 0m 0s (remain 1m 59s) Loss: 0.4335(0.4335)
# Epoch: [4][129/130] Elapsed 0m 37s (remain 0m 0s) Loss: 0.2154(0.3502)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.2881(0.2881)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1953(0.3357)
# 	 epoch:4, avg train loss:0.3502, avg valid loss:0.3357
# 	 score:0.4870(th=0.750000), auc=0.875894::: time:224.41s
# Epoch 4 - Save Best Score: 0.4870. Model is saved.
# dice_list:  [0.2135519373076553, 0.24821964107386243, 0.27582788954035226, 0.3011437620636488, 0.32363989953489425, 0.34538766633373824, 0.36600891297056093, 0.3868013799418282, 0.40688160306331617, 0.4276973047048413, 0.44796198279113436, 0.46509412970269814, 0.4771289464161629, 0.4869595018817419, 0.47446469438841, 0.42920715253867653, 0.339289296296094, 0.16085049540425822, 0.0]
# Epoch 4 - Save Best AUC: 0.8759. Model is saved.
# - epoch:5 -
# Epoch: [5][0/130] Elapsed 0m 0s (remain 1m 52s) Loss: 0.2258(0.2258)
# Epoch: [5][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.4797(0.3278)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.3071(0.3071)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1970(0.3492)
# 	 epoch:5, avg train loss:0.3278, avg valid loss:0.3492
# 	 score:0.4935(th=0.850000), auc=0.880656::: time:279.49s
# Epoch 5 - Save Best Score: 0.4935. Model is saved.
# dice_list:  [0.22452802298127103, 0.2600928437486641, 0.28838483459924313, 0.31275977765808416, 0.3320341254053773, 0.3484903456726812, 0.36389135642386516, 0.3803585115045883, 0.3977206232415066, 0.41409411148319625, 0.4301593921188834, 0.44413223926826556, 0.45969678148420456, 0.4775197397771044, 0.49160398717398907, 0.4934737547256077, 0.4539375639672958, 0.31180365361320345, 0.0]
# Epoch 5 - Save Best AUC: 0.8807. Model is saved.
# - epoch:6 -
# Epoch: [6][0/130] Elapsed 0m 0s (remain 1m 50s) Loss: 0.3755(0.3755)
# Epoch: [6][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2323(0.3170)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.3017(0.3017)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1970(0.3451)
# 	 epoch:6, avg train loss:0.3170, avg valid loss:0.3451
# 	 score:0.4935(th=0.800000), auc=0.881139::: time:334.44s
# Epoch 6 - Save Best Score: 0.4935. Model is saved.
# dice_list:  [0.22745069518501776, 0.26265343497847893, 0.2906308154559048, 0.3141618899106625, 0.33274049326878474, 0.3476369230533084, 0.3627709044300888, 0.3799516347004831, 0.3986721414491284, 0.4158363225590118, 0.4327306195717605, 0.448364840638147, 0.464635854387315, 0.48195787880148805, 0.49353955251486353, 0.49248769928509517, 0.44539350899768093, 0.29311114589898063, 0.0]
# Epoch 6 - Save Best AUC: 0.8811. Model is saved.
# - epoch:7 -
# Epoch: [7][0/130] Elapsed 0m 1s (remain 2m 10s) Loss: 0.4388(0.4388)
# Epoch: [7][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2517(0.3159)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2539(0.2539)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1909(0.3192)
# 	 epoch:7, avg train loss:0.3159, avg valid loss:0.3192
# 	 score:0.5030(th=0.750000), auc=0.890094::: time:389.49s
# Epoch 7 - Save Best Score: 0.5030. Model is saved.
# dice_list:  [0.23014342269763627, 0.27205692719724694, 0.3041950065850358, 0.3298839648364241, 0.3533069006135831, 0.3723882989743728, 0.39318994155446874, 0.41509257545424566, 0.4361095215636468, 0.4560974159406001, 0.4750306961585642, 0.49040085357522, 0.5005650655699213, 0.5029998751016045, 0.49995536469010093, 0.4775213853999382, 0.4117832549890021, 0.2528424245203533, 0.0]
# Epoch 7 - Save Best AUC: 0.8901. Model is saved.
# - epoch:8 -
# Epoch: [8][0/130] Elapsed 0m 0s (remain 2m 6s) Loss: 0.2831(0.2831)
# Epoch: [8][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2738(0.3196)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1251(0.1251)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2070(0.2702)
# 	 epoch:8, avg train loss:0.3196, avg valid loss:0.2702
# 	 score:0.5039(th=0.500000), auc=0.883085::: time:444.47s
# Epoch 8 - Save Best Score: 0.5039. Model is saved.
# dice_list:  [0.30012118388124054, 0.3596592232877168, 0.4066002041593919, 0.44164086269303005, 0.4664931248906681, 0.4865953045224019, 0.4986433074953668, 0.5029905387041856, 0.5038893559268874, 0.496271546190377, 0.4780072280935134, 0.44846415959001223, 0.40259871575962286, 0.3379625308186258, 0.25633916768665094, 0.174063227291699, 0.10494329444991224, 0.03397773793618353, 0.0]
# - epoch:9 -
# Epoch: [9][0/130] Elapsed 0m 0s (remain 1m 59s) Loss: 0.3152(0.3152)
# Epoch: [9][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2295(0.3279)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2175(0.2175)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2180(0.2988)
# 	 epoch:9, avg train loss:0.3279, avg valid loss:0.2988
# 	 score:0.5234(th=0.650000), auc=0.871492::: time:498.34s
# Epoch 9 - Save Best Score: 0.5234. Model is saved.
# dice_list:  [0.23770038791305792, 0.276504515566776, 0.3118310747097296, 0.343782646248335, 0.3747406604023388, 0.40323674970465867, 0.4297398166474458, 0.4559709680743416, 0.4807518308470336, 0.5007274544451097, 0.5165388759732414, 0.5234020539685647, 0.5118849122710093, 0.47616633780087886, 0.4131814565680413, 0.3119688987918939, 0.16630596085481722, 0.03542368823905799, 0.0]
# - epoch:10 -
# Epoch: [10][0/130] Elapsed 0m 0s (remain 1m 57s) Loss: 0.4157(0.4157)
# Epoch: [10][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.1979(0.3352)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2033(0.2033)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2086(0.3156)
# 	 epoch:10, avg train loss:0.3352, avg valid loss:0.3156
# 	 score:0.5020(th=0.750000), auc=0.872744::: time:552.68s
# surface_list:  range(27, 37, 3)
# - epoch:11 -
# Epoch: [11][0/130] Elapsed 0m 0s (remain 2m 1s) Loss: 0.2692(0.2692)
# Epoch: [11][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2128(0.3275)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.3494(0.3494)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2515(0.4299)
# 	 epoch:11, avg train loss:0.3275, avg valid loss:0.4299
# 	 score:0.4500(th=0.900000), auc=0.859352::: time:51.75s
# Epoch 11 - Save Best Score: 0.4500. Model is saved.
# dice_list:  [0.22155510759019645, 0.24675134551401484, 0.2676744915514591, 0.28391627205580283, 0.29706940118653813, 0.3091674874320267, 0.32057715023295785, 0.33151531663064226, 0.3418925002656395, 0.35343906108084094, 0.36535405998070297, 0.37720846734098884, 0.39221528748049894, 0.40625584013467814, 0.42116267623463854, 0.4387152984029159, 0.4499771495832991, 0.4282463211865406, 0.0]
# Epoch 11 - Save Best AUC: 0.8594. Model is saved.
# - epoch:12 -
# Epoch: [12][0/130] Elapsed 0m 0s (remain 2m 7s) Loss: 0.3218(0.3218)
# Epoch: [12][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3864(0.3214)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1273(0.1273)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2249(0.2747)
# 	 epoch:12, avg train loss:0.3214, avg valid loss:0.2747
# 	 score:0.5075(th=0.550000), auc=0.880682::: time:106.98s
# Epoch 12 - Save Best Score: 0.5075. Model is saved.
# dice_list:  [0.269000575985448, 0.32169852857455944, 0.3657452503510974, 0.4027946088376441, 0.43443192352663845, 0.4624398851259393, 0.48247898394708055, 0.4959781974876762, 0.5049651045805094, 0.5075438444486228, 0.5023107618161243, 0.4894384323331578, 0.46745210386009184, 0.4290639740999836, 0.3604488239736462, 0.2647805591036655, 0.15477800222262825, 0.04316054674786763, 0.0]
# Epoch 12 - Save Best AUC: 0.8807. Model is saved.
# - epoch:13 -
# Epoch: [13][0/130] Elapsed 0m 0s (remain 2m 4s) Loss: 0.2262(0.2262)
# Epoch: [13][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.5560(0.3020)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1054(0.1054)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1929(0.2709)
# 	 epoch:13, avg train loss:0.3020, avg valid loss:0.2709
# 	 score:0.5365(th=0.650000), auc=0.891192::: time:161.65s
# Epoch 13 - Save Best Score: 0.5365. Model is saved.
# dice_list:  [0.29333130968935, 0.34473889607808134, 0.3834230245234463, 0.4154013642666223, 0.4402557773637126, 0.4632475834246992, 0.4862922322569308, 0.5071883766204098, 0.5228012166107642, 0.5304913172965271, 0.5345331502086547, 0.536519974051057, 0.5320892426722947, 0.5218244832525739, 0.5015023695768587, 0.46627981424138865, 0.40675017598473584, 0.2854353938334789, 0.0]
# Epoch 13 - Save Best AUC: 0.8912. Model is saved.
# - epoch:14 -
# Epoch: [14][0/130] Elapsed 0m 0s (remain 1m 55s) Loss: 0.2638(0.2638)
# Epoch: [14][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2519(0.2864)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1738(0.1738)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1908(0.2892)
# 	 epoch:14, avg train loss:0.2864, avg valid loss:0.2892
# 	 score:0.5566(th=0.700000), auc=0.889247::: time:216.82s
# Epoch 14 - Save Best Score: 0.5566. Model is saved.
# dice_list:  [0.24759656892537055, 0.2921861447025053, 0.3317578736203235, 0.3668984771312964, 0.3994916195719571, 0.42921807355440333, 0.4569409602169374, 0.4810595718638475, 0.5008996238662383, 0.5163694935202852, 0.5306578322605202, 0.5456721625334608, 0.5565870106542873, 0.555197579908953, 0.5434667601776539, 0.5190148772519797, 0.45620466692121087, 0.3100753949220336, 0.0]
# - epoch:15 -
# Epoch: [15][0/130] Elapsed 0m 0s (remain 1m 58s) Loss: 0.1838(0.1838)
# Epoch: [15][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.6003(0.2590)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2048(0.2048)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1969(0.3204)
# 	 epoch:15, avg train loss:0.2590, avg valid loss:0.3204
# 	 score:0.5474(th=0.850000), auc=0.888666::: time:270.35s
# - epoch:16 -
# Epoch: [16][0/130] Elapsed 0m 0s (remain 1m 53s) Loss: 0.2764(0.2764)
# Epoch: [16][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.8554(0.2622)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1472(0.1472)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1916(0.2932)
# 	 epoch:16, avg train loss:0.2622, avg valid loss:0.2932
# 	 score:0.5511(th=0.800000), auc=0.886082::: time:323.02s
# - epoch:17 -
# Epoch: [17][0/130] Elapsed 0m 0s (remain 2m 5s) Loss: 0.2985(0.2985)
# Epoch: [17][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3034(0.2631)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.2227(0.2227)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1887(0.3197)
# 	 epoch:17, avg train loss:0.2631, avg valid loss:0.3197
# 	 score:0.5433(th=0.850000), auc=0.890227::: time:375.38s
# - epoch:18 -
# Epoch: [18][0/130] Elapsed 0m 0s (remain 1m 46s) Loss: 0.2413(0.2413)
# Epoch: [18][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.4213(0.2671)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1537(0.1537)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1730(0.2807)
# 	 epoch:18, avg train loss:0.2671, avg valid loss:0.2807
# 	 score:0.5607(th=0.700000), auc=0.888604::: time:427.27s
# Epoch 18 - Save Best Score: 0.5607. Model is saved.
# dice_list:  [0.282036545664847, 0.3206387231071655, 0.3506069774633877, 0.3806266021073872, 0.4083527634936073, 0.4337666593807211, 0.4594502573333072, 0.4819545751040579, 0.5024982339218493, 0.5214987552014424, 0.5372531964417191, 0.5520062188604504, 0.5606971340034098, 0.5565470433385926, 0.5385653427542977, 0.4884215808949052, 0.3907529533083285, 0.2391390948427118, 0.0]
# - epoch:19 -
# Epoch: [19][0/130] Elapsed 0m 0s (remain 1m 58s) Loss: 0.1879(0.1879)
# Epoch: [19][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2838(0.2764)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2350(0.2350)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1820(0.3435)
# 	 epoch:19, avg train loss:0.2764, avg valid loss:0.3435
# 	 score:0.5140(th=0.750000), auc=0.883543::: time:480.51s
# - epoch:20 -
# Epoch: [20][0/130] Elapsed 0m 0s (remain 1m 51s) Loss: 0.2062(0.2062)
# Epoch: [20][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3300(0.2846)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2863(0.2863)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1599(0.3484)
# 	 epoch:20, avg train loss:0.2846, avg valid loss:0.3484
# 	 score:0.5196(th=0.800000), auc=0.883843::: time:532.63s
# surface_list:  range(25, 35, 3)
# - epoch:21 -
# Epoch: [21][0/130] Elapsed 0m 0s (remain 2m 4s) Loss: 0.2439(0.2439)
# Epoch: [21][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2242(0.3141)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.0610(0.0610)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2108(0.2593)
# 	 epoch:21, avg train loss:0.3141, avg valid loss:0.2593
# 	 score:0.5492(th=0.500000), auc=0.892627::: time:52.84s
# Epoch 21 - Save Best Score: 0.5492. Model is saved.
# dice_list:  [0.3316713783704651, 0.39208417228077125, 0.43267837748278226, 0.4644074581488145, 0.4935184796647405, 0.5160226230287878, 0.5357262071132495, 0.5466175618604512, 0.5492306225981421, 0.5439378730086752, 0.5312950251902246, 0.5051917515536244, 0.4682160721223399, 0.4199148923587833, 0.3456050002621777, 0.23218406999674276, 0.11041042664158093, 0.020769183726737906, 0.0]
# Epoch 21 - Save Best AUC: 0.8926. Model is saved.
# - epoch:22 -
# Epoch: [22][0/130] Elapsed 0m 1s (remain 2m 9s) Loss: 0.2024(0.2024)
# Epoch: [22][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2647(0.2936)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.0953(0.0953)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1841(0.2757)
# 	 epoch:22, avg train loss:0.2936, avg valid loss:0.2757
# 	 score:0.5469(th=0.650000), auc=0.881906::: time:107.93s
# - epoch:23 -
# Epoch: [23][0/130] Elapsed 0m 1s (remain 2m 13s) Loss: 0.2244(0.2244)
# Epoch: [23][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.8905(0.2703)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2751(0.2751)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3688(0.3495)
# 	 epoch:23, avg train loss:0.2703, avg valid loss:0.3495
# 	 score:0.4361(th=0.400000), auc=0.862557::: time:159.99s
# - epoch:24 -
# Epoch: [24][0/130] Elapsed 0m 0s (remain 1m 59s) Loss: 0.2503(0.2503)
# Epoch: [24][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.1900(0.2573)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.0664(0.0664)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2075(0.2602)
# 	 epoch:24, avg train loss:0.2573, avg valid loss:0.2602
# 	 score:0.5553(th=0.550000), auc=0.890381::: time:211.99s
# Epoch 24 - Save Best Score: 0.5553. Model is saved.
# dice_list:  [0.33212486594099255, 0.39539702396904114, 0.43937171655978574, 0.46975596125058894, 0.4935328961810189, 0.5142724433474724, 0.5318346290264716, 0.5444989394817379, 0.5532416775185068, 0.5553133924542215, 0.5515846365687408, 0.5396475070275536, 0.5244645977777538, 0.5008848427973451, 0.4628520682304344, 0.41191517977037845, 0.3270504542565562, 0.2150433349030797, 0.0]
# - epoch:25 -
# Epoch: [25][0/130] Elapsed 0m 0s (remain 2m 3s) Loss: 0.2478(0.2478)
# Epoch: [25][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3238(0.2255)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1226(0.1226)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2032(0.3010)
# 	 epoch:25, avg train loss:0.2255, avg valid loss:0.3010
# 	 score:0.5604(th=0.850000), auc=0.890427::: time:265.02s
# Epoch 25 - Save Best Score: 0.5604. Model is saved.
# dice_list:  [0.2913938757634648, 0.33279537046504465, 0.3639698798509606, 0.38900141486830175, 0.41076905912492834, 0.43028168594986826, 0.44836390171949214, 0.4669302437234603, 0.4838169264068068, 0.4983960411684172, 0.5120723510444526, 0.5278697323767914, 0.5433924445274343, 0.5530388695188289, 0.5603199541912699, 0.5604022515086496, 0.5468672037712649, 0.4859368119197132, 0.0]
# - epoch:26 -
# Epoch: [26][0/130] Elapsed 0m 0s (remain 1m 48s) Loss: 0.2281(0.2281)
# Epoch: [26][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2748(0.2300)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1497(0.1497)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2033(0.3202)
# 	 epoch:26, avg train loss:0.2300, avg valid loss:0.3202
# 	 score:0.5575(th=0.850000), auc=0.889896::: time:318.54s
# - epoch:27 -
# Epoch: [27][0/130] Elapsed 0m 0s (remain 1m 57s) Loss: 0.1635(0.1635)
# Epoch: [27][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.3251(0.2278)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1053(0.1053)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2004(0.2849)
# 	 epoch:27, avg train loss:0.2278, avg valid loss:0.2849
# 	 score:0.5618(th=0.750000), auc=0.888994::: time:371.72s
# Epoch 27 - Save Best Score: 0.5618. Model is saved.
# dice_list:  [0.3109238259141661, 0.3536569112329475, 0.3851912479304714, 0.4118993166970554, 0.43470038548914774, 0.45425940645893376, 0.4708381183020907, 0.488096306293438, 0.5048107011418822, 0.5201271959538092, 0.5351394081304774, 0.5450433239250969, 0.5549383543968792, 0.561800843681887, 0.5595255803714122, 0.5476666343213275, 0.5123738434630638, 0.3968324484443884, 0.0]
# - epoch:28 -
# Epoch: [28][0/130] Elapsed 0m 0s (remain 2m 2s) Loss: 0.1930(0.1930)
# Epoch: [28][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.4548(0.2409)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1127(0.1127)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1884(0.2993)
# 	 epoch:28, avg train loss:0.2409, avg valid loss:0.2993
# 	 score:0.5599(th=0.750000), auc=0.887825::: time:424.98s
# - epoch:29 -
# Epoch: [29][0/130] Elapsed 0m 0s (remain 1m 50s) Loss: 0.2031(0.2031)
# Epoch: [29][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2539(0.2461)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.2186(0.2186)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1671(0.3454)
# 	 epoch:29, avg train loss:0.2461, avg valid loss:0.3454
# 	 score:0.5045(th=0.800000), auc=0.886858::: time:477.33s
# - epoch:30 -
# Epoch: [30][0/130] Elapsed 0m 0s (remain 1m 51s) Loss: 0.3002(0.3002)
# Epoch: [30][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.4652(0.2555)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.0554(0.0554)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1854(0.2740)
# 	 epoch:30, avg train loss:0.2555, avg valid loss:0.2740
# 	 score:0.5785(th=0.700000), auc=0.888234::: time:529.69s
# Epoch 30 - Save Best Score: 0.5785. Model is saved.
# dice_list:  [0.29103229966020827, 0.3340541025058879, 0.3738957647207561, 0.4090902917445583, 0.4421655409359756, 0.4737867403801347, 0.5002531539921848, 0.5236703672671323, 0.5442437215822079, 0.5599915947972492, 0.570596108901367, 0.5783933920131514, 0.578547876083305, 0.5667544350119464, 0.5366816027142588, 0.47706909456867613, 0.3694331587909068, 0.2068271269593613, 0.0]
# [fold0] slice ave score:0.5783(th=0.700000), auc=0.889078
# [fold0] BEST Epoch 30 - Save Best Score:0.5785. Best loss:0.2740
# [fold0] BEST AUC Epoch 21 - Save Best Score:0.8926. Best loss:0.2593
# -- fold1 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# Epoch: [1][0/58] Elapsed 0m 0s (remain 0m 49s) Loss: 0.7661(0.7661)
# Epoch: [1][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.5464(0.6684)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.3727(0.3727)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3756(0.6565)
# 	 epoch:1, avg train loss:0.6684, avg valid loss:0.6565
# 	 score:0.3916(th=0.750000), auc=0.798052::: time:77.86s
# Epoch 1 - Save Best Score: 0.3916. Model is saved.
# dice_list:  [0.19682020310492132, 0.19682415021024133, 0.19687297950492225, 0.19901120043314283, 0.2172735790312324, 0.24049192786889803, 0.265185254492776, 0.28935165990632106, 0.31283615282365146, 0.3353545576930029, 0.35644307532479835, 0.3736138284486542, 0.38556649219423134, 0.39158523217809843, 0.38902328685900134, 0.37350792832520446, 0.3307807359777147, 0.21743939174279017, 0.0]
# Epoch 1 - Save Best AUC: 0.7981. Model is saved.
# - epoch:2 -
# Epoch: [2][0/58] Elapsed 0m 0s (remain 0m 48s) Loss: 0.6494(0.6494)
# Epoch: [2][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.4814(0.5639)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 26s) Loss: 0.2304(0.2304)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2302(0.4755)
# 	 epoch:2, avg train loss:0.5639, avg valid loss:0.4755
# 	 score:0.3415(th=0.450000), auc=0.779911::: time:163.60s
# - epoch:3 -
# Epoch: [3][0/58] Elapsed 0m 0s (remain 0m 56s) Loss: 0.5320(0.5320)
# Epoch: [3][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.4646(0.4646)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.2278(0.2278)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2279(0.4436)
# 	 epoch:3, avg train loss:0.4646, avg valid loss:0.4436
# 	 score:0.3885(th=0.400000), auc=0.790247::: time:243.35s
# - epoch:4 -
# Epoch: [4][0/58] Elapsed 0m 1s (remain 0m 57s) Loss: 0.3541(0.3541)
# Epoch: [4][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.3557(0.3954)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1507(0.1507)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1495(0.4146)
# 	 epoch:4, avg train loss:0.3954, avg valid loss:0.4146
# 	 score:0.4018(th=0.300000), auc=0.796129::: time:322.43s
# Epoch 4 - Save Best Score: 0.4018. Model is saved.
# dice_list:  [0.1971484824339752, 0.22342480473445733, 0.28485059844513905, 0.3599631802502562, 0.40183600939885405, 0.3947932731079871, 0.36462938085703356, 0.32338953808344495, 0.2796803608300552, 0.23706767566123646, 0.19585099388673072, 0.1586945279011087, 0.12520330511926286, 0.09728531962395165, 0.07255601273155522, 0.049698847033330454, 0.02988295752338163, 0.015654204968870166, 0.0]
# - epoch:5 -
# Epoch: [5][0/58] Elapsed 0m 0s (remain 0m 52s) Loss: 0.3864(0.3864)
# Epoch: [5][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.3175(0.3675)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 27s) Loss: 0.1613(0.1613)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1514(0.4079)
# 	 epoch:5, avg train loss:0.3675, avg valid loss:0.4079
# 	 score:0.4169(th=0.300000), auc=0.798376::: time:404.39s
# Epoch 5 - Save Best Score: 0.4169. Model is saved.
# dice_list:  [0.19735999967286974, 0.24373240420713435, 0.319115177214918, 0.37956806355606953, 0.41687019567270694, 0.4153916253303685, 0.3948895354372508, 0.36419931460958016, 0.3302901415349705, 0.2908762510701129, 0.24797031029028238, 0.20371674148432092, 0.16424381625989215, 0.12784862135745842, 0.09529134238855398, 0.0663006771903849, 0.04066501924394133, 0.016463217686456373, 0.0]
# Epoch 5 - Save Best AUC: 0.7984. Model is saved.
# - epoch:6 -
# Epoch: [6][0/58] Elapsed 0m 0s (remain 0m 48s) Loss: 0.3236(0.3236)
# Epoch: [6][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.5740(0.3521)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.1477(0.1477)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1412(0.4062)
# 	 epoch:6, avg train loss:0.3521, avg valid loss:0.4062
# 	 score:0.4169(th=0.300000), auc=0.799447::: time:489.15s
# Epoch 6 - Save Best Score: 0.4169. Model is saved.
# dice_list:  [0.19782411680863357, 0.2530797144781476, 0.33091237790600736, 0.39083797552574073, 0.41691454011089735, 0.40407850205284784, 0.3764096520796181, 0.34392084854600224, 0.30683465885665473, 0.26597190906771173, 0.22529020851502363, 0.18636402473906116, 0.15061547302978606, 0.11830722644099258, 0.0900391404525814, 0.06431056158106424, 0.04049006282625259, 0.01810924114311192, 0.0]
# Epoch 6 - Save Best AUC: 0.7994. Model is saved.
# - epoch:7 -
# Epoch: [7][0/58] Elapsed 0m 0s (remain 0m 56s) Loss: 0.3366(0.3366)
# Epoch: [7][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.4054(0.3455)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1807(0.1807)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1610(0.4105)
# 	 epoch:7, avg train loss:0.3455, avg valid loss:0.4105
# 	 score:0.4096(th=0.350000), auc=0.795057::: time:575.14s
# - epoch:8 -
# Epoch: [8][0/58] Elapsed 0m 0s (remain 0m 55s) Loss: 0.3211(0.3211)
# Epoch: [8][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.3428(0.3405)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1284(0.1284)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.1273(0.4092)
# 	 epoch:8, avg train loss:0.3405, avg valid loss:0.4092
# 	 score:0.4052(th=0.250000), auc=0.793314::: time:654.93s
# - epoch:9 -
# Epoch: [9][0/58] Elapsed 0m 0s (remain 0m 50s) Loss: 0.2503(0.2503)
# Epoch: [9][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3219(0.3249)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0792(0.0792)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0820(0.4134)
# 	 epoch:9, avg train loss:0.3249, avg valid loss:0.4134
# 	 score:0.3873(th=0.200000), auc=0.785649::: time:733.94s
# - epoch:10 -
# Epoch: [10][0/58] Elapsed 0m 1s (remain 0m 57s) Loss: 0.3403(0.3403)
# Epoch: [10][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3154(0.3045)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0351(0.0351)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0404(0.4364)
# 	 epoch:10, avg train loss:0.3045, avg valid loss:0.4364
# 	 score:0.3845(th=0.150000), auc=0.799261::: time:812.17s
# surface_list:  range(27, 37, 3)
# - epoch:11 -
# Epoch: [11][0/58] Elapsed 0m 0s (remain 0m 54s) Loss: 0.2294(0.2294)
# Epoch: [11][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2289(0.2922)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0261(0.0261)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0272(0.4432)
# 	 epoch:11, avg train loss:0.2922, avg valid loss:0.4432
# 	 score:0.3956(th=0.200000), auc=0.797502::: time:77.76s
# Epoch 11 - Save Best Score: 0.3956. Model is saved.
# dice_list:  [0.35452371847000885, 0.3947783016177279, 0.3955738916401371, 0.36736737123396285, 0.32715710980399376, 0.283561133696812, 0.23916527111806543, 0.19774807108118767, 0.16146868715650264, 0.13019871038520703, 0.10168400957822284, 0.07804008516448113, 0.05788294707441331, 0.04097563652405902, 0.02709570259542636, 0.017310937007744113, 0.00899052943119083, 0.002143444879502593, 0.0]
# Epoch 11 - Save Best AUC: 0.7975. Model is saved.
# - epoch:12 -
# Epoch: [12][0/58] Elapsed 0m 0s (remain 0m 51s) Loss: 0.4407(0.4407)
# Epoch: [12][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1477(0.2724)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0376(0.0376)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0422(0.4363)
# 	 epoch:12, avg train loss:0.2724, avg valid loss:0.4363
# 	 score:0.3839(th=0.200000), auc=0.790107::: time:162.09s
# - epoch:13 -
# Epoch: [13][0/58] Elapsed 0m 1s (remain 0m 58s) Loss: 0.1779(0.1779)
# Epoch: [13][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1403(0.2564)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0330(0.0330)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0389(0.5078)
# 	 epoch:13, avg train loss:0.2564, avg valid loss:0.5078
# 	 score:0.3990(th=0.150000), auc=0.771193::: time:240.26s
# Epoch 13 - Save Best Score: 0.3990. Model is saved.
# dice_list:  [0.3948898224128942, 0.39902331098548893, 0.37146753436066154, 0.3342726773175918, 0.2944194734739289, 0.25318891708221114, 0.21243708103906303, 0.1746863640451317, 0.14503264594766038, 0.12111335640063074, 0.09970276367471638, 0.08055837704998163, 0.06263614281396335, 0.0473925776968392, 0.033814953326798604, 0.020625266209875526, 0.009966246421684158, 0.0023609529255663978, 0.0]
# - epoch:14 -
# Epoch: [14][0/58] Elapsed 0m 1s (remain 0m 59s) Loss: 0.1556(0.1556)
# Epoch: [14][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3144(0.2398)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.0252(0.0252)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0311(0.5030)
# 	 epoch:14, avg train loss:0.2398, avg valid loss:0.5030
# 	 score:0.4027(th=0.100000), auc=0.787796::: time:320.69s
# Epoch 14 - Save Best Score: 0.4027. Model is saved.
# dice_list:  [0.40271708739341555, 0.395325988240585, 0.36849660047084287, 0.33394016578959745, 0.30029395459645575, 0.2704389862567325, 0.24624618620915542, 0.2227142690098597, 0.19907566545369784, 0.1784878072853793, 0.15807381399426762, 0.1378768063794511, 0.11845875759594039, 0.0989321099619849, 0.07880940903045794, 0.057203457228101245, 0.035977482955499095, 0.016170717881764784, 0.0]
# - epoch:15 -
# Epoch: [15][0/58] Elapsed 0m 1s (remain 0m 58s) Loss: 0.1832(0.1832)
# Epoch: [15][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3166(0.2311)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0217(0.0217)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0237(0.5169)
# 	 epoch:15, avg train loss:0.2311, avg valid loss:0.5169
# 	 score:0.4073(th=0.100000), auc=0.789849::: time:401.33s
# Epoch 15 - Save Best Score: 0.4073. Model is saved.
# dice_list:  [0.40728779880606597, 0.39340473046530444, 0.3647381080117242, 0.32811106177186405, 0.29191680631220224, 0.25719608222948426, 0.22596016185252807, 0.19678638670306575, 0.16842078874786415, 0.14202333596267228, 0.11841588082765622, 0.0974760239759877, 0.07764090106808397, 0.05987248160538568, 0.04480132418585767, 0.029547506524906012, 0.016010801633219118, 0.004736107027736799, 0.0]
# - epoch:16 -
# Epoch: [16][0/58] Elapsed 0m 1s (remain 0m 57s) Loss: 0.2592(0.2592)
# Epoch: [16][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2559(0.2186)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0206(0.0206)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0225(0.5392)
# 	 epoch:16, avg train loss:0.2186, avg valid loss:0.5392
# 	 score:0.3968(th=0.100000), auc=0.783020::: time:481.27s
# - epoch:17 -
# Epoch: [17][0/58] Elapsed 0m 1s (remain 0m 57s) Loss: 0.2330(0.2330)
# Epoch: [17][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1820(0.2164)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.0253(0.0253)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0287(0.5283)
# 	 epoch:17, avg train loss:0.2164, avg valid loss:0.5283
# 	 score:0.3930(th=0.100000), auc=0.773755::: time:559.79s
# - epoch:18 -
# Epoch: [18][0/58] Elapsed 0m 0s (remain 0m 55s) Loss: 0.3679(0.3679)
# Epoch: [18][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2201(0.2158)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0181(0.0181)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0241(0.5595)
# 	 epoch:18, avg train loss:0.2158, avg valid loss:0.5595
# 	 score:0.3759(th=0.100000), auc=0.759804::: time:638.59s
# - epoch:19 -
# Epoch: [19][0/58] Elapsed 0m 0s (remain 0m 56s) Loss: 0.1761(0.1761)
# Epoch: [19][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2694(0.2258)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0146(0.0146)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0171(0.5094)
# 	 epoch:19, avg train loss:0.2258, avg valid loss:0.5094
# 	 score:0.3730(th=0.150000), auc=0.786338::: time:717.11s
# - epoch:20 -
# Epoch: [20][0/58] Elapsed 0m 1s (remain 0m 57s) Loss: 0.2312(0.2312)
# Epoch: [20][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2269(0.2296)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0234(0.0234)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0238(0.5260)
# 	 epoch:20, avg train loss:0.2296, avg valid loss:0.5260
# 	 score:0.3793(th=0.150000), auc=0.778081::: time:795.81s
# surface_list:  range(25, 35, 3)
# - epoch:21 -
# Epoch: [21][0/58] Elapsed 0m 0s (remain 0m 56s) Loss: 0.2467(0.2467)
# Epoch: [21][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1993(0.2727)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0122(0.0122)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0171(0.4427)
# 	 epoch:21, avg train loss:0.2727, avg valid loss:0.4427
# 	 score:0.4112(th=0.450000), auc=0.805836::: time:77.67s
# Epoch 21 - Save Best Score: 0.4112. Model is saved.
# dice_list:  [0.3211498152771749, 0.3485972948149683, 0.3689797311002251, 0.3847117319830211, 0.3968383113851549, 0.4051863747374892, 0.4097625113727022, 0.4112192663295503, 0.4085156421866894, 0.40127531070573175, 0.3888691202744515, 0.370552438999142, 0.34830181048020525, 0.32028764082795025, 0.28192910048164815, 0.23023931563145303, 0.16465682423608236, 0.08790567647470941, 0.0]
# Epoch 21 - Save Best AUC: 0.8058. Model is saved.
# - epoch:22 -
# Epoch: [22][0/58] Elapsed 0m 1s (remain 0m 57s) Loss: 0.1690(0.1690)
# Epoch: [22][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1954(0.2391)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 39s) Loss: 0.0115(0.0115)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0082(0.5037)
# 	 epoch:22, avg train loss:0.2391, avg valid loss:0.5037
# 	 score:0.3841(th=0.150000), auc=0.790030::: time:162.23s
# - epoch:23 -
# Epoch: [23][0/58] Elapsed 0m 0s (remain 0m 51s) Loss: 0.2701(0.2701)
# Epoch: [23][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.6012(0.2350)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.0184(0.0184)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0065(0.6160)
# 	 epoch:23, avg train loss:0.2350, avg valid loss:0.6160
# 	 score:0.3867(th=0.100000), auc=0.781369::: time:239.71s
# - epoch:24 -
# Epoch: [24][0/58] Elapsed 0m 0s (remain 0m 55s) Loss: 0.1504(0.1504)
# Epoch: [24][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1816(0.2051)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0173(0.0173)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0138(0.5974)
# 	 epoch:24, avg train loss:0.2051, avg valid loss:0.5974
# 	 score:0.3711(th=0.100000), auc=0.776017::: time:316.49s
# - epoch:25 -
# Epoch: [25][0/58] Elapsed 0m 0s (remain 0m 56s) Loss: 0.2184(0.2184)
# Epoch: [25][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2809(0.2005)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0182(0.0182)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0119(0.6102)
# 	 epoch:25, avg train loss:0.2005, avg valid loss:0.6102
# 	 score:0.3817(th=0.100000), auc=0.779110::: time:394.87s
# - epoch:26 -
# Epoch: [26][0/58] Elapsed 0m 0s (remain 0m 54s) Loss: 0.1616(0.1616)
# Epoch: [26][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1812(0.1830)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.0205(0.0205)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0123(0.5909)
# 	 epoch:26, avg train loss:0.1830, avg valid loss:0.5909
# 	 score:0.3933(th=0.100000), auc=0.783036::: time:472.87s
# - epoch:27 -
# Epoch: [27][0/58] Elapsed 0m 0s (remain 0m 53s) Loss: 0.1763(0.1763)
# Epoch: [27][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1661(0.1981)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0278(0.0278)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0122(0.5704)
# 	 epoch:27, avg train loss:0.1981, avg valid loss:0.5704
# 	 score:0.3975(th=0.100000), auc=0.787286::: time:549.90s
# - epoch:28 -
# Epoch: [28][0/58] Elapsed 0m 0s (remain 0m 50s) Loss: 0.1743(0.1743)
# Epoch: [28][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1436(0.1858)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.0149(0.0149)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0102(0.6218)
# 	 epoch:28, avg train loss:0.1858, avg valid loss:0.6218
# 	 score:0.3765(th=0.100000), auc=0.771100::: time:627.20s
# - epoch:29 -
# Epoch: [29][0/58] Elapsed 0m 0s (remain 0m 53s) Loss: 0.2247(0.2247)
# Epoch: [29][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2809(0.1953)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.0279(0.0279)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0245(0.5414)
# 	 epoch:29, avg train loss:0.1953, avg valid loss:0.5414
# 	 score:0.3941(th=0.150000), auc=0.791344::: time:706.02s
# - epoch:30 -
# Epoch: [30][0/58] Elapsed 0m 0s (remain 0m 56s) Loss: 0.1973(0.1973)
# Epoch: [30][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3552(0.1973)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0096(0.0096)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0176(0.6220)
# 	 epoch:30, avg train loss:0.1973, avg valid loss:0.6220
# 	 score:0.3651(th=0.150000), auc=0.768587::: time:784.09s
# [fold1] slice ave score:0.4267(th=0.150000), auc=0.809144
# [fold1] BEST Epoch 21 - Save Best Score:0.4112. Best loss:0.4427
# [fold1] BEST AUC Epoch 21 - Save Best Score:0.8058. Best loss:0.4427
# -- fold2 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# Epoch: [1][0/125] Elapsed 0m 1s (remain 2m 7s) Loss: 0.7180(0.7180)
# Epoch: [1][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.4564(0.5677)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.3225(0.3225)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.3114(0.4827)
# 	 epoch:1, avg train loss:0.5677, avg valid loss:0.4827
# 	 score:0.3921(th=0.450000), auc=0.857430::: time:56.07s
# Epoch 1 - Save Best Score: 0.3921. Model is saved.
# dice_list:  [0.1985037673071646, 0.19899745729667154, 0.21922636699764353, 0.23875247520147455, 0.2761271475856764, 0.33809542225098316, 0.37405979752609014, 0.39205357221498166, 0.3742511852427723, 0.30469916020984344, 0.2070426035315909, 0.11397319343801351, 0.054549723641438154, 0.01889172174215904, 0.004909135657724692, 0.0010516206847223384, 0.0, 0.0, 0.0]
# Epoch 1 - Save Best AUC: 0.8574. Model is saved.
# - epoch:2 -
# Epoch: [2][0/125] Elapsed 0m 1s (remain 2m 7s) Loss: 0.4559(0.4559)
# Epoch: [2][124/125] Elapsed 0m 36s (remain 0m 0s) Loss: 0.3462(0.4234)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1887(0.1887)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1564(0.3891)
# 	 epoch:2, avg train loss:0.4234, avg valid loss:0.3891
# 	 score:0.4332(th=0.300000), auc=0.861049::: time:115.85s
# Epoch 2 - Save Best Score: 0.4332. Model is saved.
# dice_list:  [0.23407984008874844, 0.29520196455194386, 0.38371775650417045, 0.4309505614621473, 0.433188584147858, 0.42517347429443875, 0.4107204212537034, 0.39113820539176264, 0.36837738029740397, 0.3446907147394947, 0.3217585215556715, 0.2948591891424146, 0.26506941861521294, 0.23138345965645568, 0.19503630053725451, 0.1569991321733009, 0.10541923902000241, 0.04926525669597743, 0.0]
# Epoch 2 - Save Best AUC: 0.8610. Model is saved.
# - epoch:3 -
# Epoch: [3][0/125] Elapsed 0m 1s (remain 2m 8s) Loss: 0.3295(0.3295)
# Epoch: [3][124/125] Elapsed 0m 36s (remain 0m 0s) Loss: 0.3834(0.3645)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1693(0.1693)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1550(0.3754)
# 	 epoch:3, avg train loss:0.3645, avg valid loss:0.3754
# 	 score:0.4791(th=0.500000), auc=0.877743::: time:175.46s
# Epoch 3 - Save Best Score: 0.4791. Model is saved.
# dice_list:  [0.2517639182852863, 0.2895032168230174, 0.3370825956369731, 0.385369469455768, 0.4261214309296698, 0.4547971525833432, 0.4695860459436804, 0.47700119895043, 0.47913106453690424, 0.4767149931402704, 0.46777750615735647, 0.4518802730161575, 0.42696333329022895, 0.3930832608285537, 0.3444618550755766, 0.2625020270635906, 0.1528193607797527, 0.03800613591173385, 0.0]
# Epoch 3 - Save Best AUC: 0.8777. Model is saved.
# - epoch:4 -
# Epoch: [4][0/125] Elapsed 0m 0s (remain 1m 56s) Loss: 0.2769(0.2769)
# Epoch: [4][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2947(0.3346)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2186(0.2186)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1542(0.4014)
# 	 epoch:4, avg train loss:0.3346, avg valid loss:0.4014
# 	 score:0.4927(th=0.650000), auc=0.880399::: time:234.51s
# Epoch 4 - Save Best Score: 0.4927. Model is saved.
# dice_list:  [0.2605014247504025, 0.289719980937758, 0.31637481231308034, 0.338108489539398, 0.3581177589262801, 0.3804107531516911, 0.40488875102890554, 0.4305970020133872, 0.4551166771937407, 0.4755904006109666, 0.48845922005307635, 0.4927445889260721, 0.48386747607482666, 0.4612723366791715, 0.42114222385002065, 0.3524967310160717, 0.25518256509956017, 0.11505159740658591, 0.0]
# Epoch 4 - Save Best AUC: 0.8804. Model is saved.
# - epoch:5 -
# Epoch: [5][0/125] Elapsed 0m 0s (remain 2m 1s) Loss: 0.3954(0.3954)
# Epoch: [5][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3242(0.3116)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1894(0.1894)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1412(0.3763)
# 	 epoch:5, avg train loss:0.3116, avg valid loss:0.3763
# 	 score:0.4642(th=0.550000), auc=0.878025::: time:293.09s
# - epoch:6 -
# Epoch: [6][0/125] Elapsed 0m 1s (remain 2m 7s) Loss: 0.3215(0.3215)
# Epoch: [6][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2633(0.3126)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2314(0.2314)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1650(0.4005)
# 	 epoch:6, avg train loss:0.3126, avg valid loss:0.4005
# 	 score:0.4667(th=0.650000), auc=0.878030::: time:347.96s
# - epoch:7 -
# Epoch: [7][0/125] Elapsed 0m 0s (remain 2m 2s) Loss: 0.3119(0.3119)
# Epoch: [7][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3460(0.3079)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2314(0.2314)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1619(0.4017)
# 	 epoch:7, avg train loss:0.3079, avg valid loss:0.4017
# 	 score:0.5184(th=0.700000), auc=0.888039::: time:402.61s
# Epoch 7 - Save Best Score: 0.5184. Model is saved.
# dice_list:  [0.26697457414507614, 0.29590866345618316, 0.3225277859122648, 0.34499742478480844, 0.3665852487001331, 0.3893184547528147, 0.41115915209698745, 0.43543613443059365, 0.45962730227151766, 0.48323032094034735, 0.5018182208613691, 0.513556964417105, 0.518383595494101, 0.5095637952858301, 0.47488390393495195, 0.4151757695103369, 0.3153674606068415, 0.15379226725572928, 0.0]
# Epoch 7 - Save Best AUC: 0.8880. Model is saved.
# - epoch:8 -
# Epoch: [8][0/125] Elapsed 0m 0s (remain 1m 59s) Loss: 0.3735(0.3735)
# Epoch: [8][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2901(0.3170)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1704(0.1704)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1177(0.3696)
# 	 epoch:8, avg train loss:0.3170, avg valid loss:0.3696
# 	 score:0.4674(th=0.500000), auc=0.878342::: time:460.68s
# - epoch:9 -
# Epoch: [9][0/125] Elapsed 0m 1s (remain 2m 8s) Loss: 0.3923(0.3923)
# Epoch: [9][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2285(0.3187)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1197(0.1197)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1030(0.3628)
# 	 epoch:9, avg train loss:0.3187, avg valid loss:0.3628
# 	 score:0.4968(th=0.400000), auc=0.881846::: time:515.40s
# - epoch:10 -
# Epoch: [10][0/125] Elapsed 0m 0s (remain 1m 50s) Loss: 0.3023(0.3023)
# Epoch: [10][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3939(0.3246)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 10s) Loss: 0.1804(0.1804)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1825(0.3878)
# 	 epoch:10, avg train loss:0.3246, avg valid loss:0.3878
# 	 score:0.4334(th=0.500000), auc=0.869084::: time:570.71s
# surface_list:  range(27, 37, 3)
# - epoch:11 -
# Epoch: [11][0/125] Elapsed 0m 0s (remain 2m 2s) Loss: 0.3807(0.3807)
# Epoch: [11][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3175(0.3169)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1616(0.1616)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0870(0.3820)
# 	 epoch:11, avg train loss:0.3169, avg valid loss:0.3820
# 	 score:0.4481(th=0.500000), auc=0.875779::: time:54.64s
# Epoch 11 - Save Best Score: 0.4481. Model is saved.
# dice_list:  [0.3196684559196115, 0.3502467998769862, 0.37738791320184917, 0.39947661083924424, 0.4163948782336856, 0.4284941785145743, 0.4371978099716915, 0.4438112964122637, 0.4480704039850721, 0.4478232524433238, 0.4407630370129522, 0.4246204143727767, 0.3951047530966039, 0.3519088950546355, 0.28552015803851866, 0.19457086595537204, 0.0942124879309056, 0.0149016436935111, 0.0]
# Epoch 11 - Save Best AUC: 0.8758. Model is saved.
# - epoch:12 -
# Epoch: [12][0/125] Elapsed 0m 1s (remain 2m 5s) Loss: 0.3180(0.3180)
# Epoch: [12][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2664(0.3085)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1732(0.1732)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1147(0.4200)
# 	 epoch:12, avg train loss:0.3085, avg valid loss:0.4200
# 	 score:0.4795(th=0.700000), auc=0.874856::: time:112.80s
# Epoch 12 - Save Best Score: 0.4795. Model is saved.
# dice_list:  [0.31427817115638507, 0.3489335221285798, 0.37377484469066485, 0.3921164386181127, 0.40793325540819947, 0.42352745922968416, 0.4373726487596746, 0.44884515109377165, 0.45754454496949554, 0.4630716725862408, 0.4676865077680202, 0.47382007743508797, 0.4794802310080265, 0.47893123852452213, 0.47188025017646834, 0.453198624705399, 0.40633494032924505, 0.2969354801018934, 0.0]
# - epoch:13 -
# Epoch: [13][0/125] Elapsed 0m 0s (remain 1m 51s) Loss: 0.3117(0.3117)
# Epoch: [13][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2063(0.2905)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2074(0.2074)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1236(0.3970)
# 	 epoch:13, avg train loss:0.2905, avg valid loss:0.3970
# 	 score:0.4939(th=0.650000), auc=0.882019::: time:169.45s
# Epoch 13 - Save Best Score: 0.4939. Model is saved.
# dice_list:  [0.28169874091195735, 0.30814894221456496, 0.33267454121665946, 0.3548604883658821, 0.37713893479647953, 0.4000859788492818, 0.420355700215607, 0.43803686942213105, 0.4547784777967429, 0.4707507789102707, 0.48529557353055663, 0.4938551946469677, 0.49162252729613987, 0.470091216015299, 0.42641684486983433, 0.3492809967475344, 0.22831677556869717, 0.09537711317128601, 0.0]
# Epoch 13 - Save Best AUC: 0.8820. Model is saved.
# - epoch:14 -
# Epoch: [14][0/125] Elapsed 0m 1s (remain 2m 10s) Loss: 0.3430(0.3430)
# Epoch: [14][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.1686(0.2671)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1633(0.1633)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0923(0.3720)
# 	 epoch:14, avg train loss:0.2671, avg valid loss:0.3720
# 	 score:0.5047(th=0.600000), auc=0.887965::: time:227.14s
# Epoch 14 - Save Best Score: 0.5047. Model is saved.
# dice_list:  [0.33092669499206673, 0.3698268965074104, 0.4002482708109924, 0.4254369529052401, 0.4455045325596885, 0.46081067530556025, 0.4738000190874579, 0.484845604782997, 0.4940566936514274, 0.5002275127966375, 0.504679527315229, 0.5036000609831087, 0.49328533054467355, 0.47609126110454286, 0.4431688249493912, 0.38387456168353595, 0.29179965639207434, 0.16461142235776807, 0.0]
# Epoch 14 - Save Best AUC: 0.8880. Model is saved.
# - epoch:15 -
# Epoch: [15][0/125] Elapsed 0m 0s (remain 2m 0s) Loss: 0.3148(0.3148)
# Epoch: [15][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2592(0.2608)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1627(0.1627)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0895(0.3595)
# 	 epoch:15, avg train loss:0.2608, avg valid loss:0.3595
# 	 score:0.5112(th=0.600000), auc=0.893786::: time:285.57s
# Epoch 15 - Save Best Score: 0.5112. Model is saved.
# dice_list:  [0.33359528603519395, 0.3769446926634096, 0.4084398403286258, 0.43426028618194545, 0.45547628615822183, 0.47222947572801394, 0.4866212090881871, 0.49841096105494165, 0.5070719682289084, 0.5110407511432776, 0.5111904318248525, 0.5063022609393258, 0.4907252579032658, 0.45714331023036936, 0.404345254001472, 0.3310652786330591, 0.23075752965657517, 0.08853969872751088, 0.0]
# Epoch 15 - Save Best AUC: 0.8938. Model is saved.
# - epoch:16 -
# Epoch: [16][0/125] Elapsed 0m 1s (remain 2m 12s) Loss: 0.2685(0.2685)
# Epoch: [16][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2438(0.2509)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 8s) Loss: 0.1746(0.1746)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0937(0.3676)
# 	 epoch:16, avg train loss:0.2509, avg valid loss:0.3676
# 	 score:0.5112(th=0.600000), auc=0.892910::: time:343.76s
# - epoch:17 -
# Epoch: [17][0/125] Elapsed 0m 0s (remain 1m 56s) Loss: 0.3143(0.3143)
# Epoch: [17][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.1824(0.2530)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1931(0.1931)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0935(0.3782)
# 	 epoch:17, avg train loss:0.2530, avg valid loss:0.3782
# 	 score:0.5082(th=0.650000), auc=0.890779::: time:398.52s
# - epoch:18 -
# Epoch: [18][0/125] Elapsed 0m 0s (remain 2m 0s) Loss: 0.3673(0.3673)
# Epoch: [18][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2591(0.2551)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2888(0.2888)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1909(0.4562)
# 	 epoch:18, avg train loss:0.2551, avg valid loss:0.4562
# 	 score:0.4706(th=0.750000), auc=0.879969::: time:453.61s
# - epoch:19 -
# Epoch: [19][0/125] Elapsed 0m 1s (remain 2m 8s) Loss: 0.2578(0.2578)
# Epoch: [19][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2841(0.2634)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2066(0.2066)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1173(0.4055)
# 	 epoch:19, avg train loss:0.2634, avg valid loss:0.4055
# 	 score:0.5075(th=0.800000), auc=0.895361::: time:508.71s
# Epoch 19 - Save Best AUC: 0.8954. Model is saved.
# - epoch:20 -
# Epoch: [20][0/125] Elapsed 0m 1s (remain 2m 9s) Loss: 0.2202(0.2202)
# Epoch: [20][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2788(0.2795)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.5159(0.5159)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2890(0.6439)
# 	 epoch:20, avg train loss:0.2795, avg valid loss:0.6439
# 	 score:0.4382(th=0.850000), auc=0.878703::: time:565.67s
# surface_list:  range(25, 35, 3)
# - epoch:21 -
# Epoch: [21][0/125] Elapsed 0m 0s (remain 1m 51s) Loss: 0.2977(0.2977)
# Epoch: [21][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3665(0.2976)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 8s) Loss: 0.1196(0.1196)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1166(0.4045)
# 	 epoch:21, avg train loss:0.2976, avg valid loss:0.4045
# 	 score:0.4118(th=0.350000), auc=0.854418::: time:54.76s
# Epoch 21 - Save Best Score: 0.4118. Model is saved.
# dice_list:  [0.32483839971904144, 0.35365811623347637, 0.3746437985925251, 0.39489595629751634, 0.40884430454916765, 0.4117824013176446, 0.40278878573255217, 0.3817232313423099, 0.3464370348312585, 0.30423038168550864, 0.25764512000139517, 0.20538189168184062, 0.15443773570106187, 0.1070574180536837, 0.06907552142191623, 0.03380584538459249, 0.006347971127494707, 0.0, 0.0]
# Epoch 21 - Save Best AUC: 0.8544. Model is saved.
# - epoch:22 -
# Epoch: [22][0/125] Elapsed 0m 0s (remain 1m 54s) Loss: 0.2896(0.2896)
# Epoch: [22][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2788(0.2857)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1375(0.1375)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1364(0.4132)
# 	 epoch:22, avg train loss:0.2857, avg valid loss:0.4132
# 	 score:0.3801(th=0.450000), auc=0.844254::: time:112.56s
# - epoch:23 -
# Epoch: [23][0/125] Elapsed 0m 0s (remain 1m 52s) Loss: 0.3500(0.3500)
# Epoch: [23][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2160(0.2673)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2087(0.2087)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1106(0.3974)
# 	 epoch:23, avg train loss:0.2673, avg valid loss:0.3974
# 	 score:0.4262(th=0.550000), auc=0.864412::: time:167.33s
# Epoch 23 - Save Best Score: 0.4262. Model is saved.
# dice_list:  [0.296998343795394, 0.321489112787367, 0.3424070029086058, 0.36402421277911956, 0.38333998432158806, 0.39770497606155963, 0.4056431930496413, 0.4133570861899588, 0.42211680597660206, 0.4262019492100188, 0.42309805519489435, 0.41607599451936883, 0.4043124639202119, 0.38672345620163995, 0.3527536428036296, 0.2961657140012756, 0.2185364617092437, 0.12331837642156038, 0.0]
# Epoch 23 - Save Best AUC: 0.8644. Model is saved.
# - epoch:24 -
# Epoch: [24][0/125] Elapsed 0m 0s (remain 1m 59s) Loss: 0.1992(0.1992)
# Epoch: [24][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2492(0.2452)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2329(0.2329)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1223(0.4386)
# 	 epoch:24, avg train loss:0.2452, avg valid loss:0.4386
# 	 score:0.4674(th=0.700000), auc=0.879441::: time:224.95s
# Epoch 24 - Save Best Score: 0.4674. Model is saved.
# dice_list:  [0.2897587931238574, 0.3097677016041648, 0.32892003770375067, 0.3467878891662548, 0.3627679317719427, 0.3770603012216481, 0.3936811691770644, 0.4088477012677672, 0.42270622021409904, 0.4357508871854594, 0.4479325419109993, 0.46007617697543257, 0.4673689351388143, 0.4642283038242419, 0.4479473806307198, 0.4163383873592333, 0.356486024093974, 0.21797897999744514, 0.0]
# Epoch 24 - Save Best AUC: 0.8794. Model is saved.
# - epoch:25 -
# Epoch: [25][0/125] Elapsed 0m 0s (remain 1m 56s) Loss: 0.2590(0.2590)
# Epoch: [25][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.1473(0.2261)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1632(0.1632)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0987(0.3851)
# 	 epoch:25, avg train loss:0.2261, avg valid loss:0.3851
# 	 score:0.4850(th=0.600000), auc=0.878294::: time:282.70s
# Epoch 25 - Save Best Score: 0.4850. Model is saved.
# dice_list:  [0.3255052777056814, 0.3551774059321072, 0.3799997362502825, 0.4038271371602561, 0.42467039728616135, 0.44015394327341695, 0.45287061098722386, 0.4631028280342562, 0.4719773534634658, 0.4810183559413854, 0.4849869784582957, 0.4840491061206412, 0.47442161283473555, 0.4540865958615637, 0.4243541432368572, 0.37348689603396995, 0.2971459821273482, 0.17404708853751927, 0.0]
# - epoch:26 -
# Epoch: [26][0/125] Elapsed 0m 0s (remain 1m 57s) Loss: 0.1873(0.1873)
# Epoch: [26][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2054(0.2238)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1593(0.1593)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0994(0.3833)
# 	 epoch:26, avg train loss:0.2238, avg valid loss:0.3833
# 	 score:0.4745(th=0.600000), auc=0.876306::: time:338.82s
# - epoch:27 -
# Epoch: [27][0/125] Elapsed 0m 0s (remain 1m 57s) Loss: 0.2231(0.2231)
# Epoch: [27][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.1956(0.2225)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 8s) Loss: 0.1600(0.1600)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0960(0.3803)
# 	 epoch:27, avg train loss:0.2225, avg valid loss:0.3803
# 	 score:0.4830(th=0.550000), auc=0.877146::: time:393.63s
# - epoch:28 -
# Epoch: [28][0/125] Elapsed 0m 0s (remain 1m 57s) Loss: 0.1603(0.1603)
# Epoch: [28][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2028(0.2187)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1794(0.1794)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0886(0.3917)
# 	 epoch:28, avg train loss:0.2187, avg valid loss:0.3917
# 	 score:0.4919(th=0.600000), auc=0.879774::: time:448.68s
# Epoch 28 - Save Best Score: 0.4919. Model is saved.
# dice_list:  [0.3255265651810547, 0.35986573106519576, 0.3897204599693673, 0.41295368218782325, 0.4321408576161357, 0.44892814176136764, 0.4629027107051975, 0.47311420652008684, 0.48246271737871116, 0.4886574667935976, 0.49193485483185945, 0.4912457544199321, 0.48669931665897426, 0.47883650255391463, 0.4657241165073676, 0.4425529158340287, 0.40453484560031905, 0.3289037994889253, 0.0]
# Epoch 28 - Save Best AUC: 0.8798. Model is saved.
# - epoch:29 -
# Epoch: [29][0/125] Elapsed 0m 0s (remain 2m 3s) Loss: 0.1707(0.1707)
# Epoch: [29][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.1738(0.2368)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2488(0.2488)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0917(0.3976)
# 	 epoch:29, avg train loss:0.2368, avg valid loss:0.3976
# 	 score:0.4865(th=0.700000), auc=0.880372::: time:506.30s
# Epoch 29 - Save Best AUC: 0.8804. Model is saved.
# - epoch:30 -
# Epoch: [30][0/125] Elapsed 0m 0s (remain 2m 3s) Loss: 0.2297(0.2297)
# Epoch: [30][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2683(0.2445)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.5354(0.5354)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2098(0.6014)
# 	 epoch:30, avg train loss:0.2445, avg valid loss:0.6014
# 	 score:0.4728(th=0.900000), auc=0.871295::: time:562.47s
# [fold2] slice ave score:0.4801(th=0.750000), auc=0.884648
# [fold2] BEST Epoch 28 - Save Best Score:0.4919. Best loss:0.3917
# [fold2] BEST AUC Epoch 29 - Save Best Score:0.8804. Best loss:0.3976
# fold[0] BEST SCORE = 0.5785 thr=0.7 (epoch=30)
# fold[0] slice ave score:0.5783(th=0.700000), auc=0.889078
# fold[1] BEST SCORE = 0.4112 thr=0.45 (epoch=21)
# fold[1] slice ave score:0.4267(th=0.150000), auc=0.809144
# fold[2] BEST SCORE = 0.4919 thr=0.6 (epoch=28)
# fold[2] slice ave score:0.4801(th=0.750000), auc=0.884648
# CPU times: user 1h 16min 10s, sys: 20min 16s, total: 1h 36min 26s
# Wall time: 1h 42min 43s

# %% [markdown]
# ---
# # OOF SCORE CHECK

# %%
# %%time
slice_ave_score_list, slice_ave_score_threshold_list, slice_ave_auc_list = slide_inference(CFG)
for fold in CFG["folds"]:
    print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    wandb.log({"OOF SCORE" : {f"slice average score":slice_ave_score_list[fold],
                            f"slice average threshold":slice_ave_score_threshold_list[fold],
                            f"slice_average auc":slice_ave_auc_list[fold],
                            }})
# Out:
# -- fold0 slide inference start --
# surface_list:  range(26, 36, 3)
# slide pos: [0, 0]
# 	 score:0.5390(th=0.550000), auc=0.891497::: time:26.10s
# slide pos: [128, 0]
# 	 score:0.5427(th=0.550000), auc=0.886301::: time:43.77s
# slide pos: [0, 128]
# 	 score:0.5374(th=0.500000), auc=0.895301::: time:61.37s
# slide pos: [128, 128]
# 	 score:0.5464(th=0.500000), auc=0.895702::: time:79.10s
# surface_list:  range(27, 37, 3)
# slide pos: [0, 0]
# 	 score:0.5437(th=0.500000), auc=0.888315::: time:103.43s
# slide pos: [128, 0]
# 	 score:0.5313(th=0.500000), auc=0.885904::: time:120.84s
# slide pos: [0, 128]
# 	 score:0.5279(th=0.500000), auc=0.893250::: time:138.41s
# slide pos: [128, 128]
# 	 score:0.5300(th=0.450000), auc=0.892138::: time:156.30s
# surface_list:  range(25, 35, 3)
# slide pos: [0, 0]
# 	 score:0.5492(th=0.500000), auc=0.892627::: time:181.39s
# slide pos: [128, 0]
# 	 score:0.5460(th=0.500000), auc=0.890653::: time:199.19s
# slide pos: [0, 128]
# 	 score:0.5333(th=0.500000), auc=0.893873::: time:216.86s
# slide pos: [128, 128]
# 	 score:0.5394(th=0.500000), auc=0.895429::: time:234.78s
# [fold0] slice ave score:0.5816(th=0.500000), auc=0.905291
# -- fold1 slide inference start --
# surface_list:  range(26, 36, 3)
# slide pos: [0, 0]
# 	 score:0.4081(th=0.450000), auc=0.809019::: time:338.43s
# slide pos: [128, 0]
# 	 score:0.4082(th=0.450000), auc=0.807397::: time:405.48s
# slide pos: [0, 128]
# 	 score:0.4132(th=0.450000), auc=0.805830::: time:471.80s
# slide pos: [128, 128]
# 	 score:0.4112(th=0.450000), auc=0.807024::: time:538.94s
# surface_list:  range(27, 37, 3)
# slide pos: [0, 0]
# 	 score:0.4106(th=0.450000), auc=0.809852::: time:629.57s
# slide pos: [128, 0]
# 	 score:0.4066(th=0.450000), auc=0.809316::: time:698.35s
# slide pos: [0, 128]
# 	 score:0.4095(th=0.450000), auc=0.807983::: time:769.09s
# slide pos: [128, 128]
# 	 score:0.4042(th=0.400000), auc=0.809787::: time:835.95s
# surface_list:  range(25, 35, 3)
# slide pos: [0, 0]
# 	 score:0.4112(th=0.450000), auc=0.805836::: time:929.46s
# slide pos: [128, 0]
# 	 score:0.4094(th=0.400000), auc=0.804786::: time:996.97s
# slide pos: [0, 128]
# 	 score:0.4083(th=0.450000), auc=0.801034::: time:1067.68s
# slide pos: [128, 128]
# 	 score:0.4055(th=0.450000), auc=0.802181::: time:1135.75s
# [fold1] slice ave score:0.4389(th=0.400000), auc=0.819803
# -- fold2 slide inference start --
# surface_list:  range(26, 36, 3)
# slide pos: [0, 0]
# 	 score:0.4992(th=0.700000), auc=0.884601::: time:1223.07s
# slide pos: [128, 0]
# 	 score:0.5070(th=0.650000), auc=0.880004::: time:1244.71s
# slide pos: [0, 128]
# 	 score:0.5152(th=0.650000), auc=0.886543::: time:1266.47s
# slide pos: [128, 128]
# 	 score:0.5087(th=0.600000), auc=0.887794::: time:1288.44s
# surface_list:  range(27, 37, 3)
# slide pos: [0, 0]
# 	 score:0.4884(th=0.650000), auc=0.884953::: time:1319.88s
# slide pos: [128, 0]
# 	 score:0.4883(th=0.600000), auc=0.883541::: time:1341.49s
# slide pos: [0, 128]
# 	 score:0.4987(th=0.650000), auc=0.887001::: time:1363.05s
# slide pos: [128, 128]
# 	 score:0.5105(th=0.650000), auc=0.888776::: time:1385.10s
# surface_list:  range(25, 35, 3)
# slide pos: [0, 0]
# 	 score:0.4865(th=0.700000), auc=0.880372::: time:1415.41s
# slide pos: [128, 0]
# 	 score:0.4939(th=0.700000), auc=0.872873::: time:1436.99s
# slide pos: [0, 128]
# 	 score:0.5036(th=0.650000), auc=0.881302::: time:1459.52s
# slide pos: [128, 128]
# 	 score:0.4945(th=0.650000), auc=0.880996::: time:1481.83s
# [fold2] slice ave score:0.5376(th=0.600000), auc=0.898428
# fold[0] slice ave score:0.5816(th=0.905291), auc=0.500000
# fold[1] slice ave score:0.4389(th=0.819803), auc=0.400000
# fold[2] slice ave score:0.5376(th=0.898428), auc=0.600000
# CPU times: user 19min 31s, sys: 3min 27s, total: 22min 59s
# Wall time: 24min 59s

# %%
import yaml
with open(os.path.join(CFG["OUTPUT_DIR"], "Config.yaml"), "w") as f:
    yaml.dump(CFG, f)

# %%
if not CFG["DEBUG"]:
    wandb.finish()
