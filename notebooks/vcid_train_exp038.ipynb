# %% [markdown]
# # ex038
# bug fix masked_img
# 5-fold
# img size 512
# output shape is half of input shape
# not channel shuffle
# bcewithlogits weight 0.3
#
# effnet 5fold(exp037:4fold)
# lr, epoch change

# %%
import gc
import os
import random
import time
import math

import cv2
import numpy as np
import matplotlib.pyplot as plt

# model
import torch
import torchvision
import torch.nn as nn
import timm
from torchvision.models.feature_extraction import create_feature_extractor
import torchvision.transforms.functional as TF

# data loader
import albumentations as A
from albumentations.pytorch import ToTensorV2
from torch.utils.data import DataLoader, Dataset

# training
from torch.optim import SGD, Adam, AdamW
from torch.optim.lr_scheduler import CosineAnnealingLR, CosineAnnealingWarmRestarts, ReduceLROnPlateau, ExponentialLR, CyclicLR

# metric
from sklearn.metrics import fbeta_score, roc_auc_score

import wandb

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # config

# %%
BASE_DIR = "/working/"
INPUT_DIR = os.path.join(BASE_DIR, "input", "vesuvius-challenge-ink-detection")
TRAIN_DIR = os.path.join(INPUT_DIR, "train")
TEST_DIR = os.path.join(INPUT_DIR, "test")
# IMG_SIZE = [256, 256]
# IMG_SIZE = [128, 128]
IMG_SIZE = [512, 512]
SURFACE_LIST = [
                list(range(26, 36, 3)),
                list(range(27, 37, 3)),                
                list(range(25, 35, 3)),
                ]
print(len(SURFACE_LIST[0]))
print(SURFACE_LIST)

SURFACE_NUM = len(SURFACE_LIST[0])
# print("Start surface idx =",START_SURFACE)

# SLIDE_POS_LIST = [[idx*(IMG_SIZE[0]//6), idx*(IMG_SIZE[1]//6)] for idx in range(0, 3)]
SLIDE_POS_LIST = [[0,0], [IMG_SIZE[0]//2, 0], [0, IMG_SIZE[1]//2], [IMG_SIZE[0]//2, IMG_SIZE[1]//2]]
print("SLIDE_POS_LIST =", SLIDE_POS_LIST)
CFG = {
    "DEBUG" : False,
    # exp setting
    "EXP_CATEGORY" : "5fold",
    "EXP_NAME" : "exp038",
    "folds" : [0, 1, 2, 3, 4],

    # model
    # "model_name" : "tf_efficientnet_b2",
    "model_name" : "tf_efficientnet_b6",
    # "model_name" : "convnext_tiny",
    "inp_channels" : SURFACE_NUM,
    "out_channels" : 1,
    "pretrained" : True,
    # "out_indices" : [0,1,2,3,4],
    "out_indices": [0,1,2,3],
 
    # data   
    "img_size": IMG_SIZE,
    # "batch_size": 32,
    # "batch_size": 16,#batch normの関係か？16の方が64より安定してそう？？
    "batch_size": 8,
    "INPUT_DIR": INPUT_DIR,
    "TRAIN_DIR": TRAIN_DIR,
    "TEST_DIR": TEST_DIR,
    "surface_num": SURFACE_NUM,
    "surface_list": list(SURFACE_LIST),
    "slide_pos_list": SLIDE_POS_LIST,
    "RANDOM_SLIDE": True,
#     "surface_start_idx": START_SURFACE,
    # "TRAIN_DIR_LIST": [["1", "2"], ["1", "3"], ["2", "3"]],
    "TRAIN_DIR_LIST": [["1", "2_0", "2_1", "2_2"], 
                       ["1", "2_0", "2_1", "3"],
                       ["1", "2_0",  "2_2", "3"],
                       ["1", "2_1", "2_2", "3"],
                       ["2_0", "2_1", "2_2", "3"],
                       ],
#     "TRAIN_IDX_LIST" : ["1"],
    # "VALID_DIR_LIST": [["3"],["2"],["1"]],
    "VALID_DIR_LIST": [["3"], ["2_2"], ["2_1"], ["2_0"],["1"]],
    "TEST_DIR_LIST": ["a", "b"],

    # learning
    "n_epoch" : 15,
    "lr" : 1e-4,
    "T_max" : 5,
    "min_lr" : 1e-8,
    "weight_decay" : 1e-6,
    
    # cycliclr
    "step_size_up" : 5,
    "step_size_down" : 10,
    "max_lr" : 5e-4,
    "base_lr" : 5e-6,

    # etc
    "print_freq" : 1000,
    "random_seed" : 21,
    "num_workers": 2,
}


if CFG["model_name"]=="tf_efficientnet_b0":
    CFG["channel_nums"] = [320, 112, 40, 24, 16]
elif CFG["model_name"]=="tf_efficientnet_b2":
    CFG["channel_nums"] = [352, 120, 48, 24, 16]
elif CFG["model_name"]=="tf_efficientnet_b4":
    CFG["channel_nums"] = [448, 160, 56, 32, 24]
elif CFG["model_name"]=="tf_efficientnet_b6":
    # CFG["channel_nums"] = [576, 200, 72, 40, 32]
    CFG["channel_nums"] = [200, 72, 40, 32]
elif CFG["model_name"] == "convnext_tiny":
    CFG["channel_nums"] = [768, 384, 192, 96]


if CFG["DEBUG"]:
    CFG["n_epoch"] = 1
    CFG["EXP_NAME"] = "DEBUG"
    

CFG["OUTPUT_DIR"] = os.path.join(BASE_DIR, "output", CFG["EXP_NAME"])
# Out:
# 4
# [[26, 29, 32, 35], [27, 30, 33, 36], [25, 28, 31, 34]]
# SLIDE_POS_LIST = [[0, 0], [256, 0], [0, 256], [256, 256]]

# %%
if not CFG["DEBUG"]:
    os.makedirs(CFG["OUTPUT_DIR"])
    os.makedirs(os.path.join(CFG["OUTPUT_DIR"], "imgs"))

# %%
if not CFG["DEBUG"]:
    WANDB_CONFIG = {'competition': 'vcid', '_wandb_kernel': 'taro'}
    os.environ["WANDB_SILENT"] = "true"
    wandb.init(project=WANDB_CONFIG["competition"], config=CFG, group=CFG["EXP_CATEGORY"], name=CFG["EXP_NAME"], reinit=True)
# Out:
# 2023-04-24 11:14:05.339321: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-24 11:14:05.423200: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-24 11:14:06.012780: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-24 11:14:06.012863: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-24 11:14:06.012871: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
def logging_metrics_epoch(CFG, fold, epoch, slice_idx,train_loss_avg, valid_loss_avg, score, threshold, auc_score):
    wandb.log({f"train/fold{fold}": train_loss_avg,
                f"valid/fold{fold}": valid_loss_avg,
                f"score/fold{fold}":score,
                f"score threshold/fold{fold}":threshold,
                f"auc/fold{fold}":auc_score,
                f"epoch/fold{fold}":epoch+slice_idx*CFG["n_epoch"],
                })

# %%
def seed_everything(seed=CFG["random_seed"]):
    #os.environ['PYTHONSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic =True
    torch.backends.cudnn.benchmark = False
seed_everything()

# device optimization
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
def asMinutes(s):
    """Convert Seconds to Minutes."""
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    """Accessing and Converting Time Data."""
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))

class AverageMeter(object):
    """Computes and stores the average and current value."""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# # metric

# %%
def fbeta_numpy(targets, preds, beta=0.5, smooth=1e-5):
    y_true_count = targets.sum()
    ctp = preds[targets==1].sum()
    cfp = preds[targets==0].sum()
    beta_squared = beta * beta

    c_precision = ctp / (ctp + cfp + smooth)
    c_recall = ctp / (y_true_count + smooth)
    dice = (1 + beta_squared) * (c_precision * c_recall) / (beta_squared * c_precision + c_recall + smooth)

    return dice

def calc_fbeta_auc(mask, mask_pred):
    mask = mask.astype(int).flatten()
    mask_pred = mask_pred.flatten()

    best_th = 0
    best_dice = 0
    dice_list = [] 
    # for th in np.array(range(10, 50+1, 5)) / 100:
    for th in np.array(range(10, 100+1, 5)) / 100:
        # dice = fbeta_score(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice = fbeta_numpy(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice_list.append(dice)
        # print(f'\t th: {th}, fbeta: {dice}')
        if dice > best_dice:
            best_dice = dice
            best_th = th
    
    auc = roc_auc_score(mask, mask_pred)
    # Logger.info(f'best_th: {best_th}, fbeta: {best_dice}')
    return best_dice, best_th, auc, dice_list


def calc_cv(mask_gt, mask_pred):
    best_dice, best_th, auc, dice_list = calc_fbeta_auc(mask_gt, mask_pred)

    return best_dice, best_th, auc, dice_list

# %% [markdown]
# # model

# %%
# class Encoder(nn.Module):
#     def __init__(self, CFG):
#         super().__init__()
#         self.encoder = timm.create_model(CFG["model_name"], in_chans=CFG["inp_channels"], features_only=True, out_indices=CFG["out_indices"], pretrained=CFG["pretrained"])
#     def forward(self, img):
#         skip_connection_list = self.encoder(img)
#         return skip_connection_list

# class UpConv(nn.Module):
#     def __init__(self, in_channels, out_channels):
#         super().__init__()
#         self.up = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
#         self.bn1 = nn.BatchNorm2d(in_channels)
#         self.conv = nn.Conv2d(in_channels, out_channels, kernel_size = 2, padding="same")
#         self.bn2 = nn.BatchNorm2d(out_channels)

#     def forward(self, x):
#         x = self.up(x)
#         x = self.bn1(x)
#         x = self.conv(x)
#         x = self.bn2(x)
#         return x


# class Decoder(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.UpConv_0 = UpConv(CFG["channel_nums"][0], CFG["channel_nums"][1])
#         self.UpConv_1 = UpConv(CFG["channel_nums"][1]*2, CFG["channel_nums"][2])
#         self.UpConv_2 = UpConv(CFG["channel_nums"][2]*2, CFG["channel_nums"][3])
#         self.UpConv_3 = UpConv(CFG["channel_nums"][3]*2, CFG["channel_nums"][4])
#         # self.UpConv_4 = UpConv(CFG["channel_nums"][4]*2, CFG["channel_nums"][4])
    
#     def forward(self, skip_connection_list):
#         emb = self.UpConv_0(skip_connection_list[4]) # emb.shape = (None, 160, 14, 14)
#         emb_cat = torch.cat([skip_connection_list[3], emb], dim = 1)
        
#         emb = self.UpConv_1(emb_cat)
#         emb_cat = torch.cat([skip_connection_list[2], emb], dim = 1)
        
#         emb = self.UpConv_2(emb_cat)
#         emb_cat = torch.cat([skip_connection_list[1], emb], dim = 1)
        
#         emb = self.UpConv_3(emb_cat)
#         emb_cat = torch.cat([skip_connection_list[0], emb], dim = 1)

#         # emb_cat = self.UpConv_4(emb_cat)
        
#         return emb_cat

# class SegModel(nn.Module):
#     def __init__(self, CFG):
#         super().__init__()
#         self.encoder = Encoder(CFG)
#         self.decoder = Decoder()
#         self.head = nn.Sequential(
#             nn.Conv2d(CFG["channel_nums"][-1]*2, CFG["out_channels"], kernel_size=1, stride=1, padding=0),
#             # nn.Sigmoid()
#         )
#     def forward(self, img):
#         skip_connection_list = self.encoder(img)
#         emb = self.decoder(skip_connection_list)
#         output = self.head(emb)
#         assert output is not None, f"output is None, {img}, {skip_connection_list}, {emb}, {output}"
#         return output

# %%
class Encoder(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = timm.create_model(CFG["model_name"], in_chans=CFG["inp_channels"], 
                                         features_only=True, out_indices=CFG["out_indices"], pretrained=CFG["pretrained"])
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        return skip_connection_list

class UpConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.bn1 = nn.BatchNorm2d(in_channels)
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size = 2, padding="same")
        self.bn2 = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        x = self.up(x)
        x = self.bn1(x)
        x = self.conv(x)
        x = self.bn2(x)
        return x

"""
下に２層を使わない
"""
# class Decoder(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.UpConv_0 = UpConv(CFG["channel_nums"][0], CFG["channel_nums"][1])
#         self.UpConv_1 = UpConv(CFG["channel_nums"][1]*2, CFG["channel_nums"][2])
#         self.UpConv_2 = UpConv(CFG["channel_nums"][2]*2, CFG["channel_nums"][2])
    
#     def forward(self, skip_connection_list):
#         emb = self.UpConv_0(skip_connection_list[2]) # emb.shape = (None, 160, 14, 14)
#         emb_cat = torch.cat([skip_connection_list[1], emb], dim = 1)
        
#         emb = self.UpConv_1(emb_cat)
#         emb_cat = torch.cat([skip_connection_list[0], emb], dim = 1)
        
#         return emb_cat

"""
下に1層を使わない
"""
class Decoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.UpConv_0 = UpConv(CFG["channel_nums"][0], CFG["channel_nums"][1])
        self.UpConv_1 = UpConv(CFG["channel_nums"][1]*2, CFG["channel_nums"][2])
        self.UpConv_2 = UpConv(CFG["channel_nums"][2]*2, CFG["channel_nums"][3])
        self.UpConv_3 = UpConv(CFG["channel_nums"][3]*2, CFG["channel_nums"][3])
    
    def forward(self, skip_connection_list):
        emb = self.UpConv_0(skip_connection_list[3]) # emb.shape = (None, 160, 14, 14)
        emb_cat = torch.cat([skip_connection_list[2], emb], dim = 1)
        
        emb = self.UpConv_1(emb_cat)
        emb_cat = torch.cat([skip_connection_list[1], emb], dim = 1)
        
        emb = self.UpConv_2(emb_cat)
        emb_cat = torch.cat([skip_connection_list[0], emb], dim = 1)
        
        return emb_cat
    
# class Decoder(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.UpConv_0 = UpConv(CFG["channel_nums"][0], CFG["channel_nums"][1])
#         self.UpConv_1 = UpConv(CFG["channel_nums"][1]*2, CFG["channel_nums"][2])
#         self.UpConv_2 = UpConv(CFG["channel_nums"][2]*2, CFG["channel_nums"][3])
#         self.UpConv_3 = UpConv(CFG["channel_nums"][3]*2, CFG["channel_nums"][4])
#         self.UpConv_4 = UpConv(CFG["channel_nums"][4]*2, CFG["channel_nums"][4])
    
#     def forward(self, skip_connection_list):
#         emb = self.UpConv_0(skip_connection_list[4]) # emb.shape = (None, 160, 14, 14)
#         emb_cat = torch.cat([skip_connection_list[3], emb], dim = 1)
        
#         emb = self.UpConv_1(emb_cat)
#         emb_cat = torch.cat([skip_connection_list[2], emb], dim = 1)
        
#         emb = self.UpConv_2(emb_cat)
#         emb_cat = torch.cat([skip_connection_list[1], emb], dim = 1)
        
#         emb = self.UpConv_3(emb_cat)
#         emb_cat = torch.cat([skip_connection_list[0], emb], dim = 1)

#         emb_cat = self.UpConv_4(emb_cat)
        
#         return emb_cat

class SegModel(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = Encoder(CFG)
        self.decoder = Decoder()
        self.head = nn.Sequential(
            nn.Conv2d(CFG["channel_nums"][-1]*2, CFG["out_channels"], kernel_size=1, stride=1, padding=0),
            # nn.Sigmoid()
        )
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        emb = self.decoder(skip_connection_list)
        output = self.head(emb)
#         output = TF.resize(img=output, size=(CFG["img_size"][0], CFG["img_size"][1]))
        return output

# %% [markdown]
# # Dataset

# %%
train_transforms = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.RandomCrop(int(CFG["img_size"][0]*0.8), int(CFG["img_size"][1]*0.8), p=0.3),
    A.Blur(blur_limit=3, p=0.3),
    A.Resize(CFG["img_size"][0], CFG["img_size"][1]),
    ToTensorV2(),
])

valid_transforms = A.Compose([
    ToTensorV2(),
])

# %%
class VCID_Dataset(Dataset):
    def __init__(self, CFG, data_dir_list, surface_list, surface_volumes=None, slide_pos=[0,0], mode="train", transform=None):
        # get config
        self.mode = mode
        self.RANDOM_SLIDE = CFG["RANDOM_SLIDE"]
        self.img_size = CFG["img_size"]
        if self.mode=="train":  self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode=="valid":    self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode == "test":   self.DATADIR = CFG["TEST_DIR"]
        self.data_dir_list = data_dir_list
        self.surface_list = surface_list
        self.slide_pos = slide_pos
        self.transform = transform
        
        # get imgs
        # print("initializing dataset...")
        self.imgs = []
        for data_dir in self.data_dir_list:
            img_path = os.path.join(self.DATADIR, data_dir, "mask.png")
            # print(img_path)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            img = img.reshape(img.shape[0], img.shape[1], 1) # (h, w, channel=1)
            assert img is not None, "img is None. data path is wrong"
            self.imgs.append(img)  
        
        # get and split surface
        if surface_volumes is None:
            self.surface_vols = self.read_surfacevols()
        else:
            # print("using loaded surface_vols")
            self.surface_vols = surface_volumes
       
        # split grid
        self.get_all_grid()
        self.fileter_grid()
        self.get_flatten_grid()
        # print("split grid done.") 
       
        # get label imgs
        if self.mode == "train" or self.mode == "valid":
            self.labels = []
            for data_dir in self.data_dir_list:
                label_path = os.path.join(self.DATADIR, data_dir, "inklabels.png")
                assert os.path.exists(label_path), f"{label_path} is not exist."
                # read label
                label = cv2.imread(label_path, cv2.IMREAD_GRAYSCALE)
                label = label.reshape(label.shape[0], label.shape[1], 1) # (h, w, channel=1)
                self.labels.append(label)# 画像サイズがそれぞれ違うので単純にconcatできずlist化しているs
        # print("initializing dataset done.")

    def get_surface_volumes(self):
        return self.surface_vols

    def read_surfacevols(self):
        """ read surface volume by data_dir_list and surface_list 
            Returns:surface_vuls (list): surface volume list [array(h,w,channel=surface_num), array(), ...]
        """
        surface_vols = []
        # print("reading surface volume...")
        for data_dir in self.data_dir_list:
            surface_vol_ = None
            for read_idx, surface_idx in enumerate(self.surface_list):
                # print("\r", f"reading idx : {read_idx+1}/{len(self.surface_list)}", end="")
                surface_path = os.path.join(self.DATADIR, data_dir, "surface_volume", f"{surface_idx:02}.tif")
                surface_vol = cv2.imread(surface_path, cv2.IMREAD_GRAYSCALE)
                surface_vol = surface_vol.reshape(surface_vol.shape[0], surface_vol.shape[1], 1) # (h, w, channel=1)
                if surface_vol_ is None:
                    surface_vol_ = surface_vol
                else:
                    surface_vol_ = np.concatenate([surface_vol_, surface_vol], axis=2) # (h, w, channel=surface_num)
            surface_vols.append(surface_vol_)
            # print(f"  => read surface volume done. [{data_dir}]")
        return surface_vols


    def get_grid_img(self, img, grid_idx):
        """ crop grid img from original img"""
        img_grid = img[(grid_idx[0]*self.img_size[0]) + self.slide_pos[0] : ((grid_idx[0]+1)*self.img_size[0]) + self.slide_pos[0],
                        (grid_idx[1]*self.img_size[1]) + self.slide_pos[1] : ((grid_idx[1]+1)*self.img_size[1]) + self.slide_pos[1]]
        return img_grid
    
    def get_grid_img_and_mask(self, img, mask, grid_idx):
        """ crop grid img from original img"""
        if self.RANDOM_SLIDE and self.mode=="train" and random.random() < 0.5:
            if (grid_idx[0]!=0 and grid_idx[1]!=0) and (grid_idx[0]!=img.shape[0]//self.img_size[0] and grid_idx[1]!=img.shape[1]//self.img_size[1]):
                rand_pos = [np.random.randint(0, self.img_size[0]//4) - self.img_size[0]//4, np.random.randint(0, self.img_size[1]//4)-self.img_size[1]//4]
            else:
                rand_pos = [0, 0]
        else:
            rand_pos = [0, 0]
        self.rand_pos = rand_pos
        img_grid = img[(grid_idx[0]*self.img_size[0]) + self.slide_pos[0] + rand_pos[0] : ((grid_idx[0]+1)*self.img_size[0]) + self.slide_pos[0] + rand_pos[0],
                        (grid_idx[1]*self.img_size[1]) + self.slide_pos[1] + rand_pos[1] : ((grid_idx[1]+1)*self.img_size[1]) + self.slide_pos[1] + rand_pos[1]]
        mask_grid = mask[(grid_idx[0]*self.img_size[0]) + self.slide_pos[0] + rand_pos[0] : ((grid_idx[0]+1)*self.img_size[0]) + self.slide_pos[0] + rand_pos[0],
                         (grid_idx[1]*self.img_size[1]) + self.slide_pos[1] + rand_pos[1] : ((grid_idx[1]+1)*self.img_size[1]) + self.slide_pos[1] + rand_pos[1]]
        return img_grid/255., mask_grid/255.
    
    def get_masked_img(self, img, mask):
        """ multiply mask to surface_volumes """
        masked_img = None
        for channel in range(img.shape[2]):
            img_channel = img[:,:,channel].reshape(img.shape[0], img.shape[1],1)
            masked = img_channel*mask
            if masked_img is None:
                masked_img = masked.reshape(masked.shape[0], masked.shape[1], 1)
            else:
                masked = masked.reshape(masked.shape[0], masked.shape[1], 1)
                masked_img = np.concatenate([masked_img, masked], axis=2)
        return masked_img
    
    
    def get_all_grid(self):
        """ get all grid indices by img size and grid size
        """
        self.grid_indices = []
        for img in self.imgs:
            self.x_grid_size = (img.shape[0] - self.slide_pos[0]) // self.img_size[0]
            self.y_grid_size = (img.shape[1] - self.slide_pos[1]) // self.img_size[1]
            grid_img = []
            for i in range(self.x_grid_size):
                for j in range(self.y_grid_size):
                    grid_img.append([i, j])
            self.grid_indices.append(grid_img)
        return self.grid_indices
          
    def fileter_grid(self):
        """ get grid indices which mask is not 0 by all grid indices"""
        grid_indices_all = []
        for img, grid_indices in zip(self.imgs, self.grid_indices):
            grid_indices_copy = grid_indices.copy()
            for grid_idx in grid_indices:
                img_grid = self.get_grid_img(img, grid_idx)
                if img_grid.sum() == 0:
                    grid_indices_copy.remove(grid_idx)
            grid_indices_all.append(grid_indices_copy)
        self.grid_indices = grid_indices_all
        return self.grid_indices

    def get_flatten_grid(self):
        """ get flatten index list by grid indices
            Returns:flatten_grid (list): flatten index list [[img_idx, grid_idx], [img_idx, grid_idx], ...]
        """
        flatten_grid = []
        for img_idx, grid_indices in enumerate(self.grid_indices):
            for grid_idx in grid_indices:
                grid_imgidx_list = [img_idx]
                grid_imgidx_list.extend(grid_idx)
                flatten_grid.append(grid_imgidx_list)
        self.flatten_grid = flatten_grid
        return self.flatten_grid
    
    def channel_shuffle(self, img):
        img = img.transpose(2, 0, 1)
        np.random.shuffle(img)
        return img.transpose(1, 2, 0)

    def __len__(self):
        return len(self.flatten_grid)

    def __getitem__(self, idx):
        # get indices
        img_grid_idx = self.flatten_grid[idx]
        img_idx = img_grid_idx[0]
        grid_idx = img_grid_idx[1:]
        # get img & surface_vol
        mask = self.imgs[img_idx]
        surface_vol = self.surface_vols[img_idx]
        # mask = self.get_grid_img(mask, grid_idx)/255.
        # surface_vol = self.get_grid_img(surface_vol, grid_idx)/255.
        mask, surface_vol = self.get_grid_img_and_mask(mask, surface_vol, grid_idx)
        # multiple small mask 
        assert surface_vol.shape[0]==mask.shape[0] and surface_vol.shape[1]==mask.shape[1] , "surface_vol_list shape is not same as img shape"
        img = surface_vol
        # transform
        if self.mode == "test":
            if self.transform:
                img = self.transform(image=img)["image"]
            else:
                img = img.transpose(2, 0, 1)
                img = torch.tensor(img, dtype=torch.float32)
            return img, grid_idx
        elif self.mode == "train" or self.mode=="valid":
            # get label(segmentation mask)
            label = self.labels[img_idx]
            label = self.get_grid_img(label, grid_idx)
            # if self.mode == "train":
            #     img = self.channel_shuffle(img)
            if self.transform:
                transformed = self.transform(image=img, mask=label)
                img = transformed["image"]
                label = transformed["mask"]
                label = label.permute(2, 0, 1)/255. # (channel, h, w)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            else:
                img = img.transpose(2, 0, 1) # (channel, h, w)
                label = label.transpose(2, 0, 1)/255. # (channel, h, w){}
                img = torch.tensor(img, dtype=torch.float32)
                label = torch.tensor(label, dtype=torch.float32)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            assert img is not None and label is not None, f"img or label is None {img} {label}, {img_idx}, {grid_idx}, {self.rand_pos}"
            return img, label, grid_idx

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train")
# surface_volumes = dataset_notrans.surface_vols
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx < 2:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
        
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train")
# surface_volumes = dataset_notrans.surface_vols
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx < 2:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos=[0,50],mode="train")
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 1:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train", transform=train_transforms)
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)


# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 0:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %% [markdown]
# # Loss

# %%
#PyTorch
ALPHA = 0.1 # < 0.5 penalises FP more, > 0.5 penalises FN more
CE_RATIO = 0.90 #weighted contribution of modified CE loss compared to Dice loss

class ComboLoss(nn.Module):
    def __init__(self, weight=None, size_average=True):
        super(ComboLoss, self).__init__()

    def forward(self, inputs, targets, smooth=1, alpha=ALPHA, eps=1e-9):
        
        #flatten label and prediction tensors
        inputs = inputs.view(-1)
        targets = targets.view(-1)
        
        #True Positives, False Positives & False Negatives
        intersection = (inputs * targets).sum()    
        dice = (2. * intersection + smooth) / (inputs.sum() + targets.sum() + smooth)
        
        inputs = torch.clamp(inputs, eps, 1.0 - eps)       
        out = - (ALPHA * ((targets * torch.log(inputs)) + ((1 - ALPHA) * (1.0 - targets) * torch.log(1.0 - inputs))))
        weighted_ce = out.mean(-1)
        # if dice is None or dice > 0:
        #     combo = weighted_ce
        # else:
        #     combo = (CE_RATIO * weighted_ce) - ((1 - CE_RATIO) * dice)
        combo = (CE_RATIO * weighted_ce) - ((1 - CE_RATIO) * dice)
        assert combo is not None, f"combo loss is None, weighted_ce: {weighted_ce}, dice: {dice}"
        return combo

# %% [markdown]
# # train valid fn

# %%
def train_fn(train_loader, model, criterion, epoch ,optimizer, scheduler):
    model.train()
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, _) in enumerate(train_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()     
        preds = model(images)
        preds = TF.resize(img=preds, size=(CFG["img_size"][0], CFG["img_size"][1]))
        assert preds is not None, f"preds is None, {preds}, {images}, {targets}"
        loss = criterion(preds, targets)
        preds = torch.sigmoid(preds)
        assert loss is not None, f"loss is None, {loss}, {preds}, {targets}"
        losses.update(loss.item(), CFG["batch_size"]) 
        targets = targets.detach().cpu().numpy().ravel().tolist()
        preds = preds.detach().cpu().numpy().ravel().tolist()
        loss.backward() # パラメータの勾配を計算
        optimizer.step() # モデル更新
        optimizer.zero_grad() # 勾配の初期化
                
        batch_time.update(time.time() - end)
        end = time.time()
        if batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(train_loader)-1):
            print('Epoch: [{0}][{1}/{2}] '
                    'Elapsed {remain:s} '
                    'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                    .format(
                        epoch, batch_idx, len(train_loader), batch_time=batch_time, loss=losses,
                        remain=timeSince(start, float(batch_idx+1)/len(train_loader)),
            ))
        del preds, images, targets
    gc.collect()
    torch.cuda.empty_cache()
    return losses.avg

# %%
def valid_fn(model, valid_loader, criterion=None):
    model.eval()# モデルを検証モードに設定
    test_targets = []
    test_preds = []
    test_grid_idx = []
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, grid_idx) in enumerate(valid_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()
        with torch.no_grad():
            preds = model(images)
            preds = TF.resize(img=preds, size=(CFG["img_size"][0], CFG["img_size"][1]))
            assert preds is not None, f"preds is None, {preds}, {images}, {targets}"
            if not criterion is None:
                loss = criterion(preds, targets)
                assert loss is not None, f"loss is None, {loss}, {preds}, {targets}"
            preds = torch.sigmoid(preds)
        if not criterion is None:
            losses.update(loss.item(), CFG["batch_size"])
        batch_time.update(time.time() - end)

        targets = targets.detach().cpu().numpy()
        preds = preds.detach().cpu().numpy()
        
        test_preds.extend([preds[idx, :,:,:].transpose(1,2,0) for idx in range(preds.shape[0])])
        test_targets.extend([targets[idx, :,:,:].transpose(1,2,0) for idx in range(targets.shape[0])])
        test_grid_idx.extend([[x_idx, y_idx] for x_idx, y_idx in zip(grid_idx[0].tolist(), grid_idx[1].tolist())])

        if (batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(valid_loader)-1)) and (not criterion is None):
            print('EVAL: [{0}/{1}] '
                'Elapsed {remain:s} '
                'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                .format(
                    batch_idx, len(valid_loader), batch_time=batch_time, loss=losses,
                    remain=timeSince(start, float(batch_idx+1)/len(valid_loader)),
                ))
        del preds, images, targets
        gc.collect()
        torch.cuda.empty_cache()
    if criterion is None:
        return test_targets, test_preds, test_grid_idx
    else:
        return test_targets, test_preds, test_grid_idx, losses.avg

# %% [markdown]
# # training loop

# %%
# def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list):
#     # concat pred img and label to original size
#     img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
#     img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
#     img = img.reshape(img.shape[0], img.shape[1], 1)
#     pred_img = np.zeros_like(img).astype(np.float32)
#     label_img = np.zeros_like(img).astype(np.float32)
#     for img_idx, grid_idx in enumerate(grid_idx_list):
#         pred_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += img_list[img_idx]
        
#         label_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += label_list[img_idx]
#     return pred_img, label_img

# %%
def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list, slide_pos=[0,0]):
    # concat pred img and label to original size
    img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    img = img.reshape(img.shape[0], img.shape[1], 1)
    pred_img = np.zeros_like(img).astype(np.float32)
    label_img = np.zeros_like(img).astype(np.float32)
    for img_idx, grid_idx in enumerate(grid_idx_list):
        pred_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += img_list[img_idx]
        
        label_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += label_list[img_idx]
    return pred_img, label_img

# %%
def save_and_plot_oof(mode, fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary):
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_pred_img.png"), valid_preds_img*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_predbin_img.png"), valid_preds_binary*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_targets_img.png"), valid_targets_img*255)
    
    # plot preds & binary preds
    # plt.figure(dpi=100)
    # plt.subplot(1,3,1)
    # plt.imshow(valid_preds_img)
    # plt.subplot(1,3,2)
    # plt.imshow(valid_preds_binary)
    # plt.subplot(1,3,3)
    # plt.imshow(valid_targets_img)
    # plt.show()

# %%
def training_loop(CFG):
    best_score_list = []
    best_threshold_list = []
    best_epoch_list = []
    slice_ave_score_list = []
    slice_ave_auc_list = []
    slice_ave_score_threshold_list = []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} training start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        model = model.to(device)
        valid_img_slice = []
        # criterion = nn.BCELoss()
        # criterion = ComboLoss()
        weights = torch.tensor([0.3]).cuda()
        criterion = torch.nn.BCEWithLogitsLoss(pos_weight=weights)
        optimizer = AdamW(model.parameters(), lr=CFG["lr"], weight_decay=CFG["weight_decay"], amsgrad=False)
        scheduler = CosineAnnealingLR(optimizer, T_max=CFG["T_max"], eta_min=CFG["min_lr"], last_epoch=-1)
        # scheduler = ExponentialLR(optimizer, gamma=0.60)
        scheduler = CyclicLR(optimizer, base_lr=CFG["base_lr"], max_lr=CFG["max_lr"],
                            step_size_up=CFG["step_size_up"], step_size_down=CFG["step_size_down"], 
                            cycle_momentum=False, mode='triangular2')
        
        # training
        best_score = -np.inf
        best_auc = -np.inf
        best_valloss = np.inf
        best_auc_valloss = np.inf
        best_threshold = -1
        start_time = time.time()
        best_epoch = -1
        best_auc_epoch = -1
        valid_slice_ave = None       
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            # separate train/valid data 
            train_dirs = CFG["TRAIN_DIR_LIST"][fold]
            valid_dirs = CFG["VALID_DIR_LIST"][fold]
            train_dataset = VCID_Dataset(CFG, train_dirs, surface_list, mode="train", transform=train_transforms)
            valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, mode="valid", transform=valid_transforms)
            train_loader = DataLoader(train_dataset, batch_size=CFG["batch_size"], shuffle = True,
                                        num_workers = CFG["num_workers"], pin_memory = True)
            valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                        num_workers = CFG["num_workers"], pin_memory = True)
            for epoch in range(1, CFG["n_epoch"] + 1):
                epochs_ = epoch + CFG["n_epoch"] * slice_idx
                print(f'- epoch:{epochs_} -')
                train_loss_avg = train_fn(train_loader, model, criterion, epochs_ ,optimizer, scheduler)
                valid_targets, valid_preds, valid_grid_idx, valid_loss_avg = valid_fn(model, valid_loader, criterion)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                
                elapsed = time.time() - start_time
                print(f"\t epoch:{epochs_}, avg train loss:{train_loss_avg:.4f}, avg valid loss:{valid_loss_avg:.4f}")
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                if not CFG["DEBUG"]:
                    logging_metrics_epoch(CFG, fold, epoch, slice_idx, train_loss_avg, valid_loss_avg, valid_score, valid_threshold, auc)
                scheduler.step()
                # validationスコアがbestを更新したらモデルを保存する
                if valid_score > best_score:
                    best_epoch = epochs_
                    best_valloss = valid_loss_avg
                    best_score = valid_score
                    best_threshold = valid_threshold
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epochs_} - Save Best Score: {best_score:.4f}. Model is saved.')
                    print("dice_list: ", dice_list)
                    # save oof
                    save_and_plot_oof("score", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
                
                if auc > best_auc:
                    best_auc = auc
                    best_auc_epoch = epochs_
                    best_auc_valloss = valid_loss_avg
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_auc_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epochs_} - Save Best AUC: {best_auc:.4f}. Model is saved.')
                    # save oof
                    save_and_plot_oof("auc", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
            # valid_img_slice.append(valid_preds_img)
            if valid_slice_ave is None:
                valid_slice_ave = valid_preds_img
            else:
                valid_slice_ave += valid_preds_img
        # valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        # for idx in range(len(SURFACE_LIST)):
        #     valid_pred_slice = valid_img_slice[idx]
        #     valid_slice_ave += valid_pred_slice
        valid_slice_ave /= len(SURFACE_LIST)
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_slice_ave)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)
 
        valid_slice_binary = (valid_slice_ave > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 999, valid_slice_ave, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
        
        print(f'[fold{fold}] BEST Epoch {best_epoch} - Save Best Score:{best_score:.4f}. Best loss:{best_valloss:.4f}')
        print(f'[fold{fold}] BEST AUC Epoch {best_auc_epoch} - Save Best Score:{best_auc:.4f}. Best loss:{best_auc_valloss:.4f}')
            
        best_score_list.append(best_score)
        best_threshold_list.append(best_threshold)
        best_epoch_list.append(best_epoch)
        del model, train_loader, train_dataset, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
        
    for fold, (best_score, best_threshold, best_epoch) in enumerate(zip(best_score_list, best_threshold_list, best_epoch_list)):
        print(f"fold[{fold}] BEST SCORE = {best_score:.4f} thr={best_threshold} (epoch={best_epoch})")
        print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    return best_score_list, best_threshold_list, best_epoch_list

# %% [markdown]
# # slice inference

# %%
def slide_inference(CFG):
    start_time = time.time()
    slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list = [], [], []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} slide inference start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        # model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_fold{fold}.pth')
        model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_auc_fold{fold}.pth')
        model.load_state_dict(torch.load(model_path))
        model = model.to(device)
        valid_img_slice = None
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            surface_volumes = None
            for slide_pos in CFG["slide_pos_list"]:
                print("slide pos:", slide_pos)
                valid_dirs = CFG["VALID_DIR_LIST"][fold]
                valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos, mode="valid", transform=valid_transforms)
                surface_volumes = valid_dataset.get_surface_volumes()
                valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                            num_workers = CFG["num_workers"], pin_memory = True)

                valid_targets, valid_preds, valid_grid_idx = valid_fn(model, valid_loader)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs, slide_pos)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                save_and_plot_oof("slide", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary) 
                
                elapsed = time.time() - start_time
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                # valid_img_slice.append(valid_preds_img)
                if valid_img_slice is None:
                    valid_img_slice = valid_preds_img
                else:
                    valid_img_slice += valid_preds_img
            # valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        # for idx in range(len(SURFACE_LIST)*len(CFG["slide_pos_list"])):
        #     valid_pred_slice = valid_img_slice[idx]
        #     valid_slice_ave += valid_pred_slice
        valid_img_slice /= len(SURFACE_LIST)*len(CFG["slide_pos_list"])
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_img_slice)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)

        valid_slice_binary = (valid_img_slice > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 555, valid_img_slice, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
         
        del model, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
    return slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list

# %% [markdown]
# # main

# %%
# %%time
best_score_list, best_threshold_list, best_epoch_list = training_loop(CFG)
# Out:
# -- fold0 training start --
# surface_list:  [26, 29, 32, 35]
# - epoch:1 -
# Epoch: [1][0/65] Elapsed 0m 1s (remain 1m 16s) Loss: 0.7667(0.7667)
# Epoch: [1][64/65] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4660(0.5625)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.3874(0.3874)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3456(0.3929)
# 	 epoch:1, avg train loss:0.5625, avg valid loss:0.3929
# 	 score:0.1922(th=0.450000), auc=0.734870::: time:76.86s
# Epoch 1 - Save Best Score: 0.1922. Model is saved.
# dice_list:  [0.13067366932925517, 0.13386426688156963, 0.15613871311998367, 0.17233080536544348, 0.18021309005538813, 0.1862739039455724, 0.1905795438046309, 0.19216859681171788, 0.19065481091000283, 0.1850086036014639, 0.17458330235405073, 0.15807084912008554, 0.13502470287592444, 0.10599293229389656, 0.07540828833007339, 0.04657586103054791, 0.023607810424706457, 0.007572152819657981, 0.0]
# Epoch 1 - Save Best AUC: 0.7349. Model is saved.
# - epoch:2 -
# Epoch: [2][0/65] Elapsed 0m 1s (remain 1m 8s) Loss: 0.4463(0.4463)
# Epoch: [2][64/65] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4010(0.3797)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.3003(0.3003)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2803(0.3062)
# 	 epoch:2, avg train loss:0.3797, avg valid loss:0.3062
# 	 score:0.2483(th=0.450000), auc=0.761303::: time:122.82s
# Epoch 2 - Save Best Score: 0.2483. Model is saved.
# dice_list:  [0.13394661517929435, 0.1413312896616914, 0.1687033860337687, 0.2082313973979615, 0.2252053739902721, 0.2385764263113067, 0.24695273389919872, 0.24829561925262728, 0.24058350713416785, 0.22172801280634688, 0.19137283068631103, 0.1521743863097929, 0.10937098705248317, 0.07005833991532917, 0.03921656247462038, 0.018170163635927997, 0.006442942749867775, 0.0013028935156158127, 0.0]
# Epoch 2 - Save Best AUC: 0.7613. Model is saved.
# - epoch:3 -
# Epoch: [3][0/65] Elapsed 0m 1s (remain 1m 10s) Loss: 0.3190(0.3190)
# Epoch: [3][64/65] Elapsed 0m 25s (remain 0m 0s) Loss: 0.4208(0.2667)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1722(0.1722)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1842(0.1853)
# 	 epoch:3, avg train loss:0.2667, avg valid loss:0.1853
# 	 score:0.4129(th=0.300000), auc=0.793943::: time:168.39s
# Epoch 3 - Save Best Score: 0.4129. Model is saved.
# dice_list:  [0.15938467634820697, 0.24216443219435752, 0.344307859215037, 0.3914614874929946, 0.4129263858172202, 0.4115763141363748, 0.39249291011783805, 0.3622479445717227, 0.32501932695187935, 0.28384712656534195, 0.24060706574732277, 0.19699115648811047, 0.15373037385120672, 0.11219773258711122, 0.07459019954871374, 0.04344977663047022, 0.020484850675655787, 0.005835401677434718, 0.0]
# Epoch 3 - Save Best AUC: 0.7939. Model is saved.
# - epoch:4 -
# Epoch: [4][0/65] Elapsed 0m 1s (remain 1m 10s) Loss: 0.2218(0.2218)
# Epoch: [4][64/65] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1230(0.2023)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1422(0.1422)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1338(0.1641)
# 	 epoch:4, avg train loss:0.2023, avg valid loss:0.1641
# 	 score:0.4600(th=0.400000), auc=0.872129::: time:213.72s
# Epoch 4 - Save Best Score: 0.4600. Model is saved.
# dice_list:  [0.24594421517881634, 0.3040768934999117, 0.3528004334886905, 0.3936281259278878, 0.4266786557284786, 0.4494812100023942, 0.4600202506793065, 0.45512034230298576, 0.43172434430053147, 0.3896591889815929, 0.32950590161440413, 0.25685507982173245, 0.18014015942666156, 0.11008985122665285, 0.055844765247630816, 0.022630798696417254, 0.006398455141205458, 0.0008403611745805278, 0.0]
# Epoch 4 - Save Best AUC: 0.8721. Model is saved.
# - epoch:5 -
# Epoch: [5][0/65] Elapsed 0m 1s (remain 1m 19s) Loss: 0.1346(0.1346)
# Epoch: [5][64/65] Elapsed 0m 25s (remain 0m 0s) Loss: 0.1114(0.1747)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0620(0.0620)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1236(0.1164)
# 	 epoch:5, avg train loss:0.1747, avg valid loss:0.1164
# 	 score:0.4701(th=0.200000), auc=0.863206::: time:259.24s
# Epoch 5 - Save Best Score: 0.4701. Model is saved.
# dice_list:  [0.4156638575687343, 0.45720296117709086, 0.4701363954711935, 0.4671822133971043, 0.4546636394560691, 0.4354930104857879, 0.41198401158764003, 0.3851584880925831, 0.35505860791171984, 0.32188394886214516, 0.2859361213775367, 0.2475624621886414, 0.20635960450989, 0.1633692557963143, 0.1204200138594752, 0.07999876832851484, 0.04299716411260374, 0.01031244857847038, 0.0]
# - epoch:6 -
# Epoch: [6][0/65] Elapsed 0m 1s (remain 1m 11s) Loss: 0.1140(0.1140)
# Epoch: [6][64/65] Elapsed 0m 26s (remain 0m 0s) Loss: 0.0918(0.1676)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0810(0.0810)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1178(0.1220)
# 	 epoch:6, avg train loss:0.1676, avg valid loss:0.1220
# 	 score:0.4578(th=0.300000), auc=0.874333::: time:302.67s
# Epoch 6 - Save Best AUC: 0.8743. Model is saved.
# - epoch:7 -
# Epoch: [7][0/65] Elapsed 0m 1s (remain 1m 13s) Loss: 0.2647(0.2647)
# Epoch: [7][64/65] Elapsed 0m 25s (remain 0m 0s) Loss: 0.1446(0.1637)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0684(0.0684)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1222(0.1168)
# 	 epoch:7, avg train loss:0.1637, avg valid loss:0.1168
# 	 score:0.4612(th=0.200000), auc=0.855702::: time:345.24s
# - epoch:8 -
# Epoch: [8][0/65] Elapsed 0m 1s (remain 1m 9s) Loss: 0.1557(0.1557)
# Epoch: [8][64/65] Elapsed 0m 25s (remain 0m 0s) Loss: 0.0877(0.1543)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0587(0.0587)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1219(0.1111)
# 	 epoch:8, avg train loss:0.1543, avg valid loss:0.1111
# 	 score:0.4982(th=0.150000), auc=0.874619::: time:386.00s
# Epoch 8 - Save Best Score: 0.4982. Model is saved.
# dice_list:  [0.46146898463247915, 0.49820216408478374, 0.49580846644010673, 0.4698742401760804, 0.4292316249146362, 0.3804305626916501, 0.3280816772678941, 0.2733679828878668, 0.2184652177410364, 0.16788650828292043, 0.12184549039043102, 0.08173482923002362, 0.048543520408103065, 0.023592933084115565, 0.007977096503145258, 0.0015070646804180902, 0.00014124325503916211, 4.815644930245755e-06, 0.0]
# Epoch 8 - Save Best AUC: 0.8746. Model is saved.
# - epoch:9 -
# Epoch: [9][0/65] Elapsed 0m 1s (remain 1m 20s) Loss: 0.1533(0.1533)
# Epoch: [9][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1311(0.1509)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0749(0.0749)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1166(0.1143)
# 	 epoch:9, avg train loss:0.1509, avg valid loss:0.1143
# 	 score:0.4983(th=0.250000), auc=0.872948::: time:429.32s
# Epoch 9 - Save Best Score: 0.4983. Model is saved.
# dice_list:  [0.42108742680509226, 0.46633873089118627, 0.4894544726781388, 0.49828973983268227, 0.49610926050046783, 0.4846968187825725, 0.4669527399204489, 0.44437845357500955, 0.4173411964577325, 0.38607473490854016, 0.34923296317295155, 0.30387121051573873, 0.24986792778959244, 0.18776707912003204, 0.12186435946442686, 0.05994308425232555, 0.018085583850048045, 0.0016800107890468576, 0.0]
# - epoch:10 -
# Epoch: [10][0/65] Elapsed 0m 1s (remain 1m 22s) Loss: 0.1821(0.1821)
# Epoch: [10][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.0852(0.1528)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0709(0.0709)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1158(0.1155)
# 	 epoch:10, avg train loss:0.1528, avg valid loss:0.1155
# 	 score:0.4971(th=0.250000), auc=0.873469::: time:471.26s
# - epoch:11 -
# Epoch: [11][0/65] Elapsed 0m 1s (remain 1m 21s) Loss: 0.1393(0.1393)
# Epoch: [11][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2684(0.1478)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0558(0.0558)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1249(0.1156)
# 	 epoch:11, avg train loss:0.1478, avg valid loss:0.1156
# 	 score:0.4935(th=0.150000), auc=0.850930::: time:511.41s
# - epoch:12 -
# Epoch: [12][0/65] Elapsed 0m 1s (remain 1m 26s) Loss: 0.1111(0.1111)
# Epoch: [12][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1015(0.1423)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0629(0.0629)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1164(0.1132)
# 	 epoch:12, avg train loss:0.1423, avg valid loss:0.1132
# 	 score:0.4904(th=0.200000), auc=0.869656::: time:551.88s
# - epoch:13 -
# Epoch: [13][0/65] Elapsed 0m 1s (remain 1m 14s) Loss: 0.0873(0.0873)
# Epoch: [13][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.0697(0.1354)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0819(0.0819)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1165(0.1180)
# 	 epoch:13, avg train loss:0.1354, avg valid loss:0.1180
# 	 score:0.4969(th=0.250000), auc=0.860223::: time:592.13s
# - epoch:14 -
# Epoch: [14][0/65] Elapsed 0m 1s (remain 1m 23s) Loss: 0.1437(0.1437)
# Epoch: [14][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.3443(0.1387)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0599(0.0599)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1227(0.1103)
# 	 epoch:14, avg train loss:0.1387, avg valid loss:0.1103
# 	 score:0.5349(th=0.200000), auc=0.872015::: time:632.27s
# Epoch 14 - Save Best Score: 0.5349. Model is saved.
# dice_list:  [0.4724127803946301, 0.5216957945178596, 0.534869540811884, 0.5285568937309052, 0.5116402933619558, 0.4878586265311755, 0.45814634146956634, 0.41941004605384824, 0.3719927470471121, 0.31612496508769056, 0.25218024082628937, 0.18229685804979434, 0.11412222126457561, 0.05719820244662668, 0.02123812313271958, 0.004645331437628617, 0.0003049148887942013, 1.605219099075328e-06, 0.0]
# - epoch:15 -
# Epoch: [15][0/65] Elapsed 0m 1s (remain 1m 16s) Loss: 0.0614(0.0614)
# Epoch: [15][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1867(0.1312)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0614(0.0614)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1228(0.1108)
# 	 epoch:15, avg train loss:0.1312, avg valid loss:0.1108
# 	 score:0.5191(th=0.200000), auc=0.875283::: time:674.40s
# Epoch 15 - Save Best AUC: 0.8753. Model is saved.
# surface_list:  [27, 30, 33, 36]
# - epoch:16 -
# Epoch: [16][0/65] Elapsed 0m 1s (remain 1m 18s) Loss: 0.1535(0.1535)
# Epoch: [16][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.0876(0.1337)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0608(0.0608)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1172(0.1116)
# 	 epoch:16, avg train loss:0.1337, avg valid loss:0.1116
# 	 score:0.5160(th=0.250000), auc=0.876267::: time:754.26s
# Epoch 16 - Save Best AUC: 0.8763. Model is saved.
# - epoch:17 -
# Epoch: [17][0/65] Elapsed 0m 1s (remain 1m 15s) Loss: 0.1279(0.1279)
# Epoch: [17][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.3229(0.1377)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0524(0.0524)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1213(0.1102)
# 	 epoch:17, avg train loss:0.1377, avg valid loss:0.1102
# 	 score:0.5170(th=0.200000), auc=0.879326::: time:796.19s
# Epoch 17 - Save Best AUC: 0.8793. Model is saved.
# - epoch:18 -
# Epoch: [18][0/65] Elapsed 0m 1s (remain 1m 18s) Loss: 0.1260(0.1260)
# Epoch: [18][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1557(0.1360)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0681(0.0681)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1151(0.1121)
# 	 epoch:18, avg train loss:0.1360, avg valid loss:0.1121
# 	 score:0.5210(th=0.250000), auc=0.880033::: time:837.51s
# Epoch 18 - Save Best AUC: 0.8800. Model is saved.
# - epoch:19 -
# Epoch: [19][0/65] Elapsed 0m 1s (remain 1m 19s) Loss: 0.1182(0.1182)
# Epoch: [19][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1688(0.1331)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0587(0.0587)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1300(0.1126)
# 	 epoch:19, avg train loss:0.1331, avg valid loss:0.1126
# 	 score:0.5105(th=0.200000), auc=0.862717::: time:878.95s
# - epoch:20 -
# Epoch: [20][0/65] Elapsed 0m 1s (remain 1m 16s) Loss: 0.1187(0.1187)
# Epoch: [20][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.6098(0.1402)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0597(0.0597)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1138(0.1118)
# 	 epoch:20, avg train loss:0.1402, avg valid loss:0.1118
# 	 score:0.5330(th=0.250000), auc=0.866681::: time:919.15s
# - epoch:21 -
# Epoch: [21][0/65] Elapsed 0m 1s (remain 1m 16s) Loss: 0.0945(0.0945)
# Epoch: [21][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1103(0.1350)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0548(0.0548)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1191(0.1123)
# 	 epoch:21, avg train loss:0.1350, avg valid loss:0.1123
# 	 score:0.5502(th=0.300000), auc=0.871251::: time:959.25s
# Epoch 21 - Save Best Score: 0.5502. Model is saved.
# dice_list:  [0.40972471762355817, 0.47484172290790616, 0.516938584205573, 0.5421447040587725, 0.5502013312821779, 0.5420934079317816, 0.5159876174914106, 0.4742474265448309, 0.4190448363706538, 0.3535100892141135, 0.2829842653986113, 0.21528260845399746, 0.15558712833182775, 0.10454984343225406, 0.05933535520195902, 0.02433714731353289, 0.005791897093683479, 0.00033379684143456187, 0.0]
# - epoch:22 -
# Epoch: [22][0/65] Elapsed 0m 1s (remain 1m 15s) Loss: 0.0948(0.0948)
# Epoch: [22][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.0535(0.1318)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0649(0.0649)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1152(0.1112)
# 	 epoch:22, avg train loss:0.1318, avg valid loss:0.1112
# 	 score:0.5335(th=0.250000), auc=0.879961::: time:1000.85s
# - epoch:23 -
# Epoch: [23][0/65] Elapsed 0m 1s (remain 1m 21s) Loss: 0.1203(0.1203)
# Epoch: [23][64/65] Elapsed 0m 25s (remain 0m 0s) Loss: 0.0994(0.1278)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0497(0.0497)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1158(0.1078)
# 	 epoch:23, avg train loss:0.1278, avg valid loss:0.1078
# 	 score:0.5543(th=0.250000), auc=0.880583::: time:1041.59s
# Epoch 23 - Save Best Score: 0.5543. Model is saved.
# dice_list:  [0.47162867932722485, 0.5249735665893582, 0.5486194113273936, 0.5542634043689545, 0.5467438507556305, 0.5286044991590381, 0.5028203430195517, 0.46986834206415906, 0.42914410554543897, 0.3810741731662151, 0.32501085558857673, 0.26300964872539373, 0.19858384138433277, 0.1336884588718032, 0.07121750853695744, 0.025187823542725717, 0.0041915224158986875, 4.0129240700798975e-05, 0.0]
# Epoch 23 - Save Best AUC: 0.8806. Model is saved.
# - epoch:24 -
# Epoch: [24][0/65] Elapsed 0m 1s (remain 1m 19s) Loss: 0.1326(0.1326)
# Epoch: [24][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2464(0.1295)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0517(0.0517)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1204(0.1073)
# 	 epoch:24, avg train loss:0.1295, avg valid loss:0.1073
# 	 score:0.5422(th=0.200000), auc=0.885821::: time:1084.68s
# Epoch 24 - Save Best AUC: 0.8858. Model is saved.
# - epoch:25 -
# Epoch: [25][0/65] Elapsed 0m 1s (remain 1m 21s) Loss: 0.1813(0.1813)
# Epoch: [25][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.0799(0.1258)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0468(0.0468)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1269(0.1113)
# 	 epoch:25, avg train loss:0.1258, avg valid loss:0.1113
# 	 score:0.5367(th=0.150000), auc=0.868471::: time:1126.43s
# - epoch:26 -
# Epoch: [26][0/65] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2097(0.2097)
# Epoch: [26][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1003(0.1265)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0498(0.0498)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1258(0.1120)
# 	 epoch:26, avg train loss:0.1265, avg valid loss:0.1120
# 	 score:0.5060(th=0.200000), auc=0.868781::: time:1166.69s
# - epoch:27 -
# Epoch: [27][0/65] Elapsed 0m 1s (remain 1m 14s) Loss: 0.0866(0.0866)
# Epoch: [27][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.3686(0.1271)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0512(0.0512)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1255(0.1130)
# 	 epoch:27, avg train loss:0.1271, avg valid loss:0.1130
# 	 score:0.5148(th=0.200000), auc=0.865682::: time:1206.72s
# - epoch:28 -
# Epoch: [28][0/65] Elapsed 0m 1s (remain 1m 22s) Loss: 0.0851(0.0851)
# Epoch: [28][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2672(0.1233)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0459(0.0459)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1289(0.1133)
# 	 epoch:28, avg train loss:0.1233, avg valid loss:0.1133
# 	 score:0.5292(th=0.150000), auc=0.867253::: time:1246.76s
# - epoch:29 -
# Epoch: [29][0/65] Elapsed 0m 1s (remain 1m 20s) Loss: 0.1163(0.1163)
# Epoch: [29][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2633(0.1214)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0487(0.0487)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1266(0.1111)
# 	 epoch:29, avg train loss:0.1214, avg valid loss:0.1111
# 	 score:0.5270(th=0.200000), auc=0.872563::: time:1287.14s
# - epoch:30 -
# Epoch: [30][0/65] Elapsed 0m 1s (remain 1m 18s) Loss: 0.1363(0.1363)
# Epoch: [30][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2762(0.1221)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0458(0.0458)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1294(0.1144)
# 	 epoch:30, avg train loss:0.1221, avg valid loss:0.1144
# 	 score:0.5198(th=0.150000), auc=0.860592::: time:1327.22s
# surface_list:  [25, 28, 31, 34]
# - epoch:31 -
# Epoch: [31][0/65] Elapsed 0m 1s (remain 1m 11s) Loss: 0.1251(0.1251)
# Epoch: [31][64/65] Elapsed 0m 25s (remain 0m 0s) Loss: 0.0951(0.1283)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0568(0.0568)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1162(0.1166)
# 	 epoch:31, avg train loss:0.1283, avg valid loss:0.1166
# 	 score:0.4915(th=0.300000), auc=0.868045::: time:1407.97s
# - epoch:32 -
# Epoch: [32][0/65] Elapsed 0m 1s (remain 1m 17s) Loss: 0.1331(0.1331)
# Epoch: [32][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2003(0.1300)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0494(0.0494)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1204(0.1137)
# 	 epoch:32, avg train loss:0.1300, avg valid loss:0.1137
# 	 score:0.4885(th=0.200000), auc=0.869643::: time:1448.61s
# - epoch:33 -
# Epoch: [33][0/65] Elapsed 0m 1s (remain 1m 11s) Loss: 0.1567(0.1567)
# Epoch: [33][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2429(0.1282)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0523(0.0523)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1183(0.1123)
# 	 epoch:33, avg train loss:0.1282, avg valid loss:0.1123
# 	 score:0.4876(th=0.200000), auc=0.876290::: time:1488.56s
# - epoch:34 -
# Epoch: [34][0/65] Elapsed 0m 1s (remain 1m 14s) Loss: 0.1437(0.1437)
# Epoch: [34][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.0951(0.1288)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0533(0.0533)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1144(0.1127)
# 	 epoch:34, avg train loss:0.1288, avg valid loss:0.1127
# 	 score:0.5044(th=0.250000), auc=0.875273::: time:1528.84s
# - epoch:35 -
# Epoch: [35][0/65] Elapsed 0m 1s (remain 1m 20s) Loss: 0.1233(0.1233)
# Epoch: [35][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2038(0.1291)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0572(0.0572)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1125(0.1112)
# 	 epoch:35, avg train loss:0.1291, avg valid loss:0.1112
# 	 score:0.5275(th=0.300000), auc=0.878102::: time:1568.78s
# - epoch:36 -
# Epoch: [36][0/65] Elapsed 0m 1s (remain 1m 22s) Loss: 0.1332(0.1332)
# Epoch: [36][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.0878(0.1224)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0472(0.0472)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1266(0.1146)
# 	 epoch:36, avg train loss:0.1224, avg valid loss:0.1146
# 	 score:0.4930(th=0.150000), auc=0.866454::: time:1609.24s
# - epoch:37 -
# Epoch: [37][0/65] Elapsed 0m 1s (remain 1m 22s) Loss: 0.1103(0.1103)
# Epoch: [37][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1063(0.1232)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0626(0.0626)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1127(0.1172)
# 	 epoch:37, avg train loss:0.1232, avg valid loss:0.1172
# 	 score:0.5025(th=0.300000), auc=0.872060::: time:1649.54s
# - epoch:38 -
# Epoch: [38][0/65] Elapsed 0m 1s (remain 1m 24s) Loss: 0.0980(0.0980)
# Epoch: [38][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.5378(0.1288)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0439(0.0439)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1311(0.1131)
# 	 epoch:38, avg train loss:0.1288, avg valid loss:0.1131
# 	 score:0.5227(th=0.150000), auc=0.877577::: time:1689.97s
# - epoch:39 -
# Epoch: [39][0/65] Elapsed 0m 1s (remain 1m 26s) Loss: 0.1004(0.1004)
# Epoch: [39][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1098(0.1175)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0465(0.0465)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1276(0.1125)
# 	 epoch:39, avg train loss:0.1175, avg valid loss:0.1125
# 	 score:0.5083(th=0.200000), auc=0.872199::: time:1730.28s
# - epoch:40 -
# Epoch: [40][0/65] Elapsed 0m 1s (remain 1m 18s) Loss: 0.1193(0.1193)
# Epoch: [40][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.4114(0.1259)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0498(0.0498)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1221(0.1125)
# 	 epoch:40, avg train loss:0.1259, avg valid loss:0.1125
# 	 score:0.5050(th=0.150000), auc=0.874629::: time:1771.06s
# - epoch:41 -
# Epoch: [41][0/65] Elapsed 0m 1s (remain 1m 13s) Loss: 0.1444(0.1444)
# Epoch: [41][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1102(0.1173)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0498(0.0498)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1231(0.1107)
# 	 epoch:41, avg train loss:0.1173, avg valid loss:0.1107
# 	 score:0.5131(th=0.200000), auc=0.876955::: time:1811.30s
# - epoch:42 -
# Epoch: [42][0/65] Elapsed 0m 1s (remain 1m 24s) Loss: 0.0996(0.0996)
# Epoch: [42][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.0768(0.1180)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0478(0.0478)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1359(0.1152)
# 	 epoch:42, avg train loss:0.1180, avg valid loss:0.1152
# 	 score:0.5100(th=0.150000), auc=0.869643::: time:1851.79s
# - epoch:43 -
# Epoch: [43][0/65] Elapsed 0m 1s (remain 1m 16s) Loss: 0.1456(0.1456)
# Epoch: [43][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1883(0.1183)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0466(0.0466)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1273(0.1122)
# 	 epoch:43, avg train loss:0.1183, avg valid loss:0.1122
# 	 score:0.5044(th=0.150000), auc=0.871868::: time:1891.96s
# - epoch:44 -
# Epoch: [44][0/65] Elapsed 0m 1s (remain 1m 17s) Loss: 0.0934(0.0934)
# Epoch: [44][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1179(0.1165)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0520(0.0520)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1196(0.1118)
# 	 epoch:44, avg train loss:0.1165, avg valid loss:0.1118
# 	 score:0.5026(th=0.200000), auc=0.876539::: time:1932.19s
# - epoch:45 -
# Epoch: [45][0/65] Elapsed 0m 1s (remain 1m 16s) Loss: 0.0942(0.0942)
# Epoch: [45][64/65] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1567(0.1174)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0464(0.0464)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1275(0.1142)
# 	 epoch:45, avg train loss:0.1174, avg valid loss:0.1142
# 	 score:0.5173(th=0.150000), auc=0.867235::: time:1972.12s
# [fold0] slice ave score:0.5377(th=0.200000), auc=0.877175
# [fold0] BEST Epoch 23 - Save Best Score:0.5543. Best loss:0.1078
# [fold0] BEST AUC Epoch 24 - Save Best Score:0.8858. Best loss:0.1073
# -- fold1 training start --
# surface_list:  [26, 29, 32, 35]
# - epoch:1 -
# Epoch: [1][0/60] Elapsed 0m 1s (remain 1m 13s) Loss: 0.5125(0.5125)
# Epoch: [1][59/60] Elapsed 0m 22s (remain 0m 0s) Loss: 0.3103(0.3851)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.3620(0.3620)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2469(0.3207)
# 	 epoch:1, avg train loss:0.3851, avg valid loss:0.3207
# 	 score:0.2381(th=0.250000), auc=0.633890::: time:81.14s
# Epoch 1 - Save Best Score: 0.2381. Model is saved.
# dice_list:  [0.2145188924955571, 0.2175905360354922, 0.22126407075235918, 0.23806575055398277, 0.23572108223923655, 0.22813991236195563, 0.21588345382298266, 0.1992923104450336, 0.1790368450210538, 0.15627419648073043, 0.132477526036057, 0.10888327145894562, 0.08696440688762191, 0.06721930190513298, 0.049702548556376014, 0.034288887240297855, 0.02080288368148349, 0.008837075624704163, 0.0]
# Epoch 1 - Save Best AUC: 0.6339. Model is saved.
# - epoch:2 -
# Epoch: [2][0/60] Elapsed 0m 1s (remain 1m 10s) Loss: 0.2844(0.2844)
# Epoch: [2][59/60] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2491(0.2649)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.3097(0.3097)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1518(0.2489)
# 	 epoch:2, avg train loss:0.2649, avg valid loss:0.2489
# 	 score:0.2958(th=0.250000), auc=0.691614::: time:130.84s
# Epoch 2 - Save Best Score: 0.2958. Model is saved.
# dice_list:  [0.23481800893544938, 0.27173468996524874, 0.2895890717033311, 0.2957886203940492, 0.2894139916755333, 0.2712479343628901, 0.24299254330016914, 0.2083417193982407, 0.17067444559986553, 0.13475393557513535, 0.10263243402570564, 0.07553331622634399, 0.053810401045050506, 0.03677488180487351, 0.02364492594906168, 0.01385392525653297, 0.00665528022782551, 0.001892306222429843, 0.0]
# Epoch 2 - Save Best AUC: 0.6916. Model is saved.
# - epoch:3 -
# Epoch: [3][0/60] Elapsed 0m 1s (remain 1m 4s) Loss: 0.2135(0.2135)
# Epoch: [3][59/60] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1785(0.2006)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2883(0.2883)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0861(0.1980)
# 	 epoch:3, avg train loss:0.2006, avg valid loss:0.1980
# 	 score:0.3210(th=0.150000), auc=0.700100::: time:180.46s
# Epoch 3 - Save Best Score: 0.3210. Model is saved.
# dice_list:  [0.2975262875608098, 0.32100947762205373, 0.29290663464534406, 0.23942907797791912, 0.18473730704965308, 0.13923065023444814, 0.10345747811928, 0.07610956052899294, 0.05518418523773086, 0.039450830044434504, 0.027245196195079865, 0.018127323604677024, 0.011423530362024157, 0.006897108552127706, 0.0038373734425844455, 0.0017939066869508682, 0.000621341710539955, 0.00010445953168599751, 0.0]
# Epoch 3 - Save Best AUC: 0.7001. Model is saved.
# - epoch:4 -
# Epoch: [4][0/60] Elapsed 0m 1s (remain 1m 12s) Loss: 0.1631(0.1631)
# Epoch: [4][59/60] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1336(0.1691)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2675(0.2675)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0583(0.2054)
# 	 epoch:4, avg train loss:0.1691, avg valid loss:0.2054
# 	 score:0.3432(th=0.250000), auc=0.749387::: time:229.24s
# Epoch 4 - Save Best Score: 0.3432. Model is saved.
# dice_list:  [0.29688476296298955, 0.3246466747212262, 0.3418702476282376, 0.343166375359033, 0.3235254281973687, 0.28088398806501563, 0.2209529522123134, 0.15606608377759917, 0.09940021674333901, 0.05774691670704901, 0.031097720478090906, 0.015847483182482622, 0.007766226774198664, 0.003680249038823868, 0.0016060343646235012, 0.0006024459858275173, 0.00018727175821121138, 1.7290557386144505e-05, 0.0]
# Epoch 4 - Save Best AUC: 0.7494. Model is saved.
# - epoch:5 -
# Epoch: [5][0/60] Elapsed 0m 1s (remain 1m 12s) Loss: 0.2100(0.2100)
# Epoch: [5][59/60] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1344(0.1587)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2627(0.2627)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0580(0.1846)
# 	 epoch:5, avg train loss:0.1587, avg valid loss:0.1846
# 	 score:0.4163(th=0.200000), auc=0.776879::: time:278.29s
# Epoch 5 - Save Best Score: 0.4163. Model is saved.
# dice_list:  [0.3648103969394244, 0.4113746926421271, 0.41625829492945643, 0.3949890880990642, 0.35712041484789137, 0.3083112564921426, 0.2540242526261424, 0.2007104797186529, 0.15291782213806873, 0.1128905948023409, 0.08102896752784491, 0.056340334098190455, 0.03769452240732948, 0.02370931516740324, 0.012576115263545462, 0.00425839686437223, 0.0005761259020999383, 2.593834372918503e-05, 0.0]
# Epoch 5 - Save Best AUC: 0.7769. Model is saved.
# - epoch:6 -
# Epoch: [6][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.1593(0.1593)
# Epoch: [6][59/60] Elapsed 0m 24s (remain 0m 0s) Loss: 0.0787(0.1514)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2557(0.2557)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0434(0.1757)
# 	 epoch:6, avg train loss:0.1514, avg valid loss:0.1757
# 	 score:0.4382(th=0.150000), auc=0.804758::: time:326.48s
# Epoch 6 - Save Best Score: 0.4382. Model is saved.
# dice_list:  [0.40118182427713706, 0.4382187966014099, 0.42174251243654226, 0.35675768846810996, 0.2632484718590965, 0.1685582923092453, 0.09524883680830581, 0.04903400547064215, 0.02391935200082161, 0.011330848099565747, 0.005237616457572183, 0.002420450897778319, 0.001066987026540704, 0.0004622745755653033, 0.00018727914076756383, 6.123685655271916e-05, 1.2247842243551647e-05, 0.0, 0.0]
# Epoch 6 - Save Best AUC: 0.8048. Model is saved.
# - epoch:7 -
# Epoch: [7][0/60] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2259(0.2259)
# Epoch: [7][59/60] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1778(0.1477)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2909(0.2909)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0394(0.1761)
# 	 epoch:7, avg train loss:0.1477, avg valid loss:0.1761
# 	 score:0.4586(th=0.100000), auc=0.803344::: time:374.16s
# Epoch 7 - Save Best Score: 0.4586. Model is saved.
# dice_list:  [0.4585703822624865, 0.44113797127564985, 0.3815872978730678, 0.3129709077834723, 0.2453962848259348, 0.18422115202695982, 0.1319544820292473, 0.08943294069272455, 0.05675090636780828, 0.033029233073041994, 0.017649817801429976, 0.008663325965327224, 0.003758546663456604, 0.0013846738054190334, 0.0004177611360856965, 0.00012247924801534588, 2.0174806981611905e-05, 7.204960130882585e-07, 0.0]
# - epoch:8 -
# Epoch: [8][0/60] Elapsed 0m 1s (remain 1m 10s) Loss: 0.0983(0.0983)
# Epoch: [8][59/60] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1196(0.1435)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2464(0.2464)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0361(0.1687)
# 	 epoch:8, avg train loss:0.1435, avg valid loss:0.1687
# 	 score:0.4988(th=0.150000), auc=0.821285::: time:419.49s
# Epoch 8 - Save Best Score: 0.4988. Model is saved.
# dice_list:  [0.47597435987016534, 0.4987507869663291, 0.4978892777912137, 0.4854599836188235, 0.46722204256270955, 0.4452691198368383, 0.41935253977088427, 0.389845950697041, 0.35581265456264943, 0.3174103660310999, 0.27537155979803496, 0.23147970619613045, 0.18791265428085951, 0.1467739669039301, 0.10916553210836208, 0.07394220377411687, 0.03965873263560255, 0.010919286123923577, 0.0]
# Epoch 8 - Save Best AUC: 0.8213. Model is saved.
# - epoch:9 -
# Epoch: [9][0/60] Elapsed 0m 1s (remain 1m 12s) Loss: 0.1345(0.1345)
# Epoch: [9][59/60] Elapsed 0m 23s (remain 0m 0s) Loss: 0.0673(0.1379)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2248(0.2248)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0364(0.1756)
# 	 epoch:9, avg train loss:0.1379, avg valid loss:0.1756
# 	 score:0.5129(th=0.300000), auc=0.833638::: time:466.70s
# Epoch 9 - Save Best Score: 0.5129. Model is saved.
# dice_list:  [0.41792041384443657, 0.4626370688874598, 0.4919640792829393, 0.5081526986526961, 0.5128549524469708, 0.5084575980730202, 0.4974201522571334, 0.48074837738316295, 0.45879493363605955, 0.4313794958945754, 0.3978244933152718, 0.3575445512962365, 0.3082945995021671, 0.24647266653500613, 0.17270103511851811, 0.0964252162172978, 0.03163003157709254, 0.0016154236789482131, 0.0]
# Epoch 9 - Save Best AUC: 0.8336. Model is saved.
# - epoch:10 -
# Epoch: [10][0/60] Elapsed 0m 1s (remain 1m 13s) Loss: 0.1300(0.1300)
# Epoch: [10][59/60] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1599(0.1372)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2317(0.2317)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0375(0.1658)
# 	 epoch:10, avg train loss:0.1372, avg valid loss:0.1658
# 	 score:0.5152(th=0.200000), auc=0.833450::: time:513.46s
# Epoch 10 - Save Best Score: 0.5152. Model is saved.
# dice_list:  [0.4536171078779395, 0.4961313559955976, 0.5151552416643267, 0.5119899249480906, 0.4851392834671792, 0.4358650862359219, 0.36777530210334264, 0.28523928630398193, 0.19739164235915804, 0.11652507541772501, 0.057787176842531256, 0.023684973186173356, 0.008700542187295303, 0.0029257636761668244, 0.0009451873349407098, 0.00024924192960715225, 4.106870492246452e-05, 1.4410488307860834e-06, 0.0]
# - epoch:11 -
# Epoch: [11][0/60] Elapsed 0m 1s (remain 1m 14s) Loss: 0.1587(0.1587)
# Epoch: [11][59/60] Elapsed 0m 23s (remain 0m 0s) Loss: 0.0874(0.1316)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2357(0.2357)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0307(0.1641)
# 	 epoch:11, avg train loss:0.1316, avg valid loss:0.1641
# 	 score:0.5390(th=0.150000), auc=0.838281::: time:558.84s
# Epoch 11 - Save Best Score: 0.5390. Model is saved.
# dice_list:  [0.5081225541179575, 0.5389796597491069, 0.5345556158264162, 0.5102332156690006, 0.4739128610781121, 0.4259113075223726, 0.36544689929850965, 0.2947209791762609, 0.21999544145405223, 0.14739351665796238, 0.08476710075714654, 0.0403382313783117, 0.015326477153798158, 0.004399963702196847, 0.0008863228681181438, 0.0001448126219157413, 8.64642992796098e-06, 0.0, 0.0]
# Epoch 11 - Save Best AUC: 0.8383. Model is saved.
# - epoch:12 -
# Epoch: [12][0/60] Elapsed 0m 1s (remain 1m 13s) Loss: 0.0760(0.0760)
# Epoch: [12][59/60] Elapsed 0m 22s (remain 0m 0s) Loss: 0.1731(0.1292)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2687(0.2687)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0355(0.1677)
# 	 epoch:12, avg train loss:0.1292, avg valid loss:0.1677
# 	 score:0.5189(th=0.150000), auc=0.834494::: time:605.41s
# - epoch:13 -
# Epoch: [13][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.1024(0.1024)
# Epoch: [13][59/60] Elapsed 0m 23s (remain 0m 0s) Loss: 0.2436(0.1243)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2345(0.2345)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0308(0.1619)
# 	 epoch:13, avg train loss:0.1243, avg valid loss:0.1619
# 	 score:0.5489(th=0.250000), auc=0.847146::: time:648.18s
# Epoch 13 - Save Best Score: 0.5489. Model is saved.
# dice_list:  [0.49498016722913535, 0.5313168504361844, 0.5458077477398346, 0.5489229505673682, 0.5418401341413436, 0.5257515888492487, 0.5013835031717452, 0.46980256254402664, 0.4308215778209202, 0.384505050111807, 0.33146911501604803, 0.2726231862976547, 0.20610135172043012, 0.13767448170663024, 0.07636283315306809, 0.030236613167888664, 0.005358740604826965, 5.259823496609065e-05, 0.0]
# Epoch 13 - Save Best AUC: 0.8471. Model is saved.
# - epoch:14 -
# Epoch: [14][0/60] Elapsed 0m 1s (remain 1m 7s) Loss: 0.2169(0.2169)
# Epoch: [14][59/60] Elapsed 0m 22s (remain 0m 0s) Loss: 0.1473(0.1245)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2588(0.2588)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0333(0.1665)
# 	 epoch:14, avg train loss:0.1245, avg valid loss:0.1665
# 	 score:0.5188(th=0.200000), auc=0.833987::: time:694.18s
# - epoch:15 -
# Epoch: [15][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.1234(0.1234)
# Epoch: [15][59/60] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1794(0.1214)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2814(0.2814)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0335(0.1720)
# 	 epoch:15, avg train loss:0.1214, avg valid loss:0.1720
# 	 score:0.5428(th=0.150000), auc=0.831480::: time:736.85s
# surface_list:  [27, 30, 33, 36]
# - epoch:16 -
# Epoch: [16][0/60] Elapsed 0m 1s (remain 1m 13s) Loss: 0.0749(0.0749)
# Epoch: [16][59/60] Elapsed 0m 22s (remain 0m 0s) Loss: 0.0957(0.1240)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2658(0.2658)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0340(0.1671)
# 	 epoch:16, avg train loss:0.1240, avg valid loss:0.1671
# 	 score:0.5444(th=0.200000), auc=0.833334::: time:812.98s
# - epoch:17 -
# Epoch: [17][0/60] Elapsed 0m 1s (remain 1m 15s) Loss: 0.1611(0.1611)
# Epoch: [17][59/60] Elapsed 0m 23s (remain 0m 0s) Loss: 0.0622(0.1207)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2613(0.2613)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0306(0.1659)
# 	 epoch:17, avg train loss:0.1207, avg valid loss:0.1659
# 	 score:0.5567(th=0.200000), auc=0.834047::: time:856.43s
# Epoch 17 - Save Best Score: 0.5567. Model is saved.
# dice_list:  [0.5240787029362833, 0.5542089718461982, 0.5567059269306391, 0.5433346179323026, 0.5201854763373543, 0.48988227398992096, 0.4499245927799407, 0.3989844245805239, 0.33776713742754527, 0.26959185097087507, 0.20000718454128535, 0.13248147955497505, 0.0747331236660761, 0.034698712550571935, 0.011976057096592704, 0.002363744490618401, 0.00016210064860324702, 3.6026714087954028e-06, 0.0]
# - epoch:18 -
# Epoch: [18][0/60] Elapsed 0m 1s (remain 1m 9s) Loss: 0.0784(0.0784)
# Epoch: [18][59/60] Elapsed 0m 22s (remain 0m 0s) Loss: 0.0780(0.1214)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2575(0.2575)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0329(0.1634)
# 	 epoch:18, avg train loss:0.1214, avg valid loss:0.1634
# 	 score:0.5553(th=0.200000), auc=0.838327::: time:900.95s
# - epoch:19 -
# Epoch: [19][0/60] Elapsed 0m 1s (remain 1m 12s) Loss: 0.0715(0.0715)
# Epoch: [19][59/60] Elapsed 0m 22s (remain 0m 0s) Loss: 0.1018(0.1230)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2395(0.2395)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0292(0.1637)
# 	 epoch:19, avg train loss:0.1230, avg valid loss:0.1637
# 	 score:0.5408(th=0.250000), auc=0.842272::: time:943.81s
# - epoch:20 -
# Epoch: [20][0/60] Elapsed 0m 1s (remain 1m 14s) Loss: 0.1678(0.1678)
# Epoch: [20][59/60] Elapsed 0m 22s (remain 0m 0s) Loss: 0.1979(0.1250)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2726(0.2726)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0341(0.1729)
# 	 epoch:20, avg train loss:0.1250, avg valid loss:0.1729
# 	 score:0.5291(th=0.150000), auc=0.830269::: time:986.46s
# - epoch:21 -
# Epoch: [21][0/60] Elapsed 0m 1s (remain 1m 15s) Loss: 0.0960(0.0960)
# Epoch: [21][59/60] Elapsed 0m 22s (remain 0m 0s) Loss: 0.1137(0.1238)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2316(0.2316)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0310(0.1627)
# 	 epoch:21, avg train loss:0.1238, avg valid loss:0.1627
# 	 score:0.5366(th=0.200000), auc=0.845941::: time:1029.04s
# - epoch:22 -
# Epoch: [22][0/60] Elapsed 0m 1s (remain 1m 5s) Loss: 0.1431(0.1431)
# Epoch: [22][59/60] Elapsed 0m 22s (remain 0m 0s) Loss: 0.1088(0.1180)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2724(0.2724)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0376(0.1727)
# 	 epoch:22, avg train loss:0.1180, avg valid loss:0.1727
# 	 score:0.5315(th=0.200000), auc=0.827975::: time:1071.37s
# - epoch:23 -
# Epoch: [23][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.0700(0.0700)
# Epoch: [23][59/60] Elapsed 0m 23s (remain 0m 0s) Loss: 0.0891(0.1209)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2667(0.2667)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0295(0.1743)
# 	 epoch:23, avg train loss:0.1209, avg valid loss:0.1743
# 	 score:0.4972(th=0.200000), auc=0.825190::: time:1113.95s
# - epoch:24 -
# Epoch: [24][0/60] Elapsed 0m 1s (remain 1m 14s) Loss: 0.1217(0.1217)
# Epoch: [24][59/60] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1055(0.1182)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2580(0.2580)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0324(0.1678)
# 	 epoch:24, avg train loss:0.1182, avg valid loss:0.1678
# 	 score:0.5383(th=0.200000), auc=0.833690::: time:1156.79s
# - epoch:25 -
# Epoch: [25][0/60] Elapsed 0m 1s (remain 1m 11s) Loss: 0.1208(0.1208)
# Epoch: [25][59/60] Elapsed 0m 23s (remain 0m 0s) Loss: 0.0770(0.1122)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2393(0.2393)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0321(0.1608)
# 	 epoch:25, avg train loss:0.1122, avg valid loss:0.1608
# 	 score:0.5565(th=0.250000), auc=0.853318::: time:1199.53s
# Epoch 25 - Save Best AUC: 0.8533. Model is saved.
# - epoch:26 -
# Epoch: [26][0/60] Elapsed 0m 1s (remain 1m 16s) Loss: 0.1007(0.1007)
# Epoch: [26][59/60] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1796(0.1130)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2533(0.2533)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0363(0.1690)
# 	 epoch:26, avg train loss:0.1130, avg valid loss:0.1690
# 	 score:0.5297(th=0.200000), auc=0.833277::: time:1244.33s
# - epoch:27 -
# Epoch: [27][0/60] Elapsed 0m 1s (remain 1m 9s) Loss: 0.1573(0.1573)
# Epoch: [27][59/60] Elapsed 0m 22s (remain 0m 0s) Loss: 0.0840(0.1112)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2434(0.2434)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0285(0.1614)
# 	 epoch:27, avg train loss:0.1112, avg valid loss:0.1614
# 	 score:0.5469(th=0.250000), auc=0.851192::: time:1287.08s
# - epoch:28 -
# Epoch: [28][0/60] Elapsed 0m 1s (remain 1m 10s) Loss: 0.0855(0.0855)
# Epoch: [28][59/60] Elapsed 0m 22s (remain 0m 0s) Loss: 0.0539(0.1111)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2532(0.2532)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0310(0.1610)
# 	 epoch:28, avg train loss:0.1111, avg valid loss:0.1610
# 	 score:0.5442(th=0.200000), auc=0.848208::: time:1329.97s
# - epoch:29 -
# Epoch: [29][0/60] Elapsed 0m 1s (remain 1m 16s) Loss: 0.0670(0.0670)
# Epoch: [29][59/60] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1490(0.1089)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2736(0.2736)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0302(0.1646)
# 	 epoch:29, avg train loss:0.1089, avg valid loss:0.1646
# 	 score:0.5481(th=0.200000), auc=0.844303::: time:1372.60s
# - epoch:30 -
# Epoch: [30][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.1121(0.1121)
# Epoch: [30][59/60] Elapsed 0m 23s (remain 0m 0s) Loss: 0.0816(0.1054)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2732(0.2732)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0295(0.1645)
# 	 epoch:30, avg train loss:0.1054, avg valid loss:0.1645
# 	 score:0.5545(th=0.150000), auc=0.847118::: time:1415.11s
# surface_list:  [25, 28, 31, 34]
# - epoch:31 -
# Epoch: [31][0/60] Elapsed 0m 1s (remain 1m 21s) Loss: 0.1545(0.1545)
# Epoch: [31][59/60] Elapsed 0m 22s (remain 0m 0s) Loss: 0.1192(0.1169)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2431(0.2431)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0278(0.1654)
# 	 epoch:31, avg train loss:0.1169, avg valid loss:0.1654
# 	 score:0.5358(th=0.200000), auc=0.844865::: time:1500.35s
# - epoch:32 -
# Epoch: [32][0/60] Elapsed 0m 1s (remain 1m 11s) Loss: 0.1420(0.1420)
# Epoch: [32][59/60] Elapsed 0m 22s (remain 0m 0s) Loss: 0.0875(0.1197)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2383(0.2383)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0273(0.1655)
# 	 epoch:32, avg train loss:0.1197, avg valid loss:0.1655
# 	 score:0.5329(th=0.200000), auc=0.843227::: time:1542.86s
# - epoch:33 -
# Epoch: [33][0/60] Elapsed 0m 1s (remain 1m 15s) Loss: 0.0813(0.0813)
# Epoch: [33][59/60] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1211(0.1179)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2478(0.2478)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0268(0.1677)
# 	 epoch:33, avg train loss:0.1179, avg valid loss:0.1677
# 	 score:0.5293(th=0.200000), auc=0.838219::: time:1586.07s
# - epoch:34 -
# Epoch: [34][0/60] Elapsed 0m 1s (remain 1m 14s) Loss: 0.1670(0.1670)
# Epoch: [34][59/60] Elapsed 0m 22s (remain 0m 0s) Loss: 0.0856(0.1178)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2387(0.2387)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0265(0.1694)
# 	 epoch:34, avg train loss:0.1178, avg valid loss:0.1694
# 	 score:0.5223(th=0.250000), auc=0.838077::: time:1628.80s
# - epoch:35 -
# Epoch: [35][0/60] Elapsed 0m 1s (remain 1m 13s) Loss: 0.1950(0.1950)
# Epoch: [35][59/60] Elapsed 0m 22s (remain 0m 0s) Loss: 0.1741(0.1157)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2170(0.2170)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0228(0.1644)
# 	 epoch:35, avg train loss:0.1157, avg valid loss:0.1644
# 	 score:0.5445(th=0.250000), auc=0.845278::: time:1671.33s
# - epoch:36 -
# Epoch: [36][0/60] Elapsed 0m 1s (remain 1m 21s) Loss: 0.1074(0.1074)
# Epoch: [36][59/60] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1237(0.1130)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2173(0.2173)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0265(0.1697)
# 	 epoch:36, avg train loss:0.1130, avg valid loss:0.1697
# 	 score:0.5232(th=0.300000), auc=0.834172::: time:1714.00s
# - epoch:37 -
# Epoch: [37][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.0916(0.0916)
# Epoch: [37][59/60] Elapsed 0m 22s (remain 0m 0s) Loss: 0.1993(0.1083)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2375(0.2375)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0247(0.1685)
# 	 epoch:37, avg train loss:0.1083, avg valid loss:0.1685
# 	 score:0.5121(th=0.200000), auc=0.841479::: time:1756.52s
# - epoch:38 -
# Epoch: [38][0/60] Elapsed 0m 1s (remain 1m 10s) Loss: 0.1422(0.1422)
# Epoch: [38][59/60] Elapsed 0m 22s (remain 0m 0s) Loss: 0.2528(0.1130)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2538(0.2538)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0222(0.1716)
# 	 epoch:38, avg train loss:0.1130, avg valid loss:0.1716
# 	 score:0.5194(th=0.150000), auc=0.835229::: time:1799.00s
# - epoch:39 -
# Epoch: [39][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.1065(0.1065)
# Epoch: [39][59/60] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1390(0.1121)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2431(0.2431)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0248(0.1689)
# 	 epoch:39, avg train loss:0.1121, avg valid loss:0.1689
# 	 score:0.5048(th=0.200000), auc=0.833463::: time:1842.00s
# - epoch:40 -
# Epoch: [40][0/60] Elapsed 0m 1s (remain 1m 12s) Loss: 0.1438(0.1438)
# Epoch: [40][59/60] Elapsed 0m 22s (remain 0m 0s) Loss: 0.0982(0.1079)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2426(0.2426)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0239(0.1710)
# 	 epoch:40, avg train loss:0.1079, avg valid loss:0.1710
# 	 score:0.5219(th=0.200000), auc=0.835420::: time:1884.60s
# - epoch:41 -
# Epoch: [41][0/60] Elapsed 0m 1s (remain 1m 16s) Loss: 0.0722(0.0722)
# Epoch: [41][59/60] Elapsed 0m 23s (remain 0m 0s) Loss: 0.0815(0.1037)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2407(0.2407)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0258(0.1704)
# 	 epoch:41, avg train loss:0.1037, avg valid loss:0.1704
# 	 score:0.5192(th=0.200000), auc=0.833863::: time:1927.54s
# - epoch:42 -
# Epoch: [42][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.1678(0.1678)
# Epoch: [42][59/60] Elapsed 0m 22s (remain 0m 0s) Loss: 0.1072(0.1088)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2428(0.2428)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0208(0.1696)
# 	 epoch:42, avg train loss:0.1088, avg valid loss:0.1696
# 	 score:0.5355(th=0.200000), auc=0.836914::: time:1970.27s
# - epoch:43 -
# Epoch: [43][0/60] Elapsed 0m 1s (remain 1m 14s) Loss: 0.0867(0.0867)
# Epoch: [43][59/60] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1528(0.1079)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2300(0.2300)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0223(0.1674)
# 	 epoch:43, avg train loss:0.1079, avg valid loss:0.1674
# 	 score:0.5298(th=0.200000), auc=0.841691::: time:2013.28s
# - epoch:44 -
# Epoch: [44][0/60] Elapsed 0m 1s (remain 1m 21s) Loss: 0.0635(0.0635)
# Epoch: [44][59/60] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1136(0.1051)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2432(0.2432)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0210(0.1681)
# 	 epoch:44, avg train loss:0.1051, avg valid loss:0.1681
# 	 score:0.5391(th=0.200000), auc=0.841708::: time:2055.96s
# - epoch:45 -
# Epoch: [45][0/60] Elapsed 0m 1s (remain 1m 13s) Loss: 0.1156(0.1156)
# Epoch: [45][59/60] Elapsed 0m 22s (remain 0m 0s) Loss: 0.1380(0.1048)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.2484(0.2484)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0226(0.1709)
# 	 epoch:45, avg train loss:0.1048, avg valid loss:0.1709
# 	 score:0.5275(th=0.150000), auc=0.834955::: time:2098.43s
# [fold1] slice ave score:0.5595(th=0.150000), auc=0.846385
# [fold1] BEST Epoch 17 - Save Best Score:0.5567. Best loss:0.1659
# [fold1] BEST AUC Epoch 25 - Save Best Score:0.8533. Best loss:0.1608
# -- fold2 training start --
# surface_list:  [26, 29, 32, 35]
# - epoch:1 -
# Epoch: [1][0/60] Elapsed 0m 1s (remain 1m 12s) Loss: 1.2820(1.2820)
# ...
# Epoch 12 - Save Best Score: 0.4564. Model is saved.
# dice_list:  [0.35757928045286314, 0.417290014788809, 0.4544303035450738, 0.4563598172524194, 0.41442110795242953, 0.3326639511353697, 0.23387833613404976, 0.14308376687058358, 0.07598331147766411, 0.0340617228686275, 0.012062422442806708, 0.003340377088346949, 0.0008427655947125398, 0.00020659779900422995, 4.414499723832068e-05, 1.2210694465610965e-05, 4.696575034360739e-06, 0.0, 0.0]
# Epoch 12 - Save Best AUC: 0.8811. Model is saved.
# - epoch:13 -
# Epoch: [13][0/62] Elapsed 0m 1s (remain 1m 18s) Loss: 0.1180(0.1180)
# Epoch: [13][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1557(0.1327)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0376(0.0376)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1268(0.1523)
# 	 epoch:13, avg train loss:0.1327, avg valid loss:0.1523
# 	 score:0.4564(th=0.150000), auc=0.878878::: time:664.99s
# Epoch 13 - Save Best Score: 0.4564. Model is saved.
# dice_list:  [0.4172526184000029, 0.4563799195411197, 0.44845360077261276, 0.40286961047861747, 0.33316516516860434, 0.25623113339762416, 0.18531332004197748, 0.12660844923150477, 0.07918912357702458, 0.04406128248978483, 0.020671125567028242, 0.0074641142920358625, 0.0017833104221012183, 0.0002497810958124355, 3.381209655124279e-05, 4.696328446066304e-06, 9.39317829980648e-07, 0.0, 0.0]
# - epoch:14 -
# Epoch: [14][0/62] Elapsed 0m 1s (remain 1m 17s) Loss: 0.1370(0.1370)
# Epoch: [14][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.0950(0.1252)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0478(0.0478)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1285(0.1562)
# 	 epoch:14, avg train loss:0.1252, avg valid loss:0.1562
# 	 score:0.4864(th=0.250000), auc=0.880257::: time:710.73s
# Epoch 14 - Save Best Score: 0.4864. Model is saved.
# dice_list:  [0.3792523525439566, 0.4373205143322315, 0.47276668317933646, 0.4863557571805148, 0.47781572866882616, 0.44883371100420716, 0.4019280864697717, 0.34023679969458054, 0.270005542746591, 0.1995546310071619, 0.13741842280974204, 0.08837776954809583, 0.05265082979796247, 0.02625204359991911, 0.008703325093633573, 0.0010623213403858664, 2.254258420462897e-05, 0.0, 0.0]
# - epoch:15 -
# Epoch: [15][0/62] Elapsed 0m 1s (remain 1m 18s) Loss: 0.1279(0.1279)
# Epoch: [15][61/62] Elapsed 0m 24s (remain 0m 0s) Loss: 0.0966(0.1214)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0428(0.0428)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1175(0.1544)
# 	 epoch:15, avg train loss:0.1214, avg valid loss:0.1544
# 	 score:0.4554(th=0.200000), auc=0.875710::: time:756.27s
# surface_list:  [27, 30, 33, 36]
# - epoch:16 -
# Epoch: [16][0/62] Elapsed 0m 1s (remain 1m 16s) Loss: 0.1284(0.1284)
# Epoch: [16][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1171(0.1295)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0403(0.0403)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1342(0.1555)
# 	 epoch:16, avg train loss:0.1295, avg valid loss:0.1555
# 	 score:0.4671(th=0.200000), auc=0.880214::: time:843.29s
# - epoch:17 -
# Epoch: [17][0/62] Elapsed 0m 1s (remain 1m 15s) Loss: 0.1389(0.1389)
# Epoch: [17][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1246(0.1289)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0479(0.0479)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1336(0.1578)
# 	 epoch:17, avg train loss:0.1289, avg valid loss:0.1578
# 	 score:0.4693(th=0.250000), auc=0.882704::: time:886.16s
# Epoch 17 - Save Best AUC: 0.8827. Model is saved.
# - epoch:18 -
# Epoch: [18][0/62] Elapsed 0m 1s (remain 1m 17s) Loss: 0.1548(0.1548)
# Epoch: [18][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1506(0.1288)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0487(0.0487)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1415(0.1599)
# 	 epoch:18, avg train loss:0.1288, avg valid loss:0.1599
# 	 score:0.4664(th=0.250000), auc=0.884164::: time:930.88s
# Epoch 18 - Save Best AUC: 0.8842. Model is saved.
# - epoch:19 -
# Epoch: [19][0/62] Elapsed 0m 1s (remain 1m 19s) Loss: 0.0891(0.0891)
# Epoch: [19][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1776(0.1298)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0393(0.0393)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1368(0.1620)
# 	 epoch:19, avg train loss:0.1298, avg valid loss:0.1620
# 	 score:0.4559(th=0.250000), auc=0.881651::: time:975.62s
# - epoch:20 -
# Epoch: [20][0/62] Elapsed 0m 1s (remain 1m 15s) Loss: 0.0774(0.0774)
# Epoch: [20][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.0930(0.1225)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0422(0.0422)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1378(0.1555)
# 	 epoch:20, avg train loss:0.1225, avg valid loss:0.1555
# 	 score:0.4869(th=0.250000), auc=0.883069::: time:1018.67s
# Epoch 20 - Save Best Score: 0.4869. Model is saved.
# dice_list:  [0.3971689048318798, 0.4475762188572886, 0.47921706335837533, 0.48691521885082184, 0.4734836998487407, 0.4446180163964068, 0.4058157925751069, 0.35668565040875205, 0.2976063552274113, 0.23137878690140523, 0.16541973689613942, 0.10869489683613615, 0.06339726025382714, 0.030511680541672807, 0.010200880610096642, 0.001579531969635989, 7.044320054056781e-05, 1.8786342486292909e-06, 0.0]
# - epoch:21 -
# Epoch: [21][0/62] Elapsed 0m 1s (remain 1m 10s) Loss: 0.1264(0.1264)
# Epoch: [21][61/62] Elapsed 0m 24s (remain 0m 0s) Loss: 0.0920(0.1264)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0334(0.0334)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1375(0.1560)
# 	 epoch:21, avg train loss:0.1264, avg valid loss:0.1560
# 	 score:0.4499(th=0.150000), auc=0.870397::: time:1064.11s
# - epoch:22 -
# Epoch: [22][0/62] Elapsed 0m 1s (remain 1m 17s) Loss: 0.0836(0.0836)
# Epoch: [22][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1141(0.1249)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0467(0.0467)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1466(0.1735)
# 	 epoch:22, avg train loss:0.1249, avg valid loss:0.1735
# 	 score:0.4396(th=0.350000), auc=0.875025::: time:1107.43s
# - epoch:23 -
# Epoch: [23][0/62] Elapsed 0m 1s (remain 1m 17s) Loss: 0.0789(0.0789)
# Epoch: [23][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1929(0.1209)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0420(0.0420)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1396(0.1623)
# 	 epoch:23, avg train loss:0.1209, avg valid loss:0.1623
# 	 score:0.4409(th=0.300000), auc=0.878543::: time:1150.44s
# - epoch:24 -
# Epoch: [24][0/62] Elapsed 0m 1s (remain 1m 11s) Loss: 0.1206(0.1206)
# Epoch: [24][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1657(0.1189)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0455(0.0455)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1255(0.1543)
# 	 epoch:24, avg train loss:0.1189, avg valid loss:0.1543
# 	 score:0.4682(th=0.250000), auc=0.882544::: time:1193.46s
# - epoch:25 -
# Epoch: [25][0/62] Elapsed 0m 1s (remain 1m 25s) Loss: 0.1071(0.1071)
# Epoch: [25][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1066(0.1150)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0330(0.0330)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1166(0.1503)
# 	 epoch:25, avg train loss:0.1150, avg valid loss:0.1503
# 	 score:0.4805(th=0.200000), auc=0.887345::: time:1236.25s
# Epoch 25 - Save Best AUC: 0.8873. Model is saved.
# - epoch:26 -
# Epoch: [26][0/62] Elapsed 0m 1s (remain 1m 14s) Loss: 0.1327(0.1327)
# Epoch: [26][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.0944(0.1181)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0358(0.0358)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1207(0.1578)
# 	 epoch:26, avg train loss:0.1181, avg valid loss:0.1578
# 	 score:0.4659(th=0.250000), auc=0.885026::: time:1280.93s
# - epoch:27 -
# Epoch: [27][0/62] Elapsed 0m 1s (remain 1m 21s) Loss: 0.1050(0.1050)
# Epoch: [27][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1111(0.1133)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0313(0.0313)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1153(0.1531)
# 	 epoch:27, avg train loss:0.1133, avg valid loss:0.1531
# 	 score:0.4768(th=0.250000), auc=0.884494::: time:1323.78s
# - epoch:28 -
# Epoch: [28][0/62] Elapsed 0m 1s (remain 1m 9s) Loss: 0.1266(0.1266)
# Epoch: [28][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1690(0.1160)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0346(0.0346)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1280(0.1534)
# 	 epoch:28, avg train loss:0.1160, avg valid loss:0.1534
# 	 score:0.4688(th=0.200000), auc=0.878207::: time:1366.74s
# - epoch:29 -
# Epoch: [29][0/62] Elapsed 0m 1s (remain 1m 11s) Loss: 0.0667(0.0667)
# Epoch: [29][61/62] Elapsed 0m 24s (remain 0m 0s) Loss: 0.0911(0.1117)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0423(0.0423)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1300(0.1574)
# 	 epoch:29, avg train loss:0.1117, avg valid loss:0.1574
# 	 score:0.4711(th=0.250000), auc=0.881208::: time:1410.23s
# - epoch:30 -
# Epoch: [30][0/62] Elapsed 0m 1s (remain 1m 16s) Loss: 0.1056(0.1056)
# Epoch: [30][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1684(0.1135)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0393(0.0393)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1246(0.1570)
# 	 epoch:30, avg train loss:0.1135, avg valid loss:0.1570
# 	 score:0.4714(th=0.250000), auc=0.881478::: time:1453.67s
# surface_list:  [25, 28, 31, 34]
# - epoch:31 -
# Epoch: [31][0/62] Elapsed 0m 1s (remain 1m 19s) Loss: 0.1315(0.1315)
# Epoch: [31][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1271(0.1238)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0607(0.0607)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1270(0.1707)
# 	 epoch:31, avg train loss:0.1238, avg valid loss:0.1707
# 	 score:0.4313(th=0.300000), auc=0.875026::: time:1535.44s
# - epoch:32 -
# Epoch: [32][0/62] Elapsed 0m 1s (remain 1m 13s) Loss: 0.1691(0.1691)
# Epoch: [32][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1484(0.1236)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0533(0.0533)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1215(0.1646)
# 	 epoch:32, avg train loss:0.1236, avg valid loss:0.1646
# 	 score:0.4341(th=0.250000), auc=0.873122::: time:1578.26s
# - epoch:33 -
# Epoch: [33][0/62] Elapsed 0m 1s (remain 1m 17s) Loss: 0.1155(0.1155)
# Epoch: [33][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1424(0.1202)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0511(0.0511)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1227(0.1665)
# 	 epoch:33, avg train loss:0.1202, avg valid loss:0.1665
# 	 score:0.4199(th=0.250000), auc=0.872366::: time:1621.08s
# - epoch:34 -
# Epoch: [34][0/62] Elapsed 0m 1s (remain 1m 14s) Loss: 0.1097(0.1097)
# Epoch: [34][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1181(0.1164)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0545(0.0545)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1255(0.1657)
# 	 epoch:34, avg train loss:0.1164, avg valid loss:0.1657
# 	 score:0.4322(th=0.250000), auc=0.875061::: time:1663.90s
# - epoch:35 -
# Epoch: [35][0/62] Elapsed 0m 1s (remain 1m 17s) Loss: 0.1065(0.1065)
# Epoch: [35][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1432(0.1159)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0452(0.0452)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1324(0.1621)
# 	 epoch:35, avg train loss:0.1159, avg valid loss:0.1621
# 	 score:0.4178(th=0.200000), auc=0.867128::: time:1707.15s
# - epoch:36 -
# Epoch: [36][0/62] Elapsed 0m 1s (remain 1m 19s) Loss: 0.1114(0.1114)
# Epoch: [36][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1669(0.1170)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0579(0.0579)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1276(0.1679)
# 	 epoch:36, avg train loss:0.1170, avg valid loss:0.1679
# 	 score:0.4170(th=0.250000), auc=0.872343::: time:1750.30s
# - epoch:37 -
# Epoch: [37][0/62] Elapsed 0m 1s (remain 1m 19s) Loss: 0.1305(0.1305)
# Epoch: [37][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.0720(0.1120)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0384(0.0384)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1262(0.1648)
# 	 epoch:37, avg train loss:0.1120, avg valid loss:0.1648
# 	 score:0.4559(th=0.300000), auc=0.875962::: time:1793.71s
# - epoch:38 -
# Epoch: [38][0/62] Elapsed 0m 1s (remain 1m 15s) Loss: 0.1616(0.1616)
# Epoch: [38][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.0914(0.1102)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0438(0.0438)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1246(0.1679)
# 	 epoch:38, avg train loss:0.1102, avg valid loss:0.1679
# 	 score:0.4365(th=0.250000), auc=0.871068::: time:1836.97s
# - epoch:39 -
# Epoch: [39][0/62] Elapsed 0m 1s (remain 1m 12s) Loss: 0.1421(0.1421)
# Epoch: [39][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1203(0.1120)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0421(0.0421)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1188(0.1602)
# 	 epoch:39, avg train loss:0.1120, avg valid loss:0.1602
# 	 score:0.4497(th=0.250000), auc=0.873189::: time:1880.66s
# - epoch:40 -
# Epoch: [40][0/62] Elapsed 0m 1s (remain 1m 23s) Loss: 0.0960(0.0960)
# Epoch: [40][61/62] Elapsed 0m 24s (remain 0m 0s) Loss: 0.0768(0.1118)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0399(0.0399)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1113(0.1650)
# 	 epoch:40, avg train loss:0.1118, avg valid loss:0.1650
# 	 score:0.4428(th=0.300000), auc=0.874656::: time:1924.06s
# - epoch:41 -
# Epoch: [41][0/62] Elapsed 0m 1s (remain 1m 15s) Loss: 0.0985(0.0985)
# Epoch: [41][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1557(0.1141)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0463(0.0463)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1221(0.1644)
# 	 epoch:41, avg train loss:0.1141, avg valid loss:0.1644
# 	 score:0.4270(th=0.250000), auc=0.872277::: time:1966.96s
# - epoch:42 -
# Epoch: [42][0/62] Elapsed 0m 1s (remain 1m 8s) Loss: 0.0719(0.0719)
# Epoch: [42][61/62] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2479(0.1084)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0462(0.0462)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1167(0.1623)
# 	 epoch:42, avg train loss:0.1084, avg valid loss:0.1623
# 	 score:0.4397(th=0.300000), auc=0.875406::: time:2010.54s
# - epoch:43 -
# Epoch: [43][0/62] Elapsed 0m 1s (remain 1m 10s) Loss: 0.0781(0.0781)
# Epoch: [43][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1148(0.1119)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0441(0.0441)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1208(0.1652)
# 	 epoch:43, avg train loss:0.1119, avg valid loss:0.1652
# 	 score:0.4330(th=0.300000), auc=0.873050::: time:2053.66s
# - epoch:44 -
# Epoch: [44][0/62] Elapsed 0m 1s (remain 1m 13s) Loss: 0.0882(0.0882)
# Epoch: [44][61/62] Elapsed 0m 23s (remain 0m 0s) Loss: 0.1178(0.1095)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0401(0.0401)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1232(0.1625)
# 	 epoch:44, avg train loss:0.1095, avg valid loss:0.1625
# 	 score:0.4447(th=0.250000), auc=0.873339::: time:2097.18s
# - epoch:45 -
# Epoch: [45][0/62] Elapsed 0m 1s (remain 1m 18s) Loss: 0.0994(0.0994)
# Epoch: [45][61/62] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1873(0.1107)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0427(0.0427)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.1197(0.1626)
# 	 epoch:45, avg train loss:0.1107, avg valid loss:0.1626
# 	 score:0.4301(th=0.250000), auc=0.871585::: time:2140.92s
# [fold4] slice ave score:0.4722(th=0.250000), auc=0.882748
# [fold4] BEST Epoch 20 - Save Best Score:0.4869. Best loss:0.1555
# [fold4] BEST AUC Epoch 25 - Save Best Score:0.8873. Best loss:0.1503
# fold[0] BEST SCORE = 0.5543 thr=0.25 (epoch=23)
# fold[0] slice ave score:0.5377(th=0.200000), auc=0.877175
# fold[1] BEST SCORE = 0.5567 thr=0.2 (epoch=17)
# fold[1] slice ave score:0.5595(th=0.150000), auc=0.846385
# fold[2] BEST SCORE = 0.5426 thr=0.25 (epoch=35)
# fold[2] slice ave score:0.5298(th=0.200000), auc=0.846734
# fold[3] BEST SCORE = 0.5348 thr=0.2 (epoch=25)
# fold[3] slice ave score:0.5107(th=0.200000), auc=0.922574
# fold[4] BEST SCORE = 0.4869 thr=0.25 (epoch=20)
# fold[4] slice ave score:0.4722(th=0.250000), auc=0.882748
# CPU times: user 2h 3min 4s, sys: 43min 31s, total: 2h 46min 35s
# Wall time: 2h 53min 51s

# %% [markdown]
# ---
# # OOF SCORE INFER

# %%
# %%time
slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list = slide_inference(CFG)
for fold in CFG["folds"]:
    print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    wandb.log({"OOF SCORE" : {f"slice average score":slice_ave_score_list[fold],
                            f"slice average threshold":slice_ave_score_threshold_list[fold],
                            f"slice_average auc":slice_ave_auc_list[fold],
                            "fold":fold,
                            }})
# Out:
# -- fold0 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.5334(th=0.250000), auc=0.880321::: time:26.96s
# slide pos: [256, 0]
# 	 score:0.5275(th=0.200000), auc=0.884700::: time:43.67s
# slide pos: [0, 256]
# 	 score:0.5267(th=0.200000), auc=0.892366::: time:59.89s
# slide pos: [256, 256]
# 	 score:0.5198(th=0.200000), auc=0.890362::: time:75.98s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.5422(th=0.200000), auc=0.885821::: time:100.52s
# slide pos: [256, 0]
# 	 score:0.5399(th=0.200000), auc=0.885431::: time:117.32s
# slide pos: [0, 256]
# 	 score:0.5157(th=0.200000), auc=0.895482::: time:133.32s
# slide pos: [256, 256]
# 	 score:0.5174(th=0.200000), auc=0.893566::: time:149.53s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.5206(th=0.250000), auc=0.880013::: time:174.07s
# slide pos: [256, 0]
# 	 score:0.5080(th=0.200000), auc=0.882229::: time:190.59s
# slide pos: [0, 256]
# 	 score:0.5187(th=0.250000), auc=0.886027::: time:206.73s
# slide pos: [256, 256]
# 	 score:0.4975(th=0.250000), auc=0.882807::: time:222.83s
# [fold0] slice ave score:0.5715(th=0.200000), auc=0.898090
# -- fold1 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.5580(th=0.250000), auc=0.851534::: time:265.19s
# slide pos: [256, 0]
# 	 score:0.5256(th=0.300000), auc=0.857647::: time:286.36s
# slide pos: [0, 256]
# 	 score:0.5624(th=0.250000), auc=0.852548::: time:307.22s
# slide pos: [256, 256]
# 	 score:0.5339(th=0.250000), auc=0.857051::: time:328.02s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.5565(th=0.250000), auc=0.853318::: time:353.16s
# slide pos: [256, 0]
# 	 score:0.5266(th=0.300000), auc=0.856094::: time:374.80s
# slide pos: [0, 256]
# 	 score:0.5635(th=0.250000), auc=0.850415::: time:395.97s
# slide pos: [256, 256]
# 	 score:0.5172(th=0.300000), auc=0.851548::: time:416.96s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.5371(th=0.250000), auc=0.846010::: time:443.32s
# slide pos: [256, 0]
# 	 score:0.5057(th=0.300000), auc=0.858141::: time:464.74s
# slide pos: [0, 256]
# 	 score:0.5384(th=0.250000), auc=0.846730::: time:486.09s
# slide pos: [256, 256]
# 	 score:0.5258(th=0.250000), auc=0.857580::: time:507.19s
# [fold1] slice ave score:0.5525(th=0.300000), auc=0.859840
# -- fold2 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.5171(th=0.250000), auc=0.843276::: time:551.28s
# slide pos: [256, 0]
# 	 score:0.4906(th=0.250000), auc=0.835620::: time:572.27s
# slide pos: [0, 256]
# 	 score:0.5256(th=0.300000), auc=0.839480::: time:593.22s
# slide pos: [256, 256]
# 	 score:0.5006(th=0.250000), auc=0.833615::: time:614.24s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.5233(th=0.300000), auc=0.848055::: time:640.56s
# slide pos: [256, 0]
# 	 score:0.5033(th=0.300000), auc=0.840388::: time:661.80s
# slide pos: [0, 256]
# 	 score:0.5331(th=0.300000), auc=0.843436::: time:682.86s
# slide pos: [256, 256]
# 	 score:0.5144(th=0.300000), auc=0.838862::: time:704.23s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.5113(th=0.250000), auc=0.831852::: time:730.89s
# slide pos: [256, 0]
# 	 score:0.4748(th=0.250000), auc=0.825560::: time:751.96s
# slide pos: [0, 256]
# 	 score:0.5107(th=0.250000), auc=0.831286::: time:773.18s
# slide pos: [256, 256]
# 	 score:0.5010(th=0.250000), auc=0.824050::: time:794.83s
# [fold2] slice ave score:0.5215(th=0.250000), auc=0.839192
# -- fold3 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.4907(th=0.200000), auc=0.918501::: time:833.22s
# slide pos: [256, 0]
# 	 score:0.4721(th=0.250000), auc=0.908889::: time:849.88s
# slide pos: [0, 256]
# 	 score:0.4959(th=0.250000), auc=0.914106::: time:866.83s
# slide pos: [256, 256]
# 	 score:0.4641(th=0.200000), auc=0.908785::: time:884.14s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.5342(th=0.200000), auc=0.923916::: time:903.80s
# slide pos: [256, 0]
# 	 score:0.4985(th=0.250000), auc=0.914426::: time:920.40s
# slide pos: [0, 256]
# 	 score:0.5298(th=0.200000), auc=0.919391::: time:937.03s
# slide pos: [256, 256]
# 	 score:0.4798(th=0.250000), auc=0.915937::: time:953.76s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.4581(th=0.200000), auc=0.912667::: time:973.80s
# slide pos: [256, 0]
# 	 score:0.4287(th=0.250000), auc=0.900532::: time:990.53s
# slide pos: [0, 256]
# 	 score:0.4731(th=0.200000), auc=0.904420::: time:1007.55s
# slide pos: [256, 256]
# 	 score:0.4413(th=0.200000), auc=0.898894::: time:1024.47s
# [fold3] slice ave score:0.5251(th=0.200000), auc=0.920149
# -- fold4 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.4709(th=0.200000), auc=0.882464::: time:1073.12s
# slide pos: [256, 0]
# 	 score:0.4740(th=0.200000), auc=0.881935::: time:1093.56s
# slide pos: [0, 256]
# 	 score:0.4748(th=0.200000), auc=0.883125::: time:1113.81s
# slide pos: [256, 256]
# 	 score:0.4643(th=0.200000), auc=0.879754::: time:1134.44s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.4805(th=0.200000), auc=0.887345::: time:1166.20s
# slide pos: [256, 0]
# 	 score:0.4813(th=0.200000), auc=0.881797::: time:1187.19s
# slide pos: [0, 256]
# 	 score:0.4651(th=0.150000), auc=0.886519::: time:1207.82s
# slide pos: [256, 256]
# 	 score:0.4728(th=0.200000), auc=0.880816::: time:1228.82s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.4556(th=0.200000), auc=0.875323::: time:1262.00s
# slide pos: [256, 0]
# 	 score:0.4437(th=0.150000), auc=0.877890::: time:1282.90s
# slide pos: [0, 256]
# 	 score:0.4571(th=0.200000), auc=0.877050::: time:1303.31s
# slide pos: [256, 256]
# 	 score:0.4458(th=0.200000), auc=0.873535::: time:1323.66s
# [fold4] slice ave score:0.5059(th=0.150000), auc=0.892588
# fold[0] slice ave score:0.5715(th=0.200000), auc=0.898090
# fold[1] slice ave score:0.5525(th=0.300000), auc=0.859840
# fold[2] slice ave score:0.5215(th=0.250000), auc=0.839192
# fold[3] slice ave score:0.5251(th=0.200000), auc=0.920149
# fold[4] slice ave score:0.5059(th=0.150000), auc=0.892588
# CPU times: user 17min 45s, sys: 3min 5s, total: 20min 50s
# Wall time: 22min 19s

# %%
import yaml
with open(os.path.join(CFG["OUTPUT_DIR"], "Config.yaml"), "w") as f:
    yaml.dump(CFG, f)

# %%
if not CFG["DEBUG"]:
    wandb.finish()

# %%
# %%time
pred_flatten_list = []
mask_flatten_list = []
for fold in [0,1,2,3,4]:
    pred_path = os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_average_slice555_valid_pred_img.png")
    mask_path = os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_average_slice555_valid_targets_img.png")
    print(pred_path)
    pred_img = cv2.imread(pred_path, cv2.IMREAD_GRAYSCALE)
    mask_img = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    print(pred_img.shape)
    print(mask_img.shape)
    plt.figure()
    plt.subplot(1, 2, 1)
    plt.imshow(pred_img)
    plt.subplot(1, 2, 2)
    plt.imshow(mask_img)
    plt.show()
    pred_flatten_list.extend(pred_img.flatten())
    mask_flatten_list.extend(mask_img.flatten())
# Out:
# /working/output/exp038/imgs/fold0_average_slice555_valid_pred_img.png
# (7606, 5249)
# (7606, 5249)
# /working/output/exp038/imgs/fold1_average_slice555_valid_pred_img.png
# (4943, 9506)
# (4943, 9506)
# /working/output/exp038/imgs/fold2_average_slice555_valid_pred_img.png
# (4943, 9506)
# (4943, 9506)
# /working/output/exp038/imgs/fold3_average_slice555_valid_pred_img.png
# (4943, 9506)
# (4943, 9506)
# /working/output/exp038/imgs/fold4_average_slice555_valid_pred_img.png
# (8181, 6330)
# (8181, 6330)
# CPU times: user 16.7 s, sys: 7.89 s, total: 24.6 s
# Wall time: 22.5 s

# %%
mask_flatten_list = np.array(mask_flatten_list)/255.
mask = np.array(mask_flatten_list).astype(int)
pred = np.array(pred_flatten_list)/255.

plt.figure()
plt.subplot(1, 2, 1)
plt.hist(pred, bins=100)
plt.subplot(1, 2, 2)
plt.hist(mask)
plt.show()

for th in np.array(range(10, 100+1, 5)) / 100:
    dice = fbeta_numpy(mask, (pred >= th).astype(int), beta=0.5)
    print(f"th={th:.2f}, dice={dice:.4f}")
# Out:
# th=0.10, dice=0.4549
# th=0.15, dice=0.5046
# th=0.20, dice=0.5243
# th=0.25, dice=0.5251
# th=0.30, dice=0.5078
# th=0.35, dice=0.4750
# th=0.40, dice=0.4329
# th=0.45, dice=0.3765
# th=0.50, dice=0.3128
# th=0.55, dice=0.2472
# th=0.60, dice=0.1880
# th=0.65, dice=0.1305
# th=0.70, dice=0.0820
# th=0.75, dice=0.0438
# th=0.80, dice=0.0202
# th=0.85, dice=0.0052
# th=0.90, dice=0.0004
# th=0.95, dice=0.0000
# th=1.00, dice=0.0000
