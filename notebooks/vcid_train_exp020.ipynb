# %% [markdown]
# # ex020
# bug fix masked_img
# 5-fold
# img size 512
# output shape is half of input shape
# channel shuffle
# 学習時にrandom slide

# %%
import gc
import os
import random
import time
import math

import cv2
import numpy as np
import matplotlib.pyplot as plt

# model
import torch
import torchvision
import torch.nn as nn
import timm
from torchvision.models.feature_extraction import create_feature_extractor
import torchvision.transforms.functional as TF

# data loader
import albumentations as A
from albumentations.pytorch import ToTensorV2
from torch.utils.data import DataLoader, Dataset

# training
from torch.optim import SGD, Adam, AdamW
from torch.optim.lr_scheduler import CosineAnnealingLR, CosineAnnealingWarmRestarts, ReduceLROnPlateau, ExponentialLR

# metric
from sklearn.metrics import fbeta_score, roc_auc_score

import wandb

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # config

# %%
BASE_DIR = "/working/"
INPUT_DIR = os.path.join(BASE_DIR, "input", "vesuvius-challenge-ink-detection")
TRAIN_DIR = os.path.join(INPUT_DIR, "train")
TEST_DIR = os.path.join(INPUT_DIR, "test")
# IMG_SIZE = [256, 256]
# IMG_SIZE = [128, 128]
IMG_SIZE = [512, 512]
SURFACE_LIST = [
                list(range(26, 36, 3)),
                list(range(27, 37, 3)),                
                list(range(25, 35, 3)),
                ]
print(len(SURFACE_LIST[0]))
print(SURFACE_LIST)

SURFACE_NUM = len(SURFACE_LIST[0])
# print("Start surface idx =",START_SURFACE)

# SLIDE_POS_LIST = [[idx*(IMG_SIZE[0]//6), idx*(IMG_SIZE[1]//6)] for idx in range(0, 3)]
SLIDE_POS_LIST = [[0,0], [IMG_SIZE[0]//2, 0], [0, IMG_SIZE[1]//2], [IMG_SIZE[0]//2, IMG_SIZE[1]//2]]
print("SLIDE_POS_LIST =", SLIDE_POS_LIST)
CFG = {
    "DEBUG" : False,
    # exp setting
    "EXP_CATEGORY" : "5fold",
    "EXP_NAME" : "exp020",
    "folds" : [0, 1, 2, 3, 4],

    # model
    # "model_name" : "tf_efficientnet_b0",
    "model_name" : "tf_efficientnet_b6",
    "inp_channels" : SURFACE_NUM,
    "out_channels" : 1,
    "pretrained" : True,
    "out_indices" : [0,1,2,3,4],
 
    # data   
    "img_size": IMG_SIZE,
    # "batch_size": 32,
    # "batch_size": 16,#batch normの関係か？16の方が64より安定してそう？？
    "batch_size": 8,
    "INPUT_DIR": INPUT_DIR,
    "TRAIN_DIR": TRAIN_DIR,
    "TEST_DIR": TEST_DIR,
    "surface_num": SURFACE_NUM,
    "surface_list": list(SURFACE_LIST),
    "slide_pos_list": SLIDE_POS_LIST,
    "RANDOM_SLIDE": True,
#     "surface_start_idx": START_SURFACE,
    # "TRAIN_DIR_LIST": [["1", "2"], ["1", "3"], ["2", "3"]],
    "TRAIN_DIR_LIST": [["1", "2_0", "2_1", "2_2"], 
                       ["1", "2_0", "2_1", "3"],
                       ["1", "2_0",  "2_2", "3"],
                       ["1", "2_1", "2_2", "3"],
                       ["2_0", "2_1", "2_2", "3"],
                       ],
#     "TRAIN_IDX_LIST" : ["1"],
    # "VALID_DIR_LIST": [["3"],["2"],["1"]],
    "VALID_DIR_LIST": [["3"], ["2_2"], ["2_1"], ["2_0"],["1"]],
    "TEST_DIR_LIST": ["a", "b"],

    # learning
    "n_epoch" : 15,
    "lr" : 1e-3,
    "T_max" : 5,
    "min_lr" : 1e-8,
    "weight_decay" : 1e-6,

    # etc
    "print_freq" : 1000,
    "random_seed" : 21,
    "num_workers": 2,
}


if CFG["model_name"]=="tf_efficientnet_b0":
    CFG["channel_nums"] = [320, 112, 40, 24, 16]
elif CFG["model_name"]=="tf_efficientnet_b4":
    CFG["channel_nums"] = [448, 160, 56, 32, 24]
elif CFG["model_name"]=="tf_efficientnet_b6":
    CFG["channel_nums"] = [576, 200, 72, 40, 32]


if CFG["DEBUG"]:
    CFG["n_epoch"] = 1
    CFG["EXP_NAME"] = "DEBUG"
    

CFG["OUTPUT_DIR"] = os.path.join(BASE_DIR, "output", CFG["EXP_NAME"])
# Out:
# 4
# [[26, 29, 32, 35], [27, 30, 33, 36], [25, 28, 31, 34]]
# SLIDE_POS_LIST = [[0, 0], [256, 0], [0, 256], [256, 256]]

# %%
if not CFG["DEBUG"]:
    os.makedirs(CFG["OUTPUT_DIR"])
    os.makedirs(os.path.join(CFG["OUTPUT_DIR"], "imgs"))

# %%
if not CFG["DEBUG"]:
    WANDB_CONFIG = {'competition': 'vcid', '_wandb_kernel': 'taro'}
    os.environ["WANDB_SILENT"] = "true"
    wandb.init(project=WANDB_CONFIG["competition"], config=CFG, group=CFG["EXP_CATEGORY"], name=CFG["EXP_NAME"], reinit=True)
# Out:
# 2023-04-20 11:53:44.302891: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-20 11:53:44.404570: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-20 11:53:45.006886: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-20 11:53:45.006971: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-20 11:53:45.006978: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# # utils

# %%
def logging_metrics_epoch(CFG, fold, epoch, slice_idx,train_loss_avg, valid_loss_avg, score, threshold, auc_score):
    wandb.log({f"train/fold{fold}": train_loss_avg,
                f"valid/fold{fold}": valid_loss_avg,
                f"score/fold{fold}":score,
                f"score threshold/fold{fold}":threshold,
                f"auc/fold{fold}":auc_score,
                f"epoch/fold{fold}":epoch+slice_idx*CFG["n_epoch"],
                })

# %%
def seed_everything(seed=CFG["random_seed"]):
    #os.environ['PYTHONSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic =True
    torch.backends.cudnn.benchmark = False
seed_everything()

# device optimization
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
def asMinutes(s):
    """Convert Seconds to Minutes."""
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    """Accessing and Converting Time Data."""
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))

class AverageMeter(object):
    """Computes and stores the average and current value."""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# # metric

# %%
def fbeta_numpy(targets, preds, beta=0.5, smooth=1e-5):
    y_true_count = targets.sum()
    ctp = preds[targets==1].sum()
    cfp = preds[targets==0].sum()
    beta_squared = beta * beta

    c_precision = ctp / (ctp + cfp + smooth)
    c_recall = ctp / (y_true_count + smooth)
    dice = (1 + beta_squared) * (c_precision * c_recall) / (beta_squared * c_precision + c_recall + smooth)

    return dice

def calc_fbeta_auc(mask, mask_pred):
    mask = mask.astype(int).flatten()
    mask_pred = mask_pred.flatten()

    best_th = 0
    best_dice = 0
    dice_list = [] 
    # for th in np.array(range(10, 50+1, 5)) / 100:
    for th in np.array(range(10, 100+1, 5)) / 100:
        # dice = fbeta_score(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice = fbeta_numpy(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice_list.append(dice)
        # print(f'\t th: {th}, fbeta: {dice}')
        if dice > best_dice:
            best_dice = dice
            best_th = th
    
    auc = roc_auc_score(mask, mask_pred)
    # Logger.info(f'best_th: {best_th}, fbeta: {best_dice}')
    return best_dice, best_th, auc, dice_list


def calc_cv(mask_gt, mask_pred):
    best_dice, best_th, auc, dice_list = calc_fbeta_auc(mask_gt, mask_pred)

    return best_dice, best_th, auc, dice_list

# %% [markdown]
# # model

# %%
class Encoder(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = timm.create_model(CFG["model_name"], in_chans=CFG["inp_channels"], features_only=True, out_indices=CFG["out_indices"], pretrained=CFG["pretrained"])
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        return skip_connection_list

class UpConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.bn1 = nn.BatchNorm2d(in_channels)
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size = 2, padding="same")
        self.bn2 = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        x = self.up(x)
        x = self.bn1(x)
        x = self.conv(x)
        x = self.bn2(x)
        return x


class Decoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.UpConv_0 = UpConv(CFG["channel_nums"][0], CFG["channel_nums"][1])
        self.UpConv_1 = UpConv(CFG["channel_nums"][1]*2, CFG["channel_nums"][2])
        self.UpConv_2 = UpConv(CFG["channel_nums"][2]*2, CFG["channel_nums"][3])
        self.UpConv_3 = UpConv(CFG["channel_nums"][3]*2, CFG["channel_nums"][4])
        # self.UpConv_4 = UpConv(CFG["channel_nums"][4]*2, CFG["channel_nums"][4])
    
    def forward(self, skip_connection_list):
        emb = self.UpConv_0(skip_connection_list[4]) # emb.shape = (None, 160, 14, 14)
        emb_cat = torch.cat([skip_connection_list[3], emb], dim = 1)
        
        emb = self.UpConv_1(emb_cat)
        emb_cat = torch.cat([skip_connection_list[2], emb], dim = 1)
        
        emb = self.UpConv_2(emb_cat)
        emb_cat = torch.cat([skip_connection_list[1], emb], dim = 1)
        
        emb = self.UpConv_3(emb_cat)
        emb_cat = torch.cat([skip_connection_list[0], emb], dim = 1)

        # emb_cat = self.UpConv_4(emb_cat)
        
        return emb_cat

class SegModel(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = Encoder(CFG)
        self.decoder = Decoder()
        self.head = nn.Sequential(
            nn.Conv2d(CFG["channel_nums"][-1]*2, CFG["out_channels"], kernel_size=1, stride=1, padding=0),
            nn.Sigmoid()
        )
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        emb = self.decoder(skip_connection_list)
        output = self.head(emb)
        return output

# %% [markdown]
# # Dataset

# %%
train_transforms = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.RandomCrop(int(CFG["img_size"][0]*0.8), int(CFG["img_size"][1]*0.8), p=0.3),
    A.Blur(blur_limit=3, p=0.3),
    A.Resize(CFG["img_size"][0], CFG["img_size"][1]),
    ToTensorV2(),
])

valid_transforms = A.Compose([
    ToTensorV2(),
])

# %%
class VCID_Dataset(Dataset):
    def __init__(self, CFG, data_dir_list, surface_list, surface_volumes=None, slide_pos=[0,0], mode="train", transform=None):
        # get config
        self.mode = mode
        self.RANDOM_SLIDE = CFG["RANDOM_SLIDE"]
        self.img_size = CFG["img_size"]
        if self.mode=="train":  self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode=="valid":    self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode == "test":   self.DATADIR = CFG["TEST_DIR"]
        self.data_dir_list = data_dir_list
        self.surface_list = surface_list
        self.slide_pos = slide_pos
        self.transform = transform
        
        # get imgs
        # print("initializing dataset...")
        self.imgs = []
        for data_dir in self.data_dir_list:
            img_path = os.path.join(self.DATADIR, data_dir, "mask.png")
            # print(img_path)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            img = img.reshape(img.shape[0], img.shape[1], 1) # (h, w, channel=1)
            assert img is not None, "img is None. data path is wrong"
        
            # mask erosion
            kernel_size = (img.shape[0]+img.shape[1])//2//100
            kernel = np.ones((kernel_size, kernel_size), np.uint8)
            img = cv2.erode(img, kernel,iterations = 3)
            self.imgs.append(img[:,:,np.newaxis])    
        
        # get and split surface
        if surface_volumes is None:
            self.surface_vols = self.read_surfacevols()
        else:
            # print("using loaded surface_vols")
            self.surface_vols = surface_volumes
        for surface_idx, surface_vol in enumerate(self.surface_vols):
            self.surface_vols[surface_idx] = self.get_masked_img(surface_vol, self.imgs[surface_idx])
       
        # split grid
        self.get_all_grid()
        self.fileter_grid()
        self.get_flatten_grid()
        # print("split grid done.") 
       
        # get label imgs
        if self.mode == "train" or self.mode == "valid":
            self.labels = []
            for data_dir in self.data_dir_list:
                label_path = os.path.join(self.DATADIR, data_dir, "inklabels.png")
                assert os.path.exists(label_path), f"{label_path} is not exist."
                # read label
                label = cv2.imread(label_path, cv2.IMREAD_GRAYSCALE)
                label = label.reshape(label.shape[0], label.shape[1], 1) # (h, w, channel=1)
                self.labels.append(label)# 画像サイズがそれぞれ違うので単純にconcatできずlist化しているs
        # print("initializing dataset done.")

    def get_surface_volumes(self):
        return self.surface_vols

    def read_surfacevols(self):
        """ read surface volume by data_dir_list and surface_list 
            Returns:surface_vuls (list): surface volume list [array(h,w,channel=surface_num), array(), ...]
        """
        surface_vols = []
        # print("reading surface volume...")
        for data_dir in self.data_dir_list:
            surface_vol_ = None
            for read_idx, surface_idx in enumerate(self.surface_list):
                # print("\r", f"reading idx : {read_idx+1}/{len(self.surface_list)}", end="")
                surface_path = os.path.join(self.DATADIR, data_dir, "surface_volume", f"{surface_idx:02}.tif")
                surface_vol = cv2.imread(surface_path, cv2.IMREAD_GRAYSCALE)
                surface_vol = surface_vol.reshape(surface_vol.shape[0], surface_vol.shape[1], 1) # (h, w, channel=1)
                if surface_vol_ is None:
                    surface_vol_ = surface_vol
                else:
                    surface_vol_ = np.concatenate([surface_vol_, surface_vol], axis=2) # (h, w, channel=surface_num)
            surface_vols.append(surface_vol_)
            # print(f"  => read surface volume done. [{data_dir}]")
        return surface_vols


    def get_grid_img(self, img, grid_idx):
        """ crop grid img from original img"""
        img_grid = img[(grid_idx[0]*self.img_size[0]) + self.slide_pos[0] : ((grid_idx[0]+1)*self.img_size[0]) + self.slide_pos[0],
                        (grid_idx[1]*self.img_size[1]) + self.slide_pos[1] : ((grid_idx[1]+1)*self.img_size[1]) + self.slide_pos[1]]
        return img_grid
    
    def get_grid_img_and_mask(self, img, mask, grid_idx):
        """ crop grid img from original img"""
        if self.RANDOM_SLIDE and self.mode=="train" and random.random() < 0.5:
            if (grid_idx[0]!=0 and grid_idx[1]!=0) and (grid_idx[0]!=img.shape[0]//self.img_size[0] and grid_idx[1]!=img.shape[1]//self.img_size[1]):
                rand_pos = [np.random.randint(0, self.img_size[0]//4) - self.img_size[0]//4, np.random.randint(0, self.img_size[1]//4)-self.img_size[1]//4]
            else:
                rand_pos = [0, 0]
        else:
            rand_pos = [0, 0]
        img_grid = img[(grid_idx[0]*self.img_size[0]) + self.slide_pos[0] + rand_pos[0] : ((grid_idx[0]+1)*self.img_size[0]) + self.slide_pos[0] + rand_pos[0],
                        (grid_idx[1]*self.img_size[1]) + self.slide_pos[1] + rand_pos[1] : ((grid_idx[1]+1)*self.img_size[1]) + self.slide_pos[1] + rand_pos[1]]
        mask_grid = mask[(grid_idx[0]*self.img_size[0]) + self.slide_pos[0] + rand_pos[0] : ((grid_idx[0]+1)*self.img_size[0]) + self.slide_pos[0] + rand_pos[0],
                         (grid_idx[1]*self.img_size[1]) + self.slide_pos[1] + rand_pos[1] : ((grid_idx[1]+1)*self.img_size[1]) + self.slide_pos[1] + rand_pos[1]]
        return img_grid/255., mask_grid/255.
    
    def get_masked_img(self, img, mask):
        """ multiply mask to surface_volumes """
        masked_img = None
        for channel in range(img.shape[2]):
            img_channel = img[:,:,channel].reshape(img.shape[0], img.shape[1],1)
            masked = img_channel*mask
            if masked_img is None:
                masked_img = masked.reshape(masked.shape[0], masked.shape[1], 1)
            else:
                masked = masked.reshape(masked.shape[0], masked.shape[1], 1)
                masked_img = np.concatenate([masked_img, masked], axis=2)
        return masked_img
    
    
    def get_all_grid(self):
        """ get all grid indices by img size and grid size
        """
        self.grid_indices = []
        for img in self.imgs:
            self.x_grid_size = (img.shape[0] - self.slide_pos[0]) // self.img_size[0]
            self.y_grid_size = (img.shape[1] - self.slide_pos[1]) // self.img_size[1]
            grid_img = []
            for i in range(self.x_grid_size):
                for j in range(self.y_grid_size):
                    grid_img.append([i, j])
            self.grid_indices.append(grid_img)
        return self.grid_indices
          
    def fileter_grid(self):
        """ get grid indices which mask is not 0 by all grid indices"""
        grid_indices_all = []
        for img, grid_indices in zip(self.imgs, self.grid_indices):
            grid_indices_copy = grid_indices.copy()
            for grid_idx in grid_indices:
                img_grid = self.get_grid_img(img, grid_idx)
                if img_grid.sum() == 0:
                    grid_indices_copy.remove(grid_idx)
            grid_indices_all.append(grid_indices_copy)
        self.grid_indices = grid_indices_all
        return self.grid_indices

    def get_flatten_grid(self):
        """ get flatten index list by grid indices
            Returns:flatten_grid (list): flatten index list [[img_idx, grid_idx], [img_idx, grid_idx], ...]
        """
        flatten_grid = []
        for img_idx, grid_indices in enumerate(self.grid_indices):
            for grid_idx in grid_indices:
                grid_imgidx_list = [img_idx]
                grid_imgidx_list.extend(grid_idx)
                flatten_grid.append(grid_imgidx_list)
        self.flatten_grid = flatten_grid
        return self.flatten_grid
    
    def channel_shuffle(self, img):
        img = img.transpose(2, 0, 1)
        np.random.shuffle(img)
        return img.transpose(1, 2, 0)

    def __len__(self):
        return len(self.flatten_grid)

    def __getitem__(self, idx):
        # get indices
        img_grid_idx = self.flatten_grid[idx]
        img_idx = img_grid_idx[0]
        grid_idx = img_grid_idx[1:]
        # get img & surface_vol
        mask = self.imgs[img_idx]
        surface_vol = self.surface_vols[img_idx]
        # mask = self.get_grid_img(mask, grid_idx)/255.
        # surface_vol = self.get_grid_img(surface_vol, grid_idx)/255.
        mask, surface_vol = self.get_grid_img_and_mask(mask, surface_vol, grid_idx)
        # multiple small mask 
        assert surface_vol.shape[0]==mask.shape[0] and surface_vol.shape[1]==mask.shape[1] , "surface_vol_list shape is not same as img shape"
        img = surface_vol
        # transform
        if self.mode == "test":
            if self.transform:
                img = self.transform(image=img)["image"]
            else:
                img = img.transpose(2, 0, 1)
                img = torch.tensor(img, dtype=torch.float32)
            return img, grid_idx
        elif self.mode == "train" or self.mode=="valid":
            # get label(segmentation mask)
            label = self.labels[img_idx]
            label = self.get_grid_img(label, grid_idx)
            if self.mode == "train":
                img = self.channel_shuffle(img)
            if self.transform:
                transformed = self.transform(image=img, mask=label)
                img = transformed["image"]
                label = transformed["mask"]
                label = label.permute(2, 0, 1)/255. # (channel, h, w)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            else:
                img = img.transpose(2, 0, 1) # (channel, h, w)
                label = label.transpose(2, 0, 1)/255. # (channel, h, w){}
                img = torch.tensor(img, dtype=torch.float32)
                label = torch.tensor(label, dtype=torch.float32)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            return img, label, grid_idx

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train")
# surface_volumes = dataset_notrans.surface_vols
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx < 2:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
        
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train")
# surface_volumes = dataset_notrans.surface_vols
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx < 2:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos=[0,50],mode="train")
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 1:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train", transform=train_transforms)
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)


# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 0:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %% [markdown]
# # train valid fn

# %%
def train_fn(train_loader, model, criterion, epoch ,optimizer, scheduler):
    model.train()
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, _) in enumerate(train_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()     
        preds = model(images)
        preds = TF.resize(img=preds, size=(CFG["img_size"][0], CFG["img_size"][1]))
        # preds = torch.sigmoid(preds)
        loss = criterion(preds, targets)
        
        losses.update(loss.item(), CFG["batch_size"]) 
        targets = targets.detach().cpu().numpy().ravel().tolist()
        preds = preds.detach().cpu().numpy().ravel().tolist()
        loss.backward() # パラメータの勾配を計算
        optimizer.step() # モデル更新
        optimizer.zero_grad() # 勾配の初期化
                
        batch_time.update(time.time() - end)
        end = time.time()
        if batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(train_loader)-1):
            print('Epoch: [{0}][{1}/{2}] '
                    'Elapsed {remain:s} '
                    'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                    .format(
                        epoch, batch_idx, len(train_loader), batch_time=batch_time, loss=losses,
                        remain=timeSince(start, float(batch_idx+1)/len(train_loader)),
            ))
        del preds, images, targets
    gc.collect()
    torch.cuda.empty_cache()
    return losses.avg

# %%
def valid_fn(model, valid_loader, criterion=None):
    model.eval()# モデルを検証モードに設定
    test_targets = []
    test_preds = []
    test_grid_idx = []
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, grid_idx) in enumerate(valid_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()
        with torch.no_grad():
            preds = model(images)
            preds = TF.resize(img=preds, size=(CFG["img_size"][0], CFG["img_size"][1]))
            if not criterion is None:
                loss = criterion(preds, targets)
        if not criterion is None:
            losses.update(loss.item(), CFG["batch_size"])
        batch_time.update(time.time() - end)

        targets = targets.detach().cpu().numpy()
        preds = preds.detach().cpu().numpy()
        
        test_preds.extend([preds[idx, :,:,:].transpose(1,2,0) for idx in range(preds.shape[0])])
        test_targets.extend([targets[idx, :,:,:].transpose(1,2,0) for idx in range(targets.shape[0])])
        test_grid_idx.extend([[x_idx, y_idx] for x_idx, y_idx in zip(grid_idx[0].tolist(), grid_idx[1].tolist())])

        if (batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(valid_loader)-1)) and (not criterion is None):
            print('EVAL: [{0}/{1}] '
                'Elapsed {remain:s} '
                'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                .format(
                    batch_idx, len(valid_loader), batch_time=batch_time, loss=losses,
                    remain=timeSince(start, float(batch_idx+1)/len(valid_loader)),
                ))
        del preds, images, targets
        gc.collect()
        torch.cuda.empty_cache()
    if criterion is None:
        return test_targets, test_preds, test_grid_idx
    else:
        return test_targets, test_preds, test_grid_idx, losses.avg

# %% [markdown]
# # training loop

# %%
# def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list):
#     # concat pred img and label to original size
#     img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
#     img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
#     img = img.reshape(img.shape[0], img.shape[1], 1)
#     pred_img = np.zeros_like(img).astype(np.float32)
#     label_img = np.zeros_like(img).astype(np.float32)
#     for img_idx, grid_idx in enumerate(grid_idx_list):
#         pred_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += img_list[img_idx]
        
#         label_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += label_list[img_idx]
#     return pred_img, label_img

# %%
def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list, slide_pos=[0,0]):
    # concat pred img and label to original size
    img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    img = img.reshape(img.shape[0], img.shape[1], 1)
    pred_img = np.zeros_like(img).astype(np.float32)
    label_img = np.zeros_like(img).astype(np.float32)
    for img_idx, grid_idx in enumerate(grid_idx_list):
        pred_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += img_list[img_idx]
        
        label_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += label_list[img_idx]
    return pred_img, label_img

# %%
def save_and_plot_oof(mode, fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary):
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_pred_img.png"), valid_preds_img*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_predbin_img.png"), valid_preds_binary*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_targets_img.png"), valid_targets_img*255)
    
    # plot preds & binary preds
    # plt.figure(dpi=100)
    # plt.subplot(1,3,1)
    # plt.imshow(valid_preds_img)
    # plt.subplot(1,3,2)
    # plt.imshow(valid_preds_binary)
    # plt.subplot(1,3,3)
    # plt.imshow(valid_targets_img)
    # plt.show()

# %%
def training_loop(CFG):
    best_score_list = []
    best_threshold_list = []
    best_epoch_list = []
    slice_ave_score_list = []
    slice_ave_auc_list = []
    slice_ave_score_threshold_list = []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} training start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        model = model.to(device)
        valid_img_slice = []
        criterion = nn.BCELoss()
        optimizer = AdamW(model.parameters(), lr=CFG["lr"], weight_decay=CFG["weight_decay"], amsgrad=False)
        scheduler = CosineAnnealingLR(optimizer, T_max=CFG["T_max"], eta_min=CFG["min_lr"], last_epoch=-1)
        # scheduler = ExponentialLR(optimizer, gamma=0.60)
        
        # training
        best_score = -np.inf
        best_auc = -np.inf
        best_valloss = np.inf
        best_auc_valloss = np.inf
        best_threshold = -1
        start_time = time.time()
        best_epoch = -1
        best_auc_epoch = -1
        valid_slice_ave = None       
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            # separate train/valid data 
            train_dirs = CFG["TRAIN_DIR_LIST"][fold]
            valid_dirs = CFG["VALID_DIR_LIST"][fold]
            train_dataset = VCID_Dataset(CFG, train_dirs, surface_list, mode="train", transform=train_transforms)
            valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, mode="valid", transform=valid_transforms)
            train_loader = DataLoader(train_dataset, batch_size=CFG["batch_size"], shuffle = True,
                                        num_workers = CFG["num_workers"], pin_memory = True)
            valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                        num_workers = CFG["num_workers"], pin_memory = True)
            for epoch in range(1, CFG["n_epoch"] + 1):
                epochs_ = epoch + CFG["n_epoch"] * slice_idx
                print(f'- epoch:{epochs_} -')
                train_loss_avg = train_fn(train_loader, model, criterion, epochs_ ,optimizer, scheduler)
                valid_targets, valid_preds, valid_grid_idx, valid_loss_avg = valid_fn(model, valid_loader, criterion)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                
                elapsed = time.time() - start_time
                print(f"\t epoch:{epochs_}, avg train loss:{train_loss_avg:.4f}, avg valid loss:{valid_loss_avg:.4f}")
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                if not CFG["DEBUG"]:
                    logging_metrics_epoch(CFG, fold, epoch, slice_idx, train_loss_avg, valid_loss_avg, valid_score, valid_threshold, auc)
                scheduler.step()
                # validationスコアがbestを更新したらモデルを保存する
                if valid_score > best_score:
                    best_epoch = epochs_
                    best_valloss = valid_loss_avg
                    best_score = valid_score
                    best_threshold = valid_threshold
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epochs_} - Save Best Score: {best_score:.4f}. Model is saved.')
                    print("dice_list: ", dice_list)
                    # save oof
                    save_and_plot_oof("score", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
                
                if auc > best_auc:
                    best_auc = auc
                    best_auc_epoch = epochs_
                    best_auc_valloss = valid_loss_avg
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_auc_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epochs_} - Save Best AUC: {best_auc:.4f}. Model is saved.')
                    # save oof
                    save_and_plot_oof("auc", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
            # valid_img_slice.append(valid_preds_img)
            if valid_slice_ave is None:
                valid_slice_ave = valid_preds_img
            else:
                valid_slice_ave += valid_preds_img
        # valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        # for idx in range(len(SURFACE_LIST)):
        #     valid_pred_slice = valid_img_slice[idx]
        #     valid_slice_ave += valid_pred_slice
        valid_slice_ave /= len(SURFACE_LIST)
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_slice_ave)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)
 
        valid_slice_binary = (valid_slice_ave > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 999, valid_slice_ave, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
        
        print(f'[fold{fold}] BEST Epoch {best_epoch} - Save Best Score:{best_score:.4f}. Best loss:{best_valloss:.4f}')
        print(f'[fold{fold}] BEST AUC Epoch {best_auc_epoch} - Save Best Score:{best_auc:.4f}. Best loss:{best_auc_valloss:.4f}')
            
        best_score_list.append(best_score)
        best_threshold_list.append(best_threshold)
        best_epoch_list.append(best_epoch)
        del model, train_loader, train_dataset, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
        
    for fold, (best_score, best_threshold, best_epoch) in enumerate(zip(best_score_list, best_threshold_list, best_epoch_list)):
        print(f"fold[{fold}] BEST SCORE = {best_score:.4f} thr={best_threshold} (epoch={best_epoch})")
        print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    return best_score_list, best_threshold_list, best_epoch_list

# %% [markdown]
# # slice inference

# %%
def slide_inference(CFG):
    start_time = time.time()
    slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list = [], [], []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} slide inference start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        # model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_fold{fold}.pth')
        model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_auc_fold{fold}.pth')
        model.load_state_dict(torch.load(model_path))
        model = model.to(device)
        valid_img_slice = None
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            surface_volumes = None
            for slide_pos in CFG["slide_pos_list"]:
                print("slide pos:", slide_pos)
                valid_dirs = CFG["VALID_DIR_LIST"][fold]
                valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos, mode="valid", transform=valid_transforms)
                surface_volumes = valid_dataset.get_surface_volumes()
                valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                            num_workers = CFG["num_workers"], pin_memory = True)

                valid_targets, valid_preds, valid_grid_idx = valid_fn(model, valid_loader)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs, slide_pos)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                save_and_plot_oof("slide", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary) 
                
                elapsed = time.time() - start_time
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                # valid_img_slice.append(valid_preds_img)
                if valid_img_slice is None:
                    valid_img_slice = valid_preds_img
                else:
                    valid_img_slice += valid_preds_img
            # valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        # for idx in range(len(SURFACE_LIST)*len(CFG["slide_pos_list"])):
        #     valid_pred_slice = valid_img_slice[idx]
        #     valid_slice_ave += valid_pred_slice
        valid_img_slice /= len(SURFACE_LIST)*len(CFG["slide_pos_list"])
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_img_slice)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)

        valid_slice_binary = (valid_img_slice > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 555, valid_img_slice, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
         
        del model, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
    return slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list

# %% [markdown]
# # main

# %%
# %%time
best_score_list, best_threshold_list, best_epoch_list = training_loop(CFG)
# Out:
# -- fold0 training start --
# surface_list:  [26, 29, 32, 35]
# - epoch:1 -
# Epoch: [1][0/61] Elapsed 0m 1s (remain 1m 21s) Loss: 0.7976(0.7976)
# Epoch: [1][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.4783(0.4855)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1561(0.1561)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4789(0.3249)
# 	 epoch:1, avg train loss:0.4855, avg valid loss:0.3249
# 	 score:0.2885(th=0.300000), auc=0.827127::: time:76.58s
# Epoch 1 - Save Best Score: 0.2885. Model is saved.
# dice_list:  [0.19357423859064052, 0.2319119946666729, 0.2647559026830041, 0.2838048998970944, 0.2884504686791704, 0.27955052347130127, 0.25957895224756294, 0.22929540044240632, 0.19224631262644123, 0.15161025165715322, 0.11092778552243814, 0.0742945007031857, 0.044147997342452526, 0.023043111523366862, 0.010373295274956828, 0.003786362473628426, 0.0005935019183551316, 2.247148248441443e-05, 0.0]
# Epoch 1 - Save Best AUC: 0.8271. Model is saved.
# - epoch:2 -
# Epoch: [2][0/61] Elapsed 0m 1s (remain 1m 21s) Loss: 0.4978(0.4978)
# Epoch: [2][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.4744(0.4307)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1559(0.1559)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4351(0.3133)
# 	 epoch:2, avg train loss:0.4307, avg valid loss:0.3133
# 	 score:0.3757(th=0.400000), auc=0.849185::: time:123.79s
# Epoch 2 - Save Best Score: 0.3757. Model is saved.
# dice_list:  [0.19384676777473353, 0.24195114843275492, 0.28965521475049943, 0.32869244336453773, 0.3565110637945579, 0.3718560277827463, 0.37568709842797166, 0.3689984699097325, 0.3514103879553477, 0.32357634498477106, 0.28574073956894597, 0.23738133530893288, 0.18146856404216652, 0.12098287212977078, 0.064543577858545, 0.02413438613992915, 0.005216845288342854, 0.00015246103189992598, 0.0]
# Epoch 2 - Save Best AUC: 0.8492. Model is saved.
# - epoch:3 -
# Epoch: [3][0/61] Elapsed 0m 1s (remain 1m 15s) Loss: 0.3570(0.3570)
# Epoch: [3][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.5422(0.4159)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1282(0.1282)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4692(0.3057)
# 	 epoch:3, avg train loss:0.4159, avg valid loss:0.3057
# 	 score:0.3912(th=0.250000), auc=0.846893::: time:170.31s
# Epoch 3 - Save Best Score: 0.3912. Model is saved.
# dice_list:  [0.2575647252287594, 0.3394465028093521, 0.38520381219187044, 0.3911617134549021, 0.36527189730590737, 0.30823564105322876, 0.22852173278514537, 0.1474494705597505, 0.08216881244545977, 0.0390727127081935, 0.014393735196261375, 0.0037004019211381214, 0.0006994126493008107, 0.00013161077812469494, 2.407747312481708e-05, 8.026054270502933e-06, 4.815644930245755e-06, 0.0, 0.0]
# - epoch:4 -
# Epoch: [4][0/61] Elapsed 0m 1s (remain 1m 21s) Loss: 0.3751(0.3751)
# Epoch: [4][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3897(0.4029)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1439(0.1439)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4553(0.2972)
# 	 epoch:4, avg train loss:0.4029, avg valid loss:0.2972
# 	 score:0.4154(th=0.350000), auc=0.858823::: time:215.33s
# Epoch 4 - Save Best Score: 0.4154. Model is saved.
# dice_list:  [0.2529439705814139, 0.3298098455344408, 0.3793375049188986, 0.404877473456469, 0.4147673926380583, 0.41543453394172863, 0.41050054365749, 0.40145968478633065, 0.3861889092871055, 0.36201214886676103, 0.32550942620888507, 0.2758849641080588, 0.21387523436230163, 0.1485602117421948, 0.09167800490289789, 0.045187015424740226, 0.009816696347355092, 9.149090922286805e-05, 0.0]
# Epoch 4 - Save Best AUC: 0.8588. Model is saved.
# - epoch:5 -
# Epoch: [5][0/61] Elapsed 0m 1s (remain 1m 13s) Loss: 0.4198(0.4198)
# Epoch: [5][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2756(0.3915)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1503(0.1503)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4001(0.2905)
# 	 epoch:5, avg train loss:0.3915, avg valid loss:0.2905
# 	 score:0.4381(th=0.400000), auc=0.868205::: time:261.52s
# Epoch 5 - Save Best Score: 0.4381. Model is saved.
# dice_list:  [0.23695236766102665, 0.306283750900389, 0.35724870703909317, 0.39070772922174934, 0.41367174525150197, 0.4297293198884117, 0.4380932370436303, 0.43443150645266276, 0.4157844660475274, 0.37887490783221517, 0.3189913553981658, 0.2353970565217758, 0.13853466946984141, 0.05422290098735327, 0.01111332436502833, 0.0008196363520831203, 2.0867435724053696e-05, 0.0, 0.0]
# Epoch 5 - Save Best AUC: 0.8682. Model is saved.
# - epoch:6 -
# Epoch: [6][0/61] Elapsed 0m 1s (remain 1m 14s) Loss: 0.5333(0.5333)
# Epoch: [6][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3329(0.3898)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1531(0.1531)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3923(0.2912)
# 	 epoch:6, avg train loss:0.3898, avg valid loss:0.2912
# 	 score:0.4387(th=0.400000), auc=0.868094::: time:307.65s
# Epoch 6 - Save Best Score: 0.4387. Model is saved.
# dice_list:  [0.2316222804238736, 0.30031529388365463, 0.35326481852411085, 0.3901165414139463, 0.4150029911344113, 0.4305550014108406, 0.4386541631518174, 0.4354271283028898, 0.416810057540168, 0.37941639963975526, 0.31879945665330683, 0.23407668838898293, 0.1363895630214898, 0.05251286949014701, 0.01026096855280533, 0.0006465105131955921, 1.6051920656702865e-05, 0.0, 0.0]
# - epoch:7 -
# Epoch: [7][0/61] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2788(0.2788)
# Epoch: [7][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2610(0.3827)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1494(0.1494)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3956(0.2884)
# 	 epoch:7, avg train loss:0.3827, avg valid loss:0.2884
# 	 score:0.4481(th=0.450000), auc=0.873948::: time:352.21s
# Epoch 7 - Save Best Score: 0.4481. Model is saved.
# dice_list:  [0.23326770113673323, 0.29698737569349765, 0.34805585417229856, 0.38879087884641467, 0.4193572677177349, 0.4378777159621401, 0.4457305576509867, 0.44810926697354403, 0.4424903091035846, 0.42431975048922405, 0.389624915626642, 0.3384313784119916, 0.27394482526320296, 0.18930219018743089, 0.0949604719181432, 0.025471718022150473, 0.0010344815491450982, 1.605219099075328e-06, 0.0]
# Epoch 7 - Save Best AUC: 0.8739. Model is saved.
# - epoch:8 -
# Epoch: [8][0/61] Elapsed 0m 1s (remain 1m 23s) Loss: 0.3026(0.3026)
# Epoch: [8][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.4481(0.3916)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1204(0.1204)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4524(0.2987)
# 	 epoch:8, avg train loss:0.3916, avg valid loss:0.2987
# 	 score:0.4186(th=0.250000), auc=0.866786::: time:399.33s
# - epoch:9 -
# Epoch: [9][0/61] Elapsed 0m 1s (remain 1m 16s) Loss: 0.4191(0.4191)
# Epoch: [9][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2707(0.4042)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2043(0.2043)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4035(0.3293)
# 	 epoch:9, avg train loss:0.4042, avg valid loss:0.3293
# 	 score:0.4418(th=0.600000), auc=0.863820::: time:441.96s
# - epoch:10 -
# Epoch: [10][0/61] Elapsed 0m 1s (remain 1m 15s) Loss: 0.3837(0.3837)
# Epoch: [10][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3877(0.4005)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1323(0.1323)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4153(0.2950)
# 	 epoch:10, avg train loss:0.4005, avg valid loss:0.2950
# 	 score:0.4383(th=0.400000), auc=0.862096::: time:484.57s
# - epoch:11 -
# Epoch: [11][0/61] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2967(0.2967)
# Epoch: [11][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.4155(0.4052)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1261(0.1261)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.5065(0.2989)
# 	 epoch:11, avg train loss:0.4052, avg valid loss:0.2989
# 	 score:0.4407(th=0.250000), auc=0.854416::: time:526.88s
# - epoch:12 -
# Epoch: [12][0/61] Elapsed 0m 1s (remain 1m 17s) Loss: 0.4053(0.4053)
# Epoch: [12][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3719(0.3943)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1326(0.1326)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4366(0.2913)
# 	 epoch:12, avg train loss:0.3943, avg valid loss:0.2913
# 	 score:0.4521(th=0.400000), auc=0.867831::: time:569.06s
# Epoch 12 - Save Best Score: 0.4521. Model is saved.
# dice_list:  [0.20795352229488376, 0.2752784611815273, 0.34290873206466116, 0.40335291480275964, 0.4363852640359292, 0.45006193058859606, 0.45210098892090533, 0.4369364978477496, 0.39919844238216684, 0.3421987264576568, 0.26475414993177515, 0.18021205184714417, 0.11669348545626658, 0.06145455647265206, 0.022395914515018794, 0.003248525159280693, 0.00011717016065301105, 0.0, 0.0]
# - epoch:13 -
# Epoch: [13][0/61] Elapsed 0m 1s (remain 1m 17s) Loss: 0.3075(0.3075)
# Epoch: [13][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3448(0.3836)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1580(0.1580)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4014(0.2906)
# 	 epoch:13, avg train loss:0.3836, avg valid loss:0.2906
# 	 score:0.4888(th=0.400000), auc=0.884455::: time:612.41s
# Epoch 13 - Save Best Score: 0.4888. Model is saved.
# dice_list:  [0.20729760292877628, 0.24906093060327553, 0.2989091070021327, 0.3565011253839101, 0.4129799636429751, 0.46129485566082173, 0.4887931166866524, 0.48249027884937007, 0.4461809175474643, 0.38605817898013145, 0.3053576408532789, 0.21526348982975843, 0.12864160265752184, 0.06866966384597362, 0.036894117935574795, 0.013327117289599066, 0.002323241628773306, 0.0, 0.0]
# Epoch 13 - Save Best AUC: 0.8845. Model is saved.
# - epoch:14 -
# Epoch: [14][0/61] Elapsed 0m 1s (remain 1m 20s) Loss: 0.4934(0.4934)
# Epoch: [14][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4056(0.3759)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1721(0.1721)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3751(0.2931)
# 	 epoch:14, avg train loss:0.3759, avg valid loss:0.2931
# 	 score:0.4719(th=0.500000), auc=0.875953::: time:656.91s
# - epoch:15 -
# Epoch: [15][0/61] Elapsed 0m 1s (remain 1m 14s) Loss: 0.3263(0.3263)
# Epoch: [15][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4092(0.3587)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1690(0.1690)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3898(0.2910)
# 	 epoch:15, avg train loss:0.3587, avg valid loss:0.2910
# 	 score:0.4710(th=0.450000), auc=0.873497::: time:698.13s
# surface_list:  [27, 30, 33, 36]
# - epoch:16 -
# Epoch: [16][0/61] Elapsed 0m 1s (remain 1m 16s) Loss: 0.4234(0.4234)
# Epoch: [16][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.5207(0.3557)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1609(0.1609)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3795(0.2901)
# 	 epoch:16, avg train loss:0.3557, avg valid loss:0.2901
# 	 score:0.4775(th=0.450000), auc=0.874267::: time:774.51s
# - epoch:17 -
# Epoch: [17][0/61] Elapsed 0m 1s (remain 1m 28s) Loss: 0.3562(0.3562)
# Epoch: [17][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2741(0.3623)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1424(0.1424)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3921(0.2819)
# 	 epoch:17, avg train loss:0.3623, avg valid loss:0.2819
# 	 score:0.4947(th=0.450000), auc=0.875394::: time:816.56s
# Epoch 17 - Save Best Score: 0.4947. Model is saved.
# dice_list:  [0.23454983737841717, 0.29724991139676005, 0.35844955588233096, 0.41132620684276194, 0.4519261690250164, 0.4785785591092453, 0.49360560383754765, 0.4947021888501634, 0.4817067755096035, 0.45130597769347863, 0.40467980557621613, 0.3415057231373216, 0.25145790958438163, 0.1528475081414529, 0.08463337704220092, 0.04545707376918686, 0.024458488493794003, 5.29700535593646e-05, 0.0]
# - epoch:18 -
# Epoch: [18][0/61] Elapsed 0m 1s (remain 1m 22s) Loss: 0.3654(0.3654)
# Epoch: [18][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4154(0.3546)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1535(0.1535)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3808(0.2926)
# 	 epoch:18, avg train loss:0.3546, avg valid loss:0.2926
# 	 score:0.4653(th=0.500000), auc=0.876555::: time:860.08s
# - epoch:19 -
# Epoch: [19][0/61] Elapsed 0m 1s (remain 1m 23s) Loss: 0.2676(0.2676)
# Epoch: [19][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3844(0.3661)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1779(0.1779)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3658(0.3036)
# 	 epoch:19, avg train loss:0.3661, avg valid loss:0.3036
# 	 score:0.4702(th=0.500000), auc=0.875644::: time:901.89s
# - epoch:20 -
# Epoch: [20][0/61] Elapsed 0m 1s (remain 1m 27s) Loss: 0.4349(0.4349)
# Epoch: [20][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3833(0.3712)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1814(0.1814)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3741(0.2957)
# 	 epoch:20, avg train loss:0.3712, avg valid loss:0.2957
# 	 score:0.4431(th=0.450000), auc=0.871426::: time:943.78s
# - epoch:21 -
# Epoch: [21][0/61] Elapsed 0m 1s (remain 1m 16s) Loss: 0.2643(0.2643)
# Epoch: [21][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3481(0.3778)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1638(0.1638)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3921(0.3039)
# 	 epoch:21, avg train loss:0.3778, avg valid loss:0.3039
# 	 score:0.4194(th=0.400000), auc=0.863447::: time:985.63s
# - epoch:22 -
# Epoch: [22][0/61] Elapsed 0m 1s (remain 1m 23s) Loss: 0.3378(0.3378)
# Epoch: [22][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.5437(0.3766)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.3560(0.3560)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3267(0.3540)
# 	 epoch:22, avg train loss:0.3766, avg valid loss:0.3540
# 	 score:0.4626(th=0.750000), auc=0.877497::: time:1027.35s
# - epoch:23 -
# Epoch: [23][0/61] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2383(0.2383)
# Epoch: [23][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2779(0.3564)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1996(0.1996)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3546(0.2925)
# 	 epoch:23, avg train loss:0.3564, avg valid loss:0.2925
# 	 score:0.4769(th=0.500000), auc=0.867852::: time:1069.01s
# - epoch:24 -
# Epoch: [24][0/61] Elapsed 0m 1s (remain 1m 13s) Loss: 0.3221(0.3221)
# Epoch: [24][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2271(0.3458)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1523(0.1523)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3797(0.2786)
# 	 epoch:24, avg train loss:0.3458, avg valid loss:0.2786
# 	 score:0.5090(th=0.500000), auc=0.880966::: time:1110.95s
# Epoch 24 - Save Best Score: 0.5090. Model is saved.
# dice_list:  [0.25812642172688566, 0.3068829121487391, 0.34841499564429146, 0.38187127150438, 0.4106133599628729, 0.4391660589240876, 0.4685497966583985, 0.4948971643061103, 0.5089977070213737, 0.5018253696103284, 0.4780731104069235, 0.4386369912029584, 0.36202026172850577, 0.25680188543282684, 0.15700699211549696, 0.06765426380888434, 0.019087073035911017, 0.004621935897426573, 0.0]
# - epoch:25 -
# Epoch: [25][0/61] Elapsed 0m 1s (remain 1m 14s) Loss: 0.3648(0.3648)
# Epoch: [25][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2501(0.3338)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1550(0.1550)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3826(0.2814)
# 	 epoch:25, avg train loss:0.3338, avg valid loss:0.2814
# 	 score:0.4927(th=0.500000), auc=0.876917::: time:1153.77s
# - epoch:26 -
# Epoch: [26][0/61] Elapsed 0m 1s (remain 1m 26s) Loss: 0.5622(0.5622)
# Epoch: [26][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4835(0.3358)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1544(0.1544)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3884(0.2829)
# 	 epoch:26, avg train loss:0.3358, avg valid loss:0.2829
# 	 score:0.4932(th=0.500000), auc=0.877511::: time:1195.76s
# - epoch:27 -
# Epoch: [27][0/61] Elapsed 0m 1s (remain 1m 29s) Loss: 0.3323(0.3323)
# Epoch: [27][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.4269(0.3318)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1551(0.1551)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3770(0.2792)
# 	 epoch:27, avg train loss:0.3318, avg valid loss:0.2792
# 	 score:0.4982(th=0.500000), auc=0.878722::: time:1237.79s
# - epoch:28 -
# Epoch: [28][0/61] Elapsed 0m 1s (remain 1m 21s) Loss: 0.3204(0.3204)
# Epoch: [28][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3462(0.3262)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1237(0.1237)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3946(0.2808)
# 	 epoch:28, avg train loss:0.3262, avg valid loss:0.2808
# 	 score:0.4783(th=0.450000), auc=0.875191::: time:1279.59s
# - epoch:29 -
# Epoch: [29][0/61] Elapsed 0m 1s (remain 1m 19s) Loss: 0.2505(0.2505)
# Epoch: [29][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2994(0.3503)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1639(0.1639)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4131(0.2996)
# 	 epoch:29, avg train loss:0.3503, avg valid loss:0.2996
# 	 score:0.4418(th=0.450000), auc=0.859244::: time:1321.35s
# - epoch:30 -
# Epoch: [30][0/61] Elapsed 0m 1s (remain 1m 21s) Loss: 0.3352(0.3352)
# Epoch: [30][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3248(0.3575)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2049(0.2049)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3855(0.3079)
# 	 epoch:30, avg train loss:0.3575, avg valid loss:0.3079
# 	 score:0.4710(th=0.600000), auc=0.878956::: time:1362.96s
# surface_list:  [25, 28, 31, 34]
# - epoch:31 -
# Epoch: [31][0/61] Elapsed 0m 1s (remain 1m 21s) Loss: 0.3812(0.3812)
# Epoch: [31][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2742(0.3664)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2540(0.2540)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3818(0.3127)
# 	 epoch:31, avg train loss:0.3664, avg valid loss:0.3127
# 	 score:0.4249(th=0.450000), auc=0.874342::: time:1439.10s
# - epoch:32 -
# Epoch: [32][0/61] Elapsed 0m 1s (remain 1m 27s) Loss: 0.3154(0.3154)
# Epoch: [32][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3265(0.3514)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1849(0.1849)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3769(0.2873)
# 	 epoch:32, avg train loss:0.3514, avg valid loss:0.2873
# 	 score:0.4768(th=0.500000), auc=0.876800::: time:1481.20s
# - epoch:33 -
# Epoch: [33][0/61] Elapsed 0m 1s (remain 1m 23s) Loss: 0.3473(0.3473)
# Epoch: [33][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3452(0.3490)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1612(0.1612)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3707(0.2890)
# 	 epoch:33, avg train loss:0.3490, avg valid loss:0.2890
# 	 score:0.5021(th=0.550000), auc=0.868962::: time:1522.84s
# - epoch:34 -
# Epoch: [34][0/61] Elapsed 0m 1s (remain 1m 15s) Loss: 0.3962(0.3962)
# Epoch: [34][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2494(0.3332)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1924(0.1924)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3795(0.3025)
# 	 epoch:34, avg train loss:0.3332, avg valid loss:0.3025
# 	 score:0.4976(th=0.600000), auc=0.874084::: time:1564.43s
# - epoch:35 -
# Epoch: [35][0/61] Elapsed 0m 1s (remain 1m 27s) Loss: 0.4856(0.4856)
# Epoch: [35][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3390(0.3253)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2193(0.2193)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3654(0.3126)
# 	 epoch:35, avg train loss:0.3253, avg valid loss:0.3126
# 	 score:0.5121(th=0.650000), auc=0.881613::: time:1606.26s
# Epoch 35 - Save Best Score: 0.5121. Model is saved.
# dice_list:  [0.21100388371438691, 0.24691938899650687, 0.27914007766348664, 0.3069629481509458, 0.33758602788408165, 0.37023141367465434, 0.40432039724312085, 0.43561310645786316, 0.4662644109211421, 0.49084724555782683, 0.5074968002899273, 0.5120694931063908, 0.5054072716468826, 0.4849717440840729, 0.42355295144322813, 0.3147474374251951, 0.15435141507629, 0.015120637208241175, 0.0]
# - epoch:36 -
# Epoch: [36][0/61] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2784(0.2784)
# Epoch: [36][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2816(0.3189)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2073(0.2073)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3602(0.3058)
# 	 epoch:36, avg train loss:0.3189, avg valid loss:0.3058
# 	 score:0.5117(th=0.600000), auc=0.881599::: time:1649.05s
# - epoch:37 -
# Epoch: [37][0/61] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2522(0.2522)
# Epoch: [37][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2779(0.3244)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2251(0.2251)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3684(0.3212)
# 	 epoch:37, avg train loss:0.3244, avg valid loss:0.3212
# 	 score:0.5104(th=0.650000), auc=0.886373::: time:1690.63s
# Epoch 37 - Save Best AUC: 0.8864. Model is saved.
# - epoch:38 -
# Epoch: [38][0/61] Elapsed 0m 1s (remain 1m 16s) Loss: 0.5315(0.5315)
# Epoch: [38][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4566(0.3326)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2210(0.2210)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3681(0.3085)
# 	 epoch:38, avg train loss:0.3326, avg valid loss:0.3085
# 	 score:0.4954(th=0.600000), auc=0.877098::: time:1733.73s
# - epoch:39 -
# Epoch: [39][0/61] Elapsed 0m 1s (remain 1m 15s) Loss: 0.3704(0.3704)
# Epoch: [39][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3708(0.3397)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2012(0.2012)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3561(0.3055)
# 	 epoch:39, avg train loss:0.3397, avg valid loss:0.3055
# 	 score:0.4812(th=0.600000), auc=0.883511::: time:1774.93s
# - epoch:40 -
# Epoch: [40][0/61] Elapsed 0m 1s (remain 1m 29s) Loss: 0.3015(0.3015)
# Epoch: [40][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3604(0.3461)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1609(0.1609)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3939(0.2796)
# 	 epoch:40, avg train loss:0.3461, avg valid loss:0.2796
# 	 score:0.5172(th=0.500000), auc=0.892273::: time:1817.32s
# Epoch 40 - Save Best Score: 0.5172. Model is saved.
# dice_list:  [0.21633301158606547, 0.27024681858023636, 0.32668516072986803, 0.3818323255586476, 0.42612119699092027, 0.4606316184168185, 0.4903682725170249, 0.5075206613993488, 0.517199499760958, 0.5136753881039273, 0.4917979481949503, 0.4368286196346661, 0.35470320588979215, 0.2656187710253304, 0.1738172263884381, 0.09160551186920579, 0.025483854732395173, 2.086752672494036e-05, 0.0]
# Epoch 40 - Save Best AUC: 0.8923. Model is saved.
# - epoch:41 -
# Epoch: [41][0/61] Elapsed 0m 1s (remain 1m 16s) Loss: 0.3342(0.3342)
# Epoch: [41][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2689(0.3499)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1250(0.1250)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3952(0.2793)
# 	 epoch:41, avg train loss:0.3499, avg valid loss:0.2793
# 	 score:0.4978(th=0.500000), auc=0.880220::: time:1861.86s
# - epoch:42 -
# Epoch: [42][0/61] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2677(0.2677)
# Epoch: [42][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2821(0.3452)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1808(0.1808)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4455(0.2910)
# 	 epoch:42, avg train loss:0.3452, avg valid loss:0.2910
# 	 score:0.4661(th=0.450000), auc=0.873976::: time:1903.76s
# - epoch:43 -
# Epoch: [43][0/61] Elapsed 0m 1s (remain 1m 23s) Loss: 0.4059(0.4059)
# Epoch: [43][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2868(0.3471)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2048(0.2048)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3699(0.3100)
# 	 epoch:43, avg train loss:0.3471, avg valid loss:0.3100
# 	 score:0.4552(th=0.550000), auc=0.876321::: time:1946.08s
# - epoch:44 -
# Epoch: [44][0/61] Elapsed 0m 1s (remain 1m 19s) Loss: 0.3267(0.3267)
# Epoch: [44][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3887(0.3137)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1893(0.1893)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3766(0.3039)
# 	 epoch:44, avg train loss:0.3137, avg valid loss:0.3039
# 	 score:0.4804(th=0.600000), auc=0.888389::: time:1987.59s
# - epoch:45 -
# Epoch: [45][0/61] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2621(0.2621)
# Epoch: [45][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2072(0.3110)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1656(0.1656)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3837(0.2959)
# 	 epoch:45, avg train loss:0.3110, avg valid loss:0.2959
# 	 score:0.5042(th=0.600000), auc=0.889060::: time:2029.33s
# [fold0] slice ave score:0.5234(th=0.500000), auc=0.892401
# [fold0] BEST Epoch 40 - Save Best Score:0.5172. Best loss:0.2796
# [fold0] BEST AUC Epoch 40 - Save Best Score:0.8923. Best loss:0.2796
# -- fold1 training start --
# surface_list:  [26, 29, 32, 35]
# - epoch:1 -
# Epoch: [1][0/57] Elapsed 0m 1s (remain 1m 12s) Loss: 0.9398(0.9398)
# Epoch: [1][56/57] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2809(0.4986)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.6532(0.6532)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1029(0.4406)
# 	 epoch:1, avg train loss:0.4986, avg valid loss:0.4406
# 	 score:0.3617(th=0.350000), auc=0.747242::: time:82.42s
# Epoch 1 - Save Best Score: 0.3617. Model is saved.
# dice_list:  [0.2493238198379372, 0.2790219910203001, 0.31287599094920393, 0.33933211308334765, 0.35485114408498364, 0.3616505694408658, 0.3615853332948815, 0.35515250115138747, 0.34184764541666873, 0.32001257326773186, 0.28902202215154327, 0.24807351244501996, 0.19827168282255217, 0.14214350875085544, 0.08579817707040924, 0.03794758226799122, 0.008765299751202407, 0.00016996418942675582, 0.0]
# Epoch 1 - Save Best AUC: 0.7472. Model is saved.
# - epoch:2 -
# Epoch: [2][0/57] Elapsed 0m 1s (remain 1m 6s) Loss: 0.2761(0.2761)
# Epoch: [2][56/57] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3684(0.3972)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6965(0.6965)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1069(0.4245)
# 	 epoch:2, avg train loss:0.3972, avg valid loss:0.4245
# 	 score:0.3459(th=0.250000), auc=0.759488::: time:134.00s
# Epoch 2 - Save Best AUC: 0.7595. Model is saved.
# - epoch:3 -
# Epoch: [3][0/57] Elapsed 0m 1s (remain 1m 13s) Loss: 0.3300(0.3300)
# Epoch: [3][56/57] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1551(0.3874)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6161(0.6161)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1204(0.4068)
# 	 epoch:3, avg train loss:0.3874, avg valid loss:0.4068
# 	 score:0.4289(th=0.300000), auc=0.787206::: time:182.91s
# Epoch 3 - Save Best Score: 0.4289. Model is saved.
# dice_list:  [0.2506123042230284, 0.2997407488632199, 0.35606336228354174, 0.4037333089901001, 0.4288571126254071, 0.42744652941141764, 0.40189990755914823, 0.35821691225586316, 0.2998663956742518, 0.23029517362424404, 0.15532089951337058, 0.0860521509473197, 0.037983173756636034, 0.012626974907645807, 0.0023325469487845175, 0.00015488534483260437, 1.0807038398759133e-05, 7.204083288877418e-07, 0.0]
# Epoch 3 - Save Best AUC: 0.7872. Model is saved.
# - epoch:4 -
# Epoch: [4][0/57] Elapsed 0m 1s (remain 1m 14s) Loss: 0.3791(0.3791)
# Epoch: [4][56/57] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1775(0.3803)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5797(0.5797)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0885(0.4026)
# 	 epoch:4, avg train loss:0.3803, avg valid loss:0.4026
# 	 score:0.4328(th=0.350000), auc=0.800456::: time:233.73s
# Epoch 4 - Save Best Score: 0.4328. Model is saved.
# dice_list:  [0.25476610328909943, 0.2959683986128715, 0.33831210329510797, 0.37940809706270845, 0.4135540187189265, 0.43281312919770976, 0.42774451446741596, 0.37977292674074764, 0.2764021711351713, 0.14657918797083924, 0.05479774129941722, 0.016527048795930158, 0.005173616531169979, 0.0017750835168285598, 0.0006368570672351567, 0.00020382321697218244, 4.0343991882107776e-05, 1.4407820369088321e-06, 0.0]
# Epoch 4 - Save Best AUC: 0.8005. Model is saved.
# - epoch:5 -
# Epoch: [5][0/57] Elapsed 0m 1s (remain 1m 18s) Loss: 0.3810(0.3810)
# Epoch: [5][56/57] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4822(0.3664)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5615(0.5615)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0806(0.3916)
# 	 epoch:5, avg train loss:0.3664, avg valid loss:0.3916
# 	 score:0.4591(th=0.350000), auc=0.806745::: time:284.22s
# Epoch 5 - Save Best Score: 0.4591. Model is saved.
# dice_list:  [0.29117660426683545, 0.3468950640251574, 0.39670267516999524, 0.4319432808315424, 0.4516714726922048, 0.4590970524118027, 0.45669035676035735, 0.4432646948057063, 0.4144055857874684, 0.3623955874620403, 0.2841613331744192, 0.18808330528118672, 0.09635717945341528, 0.033165173716721834, 0.006519625177201161, 0.0005466272711788564, 1.5130606227252054e-05, 0.0, 0.0]
# Epoch 5 - Save Best AUC: 0.8067. Model is saved.
# - epoch:6 -
# Epoch: [6][0/57] Elapsed 0m 1s (remain 1m 7s) Loss: 0.2378(0.2378)
# Epoch: [6][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.1725(0.3582)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5518(0.5518)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0796(0.3910)
# 	 epoch:6, avg train loss:0.3582, avg valid loss:0.3910
# 	 score:0.4605(th=0.400000), auc=0.808633::: time:333.76s
# Epoch 6 - Save Best Score: 0.4605. Model is saved.
# dice_list:  [0.28620941663953886, 0.33593498850953196, 0.38055363671875625, 0.4147850322168336, 0.4390065710059428, 0.4541209752080735, 0.4605149424205567, 0.45798611092675295, 0.4439276079683787, 0.41288354959204593, 0.3573391929105791, 0.27338903385916685, 0.16943765451013046, 0.07445779116646742, 0.01858555313172166, 0.0019544405136356917, 4.467056977747127e-05, 0.0, 0.0]
# Epoch 6 - Save Best AUC: 0.8086. Model is saved.
# - epoch:7 -
# Epoch: [7][0/57] Elapsed 0m 1s (remain 1m 8s) Loss: 0.3607(0.3607)
# Epoch: [7][56/57] Elapsed 0m 26s (remain 0m 0s) Loss: 0.5089(0.3709)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5589(0.5589)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0887(0.3901)
# 	 epoch:7, avg train loss:0.3709, avg valid loss:0.3901
# 	 score:0.4622(th=0.350000), auc=0.811617::: time:382.98s
# Epoch 7 - Save Best Score: 0.4622. Model is saved.
# dice_list:  [0.28807917010732487, 0.3426287626549998, 0.3920292107546703, 0.42823647699472306, 0.450794946080627, 0.4621782769418987, 0.46183496768324345, 0.4429205806090074, 0.3947979677602274, 0.30883167330287936, 0.19223351474761438, 0.08213261755358707, 0.021406099006536655, 0.003432043971141456, 0.00043858088766693165, 5.619598075754353e-05, 5.043324600796198e-06, 0.0, 0.0]
# Epoch 7 - Save Best AUC: 0.8116. Model is saved.
# - epoch:8 -
# Epoch: [8][0/57] Elapsed 0m 1s (remain 1m 10s) Loss: 0.2747(0.2747)
# Epoch: [8][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.1646(0.3601)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5930(0.5930)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1109(0.3944)
# 	 epoch:8, avg train loss:0.3601, avg valid loss:0.3944
# 	 score:0.4492(th=0.300000), auc=0.811503::: time:433.22s
# - epoch:9 -
# Epoch: [9][0/57] Elapsed 0m 1s (remain 1m 12s) Loss: 0.4805(0.4805)
# Epoch: [9][56/57] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3174(0.3685)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5967(0.5967)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0993(0.4011)
# 	 epoch:9, avg train loss:0.3685, avg valid loss:0.4011
# 	 score:0.4241(th=0.350000), auc=0.802342::: time:479.20s
# - epoch:10 -
# Epoch: [10][0/57] Elapsed 0m 1s (remain 1m 11s) Loss: 0.3699(0.3699)
# Epoch: [10][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2129(0.3693)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.6666(0.6666)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0827(0.4467)
# 	 epoch:10, avg train loss:0.3693, avg valid loss:0.4467
# 	 score:0.3541(th=0.300000), auc=0.774849::: time:524.61s
# - epoch:11 -
# Epoch: [11][0/57] Elapsed 0m 1s (remain 1m 18s) Loss: 0.3891(0.3891)
# Epoch: [11][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.6813(0.3780)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6570(0.6570)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0840(0.4293)
# 	 epoch:11, avg train loss:0.3780, avg valid loss:0.4293
# 	 score:0.4608(th=0.650000), auc=0.805020::: time:569.63s
# - epoch:12 -
# Epoch: [12][0/57] Elapsed 0m 1s (remain 1m 18s) Loss: 0.3032(0.3032)
# Epoch: [12][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.6343(0.3726)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5934(0.5934)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0847(0.3939)
# 	 epoch:12, avg train loss:0.3726, avg valid loss:0.3939
# 	 score:0.4790(th=0.300000), auc=0.805440::: time:614.52s
# Epoch 12 - Save Best Score: 0.4790. Model is saved.
# dice_list:  [0.2998619532925269, 0.37872727222745, 0.43752303822427285, 0.4676650191316138, 0.4790149735772353, 0.4728547185940391, 0.4490246524153261, 0.4126026835782425, 0.36488129696245053, 0.31021058416525077, 0.2573666181942796, 0.20668742905862017, 0.1571967965959207, 0.11265822447088517, 0.07192361468571179, 0.03718657699410977, 0.010988824133226284, 0.00011167565813329938, 0.0]
# - epoch:13 -
# Epoch: [13][0/57] Elapsed 0m 1s (remain 1m 8s) Loss: 0.4934(0.4934)
# Epoch: [13][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2991(0.3732)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5786(0.5786)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1032(0.3969)
# 	 epoch:13, avg train loss:0.3732, avg valid loss:0.3969
# 	 score:0.4771(th=0.300000), auc=0.807696::: time:661.23s
# - epoch:14 -
# Epoch: [14][0/57] Elapsed 0m 1s (remain 1m 14s) Loss: 0.2928(0.2928)
# Epoch: [14][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2281(0.3551)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5734(0.5734)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0996(0.3718)
# 	 epoch:14, avg train loss:0.3551, avg valid loss:0.3718
# 	 score:0.5335(th=0.350000), auc=0.833539::: time:705.63s
# Epoch 14 - Save Best Score: 0.5335. Model is saved.
# dice_list:  [0.29405121804481255, 0.35670135695719757, 0.416220407788252, 0.4694349478925617, 0.5108366907507936, 0.5334875749197507, 0.5330237085938326, 0.5128812697138228, 0.47867338471820847, 0.43887330983134076, 0.3989105525284748, 0.3566664467071776, 0.3120055747506653, 0.261832306562955, 0.20587156082695185, 0.14221759274166043, 0.07805908067782702, 0.02841540851522983, 0.0]
# Epoch 14 - Save Best AUC: 0.8335. Model is saved.
# - epoch:15 -
# Epoch: [15][0/57] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2914(0.2914)
# Epoch: [15][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2392(0.3431)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5643(0.5643)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0961(0.3760)
# 	 epoch:15, avg train loss:0.3431, avg valid loss:0.3760
# 	 score:0.5153(th=0.400000), auc=0.827415::: time:753.64s
# surface_list:  [27, 30, 33, 36]
# - epoch:16 -
# Epoch: [16][0/57] Elapsed 0m 1s (remain 1m 11s) Loss: 0.3020(0.3020)
# Epoch: [16][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1794(0.3373)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5534(0.5534)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0978(0.3751)
# 	 epoch:16, avg train loss:0.3373, avg valid loss:0.3751
# 	 score:0.5216(th=0.450000), auc=0.829107::: time:832.66s
# - epoch:17 -
# Epoch: [17][0/57] Elapsed 0m 1s (remain 1m 13s) Loss: 0.3493(0.3493)
# Epoch: [17][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.5266(0.3436)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5412(0.5412)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0935(0.3751)
# 	 epoch:17, avg train loss:0.3436, avg valid loss:0.3751
# 	 score:0.5286(th=0.500000), auc=0.829870::: time:877.06s
# - epoch:18 -
# Epoch: [18][0/57] Elapsed 0m 1s (remain 1m 10s) Loss: 0.4574(0.4574)
# Epoch: [18][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.4926(0.3440)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5140(0.5140)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1149(0.3919)
# 	 epoch:18, avg train loss:0.3440, avg valid loss:0.3919
# 	 score:0.4989(th=0.500000), auc=0.817236::: time:921.31s
# - epoch:19 -
# Epoch: [19][0/57] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2861(0.2861)
# Epoch: [19][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1628(0.3512)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5563(0.5563)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0801(0.3813)
# 	 epoch:19, avg train loss:0.3512, avg valid loss:0.3813
# 	 score:0.4841(th=0.350000), auc=0.824552::: time:965.86s
# - epoch:20 -
# Epoch: [20][0/57] Elapsed 0m 1s (remain 1m 9s) Loss: 0.4197(0.4197)
# Epoch: [20][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.6765(0.3646)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6325(0.6325)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1114(0.3954)
# 	 epoch:20, avg train loss:0.3646, avg valid loss:0.3954
# 	 score:0.4453(th=0.300000), auc=0.816985::: time:1009.89s
# - epoch:21 -
# Epoch: [21][0/57] Elapsed 0m 1s (remain 1m 15s) Loss: 0.3377(0.3377)
# Epoch: [21][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.4120(0.3613)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5409(0.5409)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1132(0.3794)
# 	 epoch:21, avg train loss:0.3613, avg valid loss:0.3794
# 	 score:0.5001(th=0.400000), auc=0.827458::: time:1054.21s
# - epoch:22 -
# Epoch: [22][0/57] Elapsed 0m 1s (remain 1m 12s) Loss: 0.3477(0.3477)
# Epoch: [22][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2050(0.3456)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5621(0.5621)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0986(0.3790)
# 	 epoch:22, avg train loss:0.3456, avg valid loss:0.3790
# 	 score:0.5058(th=0.350000), auc=0.828312::: time:1098.33s
# - epoch:23 -
# Epoch: [23][0/57] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2145(0.2145)
# Epoch: [23][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1920(0.3401)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5218(0.5218)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0912(0.3754)
# 	 epoch:23, avg train loss:0.3401, avg valid loss:0.3754
# 	 score:0.5260(th=0.450000), auc=0.828761::: time:1142.36s
# - epoch:24 -
# Epoch: [24][0/57] Elapsed 0m 1s (remain 1m 9s) Loss: 0.3826(0.3826)
# Epoch: [24][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2862(0.3319)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5506(0.5506)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0891(0.3707)
# 	 epoch:24, avg train loss:0.3319, avg valid loss:0.3707
# 	 score:0.5383(th=0.400000), auc=0.835470::: time:1186.44s
# Epoch 24 - Save Best Score: 0.5383. Model is saved.
# dice_list:  [0.34111537170936024, 0.40667348376944695, 0.4555936713777299, 0.49468203921843107, 0.5187724352916315, 0.533450213869712, 0.5382666747041231, 0.5261741517587109, 0.4997741030204236, 0.4605091218460826, 0.4060322512804753, 0.34154110010488903, 0.2709586089294953, 0.1972145098921267, 0.11860930788919546, 0.044671664805738386, 0.005185701948361634, 1.4411081317330158e-06, 0.0]
# Epoch 24 - Save Best AUC: 0.8355. Model is saved.
# - epoch:25 -
# Epoch: [25][0/57] Elapsed 0m 1s (remain 1m 16s) Loss: 0.4149(0.4149)
# Epoch: [25][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2725(0.3295)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5464(0.5464)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0919(0.3702)
# 	 epoch:25, avg train loss:0.3295, avg valid loss:0.3702
# 	 score:0.5460(th=0.350000), auc=0.837481::: time:1234.08s
# Epoch 25 - Save Best Score: 0.5460. Model is saved.
# dice_list:  [0.34410808166143, 0.412123718619925, 0.47124111972598515, 0.5147590258209548, 0.5381929177560798, 0.5460086437322619, 0.5393538184466846, 0.5189258914915703, 0.48358702307258966, 0.43333902884442543, 0.37204331374627675, 0.3007592203664148, 0.22419462598397785, 0.15048886746087772, 0.07770193126257523, 0.01954917793718517, 0.001062632982217884, 0.0, 0.0]
# Epoch 25 - Save Best AUC: 0.8375. Model is saved.
# - epoch:26 -
# Epoch: [26][0/57] Elapsed 0m 1s (remain 1m 11s) Loss: 0.3348(0.3348)
# Epoch: [26][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.1782(0.3228)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5490(0.5490)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1011(0.3750)
# 	 epoch:26, avg train loss:0.3228, avg valid loss:0.3750
# 	 score:0.5490(th=0.350000), auc=0.833923::: time:1281.89s
# Epoch 26 - Save Best Score: 0.5490. Model is saved.
# dice_list:  [0.34030233376562335, 0.4124423118640432, 0.4745129694381267, 0.5210538525541883, 0.5466805610266021, 0.5489946440813653, 0.5301367128610535, 0.49272863197765, 0.4407707614348107, 0.3853381023324958, 0.3230545613175652, 0.25690332703117547, 0.18951182405122105, 0.11964460509767891, 0.05228300170824022, 0.012570471703825565, 0.0008345630056133775, 3.602764099397685e-06, 0.0]
# - epoch:27 -
# Epoch: [27][0/57] Elapsed 0m 1s (remain 1m 18s) Loss: 0.4321(0.4321)
# Epoch: [27][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2835(0.3274)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5717(0.5717)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0909(0.3672)
# 	 epoch:27, avg train loss:0.3274, avg valid loss:0.3672
# 	 score:0.5436(th=0.400000), auc=0.839910::: time:1328.60s
# Epoch 27 - Save Best AUC: 0.8399. Model is saved.
# - epoch:28 -
# Epoch: [28][0/57] Elapsed 0m 1s (remain 1m 12s) Loss: 0.3914(0.3914)
# Epoch: [28][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.3874(0.3246)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5418(0.5418)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0876(0.3662)
# 	 epoch:28, avg train loss:0.3246, avg valid loss:0.3662
# 	 score:0.5434(th=0.500000), auc=0.840774::: time:1374.53s
# Epoch 28 - Save Best AUC: 0.8408. Model is saved.
# - epoch:29 -
# Epoch: [29][0/57] Elapsed 0m 1s (remain 1m 17s) Loss: 0.4373(0.4373)
# Epoch: [29][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2785(0.3288)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5371(0.5371)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1137(0.4140)
# 	 epoch:29, avg train loss:0.3288, avg valid loss:0.4140
# 	 score:0.4445(th=0.500000), auc=0.809784::: time:1420.37s
# - epoch:30 -
# Epoch: [30][0/57] Elapsed 0m 1s (remain 1m 14s) Loss: 0.4800(0.4800)
# Epoch: [30][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.3101(0.3454)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5460(0.5460)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0913(0.3652)
# 	 epoch:30, avg train loss:0.3454, avg valid loss:0.3652
# 	 score:0.5219(th=0.400000), auc=0.843532::: time:1464.65s
# Epoch 30 - Save Best AUC: 0.8435. Model is saved.
# surface_list:  [25, 28, 31, 34]
# - epoch:31 -
# Epoch: [31][0/57] Elapsed 0m 1s (remain 1m 14s) Loss: 0.2975(0.2975)
# Epoch: [31][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2337(0.3388)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6301(0.6301)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0971(0.4758)
# 	 epoch:31, avg train loss:0.3388, avg valid loss:0.4758
# 	 score:0.4638(th=0.750000), auc=0.802342::: time:1546.11s
# - epoch:32 -
# Epoch: [32][0/57] Elapsed 0m 1s (remain 1m 15s) Loss: 0.3678(0.3678)
# Epoch: [32][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2050(0.4126)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.6518(0.6518)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1285(0.4584)
# 	 epoch:32, avg train loss:0.4126, avg valid loss:0.4584
# 	 score:0.3363(th=0.350000), auc=0.744471::: time:1591.17s
# - epoch:33 -
# Epoch: [33][0/57] Elapsed 0m 1s (remain 1m 12s) Loss: 0.3882(0.3882)
# Epoch: [33][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2190(0.3757)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6234(0.6234)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0925(0.4148)
# 	 epoch:33, avg train loss:0.3757, avg valid loss:0.4148
# 	 score:0.4423(th=0.350000), auc=0.785252::: time:1636.32s
# - epoch:34 -
# Epoch: [34][0/57] Elapsed 0m 1s (remain 1m 13s) Loss: 0.2934(0.2934)
# Epoch: [34][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2176(0.3514)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5879(0.5879)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1114(0.4008)
# 	 epoch:34, avg train loss:0.3514, avg valid loss:0.4008
# 	 score:0.4694(th=0.400000), auc=0.806160::: time:1681.23s
# - epoch:35 -
# Epoch: [35][0/57] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2553(0.2553)
# Epoch: [35][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.5889(0.3505)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5977(0.5977)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1081(0.3882)
# 	 epoch:35, avg train loss:0.3505, avg valid loss:0.3882
# 	 score:0.4891(th=0.400000), auc=0.816589::: time:1726.25s
# - epoch:36 -
# Epoch: [36][0/57] Elapsed 0m 1s (remain 1m 16s) Loss: 0.3673(0.3673)
# Epoch: [36][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.3233(0.3375)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5928(0.5928)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0987(0.3868)
# 	 epoch:36, avg train loss:0.3375, avg valid loss:0.3868
# 	 score:0.4840(th=0.450000), auc=0.816106::: time:1771.32s
# - epoch:37 -
# Epoch: [37][0/57] Elapsed 0m 1s (remain 1m 12s) Loss: 0.4395(0.4395)
# Epoch: [37][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2871(0.3377)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6328(0.6328)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0994(0.4068)
# 	 epoch:37, avg train loss:0.3377, avg valid loss:0.4068
# 	 score:0.4585(th=0.400000), auc=0.798841::: time:1816.12s
# - epoch:38 -
# Epoch: [38][0/57] Elapsed 0m 1s (remain 1m 9s) Loss: 0.2677(0.2677)
# Epoch: [38][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2992(0.3407)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6155(0.6155)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1028(0.3937)
# 	 epoch:38, avg train loss:0.3407, avg valid loss:0.3937
# 	 score:0.4841(th=0.400000), auc=0.810979::: time:1860.43s
# - epoch:39 -
# Epoch: [39][0/57] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2646(0.2646)
# Epoch: [39][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.4534(0.3390)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6728(0.6728)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1011(0.4052)
# 	 epoch:39, avg train loss:0.3390, avg valid loss:0.4052
# 	 score:0.4723(th=0.350000), auc=0.799823::: time:1905.02s
# - epoch:40 -
# Epoch: [40][0/57] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2711(0.2711)
# Epoch: [40][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.3964(0.3545)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.6379(0.6379)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0963(0.3948)
# 	 epoch:40, avg train loss:0.3545, avg valid loss:0.3948
# 	 score:0.4997(th=0.350000), auc=0.808678::: time:1949.60s
# - epoch:41 -
# Epoch: [41][0/57] Elapsed 0m 1s (remain 1m 16s) Loss: 0.2794(0.2794)
# Epoch: [41][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2315(0.3382)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5900(0.5900)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0905(0.3744)
# 	 epoch:41, avg train loss:0.3382, avg valid loss:0.3744
# 	 score:0.5006(th=0.450000), auc=0.835572::: time:1994.46s
# - epoch:42 -
# Epoch: [42][0/57] Elapsed 0m 1s (remain 1m 12s) Loss: 0.4332(0.4332)
# Epoch: [42][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.8316(0.3450)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5471(0.5471)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0889(0.4032)
# 	 epoch:42, avg train loss:0.3450, avg valid loss:0.4032
# 	 score:0.4951(th=0.550000), auc=0.819775::: time:2039.51s
# - epoch:43 -
# Epoch: [43][0/57] Elapsed 0m 1s (remain 1m 16s) Loss: 0.3218(0.3218)
# Epoch: [43][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2943(0.3321)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5811(0.5811)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0963(0.4206)
# 	 epoch:43, avg train loss:0.3321, avg valid loss:0.4206
# 	 score:0.5030(th=0.650000), auc=0.830310::: time:2084.10s
# - epoch:44 -
# Epoch: [44][0/57] Elapsed 0m 1s (remain 1m 17s) Loss: 0.3118(0.3118)
# Epoch: [44][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2214(0.3226)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6841(0.6841)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0995(0.4013)
# 	 epoch:44, avg train loss:0.3226, avg valid loss:0.4013
# 	 score:0.4858(th=0.350000), auc=0.809617::: time:2129.08s
# - epoch:45 -
# Epoch: [45][0/57] Elapsed 0m 1s (remain 1m 17s) Loss: 0.1853(0.1853)
# Epoch: [45][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2033(0.3282)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5329(0.5329)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0931(0.3713)
# 	 epoch:45, avg train loss:0.3282, avg valid loss:0.3713
# 	 score:0.5174(th=0.500000), auc=0.839100::: time:2173.96s
# [fold1] slice ave score:0.5496(th=0.400000), auc=0.852742
# [fold1] BEST Epoch 26 - Save Best Score:0.5490. Best loss:0.3750
# [fold1] BEST AUC Epoch 30 - Save Best Score:0.8435. Best loss:0.3652
# ...
# - epoch:12 -
# Epoch: [12][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.3089(0.3089)
# Epoch: [12][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3215(0.3702)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2180(0.2180)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3891(0.4110)
# 	 epoch:12, avg train loss:0.3702, avg valid loss:0.4110
# 	 score:0.4368(th=0.550000), auc=0.870348::: time:613.07s
# Epoch 12 - Save Best Score: 0.4368. Model is saved.
# dice_list:  [0.27095103987346, 0.2965606739369504, 0.3193198822033113, 0.34209209330691104, 0.3647168115716039, 0.3868965360375646, 0.4067573547383948, 0.42283292289618707, 0.4327089552925496, 0.4367516386389315, 0.43414421801802744, 0.4192027408627801, 0.3869680370046572, 0.333226249242761, 0.2510966949814576, 0.1455330317259613, 0.0479268069965057, 0.000315526417302739, 0.0]
# Epoch 12 - Save Best AUC: 0.8703. Model is saved.
# - epoch:13 -
# Epoch: [13][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.4170(0.4170)
# Epoch: [13][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4017(0.3589)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2361(0.2361)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4089(0.3797)
# 	 epoch:13, avg train loss:0.3589, avg valid loss:0.3797
# 	 score:0.4738(th=0.400000), auc=0.875538::: time:662.26s
# Epoch 13 - Save Best Score: 0.4738. Model is saved.
# dice_list:  [0.301370979611598, 0.3353664468189205, 0.3685882658009161, 0.40236824404361016, 0.4349395855450263, 0.45917844821605075, 0.4737546620620279, 0.46830481792729883, 0.4369581126215807, 0.3754779098556042, 0.2862727254634203, 0.19155742928654867, 0.10710087590141788, 0.04518311696810515, 0.0113404079884197, 0.0010464625421624475, 1.6907504957354887e-05, 0.0, 0.0]
# Epoch 13 - Save Best AUC: 0.8755. Model is saved.
# - epoch:14 -
# Epoch: [14][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2310(0.2310)
# Epoch: [14][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3216(0.3512)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2111(0.2111)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3818(0.3733)
# 	 epoch:14, avg train loss:0.3512, avg valid loss:0.3733
# 	 score:0.4961(th=0.500000), auc=0.884315::: time:710.74s
# Epoch 14 - Save Best Score: 0.4961. Model is saved.
# dice_list:  [0.28750630308409025, 0.32136679478006586, 0.35993294103287987, 0.3950008243135272, 0.4259064923998469, 0.4537774496301859, 0.47675111624250816, 0.4919387661103505, 0.4960596766474878, 0.48389784122066976, 0.45025198040800685, 0.40586304915603494, 0.34650004380203986, 0.27011554148165723, 0.17426658173001877, 0.09176427832457605, 0.03101951639657186, 0.00010895145303705379, 0.0]
# Epoch 14 - Save Best AUC: 0.8843. Model is saved.
# - epoch:15 -
# Epoch: [15][0/60] Elapsed 0m 1s (remain 1m 23s) Loss: 0.3055(0.3055)
# Epoch: [15][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2701(0.3272)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2044(0.2044)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3773(0.3757)
# 	 epoch:15, avg train loss:0.3272, avg valid loss:0.3757
# 	 score:0.4902(th=0.500000), auc=0.884385::: time:759.12s
# Epoch 15 - Save Best AUC: 0.8844. Model is saved.
# surface_list:  [27, 30, 33, 36]
# - epoch:16 -
# Epoch: [16][0/60] Elapsed 0m 1s (remain 1m 12s) Loss: 0.3911(0.3911)
# Epoch: [16][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4805(0.3398)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2091(0.2091)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3674(0.3709)
# 	 epoch:16, avg train loss:0.3398, avg valid loss:0.3709
# 	 score:0.4884(th=0.500000), auc=0.886715::: time:839.72s
# Epoch 16 - Save Best AUC: 0.8867. Model is saved.
# - epoch:17 -
# Epoch: [17][0/60] Elapsed 0m 1s (remain 1m 14s) Loss: 0.2516(0.2516)
# Epoch: [17][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4443(0.3366)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2024(0.2024)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3692(0.3784)
# 	 epoch:17, avg train loss:0.3366, avg valid loss:0.3784
# 	 score:0.4861(th=0.550000), auc=0.884590::: time:886.87s
# - epoch:18 -
# Epoch: [18][0/60] Elapsed 0m 1s (remain 1m 21s) Loss: 0.2478(0.2478)
# Epoch: [18][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4092(0.3367)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2140(0.2140)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3865(0.4232)
# 	 epoch:18, avg train loss:0.3367, avg valid loss:0.4232
# 	 score:0.4688(th=0.650000), auc=0.878254::: time:932.11s
# - epoch:19 -
# Epoch: [19][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.3693(0.3693)
# Epoch: [19][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2222(0.3484)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2110(0.2110)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4018(0.4734)
# 	 epoch:19, avg train loss:0.3484, avg valid loss:0.4734
# 	 score:0.4299(th=0.650000), auc=0.866735::: time:977.68s
# - epoch:20 -
# Epoch: [20][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.3792(0.3792)
# Epoch: [20][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3242(0.3431)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2110(0.2110)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4028(0.4084)
# 	 epoch:20, avg train loss:0.3431, avg valid loss:0.4084
# 	 score:0.4313(th=0.450000), auc=0.861750::: time:1023.06s
# - epoch:21 -
# Epoch: [21][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2572(0.2572)
# Epoch: [21][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.5885(0.3574)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2418(0.2418)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3892(0.4419)
# 	 epoch:21, avg train loss:0.3574, avg valid loss:0.4419
# 	 score:0.4123(th=0.500000), auc=0.865154::: time:1067.98s
# - epoch:22 -
# Epoch: [22][0/60] Elapsed 0m 1s (remain 1m 22s) Loss: 0.3913(0.3913)
# Epoch: [22][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2612(0.3492)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2697(0.2697)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4512(0.4178)
# 	 epoch:22, avg train loss:0.3492, avg valid loss:0.4178
# 	 score:0.4291(th=0.550000), auc=0.867651::: time:1113.37s
# - epoch:23 -
# Epoch: [23][0/60] Elapsed 0m 1s (remain 1m 23s) Loss: 0.3505(0.3505)
# Epoch: [23][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3307(0.3438)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2284(0.2284)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3909(0.3931)
# 	 epoch:23, avg train loss:0.3438, avg valid loss:0.3931
# 	 score:0.4624(th=0.550000), auc=0.877909::: time:1158.14s
# - epoch:24 -
# Epoch: [24][0/60] Elapsed 0m 1s (remain 1m 22s) Loss: 0.3298(0.3298)
# Epoch: [24][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1708(0.3245)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2553(0.2553)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4371(0.4462)
# 	 epoch:24, avg train loss:0.3245, avg valid loss:0.4462
# 	 score:0.3818(th=0.650000), auc=0.857101::: time:1202.29s
# - epoch:25 -
# Epoch: [25][0/60] Elapsed 0m 1s (remain 1m 12s) Loss: 0.3154(0.3154)
# Epoch: [25][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2977(0.3222)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2136(0.2136)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4186(0.4283)
# 	 epoch:25, avg train loss:0.3222, avg valid loss:0.4283
# 	 score:0.4345(th=0.650000), auc=0.874604::: time:1247.29s
# - epoch:26 -
# Epoch: [26][0/60] Elapsed 0m 1s (remain 1m 14s) Loss: 0.4362(0.4362)
# Epoch: [26][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2234(0.3208)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2151(0.2151)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4150(0.4167)
# 	 epoch:26, avg train loss:0.3208, avg valid loss:0.4167
# 	 score:0.4370(th=0.600000), auc=0.873866::: time:1292.02s
# - epoch:27 -
# Epoch: [27][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.3929(0.3929)
# Epoch: [27][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3330(0.3191)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2197(0.2197)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4322(0.4239)
# 	 epoch:27, avg train loss:0.3191, avg valid loss:0.4239
# 	 score:0.4261(th=0.600000), auc=0.865393::: time:1336.98s
# - epoch:28 -
# Epoch: [28][0/60] Elapsed 0m 1s (remain 1m 16s) Loss: 0.2129(0.2129)
# Epoch: [28][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4939(0.3266)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2146(0.2146)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3994(0.4044)
# 	 epoch:28, avg train loss:0.3266, avg valid loss:0.4044
# 	 score:0.4368(th=0.550000), auc=0.876200::: time:1381.92s
# - epoch:29 -
# Epoch: [29][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2102(0.2102)
# Epoch: [29][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4593(0.3229)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2309(0.2309)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4309(0.4064)
# 	 epoch:29, avg train loss:0.3229, avg valid loss:0.4064
# 	 score:0.3870(th=0.450000), auc=0.858732::: time:1427.28s
# - epoch:30 -
# Epoch: [30][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.3098(0.3098)
# Epoch: [30][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3438(0.3346)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2491(0.2491)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4168(0.4247)
# 	 epoch:30, avg train loss:0.3346, avg valid loss:0.4247
# 	 score:0.3908(th=0.500000), auc=0.859742::: time:1472.42s
# surface_list:  [25, 28, 31, 34]
# - epoch:31 -
# Epoch: [31][0/60] Elapsed 0m 1s (remain 1m 16s) Loss: 0.2188(0.2188)
# Epoch: [31][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2422(0.3442)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2701(0.2701)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4106(0.3973)
# 	 epoch:31, avg train loss:0.3442, avg valid loss:0.3973
# 	 score:0.4108(th=0.450000), auc=0.868040::: time:1551.35s
# - epoch:32 -
# Epoch: [32][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2854(0.2854)
# Epoch: [32][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2393(0.3411)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2332(0.2332)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3844(0.4064)
# 	 epoch:32, avg train loss:0.3411, avg valid loss:0.4064
# 	 score:0.4363(th=0.550000), auc=0.866058::: time:1596.41s
# - epoch:33 -
# Epoch: [33][0/60] Elapsed 0m 1s (remain 1m 22s) Loss: 0.3403(0.3403)
# Epoch: [33][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3056(0.3295)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2313(0.2313)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3862(0.4074)
# 	 epoch:33, avg train loss:0.3295, avg valid loss:0.4074
# 	 score:0.4278(th=0.650000), auc=0.871080::: time:1641.23s
# - epoch:34 -
# Epoch: [34][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.4335(0.4335)
# Epoch: [34][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3006(0.3167)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2554(0.2554)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3837(0.3963)
# 	 epoch:34, avg train loss:0.3167, avg valid loss:0.3963
# 	 score:0.4062(th=0.500000), auc=0.863340::: time:1686.47s
# - epoch:35 -
# Epoch: [35][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.4920(0.4920)
# Epoch: [35][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3709(0.3108)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2382(0.2382)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3836(0.3898)
# 	 epoch:35, avg train loss:0.3108, avg valid loss:0.3898
# 	 score:0.4399(th=0.550000), auc=0.872701::: time:1731.91s
# - epoch:36 -
# Epoch: [36][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2526(0.2526)
# Epoch: [36][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2957(0.3056)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2324(0.2324)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3884(0.3983)
# 	 epoch:36, avg train loss:0.3056, avg valid loss:0.3983
# 	 score:0.4392(th=0.600000), auc=0.872749::: time:1777.33s
# - epoch:37 -
# Epoch: [37][0/60] Elapsed 0m 1s (remain 1m 11s) Loss: 0.3082(0.3082)
# Epoch: [37][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.7348(0.3154)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2349(0.2349)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3793(0.4023)
# 	 epoch:37, avg train loss:0.3154, avg valid loss:0.4023
# 	 score:0.4367(th=0.650000), auc=0.872632::: time:1822.05s
# - epoch:38 -
# Epoch: [38][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2530(0.2530)
# Epoch: [38][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4272(0.3007)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2514(0.2514)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4007(0.4089)
# 	 epoch:38, avg train loss:0.3007, avg valid loss:0.4089
# 	 score:0.3982(th=0.550000), auc=0.863679::: time:1866.77s
# - epoch:39 -
# Epoch: [39][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.3566(0.3566)
# Epoch: [39][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3214(0.3143)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2617(0.2617)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3981(0.4017)
# 	 epoch:39, avg train loss:0.3143, avg valid loss:0.4017
# 	 score:0.3978(th=0.450000), auc=0.865789::: time:1911.67s
# - epoch:40 -
# Epoch: [40][0/60] Elapsed 0m 1s (remain 1m 22s) Loss: 0.2759(0.2759)
# Epoch: [40][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3860(0.3258)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2474(0.2474)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4108(0.5006)
# 	 epoch:40, avg train loss:0.3258, avg valid loss:0.5006
# 	 score:0.3818(th=0.700000), auc=0.866461::: time:1956.22s
# - epoch:41 -
# Epoch: [41][0/60] Elapsed 0m 1s (remain 1m 14s) Loss: 0.4529(0.4529)
# Epoch: [41][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2920(0.3315)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2605(0.2605)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3937(0.3923)
# 	 epoch:41, avg train loss:0.3315, avg valid loss:0.3923
# 	 score:0.4119(th=0.450000), auc=0.870721::: time:2001.08s
# - epoch:42 -
# Epoch: [42][0/60] Elapsed 0m 1s (remain 1m 23s) Loss: 0.4017(0.4017)
# Epoch: [42][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3899(0.3290)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2809(0.2809)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4159(0.3942)
# 	 epoch:42, avg train loss:0.3290, avg valid loss:0.3942
# 	 score:0.4328(th=0.350000), auc=0.871287::: time:2046.21s
# - epoch:43 -
# Epoch: [43][0/60] Elapsed 0m 1s (remain 1m 25s) Loss: 0.4418(0.4418)
# Epoch: [43][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2568(0.3258)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2729(0.2729)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3958(0.4178)
# 	 epoch:43, avg train loss:0.3258, avg valid loss:0.4178
# 	 score:0.3798(th=0.500000), auc=0.855345::: time:2090.89s
# - epoch:44 -
# Epoch: [44][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.3129(0.3129)
# Epoch: [44][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3378(0.3057)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2616(0.2616)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4327(0.4074)
# 	 epoch:44, avg train loss:0.3057, avg valid loss:0.4074
# 	 score:0.4370(th=0.550000), auc=0.861547::: time:2136.09s
# - epoch:45 -
# Epoch: [45][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2501(0.2501)
# Epoch: [45][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1806(0.2941)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2602(0.2602)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4121(0.4032)
# 	 epoch:45, avg train loss:0.2941, avg valid loss:0.4032
# 	 score:0.4213(th=0.500000), auc=0.863045::: time:2180.95s
# [fold4] slice ave score:0.4787(th=0.500000), auc=0.878488
# [fold4] BEST Epoch 14 - Save Best Score:0.4961. Best loss:0.3733
# [fold4] BEST AUC Epoch 16 - Save Best Score:0.8867. Best loss:0.3709
# fold[0] BEST SCORE = 0.5172 thr=0.5 (epoch=40)
# fold[0] slice ave score:0.5234(th=0.500000), auc=0.892401
# fold[1] BEST SCORE = 0.5490 thr=0.35 (epoch=26)
# fold[1] slice ave score:0.5496(th=0.400000), auc=0.852742
# fold[2] BEST SCORE = 0.5306 thr=0.55 (epoch=37)
# fold[2] slice ave score:0.5308(th=0.450000), auc=0.836874
# fold[3] BEST SCORE = 0.4984 thr=0.55 (epoch=18)
# fold[3] slice ave score:0.4755(th=0.450000), auc=0.921515
# fold[4] BEST SCORE = 0.4961 thr=0.5 (epoch=14)
# fold[4] slice ave score:0.4787(th=0.500000), auc=0.878488
# CPU times: user 2h 6min 23s, sys: 46min 1s, total: 2h 52min 24s
# Wall time: 2h 58min 54s

# %% [markdown]
# ---
# # OOF SCORE INFER

# %%
# %%time
slice_ave_score_list, slice_ave_score_threshold_list, slice_ave_auc_list = slide_inference(CFG)
for fold in CFG["folds"]:
    print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    wandb.log({"OOF SCORE" : {f"slice average score":slice_ave_score_list[fold],
                            f"slice average threshold":slice_ave_score_threshold_list[fold],
                            f"slice_average auc":slice_ave_auc_list[fold],
                            }})
# Out:
# -- fold0 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.5205(th=0.500000), auc=0.892419::: time:25.73s
# slide pos: [256, 0]
# 	 score:0.2714(th=0.350000), auc=0.830224::: time:43.46s
# slide pos: [0, 256]
# 	 score:0.5064(th=0.450000), auc=0.896667::: time:60.76s
# slide pos: [256, 256]
# 	 score:0.2850(th=0.350000), auc=0.834207::: time:78.08s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.5241(th=0.450000), auc=0.892565::: time:103.14s
# slide pos: [256, 0]
# 	 score:0.2699(th=0.350000), auc=0.826556::: time:120.50s
# slide pos: [0, 256]
# 	 score:0.4985(th=0.450000), auc=0.895989::: time:137.88s
# slide pos: [256, 256]
# 	 score:0.2755(th=0.300000), auc=0.832759::: time:154.98s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.5172(th=0.500000), auc=0.892273::: time:179.74s
# slide pos: [256, 0]
# 	 score:0.2799(th=0.400000), auc=0.830241::: time:197.44s
# slide pos: [0, 256]
# 	 score:0.5048(th=0.450000), auc=0.897421::: time:214.14s
# slide pos: [256, 256]
# 	 score:0.2843(th=0.350000), auc=0.834140::: time:231.24s
# [fold0] slice ave score:0.4723(th=0.400000), auc=0.889336
# -- fold1 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.5198(th=0.400000), auc=0.846248::: time:273.13s
# slide pos: [256, 0]
# 	 score:0.3505(th=0.200000), auc=0.787069::: time:295.34s
# slide pos: [0, 256]
# 	 score:0.5109(th=0.400000), auc=0.837424::: time:319.36s
# slide pos: [256, 256]
# 	 score:0.3591(th=0.200000), auc=0.784380::: time:342.18s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.5219(th=0.400000), auc=0.843532::: time:369.17s
# slide pos: [256, 0]
# 	 score:0.3595(th=0.200000), auc=0.791362::: time:391.56s
# slide pos: [0, 256]
# 	 score:0.5065(th=0.400000), auc=0.836436::: time:415.10s
# slide pos: [256, 256]
# 	 score:0.3570(th=0.200000), auc=0.787927::: time:438.52s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.5111(th=0.350000), auc=0.844322::: time:466.14s
# slide pos: [256, 0]
# 	 score:0.3492(th=0.200000), auc=0.782657::: time:488.53s
# slide pos: [0, 256]
# 	 score:0.5101(th=0.350000), auc=0.837536::: time:511.38s
# slide pos: [256, 256]
# 	 score:0.3597(th=0.200000), auc=0.781525::: time:533.77s
# [fold1] slice ave score:0.4786(th=0.300000), auc=0.834451
# -- fold2 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.5112(th=0.500000), auc=0.833396::: time:577.50s
# slide pos: [256, 0]
# 	 score:0.3329(th=0.300000), auc=0.770518::: time:600.14s
# slide pos: [0, 256]
# 	 score:0.4970(th=0.550000), auc=0.832600::: time:622.62s
# slide pos: [256, 256]
# 	 score:0.3301(th=0.250000), auc=0.771931::: time:645.46s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.5130(th=0.500000), auc=0.838378::: time:671.81s
# slide pos: [256, 0]
# 	 score:0.3279(th=0.250000), auc=0.767622::: time:694.47s
# slide pos: [0, 256]
# 	 score:0.5099(th=0.550000), auc=0.837033::: time:717.26s
# slide pos: [256, 256]
# 	 score:0.3233(th=0.300000), auc=0.767352::: time:740.16s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.5034(th=0.500000), auc=0.827158::: time:767.32s
# slide pos: [256, 0]
# 	 score:0.3336(th=0.250000), auc=0.770540::: time:790.16s
# slide pos: [0, 256]
# 	 score:0.4933(th=0.500000), auc=0.827853::: time:812.46s
# slide pos: [256, 256]
# 	 score:0.3349(th=0.250000), auc=0.772784::: time:835.32s
# [fold2] slice ave score:0.4621(th=0.400000), auc=0.809835
# -- fold3 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.4780(th=0.600000), auc=0.919495::: time:875.09s
# slide pos: [256, 0]
# 	 score:0.3611(th=0.450000), auc=0.892330::: time:893.10s
# slide pos: [0, 256]
# 	 score:0.4961(th=0.550000), auc=0.917684::: time:910.88s
# slide pos: [256, 256]
# 	 score:0.3805(th=0.450000), auc=0.891859::: time:929.08s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.4881(th=0.600000), auc=0.922660::: time:949.81s
# slide pos: [256, 0]
# 	 score:0.3561(th=0.450000), auc=0.893612::: time:967.54s
# slide pos: [0, 256]
# 	 score:0.5028(th=0.550000), auc=0.921157::: time:985.76s
# slide pos: [256, 256]
# 	 score:0.3837(th=0.450000), auc=0.893869::: time:1004.31s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.4625(th=0.550000), auc=0.915137::: time:1026.02s
# slide pos: [256, 0]
# 	 score:0.3547(th=0.450000), auc=0.889275::: time:1043.39s
# slide pos: [0, 256]
# 	 score:0.4828(th=0.550000), auc=0.912311::: time:1061.30s
# slide pos: [256, 256]
# 	 score:0.3599(th=0.450000), auc=0.888289::: time:1079.05s
# [fold3] slice ave score:0.4863(th=0.500000), auc=0.913332
# -- fold4 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.4909(th=0.450000), auc=0.884036::: time:1125.75s
# slide pos: [256, 0]
# 	 score:0.4324(th=0.200000), auc=0.877445::: time:1147.92s
# slide pos: [0, 256]
# 	 score:0.4740(th=0.450000), auc=0.883154::: time:1169.37s
# slide pos: [256, 256]
# 	 score:0.4278(th=0.200000), auc=0.873845::: time:1191.30s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.4884(th=0.500000), auc=0.886715::: time:1221.60s
# slide pos: [256, 0]
# 	 score:0.4252(th=0.200000), auc=0.876919::: time:1242.50s
# slide pos: [0, 256]
# 	 score:0.4812(th=0.500000), auc=0.885615::: time:1263.78s
# slide pos: [256, 256]
# 	 score:0.4241(th=0.200000), auc=0.874367::: time:1285.18s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.4901(th=0.450000), auc=0.880623::: time:1315.99s
# slide pos: [256, 0]
# 	 score:0.4217(th=0.200000), auc=0.871477::: time:1336.92s
# slide pos: [0, 256]
# 	 score:0.4777(th=0.450000), auc=0.878186::: time:1358.01s
# slide pos: [256, 256]
# 	 score:0.4227(th=0.200000), auc=0.869586::: time:1380.23s
# [fold4] slice ave score:0.5036(th=0.300000), auc=0.892813
# fold[0] slice ave score:0.4723(th=0.889336), auc=0.400000
# fold[1] slice ave score:0.4786(th=0.834451), auc=0.300000
# fold[2] slice ave score:0.4621(th=0.809835), auc=0.400000
# fold[3] slice ave score:0.4863(th=0.913332), auc=0.500000
# fold[4] slice ave score:0.5036(th=0.892813), auc=0.300000
# CPU times: user 18min 28s, sys: 3min 24s, total: 21min 53s
# Wall time: 23min 16s

# %%
import yaml
with open(os.path.join(CFG["OUTPUT_DIR"], "Config.yaml"), "w") as f:
    yaml.dump(CFG, f)

# %%
if not CFG["DEBUG"]:
    wandb.finish()
