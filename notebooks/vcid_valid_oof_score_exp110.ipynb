# %%
import gc
import os
import random
import time
import math

import cv2
import numpy as np
import matplotlib.pyplot as plt

# model
import torch
import torchvision
import torch.nn as nn
import timm
from torchvision.models.feature_extraction import create_feature_extractor
import torchvision.transforms.functional as TF

# data loader
import albumentations as A
from albumentations.pytorch import ToTensorV2
from torch.utils.data import DataLoader, Dataset

# training
from torch.optim import SGD, Adam, AdamW
from torch.optim.lr_scheduler import CosineAnnealingLR, CosineAnnealingWarmRestarts, ReduceLROnPlateau, ExponentialLR

# metric
from sklearn.metrics import fbeta_score, roc_auc_score

import wandb

# %% [markdown]
# # config

# %%
import yaml
OUTPUT_DIR = "/working/output" 
EXP_NAME = "exp110"
with open(os.path.join(OUTPUT_DIR, EXP_NAME, "Config.yaml")) as file:
    CFG = yaml.safe_load(file)
print(CFG)
CFG["OUTPUT_DIR"] = os.path.join(OUTPUT_DIR, EXP_NAME)
# Out:
# {'EXP_CATEGORY': 'ADDROT', 'INPUT_DIR': '/working/input/vesuvius-challenge-ink-detection', 'RANDOM_SLIDE': True, 'TRAIN_DIR': '/working/input/vesuvius-challenge-ink-detection/train', 'TRAIN_DIR_LIST': [['1', '2_0', '2_1', '2_2'], ['1', '2_0', '2_1', '3'], ['1', '2_0', '2_2', '3'], ['1', '2_1', '2_2', '3'], ['2_0', '2_1', '2_2', '3']], 'T_max': 5, 'VALID_DIR_LIST': [['3'], ['2_2'], ['2_1'], ['2_0'], ['1']], 'batch_size': 8, 'folds': [0, 1, 2, 3, 4], 'img_size': [256, 256], 'input_img_size': [512, 512], 'inp_channels': 4, 'lr': 0.001, 'min_lr': 5e-05, 'model_name': 'tf_efficientnet_b6', 'channel_nums': [576, 200, 72, 40, 32], 'n_epoch': 5, 'num_workers': 2, 'out_channels': 1, 'out_indices': [0, 1, 2, 3, 4], 'pretrained': True, 'print_freq': 1000, 'random_seed': 21, 'slide_pos_list': [[0, 0], [128, 0], [0, 128], [128, 128]], 'SURFACE_LIST': [[30, 33, 36, 39], [25, 28, 31, 34], [28, 31, 34, 37]], 'TRAIN_SURFACE_LIST': [[25, 28, 31, 34], [30, 33, 36, 39], [28, 31, 34, 37]], 'surface_num': 4, 'weight_decay': 1e-06, 'rot90_num': [1, 3, 0, 2]}

# %% [markdown]
# # utils

# %%
def seed_everything(seed=CFG["random_seed"]):
    #os.environ['PYTHONSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic =True
    torch.backends.cudnn.benchmark = False
seed_everything()

# device optimization
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
def asMinutes(s):
    """Convert Seconds to Minutes."""
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    """Accessing and Converting Time Data."""
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))

class AverageMeter(object):
    """Computes and stores the average and current value."""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# # metric

# %%
def fbeta_numpy(targets, preds, beta=0.5, smooth=1e-5):
    y_true_count = targets.sum()
    ctp = preds[targets==1].sum()
    cfp = preds[targets==0].sum()
    beta_squared = beta * beta

    c_precision = ctp / (ctp + cfp + smooth)
    c_recall = ctp / (y_true_count + smooth)
    dice = (1 + beta_squared) * (c_precision * c_recall) / (beta_squared * c_precision + c_recall + smooth)

    return dice

def calc_fbeta_auc(mask, mask_pred):
    mask = mask.astype(int).flatten()
    mask_pred = mask_pred.flatten()

    best_th = 0
    best_dice = 0
    dice_list = [] 
    # for th in np.array(range(10, 50+1, 5)) / 100:
    for th in np.array(range(10, 100+1, 5)) / 100:
        # dice = fbeta_score(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice = fbeta_numpy(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice_list.append(dice)
        # print(f'\t th: {th}, fbeta: {dice}')
        if dice > best_dice:
            best_dice = dice
            best_th = th
    
    auc = roc_auc_score(mask, mask_pred)
    # Logger.info(f'best_th: {best_th}, fbeta: {best_dice}')
    return best_dice, best_th, auc, dice_list


def calc_cv(mask_gt, mask_pred):
    best_dice, best_th, auc, dice_list = calc_fbeta_auc(mask_gt, mask_pred)

    return best_dice, best_th, auc, dice_list

# %% [markdown]
# # model

# %%
class Encoder(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = timm.create_model(CFG["model_name"], in_chans=CFG["inp_channels"], 
                                         features_only=True, out_indices=CFG["out_indices"], pretrained=CFG["pretrained"])
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        return skip_connection_list

class UpConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.bn1 = nn.BatchNorm2d(in_channels)
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size = 2, padding="same")
        self.bn2 = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        x = self.up(x)
        x = self.bn1(x)
        x = self.conv(x)
        x = self.bn2(x)
        return x


#下に1層を使わない
class Decoder(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.UpConv_0 = UpConv(CFG["channel_nums"][0], CFG["channel_nums"][1])
        self.UpConv_1 = UpConv(CFG["channel_nums"][1]*2, CFG["channel_nums"][2])
        self.UpConv_2 = UpConv(CFG["channel_nums"][2]*2, CFG["channel_nums"][3])
        self.UpConv_3 = UpConv(CFG["channel_nums"][3]*2, CFG["channel_nums"][4])
    
    def forward(self, skip_connection_list):
        emb = self.UpConv_0(skip_connection_list[-1])
        emb_cat = torch.cat([skip_connection_list[-2], emb], dim = 1)
        
        emb = self.UpConv_1(emb_cat)
        emb_cat = torch.cat([skip_connection_list[-3], emb], dim = 1)
        
        emb = self.UpConv_2(emb_cat)
        emb_cat = torch.cat([skip_connection_list[-4], emb], dim = 1)
        
        emb = self.UpConv_3(emb_cat)
        emb_cat = torch.cat([skip_connection_list[-5], emb], dim = 1)
        
        return emb_cat

class SegModel(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = Encoder(CFG)
        self.decoder = Decoder(CFG)
        self.head = nn.Sequential(
            nn.Conv2d(CFG["channel_nums"][-1]*2, CFG["out_channels"], kernel_size=1, stride=1, padding=0),
            # nn.BatchNorm2d(CFG["out_channels"]),
            # nn.Sigmoid()
        )
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        emb = self.decoder(skip_connection_list)
        output = self.head(emb)
        return output

# %% [markdown]
# # Dataset

# %%
train_transforms = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.RandomCrop(int(CFG["img_size"][0]*0.8), int(CFG["img_size"][1]*0.8), p=0.5),
    A.Blur(blur_limit=3, p=0.3),
    A.Resize(CFG["img_size"][0], CFG["img_size"][1]),
    ToTensorV2(),
])

valid_transforms = A.Compose([
    ToTensorV2(),
])

# %%
class VCID_Dataset(Dataset):
    def __init__(self, CFG, data_dir_list, surface_list, surface_volumes=None, slide_pos=[0,0], rot90_num=0, mode="train", transform=None):
        # get config
        self.mode = mode
        self.RANDOM_SLIDE = CFG["RANDOM_SLIDE"]
        self.img_size = CFG["img_size"]
        if self.mode=="train":  self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode=="valid":    self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode == "test":   self.DATADIR = CFG["TEST_DIR"]
        self.data_dir_list = data_dir_list
        self.surface_list = surface_list
        self.slide_pos = slide_pos
        self.transform = transform
        self.rot90_num = rot90_num
        # self.cleha = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
        # get imgs
        # print("initializing dataset...")
        self.imgs = []
        for data_dir in self.data_dir_list:
            img_path = os.path.join(self.DATADIR, data_dir, "mask.png")
            # print(img_path)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            img = img.reshape(img.shape[0], img.shape[1], 1) # (h, w, channel=1)
            assert img is not None, "img is None. data path is wrong"
            self.imgs.append(img)  
        
        # get and split surface
        if surface_volumes is None:
            self.surface_vols = self.read_surfacevols()
        else:
            # print("using loaded surface_vols")
            self.surface_vols = surface_volumes
       
        # split grid
        self.get_all_grid()
        self.fileter_grid()
        self.get_flatten_grid()
        # print("split grid done.") 
       
        # get label imgs
        if self.mode == "train" or self.mode == "valid":
            self.labels = []
            for data_dir in self.data_dir_list:
                label_path = os.path.join(self.DATADIR, data_dir, "inklabels.png")
                assert os.path.exists(label_path), f"{label_path} is not exist."
                # read label
                label = cv2.imread(label_path, cv2.IMREAD_GRAYSCALE)
                label = label.reshape(label.shape[0], label.shape[1], 1) # (h, w, channel=1)
                self.labels.append(label)# 画像サイズがそれぞれ違うので単純にconcatできずlist化しているs
        # print("initializing dataset done.")

    def get_surface_volumes(self):
        return self.surface_vols

    def read_surfacevols(self):
        """ read surface volume by data_dir_list and surface_list 
            Returns:surface_vuls (list): surface volume list [array(h,w,channel=surface_num), array(), ...]
        """
        surface_vols = []
        # print("reading surface volume...")
        for data_dir in self.data_dir_list:
            surface_vol_ = None
            for read_idx, surface_idx in enumerate(self.surface_list):
                # print("\r", f"reading idx : {read_idx+1}/{len(self.surface_list)}", end="")
                surface_path = os.path.join(self.DATADIR, data_dir, "surface_volume", f"{surface_idx:02}.tif")
                surface_vol = cv2.imread(surface_path, cv2.IMREAD_GRAYSCALE)
                # surface_vol = self.cleha.apply(surface_vol)
                surface_vol = surface_vol.reshape(surface_vol.shape[0], surface_vol.shape[1], 1) # (h, w, channel=1)
                if surface_vol_ is None:
                    surface_vol_ = surface_vol
                else:
                    surface_vol_ = np.concatenate([surface_vol_, surface_vol], axis=2) # (h, w, channel=surface_num)
            surface_vols.append(surface_vol_)
            # print(f"  => read surface volume done. [{data_dir}]")
        return surface_vols


    def get_grid_img(self, img, grid_idx):
        """ crop grid img from original img"""
        img_grid = img[(grid_idx[0]*self.img_size[0]) + self.slide_pos[0] : ((grid_idx[0]+1)*self.img_size[0]) + self.slide_pos[0],
                        (grid_idx[1]*self.img_size[1]) + self.slide_pos[1] : ((grid_idx[1]+1)*self.img_size[1]) + self.slide_pos[1]]
        return img_grid
    
    def get_grid_img_and_mask(self, img, mask, grid_idx):
        """ crop grid img from original img"""
        if self.RANDOM_SLIDE and self.mode=="train" and random.random() < 0.5:
            if (grid_idx[0]!=0 and grid_idx[1]!=0) and (grid_idx[0]!=img.shape[0]//self.img_size[0] and grid_idx[1]!=img.shape[1]//self.img_size[1]):
                rand_pos = [np.random.randint(0, self.img_size[0]//4) - self.img_size[0]//4, np.random.randint(0, self.img_size[1]//4)-self.img_size[1]//4]
            else:
                rand_pos = [0, 0]
        else:
            rand_pos = [0, 0]
        self.rand_pos = rand_pos
        img_grid = img[(grid_idx[0]*self.img_size[0]) + self.slide_pos[0] + rand_pos[0] : ((grid_idx[0]+1)*self.img_size[0]) + self.slide_pos[0] + rand_pos[0],
                        (grid_idx[1]*self.img_size[1]) + self.slide_pos[1] + rand_pos[1] : ((grid_idx[1]+1)*self.img_size[1]) + self.slide_pos[1] + rand_pos[1]]
        mask_grid = mask[(grid_idx[0]*self.img_size[0]) + self.slide_pos[0] + rand_pos[0] : ((grid_idx[0]+1)*self.img_size[0]) + self.slide_pos[0] + rand_pos[0],
                         (grid_idx[1]*self.img_size[1]) + self.slide_pos[1] + rand_pos[1] : ((grid_idx[1]+1)*self.img_size[1]) + self.slide_pos[1] + rand_pos[1]]
        img_grid = np.rot90(img_grid, k=self.rot90_num)
        mask_grid = np.rot90(mask_grid, k=self.rot90_num)
        return img_grid/255., mask_grid/255.
    
    def get_masked_img(self, img, mask):
        """ multiply mask to surface_volumes """
        masked_img = None
        for channel in range(img.shape[2]):
            img_channel = img[:,:,channel].reshape(img.shape[0], img.shape[1],1)
            masked = img_channel*mask
            if masked_img is None:
                masked_img = masked.reshape(masked.shape[0], masked.shape[1], 1)
            else:
                masked = masked.reshape(masked.shape[0], masked.shape[1], 1)
                masked_img = np.concatenate([masked_img, masked], axis=2)
        return masked_img
    
    
    def get_all_grid(self):
        """ get all grid indices by img size and grid size
        """
        self.grid_indices = []
        for img in self.imgs:
            self.x_grid_size = (img.shape[0] - self.slide_pos[0]) // self.img_size[0]
            self.y_grid_size = (img.shape[1] - self.slide_pos[1]) // self.img_size[1]
            grid_img = []
            for i in range(self.x_grid_size):
                for j in range(self.y_grid_size):
                    grid_img.append([i, j])
            self.grid_indices.append(grid_img)
        return self.grid_indices
          
    def fileter_grid(self):
        """ get grid indices which mask is not 0 by all grid indices"""
        grid_indices_all = []
        for img, grid_indices in zip(self.imgs, self.grid_indices):
            grid_indices_copy = grid_indices.copy()
            for grid_idx in grid_indices:
                img_grid = self.get_grid_img(img, grid_idx)
                if img_grid.sum() == 0:
                    grid_indices_copy.remove(grid_idx)
            grid_indices_all.append(grid_indices_copy)
        self.grid_indices = grid_indices_all
        return self.grid_indices

    def get_flatten_grid(self):
        """ get flatten index list by grid indices
            Returns:flatten_grid (list): flatten index list [[img_idx, grid_idx], [img_idx, grid_idx], ...]
        """
        flatten_grid = []
        for img_idx, grid_indices in enumerate(self.grid_indices):
            for grid_idx in grid_indices:
                grid_imgidx_list = [img_idx]
                grid_imgidx_list.extend(grid_idx)
                flatten_grid.append(grid_imgidx_list)
        self.flatten_grid = flatten_grid
        return self.flatten_grid

    def __len__(self):
        return len(self.flatten_grid)

    def __getitem__(self, idx):
        # get indices
        img_grid_idx = self.flatten_grid[idx]
        img_idx = img_grid_idx[0]
        grid_idx = img_grid_idx[1:]
        # get img & surface_vol
        mask = self.imgs[img_idx]
        surface_vol = self.surface_vols[img_idx]
        # mask = self.get_grid_img(mask, grid_idx)/255.
        # surface_vol = self.get_grid_img(surface_vol, grid_idx)/255.
        mask, surface_vol = self.get_grid_img_and_mask(mask, surface_vol, grid_idx)
        # multiple small mask 
        assert surface_vol.shape[0]==mask.shape[0] and surface_vol.shape[1]==mask.shape[1] , "surface_vol_list shape is not same as img shape"
        img = surface_vol
        # transform
        if self.mode == "test":
            if self.transform:
                img = self.transform(image=img)["image"]
            else:
                img = img.transpose(2, 0, 1)
                img = torch.tensor(img, dtype=torch.float32)
            return img, grid_idx
        elif self.mode == "train" or self.mode=="valid":
            # get label(segmentation mask)
            label = self.labels[img_idx]
            label = self.get_grid_img(label, grid_idx)/255.
            label = np.rot90(label, k=self.rot90_num)
            label = (label > 0).astype(np.float32)
            # if self.mode == "train":
            #     img = self.channel_shuffle(img)
            if self.transform:
                transformed = self.transform(image=img, mask=label.copy())
                img = transformed["image"]
                label = transformed["mask"]
                label = label.permute(2, 0, 1) # (channel, h, w)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            else:
                img = img.transpose(2, 0, 1) # (channel, h, w)
                label = label.transpose(2, 0, 1) # (channel, h, w)
                img = torch.tensor(img, dtype=torch.float32)
                label = torch.tensor(label.copy(), dtype=torch.float32)
            assert img is not None and label is not None, f"img or label is None {img} {label}, {img_idx}, {grid_idx}, {self.rand_pos}"
            return img, label, grid_idx

# %% [markdown]
# # train valid fn

# %%
def train_fn(train_loader, model, criterion, epoch ,optimizer, scheduler):
    model.train()
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, _) in enumerate(train_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()     
        preds = model(images)
        
        # preds = torch.sigmoid(preds)
        loss = criterion(preds, targets)
        
        losses.update(loss.item(), CFG["batch_size"]) 
        targets = targets.detach().cpu().numpy().ravel().tolist()
        preds = preds.detach().cpu().numpy().ravel().tolist()
        loss.backward() # パラメータの勾配を計算
        optimizer.step() # モデル更新
        optimizer.zero_grad() # 勾配の初期化
                
        batch_time.update(time.time() - end)
        end = time.time()
        if batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(train_loader)-1):
            print('Epoch: [{0}][{1}/{2}] '
                    'Elapsed {remain:s} '
                    'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                    .format(
                        epoch, batch_idx, len(train_loader), batch_time=batch_time, loss=losses,
                        remain=timeSince(start, float(batch_idx+1)/len(train_loader)),
            ))
        del preds, images, targets
    gc.collect()
    torch.cuda.empty_cache()
    return losses.avg

# %%
def valid_fn(model, valid_loader, criterion=None):
    model.eval()# モデルを検証モードに設定
    test_targets = []
    test_preds = []
    test_grid_idx = []
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, grid_idx) in enumerate(valid_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()
        with torch.no_grad():
            preds = model(images)
            preds = TF.resize(img=preds, size=(CFG["input_img_size"][0], CFG["input_img_size"][1]))
            if not criterion is None:
                loss = criterion(preds, targets)
        if not criterion is None:
            losses.update(loss.item(), CFG["batch_size"])
        batch_time.update(time.time() - end)

        preds = torch.sigmoid(preds)
        targets = targets.detach().cpu().numpy()
        preds = preds.detach().cpu().numpy()
        
        test_preds.extend([preds[idx, :,:,:].transpose(1,2,0) for idx in range(preds.shape[0])])
        test_targets.extend([targets[idx, :,:,:].transpose(1,2,0) for idx in range(targets.shape[0])])
        test_grid_idx.extend([[x_idx, y_idx] for x_idx, y_idx in zip(grid_idx[0].tolist(), grid_idx[1].tolist())])

        if (batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(valid_loader)-1)) and (not criterion is None):
            print('EVAL: [{0}/{1}] '
                'Elapsed {remain:s} '
                'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                .format(
                    batch_idx, len(valid_loader), batch_time=batch_time, loss=losses,
                    remain=timeSince(start, float(batch_idx+1)/len(valid_loader)),
                ))
        del preds, images, targets
        gc.collect()
        torch.cuda.empty_cache()
    if criterion is None:
        return test_targets, test_preds, test_grid_idx
    else:
        return test_targets, test_preds, test_grid_idx, losses.avg

# %% [markdown]
# # training loop

# %%
# def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list, slide_pos=[0,0], tta="default"):
#     # concat pred img and label to original size
#     img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
#     img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
#     img = img.reshape(img.shape[0], img.shape[1], 1)
#     pred_img = np.zeros_like(img).astype(np.float32)
#     label_img = np.zeros_like(img).astype(np.float32)
#     for img_idx, grid_idx in enumerate(grid_idx_list):
#         img_ = img_list[img_idx]
#         label_ = label_list[img_idx]
#         img_ = cv2.resize(img_, dsize=(CFG["img_size"][0], CFG["img_size"][1]))
#         label_ = cv2.resize(label_, (CFG["img_size"][0], CFG["img_size"][1]))
#         img_ = img_[:, :, np.newaxis]
#         label_ = label_[:, :, np.newaxis]
#         if tta=="default":
#             pred_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
#                     grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += img_
#             label_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
#                     grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += label_
#         elif tta=="vflip":
#             pred_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
#                     grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += np.flipud(img_)
#             label_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
#                     grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += np.flipud(label_)
#         elif tta=="hflip":
#             pred_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
#                     grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += np.fliplr(img_)
#             label_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
#                     grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += np.fliplr(label_)
#         else:
#             pred_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
#                     grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += img_
#             label_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
#                     grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += label_
        
#     return pred_img, label_img

# %%
def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list, CFG, slide_pos=[0,0], rot90_num=0, tta="default"):
    # concat pred img and label to original size
    label_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "inklabels.png")
    label_img = cv2.imread(label_path, cv2.IMREAD_GRAYSCALE)
    label_img = label_img.reshape(label_img.shape[0], label_img.shape[1], 1)
    label_img = (label_img > 0).astype(np.float32)
    pred_img = np.zeros_like(label_img).astype(np.float32)
    for img_idx, grid_idx in enumerate(grid_idx_list):
        img_ = img_list[img_idx]
        img_ = cv2.resize(img_, dsize=(CFG["img_size"][0], CFG["img_size"][1]))
        img_ = np.rot90(img_, -rot90_num)
        img_ = img_[:, :, np.newaxis]
        if tta=="default":
            pred_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                    grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += img_
        elif tta=="vflip":
            pred_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                    grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += np.flipud(img_)
        elif tta=="hflip":
            pred_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                    grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += np.fliplr(img_)
        else:
            pred_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                    grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += img_

    return pred_img, label_img

# %%
def save_and_plot_oof(mode, fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary):
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_pred_img.png"), valid_preds_img*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_oofpred.png"), valid_preds_img*255)
    # cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_predbin_img.png"), valid_preds_binary*255)
    # cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_targets_img.png"), valid_targets_img*255)
                
    # plt.figure(dpi=100)
    # plt.subplot(1,3,1)
    # plt.imshow(valid_preds_img)
    # plt.subplot(1,3,2)
    # plt.imshow(valid_preds_binary)
    # plt.subplot(1,3,3)
    # plt.imshow(valid_targets_img)
    # plt.show()

# %% [markdown]
# # slice inference

# %%
def get_tta_aug(aug_type):
    if aug_type=="default":
        return A.Compose([
            A.Resize(CFG["input_img_size"][0], CFG["input_img_size"][1], p=1.0),
            ToTensorV2(),
            ])
    elif aug_type=="hflip":
        return A.Compose([
            A.HorizontalFlip(p=1.0),
            A.Resize(CFG["input_img_size"][0], CFG["input_img_size"][1], p=1.0), 
            ToTensorV2(),
        ])
    elif aug_type=="vflip":
        return A.Compose([
            A.VerticalFlip(p=1.0),
            A.Resize(CFG["input_img_size"][0], CFG["input_img_size"][1], p=1.0),
            ToTensorV2(),
        ])
    else:
        return A.Compose([
            A.Resize(CFG["input_img_size"][0], CFG["input_img_size"][1], p=1.0),
            ToTensorV2(),
            ])

# %%
def slide_inference(CFG, tta_list):
    start_time = time.time()
    slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list = [], [], []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} slide inference start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_auc_fold{fold}.pth')
        # model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_fold{fold}.pth')
        model.load_state_dict(torch.load(model_path))
        model = model.to(device)
        valid_img_slice = None
        for rot_num in CFG["rot90_num"]:
            print(f"rot_num: {rot_num}")
            for slice_idx, surface_list in enumerate(CFG["SURFACE_LIST"]):
                print("surface_list: ", surface_list)
                surface_volumes = None
                for slide_pos in CFG["slide_pos_list"]:
                    print("slide pos:", slide_pos)
                    valid_dirs = CFG["VALID_DIR_LIST"][fold]
                    for tta in tta_list:
                        print(f"tta:{tta}")
                        valid_transforms = get_tta_aug(tta)
                        valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos, rot90_num=rot_num, mode="valid", transform=valid_transforms)
                        surface_volumes = valid_dataset.get_surface_volumes()
                        valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                                    num_workers = CFG["num_workers"], pin_memory = True)

                        valid_targets, valid_preds, valid_grid_idx = valid_fn(model, valid_loader)

                        # target, predをconcatして元のサイズに戻す
                        valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs, CFG, slide_pos, rot_num, tta)
                        valid_targets_check, _  = concat_grid_img(valid_targets, valid_targets, valid_grid_idx, valid_dirs, CFG, slide_pos, rot_num, tta)
                        valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                        valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                        save_and_plot_oof("slide_tta", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary) 

                        elapsed = time.time() - start_time
                        print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                        if valid_img_slice is None:
                            valid_img_slice = valid_preds_img
                        else:
                            valid_img_slice += valid_preds_img

        valid_img_slice /= (len(CFG["SURFACE_LIST"])*len(CFG["slide_pos_list"])*len(tta_list)*len(CFG["rot90_num"]))
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_img_slice)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)

        valid_slice_binary = (valid_img_slice > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average_tta3_spos", fold, 555, valid_img_slice, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
         
        del model, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
    return slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list

# %% [markdown]
# # main

# %% [markdown]
# ---
# # OOF SCORE INFER

# %%
# %%time
tta_list = ["default"]
slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list = slide_inference(CFG, tta_list)
for fold in CFG["folds"]:
    print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
# Out:
# -- fold0 slide inference start --
# rot_num: 1
# surface_list:  [30, 33, 36, 39]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5387(th=0.300000), auc=0.897780::: time:36.22s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5586(th=0.250000), auc=0.898805::: time:62.52s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5370(th=0.250000), auc=0.902474::: time:88.75s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5527(th=0.250000), auc=0.904087::: time:114.30s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5669(th=0.350000), auc=0.907915::: time:146.86s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5931(th=0.350000), auc=0.916998::: time:172.54s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5508(th=0.350000), auc=0.913628::: time:199.00s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5784(th=0.350000), auc=0.917473::: time:225.31s
# surface_list:  [28, 31, 34, 37]
# slide pos: [0, 0]
# tta:default
# 	 score:0.6032(th=0.300000), auc=0.917119::: time:259.63s
# slide pos: [128, 0]
# tta:default
# 	 score:0.6151(th=0.350000), auc=0.917961::: time:285.89s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5944(th=0.300000), auc=0.919216::: time:312.46s
# slide pos: [128, 128]
# tta:default
# 	 score:0.6016(th=0.350000), auc=0.919015::: time:338.99s
# rot_num: 3
# surface_list:  [30, 33, 36, 39]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5305(th=0.250000), auc=0.896907::: time:372.74s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5689(th=0.300000), auc=0.899962::: time:399.11s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5371(th=0.250000), auc=0.894866::: time:425.00s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5602(th=0.250000), auc=0.898626::: time:450.80s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5812(th=0.350000), auc=0.911167::: time:484.15s
# slide pos: [128, 0]
# tta:default
# 	 score:0.6094(th=0.350000), auc=0.915102::: time:510.09s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5606(th=0.300000), auc=0.913770::: time:536.43s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5989(th=0.350000), auc=0.914185::: time:562.82s
# surface_list:  [28, 31, 34, 37]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5909(th=0.300000), auc=0.918510::: time:596.21s
# slide pos: [128, 0]
# tta:default
# 	 score:0.6196(th=0.350000), auc=0.920144::: time:622.57s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5804(th=0.350000), auc=0.916063::: time:648.92s
# slide pos: [128, 128]
# tta:default
# 	 score:0.6006(th=0.350000), auc=0.916381::: time:675.11s
# rot_num: 0
# surface_list:  [30, 33, 36, 39]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5341(th=0.250000), auc=0.890066::: time:708.28s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5572(th=0.250000), auc=0.896683::: time:734.45s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5230(th=0.250000), auc=0.890453::: time:760.40s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5494(th=0.250000), auc=0.895500::: time:786.20s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5528(th=0.400000), auc=0.896182::: time:819.48s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5618(th=0.350000), auc=0.903895::: time:845.68s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5230(th=0.400000), auc=0.898668::: time:872.49s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5574(th=0.300000), auc=0.899481::: time:899.27s
# surface_list:  [28, 31, 34, 37]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5761(th=0.300000), auc=0.903796::: time:933.28s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5967(th=0.350000), auc=0.909264::: time:958.84s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5633(th=0.300000), auc=0.906333::: time:984.53s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5705(th=0.300000), auc=0.906840::: time:1010.31s
# rot_num: 2
# surface_list:  [30, 33, 36, 39]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5376(th=0.200000), auc=0.892158::: time:1043.19s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5749(th=0.250000), auc=0.898959::: time:1068.27s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5143(th=0.300000), auc=0.891210::: time:1094.51s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5435(th=0.250000), auc=0.894659::: time:1120.12s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5533(th=0.350000), auc=0.893070::: time:1153.32s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5848(th=0.350000), auc=0.903555::: time:1178.69s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5323(th=0.350000), auc=0.895307::: time:1204.53s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5626(th=0.300000), auc=0.900006::: time:1230.21s
# surface_list:  [28, 31, 34, 37]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5964(th=0.350000), auc=0.900563::: time:1263.46s
# slide pos: [128, 0]
# tta:default
# 	 score:0.6266(th=0.300000), auc=0.904052::: time:1288.78s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5694(th=0.300000), auc=0.902589::: time:1314.38s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5882(th=0.350000), auc=0.902976::: time:1340.11s
# [fold0] slice ave score:0.6580(th=0.300000), auc=0.932935
# -- fold1 slide inference start --
# rot_num: 1
# surface_list:  [30, 33, 36, 39]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5363(th=0.150000), auc=0.851247::: time:1391.65s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5298(th=0.150000), auc=0.808841::: time:1424.74s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5335(th=0.150000), auc=0.839977::: time:1458.94s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5162(th=0.150000), auc=0.801855::: time:1493.05s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5606(th=0.250000), auc=0.848153::: time:1534.15s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5225(th=0.250000), auc=0.804729::: time:1568.13s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5623(th=0.250000), auc=0.848186::: time:1602.93s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5271(th=0.200000), auc=0.804003::: time:1636.73s
# surface_list:  [28, 31, 34, 37]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5638(th=0.200000), auc=0.859804::: time:1676.94s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5276(th=0.150000), auc=0.819132::: time:1710.24s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5570(th=0.200000), auc=0.851113::: time:1744.80s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5406(th=0.200000), auc=0.810389::: time:1778.74s
# rot_num: 3
# surface_list:  [30, 33, 36, 39]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5620(th=0.150000), auc=0.854538::: time:1818.23s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5471(th=0.150000), auc=0.811934::: time:1852.29s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5411(th=0.150000), auc=0.837817::: time:1887.06s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5321(th=0.150000), auc=0.808706::: time:1920.35s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5574(th=0.250000), auc=0.855350::: time:1960.39s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5176(th=0.250000), auc=0.806765::: time:1994.48s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5665(th=0.250000), auc=0.852668::: time:2029.92s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5166(th=0.250000), auc=0.806366::: time:2063.90s
# surface_list:  [28, 31, 34, 37]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5532(th=0.150000), auc=0.858787::: time:2103.82s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5309(th=0.150000), auc=0.820423::: time:2138.00s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5585(th=0.150000), auc=0.852651::: time:2172.65s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5387(th=0.150000), auc=0.815380::: time:2206.64s
# rot_num: 0
# surface_list:  [30, 33, 36, 39]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5807(th=0.250000), auc=0.868986::: time:2246.68s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5631(th=0.200000), auc=0.826952::: time:2280.59s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5707(th=0.200000), auc=0.860718::: time:2316.11s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5556(th=0.250000), auc=0.822660::: time:2349.68s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5964(th=0.300000), auc=0.870228::: time:2388.72s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5591(th=0.300000), auc=0.818571::: time:2423.12s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5984(th=0.300000), auc=0.867656::: time:2458.81s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5405(th=0.250000), auc=0.819388::: time:2492.58s
# surface_list:  [28, 31, 34, 37]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5960(th=0.300000), auc=0.882201::: time:2531.48s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5823(th=0.250000), auc=0.832753::: time:2565.77s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5907(th=0.250000), auc=0.871246::: time:2601.08s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5618(th=0.250000), auc=0.824857::: time:2635.17s
# rot_num: 2
# surface_list:  [30, 33, 36, 39]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5783(th=0.250000), auc=0.865200::: time:2673.91s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5464(th=0.250000), auc=0.820404::: time:2707.57s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5574(th=0.250000), auc=0.852977::: time:2742.89s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5408(th=0.250000), auc=0.816166::: time:2776.67s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5964(th=0.300000), auc=0.864191::: time:2815.56s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5554(th=0.300000), auc=0.818362::: time:2849.42s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5996(th=0.300000), auc=0.863571::: time:2884.74s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5510(th=0.300000), auc=0.818179::: time:2917.98s
# surface_list:  [28, 31, 34, 37]
# slide pos: [0, 0]
# tta:default
# 	 score:0.6087(th=0.250000), auc=0.876434::: time:2956.92s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5813(th=0.250000), auc=0.830249::: time:2991.05s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5953(th=0.300000), auc=0.867048::: time:3025.61s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5706(th=0.250000), auc=0.821739::: time:3059.55s
# [fold1] slice ave score:0.6618(th=0.200000), auc=0.894016
# -- fold2 slide inference start --
# rot_num: 1
# surface_list:  [30, 33, 36, 39]
# slide pos: [0, 0]
# tta:default
# 	 score:0.4915(th=0.200000), auc=0.807331::: time:3115.36s
# slide pos: [128, 0]
# tta:default
# 	 score:0.4772(th=0.200000), auc=0.767996::: time:3149.21s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5094(th=0.200000), auc=0.810799::: time:3184.06s
# slide pos: [128, 128]
# tta:default
# 	 score:0.4737(th=0.200000), auc=0.767591::: time:3216.97s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5594(th=0.200000), auc=0.821672::: time:3255.48s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5331(th=0.200000), auc=0.790424::: time:3288.93s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5530(th=0.200000), auc=0.817681::: time:3323.28s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5335(th=0.150000), auc=0.781223::: time:3356.17s
# surface_list:  [28, 31, 34, 37]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5486(th=0.150000), auc=0.825671::: time:3394.44s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5273(th=0.200000), auc=0.784498::: time:3427.44s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5534(th=0.200000), auc=0.822378::: time:3462.53s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5058(th=0.150000), auc=0.780084::: time:3495.98s
# rot_num: 3
# surface_list:  [30, 33, 36, 39]
# slide pos: [0, 0]
# tta:default
# 	 score:0.4952(th=0.200000), auc=0.806108::: time:3533.85s
# slide pos: [128, 0]
# tta:default
# 	 score:0.4721(th=0.250000), auc=0.767898::: time:3567.21s
# slide pos: [0, 128]
# tta:default
# 	 score:0.4960(th=0.200000), auc=0.809775::: time:3601.52s
# slide pos: [128, 128]
# tta:default
# 	 score:0.4638(th=0.150000), auc=0.765894::: time:3634.36s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5698(th=0.200000), auc=0.822425::: time:3672.59s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5427(th=0.200000), auc=0.789013::: time:3705.42s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5564(th=0.200000), auc=0.820523::: time:3739.83s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5257(th=0.150000), auc=0.785357::: time:3772.55s
# surface_list:  [28, 31, 34, 37]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5620(th=0.200000), auc=0.826259::: time:3811.10s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5236(th=0.200000), auc=0.784015::: time:3844.17s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5325(th=0.200000), auc=0.820044::: time:3878.38s
# slide pos: [128, 128]
# tta:default
# 	 score:0.4874(th=0.200000), auc=0.778855::: time:3911.36s
# rot_num: 0
# surface_list:  [30, 33, 36, 39]
# slide pos: [0, 0]
# tta:default
# 	 score:0.4973(th=0.300000), auc=0.813231::: time:3949.41s
# slide pos: [128, 0]
# tta:default
# 	 score:0.4673(th=0.250000), auc=0.776220::: time:3982.77s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5038(th=0.250000), auc=0.819915::: time:4016.78s
# slide pos: [128, 128]
# tta:default
# 	 score:0.4838(th=0.250000), auc=0.777935::: time:4049.50s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5733(th=0.250000), auc=0.832104::: time:4088.06s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5580(th=0.250000), auc=0.798944::: time:4121.90s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5905(th=0.200000), auc=0.834052::: time:4156.68s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5713(th=0.200000), auc=0.795233::: time:4189.71s
# surface_list:  [28, 31, 34, 37]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5576(th=0.300000), auc=0.832276::: time:4228.19s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5380(th=0.250000), auc=0.788677::: time:4261.54s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5597(th=0.250000), auc=0.832912::: time:4296.37s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5428(th=0.250000), auc=0.786624::: time:4329.64s
# rot_num: 2
# surface_list:  [30, 33, 36, 39]
# slide pos: [0, 0]
# tta:default
# 	 score:0.4968(th=0.250000), auc=0.816751::: time:4368.89s
# slide pos: [128, 0]
# tta:default
# 	 score:0.4779(th=0.300000), auc=0.780843::: time:4402.19s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5005(th=0.250000), auc=0.821885::: time:4436.33s
# slide pos: [128, 128]
# tta:default
# 	 score:0.4982(th=0.300000), auc=0.780556::: time:4469.24s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5958(th=0.250000), auc=0.836676::: time:4509.81s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5597(th=0.200000), auc=0.797518::: time:4543.11s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5986(th=0.250000), auc=0.837828::: time:4577.91s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5660(th=0.200000), auc=0.796712::: time:4610.64s
# surface_list:  [28, 31, 34, 37]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5812(th=0.250000), auc=0.838163::: time:4649.65s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5469(th=0.250000), auc=0.795787::: time:4682.74s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5693(th=0.250000), auc=0.836017::: time:4716.71s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5480(th=0.250000), auc=0.793922::: time:4749.72s
# [fold2] slice ave score:0.6221(th=0.200000), auc=0.853967
# -- fold3 slide inference start --
# rot_num: 1
# surface_list:  [30, 33, 36, 39]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5163(th=0.250000), auc=0.918133::: time:4794.68s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5246(th=0.200000), auc=0.921328::: time:4819.23s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5382(th=0.250000), auc=0.922062::: time:4844.06s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5694(th=0.250000), auc=0.922926::: time:4867.90s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5457(th=0.300000), auc=0.921264::: time:4895.79s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5476(th=0.350000), auc=0.924080::: time:4920.23s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5231(th=0.350000), auc=0.916493::: time:4945.46s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5154(th=0.350000), auc=0.919211::: time:4969.26s
# surface_list:  [28, 31, 34, 37]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5446(th=0.300000), auc=0.926424::: time:4996.62s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5494(th=0.300000), auc=0.929423::: time:5020.63s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5549(th=0.250000), auc=0.927729::: time:5045.45s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5622(th=0.250000), auc=0.928251::: time:5069.85s
# rot_num: 3
# surface_list:  [30, 33, 36, 39]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5309(th=0.250000), auc=0.919002::: time:5097.55s
# slide pos: [128, 0]
# tta:default
# 	 score:0.4981(th=0.200000), auc=0.918902::: time:5121.57s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5574(th=0.250000), auc=0.921157::: time:5145.94s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5384(th=0.250000), auc=0.924411::: time:5169.88s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5552(th=0.300000), auc=0.921723::: time:5198.41s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5403(th=0.300000), auc=0.924095::: time:5222.90s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5326(th=0.300000), auc=0.920344::: time:5247.69s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5179(th=0.350000), auc=0.922274::: time:5271.54s
# surface_list:  [28, 31, 34, 37]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5467(th=0.250000), auc=0.925714::: time:5299.35s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5312(th=0.300000), auc=0.929093::: time:5323.01s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5374(th=0.250000), auc=0.926487::: time:5347.37s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5401(th=0.300000), auc=0.927461::: time:5371.18s
# rot_num: 0
# surface_list:  [30, 33, 36, 39]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5406(th=0.250000), auc=0.923396::: time:5399.07s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5108(th=0.200000), auc=0.925683::: time:5423.16s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5375(th=0.250000), auc=0.923685::: time:5447.58s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5533(th=0.200000), auc=0.926618::: time:5472.15s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5105(th=0.300000), auc=0.922109::: time:5499.77s
# slide pos: [128, 0]
# tta:default
# 	 score:0.4979(th=0.300000), auc=0.924977::: time:5523.58s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5072(th=0.350000), auc=0.918112::: time:5550.00s
# slide pos: [128, 128]
# tta:default
# 	 score:0.4972(th=0.300000), auc=0.921374::: time:5575.10s
# surface_list:  [28, 31, 34, 37]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5459(th=0.250000), auc=0.929284::: time:5603.57s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5473(th=0.200000), auc=0.933018::: time:5627.73s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5319(th=0.250000), auc=0.927703::: time:5652.95s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5520(th=0.250000), auc=0.931756::: time:5676.78s
# rot_num: 2
# surface_list:  [30, 33, 36, 39]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5062(th=0.200000), auc=0.923873::: time:5704.04s
# slide pos: [128, 0]
# tta:default
# 	 score:0.4834(th=0.250000), auc=0.923714::: time:5728.31s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5055(th=0.250000), auc=0.922135::: time:5752.91s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5248(th=0.250000), auc=0.923084::: time:5777.41s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5082(th=0.300000), auc=0.920197::: time:5805.62s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5194(th=0.300000), auc=0.921282::: time:5829.40s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5121(th=0.350000), auc=0.917730::: time:5853.82s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5138(th=0.250000), auc=0.917144::: time:5878.11s
# surface_list:  [28, 31, 34, 37]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5453(th=0.200000), auc=0.926574::: time:5907.50s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5480(th=0.250000), auc=0.930922::: time:5931.67s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5422(th=0.200000), auc=0.926787::: time:5956.51s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5625(th=0.250000), auc=0.929385::: time:5980.77s
# [fold3] slice ave score:0.6037(th=0.250000), auc=0.940382
# -- fold4 slide inference start --
# rot_num: 1
# surface_list:  [30, 33, 36, 39]
# slide pos: [0, 0]
# tta:default
# 	 score:0.4942(th=0.200000), auc=0.890351::: time:6034.98s
# slide pos: [128, 0]
# tta:default
# 	 score:0.4930(th=0.200000), auc=0.887831::: time:6065.54s
# slide pos: [0, 128]
# tta:default
# 	 score:0.4813(th=0.200000), auc=0.889029::: time:6097.12s
# slide pos: [128, 128]
# tta:default
# 	 score:0.4816(th=0.250000), auc=0.884882::: time:6128.10s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# tta:default
# 	 score:0.4832(th=0.300000), auc=0.880455::: time:6168.54s
# slide pos: [128, 0]
# tta:default
# 	 score:0.4558(th=0.250000), auc=0.881120::: time:6199.80s
# slide pos: [0, 128]
# tta:default
# 	 score:0.4805(th=0.300000), auc=0.877970::: time:6230.93s
# slide pos: [128, 128]
# tta:default
# 	 score:0.4560(th=0.350000), auc=0.877569::: time:6262.22s
# surface_list:  [28, 31, 34, 37]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5063(th=0.250000), auc=0.892148::: time:6301.98s
# slide pos: [128, 0]
# tta:default
# 	 score:0.4897(th=0.250000), auc=0.888065::: time:6333.40s
# slide pos: [0, 128]
# tta:default
# 	 score:0.4927(th=0.250000), auc=0.891381::: time:6364.80s
# slide pos: [128, 128]
# tta:default
# 	 score:0.4870(th=0.300000), auc=0.886472::: time:6395.32s
# rot_num: 3
# surface_list:  [30, 33, 36, 39]
# slide pos: [0, 0]
# tta:default
# 	 score:0.4782(th=0.200000), auc=0.884737::: time:6434.81s
# slide pos: [128, 0]
# tta:default
# 	 score:0.4707(th=0.200000), auc=0.883753::: time:6466.14s
# slide pos: [0, 128]
# tta:default
# 	 score:0.4834(th=0.200000), auc=0.883739::: time:6497.47s
# slide pos: [128, 128]
# tta:default
# 	 score:0.4771(th=0.200000), auc=0.881658::: time:6528.68s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# tta:default
# 	 score:0.4904(th=0.300000), auc=0.876797::: time:6568.83s
# slide pos: [128, 0]
# tta:default
# 	 score:0.4750(th=0.300000), auc=0.878101::: time:6600.03s
# slide pos: [0, 128]
# tta:default
# 	 score:0.4812(th=0.300000), auc=0.873089::: time:6631.61s
# slide pos: [128, 128]
# tta:default
# 	 score:0.4681(th=0.350000), auc=0.874502::: time:6663.00s
# surface_list:  [28, 31, 34, 37]
# slide pos: [0, 0]
# tta:default
# 	 score:0.4970(th=0.250000), auc=0.888336::: time:6702.58s
# slide pos: [128, 0]
# tta:default
# 	 score:0.4914(th=0.250000), auc=0.885420::: time:6733.96s
# slide pos: [0, 128]
# tta:default
# 	 score:0.4942(th=0.250000), auc=0.887152::: time:6764.67s
# slide pos: [128, 128]
# tta:default
# 	 score:0.4957(th=0.250000), auc=0.885593::: time:6795.38s
# rot_num: 0
# surface_list:  [30, 33, 36, 39]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5386(th=0.300000), auc=0.901932::: time:6835.43s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5266(th=0.300000), auc=0.900517::: time:6866.15s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5381(th=0.300000), auc=0.901495::: time:6896.86s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5335(th=0.300000), auc=0.900251::: time:6927.94s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5040(th=0.450000), auc=0.882122::: time:6967.16s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5185(th=0.400000), auc=0.885566::: time:6998.20s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5073(th=0.400000), auc=0.882301::: time:7029.69s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5110(th=0.400000), auc=0.885330::: time:7060.68s
# surface_list:  [28, 31, 34, 37]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5600(th=0.350000), auc=0.901575::: time:7100.41s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5443(th=0.400000), auc=0.898936::: time:7131.55s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5462(th=0.350000), auc=0.900714::: time:7162.69s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5431(th=0.350000), auc=0.899255::: time:7193.70s
# rot_num: 2
# surface_list:  [30, 33, 36, 39]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5252(th=0.300000), auc=0.898100::: time:7231.90s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5157(th=0.250000), auc=0.896273::: time:7263.00s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5228(th=0.300000), auc=0.894988::: time:7293.85s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5239(th=0.300000), auc=0.896774::: time:7324.83s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5255(th=0.400000), auc=0.884401::: time:7364.39s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5186(th=0.400000), auc=0.889486::: time:7395.12s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5289(th=0.400000), auc=0.882398::: time:7425.98s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5282(th=0.350000), auc=0.888514::: time:7456.47s
# surface_list:  [28, 31, 34, 37]
# slide pos: [0, 0]
# tta:default
# 	 score:0.5553(th=0.400000), auc=0.900785::: time:7496.41s
# slide pos: [128, 0]
# tta:default
# 	 score:0.5362(th=0.350000), auc=0.899734::: time:7527.68s
# slide pos: [0, 128]
# tta:default
# 	 score:0.5576(th=0.350000), auc=0.898175::: time:7558.61s
# slide pos: [128, 128]
# tta:default
# 	 score:0.5456(th=0.350000), auc=0.898407::: time:7589.74s
# [fold4] slice ave score:0.5625(th=0.250000), auc=0.912344
# fold[0] slice ave score:0.6580(th=0.300000), auc=0.932935
# fold[1] slice ave score:0.6618(th=0.200000), auc=0.894016
# fold[2] slice ave score:0.6221(th=0.200000), auc=0.853967
# fold[3] slice ave score:0.6037(th=0.250000), auc=0.940382
# fold[4] slice ave score:0.5625(th=0.250000), auc=0.912344
# CPU times: user 1h 41min 38s, sys: 17min 27s, total: 1h 59min 6s
# Wall time: 2h 6min 44s

# %%
# %%time
OUTPUT_DIR = CFG["OUTPUT_DIR"]
print(OUTPUT_DIR)
pred_flatten_list = []
mask_flatten_list = []
for fold in [0,1,2,3,4]:
    # mask_path = os.path.join(OUTPUT_DIR, "imgs", f"fold{fold}_average_tta3_spos_slice555_valid_targets_img.png")
    valid_dir_list = CFG["VALID_DIR_LIST"][fold]
    mask_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "inklabels.png")
    pred_path = os.path.join(OUTPUT_DIR, "imgs", f"fold{fold}_average_tta3_spos_slice555_valid_pred_img.png")
    pred_img = cv2.imread(pred_path, cv2.IMREAD_GRAYSCALE)
    mask_img = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    print(pred_img.shape) 
    print(mask_img.shape)
    plt.figure()
    plt.subplot(1, 2, 1)
    plt.imshow(pred_img)
    plt.subplot(1, 2, 2)
    plt.imshow(mask_img)
    plt.show()
    pred_flatten_list.extend(pred_img.flatten())
    mask_flatten_list.extend(mask_img.flatten())
# Out:
# /working/output/exp110
# (7606, 5249)
# (7606, 5249)
# (4944, 9506)
# (4944, 9506)
# (4943, 9506)
# (4943, 9506)
# (4943, 9506)
# (4943, 9506)
# (8181, 6330)
# (8181, 6330)
# CPU times: user 20.9 s, sys: 7.87 s, total: 28.8 s
# Wall time: 26.3 s

# %%
mask_flatten_list = np.array(mask_flatten_list)/255.
mask = np.array(mask_flatten_list).astype(int)
pred = np.array(pred_flatten_list)/255.

plt.figure()
plt.subplot(1, 2, 1)
plt.hist(pred, bins=100)
plt.subplot(1, 2, 2)
plt.hist(mask)
plt.show()

for th in np.array(range(10, 100+1, 5)) / 100:
    dice = fbeta_numpy(mask, (pred >= th).astype(int), beta=0.5)
    print(f"th={th:.2f}, dice={dice:.4f}")
# Out:
# th=0.10, dice=0.5100
# th=0.15, dice=0.5823
# th=0.20, dice=0.6118
# th=0.25, dice=0.6120
# th=0.30, dice=0.5935
# th=0.35, dice=0.5565
# th=0.40, dice=0.5092
# th=0.45, dice=0.4467
# th=0.50, dice=0.3775
# th=0.55, dice=0.3075
# th=0.60, dice=0.2423
# th=0.65, dice=0.1737
# th=0.70, dice=0.1139
# th=0.75, dice=0.0647
# th=0.80, dice=0.0318
# th=0.85, dice=0.0106
# th=0.90, dice=0.0010
# th=0.95, dice=0.0000
# th=1.00, dice=0.0000
# 現在のセルまたは前のセルでコードを実行中に、カーネルがクラッシュしました。エラーの原因を特定するには、セル内のコードを確認してください。詳細については、<a href='https://aka.ms/vscodeJupyterKernelCrash'>こちら</a> をクリックしてください。さらなる詳細については、Jupyter [log] (command:jupyter.viewOutput) を参照してください。
