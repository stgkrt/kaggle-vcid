# %% [markdown]
# # ex018
# bug fix masked_img
# 5-fold
# img size 512
# output shape is half of input shape
# next channel shuffle

# %%
import gc
import os
import random
import time
import math

import cv2
import numpy as np
import matplotlib.pyplot as plt

# model
import torch
import torchvision
import torch.nn as nn
import timm
from torchvision.models.feature_extraction import create_feature_extractor
import torchvision.transforms.functional as TF

# data loader
import albumentations as A
from albumentations.pytorch import ToTensorV2
from torch.utils.data import DataLoader, Dataset

# training
from torch.optim import SGD, Adam, AdamW
from torch.optim.lr_scheduler import CosineAnnealingLR, CosineAnnealingWarmRestarts, ReduceLROnPlateau, ExponentialLR

# metric
from sklearn.metrics import fbeta_score, roc_auc_score

import wandb

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # config

# %%
BASE_DIR = "/working/"
INPUT_DIR = os.path.join(BASE_DIR, "input", "vesuvius-challenge-ink-detection")
TRAIN_DIR = os.path.join(INPUT_DIR, "train")
TEST_DIR = os.path.join(INPUT_DIR, "test")
# IMG_SIZE = [256, 256]
# IMG_SIZE = [128, 128]
IMG_SIZE = [512, 512]
SURFACE_LIST = [
                list(range(26, 36, 3)),
                list(range(27, 37, 3)),                
                list(range(25, 35, 3)),
                ]
print(len(SURFACE_LIST[0]))
print(SURFACE_LIST)

SURFACE_NUM = len(SURFACE_LIST[0])
# print("Start surface idx =",START_SURFACE)

# SLIDE_POS_LIST = [[idx*(IMG_SIZE[0]//6), idx*(IMG_SIZE[1]//6)] for idx in range(0, 3)]
SLIDE_POS_LIST = [[0,0], [IMG_SIZE[0]//2, 0], [0, IMG_SIZE[1]//2], [IMG_SIZE[0]//2, IMG_SIZE[1]//2]]
print("SLIDE_POS_LIST =", SLIDE_POS_LIST)
CFG = {
    "DEBUG" : False,
    # exp setting
    "EXP_CATEGORY" : "5fold",
    "EXP_NAME" : "exp018",
    "folds" : [0, 1, 2, 3, 4],

    # model
    # "model_name" : "tf_efficientnet_b0",
    "model_name" : "tf_efficientnet_b6",
    "inp_channels" : SURFACE_NUM,
    "out_channels" : 1,
    "pretrained" : True,
    "out_indices" : [0,1,2,3,4],
 
    # data   
    "img_size": IMG_SIZE,
    # "batch_size": 32,
    # "batch_size": 16,#batch normの関係か？16の方が64より安定してそう？？
    "batch_size": 8,
    "INPUT_DIR": INPUT_DIR,
    "TRAIN_DIR": TRAIN_DIR,
    "TEST_DIR": TEST_DIR,
    "surface_num": SURFACE_NUM,
    "surface_list": list(SURFACE_LIST),
    "slide_pos_list": SLIDE_POS_LIST,
#     "surface_start_idx": START_SURFACE,
    # "TRAIN_DIR_LIST": [["1", "2"], ["1", "3"], ["2", "3"]],
    "TRAIN_DIR_LIST": [["1", "2_0", "2_1", "2_2"], 
                       ["1", "2_0", "2_1", "3"],
                       ["1", "2_0",  "2_2", "3"],
                       ["1", "2_1", "2_2", "3"],
                       ["2_0", "2_1", "2_2", "3"],
                       ],
#     "TRAIN_IDX_LIST" : ["1"],
    # "VALID_DIR_LIST": [["3"],["2"],["1"]],
    "VALID_DIR_LIST": [["3"], ["2_2"], ["2_1"], ["2_0"],["1"]],
    "TEST_DIR_LIST": ["a", "b"],

    # learning
    "n_epoch" : 15,
    "lr" : 1e-3,
    "T_max" : 5,
    "min_lr" : 1e-8,
    "weight_decay" : 1e-6,

    # etc
    "print_freq" : 1000,
    "random_seed" : 21,
    "num_workers": 2,
}


if CFG["model_name"]=="tf_efficientnet_b0":
    CFG["channel_nums"] = [320, 112, 40, 24, 16]
elif CFG["model_name"]=="tf_efficientnet_b4":
    CFG["channel_nums"] = [448, 160, 56, 32, 24]
elif CFG["model_name"]=="tf_efficientnet_b6":
    CFG["channel_nums"] = [576, 200, 72, 40, 32]


if CFG["DEBUG"]:
    CFG["n_epoch"] = 1
    CFG["EXP_NAME"] = "DEBUG"
    

CFG["OUTPUT_DIR"] = os.path.join(BASE_DIR, "output", CFG["EXP_NAME"])
# Out:
# 4
# [[26, 29, 32, 35], [27, 30, 33, 36], [25, 28, 31, 34]]
# SLIDE_POS_LIST = [[0, 0], [256, 0], [0, 256], [256, 256]]

# %%
if not CFG["DEBUG"]:
    os.makedirs(CFG["OUTPUT_DIR"])
    os.makedirs(os.path.join(CFG["OUTPUT_DIR"], "imgs"))

# %%
if not CFG["DEBUG"]:
    WANDB_CONFIG = {'competition': 'vcid', '_wandb_kernel': 'taro'}
    os.environ["WANDB_SILENT"] = "true"
    wandb.init(project=WANDB_CONFIG["competition"], config=CFG, group=CFG["EXP_CATEGORY"], name=CFG["EXP_NAME"], reinit=True)
# Out:
# 2023-04-20 03:34:57.919989: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-20 03:34:57.997100: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-20 03:34:58.639664: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-20 03:34:58.639747: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-20 03:34:58.639754: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# # utils

# %%
def logging_metrics_epoch(CFG, fold, epoch, slice_idx,train_loss_avg, valid_loss_avg, score, threshold, auc_score):
    wandb.log({f"train/fold{fold}": train_loss_avg,
                f"valid/fold{fold}": valid_loss_avg,
                f"score/fold{fold}":score,
                f"score threshold/fold{fold}":threshold,
                f"auc/fold{fold}":auc_score,
                f"epoch/fold{fold}":epoch+slice_idx*CFG["n_epoch"],
                })

# %%
def seed_everything(seed=CFG["random_seed"]):
    #os.environ['PYTHONSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic =True
    torch.backends.cudnn.benchmark = False
seed_everything()

# device optimization
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
def asMinutes(s):
    """Convert Seconds to Minutes."""
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    """Accessing and Converting Time Data."""
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))

class AverageMeter(object):
    """Computes and stores the average and current value."""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# # metric

# %%
def fbeta_numpy(targets, preds, beta=0.5, smooth=1e-5):
    y_true_count = targets.sum()
    ctp = preds[targets==1].sum()
    cfp = preds[targets==0].sum()
    beta_squared = beta * beta

    c_precision = ctp / (ctp + cfp + smooth)
    c_recall = ctp / (y_true_count + smooth)
    dice = (1 + beta_squared) * (c_precision * c_recall) / (beta_squared * c_precision + c_recall + smooth)

    return dice

def calc_fbeta_auc(mask, mask_pred):
    mask = mask.astype(int).flatten()
    mask_pred = mask_pred.flatten()

    best_th = 0
    best_dice = 0
    dice_list = [] 
    # for th in np.array(range(10, 50+1, 5)) / 100:
    for th in np.array(range(10, 100+1, 5)) / 100:
        # dice = fbeta_score(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice = fbeta_numpy(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice_list.append(dice)
        # print(f'\t th: {th}, fbeta: {dice}')
        if dice > best_dice:
            best_dice = dice
            best_th = th
    
    auc = roc_auc_score(mask, mask_pred)
    # Logger.info(f'best_th: {best_th}, fbeta: {best_dice}')
    return best_dice, best_th, auc, dice_list


def calc_cv(mask_gt, mask_pred):
    best_dice, best_th, auc, dice_list = calc_fbeta_auc(mask_gt, mask_pred)

    return best_dice, best_th, auc, dice_list

# %% [markdown]
# # model

# %%
class Encoder(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = timm.create_model(CFG["model_name"], in_chans=CFG["inp_channels"], features_only=True, out_indices=CFG["out_indices"], pretrained=CFG["pretrained"])
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        return skip_connection_list

class UpConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.bn1 = nn.BatchNorm2d(in_channels)
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size = 2, padding="same")
        self.bn2 = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        x = self.up(x)
        x = self.bn1(x)
        x = self.conv(x)
        x = self.bn2(x)
        return x


class Decoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.UpConv_0 = UpConv(CFG["channel_nums"][0], CFG["channel_nums"][1])
        self.UpConv_1 = UpConv(CFG["channel_nums"][1]*2, CFG["channel_nums"][2])
        self.UpConv_2 = UpConv(CFG["channel_nums"][2]*2, CFG["channel_nums"][3])
        self.UpConv_3 = UpConv(CFG["channel_nums"][3]*2, CFG["channel_nums"][4])
        # self.UpConv_4 = UpConv(CFG["channel_nums"][4]*2, CFG["channel_nums"][4])
    
    def forward(self, skip_connection_list):
        emb = self.UpConv_0(skip_connection_list[4]) # emb.shape = (None, 160, 14, 14)
        emb_cat = torch.cat([skip_connection_list[3], emb], dim = 1)
        
        emb = self.UpConv_1(emb_cat)
        emb_cat = torch.cat([skip_connection_list[2], emb], dim = 1)
        
        emb = self.UpConv_2(emb_cat)
        emb_cat = torch.cat([skip_connection_list[1], emb], dim = 1)
        
        emb = self.UpConv_3(emb_cat)
        emb_cat = torch.cat([skip_connection_list[0], emb], dim = 1)

        # emb_cat = self.UpConv_4(emb_cat)
        
        return emb_cat

class SegModel(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = Encoder(CFG)
        self.decoder = Decoder()
        self.head = nn.Sequential(
            nn.Conv2d(CFG["channel_nums"][-1]*2, CFG["out_channels"], kernel_size=1, stride=1, padding=0),
            nn.Sigmoid()
        )
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        emb = self.decoder(skip_connection_list)
        output = self.head(emb)
        return output

# %% [markdown]
# # Dataset

# %%
train_transforms = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.RandomCrop(int(CFG["img_size"][0]*0.8), int(CFG["img_size"][1]*0.8), p=0.5),
    A.Blur(blur_limit=3, p=0.3),
    A.Resize(CFG["img_size"][0], CFG["img_size"][1]),
    ToTensorV2(),
])

valid_transforms = A.Compose([
    ToTensorV2(),
])

# %%
def fft_transform(img):
    eps = 1e-7
    f = np.fft.fft2(img)
    fshift = np.fft.fftshift(f)
    fshift = np.nan_to_num(fshift)+eps#nanを0埋め
    magnitude_spectrum = 20*np.log(np.abs(fshift))
    return magnitude_spectrum

def highpass_filter(img):
    frange = 1
    dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
    dft_shift = np.fft.fftshift(dft)

    rows, cols = img.shape
    crow,ccol = rows//2 , cols//2

    # create a mask first, center square is 1, remaining all zeros
    mask = np.ones((rows,cols,2),np.uint8)
    mask[crow-frange:crow+frange, ccol-frange:ccol+frange] = 0

    # apply mask and inverse DFT
    fshift = dft_shift*mask
    f_ishift = np.fft.ifftshift(fshift)
    img_back = cv2.idft(f_ishift)
    img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

    return img_back

def lowpass_filter(img):
    frange = 5
    dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
    dft_shift = np.fft.fftshift(dft)

    rows, cols = img.shape
    crow,ccol = rows//2 , cols//2

    # create a mask first, center square is 1, remaining all zeros
    mask = np.zeros((rows,cols,2),np.uint8)
    mask[crow-frange:crow+frange, ccol-frange:ccol+frange] = 1

    # apply mask and inverse DFT
    fshift = dft_shift*mask
    f_ishift = np.fft.ifftshift(fshift)
    img_back = cv2.idft(f_ishift)
    img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

    return img_back

# %%
class VCID_Dataset(Dataset):
    def __init__(self, CFG, data_dir_list, surface_list, surface_volumes=None, slide_pos=[0,0], mode="train", transform=None):
        # get config
        self.mode = mode
        self.img_size = CFG["img_size"]
        if self.mode=="train":  self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode=="valid":    self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode == "test":   self.DATADIR = CFG["TEST_DIR"]
        self.data_dir_list = data_dir_list
        self.surface_list = surface_list
        self.slide_pos = slide_pos
        self.transform = transform
        
        # get imgs
        # print("initializing dataset...")
        self.imgs = []
        for data_dir in self.data_dir_list:
            img_path = os.path.join(self.DATADIR, data_dir, "mask.png")
            # print(img_path)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            img = img.reshape(img.shape[0], img.shape[1], 1) # (h, w, channel=1)
            assert img is not None, "img is None. data path is wrong"
        
            # mask erosion
            kernel_size = (img.shape[0]+img.shape[1])//2//100
            kernel = np.ones((kernel_size, kernel_size), np.uint8)
            img = cv2.erode(img, kernel,iterations = 3)
            self.imgs.append(img[:,:,np.newaxis])    
        
        # get and split surface
        if surface_volumes is None:
            self.surface_vols = self.read_surfacevols()
        else:
            # print("using loaded surface_vols")
            self.surface_vols = surface_volumes
        for surface_idx, surface_vol in enumerate(self.surface_vols):
            self.surface_vols[surface_idx] = self.get_masked_img(surface_vol, self.imgs[surface_idx])
       
        # split grid
        self.get_all_grid()
        self.fileter_grid()
        self.get_flatten_grid()
        # print("split grid done.") 
       
        # get label imgs
        if self.mode == "train" or self.mode == "valid":
            self.labels = []
            for data_dir in self.data_dir_list:
                label_path = os.path.join(self.DATADIR, data_dir, "inklabels.png")
                assert os.path.exists(label_path), f"{label_path} is not exist."
                # read label
                label = cv2.imread(label_path, cv2.IMREAD_GRAYSCALE)
                label = label.reshape(label.shape[0], label.shape[1], 1) # (h, w, channel=1)
                self.labels.append(label)# 画像サイズがそれぞれ違うので単純にconcatできずlist化しているs
        # print("initializing dataset done.")

    def get_surface_volumes(self):
        return self.surface_vols

    def read_surfacevols(self):
        """ read surface volume by data_dir_list and surface_list 
            Returns:surface_vuls (list): surface volume list [array(h,w,channel=surface_num), array(), ...]
        """
        surface_vols = []
        # print("reading surface volume...")
        for data_dir in self.data_dir_list:
            surface_vol_ = None
            for read_idx, surface_idx in enumerate(self.surface_list):
                # print("\r", f"reading idx : {read_idx+1}/{len(self.surface_list)}", end="")
                surface_path = os.path.join(self.DATADIR, data_dir, "surface_volume", f"{surface_idx:02}.tif")
                surface_vol = cv2.imread(surface_path, cv2.IMREAD_GRAYSCALE)
                surface_vol = surface_vol.reshape(surface_vol.shape[0], surface_vol.shape[1], 1) # (h, w, channel=1)
                if surface_vol_ is None:
                    surface_vol_ = surface_vol
                else:
                    surface_vol_ = np.concatenate([surface_vol_, surface_vol], axis=2) # (h, w, channel=surface_num)
            surface_vols.append(surface_vol_)
            # print(f"  => read surface volume done. [{data_dir}]")
        return surface_vols


    def get_grid_img(self, img, grid_idx):
        """ crop grid img from original img"""
        img_grid = img[grid_idx[0]*self.img_size[0] + self.slide_pos[0] : (grid_idx[0]+1)*self.img_size[0] + self.slide_pos[0],
                        grid_idx[1]*self.img_size[1] + self.slide_pos[1] : (grid_idx[1]+1)*self.img_size[1] + self.slide_pos[1]]
        return img_grid
    
    
    def get_masked_img(self, img, mask):
        """ multiply mask to surface_volumes """
        masked_img = None
        for channel in range(img.shape[2]):
            img_channel = img[:,:,channel].reshape(img.shape[0], img.shape[1],1)
            masked = img_channel*mask
            if masked_img is None:
                masked_img = masked.reshape(masked.shape[0], masked.shape[1], 1)
            else:
                masked = masked.reshape(masked.shape[0], masked.shape[1], 1)
                masked_img = np.concatenate([masked_img, masked], axis=2)
        return masked_img
    
    def get_grid_hpfimg(self, img, grid_idx):
        """ crop grid img from original img and hpf filter """
        img_grid = self.get_grid_img(img, grid_idx)
        img_transformed = None
        for channel in range(img_grid.shape[2]):
            img_grid_trans = highpass_filter(img_grid[:,:,channel])
            if img_transformed is None:
                img_transformed = img_grid_trans.reshape(img_grid_trans.shape[0], img_grid_trans.shape[1], 1)
            else:
                img_transformed = np.concatenate([img_transformed, img_grid_trans.reshape(img_grid_trans.shape[0], img_grid_trans.shape[1], 1)], axis=2)
        return img_transformed
    
    def get_all_grid(self):
        """ get all grid indices by img size and grid size
        """
        self.grid_indices = []
        for img in self.imgs:
            self.x_grid_size = (img.shape[0] - self.slide_pos[0]) // self.img_size[0]
            self.y_grid_size = (img.shape[1] - self.slide_pos[1]) // self.img_size[1]
            grid_img = []
            for i in range(self.x_grid_size):
                for j in range(self.y_grid_size):
                    grid_img.append([i, j])
            self.grid_indices.append(grid_img)
        return self.grid_indices
          
    def fileter_grid(self):
        """ get grid indices which mask is not 0 by all grid indices"""
        grid_indices_all = []
        for img, grid_indices in zip(self.imgs, self.grid_indices):
            grid_indices_copy = grid_indices.copy()
            for grid_idx in grid_indices:
                img_grid = self.get_grid_img(img, grid_idx)
                if img_grid.sum() == 0:
                    grid_indices_copy.remove(grid_idx)
            grid_indices_all.append(grid_indices_copy)
        self.grid_indices = grid_indices_all
        return self.grid_indices

    def get_flatten_grid(self):
        """ get flatten index list by grid indices
            Returns:flatten_grid (list): flatten index list [[img_idx, grid_idx], [img_idx, grid_idx], ...]
        """
        flatten_grid = []
        for img_idx, grid_indices in enumerate(self.grid_indices):
            for grid_idx in grid_indices:
                grid_imgidx_list = [img_idx]
                grid_imgidx_list.extend(grid_idx)
                flatten_grid.append(grid_imgidx_list)
        self.flatten_grid = flatten_grid
        return self.flatten_grid
    
    def channel_shuffle(self, img):
        img = img.transpose(2, 0, 1)
        np.random.shuffle(img)
        return img.transpose(1, 2, 0)

    def __len__(self):
        return len(self.flatten_grid)

    def __getitem__(self, idx):
        # get indices
        img_grid_idx = self.flatten_grid[idx]
        img_idx = img_grid_idx[0]
        grid_idx = img_grid_idx[1:]
        # get img & surface_vol
        mask = self.imgs[img_idx]
        surface_vol = self.surface_vols[img_idx]
        mask = self.get_grid_img(mask, grid_idx)/255.
        surface_vol = self.get_grid_img(surface_vol, grid_idx)/255.
        # multiple small mask 
        assert surface_vol.shape[0]==mask.shape[0] and surface_vol.shape[1]==mask.shape[1] , "surface_vol_list shape is not same as img shape"
        img = surface_vol
        # transform
        if self.mode == "test":
            if self.transform:
                img = self.transform(image=img)["image"]
            else:
                img = img.transpose(2, 0, 1)
                img = torch.tensor(img, dtype=torch.float32)
            return img, grid_idx
        elif self.mode == "train" or self.mode=="valid":
            # get label(segmentation mask)
            label = self.labels[img_idx]
            label = self.get_grid_img(label, grid_idx)
            # if self.mode == "train":
            #     img = self.channel_shuffle(img)
            if self.transform:
                transformed = self.transform(image=img, mask=label)
                img = transformed["image"]
                label = transformed["mask"]
                label = label.permute(2, 0, 1)/255. # (channel, h, w)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            else:
                img = img.transpose(2, 0, 1) # (channel, h, w)
                label = label.transpose(2, 0, 1)/255. # (channel, h, w){}
                img = torch.tensor(img, dtype=torch.float32)
                label = torch.tensor(label, dtype=torch.float32)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            return img, label, grid_idx

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train")
# surface_volumes = dataset_notrans.surface_vols
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx < 2:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
        
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train")
# surface_volumes = dataset_notrans.surface_vols
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx < 2:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos=[0,50],mode="train")
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 1:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train", transform=train_transforms)
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)


# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 0:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %% [markdown]
# # train valid fn

# %%
def train_fn(train_loader, model, criterion, epoch ,optimizer, scheduler):
    model.train()
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, _) in enumerate(train_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()     
        preds = model(images)
        preds = TF.resize(img=preds, size=(CFG["img_size"][0], CFG["img_size"][1]))
        # preds = torch.sigmoid(preds)
        loss = criterion(preds, targets)
        
        losses.update(loss.item(), CFG["batch_size"]) 
        targets = targets.detach().cpu().numpy().ravel().tolist()
        preds = preds.detach().cpu().numpy().ravel().tolist()
        loss.backward() # パラメータの勾配を計算
        optimizer.step() # モデル更新
        optimizer.zero_grad() # 勾配の初期化
                
        batch_time.update(time.time() - end)
        end = time.time()
        if batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(train_loader)-1):
            print('Epoch: [{0}][{1}/{2}] '
                    'Elapsed {remain:s} '
                    'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                    .format(
                        epoch, batch_idx, len(train_loader), batch_time=batch_time, loss=losses,
                        remain=timeSince(start, float(batch_idx+1)/len(train_loader)),
            ))
        del preds, images, targets
    gc.collect()
    torch.cuda.empty_cache()
    return losses.avg

# %%
def valid_fn(model, valid_loader, criterion=None):
    model.eval()# モデルを検証モードに設定
    test_targets = []
    test_preds = []
    test_grid_idx = []
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, grid_idx) in enumerate(valid_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()
        with torch.no_grad():
            preds = model(images)
            preds = TF.resize(img=preds, size=(CFG["img_size"][0], CFG["img_size"][1]))
            if not criterion is None:
                loss = criterion(preds, targets)
        if not criterion is None:
            losses.update(loss.item(), CFG["batch_size"])
        batch_time.update(time.time() - end)

        targets = targets.detach().cpu().numpy()
        preds = preds.detach().cpu().numpy()
        
        test_preds.extend([preds[idx, :,:,:].transpose(1,2,0) for idx in range(preds.shape[0])])
        test_targets.extend([targets[idx, :,:,:].transpose(1,2,0) for idx in range(targets.shape[0])])
        test_grid_idx.extend([[x_idx, y_idx] for x_idx, y_idx in zip(grid_idx[0].tolist(), grid_idx[1].tolist())])

        if (batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(valid_loader)-1)) and (not criterion is None):
            print('EVAL: [{0}/{1}] '
                'Elapsed {remain:s} '
                'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                .format(
                    batch_idx, len(valid_loader), batch_time=batch_time, loss=losses,
                    remain=timeSince(start, float(batch_idx+1)/len(valid_loader)),
                ))
        del preds, images, targets
        gc.collect()
        torch.cuda.empty_cache()
    if criterion is None:
        return test_targets, test_preds, test_grid_idx
    else:
        return test_targets, test_preds, test_grid_idx, losses.avg

# %% [markdown]
# # training loop

# %%
# def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list):
#     # concat pred img and label to original size
#     img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
#     img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
#     img = img.reshape(img.shape[0], img.shape[1], 1)
#     pred_img = np.zeros_like(img).astype(np.float32)
#     label_img = np.zeros_like(img).astype(np.float32)
#     for img_idx, grid_idx in enumerate(grid_idx_list):
#         pred_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += img_list[img_idx]
        
#         label_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += label_list[img_idx]
#     return pred_img, label_img

# %%
def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list, slide_pos=[0,0]):
    # concat pred img and label to original size
    img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    img = img.reshape(img.shape[0], img.shape[1], 1)
    pred_img = np.zeros_like(img).astype(np.float32)
    label_img = np.zeros_like(img).astype(np.float32)
    for img_idx, grid_idx in enumerate(grid_idx_list):
        pred_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += img_list[img_idx]
        
        label_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += label_list[img_idx]
    return pred_img, label_img

# %%
def save_and_plot_oof(mode, fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary):
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_pred_img.png"), valid_preds_img*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_predbin_img.png"), valid_preds_binary*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_targets_img.png"), valid_targets_img*255)
    
    # plot preds & binary preds
    # plt.figure(dpi=100)
    # plt.subplot(1,3,1)
    # plt.imshow(valid_preds_img)
    # plt.subplot(1,3,2)
    # plt.imshow(valid_preds_binary)
    # plt.subplot(1,3,3)
    # plt.imshow(valid_targets_img)
    # plt.show()

# %%
def training_loop(CFG):
    best_score_list = []
    best_threshold_list = []
    best_epoch_list = []
    slice_ave_score_list = []
    slice_ave_auc_list = []
    slice_ave_score_threshold_list = []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} training start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        model = model.to(device)
        valid_img_slice = []
        criterion = nn.BCELoss()
        optimizer = AdamW(model.parameters(), lr=CFG["lr"], weight_decay=CFG["weight_decay"], amsgrad=False)
        scheduler = CosineAnnealingLR(optimizer, T_max=CFG["T_max"], eta_min=CFG["min_lr"], last_epoch=-1)
        # scheduler = ExponentialLR(optimizer, gamma=0.60)
        
        # training
        best_score = -np.inf
        best_auc = -np.inf
        best_valloss = np.inf
        best_auc_valloss = np.inf
        best_threshold = -1
        start_time = time.time()
        best_epoch = -1
        best_auc_epoch = -1
        valid_slice_ave = None       
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            # separate train/valid data 
            train_dirs = CFG["TRAIN_DIR_LIST"][fold]
            valid_dirs = CFG["VALID_DIR_LIST"][fold]
            train_dataset = VCID_Dataset(CFG, train_dirs, surface_list, mode="train", transform=train_transforms)
            valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, mode="valid", transform=valid_transforms)
            train_loader = DataLoader(train_dataset, batch_size=CFG["batch_size"], shuffle = True,
                                        num_workers = CFG["num_workers"], pin_memory = True)
            valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                        num_workers = CFG["num_workers"], pin_memory = True)
            for epoch in range(1, CFG["n_epoch"] + 1):
                epochs_ = epoch + CFG["n_epoch"] * slice_idx
                print(f'- epoch:{epochs_} -')
                train_loss_avg = train_fn(train_loader, model, criterion, epochs_ ,optimizer, scheduler)
                valid_targets, valid_preds, valid_grid_idx, valid_loss_avg = valid_fn(model, valid_loader, criterion)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                
                elapsed = time.time() - start_time
                print(f"\t epoch:{epochs_}, avg train loss:{train_loss_avg:.4f}, avg valid loss:{valid_loss_avg:.4f}")
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                if not CFG["DEBUG"]:
                    logging_metrics_epoch(CFG, fold, epoch, slice_idx, train_loss_avg, valid_loss_avg, valid_score, valid_threshold, auc)
                scheduler.step()
                # validationスコアがbestを更新したらモデルを保存する
                if valid_score > best_score:
                    best_epoch = epochs_
                    best_valloss = valid_loss_avg
                    best_score = valid_score
                    best_threshold = valid_threshold
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epochs_} - Save Best Score: {best_score:.4f}. Model is saved.')
                    print("dice_list: ", dice_list)
                    # save oof
                    save_and_plot_oof("score", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
                
                if auc > best_auc:
                    best_auc = auc
                    best_auc_epoch = epochs_
                    best_auc_valloss = valid_loss_avg
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_auc_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epochs_} - Save Best AUC: {best_auc:.4f}. Model is saved.')
                    # save oof
                    save_and_plot_oof("auc", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
            # valid_img_slice.append(valid_preds_img)
            if valid_slice_ave is None:
                valid_slice_ave = valid_preds_img
            else:
                valid_slice_ave += valid_preds_img
        # valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        # for idx in range(len(SURFACE_LIST)):
        #     valid_pred_slice = valid_img_slice[idx]
        #     valid_slice_ave += valid_pred_slice
        valid_slice_ave /= len(SURFACE_LIST)
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_slice_ave)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)
 
        valid_slice_binary = (valid_slice_ave > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 999, valid_slice_ave, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
        
        print(f'[fold{fold}] BEST Epoch {best_epoch} - Save Best Score:{best_score:.4f}. Best loss:{best_valloss:.4f}')
        print(f'[fold{fold}] BEST AUC Epoch {best_auc_epoch} - Save Best Score:{best_auc:.4f}. Best loss:{best_auc_valloss:.4f}')
            
        best_score_list.append(best_score)
        best_threshold_list.append(best_threshold)
        best_epoch_list.append(best_epoch)
        del model, train_loader, train_dataset, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
        
    for fold, (best_score, best_threshold, best_epoch) in enumerate(zip(best_score_list, best_threshold_list, best_epoch_list)):
        print(f"fold[{fold}] BEST SCORE = {best_score:.4f} thr={best_threshold} (epoch={best_epoch})")
        print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    return best_score_list, best_threshold_list, best_epoch_list

# %% [markdown]
# # slice inference

# %%
def slide_inference(CFG):
    start_time = time.time()
    slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list = [], [], []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} slide inference start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        # model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_fold{fold}.pth')
        model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_auc_fold{fold}.pth')
        model.load_state_dict(torch.load(model_path))
        model = model.to(device)
        valid_img_slice = None
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            surface_volumes = None
            for slide_pos in CFG["slide_pos_list"]:
                print("slide pos:", slide_pos)
                valid_dirs = CFG["VALID_DIR_LIST"][fold]
                valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos, mode="valid", transform=valid_transforms)
                surface_volumes = valid_dataset.get_surface_volumes()
                valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                            num_workers = CFG["num_workers"], pin_memory = True)

                valid_targets, valid_preds, valid_grid_idx = valid_fn(model, valid_loader)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs, slide_pos)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                save_and_plot_oof("slide", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary) 
                
                elapsed = time.time() - start_time
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                # valid_img_slice.append(valid_preds_img)
                if valid_img_slice is None:
                    valid_img_slice = valid_preds_img
                else:
                    valid_img_slice += valid_preds_img
            # valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        # for idx in range(len(SURFACE_LIST)*len(CFG["slide_pos_list"])):
        #     valid_pred_slice = valid_img_slice[idx]
        #     valid_slice_ave += valid_pred_slice
        valid_img_slice /= len(SURFACE_LIST)*len(CFG["slide_pos_list"])
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_img_slice)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)

        valid_slice_binary = (valid_img_slice > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 555, valid_img_slice, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
         
        del model, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
    return slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list

# %% [markdown]
# # main

# %%
# %%time
best_score_list, best_threshold_list, best_epoch_list = training_loop(CFG)
# Out:
# -- fold0 training start --
# surface_list:  [26, 29, 32, 35]
# - epoch:1 -
# Epoch: [1][0/61] Elapsed 0m 1s (remain 1m 19s) Loss: 0.7965(0.7965)
# Epoch: [1][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.4486(0.4742)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1416(0.1416)
# EVAL: [13/14] Elapsed 0m 2s (remain 0m 0s) Loss: 0.4606(0.3188)
# 	 epoch:1, avg train loss:0.4742, avg valid loss:0.3188
# 	 score:0.3783(th=0.550000), auc=0.855264::: time:75.10s
# Epoch 1 - Save Best Score: 0.3783. Model is saved.
# dice_list:  [0.23347098737298203, 0.26480648999593714, 0.2911579651229616, 0.31332195751425707, 0.3320094014353119, 0.3475000545692881, 0.36013712717352264, 0.36965794167812804, 0.3759912156123552, 0.37826828842949656, 0.37600415860363995, 0.3667877784352693, 0.34799109867222866, 0.31506847253248926, 0.26378399053702917, 0.18814257005015592, 0.09504064838513478, 0.017953680122970113, 0.0]
# Epoch 1 - Save Best AUC: 0.8553. Model is saved.
# - epoch:2 -
# Epoch: [2][0/61] Elapsed 0m 1s (remain 1m 30s) Loss: 0.4505(0.4505)
# Epoch: [2][60/61] Elapsed 0m 34s (remain 0m 0s) Loss: 0.4217(0.4064)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1961(0.1961)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3997(0.3352)
# 	 epoch:2, avg train loss:0.4064, avg valid loss:0.3352
# 	 score:0.3854(th=0.600000), auc=0.859572::: time:128.95s
# Epoch 2 - Save Best Score: 0.3854. Model is saved.
# dice_list:  [0.21145408203687158, 0.24209417251711818, 0.269469301736036, 0.2942252986278107, 0.31631270886939855, 0.33598438702743444, 0.35313443440006487, 0.36738160617048415, 0.3782696996752855, 0.38491388289906875, 0.3853549472640842, 0.3760631512597104, 0.35249324020899603, 0.31132614267889835, 0.24918151582914763, 0.16670745913698065, 0.08142669567740629, 0.016879627480102664, 0.0]
# Epoch 2 - Save Best AUC: 0.8596. Model is saved.
# - epoch:3 -
# Epoch: [3][0/61] Elapsed 0m 1s (remain 1m 38s) Loss: 0.3472(0.3472)
# Epoch: [3][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.4788(0.3850)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1909(0.1909)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3576(0.2992)
# 	 epoch:3, avg train loss:0.3850, avg valid loss:0.2992
# 	 score:0.4843(th=0.600000), auc=0.885013::: time:176.06s
# Epoch 3 - Save Best Score: 0.4843. Model is saved.
# dice_list:  [0.2177925481494196, 0.25572631218899045, 0.29245909663421954, 0.3269562958072514, 0.3583710104913637, 0.3873671032233298, 0.415120391664359, 0.4411020900456792, 0.4634700043740555, 0.47871070555655715, 0.48427842127345794, 0.47614628923888197, 0.45229109357420444, 0.40776585480425753, 0.33584199678293053, 0.23896671363130906, 0.12726259070475396, 0.03277649311680241, 0.0]
# Epoch 3 - Save Best AUC: 0.8850. Model is saved.
# - epoch:4 -
# Epoch: [4][0/61] Elapsed 0m 1s (remain 1m 31s) Loss: 0.3372(0.3372)
# Epoch: [4][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3761(0.3518)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1592(0.1592)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3720(0.2770)
# 	 epoch:4, avg train loss:0.3518, avg valid loss:0.2770
# 	 score:0.4853(th=0.500000), auc=0.886490::: time:223.18s
# Epoch 4 - Save Best Score: 0.4853. Model is saved.
# dice_list:  [0.24028926546759208, 0.29737631744950105, 0.34783919946192354, 0.39070950627688733, 0.42538147586586783, 0.4512175603054474, 0.46973937308288854, 0.4814745660747141, 0.4852865261507893, 0.4778191802324768, 0.4547743759527928, 0.41370012262669703, 0.354606700744101, 0.2760106144957169, 0.18611283403531612, 0.1046596550876929, 0.045470287684433716, 0.011103313261006316, 0.0]
# Epoch 4 - Save Best AUC: 0.8865. Model is saved.
# - epoch:5 -
# Epoch: [5][0/61] Elapsed 0m 1s (remain 1m 25s) Loss: 0.3202(0.3202)
# Epoch: [5][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2519(0.3272)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1711(0.1711)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3495(0.2761)
# 	 epoch:5, avg train loss:0.3272, avg valid loss:0.2761
# 	 score:0.4942(th=0.550000), auc=0.887786::: time:270.36s
# Epoch 5 - Save Best Score: 0.4942. Model is saved.
# dice_list:  [0.2568094184883139, 0.30819322630163243, 0.35117030727993453, 0.38822008482114956, 0.4188210541164387, 0.44339495857148414, 0.46345406865441835, 0.4799706239981744, 0.491006560829898, 0.4942106585161281, 0.48683525162182717, 0.462883099145469, 0.4193757531808874, 0.3520552031185693, 0.25501758275941544, 0.13611542213413177, 0.039100043261239795, 0.0006754301506594303, 0.0]
# Epoch 5 - Save Best AUC: 0.8878. Model is saved.
# - epoch:6 -
# Epoch: [6][0/61] Elapsed 0m 1s (remain 1m 29s) Loss: 0.3064(0.3064)
# Epoch: [6][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3280(0.3226)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1681(0.1681)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3518(0.2753)
# 	 epoch:6, avg train loss:0.3226, avg valid loss:0.2753
# 	 score:0.4913(th=0.550000), auc=0.887601::: time:318.05s
# - epoch:7 -
# Epoch: [7][0/61] Elapsed 0m 1s (remain 1m 21s) Loss: 0.2359(0.2359)
# Epoch: [7][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2126(0.3168)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1530(0.1530)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3516(0.2738)
# 	 epoch:7, avg train loss:0.3168, avg valid loss:0.2738
# 	 score:0.5110(th=0.600000), auc=0.889962::: time:361.47s
# Epoch 7 - Save Best Score: 0.5110. Model is saved.
# dice_list:  [0.26523283822535376, 0.3206303509051234, 0.3670235945350244, 0.4038580396538436, 0.43280678056419036, 0.45597513320374766, 0.4743765385300192, 0.48923644750662104, 0.5008134441471389, 0.5084368174304882, 0.5110167798167267, 0.5065999436802242, 0.49234038340237934, 0.46547793827135225, 0.4225188800928951, 0.3536314040115926, 0.2402382871275156, 0.0924136834030017, 0.0]
# Epoch 7 - Save Best AUC: 0.8900. Model is saved.
# - epoch:8 -
# Epoch: [8][0/61] Elapsed 0m 1s (remain 1m 29s) Loss: 0.1951(0.1951)
# Epoch: [8][60/61] Elapsed 0m 30s (remain 0m 0s) Loss: 0.4346(0.3155)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1904(0.1904)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3351(0.2879)
# 	 epoch:8, avg train loss:0.3155, avg valid loss:0.2879
# 	 score:0.4857(th=0.650000), auc=0.890915::: time:410.53s
# Epoch 8 - Save Best AUC: 0.8909. Model is saved.
# - epoch:9 -
# Epoch: [9][0/61] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2922(0.2922)
# Epoch: [9][60/61] Elapsed 0m 30s (remain 0m 0s) Loss: 0.2276(0.3364)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2347(0.2347)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3658(0.3259)
# 	 epoch:9, avg train loss:0.3364, avg valid loss:0.3259
# 	 score:0.5200(th=0.800000), auc=0.895012::: time:459.52s
# Epoch 9 - Save Best Score: 0.5200. Model is saved.
# dice_list:  [0.24673797957655053, 0.2848746967040135, 0.31825573519715317, 0.34663641071634066, 0.3709164676473782, 0.3923478837454972, 0.41215879604313105, 0.4311482695620211, 0.4495045248584803, 0.46664433456168347, 0.48178438491359354, 0.49537244400876707, 0.5065753095136082, 0.5150743793892287, 0.519965776643972, 0.5182659939624077, 0.5042564538109068, 0.4541511118976378, 0.0]
# Epoch 9 - Save Best AUC: 0.8950. Model is saved.
# - epoch:10 -
# Epoch: [10][0/61] Elapsed 0m 1s (remain 1m 16s) Loss: 0.3103(0.3103)
# Epoch: [10][60/61] Elapsed 0m 32s (remain 0m 0s) Loss: 0.3511(0.3335)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1355(0.1355)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3804(0.2714)
# 	 epoch:10, avg train loss:0.3335, avg valid loss:0.2714
# 	 score:0.5094(th=0.500000), auc=0.886101::: time:511.30s
# - epoch:11 -
# Epoch: [11][0/61] Elapsed 0m 1s (remain 1m 21s) Loss: 0.2466(0.2466)
# Epoch: [11][60/61] Elapsed 0m 29s (remain 0m 0s) Loss: 0.4092(0.3366)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1446(0.1446)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4107(0.2763)
# 	 epoch:11, avg train loss:0.3366, avg valid loss:0.2763
# 	 score:0.5182(th=0.550000), auc=0.883474::: time:555.89s
# - epoch:12 -
# Epoch: [12][0/61] Elapsed 0m 1s (remain 1m 23s) Loss: 0.3852(0.3852)
# Epoch: [12][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3107(0.3130)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.2939(0.2939)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3539(0.3229)
# 	 epoch:12, avg train loss:0.3130, avg valid loss:0.3229
# 	 score:0.4480(th=0.700000), auc=0.883008::: time:599.73s
# - epoch:13 -
# Epoch: [13][0/61] Elapsed 0m 1s (remain 1m 21s) Loss: 0.3333(0.3333)
# Epoch: [13][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2481(0.3017)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1745(0.1745)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3152(0.2720)
# 	 epoch:13, avg train loss:0.3017, avg valid loss:0.2720
# 	 score:0.5174(th=0.550000), auc=0.884192::: time:643.11s
# - epoch:14 -
# Epoch: [14][0/61] Elapsed 0m 1s (remain 1m 19s) Loss: 0.3140(0.3140)
# Epoch: [14][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2296(0.2805)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1820(0.1820)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3336(0.3037)
# 	 epoch:14, avg train loss:0.2805, avg valid loss:0.3037
# 	 score:0.5035(th=0.700000), auc=0.888852::: time:686.21s
# - epoch:15 -
# Epoch: [15][0/61] Elapsed 0m 1s (remain 1m 22s) Loss: 0.2779(0.2779)
# Epoch: [15][60/61] Elapsed 0m 30s (remain 0m 0s) Loss: 0.2107(0.2556)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1543(0.1543)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3169(0.2814)
# 	 epoch:15, avg train loss:0.2556, avg valid loss:0.2814
# 	 score:0.4978(th=0.600000), auc=0.885993::: time:731.96s
# surface_list:  [27, 30, 33, 36]
# - epoch:16 -
# Epoch: [16][0/61] Elapsed 0m 1s (remain 1m 16s) Loss: 0.3063(0.3063)
# Epoch: [16][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3996(0.2606)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1542(0.1542)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3186(0.2877)
# 	 epoch:16, avg train loss:0.2606, avg valid loss:0.2877
# 	 score:0.4991(th=0.600000), auc=0.871376::: time:807.84s
# - epoch:17 -
# Epoch: [17][0/61] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2278(0.2278)
# Epoch: [17][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2069(0.2610)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1871(0.1871)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3146(0.2975)
# 	 epoch:17, avg train loss:0.2610, avg valid loss:0.2975
# 	 score:0.4900(th=0.700000), auc=0.874258::: time:851.08s
# - epoch:18 -
# Epoch: [18][0/61] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2618(0.2618)
# Epoch: [18][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2389(0.2512)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.2033(0.2033)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3114(0.3045)
# 	 epoch:18, avg train loss:0.2512, avg valid loss:0.3045
# 	 score:0.4891(th=0.700000), auc=0.884489::: time:894.66s
# - epoch:19 -
# Epoch: [19][0/61] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2515(0.2515)
# Epoch: [19][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3375(0.2734)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1402(0.1402)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4528(0.3097)
# 	 epoch:19, avg train loss:0.2734, avg valid loss:0.3097
# 	 score:0.4859(th=0.600000), auc=0.861509::: time:938.20s
# - epoch:20 -
# Epoch: [20][0/61] Elapsed 0m 1s (remain 1m 19s) Loss: 0.3348(0.3348)
# Epoch: [20][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2994(0.2890)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1272(0.1272)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3848(0.2876)
# 	 epoch:20, avg train loss:0.2890, avg valid loss:0.2876
# 	 score:0.4759(th=0.500000), auc=0.873744::: time:981.59s
# - epoch:21 -
# Epoch: [21][0/61] Elapsed 0m 1s (remain 1m 21s) Loss: 0.2259(0.2259)
# Epoch: [21][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2838(0.2793)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1856(0.1856)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3464(0.2959)
# 	 epoch:21, avg train loss:0.2793, avg valid loss:0.2959
# 	 score:0.4893(th=0.650000), auc=0.888163::: time:1024.84s
# - epoch:22 -
# Epoch: [22][0/61] Elapsed 0m 1s (remain 1m 25s) Loss: 0.2418(0.2418)
# Epoch: [22][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.4411(0.2811)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.2262(0.2262)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3705(0.3192)
# 	 epoch:22, avg train loss:0.2811, avg valid loss:0.3192
# 	 score:0.5200(th=0.800000), auc=0.885811::: time:1068.19s
# Epoch 22 - Save Best Score: 0.5200. Model is saved.
# dice_list:  [0.27371174731429304, 0.30010420316304626, 0.322476377630423, 0.34280301384524037, 0.36352911155557593, 0.3829175064870511, 0.4007363931983193, 0.41960175447656095, 0.4391892462104904, 0.45698522083183923, 0.47352442331594086, 0.4892481918939321, 0.5042381024913856, 0.5166843216959071, 0.5200411918201467, 0.5100042700101417, 0.4833878668817031, 0.3775506400796557, 0.0]
# - epoch:23 -
# Epoch: [23][0/61] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2014(0.2014)
# Epoch: [23][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1519(0.2617)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1388(0.1388)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4059(0.2816)
# 	 epoch:23, avg train loss:0.2617, avg valid loss:0.2816
# 	 score:0.5392(th=0.600000), auc=0.882392::: time:1112.77s
# Epoch 23 - Save Best Score: 0.5392. Model is saved.
# dice_list:  [0.30464872070977767, 0.35223823353513806, 0.389273984529009, 0.4212015540652203, 0.4489557751877148, 0.47340720612407766, 0.49381606092410546, 0.5108248520860253, 0.5243793152205014, 0.534307753817614, 0.5391651952918572, 0.537902293383242, 0.5282758645955649, 0.5097914750660552, 0.48434253653475395, 0.4499716488082612, 0.39633135593966595, 0.2771459966129831, 0.0]
# - epoch:24 -
# Epoch: [24][0/61] Elapsed 0m 1s (remain 1m 20s) Loss: 0.1980(0.1980)
# Epoch: [24][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1521(0.2283)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1777(0.1777)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3970(0.2845)
# 	 epoch:24, avg train loss:0.2283, avg valid loss:0.2845
# 	 score:0.5267(th=0.650000), auc=0.885950::: time:1157.58s
# - epoch:25 -
# Epoch: [25][0/61] Elapsed 0m 1s (remain 1m 14s) Loss: 0.2383(0.2383)
# Epoch: [25][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.1581(0.2239)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.2083(0.2083)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3815(0.3063)
# 	 epoch:25, avg train loss:0.2239, avg valid loss:0.3063
# 	 score:0.5303(th=0.800000), auc=0.884899::: time:1200.46s
# - epoch:26 -
# Epoch: [26][0/61] Elapsed 0m 1s (remain 1m 21s) Loss: 0.3318(0.3318)
# Epoch: [26][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2640(0.2129)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.2227(0.2227)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3743(0.3146)
# 	 epoch:26, avg train loss:0.2129, avg valid loss:0.3146
# 	 score:0.5244(th=0.800000), auc=0.884373::: time:1243.70s
# - epoch:27 -
# Epoch: [27][0/61] Elapsed 0m 1s (remain 1m 22s) Loss: 0.1588(0.1588)
# Epoch: [27][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2300(0.2164)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.2117(0.2117)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3831(0.3113)
# 	 epoch:27, avg train loss:0.2164, avg valid loss:0.3113
# 	 score:0.5247(th=0.800000), auc=0.883159::: time:1287.36s
# - epoch:28 -
# Epoch: [28][0/61] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2468(0.2468)
# Epoch: [28][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.1967(0.2059)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1464(0.1464)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4585(0.2912)
# 	 epoch:28, avg train loss:0.2059, avg valid loss:0.2912
# 	 score:0.5428(th=0.700000), auc=0.881418::: time:1330.68s
# Epoch 28 - Save Best Score: 0.5428. Model is saved.
# dice_list:  [0.33085673510039637, 0.36709759453167157, 0.39697212974008983, 0.4220748610064132, 0.4461032902335646, 0.46763355266170803, 0.4859736525967363, 0.501025874864689, 0.5130449962756349, 0.5239097170133545, 0.5327776305873493, 0.5400926505008076, 0.5427856762417725, 0.5393483256054193, 0.527066993283136, 0.5005854897556676, 0.45073538164123744, 0.3393963245520058, 0.0]
# - epoch:29 -
# Epoch: [29][0/61] Elapsed 0m 1s (remain 1m 15s) Loss: 0.1929(0.1929)
# Epoch: [29][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2480(0.2267)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1575(0.1575)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4948(0.3023)
# 	 epoch:29, avg train loss:0.2267, avg valid loss:0.3023
# 	 score:0.5161(th=0.700000), auc=0.884303::: time:1375.39s
# - epoch:30 -
# Epoch: [30][0/61] Elapsed 0m 1s (remain 1m 13s) Loss: 0.2204(0.2204)
# Epoch: [30][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.1579(0.2426)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1774(0.1774)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3815(0.3085)
# 	 epoch:30, avg train loss:0.2426, avg valid loss:0.3085
# 	 score:0.4541(th=0.650000), auc=0.884071::: time:1418.18s
# surface_list:  [25, 28, 31, 34]
# - epoch:31 -
# Epoch: [31][0/61] Elapsed 0m 1s (remain 1m 20s) Loss: 0.3268(0.3268)
# Epoch: [31][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2810(0.2970)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1802(0.1802)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3946(0.2806)
# 	 epoch:31, avg train loss:0.2970, avg valid loss:0.2806
# 	 score:0.5273(th=0.550000), auc=0.877281::: time:1495.27s
# - epoch:32 -
# Epoch: [32][0/61] Elapsed 0m 1s (remain 1m 26s) Loss: 0.2521(0.2521)
# Epoch: [32][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.1823(0.2676)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2920(0.2920)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3474(0.3197)
# 	 epoch:32, avg train loss:0.2676, avg valid loss:0.3197
# 	 score:0.5119(th=0.750000), auc=0.886856::: time:1538.85s
# - epoch:33 -
# Epoch: [33][0/61] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2146(0.2146)
# Epoch: [33][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2405(0.2555)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1442(0.1442)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3092(0.2777)
# 	 epoch:33, avg train loss:0.2555, avg valid loss:0.2777
# 	 score:0.5535(th=0.700000), auc=0.891860::: time:1582.36s
# Epoch 33 - Save Best Score: 0.5535. Model is saved.
# dice_list:  [0.3018410936804481, 0.3411016618400594, 0.3741530947346683, 0.40264207420469067, 0.4265593476763276, 0.4484441218431139, 0.4681616008141459, 0.48779257597267106, 0.5070584641643838, 0.5248489646042072, 0.5410381999552583, 0.5519389425792359, 0.5534694451645136, 0.5409859800844559, 0.5137960000322225, 0.4680308094084892, 0.39702004614254727, 0.2410648872807356, 0.0]
# - epoch:34 -
# Epoch: [34][0/61] Elapsed 0m 1s (remain 1m 16s) Loss: 0.2576(0.2576)
# Epoch: [34][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1507(0.2229)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1528(0.1528)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3857(0.2832)
# 	 epoch:34, avg train loss:0.2229, avg valid loss:0.2832
# 	 score:0.5308(th=0.700000), auc=0.887310::: time:1627.59s
# - epoch:35 -
# Epoch: [35][0/61] Elapsed 0m 1s (remain 1m 18s) Loss: 0.3253(0.3253)
# Epoch: [35][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2261(0.2093)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1587(0.1587)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3817(0.2857)
# 	 epoch:35, avg train loss:0.2093, avg valid loss:0.2857
# 	 score:0.5272(th=0.700000), auc=0.889969::: time:1671.36s
# - epoch:36 -
# Epoch: [36][0/61] Elapsed 0m 1s (remain 1m 22s) Loss: 0.1915(0.1915)
# Epoch: [36][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1959(0.2056)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1657(0.1657)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3741(0.2919)
# 	 epoch:36, avg train loss:0.2056, avg valid loss:0.2919
# 	 score:0.5214(th=0.750000), auc=0.888588::: time:1715.06s
# - epoch:37 -
# Epoch: [37][0/61] Elapsed 0m 1s (remain 1m 22s) Loss: 0.1615(0.1615)
# Epoch: [37][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.1691(0.2048)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1966(0.1966)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3387(0.3150)
# 	 epoch:37, avg train loss:0.2048, avg valid loss:0.3150
# 	 score:0.5384(th=0.850000), auc=0.892281::: time:1758.33s
# - epoch:38 -
# Epoch: [38][0/61] Elapsed 0m 1s (remain 1m 16s) Loss: 0.4289(0.4289)
# Epoch: [38][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2769(0.2129)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1824(0.1824)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3759(0.3004)
# 	 epoch:38, avg train loss:0.2129, avg valid loss:0.3004
# 	 score:0.5231(th=0.800000), auc=0.883156::: time:1801.63s
# - epoch:39 -
# Epoch: [39][0/61] Elapsed 0m 1s (remain 1m 22s) Loss: 0.2530(0.2530)
# Epoch: [39][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.1994(0.2170)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1731(0.1731)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3727(0.3116)
# 	 epoch:39, avg train loss:0.2170, avg valid loss:0.3116
# 	 score:0.5483(th=0.800000), auc=0.893771::: time:1844.65s
# - epoch:40 -
# Epoch: [40][0/61] Elapsed 0m 1s (remain 1m 20s) Loss: 0.1602(0.1602)
# Epoch: [40][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2113(0.2298)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1154(0.1154)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4336(0.2677)
# 	 epoch:40, avg train loss:0.2298, avg valid loss:0.2677
# 	 score:0.5096(th=0.450000), auc=0.893087::: time:1887.63s
# - epoch:41 -
# Epoch: [41][0/61] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2691(0.2691)
# Epoch: [41][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.1758(0.2235)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1191(0.1191)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3867(0.2806)
# 	 epoch:41, avg train loss:0.2235, avg valid loss:0.2806
# 	 score:0.5392(th=0.650000), auc=0.893071::: time:1930.60s
# - epoch:42 -
# Epoch: [42][0/61] Elapsed 0m 1s (remain 1m 22s) Loss: 0.1803(0.1803)
# Epoch: [42][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1917(0.2271)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1735(0.1735)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4153(0.3079)
# 	 epoch:42, avg train loss:0.2271, avg valid loss:0.3079
# 	 score:0.5374(th=0.800000), auc=0.885603::: time:1973.98s
# - epoch:43 -
# Epoch: [43][0/61] Elapsed 0m 1s (remain 1m 23s) Loss: 0.2117(0.2117)
# Epoch: [43][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2222(0.2170)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1366(0.1366)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3689(0.2831)
# 	 epoch:43, avg train loss:0.2170, avg valid loss:0.2831
# 	 score:0.5528(th=0.800000), auc=0.898784::: time:2017.53s
# Epoch 43 - Save Best AUC: 0.8988. Model is saved.
# - epoch:44 -
# Epoch: [44][0/61] Elapsed 0m 1s (remain 1m 23s) Loss: 0.1845(0.1845)
# Epoch: [44][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.1977(0.1877)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1895(0.1895)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3317(0.2875)
# 	 epoch:44, avg train loss:0.1877, avg valid loss:0.2875
# 	 score:0.5431(th=0.750000), auc=0.894996::: time:2061.97s
# - epoch:45 -
# Epoch: [45][0/61] Elapsed 0m 1s (remain 1m 23s) Loss: 0.1366(0.1366)
# Epoch: [45][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.1301(0.1817)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1644(0.1644)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3597(0.2957)
# 	 epoch:45, avg train loss:0.1817, avg valid loss:0.2957
# 	 score:0.5488(th=0.800000), auc=0.893132::: time:2105.09s
# [fold0] slice ave score:0.5292(th=0.600000), auc=0.896648
# [fold0] BEST Epoch 33 - Save Best Score:0.5535. Best loss:0.2777
# [fold0] BEST AUC Epoch 43 - Save Best Score:0.8988. Best loss:0.2831
# -- fold1 training start --
# surface_list:  [26, 29, 32, 35]
# - epoch:1 -
# Epoch: [1][0/57] Elapsed 0m 1s (remain 1m 13s) Loss: 0.9193(0.9193)
# Epoch: [1][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2684(0.4817)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6748(0.6748)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1133(0.4336)
# 	 epoch:1, avg train loss:0.4817, avg valid loss:0.4336
# 	 score:0.3932(th=0.200000), auc=0.775972::: time:78.96s
# Epoch 1 - Save Best Score: 0.3932. Model is saved.
# dice_list:  [0.32598780539029126, 0.3725604125669179, 0.3932368802679251, 0.3902704243004646, 0.36734517474777884, 0.32935225959388764, 0.2825694738632587, 0.23198863690470606, 0.18197460622085682, 0.13544253492022437, 0.09357182423951953, 0.05837839497044262, 0.0316864204615304, 0.013980916159661181, 0.004396318196072006, 0.0009470875181551776, 0.00015847278058407237, 2.5217265126464375e-05, 0.0]
# Epoch 1 - Save Best AUC: 0.7760. Model is saved.
# - epoch:2 -
# Epoch: [2][0/57] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2613(0.2613)
# Epoch: [2][56/57] Elapsed 0m 32s (remain 0m 0s) Loss: 0.2446(0.3737)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.6211(0.6211)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0986(0.4009)
# 	 epoch:2, avg train loss:0.3737, avg valid loss:0.4009
# 	 score:0.4740(th=0.300000), auc=0.807120::: time:137.65s
# Epoch 2 - Save Best Score: 0.4740. Model is saved.
# dice_list:  [0.3307539756919417, 0.4023347945701624, 0.44856963958656715, 0.4707936513940467, 0.47400734315696286, 0.4604969023166977, 0.4320856529428262, 0.38808799420733153, 0.32913390165631884, 0.2581793844864014, 0.18144726782178605, 0.10880059816382932, 0.052216492995264915, 0.01768491974897612, 0.0036957703767998215, 0.0005012329844236257, 7.4929544680999e-05, 1.5851589169417834e-05, 0.0]
# Epoch 2 - Save Best AUC: 0.8071. Model is saved.
# - epoch:3 -
# Epoch: [3][0/57] Elapsed 0m 1s (remain 1m 11s) Loss: 0.2594(0.2594)
# Epoch: [3][56/57] Elapsed 0m 29s (remain 0m 0s) Loss: 0.1667(0.3519)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5921(0.5921)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1297(0.3838)
# 	 epoch:3, avg train loss:0.3519, avg valid loss:0.3838
# 	 score:0.4824(th=0.350000), auc=0.825637::: time:191.01s
# Epoch 3 - Save Best Score: 0.4824. Model is saved.
# dice_list:  [0.335089065771808, 0.3903345131885278, 0.430146501239823, 0.45754794885998995, 0.47455289015308216, 0.4824352752613823, 0.48206886663049625, 0.4725591069122826, 0.4525555807134782, 0.4223035257948921, 0.38329211226942983, 0.33595096084390835, 0.27993939043061766, 0.21673688477655909, 0.15029894025337714, 0.08688028716652112, 0.038950667291979865, 0.008583037253875122, 0.0]
# Epoch 3 - Save Best AUC: 0.8256. Model is saved.
# - epoch:4 -
# Epoch: [4][0/57] Elapsed 0m 1s (remain 1m 10s) Loss: 0.2524(0.2524)
# Epoch: [4][56/57] Elapsed 0m 32s (remain 0m 0s) Loss: 0.1962(0.3133)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5249(0.5249)
# EVAL: [18/19] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1139(0.3669)
# 	 epoch:4, avg train loss:0.3133, avg valid loss:0.3669
# 	 score:0.5359(th=0.400000), auc=0.845697::: time:247.70s
# Epoch 4 - Save Best Score: 0.5359. Model is saved.
# dice_list:  [0.36896665392843153, 0.4327052841757292, 0.4774697154238252, 0.5067795657587495, 0.5244949464523, 0.5338853212690544, 0.5358651787401423, 0.5286297593431437, 0.5097602375702551, 0.478727390641795, 0.4369958927658799, 0.3837119111901536, 0.31868408024741224, 0.2442347423555099, 0.16175845211297252, 0.08298492317099523, 0.02408248469744724, 0.000501292058464062, 0.0]
# Epoch 4 - Save Best AUC: 0.8457. Model is saved.
# - epoch:5 -
# Epoch: [5][0/57] Elapsed 0m 1s (remain 1m 21s) Loss: 0.3487(0.3487)
# Epoch: [5][56/57] Elapsed 0m 32s (remain 0m 0s) Loss: 0.5305(0.3020)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5688(0.5688)
# EVAL: [18/19] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1060(0.3750)
# 	 epoch:5, avg train loss:0.3020, avg valid loss:0.3750
# 	 score:0.5470(th=0.350000), auc=0.840887::: time:303.91s
# Epoch 5 - Save Best Score: 0.5470. Model is saved.
# dice_list:  [0.40516651863963826, 0.4766738859265471, 0.5156452642868234, 0.5350674420355467, 0.5443170216583028, 0.5469725520662373, 0.5432252766621473, 0.5334206319022837, 0.517645142827568, 0.4966376733829035, 0.47020436273931665, 0.43798933234714377, 0.39902417824711983, 0.35079760043805625, 0.2927015198282, 0.22463282153510267, 0.135908777684712, 0.03827028309787087, 0.0]
# - epoch:6 -
# Epoch: [6][0/57] Elapsed 0m 1s (remain 1m 9s) Loss: 0.1953(0.1953)
# Epoch: [6][56/57] Elapsed 0m 29s (remain 0m 0s) Loss: 0.2040(0.2845)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5348(0.5348)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1036(0.3669)
# 	 epoch:6, avg train loss:0.2845, avg valid loss:0.3669
# 	 score:0.5516(th=0.400000), auc=0.843944::: time:355.73s
# Epoch 6 - Save Best Score: 0.5516. Model is saved.
# dice_list:  [0.38740522407618183, 0.45577333277061266, 0.49933894852275457, 0.5251375916586379, 0.5391027005954391, 0.5474504872426408, 0.5515917627607498, 0.5501589856125308, 0.5418067151006584, 0.5273900790443834, 0.5063666823334206, 0.47933427513929316, 0.44512260514781304, 0.40351221825757777, 0.34972853062419074, 0.28263243969704455, 0.19634329570990286, 0.0656122669379905, 0.0]
# - epoch:7 -
# Epoch: [7][0/57] Elapsed 0m 1s (remain 1m 14s) Loss: 0.2592(0.2592)
# Epoch: [7][56/57] Elapsed 0m 32s (remain 0m 0s) Loss: 0.4709(0.2917)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.6018(0.6018)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1127(0.3804)
# 	 epoch:7, avg train loss:0.2917, avg valid loss:0.3804
# 	 score:0.5296(th=0.400000), auc=0.835134::: time:410.43s
# - epoch:8 -
# Epoch: [8][0/57] Elapsed 0m 1s (remain 1m 15s) Loss: 0.1964(0.1964)
# Epoch: [8][56/57] Elapsed 0m 29s (remain 0m 0s) Loss: 0.2025(0.2999)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.6091(0.6091)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0912(0.3679)
# 	 epoch:8, avg train loss:0.2999, avg valid loss:0.3679
# 	 score:0.5372(th=0.400000), auc=0.846202::: time:459.62s
# Epoch 8 - Save Best AUC: 0.8462. Model is saved.
# - epoch:9 -
# Epoch: [9][0/57] Elapsed 0m 1s (remain 1m 20s) Loss: 0.3533(0.3533)
# Epoch: [9][56/57] Elapsed 0m 31s (remain 0m 0s) Loss: 0.3164(0.2970)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5380(0.5380)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0810(0.4154)
# 	 epoch:9, avg train loss:0.2970, avg valid loss:0.4154
# 	 score:0.4596(th=0.400000), auc=0.803309::: time:513.34s
# - epoch:10 -
# Epoch: [10][0/57] Elapsed 0m 1s (remain 1m 18s) Loss: 0.3050(0.3050)
# Epoch: [10][56/57] Elapsed 0m 29s (remain 0m 0s) Loss: 0.1871(0.3126)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5621(0.5621)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0746(0.3921)
# 	 epoch:10, avg train loss:0.3126, avg valid loss:0.3921
# 	 score:0.4809(th=0.450000), auc=0.813720::: time:562.38s
# - epoch:11 -
# Epoch: [11][0/57] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2594(0.2594)
# Epoch: [11][56/57] Elapsed 0m 31s (remain 0m 0s) Loss: 0.6203(0.3189)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.7197(0.7197)
# EVAL: [18/19] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0613(0.4283)
# 	 epoch:11, avg train loss:0.3189, avg valid loss:0.4283
# 	 score:0.5049(th=0.300000), auc=0.820085::: time:614.77s
# - epoch:12 -
# Epoch: [12][0/57] Elapsed 0m 1s (remain 1m 16s) Loss: 0.2164(0.2164)
# Epoch: [12][56/57] Elapsed 0m 27s (remain 0m 0s) Loss: 0.4225(0.3011)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5770(0.5770)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1141(0.3938)
# 	 epoch:12, avg train loss:0.3011, avg valid loss:0.3938
# 	 score:0.5187(th=0.300000), auc=0.830743::: time:662.39s
# - epoch:13 -
# Epoch: [13][0/57] Elapsed 0m 1s (remain 1m 10s) Loss: 0.4328(0.4328)
# Epoch: [13][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1756(0.2817)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5294(0.5294)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0717(0.3832)
# 	 epoch:13, avg train loss:0.2817, avg valid loss:0.3832
# 	 score:0.5560(th=0.500000), auc=0.845085::: time:706.81s
# Epoch 13 - Save Best Score: 0.5560. Model is saved.
# dice_list:  [0.41304830860346586, 0.4578119454816436, 0.4908123249952014, 0.5148376735135339, 0.5316607334408948, 0.543599206926651, 0.5515422049415387, 0.5557072006239281, 0.5560449260335442, 0.552304530364023, 0.5450343812776643, 0.5326115526337087, 0.5146262503258969, 0.4877504797334888, 0.4481912892751698, 0.3902799715343627, 0.30924595824363244, 0.17319730266780745, 0.0]
# - epoch:14 -
# Epoch: [14][0/57] Elapsed 0m 1s (remain 1m 17s) Loss: 0.1981(0.1981)
# Epoch: [14][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2230(0.2640)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5332(0.5332)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0760(0.4911)
# 	 epoch:14, avg train loss:0.2640, avg valid loss:0.4911
# 	 score:0.4156(th=0.700000), auc=0.800927::: time:752.15s
# - epoch:15 -
# Epoch: [15][0/57] Elapsed 0m 1s (remain 1m 13s) Loss: 0.1870(0.1870)
# Epoch: [15][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2262(0.2488)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5697(0.5697)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0650(0.3940)
# 	 epoch:15, avg train loss:0.2488, avg valid loss:0.3940
# 	 score:0.5296(th=0.500000), auc=0.844882::: time:795.44s
# surface_list:  [27, 30, 33, 36]
# - epoch:16 -
# Epoch: [16][0/57] Elapsed 0m 1s (remain 1m 7s) Loss: 0.2312(0.2312)
# Epoch: [16][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2255(0.2472)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5297(0.5297)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0658(0.3952)
# 	 epoch:16, avg train loss:0.2472, avg valid loss:0.3952
# 	 score:0.5177(th=0.550000), auc=0.839049::: time:872.90s
# - epoch:17 -
# Epoch: [17][0/57] Elapsed 0m 1s (remain 1m 13s) Loss: 0.2610(0.2610)
# Epoch: [17][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.3189(0.2435)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5725(0.5725)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0649(0.3913)
# 	 epoch:17, avg train loss:0.2435, avg valid loss:0.3913
# 	 score:0.5317(th=0.450000), auc=0.845163::: time:918.77s
# - epoch:18 -
# Epoch: [18][0/57] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2241(0.2241)
# Epoch: [18][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.5178(0.2455)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6343(0.6343)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0790(0.4302)
# 	 epoch:18, avg train loss:0.2455, avg valid loss:0.4302
# 	 score:0.5548(th=0.350000), auc=0.844925::: time:963.88s
# - epoch:19 -
# Epoch: [19][0/57] Elapsed 0m 1s (remain 1m 11s) Loss: 0.2530(0.2530)
# Epoch: [19][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1987(0.2829)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6800(0.6800)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0614(0.4029)
# 	 epoch:19, avg train loss:0.2829, avg valid loss:0.4029
# 	 score:0.5132(th=0.300000), auc=0.827142::: time:1008.06s
# - epoch:20 -
# Epoch: [20][0/57] Elapsed 0m 1s (remain 1m 13s) Loss: 0.2653(0.2653)
# Epoch: [20][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.6629(0.2781)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.7839(0.7839)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0488(0.4238)
# 	 epoch:20, avg train loss:0.2781, avg valid loss:0.4238
# 	 score:0.5490(th=0.300000), auc=0.843436::: time:1051.97s
# - epoch:21 -
# Epoch: [21][0/57] Elapsed 0m 1s (remain 1m 14s) Loss: 0.2199(0.2199)
# Epoch: [21][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.3419(0.3038)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5472(0.5472)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0987(0.4060)
# 	 epoch:21, avg train loss:0.3038, avg valid loss:0.4060
# 	 score:0.5171(th=0.400000), auc=0.818514::: time:1095.44s
# - epoch:22 -
# Epoch: [22][0/57] Elapsed 0m 1s (remain 1m 10s) Loss: 0.3139(0.3139)
# Epoch: [22][56/57] Elapsed 0m 23s (remain 0m 0s) Loss: 0.2356(0.2677)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5977(0.5977)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0664(0.3925)
# 	 epoch:22, avg train loss:0.2677, avg valid loss:0.3925
# 	 score:0.5322(th=0.400000), auc=0.834319::: time:1138.75s
# - epoch:23 -
# Epoch: [23][0/57] Elapsed 0m 1s (remain 1m 14s) Loss: 0.2134(0.2134)
# Epoch: [23][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1918(0.2531)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.8700(0.8700)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0941(0.4881)
# 	 epoch:23, avg train loss:0.2531, avg valid loss:0.4881
# 	 score:0.4608(th=0.300000), auc=0.797282::: time:1182.44s
# - epoch:24 -
# Epoch: [24][0/57] Elapsed 0m 1s (remain 1m 14s) Loss: 0.2151(0.2151)
# Epoch: [24][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.3820(0.2280)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6216(0.6216)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0724(0.3930)
# 	 epoch:24, avg train loss:0.2280, avg valid loss:0.3930
# 	 score:0.5883(th=0.400000), auc=0.854839::: time:1226.47s
# Epoch 24 - Save Best Score: 0.5883. Model is saved.
# dice_list:  [0.48623792925500997, 0.5264478778103517, 0.5520068962434778, 0.5679850517159521, 0.5802796521609195, 0.5872959156997439, 0.5882907515554788, 0.585214940793895, 0.5763566760252944, 0.5632857759912921, 0.5467388046032168, 0.5271387706914858, 0.5026958106829754, 0.470252096881962, 0.42558788953216176, 0.36109669511117654, 0.27132954254721686, 0.13209436817829365, 0.0]
# Epoch 24 - Save Best AUC: 0.8548. Model is saved.
# - epoch:25 -
# Epoch: [25][0/57] Elapsed 0m 1s (remain 1m 8s) Loss: 0.2201(0.2201)
# Epoch: [25][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2106(0.2248)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6682(0.6682)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0632(0.3989)
# 	 epoch:25, avg train loss:0.2248, avg valid loss:0.3989
# 	 score:0.5757(th=0.400000), auc=0.850945::: time:1273.96s
# - epoch:26 -
# Epoch: [26][0/57] Elapsed 0m 1s (remain 1m 11s) Loss: 0.2097(0.2097)
# Epoch: [26][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1678(0.2165)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6682(0.6682)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0891(0.3991)
# 	 epoch:26, avg train loss:0.2165, avg valid loss:0.3991
# 	 score:0.5630(th=0.400000), auc=0.842426::: time:1318.63s
# - epoch:27 -
# Epoch: [27][0/57] Elapsed 0m 1s (remain 1m 12s) Loss: 0.2708(0.2708)
# Epoch: [27][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2265(0.2140)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6842(0.6842)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0692(0.4055)
# 	 epoch:27, avg train loss:0.2140, avg valid loss:0.4055
# 	 score:0.5737(th=0.400000), auc=0.847263::: time:1362.68s
# - epoch:28 -
# Epoch: [28][0/57] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2841(0.2841)
# Epoch: [28][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.3448(0.2240)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6334(0.6334)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0778(0.4044)
# 	 epoch:28, avg train loss:0.2240, avg valid loss:0.4044
# 	 score:0.5722(th=0.550000), auc=0.846522::: time:1406.78s
# - epoch:29 -
# Epoch: [29][0/57] Elapsed 0m 1s (remain 1m 10s) Loss: 0.2307(0.2307)
# Epoch: [29][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.3523(0.2289)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.7480(0.7480)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0763(0.4084)
# 	 epoch:29, avg train loss:0.2289, avg valid loss:0.4084
# 	 score:0.5126(th=0.550000), auc=0.834420::: time:1450.52s
# - epoch:30 -
# Epoch: [30][0/57] Elapsed 0m 1s (remain 1m 13s) Loss: 0.2942(0.2942)
# Epoch: [30][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2807(0.2412)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5509(0.5509)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0893(0.4006)
# 	 epoch:30, avg train loss:0.2412, avg valid loss:0.4006
# 	 score:0.5634(th=0.450000), auc=0.842669::: time:1494.45s
# surface_list:  [25, 28, 31, 34]
# - epoch:31 -
# Epoch: [31][0/57] Elapsed 0m 1s (remain 1m 13s) Loss: 0.2030(0.2030)
# Epoch: [31][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2547(0.2752)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6704(0.6704)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0693(0.4342)
# 	 epoch:31, avg train loss:0.2752, avg valid loss:0.4342
# 	 score:0.4686(th=0.400000), auc=0.818080::: time:1572.61s
# - epoch:32 -
# Epoch: [32][0/57] Elapsed 0m 1s (remain 1m 14s) Loss: 0.1935(0.1935)
# Epoch: [32][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2447(0.2516)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.4840(0.4840)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0817(0.4075)
# 	 epoch:32, avg train loss:0.2516, avg valid loss:0.4075
# 	 score:0.5301(th=0.600000), auc=0.819010::: time:1615.94s
# - epoch:33 -
# Epoch: [33][0/57] Elapsed 0m 1s (remain 1m 16s) Loss: 0.2158(0.2158)
# Epoch: [33][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.5549(0.2399)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6668(0.6668)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0611(0.4344)
# 	 epoch:33, avg train loss:0.2399, avg valid loss:0.4344
# 	 score:0.4767(th=0.600000), auc=0.819126::: time:1659.46s
# - epoch:34 -
# Epoch: [34][0/57] Elapsed 0m 1s (remain 1m 10s) Loss: 0.1933(0.1933)
# Epoch: [34][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1547(0.2207)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6032(0.6032)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0620(0.3976)
# 	 epoch:34, avg train loss:0.2207, avg valid loss:0.3976
# 	 score:0.5588(th=0.450000), auc=0.845395::: time:1703.21s
# - epoch:35 -
# Epoch: [35][0/57] Elapsed 0m 1s (remain 1m 12s) Loss: 0.2026(0.2026)
# Epoch: [35][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.6463(0.2146)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5498(0.5498)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0568(0.3851)
# 	 epoch:35, avg train loss:0.2146, avg valid loss:0.3851
# 	 score:0.5750(th=0.600000), auc=0.856459::: time:1746.95s
# Epoch 35 - Save Best AUC: 0.8565. Model is saved.
# - epoch:36 -
# Epoch: [36][0/57] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2558(0.2558)
# Epoch: [36][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2119(0.1991)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5497(0.5497)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0545(0.3861)
# 	 epoch:36, avg train loss:0.1991, avg valid loss:0.3861
# 	 score:0.5667(th=0.550000), auc=0.856322::: time:1792.38s
# - epoch:37 -
# Epoch: [37][0/57] Elapsed 0m 1s (remain 1m 13s) Loss: 0.3131(0.3131)
# Epoch: [37][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2608(0.2093)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6509(0.6509)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0844(0.4263)
# 	 epoch:37, avg train loss:0.2093, avg valid loss:0.4263
# 	 score:0.4920(th=0.450000), auc=0.827409::: time:1835.80s
# - epoch:38 -
# Epoch: [38][0/57] Elapsed 0m 1s (remain 1m 9s) Loss: 0.1684(0.1684)
# Epoch: [38][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2606(0.2043)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5750(0.5750)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0779(0.4119)
# 	 epoch:38, avg train loss:0.2043, avg valid loss:0.4119
# 	 score:0.5294(th=0.550000), auc=0.843179::: time:1879.44s
# - epoch:39 -
# Epoch: [39][0/57] Elapsed 0m 1s (remain 1m 15s) Loss: 0.1530(0.1530)
# Epoch: [39][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2635(0.2017)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5787(0.5787)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0714(0.3918)
# 	 epoch:39, avg train loss:0.2017, avg valid loss:0.3918
# 	 score:0.5571(th=0.600000), auc=0.849332::: time:1923.06s
# - epoch:40 -
# Epoch: [40][0/57] Elapsed 0m 1s (remain 1m 14s) Loss: 0.1979(0.1979)
# Epoch: [40][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2949(0.2313)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5886(0.5886)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0724(0.3873)
# 	 epoch:40, avg train loss:0.2313, avg valid loss:0.3873
# 	 score:0.5272(th=0.600000), auc=0.837349::: time:1966.38s
# - epoch:41 -
# Epoch: [41][0/57] Elapsed 0m 1s (remain 1m 9s) Loss: 0.1815(0.1815)
# Epoch: [41][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2209(0.2270)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.8285(0.8285)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0511(0.4467)
# 	 epoch:41, avg train loss:0.2270, avg valid loss:0.4467
# 	 score:0.5003(th=0.400000), auc=0.827641::: time:2010.28s
# - epoch:42 -
# Epoch: [42][0/57] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2797(0.2797)
# Epoch: [42][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.7220(0.2351)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6028(0.6028)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0623(0.4338)
# 	 epoch:42, avg train loss:0.2351, avg valid loss:0.4338
# 	 score:0.5458(th=0.500000), auc=0.833250::: time:2053.45s
# - epoch:43 -
# Epoch: [43][0/57] Elapsed 0m 1s (remain 1m 14s) Loss: 0.2225(0.2225)
# Epoch: [43][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2784(0.2089)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.9173(0.9173)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0847(0.4467)
# 	 epoch:43, avg train loss:0.2089, avg valid loss:0.4467
# 	 score:0.5744(th=0.400000), auc=0.835949::: time:2097.35s
# - epoch:44 -
# Epoch: [44][0/57] Elapsed 0m 1s (remain 1m 7s) Loss: 0.1576(0.1576)
# Epoch: [44][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1879(0.1991)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5902(0.5902)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0602(0.3784)
# 	 epoch:44, avg train loss:0.1991, avg valid loss:0.3784
# 	 score:0.5776(th=0.500000), auc=0.853251::: time:2140.86s
# - epoch:45 -
# Epoch: [45][0/57] Elapsed 0m 1s (remain 1m 11s) Loss: 0.1345(0.1345)
# Epoch: [45][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2606(0.1878)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5467(0.5467)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0543(0.3789)
# 	 epoch:45, avg train loss:0.1878, avg valid loss:0.3789
# 	 score:0.5750(th=0.600000), auc=0.857741::: time:2184.06s
# Epoch 45 - Save Best AUC: 0.8577. Model is saved.
# [fold1] slice ave score:0.5954(th=0.500000), auc=0.865621
# [fold1] BEST Epoch 24 - Save Best Score:0.5883. Best loss:0.3930
# [fold1] BEST AUC Epoch 45 - Save Best Score:0.8577. Best loss:0.3789
# -- fold2 training start --
# surface_list:  [26, 29, 32, 35]
# - epoch:1 -
# Epoch: [1][0/58] Elapsed 0m 1s (remain 1m 15s) Loss: 0.8525(0.8525)
# Epoch: [1][57/58] Elapsed 0m 26s (remain 0m 0s) Loss: 0.5542(0.4700)
# EVAL: [0/18] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6126(0.6126)
# EVAL: [17/18] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3567(0.5635)
# 	 epoch:1, avg train loss:0.4700, avg valid loss:0.5635
# 	 score:0.3625(th=0.600000), auc=0.782824::: time:79.64s
# Epoch 1 - Save Best Score: 0.3625. Model is saved.
# dice_list:  [0.27602417896518877, 0.29799971192334024, 0.31412822775052635, 0.3258962996431513, 0.3351328235629081, 0.3428874558839672, 0.3493750874028531, 0.3544687172469656, 0.3583612138509404, 0.36098807731754357, 0.3624507890978005, 0.36235895166746224, 0.360077686862731, 0.3546022539770991, 0.34511099208974494, 0.32814606565322957, 0.29593755268548927, 0.22788613897874146, 0.0]
# Epoch 1 - Save Best AUC: 0.7828. Model is saved.
# - epoch:2 -
# Epoch: [2][0/58] Elapsed 0m 1s (remain 1m 15s) Loss: 0.3938(0.3938)
# Epoch: [2][57/58] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2453(0.3727)
# EVAL: [0/18] Elapsed 0m 0s (remain 0m 5s) Loss: 0.8077(0.8077)
# EVAL: [17/18] Elapsed 0m 3s (remain 0m 0s) Loss: 0.7762(0.4880)
# 	 epoch:2, avg train loss:0.3727, avg valid loss:0.4880
# 	 score:0.4422(th=0.650000), auc=0.807836::: time:129.13s
# Epoch 2 - Save Best Score: 0.4422. Model is saved.
# dice_list:  [0.2662787063767916, 0.2999017382089162, 0.3287440861856205, 0.35257979122806254, 0.3732876600175971, 0.39092340162630757, 0.40564103323490713, 0.4171956036084927, 0.42661725367023307, 0.43412717994713723, 0.43946714372004664, 0.4422109990451908, 0.4420747813355901, 0.43932472527310173, 0.4321247630873487, 0.4148282585252607, 0.377982138253958, 0.31260675756875883, 0.0]
# Epoch 2 - Save Best AUC: 0.8078. Model is saved.
# - epoch:3 -
# Epoch: [3][0/58] Elapsed 0m 1s (remain 1m 8s) Loss: 0.3670(0.3670)
# Epoch: [3][57/58] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4890(0.3491)
# EVAL: [0/18] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5434(0.5434)
# EVAL: [17/18] Elapsed 0m 3s (remain 0m 0s) Loss: 0.5710(0.4444)
# 	 epoch:3, avg train loss:0.3491, avg valid loss:0.4444
# 	 score:0.5018(th=0.650000), auc=0.825225::: time:178.40s
# Epoch 3 - Save Best Score: 0.5018. Model is saved.
# ...
# 	 score:0.5148(th=0.550000), auc=0.887138::: time:597.46s
# Epoch 12 - Save Best Score: 0.5148. Model is saved.
# dice_list:  [0.33576701124064046, 0.37421271809784773, 0.4081767025704167, 0.4383483450050136, 0.4620887610694158, 0.47903042102125776, 0.49168175087410304, 0.5018829233682597, 0.5104850180476038, 0.5148260891727936, 0.5119965465292834, 0.5006749703704726, 0.4851932784286332, 0.4614730878043873, 0.4226236790950572, 0.3673123900179182, 0.28660333751089606, 0.1504100065660657, 0.0]
# - epoch:13 -
# Epoch: [13][0/60] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2519(0.2519)
# Epoch: [13][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.3932(0.2754)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2802(0.2802)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4652(0.4175)
# 	 epoch:13, avg train loss:0.2754, avg valid loss:0.4175
# 	 score:0.4630(th=0.300000), auc=0.872781::: time:643.16s
# - epoch:14 -
# Epoch: [14][0/60] Elapsed 0m 1s (remain 1m 14s) Loss: 0.1757(0.1757)
# Epoch: [14][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.1817(0.2585)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2411(0.2411)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4039(0.3681)
# 	 epoch:14, avg train loss:0.2585, avg valid loss:0.3681
# 	 score:0.5150(th=0.550000), auc=0.894047::: time:687.15s
# Epoch 14 - Save Best Score: 0.5150. Model is saved.
# dice_list:  [0.35982027174328096, 0.39388341899307816, 0.4212345938737149, 0.445616896281542, 0.46561083382787216, 0.4830008400976092, 0.4958225864664047, 0.50484191156434, 0.5115703183490953, 0.514962374642902, 0.5128476080912896, 0.5042751374505873, 0.4844331715474874, 0.4476231250552086, 0.3937754597133344, 0.315715029364573, 0.20438209485772227, 0.07157024299464984, 0.0]
# Epoch 14 - Save Best AUC: 0.8940. Model is saved.
# - epoch:15 -
# Epoch: [15][0/60] Elapsed 0m 1s (remain 1m 14s) Loss: 0.2562(0.2562)
# Epoch: [15][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2497(0.2382)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2239(0.2239)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3708(0.3797)
# 	 epoch:15, avg train loss:0.2382, avg valid loss:0.3797
# 	 score:0.5100(th=0.650000), auc=0.893961::: time:734.27s
# surface_list:  [27, 30, 33, 36]
# - epoch:16 -
# Epoch: [16][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2569(0.2569)
# Epoch: [16][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.4939(0.2549)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2415(0.2415)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3622(0.3676)
# 	 epoch:16, avg train loss:0.2549, avg valid loss:0.3676
# 	 score:0.5043(th=0.450000), auc=0.894912::: time:812.40s
# Epoch 16 - Save Best AUC: 0.8949. Model is saved.
# - epoch:17 -
# Epoch: [17][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.1881(0.1881)
# Epoch: [17][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.3502(0.2405)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2295(0.2295)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3600(0.3706)
# 	 epoch:17, avg train loss:0.2405, avg valid loss:0.3706
# 	 score:0.5120(th=0.600000), auc=0.897389::: time:857.22s
# Epoch 17 - Save Best AUC: 0.8974. Model is saved.
# - epoch:18 -
# Epoch: [18][0/60] Elapsed 0m 1s (remain 1m 16s) Loss: 0.1825(0.1825)
# Epoch: [18][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2134(0.2451)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2456(0.2456)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3663(0.3930)
# 	 epoch:18, avg train loss:0.2451, avg valid loss:0.3930
# 	 score:0.5013(th=0.700000), auc=0.893319::: time:902.37s
# - epoch:19 -
# Epoch: [19][0/60] Elapsed 0m 1s (remain 1m 22s) Loss: 0.1626(0.1626)
# Epoch: [19][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2017(0.2508)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2116(0.2116)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4264(0.4830)
# 	 epoch:19, avg train loss:0.2508, avg valid loss:0.4830
# 	 score:0.4892(th=0.800000), auc=0.883544::: time:945.75s
# - epoch:20 -
# Epoch: [20][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.3274(0.3274)
# Epoch: [20][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2240(0.2617)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2256(0.2256)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4817(0.4074)
# 	 epoch:20, avg train loss:0.2617, avg valid loss:0.4074
# 	 score:0.4533(th=0.500000), auc=0.879065::: time:989.65s
# - epoch:21 -
# Epoch: [21][0/60] Elapsed 0m 1s (remain 1m 15s) Loss: 0.1923(0.1923)
# Epoch: [21][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.4598(0.2678)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2691(0.2691)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.5596(0.4512)
# 	 epoch:21, avg train loss:0.2678, avg valid loss:0.4512
# 	 score:0.4276(th=0.400000), auc=0.855188::: time:1033.56s
# - epoch:22 -
# Epoch: [22][0/60] Elapsed 0m 1s (remain 1m 16s) Loss: 0.3328(0.3328)
# Epoch: [22][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.1338(0.2782)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.4039(0.4039)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.6024(0.4921)
# 	 epoch:22, avg train loss:0.2782, avg valid loss:0.4921
# 	 score:0.5088(th=0.250000), auc=0.872730::: time:1078.15s
# - epoch:23 -
# Epoch: [23][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2763(0.2763)
# Epoch: [23][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2058(0.2545)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2454(0.2454)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4467(0.3989)
# 	 epoch:23, avg train loss:0.2545, avg valid loss:0.3989
# 	 score:0.4977(th=0.450000), auc=0.884715::: time:1121.91s
# - epoch:24 -
# Epoch: [24][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2923(0.2923)
# Epoch: [24][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2324(0.2377)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2372(0.2372)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4229(0.3990)
# 	 epoch:24, avg train loss:0.2377, avg valid loss:0.3990
# 	 score:0.4975(th=0.650000), auc=0.888411::: time:1165.85s
# - epoch:25 -
# Epoch: [25][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.1718(0.1718)
# Epoch: [25][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2025(0.2055)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2267(0.2267)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4064(0.3822)
# 	 epoch:25, avg train loss:0.2055, avg valid loss:0.3822
# 	 score:0.5147(th=0.600000), auc=0.891420::: time:1209.89s
# - epoch:26 -
# Epoch: [26][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2198(0.2198)
# Epoch: [26][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1393(0.2098)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2184(0.2184)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3959(0.3910)
# 	 epoch:26, avg train loss:0.2098, avg valid loss:0.3910
# 	 score:0.5049(th=0.650000), auc=0.891848::: time:1254.24s
# - epoch:27 -
# Epoch: [27][0/60] Elapsed 0m 1s (remain 1m 21s) Loss: 0.3099(0.3099)
# Epoch: [27][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.1824(0.2037)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2526(0.2526)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4667(0.4027)
# 	 epoch:27, avg train loss:0.2037, avg valid loss:0.4027
# 	 score:0.5132(th=0.500000), auc=0.881773::: time:1298.16s
# - epoch:28 -
# Epoch: [28][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.1771(0.1771)
# Epoch: [28][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2820(0.2148)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2264(0.2264)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4220(0.3813)
# 	 epoch:28, avg train loss:0.2148, avg valid loss:0.3813
# 	 score:0.5208(th=0.600000), auc=0.892644::: time:1342.33s
# Epoch 28 - Save Best Score: 0.5208. Model is saved.
# dice_list:  [0.3801882889666895, 0.4102549279365703, 0.4348641217081762, 0.4540975187501637, 0.4707726405367931, 0.48638517286999444, 0.49939714816621766, 0.5095059192812644, 0.5165523253562042, 0.5207163215230681, 0.5208144229765531, 0.5161762433117306, 0.5046007454722871, 0.48460392514058886, 0.4556517021773678, 0.41466721003691087, 0.34861175138153844, 0.2324131632003307, 0.0]
# - epoch:29 -
# Epoch: [29][0/60] Elapsed 0m 1s (remain 1m 13s) Loss: 0.1424(0.1424)
# Epoch: [29][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2625(0.2111)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.3605(0.3605)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.6633(0.5026)
# 	 epoch:29, avg train loss:0.2111, avg valid loss:0.5026
# 	 score:0.4957(th=0.200000), auc=0.869473::: time:1387.85s
# - epoch:30 -
# Epoch: [30][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2069(0.2069)
# Epoch: [30][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2522(0.2353)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.3988(0.3988)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.5150(0.4765)
# 	 epoch:30, avg train loss:0.2353, avg valid loss:0.4765
# 	 score:0.4743(th=0.350000), auc=0.867359::: time:1431.91s
# surface_list:  [25, 28, 31, 34]
# - epoch:31 -
# Epoch: [31][0/60] Elapsed 0m 1s (remain 1m 21s) Loss: 0.2221(0.2221)
# Epoch: [31][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.1746(0.2674)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2393(0.2393)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.5001(0.4272)
# 	 epoch:31, avg train loss:0.2674, avg valid loss:0.4272
# 	 score:0.4612(th=0.700000), auc=0.878347::: time:1509.48s
# - epoch:32 -
# Epoch: [32][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2167(0.2167)
# Epoch: [32][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2532(0.2517)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2189(0.2189)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4341(0.4130)
# 	 epoch:32, avg train loss:0.2517, avg valid loss:0.4130
# 	 score:0.4552(th=0.450000), auc=0.873916::: time:1553.45s
# - epoch:33 -
# Epoch: [33][0/60] Elapsed 0m 1s (remain 1m 14s) Loss: 0.3039(0.3039)
# Epoch: [33][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2641(0.2388)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.3519(0.3519)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.5227(0.4388)
# 	 epoch:33, avg train loss:0.2388, avg valid loss:0.4388
# 	 score:0.5011(th=0.400000), auc=0.867625::: time:1597.34s
# - epoch:34 -
# Epoch: [34][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2628(0.2628)
# Epoch: [34][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2089(0.2144)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.3000(0.3000)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4327(0.3966)
# 	 epoch:34, avg train loss:0.2144, avg valid loss:0.3966
# 	 score:0.5194(th=0.500000), auc=0.884960::: time:1640.91s
# - epoch:35 -
# Epoch: [35][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.3449(0.3449)
# Epoch: [35][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.1950(0.1969)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.3019(0.3019)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4302(0.3911)
# 	 epoch:35, avg train loss:0.1969, avg valid loss:0.3911
# 	 score:0.5347(th=0.450000), auc=0.885275::: time:1685.13s
# Epoch 35 - Save Best Score: 0.5347. Model is saved.
# dice_list:  [0.39263344127671873, 0.4332548813462797, 0.4667335102394459, 0.4921226770503314, 0.514646805610436, 0.5278410449640479, 0.5342666292097525, 0.5347400066794943, 0.5278922633269874, 0.5136215395754519, 0.4927572730348968, 0.46242794184670216, 0.4237678041778803, 0.3746890824989814, 0.3168845723843035, 0.2507523170000863, 0.1798574277535683, 0.10448345435363592, 0.0]
# - epoch:36 -
# Epoch: [36][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.1499(0.1499)
# Epoch: [36][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.1924(0.1903)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2981(0.2981)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4203(0.3902)
# 	 epoch:36, avg train loss:0.1903, avg valid loss:0.3902
# 	 score:0.5314(th=0.450000), auc=0.884273::: time:1730.31s
# - epoch:37 -
# Epoch: [37][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2070(0.2070)
# Epoch: [37][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.4861(0.1909)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2949(0.2949)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4358(0.3937)
# 	 epoch:37, avg train loss:0.1909, avg valid loss:0.3937
# 	 score:0.5286(th=0.450000), auc=0.885178::: time:1774.30s
# - epoch:38 -
# Epoch: [38][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.1711(0.1711)
# Epoch: [38][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.1932(0.1875)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2787(0.2787)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4265(0.4044)
# 	 epoch:38, avg train loss:0.1875, avg valid loss:0.4044
# 	 score:0.5136(th=0.500000), auc=0.876952::: time:1818.19s
# - epoch:39 -
# Epoch: [39][0/60] Elapsed 0m 1s (remain 1m 10s) Loss: 0.1491(0.1491)
# Epoch: [39][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2735(0.1967)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2534(0.2534)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4002(0.4138)
# 	 epoch:39, avg train loss:0.1967, avg valid loss:0.4138
# 	 score:0.5136(th=0.750000), auc=0.888560::: time:1861.95s
# - epoch:40 -
# Epoch: [40][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.1570(0.1570)
# Epoch: [40][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.1781(0.2159)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.4475(0.4475)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.5288(0.4582)
# 	 epoch:40, avg train loss:0.2159, avg valid loss:0.4582
# 	 score:0.4988(th=0.500000), auc=0.877054::: time:1905.76s
# - epoch:41 -
# Epoch: [41][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2656(0.2656)
# Epoch: [41][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.1892(0.2080)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.4195(0.4195)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.6895(0.5176)
# 	 epoch:41, avg train loss:0.2080, avg valid loss:0.5176
# 	 score:0.4508(th=0.300000), auc=0.861500::: time:1949.27s
# - epoch:42 -
# Epoch: [42][0/60] Elapsed 0m 1s (remain 1m 12s) Loss: 0.2545(0.2545)
# Epoch: [42][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2450(0.2371)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2925(0.2925)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.5991(0.5151)
# 	 epoch:42, avg train loss:0.2371, avg valid loss:0.5151
# 	 score:0.4101(th=0.200000), auc=0.860809::: time:1992.77s
# - epoch:43 -
# Epoch: [43][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.3287(0.3287)
# Epoch: [43][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2145(0.2104)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2831(0.2831)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4404(0.4204)
# 	 epoch:43, avg train loss:0.2104, avg valid loss:0.4204
# 	 score:0.4999(th=0.700000), auc=0.879927::: time:2036.34s
# - epoch:44 -
# Epoch: [44][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.1574(0.1574)
# Epoch: [44][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1831(0.1802)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2893(0.2893)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.5005(0.4111)
# 	 epoch:44, avg train loss:0.1802, avg valid loss:0.4111
# 	 score:0.5282(th=0.450000), auc=0.886155::: time:2080.59s
# - epoch:45 -
# Epoch: [45][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.1569(0.1569)
# Epoch: [45][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2450(0.1742)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2864(0.2864)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.5000(0.4182)
# 	 epoch:45, avg train loss:0.1742, avg valid loss:0.4182
# 	 score:0.5171(th=0.450000), auc=0.880578::: time:2125.01s
# [fold4] slice ave score:0.5367(th=0.450000), auc=0.895241
# [fold4] BEST Epoch 35 - Save Best Score:0.5347. Best loss:0.3911
# [fold4] BEST AUC Epoch 17 - Save Best Score:0.8974. Best loss:0.3706
# fold[0] BEST SCORE = 0.5535 thr=0.7 (epoch=33)
# fold[0] slice ave score:0.5292(th=0.600000), auc=0.896648
# fold[1] BEST SCORE = 0.5883 thr=0.4 (epoch=24)
# fold[1] slice ave score:0.5954(th=0.500000), auc=0.865621
# fold[2] BEST SCORE = 0.5780 thr=0.55 (epoch=38)
# fold[2] slice ave score:0.5775(th=0.500000), auc=0.862641
# fold[3] BEST SCORE = 0.5803 thr=0.5 (epoch=45)
# fold[3] slice ave score:0.5697(th=0.550000), auc=0.935232
# fold[4] BEST SCORE = 0.5347 thr=0.45 (epoch=35)
# fold[4] slice ave score:0.5367(th=0.450000), auc=0.895241
# CPU times: user 2h 6min 45s, sys: 46min 14s, total: 2h 53min
# Wall time: 2h 57min 50s

# %% [markdown]
# ---
# # OOF SCORE INFER

# %%
# %%time
slice_ave_score_list, slice_ave_score_threshold_list, slice_ave_auc_list = slide_inference(CFG)
for fold in CFG["folds"]:
    print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    wandb.log({"OOF SCORE" : {f"slice average score":slice_ave_score_list[fold],
                            f"slice average threshold":slice_ave_score_threshold_list[fold],
                            f"slice_average auc":slice_ave_auc_list[fold],
                            }})
# Out:
# -- fold0 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.5363(th=0.800000), auc=0.887944::: time:25.82s
# slide pos: [256, 0]
# 	 score:0.2595(th=0.650000), auc=0.809581::: time:43.00s
# slide pos: [0, 256]
# 	 score:0.5356(th=0.750000), auc=0.896768::: time:59.57s
# slide pos: [256, 256]
# 	 score:0.2569(th=0.700000), auc=0.816344::: time:76.77s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.5124(th=0.650000), auc=0.874693::: time:100.59s
# slide pos: [256, 0]
# 	 score:0.2641(th=0.600000), auc=0.811805::: time:118.05s
# slide pos: [0, 256]
# 	 score:0.5017(th=0.650000), auc=0.885788::: time:135.11s
# slide pos: [256, 256]
# 	 score:0.2818(th=0.700000), auc=0.825031::: time:151.90s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.5528(th=0.800000), auc=0.898784::: time:175.98s
# slide pos: [256, 0]
# 	 score:0.2373(th=0.650000), auc=0.798950::: time:193.21s
# slide pos: [0, 256]
# 	 score:0.5616(th=0.750000), auc=0.907716::: time:209.94s
# slide pos: [256, 256]
# 	 score:0.2343(th=0.550000), auc=0.805063::: time:227.20s
# [fold0] slice ave score:0.5344(th=0.600000), auc=0.888233
# -- fold1 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.5813(th=0.650000), auc=0.864569::: time:267.87s
# slide pos: [256, 0]
# 	 score:0.2295(th=0.100000), auc=0.681158::: time:290.05s
# slide pos: [0, 256]
# 	 score:0.5826(th=0.600000), auc=0.860703::: time:312.54s
# slide pos: [256, 256]
# 	 score:0.2346(th=0.100000), auc=0.690335::: time:334.47s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.5753(th=0.650000), auc=0.864512::: time:360.80s
# slide pos: [256, 0]
# 	 score:0.2261(th=0.100000), auc=0.680368::: time:383.42s
# slide pos: [0, 256]
# 	 score:0.5733(th=0.600000), auc=0.856844::: time:406.06s
# slide pos: [256, 256]
# 	 score:0.2287(th=0.100000), auc=0.688316::: time:429.09s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.5750(th=0.600000), auc=0.857741::: time:456.21s
# slide pos: [256, 0]
# 	 score:0.2392(th=0.100000), auc=0.692997::: time:478.70s
# slide pos: [0, 256]
# 	 score:0.5895(th=0.600000), auc=0.856198::: time:501.40s
# slide pos: [256, 256]
# 	 score:0.2514(th=0.100000), auc=0.704567::: time:523.31s
# [fold1] slice ave score:0.5144(th=0.450000), auc=0.831253
# -- fold2 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.5538(th=0.550000), auc=0.850274::: time:566.64s
# slide pos: [256, 0]
# 	 score:0.3093(th=0.250000), auc=0.747744::: time:588.76s
# slide pos: [0, 256]
# 	 score:0.5332(th=0.550000), auc=0.848744::: time:610.88s
# slide pos: [256, 256]
# 	 score:0.3124(th=0.300000), auc=0.749512::: time:632.90s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.5704(th=0.600000), auc=0.860502::: time:659.42s
# slide pos: [256, 0]
# 	 score:0.3168(th=0.250000), auc=0.752170::: time:682.27s
# slide pos: [0, 256]
# 	 score:0.5754(th=0.550000), auc=0.858321::: time:704.45s
# slide pos: [256, 256]
# 	 score:0.3119(th=0.250000), auc=0.751077::: time:726.65s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.5279(th=0.450000), auc=0.836371::: time:752.51s
# slide pos: [256, 0]
# 	 score:0.3170(th=0.300000), auc=0.747688::: time:774.62s
# slide pos: [0, 256]
# 	 score:0.5173(th=0.500000), auc=0.837530::: time:796.80s
# slide pos: [256, 256]
# 	 score:0.3390(th=0.300000), auc=0.755964::: time:819.19s
# [fold2] slice ave score:0.5220(th=0.400000), auc=0.828586
# -- fold3 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.5367(th=0.500000), auc=0.931384::: time:857.32s
# slide pos: [256, 0]
# 	 score:0.2933(th=0.300000), auc=0.879785::: time:875.74s
# slide pos: [0, 256]
# 	 score:0.5299(th=0.500000), auc=0.921544::: time:893.27s
# slide pos: [256, 256]
# 	 score:0.2894(th=0.400000), auc=0.877312::: time:911.10s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.5674(th=0.550000), auc=0.933658::: time:931.99s
# slide pos: [256, 0]
# 	 score:0.3049(th=0.400000), auc=0.879730::: time:949.63s
# slide pos: [0, 256]
# 	 score:0.5527(th=0.450000), auc=0.924812::: time:966.93s
# slide pos: [256, 256]
# 	 score:0.3004(th=0.450000), auc=0.874423::: time:984.10s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.5045(th=0.450000), auc=0.925991::: time:1004.55s
# slide pos: [256, 0]
# 	 score:0.2869(th=0.300000), auc=0.879165::: time:1021.93s
# slide pos: [0, 256]
# 	 score:0.4912(th=0.500000), auc=0.918113::: time:1039.00s
# slide pos: [256, 256]
# 	 score:0.2784(th=0.400000), auc=0.875850::: time:1056.29s
# [fold3] slice ave score:0.4983(th=0.450000), auc=0.917847
# -- fold4 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.5137(th=0.700000), auc=0.892914::: time:1100.96s
# slide pos: [256, 0]
# 	 score:0.2615(th=0.150000), auc=0.798800::: time:1122.22s
# slide pos: [0, 256]
# 	 score:0.5158(th=0.650000), auc=0.894201::: time:1142.94s
# slide pos: [256, 256]
# 	 score:0.2616(th=0.100000), auc=0.800005::: time:1164.28s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.5120(th=0.600000), auc=0.897389::: time:1194.41s
# slide pos: [256, 0]
# 	 score:0.2594(th=0.150000), auc=0.801017::: time:1216.08s
# slide pos: [0, 256]
# 	 score:0.5231(th=0.600000), auc=0.899964::: time:1237.64s
# slide pos: [256, 256]
# 	 score:0.2593(th=0.150000), auc=0.802662::: time:1258.38s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.4914(th=0.700000), auc=0.884600::: time:1288.43s
# slide pos: [256, 0]
# 	 score:0.2642(th=0.200000), auc=0.801183::: time:1309.98s
# slide pos: [0, 256]
# 	 score:0.5099(th=0.650000), auc=0.883670::: time:1331.36s
# slide pos: [256, 256]
# 	 score:0.2628(th=0.150000), auc=0.802372::: time:1352.35s
# [fold4] slice ave score:0.4887(th=0.450000), auc=0.881600
# fold[0] slice ave score:0.5344(th=0.888233), auc=0.600000
# fold[1] slice ave score:0.5144(th=0.831253), auc=0.450000
# fold[2] slice ave score:0.5220(th=0.828586), auc=0.400000
# fold[3] slice ave score:0.4983(th=0.917847), auc=0.450000
# fold[4] slice ave score:0.4887(th=0.881600), auc=0.450000
# CPU times: user 18min 8s, sys: 3min 24s, total: 21min 32s
# Wall time: 22min 48s

# %%
import yaml
with open(os.path.join(CFG["OUTPUT_DIR"], "Config.yaml"), "w") as f:
    yaml.dump(CFG, f)

# %%
if not CFG["DEBUG"]:
    wandb.finish()
