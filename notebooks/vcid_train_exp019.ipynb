# %% [markdown]
# # ex019
# bug fix masked_img
# 5-fold
# img size 512
# output shape is half of input shape
# next channel shuffle
# 学習時にrandom slide

# %%
import gc
import os
import random
import time
import math

import cv2
import numpy as np
import matplotlib.pyplot as plt

# model
import torch
import torchvision
import torch.nn as nn
import timm
from torchvision.models.feature_extraction import create_feature_extractor
import torchvision.transforms.functional as TF

# data loader
import albumentations as A
from albumentations.pytorch import ToTensorV2
from torch.utils.data import DataLoader, Dataset

# training
from torch.optim import SGD, Adam, AdamW
from torch.optim.lr_scheduler import CosineAnnealingLR, CosineAnnealingWarmRestarts, ReduceLROnPlateau, ExponentialLR

# metric
from sklearn.metrics import fbeta_score, roc_auc_score

import wandb

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # config

# %%
BASE_DIR = "/working/"
INPUT_DIR = os.path.join(BASE_DIR, "input", "vesuvius-challenge-ink-detection")
TRAIN_DIR = os.path.join(INPUT_DIR, "train")
TEST_DIR = os.path.join(INPUT_DIR, "test")
# IMG_SIZE = [256, 256]
# IMG_SIZE = [128, 128]
IMG_SIZE = [512, 512]
SURFACE_LIST = [
                list(range(26, 36, 3)),
                list(range(27, 37, 3)),                
                list(range(25, 35, 3)),
                ]
print(len(SURFACE_LIST[0]))
print(SURFACE_LIST)

SURFACE_NUM = len(SURFACE_LIST[0])
# print("Start surface idx =",START_SURFACE)

# SLIDE_POS_LIST = [[idx*(IMG_SIZE[0]//6), idx*(IMG_SIZE[1]//6)] for idx in range(0, 3)]
SLIDE_POS_LIST = [[0,0], [IMG_SIZE[0]//2, 0], [0, IMG_SIZE[1]//2], [IMG_SIZE[0]//2, IMG_SIZE[1]//2]]
print("SLIDE_POS_LIST =", SLIDE_POS_LIST)
CFG = {
    "DEBUG" : False,
    # exp setting
    "EXP_CATEGORY" : "5fold",
    "EXP_NAME" : "exp019",
    "folds" : [0, 1, 2, 3, 4],

    # model
    # "model_name" : "tf_efficientnet_b0",
    "model_name" : "tf_efficientnet_b6",
    "inp_channels" : SURFACE_NUM,
    "out_channels" : 1,
    "pretrained" : True,
    "out_indices" : [0,1,2,3,4],
 
    # data   
    "img_size": IMG_SIZE,
    # "batch_size": 32,
    # "batch_size": 16,#batch normの関係か？16の方が64より安定してそう？？
    "batch_size": 8,
    "INPUT_DIR": INPUT_DIR,
    "TRAIN_DIR": TRAIN_DIR,
    "TEST_DIR": TEST_DIR,
    "surface_num": SURFACE_NUM,
    "surface_list": list(SURFACE_LIST),
    "slide_pos_list": SLIDE_POS_LIST,
    "RANDOM_SLIDE": True,
#     "surface_start_idx": START_SURFACE,
    # "TRAIN_DIR_LIST": [["1", "2"], ["1", "3"], ["2", "3"]],
    "TRAIN_DIR_LIST": [["1", "2_0", "2_1", "2_2"], 
                       ["1", "2_0", "2_1", "3"],
                       ["1", "2_0",  "2_2", "3"],
                       ["1", "2_1", "2_2", "3"],
                       ["2_0", "2_1", "2_2", "3"],
                       ],
#     "TRAIN_IDX_LIST" : ["1"],
    # "VALID_DIR_LIST": [["3"],["2"],["1"]],
    "VALID_DIR_LIST": [["3"], ["2_2"], ["2_1"], ["2_0"],["1"]],
    "TEST_DIR_LIST": ["a", "b"],

    # learning
    "n_epoch" : 15,
    "lr" : 1e-3,
    "T_max" : 5,
    "min_lr" : 1e-8,
    "weight_decay" : 1e-6,

    # etc
    "print_freq" : 1000,
    "random_seed" : 21,
    "num_workers": 2,
}


if CFG["model_name"]=="tf_efficientnet_b0":
    CFG["channel_nums"] = [320, 112, 40, 24, 16]
elif CFG["model_name"]=="tf_efficientnet_b4":
    CFG["channel_nums"] = [448, 160, 56, 32, 24]
elif CFG["model_name"]=="tf_efficientnet_b6":
    CFG["channel_nums"] = [576, 200, 72, 40, 32]


if CFG["DEBUG"]:
    CFG["n_epoch"] = 1
    CFG["EXP_NAME"] = "DEBUG"
    

CFG["OUTPUT_DIR"] = os.path.join(BASE_DIR, "output", CFG["EXP_NAME"])
# Out:
# 4
# [[26, 29, 32, 35], [27, 30, 33, 36], [25, 28, 31, 34]]
# SLIDE_POS_LIST = [[0, 0], [256, 0], [0, 256], [256, 256]]

# %%
if not CFG["DEBUG"]:
    os.makedirs(CFG["OUTPUT_DIR"])
    os.makedirs(os.path.join(CFG["OUTPUT_DIR"], "imgs"))

# %%
if not CFG["DEBUG"]:
    WANDB_CONFIG = {'competition': 'vcid', '_wandb_kernel': 'taro'}
    os.environ["WANDB_SILENT"] = "true"
    wandb.init(project=WANDB_CONFIG["competition"], config=CFG, group=CFG["EXP_CATEGORY"], name=CFG["EXP_NAME"], reinit=True)
# Out:
# 2023-04-20 08:31:41.511349: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-20 08:31:41.590000: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-20 08:31:42.175404: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-20 08:31:42.175496: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-20 08:31:42.175505: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# # utils

# %%
def logging_metrics_epoch(CFG, fold, epoch, slice_idx,train_loss_avg, valid_loss_avg, score, threshold, auc_score):
    wandb.log({f"train/fold{fold}": train_loss_avg,
                f"valid/fold{fold}": valid_loss_avg,
                f"score/fold{fold}":score,
                f"score threshold/fold{fold}":threshold,
                f"auc/fold{fold}":auc_score,
                f"epoch/fold{fold}":epoch+slice_idx*CFG["n_epoch"],
                })

# %%
def seed_everything(seed=CFG["random_seed"]):
    #os.environ['PYTHONSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic =True
    torch.backends.cudnn.benchmark = False
seed_everything()

# device optimization
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
def asMinutes(s):
    """Convert Seconds to Minutes."""
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    """Accessing and Converting Time Data."""
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))

class AverageMeter(object):
    """Computes and stores the average and current value."""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# # metric

# %%
def fbeta_numpy(targets, preds, beta=0.5, smooth=1e-5):
    y_true_count = targets.sum()
    ctp = preds[targets==1].sum()
    cfp = preds[targets==0].sum()
    beta_squared = beta * beta

    c_precision = ctp / (ctp + cfp + smooth)
    c_recall = ctp / (y_true_count + smooth)
    dice = (1 + beta_squared) * (c_precision * c_recall) / (beta_squared * c_precision + c_recall + smooth)

    return dice

def calc_fbeta_auc(mask, mask_pred):
    mask = mask.astype(int).flatten()
    mask_pred = mask_pred.flatten()

    best_th = 0
    best_dice = 0
    dice_list = [] 
    # for th in np.array(range(10, 50+1, 5)) / 100:
    for th in np.array(range(10, 100+1, 5)) / 100:
        # dice = fbeta_score(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice = fbeta_numpy(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice_list.append(dice)
        # print(f'\t th: {th}, fbeta: {dice}')
        if dice > best_dice:
            best_dice = dice
            best_th = th
    
    auc = roc_auc_score(mask, mask_pred)
    # Logger.info(f'best_th: {best_th}, fbeta: {best_dice}')
    return best_dice, best_th, auc, dice_list


def calc_cv(mask_gt, mask_pred):
    best_dice, best_th, auc, dice_list = calc_fbeta_auc(mask_gt, mask_pred)

    return best_dice, best_th, auc, dice_list

# %% [markdown]
# # model

# %%
class Encoder(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = timm.create_model(CFG["model_name"], in_chans=CFG["inp_channels"], features_only=True, out_indices=CFG["out_indices"], pretrained=CFG["pretrained"])
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        return skip_connection_list

class UpConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.bn1 = nn.BatchNorm2d(in_channels)
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size = 2, padding="same")
        self.bn2 = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        x = self.up(x)
        x = self.bn1(x)
        x = self.conv(x)
        x = self.bn2(x)
        return x


class Decoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.UpConv_0 = UpConv(CFG["channel_nums"][0], CFG["channel_nums"][1])
        self.UpConv_1 = UpConv(CFG["channel_nums"][1]*2, CFG["channel_nums"][2])
        self.UpConv_2 = UpConv(CFG["channel_nums"][2]*2, CFG["channel_nums"][3])
        self.UpConv_3 = UpConv(CFG["channel_nums"][3]*2, CFG["channel_nums"][4])
        # self.UpConv_4 = UpConv(CFG["channel_nums"][4]*2, CFG["channel_nums"][4])
    
    def forward(self, skip_connection_list):
        emb = self.UpConv_0(skip_connection_list[4]) # emb.shape = (None, 160, 14, 14)
        emb_cat = torch.cat([skip_connection_list[3], emb], dim = 1)
        
        emb = self.UpConv_1(emb_cat)
        emb_cat = torch.cat([skip_connection_list[2], emb], dim = 1)
        
        emb = self.UpConv_2(emb_cat)
        emb_cat = torch.cat([skip_connection_list[1], emb], dim = 1)
        
        emb = self.UpConv_3(emb_cat)
        emb_cat = torch.cat([skip_connection_list[0], emb], dim = 1)

        # emb_cat = self.UpConv_4(emb_cat)
        
        return emb_cat

class SegModel(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = Encoder(CFG)
        self.decoder = Decoder()
        self.head = nn.Sequential(
            nn.Conv2d(CFG["channel_nums"][-1]*2, CFG["out_channels"], kernel_size=1, stride=1, padding=0),
            nn.Sigmoid()
        )
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        emb = self.decoder(skip_connection_list)
        output = self.head(emb)
        return output

# %% [markdown]
# # Dataset

# %%
train_transforms = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.RandomCrop(int(CFG["img_size"][0]*0.8), int(CFG["img_size"][1]*0.8), p=0.3),
    A.Blur(blur_limit=3, p=0.3),
    A.Resize(CFG["img_size"][0], CFG["img_size"][1]),
    ToTensorV2(),
])

valid_transforms = A.Compose([
    ToTensorV2(),
])

# %%
class VCID_Dataset(Dataset):
    def __init__(self, CFG, data_dir_list, surface_list, surface_volumes=None, slide_pos=[0,0], mode="train", transform=None):
        # get config
        self.mode = mode
        self.RANDOM_SLIDE = CFG["RANDOM_SLIDE"]
        self.img_size = CFG["img_size"]
        if self.mode=="train":  self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode=="valid":    self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode == "test":   self.DATADIR = CFG["TEST_DIR"]
        self.data_dir_list = data_dir_list
        self.surface_list = surface_list
        self.slide_pos = slide_pos
        self.transform = transform
        
        # get imgs
        # print("initializing dataset...")
        self.imgs = []
        for data_dir in self.data_dir_list:
            img_path = os.path.join(self.DATADIR, data_dir, "mask.png")
            # print(img_path)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            img = img.reshape(img.shape[0], img.shape[1], 1) # (h, w, channel=1)
            assert img is not None, "img is None. data path is wrong"
        
            # mask erosion
            kernel_size = (img.shape[0]+img.shape[1])//2//100
            kernel = np.ones((kernel_size, kernel_size), np.uint8)
            img = cv2.erode(img, kernel,iterations = 3)
            self.imgs.append(img[:,:,np.newaxis])    
        
        # get and split surface
        if surface_volumes is None:
            self.surface_vols = self.read_surfacevols()
        else:
            # print("using loaded surface_vols")
            self.surface_vols = surface_volumes
        for surface_idx, surface_vol in enumerate(self.surface_vols):
            self.surface_vols[surface_idx] = self.get_masked_img(surface_vol, self.imgs[surface_idx])
       
        # split grid
        self.get_all_grid()
        self.fileter_grid()
        self.get_flatten_grid()
        # print("split grid done.") 
       
        # get label imgs
        if self.mode == "train" or self.mode == "valid":
            self.labels = []
            for data_dir in self.data_dir_list:
                label_path = os.path.join(self.DATADIR, data_dir, "inklabels.png")
                assert os.path.exists(label_path), f"{label_path} is not exist."
                # read label
                label = cv2.imread(label_path, cv2.IMREAD_GRAYSCALE)
                label = label.reshape(label.shape[0], label.shape[1], 1) # (h, w, channel=1)
                self.labels.append(label)# 画像サイズがそれぞれ違うので単純にconcatできずlist化しているs
        # print("initializing dataset done.")

    def get_surface_volumes(self):
        return self.surface_vols

    def read_surfacevols(self):
        """ read surface volume by data_dir_list and surface_list 
            Returns:surface_vuls (list): surface volume list [array(h,w,channel=surface_num), array(), ...]
        """
        surface_vols = []
        # print("reading surface volume...")
        for data_dir in self.data_dir_list:
            surface_vol_ = None
            for read_idx, surface_idx in enumerate(self.surface_list):
                # print("\r", f"reading idx : {read_idx+1}/{len(self.surface_list)}", end="")
                surface_path = os.path.join(self.DATADIR, data_dir, "surface_volume", f"{surface_idx:02}.tif")
                surface_vol = cv2.imread(surface_path, cv2.IMREAD_GRAYSCALE)
                surface_vol = surface_vol.reshape(surface_vol.shape[0], surface_vol.shape[1], 1) # (h, w, channel=1)
                if surface_vol_ is None:
                    surface_vol_ = surface_vol
                else:
                    surface_vol_ = np.concatenate([surface_vol_, surface_vol], axis=2) # (h, w, channel=surface_num)
            surface_vols.append(surface_vol_)
            # print(f"  => read surface volume done. [{data_dir}]")
        return surface_vols


    def get_grid_img(self, img, grid_idx):
        """ crop grid img from original img"""
        img_grid = img[(grid_idx[0]*self.img_size[0]) + self.slide_pos[0] : ((grid_idx[0]+1)*self.img_size[0]) + self.slide_pos[0],
                        (grid_idx[1]*self.img_size[1]) + self.slide_pos[1] : ((grid_idx[1]+1)*self.img_size[1]) + self.slide_pos[1]]
        return img_grid
    
    def get_grid_img_and_mask(self, img, mask, grid_idx):
        """ crop grid img from original img"""
        if self.RANDOM_SLIDE and self.mode=="train" and random.random() < 0.5:
            if (grid_idx[0]!=0 and grid_idx[1]!=0) and (grid_idx[0]!=img.shape[0]//self.img_size[0] and grid_idx[1]!=img.shape[1]//self.img_size[1]):
                rand_pos = [np.random.randint(0, self.img_size[0]//4) - self.img_size[0]//4, np.random.randint(0, self.img_size[1]//4)-self.img_size[1]//4]
            else:
                rand_pos = [0, 0]
        else:
            rand_pos = [0, 0]
        img_grid = img[(grid_idx[0]*self.img_size[0]) + self.slide_pos[0] + rand_pos[0] : ((grid_idx[0]+1)*self.img_size[0]) + self.slide_pos[0] + rand_pos[0],
                        (grid_idx[1]*self.img_size[1]) + self.slide_pos[1] + rand_pos[1] : ((grid_idx[1]+1)*self.img_size[1]) + self.slide_pos[1] + rand_pos[1]]
        mask_grid = mask[(grid_idx[0]*self.img_size[0]) + self.slide_pos[0] + rand_pos[0] : ((grid_idx[0]+1)*self.img_size[0]) + self.slide_pos[0] + rand_pos[0],
                         (grid_idx[1]*self.img_size[1]) + self.slide_pos[1] + rand_pos[1] : ((grid_idx[1]+1)*self.img_size[1]) + self.slide_pos[1] + rand_pos[1]]
        return img_grid/255., mask_grid/255.
    
    def get_masked_img(self, img, mask):
        """ multiply mask to surface_volumes """
        masked_img = None
        for channel in range(img.shape[2]):
            img_channel = img[:,:,channel].reshape(img.shape[0], img.shape[1],1)
            masked = img_channel*mask
            if masked_img is None:
                masked_img = masked.reshape(masked.shape[0], masked.shape[1], 1)
            else:
                masked = masked.reshape(masked.shape[0], masked.shape[1], 1)
                masked_img = np.concatenate([masked_img, masked], axis=2)
        return masked_img
    
    
    def get_all_grid(self):
        """ get all grid indices by img size and grid size
        """
        self.grid_indices = []
        for img in self.imgs:
            self.x_grid_size = (img.shape[0] - self.slide_pos[0]) // self.img_size[0]
            self.y_grid_size = (img.shape[1] - self.slide_pos[1]) // self.img_size[1]
            grid_img = []
            for i in range(self.x_grid_size):
                for j in range(self.y_grid_size):
                    grid_img.append([i, j])
            self.grid_indices.append(grid_img)
        return self.grid_indices
          
    def fileter_grid(self):
        """ get grid indices which mask is not 0 by all grid indices"""
        grid_indices_all = []
        for img, grid_indices in zip(self.imgs, self.grid_indices):
            grid_indices_copy = grid_indices.copy()
            for grid_idx in grid_indices:
                img_grid = self.get_grid_img(img, grid_idx)
                if img_grid.sum() == 0:
                    grid_indices_copy.remove(grid_idx)
            grid_indices_all.append(grid_indices_copy)
        self.grid_indices = grid_indices_all
        return self.grid_indices

    def get_flatten_grid(self):
        """ get flatten index list by grid indices
            Returns:flatten_grid (list): flatten index list [[img_idx, grid_idx], [img_idx, grid_idx], ...]
        """
        flatten_grid = []
        for img_idx, grid_indices in enumerate(self.grid_indices):
            for grid_idx in grid_indices:
                grid_imgidx_list = [img_idx]
                grid_imgidx_list.extend(grid_idx)
                flatten_grid.append(grid_imgidx_list)
        self.flatten_grid = flatten_grid
        return self.flatten_grid
    
    def channel_shuffle(self, img):
        img = img.transpose(2, 0, 1)
        np.random.shuffle(img)
        return img.transpose(1, 2, 0)

    def __len__(self):
        return len(self.flatten_grid)

    def __getitem__(self, idx):
        # get indices
        img_grid_idx = self.flatten_grid[idx]
        img_idx = img_grid_idx[0]
        grid_idx = img_grid_idx[1:]
        # get img & surface_vol
        mask = self.imgs[img_idx]
        surface_vol = self.surface_vols[img_idx]
        # mask = self.get_grid_img(mask, grid_idx)/255.
        # surface_vol = self.get_grid_img(surface_vol, grid_idx)/255.
        mask, surface_vol = self.get_grid_img_and_mask(mask, surface_vol, grid_idx)
        # multiple small mask 
        assert surface_vol.shape[0]==mask.shape[0] and surface_vol.shape[1]==mask.shape[1] , "surface_vol_list shape is not same as img shape"
        img = surface_vol
        # transform
        if self.mode == "test":
            if self.transform:
                img = self.transform(image=img)["image"]
            else:
                img = img.transpose(2, 0, 1)
                img = torch.tensor(img, dtype=torch.float32)
            return img, grid_idx
        elif self.mode == "train" or self.mode=="valid":
            # get label(segmentation mask)
            label = self.labels[img_idx]
            label = self.get_grid_img(label, grid_idx)
            # if self.mode == "train":
            #     img = self.channel_shuffle(img)
            if self.transform:
                transformed = self.transform(image=img, mask=label)
                img = transformed["image"]
                label = transformed["mask"]
                label = label.permute(2, 0, 1)/255. # (channel, h, w)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            else:
                img = img.transpose(2, 0, 1) # (channel, h, w)
                label = label.transpose(2, 0, 1)/255. # (channel, h, w){}
                img = torch.tensor(img, dtype=torch.float32)
                label = torch.tensor(label, dtype=torch.float32)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            return img, label, grid_idx

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train")
# surface_volumes = dataset_notrans.surface_vols
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx < 2:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
        
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train")
# surface_volumes = dataset_notrans.surface_vols
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx < 2:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos=[0,50],mode="train")
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 1:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train", transform=train_transforms)
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)


# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 0:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %% [markdown]
# # train valid fn

# %%
def train_fn(train_loader, model, criterion, epoch ,optimizer, scheduler):
    model.train()
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, _) in enumerate(train_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()     
        preds = model(images)
        preds = TF.resize(img=preds, size=(CFG["img_size"][0], CFG["img_size"][1]))
        # preds = torch.sigmoid(preds)
        loss = criterion(preds, targets)
        
        losses.update(loss.item(), CFG["batch_size"]) 
        targets = targets.detach().cpu().numpy().ravel().tolist()
        preds = preds.detach().cpu().numpy().ravel().tolist()
        loss.backward() # パラメータの勾配を計算
        optimizer.step() # モデル更新
        optimizer.zero_grad() # 勾配の初期化
                
        batch_time.update(time.time() - end)
        end = time.time()
        if batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(train_loader)-1):
            print('Epoch: [{0}][{1}/{2}] '
                    'Elapsed {remain:s} '
                    'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                    .format(
                        epoch, batch_idx, len(train_loader), batch_time=batch_time, loss=losses,
                        remain=timeSince(start, float(batch_idx+1)/len(train_loader)),
            ))
        del preds, images, targets
    gc.collect()
    torch.cuda.empty_cache()
    return losses.avg

# %%
def valid_fn(model, valid_loader, criterion=None):
    model.eval()# モデルを検証モードに設定
    test_targets = []
    test_preds = []
    test_grid_idx = []
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, grid_idx) in enumerate(valid_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()
        with torch.no_grad():
            preds = model(images)
            preds = TF.resize(img=preds, size=(CFG["img_size"][0], CFG["img_size"][1]))
            if not criterion is None:
                loss = criterion(preds, targets)
        if not criterion is None:
            losses.update(loss.item(), CFG["batch_size"])
        batch_time.update(time.time() - end)

        targets = targets.detach().cpu().numpy()
        preds = preds.detach().cpu().numpy()
        
        test_preds.extend([preds[idx, :,:,:].transpose(1,2,0) for idx in range(preds.shape[0])])
        test_targets.extend([targets[idx, :,:,:].transpose(1,2,0) for idx in range(targets.shape[0])])
        test_grid_idx.extend([[x_idx, y_idx] for x_idx, y_idx in zip(grid_idx[0].tolist(), grid_idx[1].tolist())])

        if (batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(valid_loader)-1)) and (not criterion is None):
            print('EVAL: [{0}/{1}] '
                'Elapsed {remain:s} '
                'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                .format(
                    batch_idx, len(valid_loader), batch_time=batch_time, loss=losses,
                    remain=timeSince(start, float(batch_idx+1)/len(valid_loader)),
                ))
        del preds, images, targets
        gc.collect()
        torch.cuda.empty_cache()
    if criterion is None:
        return test_targets, test_preds, test_grid_idx
    else:
        return test_targets, test_preds, test_grid_idx, losses.avg

# %% [markdown]
# # training loop

# %%
# def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list):
#     # concat pred img and label to original size
#     img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
#     img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
#     img = img.reshape(img.shape[0], img.shape[1], 1)
#     pred_img = np.zeros_like(img).astype(np.float32)
#     label_img = np.zeros_like(img).astype(np.float32)
#     for img_idx, grid_idx in enumerate(grid_idx_list):
#         pred_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += img_list[img_idx]
        
#         label_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += label_list[img_idx]
#     return pred_img, label_img

# %%
def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list, slide_pos=[0,0]):
    # concat pred img and label to original size
    img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    img = img.reshape(img.shape[0], img.shape[1], 1)
    pred_img = np.zeros_like(img).astype(np.float32)
    label_img = np.zeros_like(img).astype(np.float32)
    for img_idx, grid_idx in enumerate(grid_idx_list):
        pred_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += img_list[img_idx]
        
        label_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += label_list[img_idx]
    return pred_img, label_img

# %%
def save_and_plot_oof(mode, fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary):
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_pred_img.png"), valid_preds_img*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_predbin_img.png"), valid_preds_binary*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_targets_img.png"), valid_targets_img*255)
    
    # plot preds & binary preds
    # plt.figure(dpi=100)
    # plt.subplot(1,3,1)
    # plt.imshow(valid_preds_img)
    # plt.subplot(1,3,2)
    # plt.imshow(valid_preds_binary)
    # plt.subplot(1,3,3)
    # plt.imshow(valid_targets_img)
    # plt.show()

# %%
def training_loop(CFG):
    best_score_list = []
    best_threshold_list = []
    best_epoch_list = []
    slice_ave_score_list = []
    slice_ave_auc_list = []
    slice_ave_score_threshold_list = []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} training start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        model = model.to(device)
        valid_img_slice = []
        criterion = nn.BCELoss()
        optimizer = AdamW(model.parameters(), lr=CFG["lr"], weight_decay=CFG["weight_decay"], amsgrad=False)
        scheduler = CosineAnnealingLR(optimizer, T_max=CFG["T_max"], eta_min=CFG["min_lr"], last_epoch=-1)
        # scheduler = ExponentialLR(optimizer, gamma=0.60)
        
        # training
        best_score = -np.inf
        best_auc = -np.inf
        best_valloss = np.inf
        best_auc_valloss = np.inf
        best_threshold = -1
        start_time = time.time()
        best_epoch = -1
        best_auc_epoch = -1
        valid_slice_ave = None       
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            # separate train/valid data 
            train_dirs = CFG["TRAIN_DIR_LIST"][fold]
            valid_dirs = CFG["VALID_DIR_LIST"][fold]
            train_dataset = VCID_Dataset(CFG, train_dirs, surface_list, mode="train", transform=train_transforms)
            valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, mode="valid", transform=valid_transforms)
            train_loader = DataLoader(train_dataset, batch_size=CFG["batch_size"], shuffle = True,
                                        num_workers = CFG["num_workers"], pin_memory = True)
            valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                        num_workers = CFG["num_workers"], pin_memory = True)
            for epoch in range(1, CFG["n_epoch"] + 1):
                epochs_ = epoch + CFG["n_epoch"] * slice_idx
                print(f'- epoch:{epochs_} -')
                train_loss_avg = train_fn(train_loader, model, criterion, epochs_ ,optimizer, scheduler)
                valid_targets, valid_preds, valid_grid_idx, valid_loss_avg = valid_fn(model, valid_loader, criterion)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                
                elapsed = time.time() - start_time
                print(f"\t epoch:{epochs_}, avg train loss:{train_loss_avg:.4f}, avg valid loss:{valid_loss_avg:.4f}")
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                if not CFG["DEBUG"]:
                    logging_metrics_epoch(CFG, fold, epoch, slice_idx, train_loss_avg, valid_loss_avg, valid_score, valid_threshold, auc)
                scheduler.step()
                # validationスコアがbestを更新したらモデルを保存する
                if valid_score > best_score:
                    best_epoch = epochs_
                    best_valloss = valid_loss_avg
                    best_score = valid_score
                    best_threshold = valid_threshold
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epochs_} - Save Best Score: {best_score:.4f}. Model is saved.')
                    print("dice_list: ", dice_list)
                    # save oof
                    save_and_plot_oof("score", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
                
                if auc > best_auc:
                    best_auc = auc
                    best_auc_epoch = epochs_
                    best_auc_valloss = valid_loss_avg
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_auc_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epochs_} - Save Best AUC: {best_auc:.4f}. Model is saved.')
                    # save oof
                    save_and_plot_oof("auc", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
            # valid_img_slice.append(valid_preds_img)
            if valid_slice_ave is None:
                valid_slice_ave = valid_preds_img
            else:
                valid_slice_ave += valid_preds_img
        # valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        # for idx in range(len(SURFACE_LIST)):
        #     valid_pred_slice = valid_img_slice[idx]
        #     valid_slice_ave += valid_pred_slice
        valid_slice_ave /= len(SURFACE_LIST)
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_slice_ave)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)
 
        valid_slice_binary = (valid_slice_ave > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 999, valid_slice_ave, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
        
        print(f'[fold{fold}] BEST Epoch {best_epoch} - Save Best Score:{best_score:.4f}. Best loss:{best_valloss:.4f}')
        print(f'[fold{fold}] BEST AUC Epoch {best_auc_epoch} - Save Best Score:{best_auc:.4f}. Best loss:{best_auc_valloss:.4f}')
            
        best_score_list.append(best_score)
        best_threshold_list.append(best_threshold)
        best_epoch_list.append(best_epoch)
        del model, train_loader, train_dataset, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
        
    for fold, (best_score, best_threshold, best_epoch) in enumerate(zip(best_score_list, best_threshold_list, best_epoch_list)):
        print(f"fold[{fold}] BEST SCORE = {best_score:.4f} thr={best_threshold} (epoch={best_epoch})")
        print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    return best_score_list, best_threshold_list, best_epoch_list

# %% [markdown]
# # slice inference

# %%
def slide_inference(CFG):
    start_time = time.time()
    slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list = [], [], []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} slide inference start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        # model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_fold{fold}.pth')
        model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_auc_fold{fold}.pth')
        model.load_state_dict(torch.load(model_path))
        model = model.to(device)
        valid_img_slice = None
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            surface_volumes = None
            for slide_pos in CFG["slide_pos_list"]:
                print("slide pos:", slide_pos)
                valid_dirs = CFG["VALID_DIR_LIST"][fold]
                valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos, mode="valid", transform=valid_transforms)
                surface_volumes = valid_dataset.get_surface_volumes()
                valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                            num_workers = CFG["num_workers"], pin_memory = True)

                valid_targets, valid_preds, valid_grid_idx = valid_fn(model, valid_loader)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs, slide_pos)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                save_and_plot_oof("slide", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary) 
                
                elapsed = time.time() - start_time
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                # valid_img_slice.append(valid_preds_img)
                if valid_img_slice is None:
                    valid_img_slice = valid_preds_img
                else:
                    valid_img_slice += valid_preds_img
            # valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        # for idx in range(len(SURFACE_LIST)*len(CFG["slide_pos_list"])):
        #     valid_pred_slice = valid_img_slice[idx]
        #     valid_slice_ave += valid_pred_slice
        valid_img_slice /= len(SURFACE_LIST)*len(CFG["slide_pos_list"])
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_img_slice)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)

        valid_slice_binary = (valid_img_slice > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 555, valid_img_slice, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
         
        del model, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
    return slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list

# %% [markdown]
# # main

# %%
# %%time
best_score_list, best_threshold_list, best_epoch_list = training_loop(CFG)
# Out:
# -- fold0 training start --
# surface_list:  [26, 29, 32, 35]
# - epoch:1 -
# Epoch: [1][0/61] Elapsed 0m 1s (remain 1m 20s) Loss: 0.8052(0.8052)
# Epoch: [1][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.4633(0.4842)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1316(0.1316)
# EVAL: [13/14] Elapsed 0m 2s (remain 0m 0s) Loss: 0.5416(0.3156)
# 	 epoch:1, avg train loss:0.4842, avg valid loss:0.3156
# 	 score:0.3495(th=0.200000), auc=0.841900::: time:77.78s
# Epoch 1 - Save Best Score: 0.3495. Model is saved.
# dice_list:  [0.27827806333190797, 0.3277579129306529, 0.3494588805657358, 0.34482341000999045, 0.3157774821520497, 0.26675137836390966, 0.20744695550801007, 0.14704737496545434, 0.09449350149989004, 0.054772823146717, 0.028022551255967542, 0.0125896011057315, 0.0049467750185662965, 0.0016329648031704381, 0.0004618233499267744, 0.000118744097700803, 3.209790655122411e-05, 6.419837506737811e-06, 0.0]
# Epoch 1 - Save Best AUC: 0.8419. Model is saved.
# - epoch:2 -
# Epoch: [2][0/61] Elapsed 0m 1s (remain 1m 10s) Loss: 0.4630(0.4630)
# Epoch: [2][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.4985(0.4302)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1495(0.1495)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4279(0.2967)
# 	 epoch:2, avg train loss:0.4302, avg valid loss:0.2967
# 	 score:0.4209(th=0.350000), auc=0.857220::: time:124.06s
# Epoch 2 - Save Best Score: 0.4209. Model is saved.
# dice_list:  [0.21218182982090358, 0.28150616491826225, 0.34165624238432935, 0.38489519290051427, 0.4101877602997465, 0.4208902038664655, 0.41684186142533636, 0.39583081875310827, 0.35497347881473607, 0.2958215370883596, 0.22503560215560311, 0.15182595143342442, 0.09017145147550275, 0.04667448103697893, 0.020695621161604796, 0.006930519040374771, 0.001087358162759644, 2.5683010872521082e-05, 0.0]
# Epoch 2 - Save Best AUC: 0.8572. Model is saved.
# - epoch:3 -
# Epoch: [3][0/61] Elapsed 0m 1s (remain 1m 15s) Loss: 0.3547(0.3547)
# Epoch: [3][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.4947(0.4109)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1368(0.1368)
# EVAL: [13/14] Elapsed 0m 2s (remain 0m 0s) Loss: 0.4355(0.2845)
# 	 epoch:3, avg train loss:0.4109, avg valid loss:0.2845
# 	 score:0.4688(th=0.350000), auc=0.871605::: time:170.29s
# Epoch 3 - Save Best Score: 0.4688. Model is saved.
# dice_list:  [0.26312782094951637, 0.3405666979686127, 0.39998446454875736, 0.4380692667363992, 0.45986436254289725, 0.468848674373145, 0.46278271614270056, 0.4413671252529455, 0.4034936949576709, 0.34834900650705897, 0.27838795466653143, 0.19880064888043097, 0.12180309383236515, 0.05997098101859732, 0.021027470272234308, 0.003364474790610434, 9.951559666178636e-05, 0.0, 0.0]
# Epoch 3 - Save Best AUC: 0.8716. Model is saved.
# - epoch:4 -
# Epoch: [4][0/61] Elapsed 0m 1s (remain 1m 16s) Loss: 0.3575(0.3575)
# Epoch: [4][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3709(0.3911)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1833(0.1833)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4088(0.2908)
# 	 epoch:4, avg train loss:0.3911, avg valid loss:0.2908
# 	 score:0.4704(th=0.500000), auc=0.876460::: time:216.02s
# Epoch 4 - Save Best Score: 0.4704. Model is saved.
# dice_list:  [0.22451800938733366, 0.27813050925978317, 0.3266726677404292, 0.3678978066998485, 0.4024861584804269, 0.43201765556446564, 0.45491572179302486, 0.4687008542533346, 0.47035653245305453, 0.45632404793015213, 0.4220197509978352, 0.36073473824171987, 0.27194751492063773, 0.16708995758548675, 0.07323958266267926, 0.018168407227225673, 0.0009271171270729712, 3.2104340760326393e-06, 0.0]
# Epoch 4 - Save Best AUC: 0.8765. Model is saved.
# - epoch:5 -
# Epoch: [5][0/61] Elapsed 0m 1s (remain 1m 12s) Loss: 0.3884(0.3884)
# Epoch: [5][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3033(0.3755)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1667(0.1667)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3813(0.2820)
# 	 epoch:5, avg train loss:0.3755, avg valid loss:0.2820
# 	 score:0.5079(th=0.450000), auc=0.873053::: time:261.95s
# Epoch 5 - Save Best Score: 0.5079. Model is saved.
# dice_list:  [0.23542906248779646, 0.300513100169914, 0.35710392692602083, 0.4044298250403154, 0.44424263960740495, 0.47715566302762175, 0.49975579988984836, 0.5078906760684837, 0.49857026199070187, 0.4683678464164521, 0.41342630977979905, 0.33047120220214676, 0.23481615792491495, 0.1461683943988247, 0.07315542024668502, 0.024876443521839327, 0.006573922466797766, 5.778529036373427e-05, 0.0]
# - epoch:6 -
# Epoch: [6][0/61] Elapsed 0m 1s (remain 1m 16s) Loss: 0.4587(0.4587)
# Epoch: [6][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3435(0.3730)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1734(0.1734)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3832(0.2841)
# 	 epoch:6, avg train loss:0.3730, avg valid loss:0.2841
# 	 score:0.5057(th=0.450000), auc=0.873367::: time:306.26s
# - epoch:7 -
# Epoch: [7][0/61] Elapsed 0m 1s (remain 1m 19s) Loss: 0.2629(0.2629)
# Epoch: [7][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2570(0.3623)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1438(0.1438)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4152(0.2745)
# 	 epoch:7, avg train loss:0.3623, avg valid loss:0.2745
# 	 score:0.5294(th=0.500000), auc=0.878677::: time:349.29s
# Epoch 7 - Save Best Score: 0.5294. Model is saved.
# dice_list:  [0.2583353299313908, 0.3358080694980906, 0.3951345291143514, 0.4372661825123511, 0.46867281397947186, 0.49414616984016896, 0.5147684648001933, 0.5275634537704422, 0.5294212409082194, 0.5142002123142646, 0.4759358021050247, 0.4082087288264841, 0.3147679221061006, 0.20826796670850478, 0.11615126959369232, 0.04435204182601751, 0.004417950831837955, 9.631252756578759e-06, 0.0]
# Epoch 7 - Save Best AUC: 0.8787. Model is saved.
# - epoch:8 -
# Epoch: [8][0/61] Elapsed 0m 1s (remain 1m 12s) Loss: 0.2844(0.2844)
# Epoch: [8][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.4579(0.3699)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1468(0.1468)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4150(0.2785)
# 	 epoch:8, avg train loss:0.3699, avg valid loss:0.2785
# 	 score:0.4781(th=0.400000), auc=0.879395::: time:395.36s
# Epoch 8 - Save Best AUC: 0.8794. Model is saved.
# - epoch:9 -
# Epoch: [9][0/61] Elapsed 0m 1s (remain 1m 14s) Loss: 0.3787(0.3787)
# Epoch: [9][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2480(0.3877)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.2015(0.2015)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3798(0.2975)
# 	 epoch:9, avg train loss:0.3877, avg valid loss:0.2975
# 	 score:0.5107(th=0.650000), auc=0.888599::: time:439.44s
# Epoch 9 - Save Best AUC: 0.8886. Model is saved.
# - epoch:10 -
# Epoch: [10][0/61] Elapsed 0m 1s (remain 1m 13s) Loss: 0.3742(0.3742)
# Epoch: [10][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3592(0.3798)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1518(0.1518)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4090(0.2862)
# 	 epoch:10, avg train loss:0.3798, avg valid loss:0.2862
# 	 score:0.4677(th=0.350000), auc=0.875293::: time:483.03s
# - epoch:11 -
# Epoch: [11][0/61] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2813(0.2813)
# Epoch: [11][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4438(0.3822)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.2321(0.2321)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3825(0.3339)
# 	 epoch:11, avg train loss:0.3822, avg valid loss:0.3339
# 	 score:0.4058(th=0.600000), auc=0.871279::: time:525.04s
# - epoch:12 -
# Epoch: [12][0/61] Elapsed 0m 1s (remain 1m 17s) Loss: 0.3839(0.3839)
# Epoch: [12][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3884(0.3708)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1651(0.1651)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4404(0.3031)
# 	 epoch:12, avg train loss:0.3708, avg valid loss:0.3031
# 	 score:0.3895(th=0.450000), auc=0.843808::: time:566.72s
# - epoch:13 -
# Epoch: [13][0/61] Elapsed 0m 1s (remain 1m 22s) Loss: 0.3074(0.3074)
# Epoch: [13][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3967(0.3609)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1613(0.1613)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3592(0.2748)
# 	 epoch:13, avg train loss:0.3609, avg valid loss:0.2748
# 	 score:0.5255(th=0.550000), auc=0.885793::: time:608.54s
# - epoch:14 -
# Epoch: [14][0/61] Elapsed 0m 1s (remain 1m 19s) Loss: 0.3456(0.3456)
# Epoch: [14][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4081(0.3428)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1318(0.1318)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3822(0.2699)
# 	 epoch:14, avg train loss:0.3428, avg valid loss:0.2699
# 	 score:0.5229(th=0.500000), auc=0.885826::: time:650.01s
# - epoch:15 -
# Epoch: [15][0/61] Elapsed 0m 1s (remain 1m 15s) Loss: 0.3043(0.3043)
# Epoch: [15][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3637(0.3313)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1337(0.1337)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3772(0.2668)
# 	 epoch:15, avg train loss:0.3313, avg valid loss:0.2668
# 	 score:0.5354(th=0.500000), auc=0.887330::: time:691.13s
# Epoch 15 - Save Best Score: 0.5354. Model is saved.
# dice_list:  [0.2943194577185759, 0.3535396872754539, 0.4040297357461701, 0.44149664768480024, 0.47009380758863917, 0.49231583269912593, 0.51434259744669, 0.5304306128848559, 0.5353826434025505, 0.5327501946221761, 0.5173988736374378, 0.4809501117337527, 0.4223608788775113, 0.34020894108805333, 0.22677666243617203, 0.09973658633547955, 0.018087229166813015, 0.0, 0.0]
# surface_list:  [27, 30, 33, 36]
# - epoch:16 -
# Epoch: [16][0/61] Elapsed 0m 1s (remain 1m 21s) Loss: 0.4182(0.4182)
# Epoch: [16][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.5132(0.3317)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1392(0.1392)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3792(0.2686)
# 	 epoch:16, avg train loss:0.3317, avg valid loss:0.2686
# 	 score:0.5327(th=0.500000), auc=0.884103::: time:766.44s
# - epoch:17 -
# Epoch: [17][0/61] Elapsed 0m 1s (remain 1m 13s) Loss: 0.3121(0.3121)
# Epoch: [17][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2569(0.3320)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1790(0.1790)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3804(0.2803)
# 	 epoch:17, avg train loss:0.3320, avg valid loss:0.2803
# 	 score:0.5244(th=0.550000), auc=0.874590::: time:807.70s
# - epoch:18 -
# Epoch: [18][0/61] Elapsed 0m 1s (remain 1m 18s) Loss: 0.3215(0.3215)
# Epoch: [18][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3616(0.3309)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1357(0.1357)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4248(0.2720)
# 	 epoch:18, avg train loss:0.3309, avg valid loss:0.2720
# 	 score:0.5494(th=0.500000), auc=0.887643::: time:849.28s
# Epoch 18 - Save Best Score: 0.5494. Model is saved.
# dice_list:  [0.2707903381482172, 0.32373484806768027, 0.36807430776279604, 0.4111223905575803, 0.4491856691362494, 0.48408137076441043, 0.5115831393071464, 0.5341644872730087, 0.5493808706922042, 0.5474749755481549, 0.5326613311354779, 0.49942860714961573, 0.4354923938523285, 0.3445518368936713, 0.22914254426285047, 0.10971491725199209, 0.028172279850929648, 1.1236447119973918e-05, 0.0]
# - epoch:19 -
# Epoch: [19][0/61] Elapsed 0m 1s (remain 1m 12s) Loss: 0.2857(0.2857)
# Epoch: [19][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3597(0.3409)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1706(0.1706)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4161(0.2937)
# 	 epoch:19, avg train loss:0.3409, avg valid loss:0.2937
# 	 score:0.5138(th=0.650000), auc=0.880132::: time:891.89s
# - epoch:20 -
# Epoch: [20][0/61] Elapsed 0m 1s (remain 1m 21s) Loss: 0.3941(0.3941)
# Epoch: [20][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3787(0.3453)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1588(0.1588)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3555(0.2831)
# 	 epoch:20, avg train loss:0.3453, avg valid loss:0.2831
# 	 score:0.5257(th=0.600000), auc=0.881692::: time:933.04s
# - epoch:21 -
# Epoch: [21][0/61] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2605(0.2605)
# Epoch: [21][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3080(0.3459)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.3103(0.3103)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4007(0.3969)
# 	 epoch:21, avg train loss:0.3459, avg valid loss:0.3969
# 	 score:0.4831(th=0.800000), auc=0.878998::: time:974.38s
# - epoch:22 -
# Epoch: [22][0/61] Elapsed 0m 1s (remain 1m 23s) Loss: 0.2795(0.2795)
# Epoch: [22][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.5758(0.3451)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1646(0.1646)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3601(0.2882)
# 	 epoch:22, avg train loss:0.3451, avg valid loss:0.2882
# 	 score:0.5022(th=0.650000), auc=0.875636::: time:1015.86s
# - epoch:23 -
# Epoch: [23][0/61] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2060(0.2060)
# Epoch: [23][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2556(0.3292)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1782(0.1782)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3508(0.2836)
# 	 epoch:23, avg train loss:0.3292, avg valid loss:0.2836
# 	 score:0.5122(th=0.600000), auc=0.876568::: time:1057.36s
# - epoch:24 -
# Epoch: [24][0/61] Elapsed 0m 1s (remain 1m 13s) Loss: 0.2387(0.2387)
# Epoch: [24][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2032(0.3153)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1549(0.1549)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3797(0.2764)
# 	 epoch:24, avg train loss:0.3153, avg valid loss:0.2764
# 	 score:0.5188(th=0.550000), auc=0.882677::: time:1098.82s
# - epoch:25 -
# Epoch: [25][0/61] Elapsed 0m 1s (remain 1m 18s) Loss: 0.3356(0.3356)
# Epoch: [25][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2149(0.3085)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1492(0.1492)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3742(0.2790)
# 	 epoch:25, avg train loss:0.3085, avg valid loss:0.2790
# 	 score:0.5166(th=0.600000), auc=0.882862::: time:1140.31s
# - epoch:26 -
# Epoch: [26][0/61] Elapsed 0m 1s (remain 1m 21s) Loss: 0.5151(0.5151)
# Epoch: [26][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4278(0.3112)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1548(0.1548)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3718(0.2829)
# 	 epoch:26, avg train loss:0.3112, avg valid loss:0.2829
# 	 score:0.5137(th=0.600000), auc=0.883473::: time:1181.77s
# - epoch:27 -
# Epoch: [27][0/61] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2924(0.2924)
# Epoch: [27][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3443(0.3054)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1397(0.1397)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3871(0.2736)
# 	 epoch:27, avg train loss:0.3054, avg valid loss:0.2736
# 	 score:0.5163(th=0.550000), auc=0.881624::: time:1223.10s
# - epoch:28 -
# Epoch: [28][0/61] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2833(0.2833)
# Epoch: [28][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3034(0.3040)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1681(0.1681)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3609(0.2917)
# 	 epoch:28, avg train loss:0.3040, avg valid loss:0.2917
# 	 score:0.4741(th=0.600000), auc=0.868748::: time:1264.78s
# - epoch:29 -
# Epoch: [29][0/61] Elapsed 0m 1s (remain 1m 16s) Loss: 0.2453(0.2453)
# Epoch: [29][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2626(0.3196)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1478(0.1478)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3966(0.2883)
# 	 epoch:29, avg train loss:0.3196, avg valid loss:0.2883
# 	 score:0.5257(th=0.600000), auc=0.886760::: time:1305.87s
# - epoch:30 -
# Epoch: [30][0/61] Elapsed 0m 1s (remain 1m 22s) Loss: 0.2910(0.2910)
# Epoch: [30][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2961(0.3388)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.2009(0.2009)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3996(0.3238)
# 	 epoch:30, avg train loss:0.3388, avg valid loss:0.3238
# 	 score:0.5014(th=0.700000), auc=0.888869::: time:1347.35s
# Epoch 30 - Save Best AUC: 0.8889. Model is saved.
# surface_list:  [25, 28, 31, 34]
# - epoch:31 -
# Epoch: [31][0/61] Elapsed 0m 1s (remain 1m 16s) Loss: 0.3739(0.3739)
# Epoch: [31][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2798(0.3547)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1424(0.1424)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4105(0.2887)
# 	 epoch:31, avg train loss:0.3547, avg valid loss:0.2887
# 	 score:0.5029(th=0.500000), auc=0.874815::: time:1423.83s
# - epoch:32 -
# Epoch: [32][0/61] Elapsed 0m 1s (remain 1m 21s) Loss: 0.3250(0.3250)
# Epoch: [32][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2995(0.3335)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1450(0.1450)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3648(0.2882)
# 	 epoch:32, avg train loss:0.3335, avg valid loss:0.2882
# 	 score:0.5248(th=0.650000), auc=0.879248::: time:1466.03s
# - epoch:33 -
# Epoch: [33][0/61] Elapsed 0m 1s (remain 1m 21s) Loss: 0.3192(0.3192)
# Epoch: [33][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3282(0.3283)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1236(0.1236)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3828(0.2819)
# 	 epoch:33, avg train loss:0.3283, avg valid loss:0.2819
# 	 score:0.5533(th=0.600000), auc=0.877847::: time:1507.61s
# Epoch 33 - Save Best Score: 0.5533. Model is saved.
# dice_list:  [0.2721360756935333, 0.31290297467496947, 0.34743360624413794, 0.3800524535065105, 0.4143156833847539, 0.4473286039698447, 0.4762765823583437, 0.49940461989227225, 0.5248185133521894, 0.5468410100562638, 0.5533406685819994, 0.5346690988725274, 0.482225948645313, 0.3946356165353175, 0.2822601414395737, 0.157175396478865, 0.028761894366092958, 0.0, 0.0]
# - epoch:34 -
# Epoch: [34][0/61] Elapsed 0m 1s (remain 1m 18s) Loss: 0.3722(0.3722)
# Epoch: [34][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2537(0.3118)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1359(0.1359)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3609(0.2747)
# 	 epoch:34, avg train loss:0.3118, avg valid loss:0.2747
# 	 score:0.5718(th=0.550000), auc=0.871902::: time:1550.60s
# Epoch 34 - Save Best Score: 0.5718. Model is saved.
# dice_list:  [0.2758597782679815, 0.3274553819864673, 0.37597544799092925, 0.421877967491969, 0.4666720320955796, 0.5038052842997174, 0.5368645948405607, 0.5579533896585014, 0.568879956267684, 0.5717840234986112, 0.5616551563718001, 0.5303976267529505, 0.4616422103712678, 0.368277949136135, 0.2438955478724095, 0.11879463491563379, 0.020396029439371303, 0.0, 0.0]
# - epoch:35 -
# Epoch: [35][0/61] Elapsed 0m 1s (remain 1m 12s) Loss: 0.3857(0.3857)
# Epoch: [35][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2948(0.2978)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1678(0.1678)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3500(0.2846)
# 	 epoch:35, avg train loss:0.2978, avg valid loss:0.2846
# 	 score:0.5691(th=0.650000), auc=0.878539::: time:1593.09s
# - epoch:36 -
# Epoch: [36][0/61] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2831(0.2831)
# Epoch: [36][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2834(0.2905)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1845(0.1845)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3520(0.2919)
# 	 epoch:36, avg train loss:0.2905, avg valid loss:0.2919
# 	 score:0.5654(th=0.700000), auc=0.879082::: time:1634.95s
# - epoch:37 -
# Epoch: [37][0/61] Elapsed 0m 1s (remain 1m 22s) Loss: 0.2341(0.2341)
# Epoch: [37][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2182(0.2919)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1661(0.1661)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3651(0.2891)
# 	 epoch:37, avg train loss:0.2919, avg valid loss:0.2891
# 	 score:0.5737(th=0.700000), auc=0.883012::: time:1677.00s
# Epoch 37 - Save Best Score: 0.5737. Model is saved.
# dice_list:  [0.24378142151084353, 0.28580851243464633, 0.32346743488726276, 0.3588091183456492, 0.3910641330148618, 0.42007723589295975, 0.44838567876779445, 0.47825414003741623, 0.5063186647142208, 0.5327001153894672, 0.5566148799096077, 0.5712111209199071, 0.5737458980826194, 0.5591746129514592, 0.5042411618164657, 0.3899853760879815, 0.20885368089904346, 0.024502739573443667, 0.0]
# - epoch:38 -
# Epoch: [38][0/61] Elapsed 0m 1s (remain 1m 17s) Loss: 0.4324(0.4324)
# Epoch: [38][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3707(0.2965)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1558(0.1558)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3489(0.2718)
# 	 epoch:38, avg train loss:0.2965, avg valid loss:0.2718
# 	 score:0.5504(th=0.550000), auc=0.886008::: time:1719.74s
# - epoch:39 -
# Epoch: [39][0/61] Elapsed 0m 1s (remain 1m 25s) Loss: 0.3475(0.3475)
# Epoch: [39][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3352(0.3122)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1247(0.1247)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4246(0.2892)
# 	 epoch:39, avg train loss:0.3122, avg valid loss:0.2892
# 	 score:0.4972(th=0.550000), auc=0.873047::: time:1761.21s
# - epoch:40 -
# Epoch: [40][0/61] Elapsed 0m 1s (remain 1m 15s) Loss: 0.3496(0.3496)
# Epoch: [40][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3650(0.3156)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1397(0.1397)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4326(0.2897)
# 	 epoch:40, avg train loss:0.3156, avg valid loss:0.2897
# 	 score:0.5376(th=0.600000), auc=0.881235::: time:1802.55s
# - epoch:41 -
# Epoch: [41][0/61] Elapsed 0m 1s (remain 1m 20s) Loss: 0.3101(0.3101)
# Epoch: [41][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2225(0.3164)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1157(0.1157)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3983(0.2921)
# 	 epoch:41, avg train loss:0.3164, avg valid loss:0.2921
# 	 score:0.5033(th=0.550000), auc=0.868565::: time:1844.30s
# - epoch:42 -
# Epoch: [42][0/61] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2217(0.2217)
# Epoch: [42][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2839(0.3153)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.0778(0.0778)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.5146(0.2776)
# 	 epoch:42, avg train loss:0.3153, avg valid loss:0.2776
# 	 score:0.5457(th=0.500000), auc=0.884344::: time:1885.54s
# - epoch:43 -
# Epoch: [43][0/61] Elapsed 0m 1s (remain 1m 19s) Loss: 0.3511(0.3511)
# Epoch: [43][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2457(0.3154)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1149(0.1149)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4508(0.2735)
# 	 epoch:43, avg train loss:0.3154, avg valid loss:0.2735
# 	 score:0.5564(th=0.600000), auc=0.885326::: time:1927.02s
# - epoch:44 -
# Epoch: [44][0/61] Elapsed 0m 1s (remain 1m 14s) Loss: 0.2854(0.2854)
# Epoch: [44][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3268(0.2914)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1427(0.1427)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3645(0.2810)
# 	 epoch:44, avg train loss:0.2914, avg valid loss:0.2810
# 	 score:0.5438(th=0.600000), auc=0.880938::: time:1968.45s
# - epoch:45 -
# Epoch: [45][0/61] Elapsed 0m 1s (remain 1m 22s) Loss: 0.2189(0.2189)
# Epoch: [45][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1699(0.2846)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1227(0.1227)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3821(0.2810)
# 	 epoch:45, avg train loss:0.2846, avg valid loss:0.2810
# 	 score:0.5451(th=0.600000), auc=0.880392::: time:2009.60s
# [fold0] slice ave score:0.5595(th=0.550000), auc=0.896373
# [fold0] BEST Epoch 37 - Save Best Score:0.5737. Best loss:0.2891
# [fold0] BEST AUC Epoch 30 - Save Best Score:0.8889. Best loss:0.3238
# -- fold1 training start --
# surface_list:  [26, 29, 32, 35]
# - epoch:1 -
# Epoch: [1][0/57] Elapsed 0m 1s (remain 1m 14s) Loss: 0.9205(0.9205)
# Epoch: [1][56/57] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2746(0.4946)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6785(0.6785)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0989(0.4841)
# 	 epoch:1, avg train loss:0.4946, avg valid loss:0.4841
# 	 score:0.3887(th=0.600000), auc=0.763535::: time:80.18s
# Epoch 1 - Save Best Score: 0.3887. Model is saved.
# dice_list:  [0.2535748267124696, 0.29170234639198794, 0.32484469200087246, 0.3466574318074785, 0.36057174263048286, 0.37043709010257436, 0.3775670689574816, 0.38260149061274457, 0.38599027904272626, 0.38790387140895843, 0.38867960778226895, 0.38849091855276985, 0.38666906997059064, 0.3823176091601922, 0.37402642213641357, 0.3583175441239857, 0.3281539732582751, 0.24920216186962113, 0.0]
# Epoch 1 - Save Best AUC: 0.7635. Model is saved.
# - epoch:2 -
# Epoch: [2][0/57] Elapsed 0m 1s (remain 1m 5s) Loss: 0.2786(0.2786)
# Epoch: [2][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.3448(0.3939)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.7152(0.7152)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1112(0.4307)
# 	 epoch:2, avg train loss:0.3939, avg valid loss:0.4307
# 	 score:0.3497(th=0.200000), auc=0.758529::: time:129.80s
# - epoch:3 -
# Epoch: [3][0/57] Elapsed 0m 1s (remain 1m 9s) Loss: 0.3040(0.3040)
# Epoch: [3][56/57] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1517(0.3836)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6144(0.6144)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1216(0.4147)
# 	 epoch:3, avg train loss:0.3836, avg valid loss:0.4147
# 	 score:0.3834(th=0.300000), auc=0.783254::: time:175.74s
# Epoch 3 - Save Best AUC: 0.7833. Model is saved.
# - epoch:4 -
# Epoch: [4][0/57] Elapsed 0m 1s (remain 1m 12s) Loss: 0.3839(0.3839)
# Epoch: [4][56/57] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1793(0.3677)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5886(0.5886)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1001(0.3977)
# 	 epoch:4, avg train loss:0.3677, avg valid loss:0.3977
# 	 score:0.4541(th=0.300000), auc=0.804084::: time:223.73s
# Epoch 4 - Save Best Score: 0.4541. Model is saved.
# dice_list:  [0.26453603539907683, 0.3304618212989708, 0.3980477469132513, 0.43943343279552977, 0.45408556762946994, 0.4478222000649378, 0.4187227959146605, 0.35869395679353083, 0.2684399176111884, 0.16459404365733082, 0.07728597350525426, 0.02721464164070137, 0.007930859767052842, 0.002190205546571483, 0.0006865626835590423, 0.0002326206602845336, 6.411675633245587e-05, 3.6021771394557196e-06, 0.0]
# Epoch 4 - Save Best AUC: 0.8041. Model is saved.
# - epoch:5 -
# Epoch: [5][0/57] Elapsed 0m 1s (remain 1m 9s) Loss: 0.3767(0.3767)
# Epoch: [5][56/57] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4678(0.3560)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5731(0.5731)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0967(0.3909)
# 	 epoch:5, avg train loss:0.3560, avg valid loss:0.3909
# 	 score:0.4747(th=0.350000), auc=0.814631::: time:273.92s
# Epoch 5 - Save Best Score: 0.4747. Model is saved.
# dice_list:  [0.31690401335237517, 0.39249612886696456, 0.44150508717402265, 0.4632693664485989, 0.47301360161720396, 0.4746920121238058, 0.46737777361962646, 0.4473469229798588, 0.4106763242737994, 0.3557334194241214, 0.27815364298911244, 0.18596998156034467, 0.10156921239446096, 0.04057215330484527, 0.010125791876778353, 0.0009208453248791007, 1.9453598547505516e-05, 0.0, 0.0]
# Epoch 5 - Save Best AUC: 0.8146. Model is saved.
# - epoch:6 -
# Epoch: [6][0/57] Elapsed 0m 1s (remain 1m 10s) Loss: 0.2231(0.2231)
# Epoch: [6][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.1710(0.3442)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5507(0.5507)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0906(0.3871)
# 	 epoch:6, avg train loss:0.3442, avg valid loss:0.3871
# 	 score:0.4755(th=0.400000), auc=0.815427::: time:322.90s
# Epoch 6 - Save Best Score: 0.4755. Model is saved.
# dice_list:  [0.3104700948166944, 0.373027169461872, 0.41881454570617305, 0.4459927503832696, 0.46196749566969786, 0.4714412490061009, 0.4755180823740166, 0.47067093816330696, 0.4528271250526292, 0.42011136011323236, 0.3680672598419712, 0.2922778555955747, 0.19943985447471435, 0.10931551720021315, 0.04139894002432887, 0.00843995041405779, 0.00030686807050102604, 7.20233024498012e-07, 0.0]
# Epoch 6 - Save Best AUC: 0.8154. Model is saved.
# - epoch:7 -
# Epoch: [7][0/57] Elapsed 0m 1s (remain 1m 8s) Loss: 0.3031(0.3031)
# Epoch: [7][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.5431(0.3576)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5375(0.5375)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0848(0.3773)
# 	 epoch:7, avg train loss:0.3576, avg valid loss:0.3773
# 	 score:0.4999(th=0.400000), auc=0.826721::: time:372.17s
# Epoch 7 - Save Best Score: 0.4999. Model is saved.
# dice_list:  [0.31037412852698315, 0.372048139514592, 0.42241248098342943, 0.4565912914769206, 0.4795093086937909, 0.49417841232316917, 0.4999213590354525, 0.49621074520022046, 0.4812005156190465, 0.4507249890346099, 0.3962418140009087, 0.31734219680480286, 0.222855757064577, 0.12444713773045735, 0.04683608113704448, 0.008058510082556149, 0.00023124706434239336, 2.8819691027973304e-06, 0.0]
# Epoch 7 - Save Best AUC: 0.8267. Model is saved.
# - epoch:8 -
# Epoch: [8][0/57] Elapsed 0m 1s (remain 1m 5s) Loss: 0.2764(0.2764)
# Epoch: [8][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.1583(0.3458)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6021(0.6021)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1159(0.3857)
# 	 epoch:8, avg train loss:0.3458, avg valid loss:0.3857
# 	 score:0.5070(th=0.300000), auc=0.826863::: time:421.90s
# Epoch 8 - Save Best Score: 0.5070. Model is saved.
# dice_list:  [0.31280160976339233, 0.38192976742509865, 0.4459223164210938, 0.4887935309659975, 0.5070308788543594, 0.49411564796188084, 0.4520401546868655, 0.38645621104009353, 0.3080492036294812, 0.22950084969619067, 0.1574543833327302, 0.09642114916619036, 0.053679994744791314, 0.025855725452494087, 0.00786999221740808, 0.0005135309349660528, 1.4409598885158967e-06, 0.0, 0.0]
# Epoch 8 - Save Best AUC: 0.8269. Model is saved.
# - epoch:9 -
# Epoch: [9][0/57] Elapsed 0m 1s (remain 1m 16s) Loss: 0.4275(0.4275)
# Epoch: [9][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.3444(0.3504)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6026(0.6026)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1079(0.4020)
# 	 epoch:9, avg train loss:0.3504, avg valid loss:0.4020
# 	 score:0.3952(th=0.300000), auc=0.802293::: time:470.32s
# - epoch:10 -
# Epoch: [10][0/57] Elapsed 0m 1s (remain 1m 10s) Loss: 0.3656(0.3656)
# Epoch: [10][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.3544(0.3589)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6919(0.6919)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0968(0.4471)
# 	 epoch:10, avg train loss:0.3589, avg valid loss:0.4471
# 	 score:0.4081(th=0.250000), auc=0.787252::: time:515.29s
# - epoch:11 -
# Epoch: [11][0/57] Elapsed 0m 1s (remain 1m 9s) Loss: 0.3657(0.3657)
# Epoch: [11][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.6688(0.3655)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6415(0.6415)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1321(0.4108)
# 	 epoch:11, avg train loss:0.3655, avg valid loss:0.4108
# 	 score:0.4925(th=0.250000), auc=0.820961::: time:559.91s
# - epoch:12 -
# Epoch: [12][0/57] Elapsed 0m 1s (remain 1m 9s) Loss: 0.2782(0.2782)
# Epoch: [12][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.5270(0.3600)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5535(0.5535)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1043(0.4026)
# 	 epoch:12, avg train loss:0.3600, avg valid loss:0.4026
# 	 score:0.4276(th=0.350000), auc=0.804158::: time:604.52s
# - epoch:13 -
# Epoch: [13][0/57] Elapsed 0m 1s (remain 1m 15s) Loss: 0.5140(0.5140)
# Epoch: [13][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2752(0.3471)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5691(0.5691)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0942(0.4079)
# 	 epoch:13, avg train loss:0.3471, avg valid loss:0.4079
# 	 score:0.4486(th=0.350000), auc=0.807198::: time:648.32s
# - epoch:14 -
# Epoch: [14][0/57] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2881(0.2881)
# Epoch: [14][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2472(0.3363)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6030(0.6030)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0943(0.3767)
# 	 epoch:14, avg train loss:0.3363, avg valid loss:0.3767
# 	 score:0.5362(th=0.350000), auc=0.840864::: time:692.65s
# Epoch 14 - Save Best Score: 0.5362. Model is saved.
# dice_list:  [0.36801105424512326, 0.4365396739776427, 0.48517337206801786, 0.5160662282654803, 0.534761060652641, 0.5362382139321491, 0.5127977821001194, 0.4725297267246695, 0.4247410710212443, 0.36647263781794687, 0.29966461452975574, 0.22915349336001845, 0.15517897890524388, 0.08569734479002827, 0.02971028679909416, 0.0037391513790304997, 2.8821213279218594e-05, 0.0, 0.0]
# Epoch 14 - Save Best AUC: 0.8409. Model is saved.
# - epoch:15 -
# Epoch: [15][0/57] Elapsed 0m 1s (remain 1m 12s) Loss: 0.2466(0.2466)
# Epoch: [15][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1922(0.3114)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5878(0.5878)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0885(0.3711)
# 	 epoch:15, avg train loss:0.3114, avg valid loss:0.3711
# 	 score:0.5415(th=0.350000), auc=0.845612::: time:739.61s
# Epoch 15 - Save Best Score: 0.5415. Model is saved.
# dice_list:  [0.3968190453683925, 0.45536092503119785, 0.4901049262689617, 0.5157383925901603, 0.5338119061552519, 0.5415114297627344, 0.5394908594514116, 0.5293412169099588, 0.508599323976165, 0.4764348639186419, 0.4334418302554802, 0.3798922781271512, 0.31155369306170255, 0.22567325143095, 0.13167937959553322, 0.04450696661031572, 0.004774079332356509, 7.205544810811717e-07, 0.0]
# Epoch 15 - Save Best AUC: 0.8456. Model is saved.
# surface_list:  [27, 30, 33, 36]
# - epoch:16 -
# Epoch: [16][0/57] Elapsed 0m 1s (remain 1m 13s) Loss: 0.2760(0.2760)
# Epoch: [16][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1640(0.3063)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5705(0.5705)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0943(0.3713)
# 	 epoch:16, avg train loss:0.3063, avg valid loss:0.3713
# 	 score:0.5411(th=0.350000), auc=0.843087::: time:821.07s
# - epoch:17 -
# Epoch: [17][0/57] Elapsed 0m 1s (remain 1m 15s) Loss: 0.3003(0.3003)
# Epoch: [17][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.6459(0.3184)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5925(0.5925)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0920(0.3854)
# 	 epoch:17, avg train loss:0.3184, avg valid loss:0.3854
# 	 score:0.5297(th=0.400000), auc=0.835186::: time:865.61s
# - epoch:18 -
# Epoch: [18][0/57] Elapsed 0m 1s (remain 1m 17s) Loss: 0.3854(0.3854)
# Epoch: [18][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.6530(0.3184)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5763(0.5763)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0918(0.3838)
# 	 epoch:18, avg train loss:0.3184, avg valid loss:0.3838
# 	 score:0.5044(th=0.450000), auc=0.830298::: time:910.35s
# - epoch:19 -
# Epoch: [19][0/57] Elapsed 0m 1s (remain 1m 11s) Loss: 0.2782(0.2782)
# Epoch: [19][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1852(0.3206)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5244(0.5244)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0805(0.3840)
# 	 epoch:19, avg train loss:0.3206, avg valid loss:0.3840
# 	 score:0.4734(th=0.450000), auc=0.829671::: time:954.73s
# - epoch:20 -
# Epoch: [20][0/57] Elapsed 0m 1s (remain 1m 9s) Loss: 0.3669(0.3669)
# Epoch: [20][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.5947(0.3413)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6551(0.6551)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0908(0.3793)
# 	 epoch:20, avg train loss:0.3413, avg valid loss:0.3793
# 	 score:0.4829(th=0.300000), auc=0.835315::: time:999.50s
# - epoch:21 -
# Epoch: [21][0/57] Elapsed 0m 1s (remain 1m 11s) Loss: 0.2778(0.2778)
# Epoch: [21][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.3960(0.3327)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5301(0.5301)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0836(0.3742)
# 	 epoch:21, avg train loss:0.3327, avg valid loss:0.3742
# 	 score:0.5329(th=0.350000), auc=0.844795::: time:1043.97s
# - epoch:22 -
# Epoch: [22][0/57] Elapsed 0m 1s (remain 1m 14s) Loss: 0.3337(0.3337)
# Epoch: [22][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2242(0.3234)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5225(0.5225)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1034(0.3739)
# 	 epoch:22, avg train loss:0.3234, avg valid loss:0.3739
# 	 score:0.5056(th=0.400000), auc=0.836177::: time:1087.91s
# - epoch:23 -
# Epoch: [23][0/57] Elapsed 0m 1s (remain 1m 11s) Loss: 0.2466(0.2466)
# Epoch: [23][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1674(0.3166)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6796(0.6796)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1079(0.3789)
# 	 epoch:23, avg train loss:0.3166, avg valid loss:0.3789
# 	 score:0.5588(th=0.400000), auc=0.840550::: time:1131.73s
# Epoch 23 - Save Best Score: 0.5588. Model is saved.
# dice_list:  [0.41544023256669765, 0.4715156936453124, 0.5050912956817668, 0.5294953028665295, 0.548142084277541, 0.5581706576591794, 0.5588047672281844, 0.548125888144656, 0.5280823812093263, 0.4998702696743779, 0.46401868918625555, 0.42272420127628635, 0.37398171664423224, 0.30776069700248, 0.22270355878254444, 0.1273854379666506, 0.04446537237886857, 0.005399452768394581, 0.0]
# - epoch:24 -
# Epoch: [24][0/57] Elapsed 0m 1s (remain 1m 15s) Loss: 0.4107(0.4107)
# Epoch: [24][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.3154(0.2989)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6060(0.6060)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0890(0.3784)
# 	 epoch:24, avg train loss:0.2989, avg valid loss:0.3784
# 	 score:0.5420(th=0.350000), auc=0.847856::: time:1177.21s
# Epoch 24 - Save Best AUC: 0.8479. Model is saved.
# - epoch:25 -
# Epoch: [25][0/57] Elapsed 0m 1s (remain 1m 9s) Loss: 0.3782(0.3782)
# Epoch: [25][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2503(0.2917)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6425(0.6425)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0866(0.3684)
# 	 epoch:25, avg train loss:0.2917, avg valid loss:0.3684
# 	 score:0.5585(th=0.350000), auc=0.853841::: time:1223.23s
# Epoch 25 - Save Best AUC: 0.8538. Model is saved.
# - epoch:26 -
# Epoch: [26][0/57] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2845(0.2845)
# Epoch: [26][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1878(0.2918)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6041(0.6041)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1023(0.3739)
# 	 epoch:26, avg train loss:0.2918, avg valid loss:0.3739
# 	 score:0.5411(th=0.350000), auc=0.844265::: time:1269.30s
# - epoch:27 -
# Epoch: [27][0/57] Elapsed 0m 1s (remain 1m 14s) Loss: 0.3188(0.3188)
# Epoch: [27][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.3027(0.2942)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6857(0.6857)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0884(0.3730)
# 	 epoch:27, avg train loss:0.2942, avg valid loss:0.3730
# 	 score:0.5659(th=0.350000), auc=0.851071::: time:1313.47s
# Epoch 27 - Save Best Score: 0.5659. Model is saved.
# dice_list:  [0.4166411115358278, 0.4727722268235413, 0.5138965810388969, 0.5439414920580191, 0.5604741227541749, 0.5659237943044342, 0.5628617120522247, 0.5516218841689656, 0.5301054853261778, 0.4995147496068095, 0.45991654002789917, 0.40689357872695403, 0.3355051837730442, 0.2427142120784551, 0.14614793471427714, 0.06536999477700266, 0.01438116712875234, 1.657254290221459e-05, 0.0]
# - epoch:28 -
# Epoch: [28][0/57] Elapsed 0m 1s (remain 1m 14s) Loss: 0.3901(0.3901)
# Epoch: [28][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.3268(0.2889)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6889(0.6889)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1064(0.3964)
# 	 epoch:28, avg train loss:0.2889, avg valid loss:0.3964
# 	 score:0.5489(th=0.300000), auc=0.845025::: time:1358.77s
# - epoch:29 -
# Epoch: [29][0/57] Elapsed 0m 1s (remain 1m 11s) Loss: 0.3827(0.3827)
# Epoch: [29][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2085(0.2935)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5531(0.5531)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1327(0.3846)
# 	 epoch:29, avg train loss:0.2935, avg valid loss:0.3846
# 	 score:0.4998(th=0.400000), auc=0.836314::: time:1403.17s
# - epoch:30 -
# Epoch: [30][0/57] Elapsed 0m 1s (remain 1m 10s) Loss: 0.3794(0.3794)
# Epoch: [30][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2702(0.3145)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5876(0.5876)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0807(0.3728)
# 	 epoch:30, avg train loss:0.3145, avg valid loss:0.3728
# 	 score:0.5174(th=0.400000), auc=0.837314::: time:1446.85s
# surface_list:  [25, 28, 31, 34]
# - epoch:31 -
# Epoch: [31][0/57] Elapsed 0m 1s (remain 1m 13s) Loss: 0.2609(0.2609)
# Epoch: [31][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1979(0.3288)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.4947(0.4947)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0791(0.3741)
# 	 epoch:31, avg train loss:0.3288, avg valid loss:0.3741
# 	 score:0.5106(th=0.550000), auc=0.839207::: time:1524.70s
# - epoch:32 -
# Epoch: [32][0/57] Elapsed 0m 1s (remain 1m 13s) Loss: 0.3301(0.3301)
# Epoch: [32][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1955(0.3214)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5144(0.5144)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1419(0.4254)
# 	 epoch:32, avg train loss:0.3214, avg valid loss:0.4254
# 	 score:0.5003(th=0.600000), auc=0.826109::: time:1568.92s
# - epoch:33 -
# Epoch: [33][0/57] Elapsed 0m 1s (remain 1m 8s) Loss: 0.2845(0.2845)
# Epoch: [33][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2238(0.3112)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6706(0.6706)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0766(0.4002)
# 	 epoch:33, avg train loss:0.3112, avg valid loss:0.4002
# 	 score:0.5169(th=0.250000), auc=0.836176::: time:1613.11s
# - epoch:34 -
# Epoch: [34][0/57] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2881(0.2881)
# Epoch: [34][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1930(0.3001)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.7091(0.7091)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0938(0.3859)
# 	 epoch:34, avg train loss:0.3001, avg valid loss:0.3859
# 	 score:0.5299(th=0.400000), auc=0.834614::: time:1658.44s
# - epoch:35 -
# Epoch: [35][0/57] Elapsed 0m 1s (remain 1m 10s) Loss: 0.2089(0.2089)
# Epoch: [35][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.5755(0.2978)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6449(0.6449)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0897(0.3731)
# 	 epoch:35, avg train loss:0.2978, avg valid loss:0.3731
# 	 score:0.5652(th=0.400000), auc=0.846758::: time:1702.79s
# - epoch:36 -
# Epoch: [36][0/57] Elapsed 0m 1s (remain 1m 13s) Loss: 0.2855(0.2855)
# Epoch: [36][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2432(0.2831)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6758(0.6758)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0853(0.3672)
# 	 epoch:36, avg train loss:0.2831, avg valid loss:0.3672
# 	 score:0.5649(th=0.450000), auc=0.847113::: time:1747.07s
# - epoch:37 -
# Epoch: [37][0/57] Elapsed 0m 1s (remain 1m 11s) Loss: 0.3862(0.3862)
# Epoch: [37][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2623(0.2811)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.6456(0.6456)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0903(0.3751)
# 	 epoch:37, avg train loss:0.2811, avg valid loss:0.3751
# 	 score:0.5486(th=0.400000), auc=0.838929::: time:1791.37s
# - epoch:38 -
# Epoch: [38][0/57] Elapsed 0m 1s (remain 1m 14s) Loss: 0.2454(0.2454)
# Epoch: [38][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.4582(0.2839)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.7347(0.7347)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0813(0.3827)
# 	 epoch:38, avg train loss:0.2839, avg valid loss:0.3827
# 	 score:0.5498(th=0.400000), auc=0.841431::: time:1835.82s
# - epoch:39 -
# Epoch: [39][0/57] Elapsed 0m 1s (remain 1m 9s) Loss: 0.2520(0.2520)
# Epoch: [39][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2956(0.2890)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.7382(0.7382)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0757(0.3793)
# 	 epoch:39, avg train loss:0.2890, avg valid loss:0.3793
# 	 score:0.5323(th=0.450000), auc=0.842776::: time:1879.94s
# - epoch:40 -
# Epoch: [40][0/57] Elapsed 0m 1s (remain 1m 11s) Loss: 0.2397(0.2397)
# Epoch: [40][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.4424(0.3072)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.7325(0.7325)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0735(0.3854)
# 	 epoch:40, avg train loss:0.3072, avg valid loss:0.3854
# 	 score:0.5095(th=0.400000), auc=0.825848::: time:1923.89s
# - epoch:41 -
# Epoch: [41][0/57] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2153(0.2153)
# Epoch: [41][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2256(0.3010)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.7222(0.7222)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0719(0.3951)
# 	 epoch:41, avg train loss:0.3010, avg valid loss:0.3951
# 	 score:0.5046(th=0.450000), auc=0.827881::: time:1968.41s
# - epoch:42 -
# Epoch: [42][0/57] Elapsed 0m 1s (remain 1m 8s) Loss: 0.4129(0.4129)
# Epoch: [42][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.7380(0.3004)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5543(0.5543)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0724(0.3892)
# 	 epoch:42, avg train loss:0.3004, avg valid loss:0.3892
# 	 score:0.5097(th=0.550000), auc=0.826475::: time:2012.16s
# - epoch:43 -
# Epoch: [43][0/57] Elapsed 0m 1s (remain 1m 10s) Loss: 0.2796(0.2796)
# Epoch: [43][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2940(0.2887)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6294(0.6294)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0890(0.3686)
# 	 epoch:43, avg train loss:0.2887, avg valid loss:0.3686
# 	 score:0.5666(th=0.500000), auc=0.844711::: time:2056.09s
# Epoch 43 - Save Best Score: 0.5666. Model is saved.
# dice_list:  [0.3592356905163831, 0.40047674304016295, 0.4379778137496214, 0.47119672610088165, 0.5001326373699908, 0.5253548729374182, 0.5462026370036125, 0.5608417998346691, 0.5665507374184242, 0.5627144090129093, 0.5527825535429305, 0.5350645240256737, 0.5052211943432512, 0.46272514837412726, 0.40272594149454405, 0.31864405811405133, 0.20069163740293275, 0.05257027492794971, 0.0]
# - epoch:44 -
# Epoch: [44][0/57] Elapsed 0m 1s (remain 1m 10s) Loss: 0.2444(0.2444)
# Epoch: [44][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.3178(0.2826)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6867(0.6867)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1021(0.4101)
# 	 epoch:44, avg train loss:0.2826, avg valid loss:0.4101
# 	 score:0.5448(th=0.350000), auc=0.823520::: time:2101.65s
# - epoch:45 -
# Epoch: [45][0/57] Elapsed 0m 1s (remain 1m 14s) Loss: 0.1678(0.1678)
# Epoch: [45][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2133(0.2744)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5898(0.5898)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0816(0.3629)
# 	 epoch:45, avg train loss:0.2744, avg valid loss:0.3629
# 	 score:0.5828(th=0.450000), auc=0.851278::: time:2145.78s
# Epoch 45 - Save Best Score: 0.5828. Model is saved.
# dice_list:  [0.3912277203031134, 0.4408244601780357, 0.48256436769106936, 0.5167800845862217, 0.5445398274241993, 0.5656722840189646, 0.5789291077126556, 0.5828239688526723, 0.5771738805617397, 0.5612092427473439, 0.5348599656449922, 0.49510807907422444, 0.44416334127783247, 0.37402531751613816, 0.27555544867265863, 0.15360420435651184, 0.03546776322875643, 0.0008180116936289854, 0.0]
# [fold1] slice ave score:0.5820(th=0.350000), auc=0.864083
# [fold1] BEST Epoch 45 - Save Best Score:0.5828. Best loss:0.3629
# [fold1] BEST AUC Epoch 25 - Save Best Score:0.8538. Best loss:0.3684
# -- fold2 training start --
# surface_list:  [26, 29, 32, 35]
# - epoch:1 -
# Epoch: [1][0/58] Elapsed 0m 1s (remain 1m 12s) Loss: 0.8416(0.8416)
# Epoch: [1][57/58] Elapsed 0m 26s (remain 0m 0s) Loss: 0.6240(0.4871)
# EVAL: [0/18] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5968(0.5968)
# EVAL: [17/18] Elapsed 0m 3s (remain 0m 0s) Loss: 0.5351(0.5503)
# 	 epoch:1, avg train loss:0.4871, avg valid loss:0.5503
# 	 score:0.2918(th=0.500000), auc=0.738429::: time:80.98s
# Epoch 1 - Save Best Score: 0.2918. Model is saved.
# ...
# Epoch 12 - Save Best Score: 0.4824. Model is saved.
# dice_list:  [0.3331164573650395, 0.3767110770300175, 0.4064269661060665, 0.4292597227252492, 0.44932698760385575, 0.46556351820359104, 0.4779340686195009, 0.48244204160337645, 0.4811998269996184, 0.4740504506692212, 0.46191993670935994, 0.4427588347088492, 0.41592780270199026, 0.3749721292436964, 0.3167772625126515, 0.23011881300282538, 0.10386417555717344, 0.007638479427434857, 0.0]
# Epoch 12 - Save Best AUC: 0.8801. Model is saved.
# - epoch:13 -
# Epoch: [13][0/60] Elapsed 0m 1s (remain 1m 14s) Loss: 0.3580(0.3580)
# Epoch: [13][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.3732(0.3324)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2663(0.2663)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4162(0.4011)
# 	 epoch:13, avg train loss:0.3324, avg valid loss:0.4011
# 	 score:0.4323(th=0.450000), auc=0.864433::: time:658.18s
# - epoch:14 -
# Epoch: [14][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.2263(0.2263)
# Epoch: [14][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2275(0.3231)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2350(0.2350)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4016(0.3815)
# 	 epoch:14, avg train loss:0.3231, avg valid loss:0.3815
# 	 score:0.4777(th=0.450000), auc=0.877778::: time:702.78s
# - epoch:15 -
# Epoch: [15][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.2893(0.2893)
# Epoch: [15][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2582(0.2976)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2248(0.2248)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3933(0.3748)
# 	 epoch:15, avg train loss:0.2976, avg valid loss:0.3748
# 	 score:0.5088(th=0.450000), auc=0.884161::: time:747.04s
# Epoch 15 - Save Best Score: 0.5088. Model is saved.
# dice_list:  [0.3393272674732851, 0.3761267270376655, 0.41066866315646133, 0.44048297803691977, 0.4630952850608369, 0.480197390161031, 0.49652158628097365, 0.5088398106516347, 0.5058727764363834, 0.4862766841619132, 0.4397766029724248, 0.37479943183425835, 0.29554315460072306, 0.20430594335350769, 0.11646778165278919, 0.043748682126489635, 0.005651572958436471, 0.0, 0.0]
# Epoch 15 - Save Best AUC: 0.8842. Model is saved.
# surface_list:  [27, 30, 33, 36]
# - epoch:16 -
# Epoch: [16][0/60] Elapsed 0m 1s (remain 1m 16s) Loss: 0.3880(0.3880)
# Epoch: [16][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.4843(0.3192)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2296(0.2296)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3983(0.3794)
# 	 epoch:16, avg train loss:0.3192, avg valid loss:0.3794
# 	 score:0.4922(th=0.400000), auc=0.883488::: time:830.12s
# - epoch:17 -
# Epoch: [17][0/60] Elapsed 0m 1s (remain 1m 16s) Loss: 0.2074(0.2074)
# Epoch: [17][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.4479(0.3137)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2267(0.2267)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3923(0.3739)
# 	 epoch:17, avg train loss:0.3137, avg valid loss:0.3739
# 	 score:0.5023(th=0.400000), auc=0.885282::: time:875.00s
# Epoch 17 - Save Best AUC: 0.8853. Model is saved.
# - epoch:18 -
# Epoch: [18][0/60] Elapsed 0m 1s (remain 1m 13s) Loss: 0.2251(0.2251)
# Epoch: [18][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3146(0.3030)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2349(0.2349)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3914(0.3723)
# 	 epoch:18, avg train loss:0.3030, avg valid loss:0.3723
# 	 score:0.4932(th=0.450000), auc=0.886604::: time:921.66s
# Epoch 18 - Save Best AUC: 0.8866. Model is saved.
# - epoch:19 -
# Epoch: [19][0/60] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2876(0.2876)
# Epoch: [19][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.1873(0.3185)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2593(0.2593)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3794(0.4076)
# 	 epoch:19, avg train loss:0.3185, avg valid loss:0.4076
# 	 score:0.4489(th=0.600000), auc=0.875896::: time:968.13s
# - epoch:20 -
# Epoch: [20][0/60] Elapsed 0m 1s (remain 1m 13s) Loss: 0.3388(0.3388)
# Epoch: [20][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2749(0.3114)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2642(0.2642)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4015(0.4075)
# 	 epoch:20, avg train loss:0.3114, avg valid loss:0.4075
# 	 score:0.4704(th=0.250000), auc=0.882172::: time:1012.62s
# - epoch:21 -
# Epoch: [21][0/60] Elapsed 0m 1s (remain 1m 21s) Loss: 0.2708(0.2708)
# Epoch: [21][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.5805(0.3315)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2460(0.2460)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3774(0.4030)
# 	 epoch:21, avg train loss:0.3315, avg valid loss:0.4030
# 	 score:0.4628(th=0.350000), auc=0.869949::: time:1056.77s
# - epoch:22 -
# Epoch: [22][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.3579(0.3579)
# Epoch: [22][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2517(0.3257)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2553(0.2553)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4207(0.3911)
# 	 epoch:22, avg train loss:0.3257, avg valid loss:0.3911
# 	 score:0.4623(th=0.450000), auc=0.873351::: time:1101.10s
# - epoch:23 -
# Epoch: [23][0/60] Elapsed 0m 1s (remain 1m 15s) Loss: 0.3431(0.3431)
# Epoch: [23][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2517(0.3107)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2926(0.2926)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4106(0.4002)
# 	 epoch:23, avg train loss:0.3107, avg valid loss:0.4002
# 	 score:0.5104(th=0.350000), auc=0.873680::: time:1145.13s
# Epoch 23 - Save Best Score: 0.5104. Model is saved.
# dice_list:  [0.3646302948949198, 0.4195452303580032, 0.4608610777481771, 0.4877865202241031, 0.5026015735323003, 0.5104206574112236, 0.5049486594481425, 0.48984711339078246, 0.4722967461559785, 0.45140137925229984, 0.42368651164188204, 0.3888507436361276, 0.3412311452905275, 0.27810878777160863, 0.19852435649204697, 0.11671458137142167, 0.048800372552714556, 0.011214448511756347, 0.0]
# - epoch:24 -
# Epoch: [24][0/60] Elapsed 0m 1s (remain 1m 24s) Loss: 0.3399(0.3399)
# Epoch: [24][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1749(0.3051)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2447(0.2447)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3874(0.3937)
# 	 epoch:24, avg train loss:0.3051, avg valid loss:0.3937
# 	 score:0.4753(th=0.550000), auc=0.873817::: time:1191.06s
# - epoch:25 -
# Epoch: [25][0/60] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2775(0.2775)
# Epoch: [25][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2680(0.2925)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2578(0.2578)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3805(0.3843)
# 	 epoch:25, avg train loss:0.2925, avg valid loss:0.3843
# 	 score:0.5038(th=0.450000), auc=0.875826::: time:1235.35s
# - epoch:26 -
# Epoch: [26][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.4017(0.4017)
# Epoch: [26][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.1632(0.2980)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2585(0.2585)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3803(0.3859)
# 	 epoch:26, avg train loss:0.2980, avg valid loss:0.3859
# 	 score:0.5011(th=0.400000), auc=0.876392::: time:1279.68s
# - epoch:27 -
# Epoch: [27][0/60] Elapsed 0m 1s (remain 1m 9s) Loss: 0.3863(0.3863)
# Epoch: [27][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2936(0.2884)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2860(0.2860)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4143(0.4049)
# 	 epoch:27, avg train loss:0.2884, avg valid loss:0.4049
# 	 score:0.5162(th=0.350000), auc=0.874794::: time:1323.81s
# Epoch 27 - Save Best Score: 0.5162. Model is saved.
# dice_list:  [0.38329759423642723, 0.4322722079086262, 0.47236297437647007, 0.5004976268590287, 0.5139473675782112, 0.5162489203835195, 0.5055995525624881, 0.47856926578096953, 0.44330746302401763, 0.4019924853113682, 0.3491944584613371, 0.2889141790763339, 0.21907136526443216, 0.14360792448902682, 0.0712698058251479, 0.023823598523476767, 0.00235512250529566, 0.0, 0.0]
# - epoch:28 -
# Epoch: [28][0/60] Elapsed 0m 1s (remain 1m 11s) Loss: 0.2089(0.2089)
# Epoch: [28][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.5045(0.2908)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2874(0.2874)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4257(0.4052)
# 	 epoch:28, avg train loss:0.2908, avg valid loss:0.4052
# 	 score:0.5127(th=0.300000), auc=0.875272::: time:1369.37s
# - epoch:29 -
# Epoch: [29][0/60] Elapsed 0m 1s (remain 1m 14s) Loss: 0.1891(0.1891)
# Epoch: [29][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.4395(0.2891)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.3147(0.3147)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4686(0.4347)
# 	 epoch:29, avg train loss:0.2891, avg valid loss:0.4347
# 	 score:0.4874(th=0.350000), auc=0.864622::: time:1413.26s
# - epoch:30 -
# Epoch: [30][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2967(0.2967)
# Epoch: [30][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.3942(0.3054)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2623(0.2623)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3814(0.4292)
# 	 epoch:30, avg train loss:0.3054, avg valid loss:0.4292
# 	 score:0.4198(th=0.500000), auc=0.862199::: time:1457.58s
# surface_list:  [25, 28, 31, 34]
# - epoch:31 -
# Epoch: [31][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2148(0.2148)
# Epoch: [31][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2318(0.3315)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.3543(0.3543)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4317(0.4285)
# 	 epoch:31, avg train loss:0.3315, avg valid loss:0.4285
# 	 score:0.4718(th=0.300000), auc=0.855450::: time:1539.08s
# - epoch:32 -
# Epoch: [32][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.3025(0.3025)
# Epoch: [32][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2416(0.3145)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2706(0.2706)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3925(0.4110)
# 	 epoch:32, avg train loss:0.3145, avg valid loss:0.4110
# 	 score:0.4523(th=0.550000), auc=0.870263::: time:1582.95s
# - epoch:33 -
# Epoch: [33][0/60] Elapsed 0m 1s (remain 1m 22s) Loss: 0.2931(0.2931)
# Epoch: [33][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.3037(0.3010)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.3345(0.3345)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4456(0.4070)
# 	 epoch:33, avg train loss:0.3010, avg valid loss:0.4070
# 	 score:0.4341(th=0.300000), auc=0.869507::: time:1627.37s
# - epoch:34 -
# Epoch: [34][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.3780(0.3780)
# Epoch: [34][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3174(0.2905)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.3142(0.3142)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4338(0.3984)
# 	 epoch:34, avg train loss:0.2905, avg valid loss:0.3984
# 	 score:0.4573(th=0.350000), auc=0.871388::: time:1671.98s
# - epoch:35 -
# Epoch: [35][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.4752(0.4752)
# Epoch: [35][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.3238(0.2849)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2898(0.2898)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4088(0.3814)
# 	 epoch:35, avg train loss:0.2849, avg valid loss:0.3814
# 	 score:0.4910(th=0.400000), auc=0.877930::: time:1715.73s
# - epoch:36 -
# Epoch: [36][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2255(0.2255)
# Epoch: [36][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2788(0.2808)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2860(0.2860)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4080(0.3822)
# 	 epoch:36, avg train loss:0.2808, avg valid loss:0.3822
# 	 score:0.4855(th=0.450000), auc=0.877033::: time:1759.34s
# - epoch:37 -
# Epoch: [37][0/60] Elapsed 0m 1s (remain 1m 23s) Loss: 0.2902(0.2902)
# Epoch: [37][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.6050(0.2785)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.3245(0.3245)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4303(0.3938)
# 	 epoch:37, avg train loss:0.2785, avg valid loss:0.3938
# 	 score:0.4946(th=0.400000), auc=0.874869::: time:1803.27s
# - epoch:38 -
# Epoch: [38][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2229(0.2229)
# Epoch: [38][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.3093(0.2784)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.3095(0.3095)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4156(0.3881)
# 	 epoch:38, avg train loss:0.2784, avg valid loss:0.3881
# 	 score:0.4952(th=0.400000), auc=0.879587::: time:1847.31s
# - epoch:39 -
# Epoch: [39][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2364(0.2364)
# Epoch: [39][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.3222(0.2850)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.3774(0.3774)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4581(0.4136)
# 	 epoch:39, avg train loss:0.2850, avg valid loss:0.4136
# 	 score:0.4685(th=0.350000), auc=0.872313::: time:1891.03s
# - epoch:40 -
# Epoch: [40][0/60] Elapsed 0m 1s (remain 1m 10s) Loss: 0.2352(0.2352)
# Epoch: [40][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2526(0.2948)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.3533(0.3533)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3974(0.4154)
# 	 epoch:40, avg train loss:0.2948, avg valid loss:0.4154
# 	 score:0.4178(th=0.500000), auc=0.864294::: time:1934.67s
# - epoch:41 -
# Epoch: [41][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.3786(0.3786)
# Epoch: [41][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2524(0.2860)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2747(0.2747)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4459(0.4273)
# 	 epoch:41, avg train loss:0.2860, avg valid loss:0.4273
# 	 score:0.4025(th=0.500000), auc=0.851522::: time:1978.47s
# - epoch:42 -
# Epoch: [42][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.3326(0.3326)
# Epoch: [42][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2825(0.3046)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.3171(0.3171)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4553(0.4197)
# 	 epoch:42, avg train loss:0.3046, avg valid loss:0.4197
# 	 score:0.4391(th=0.300000), auc=0.862038::: time:2023.19s
# - epoch:43 -
# Epoch: [43][0/60] Elapsed 0m 1s (remain 1m 11s) Loss: 0.4327(0.4327)
# Epoch: [43][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2409(0.2924)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.3874(0.3874)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4318(0.4211)
# 	 epoch:43, avg train loss:0.2924, avg valid loss:0.4211
# 	 score:0.4695(th=0.450000), auc=0.860511::: time:2067.43s
# - epoch:44 -
# Epoch: [44][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.2363(0.2363)
# Epoch: [44][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2736(0.2718)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.3524(0.3524)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4698(0.4214)
# 	 epoch:44, avg train loss:0.2718, avg valid loss:0.4214
# 	 score:0.4708(th=0.400000), auc=0.859095::: time:2111.44s
# - epoch:45 -
# Epoch: [45][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.2073(0.2073)
# Epoch: [45][59/60] Elapsed 0m 25s (remain 0m 0s) Loss: 0.1751(0.2690)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.3583(0.3583)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4737(0.4227)
# 	 epoch:45, avg train loss:0.2690, avg valid loss:0.4227
# 	 score:0.4768(th=0.350000), auc=0.862477::: time:2155.29s
# [fold4] slice ave score:0.5105(th=0.400000), auc=0.880825
# [fold4] BEST Epoch 27 - Save Best Score:0.5162. Best loss:0.4049
# [fold4] BEST AUC Epoch 18 - Save Best Score:0.8866. Best loss:0.3723
# fold[0] BEST SCORE = 0.5737 thr=0.7 (epoch=37)
# fold[0] slice ave score:0.5595(th=0.550000), auc=0.896373
# fold[1] BEST SCORE = 0.5828 thr=0.45 (epoch=45)
# fold[1] slice ave score:0.5820(th=0.350000), auc=0.864083
# fold[2] BEST SCORE = 0.5395 thr=0.6 (epoch=39)
# fold[2] slice ave score:0.5399(th=0.400000), auc=0.847404
# fold[3] BEST SCORE = 0.5412 thr=0.5 (epoch=29)
# fold[3] slice ave score:0.5233(th=0.400000), auc=0.929714
# fold[4] BEST SCORE = 0.5162 thr=0.35 (epoch=27)
# fold[4] slice ave score:0.5105(th=0.400000), auc=0.880825
# CPU times: user 2h 5min 49s, sys: 45min 40s, total: 2h 51min 29s
# Wall time: 2h 56min 56s

# %% [markdown]
# ---
# # OOF SCORE INFER

# %%
# %%time
slice_ave_score_list, slice_ave_score_threshold_list, slice_ave_auc_list = slide_inference(CFG)
for fold in CFG["folds"]:
    print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    wandb.log({"OOF SCORE" : {f"slice average score":slice_ave_score_list[fold],
                            f"slice average threshold":slice_ave_score_threshold_list[fold],
                            f"slice_average auc":slice_ave_auc_list[fold],
                            }})
# Out:
# -- fold0 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.5029(th=0.700000), auc=0.889229::: time:26.70s
# slide pos: [256, 0]
# 	 score:0.2076(th=0.300000), auc=0.784733::: time:43.74s
# slide pos: [0, 256]
# 	 score:0.5162(th=0.700000), auc=0.897716::: time:60.87s
# slide pos: [256, 256]
# 	 score:0.2092(th=0.250000), auc=0.792953::: time:77.96s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.5014(th=0.700000), auc=0.888869::: time:101.93s
# slide pos: [256, 0]
# 	 score:0.2122(th=0.400000), auc=0.785499::: time:119.16s
# slide pos: [0, 256]
# 	 score:0.5085(th=0.700000), auc=0.900310::: time:136.00s
# slide pos: [256, 256]
# 	 score:0.2122(th=0.300000), auc=0.794575::: time:153.45s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.4955(th=0.700000), auc=0.892352::: time:178.45s
# slide pos: [256, 0]
# 	 score:0.2101(th=0.350000), auc=0.782587::: time:195.47s
# slide pos: [0, 256]
# 	 score:0.5145(th=0.700000), auc=0.896143::: time:212.65s
# slide pos: [256, 256]
# 	 score:0.2091(th=0.250000), auc=0.790834::: time:229.69s
# [fold0] slice ave score:0.4251(th=0.500000), auc=0.880641
# -- fold1 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.5557(th=0.400000), auc=0.848597::: time:271.28s
# slide pos: [256, 0]
# 	 score:0.2461(th=0.250000), auc=0.716772::: time:293.24s
# slide pos: [0, 256]
# 	 score:0.5370(th=0.400000), auc=0.844619::: time:316.17s
# slide pos: [256, 256]
# 	 score:0.2546(th=0.200000), auc=0.714163::: time:338.56s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.5585(th=0.350000), auc=0.853841::: time:365.71s
# slide pos: [256, 0]
# 	 score:0.2506(th=0.250000), auc=0.715545::: time:388.52s
# slide pos: [0, 256]
# 	 score:0.5398(th=0.350000), auc=0.852258::: time:411.01s
# slide pos: [256, 256]
# 	 score:0.2576(th=0.200000), auc=0.716418::: time:433.61s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.5540(th=0.400000), auc=0.841214::: time:461.74s
# slide pos: [256, 0]
# 	 score:0.2571(th=0.150000), auc=0.720873::: time:483.97s
# slide pos: [0, 256]
# 	 score:0.5508(th=0.400000), auc=0.839483::: time:506.77s
# slide pos: [256, 256]
# 	 score:0.2624(th=0.150000), auc=0.715901::: time:529.32s
# [fold1] slice ave score:0.4854(th=0.350000), auc=0.819070
# -- fold2 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.5398(th=0.500000), auc=0.839685::: time:573.76s
# slide pos: [256, 0]
# 	 score:0.3005(th=0.500000), auc=0.742787::: time:595.56s
# slide pos: [0, 256]
# 	 score:0.5381(th=0.500000), auc=0.845969::: time:618.23s
# slide pos: [256, 256]
# 	 score:0.3016(th=0.450000), auc=0.739620::: time:640.67s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.5234(th=0.500000), auc=0.844016::: time:667.95s
# slide pos: [256, 0]
# 	 score:0.2968(th=0.450000), auc=0.744288::: time:690.05s
# slide pos: [0, 256]
# 	 score:0.5136(th=0.500000), auc=0.845003::: time:712.33s
# slide pos: [256, 256]
# 	 score:0.3015(th=0.450000), auc=0.740494::: time:734.32s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.5315(th=0.450000), auc=0.834873::: time:760.91s
# slide pos: [256, 0]
# 	 score:0.3070(th=0.500000), auc=0.745217::: time:782.89s
# slide pos: [0, 256]
# 	 score:0.5377(th=0.450000), auc=0.843035::: time:804.59s
# slide pos: [256, 256]
# 	 score:0.3121(th=0.500000), auc=0.748911::: time:826.69s
# [fold2] slice ave score:0.4802(th=0.500000), auc=0.798748
# -- fold3 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.5300(th=0.450000), auc=0.933879::: time:866.35s
# slide pos: [256, 0]
# 	 score:0.2817(th=0.200000), auc=0.876693::: time:884.07s
# slide pos: [0, 256]
# 	 score:0.5161(th=0.450000), auc=0.927855::: time:901.85s
# slide pos: [256, 256]
# 	 score:0.2850(th=0.250000), auc=0.879456::: time:919.70s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.5063(th=0.450000), auc=0.929584::: time:940.57s
# slide pos: [256, 0]
# 	 score:0.2759(th=0.200000), auc=0.875954::: time:958.24s
# slide pos: [0, 256]
# 	 score:0.5108(th=0.400000), auc=0.924886::: time:975.93s
# slide pos: [256, 256]
# 	 score:0.2648(th=0.200000), auc=0.876174::: time:993.81s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.5102(th=0.400000), auc=0.931822::: time:1014.86s
# slide pos: [256, 0]
# 	 score:0.2938(th=0.200000), auc=0.877833::: time:1033.06s
# slide pos: [0, 256]
# 	 score:0.5022(th=0.400000), auc=0.925110::: time:1050.84s
# slide pos: [256, 256]
# 	 score:0.2776(th=0.200000), auc=0.877286::: time:1068.80s
# [fold3] slice ave score:0.5074(th=0.300000), auc=0.924369
# -- fold4 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.4897(th=0.500000), auc=0.880471::: time:1115.24s
# slide pos: [256, 0]
# 	 score:0.3230(th=0.250000), auc=0.830751::: time:1136.84s
# slide pos: [0, 256]
# 	 score:0.4936(th=0.550000), auc=0.875646::: time:1158.64s
# slide pos: [256, 256]
# 	 score:0.3028(th=0.200000), auc=0.826709::: time:1180.73s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.4932(th=0.450000), auc=0.886604::: time:1211.25s
# slide pos: [256, 0]
# 	 score:0.3535(th=0.250000), auc=0.835517::: time:1232.66s
# slide pos: [0, 256]
# 	 score:0.4993(th=0.550000), auc=0.884395::: time:1253.78s
# slide pos: [256, 256]
# 	 score:0.3180(th=0.250000), auc=0.828267::: time:1276.06s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.4458(th=0.600000), auc=0.868635::: time:1306.99s
# slide pos: [256, 0]
# 	 score:0.2954(th=0.200000), auc=0.820682::: time:1328.09s
# slide pos: [0, 256]
# 	 score:0.4292(th=0.600000), auc=0.863129::: time:1349.27s
# slide pos: [256, 256]
# 	 score:0.3011(th=0.250000), auc=0.819890::: time:1371.01s
# [fold4] slice ave score:0.5221(th=0.350000), auc=0.883932
# fold[0] slice ave score:0.4251(th=0.880641), auc=0.500000
# fold[1] slice ave score:0.4854(th=0.819070), auc=0.350000
# fold[2] slice ave score:0.4802(th=0.798748), auc=0.500000
# fold[3] slice ave score:0.5074(th=0.924369), auc=0.300000
# fold[4] slice ave score:0.5221(th=0.883932), auc=0.350000
# CPU times: user 18min 19s, sys: 3min 24s, total: 21min 44s
# Wall time: 23min 6s

# %%
import yaml
with open(os.path.join(CFG["OUTPUT_DIR"], "Config.yaml"), "w") as f:
    yaml.dump(CFG, f)

# %%
if not CFG["DEBUG"]:
    wandb.finish()
