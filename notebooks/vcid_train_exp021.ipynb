# %% [markdown]
# # ex020
# bug fix masked_img
# 5-fold
# img size 512
# output shape is half of input shape
# channel shuffle
# 学習時にrandom slide=False

# %%
import gc
import os
import random
import time
import math

import cv2
import numpy as np
import matplotlib.pyplot as plt

# model
import torch
import torchvision
import torch.nn as nn
import timm
from torchvision.models.feature_extraction import create_feature_extractor
import torchvision.transforms.functional as TF

# data loader
import albumentations as A
from albumentations.pytorch import ToTensorV2
from torch.utils.data import DataLoader, Dataset

# training
from torch.optim import SGD, Adam, AdamW
from torch.optim.lr_scheduler import CosineAnnealingLR, CosineAnnealingWarmRestarts, ReduceLROnPlateau, ExponentialLR

# metric
from sklearn.metrics import fbeta_score, roc_auc_score

import wandb

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # config

# %%
BASE_DIR = "/working/"
INPUT_DIR = os.path.join(BASE_DIR, "input", "vesuvius-challenge-ink-detection")
TRAIN_DIR = os.path.join(INPUT_DIR, "train")
TEST_DIR = os.path.join(INPUT_DIR, "test")
# IMG_SIZE = [256, 256]
# IMG_SIZE = [128, 128]
IMG_SIZE = [512, 512]
SURFACE_LIST = [
                list(range(26, 36, 3)),
                list(range(27, 37, 3)),                
                list(range(25, 35, 3)),
                ]
print(len(SURFACE_LIST[0]))
print(SURFACE_LIST)

SURFACE_NUM = len(SURFACE_LIST[0])
# print("Start surface idx =",START_SURFACE)

# SLIDE_POS_LIST = [[idx*(IMG_SIZE[0]//6), idx*(IMG_SIZE[1]//6)] for idx in range(0, 3)]
SLIDE_POS_LIST = [[0,0], [IMG_SIZE[0]//2, 0], [0, IMG_SIZE[1]//2], [IMG_SIZE[0]//2, IMG_SIZE[1]//2]]
print("SLIDE_POS_LIST =", SLIDE_POS_LIST)
CFG = {
    "DEBUG" : False,
    # exp setting
    "EXP_CATEGORY" : "5fold",
    "EXP_NAME" : "exp021",
    "folds" : [0, 1, 2, 3, 4],

    # model
    # "model_name" : "tf_efficientnet_b0",
    "model_name" : "tf_efficientnet_b6",
    "inp_channels" : SURFACE_NUM,
    "out_channels" : 1,
    "pretrained" : True,
    "out_indices" : [0,1,2,3,4],
 
    # data   
    "img_size": IMG_SIZE,
    # "batch_size": 32,
    # "batch_size": 16,#batch normの関係か？16の方が64より安定してそう？？
    "batch_size": 8,
    "INPUT_DIR": INPUT_DIR,
    "TRAIN_DIR": TRAIN_DIR,
    "TEST_DIR": TEST_DIR,
    "surface_num": SURFACE_NUM,
    "surface_list": list(SURFACE_LIST),
    "slide_pos_list": SLIDE_POS_LIST,
    "RANDOM_SLIDE": False,
#     "surface_start_idx": START_SURFACE,
    # "TRAIN_DIR_LIST": [["1", "2"], ["1", "3"], ["2", "3"]],
    "TRAIN_DIR_LIST": [["1", "2_0", "2_1", "2_2"], 
                       ["1", "2_0", "2_1", "3"],
                       ["1", "2_0",  "2_2", "3"],
                       ["1", "2_1", "2_2", "3"],
                       ["2_0", "2_1", "2_2", "3"],
                       ],
#     "TRAIN_IDX_LIST" : ["1"],
    # "VALID_DIR_LIST": [["3"],["2"],["1"]],
    "VALID_DIR_LIST": [["3"], ["2_2"], ["2_1"], ["2_0"],["1"]],
    "TEST_DIR_LIST": ["a", "b"],

    # learning
    "n_epoch" : 20,
    "lr" : 1e-3,
    "T_max" : 5,
    "min_lr" : 1e-8,
    "weight_decay" : 1e-6,

    # etc
    "print_freq" : 1000,
    "random_seed" : 21,
    "num_workers": 2,
}


if CFG["model_name"]=="tf_efficientnet_b0":
    CFG["channel_nums"] = [320, 112, 40, 24, 16]
elif CFG["model_name"]=="tf_efficientnet_b4":
    CFG["channel_nums"] = [448, 160, 56, 32, 24]
elif CFG["model_name"]=="tf_efficientnet_b6":
    CFG["channel_nums"] = [576, 200, 72, 40, 32]


if CFG["DEBUG"]:
    CFG["n_epoch"] = 1
    CFG["EXP_NAME"] = "DEBUG"
    

CFG["OUTPUT_DIR"] = os.path.join(BASE_DIR, "output", CFG["EXP_NAME"])
# Out:
# 4
# [[26, 29, 32, 35], [27, 30, 33, 36], [25, 28, 31, 34]]
# SLIDE_POS_LIST = [[0, 0], [256, 0], [0, 256], [256, 256]]

# %%
if not CFG["DEBUG"]:
    os.makedirs(CFG["OUTPUT_DIR"])
    os.makedirs(os.path.join(CFG["OUTPUT_DIR"], "imgs"))

# %%
if not CFG["DEBUG"]:
    WANDB_CONFIG = {'competition': 'vcid', '_wandb_kernel': 'taro'}
    os.environ["WANDB_SILENT"] = "true"
    wandb.init(project=WANDB_CONFIG["competition"], config=CFG, group=CFG["EXP_CATEGORY"], name=CFG["EXP_NAME"], reinit=True)
# Out:
# 2023-04-20 17:00:40.207943: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-20 17:00:40.465940: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-20 17:00:41.674761: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-20 17:00:41.675285: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-20 17:00:41.675318: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# # utils

# %%
def logging_metrics_epoch(CFG, fold, epoch, slice_idx,train_loss_avg, valid_loss_avg, score, threshold, auc_score):
    wandb.log({f"train/fold{fold}": train_loss_avg,
                f"valid/fold{fold}": valid_loss_avg,
                f"score/fold{fold}":score,
                f"score threshold/fold{fold}":threshold,
                f"auc/fold{fold}":auc_score,
                f"epoch/fold{fold}":epoch+slice_idx*CFG["n_epoch"],
                })

# %%
def seed_everything(seed=CFG["random_seed"]):
    #os.environ['PYTHONSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic =True
    torch.backends.cudnn.benchmark = False
seed_everything()

# device optimization
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
def asMinutes(s):
    """Convert Seconds to Minutes."""
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    """Accessing and Converting Time Data."""
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))

class AverageMeter(object):
    """Computes and stores the average and current value."""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# # metric

# %%
def fbeta_numpy(targets, preds, beta=0.5, smooth=1e-5):
    y_true_count = targets.sum()
    ctp = preds[targets==1].sum()
    cfp = preds[targets==0].sum()
    beta_squared = beta * beta

    c_precision = ctp / (ctp + cfp + smooth)
    c_recall = ctp / (y_true_count + smooth)
    dice = (1 + beta_squared) * (c_precision * c_recall) / (beta_squared * c_precision + c_recall + smooth)

    return dice

def calc_fbeta_auc(mask, mask_pred):
    mask = mask.astype(int).flatten()
    mask_pred = mask_pred.flatten()

    best_th = 0
    best_dice = 0
    dice_list = [] 
    # for th in np.array(range(10, 50+1, 5)) / 100:
    for th in np.array(range(10, 100+1, 5)) / 100:
        # dice = fbeta_score(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice = fbeta_numpy(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice_list.append(dice)
        # print(f'\t th: {th}, fbeta: {dice}')
        if dice > best_dice:
            best_dice = dice
            best_th = th
    
    auc = roc_auc_score(mask, mask_pred)
    # Logger.info(f'best_th: {best_th}, fbeta: {best_dice}')
    return best_dice, best_th, auc, dice_list


def calc_cv(mask_gt, mask_pred):
    best_dice, best_th, auc, dice_list = calc_fbeta_auc(mask_gt, mask_pred)

    return best_dice, best_th, auc, dice_list

# %% [markdown]
# # model

# %%
class Encoder(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = timm.create_model(CFG["model_name"], in_chans=CFG["inp_channels"], features_only=True, out_indices=CFG["out_indices"], pretrained=CFG["pretrained"])
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        return skip_connection_list

class UpConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.bn1 = nn.BatchNorm2d(in_channels)
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size = 2, padding="same")
        self.bn2 = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        x = self.up(x)
        x = self.bn1(x)
        x = self.conv(x)
        x = self.bn2(x)
        return x


class Decoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.UpConv_0 = UpConv(CFG["channel_nums"][0], CFG["channel_nums"][1])
        self.UpConv_1 = UpConv(CFG["channel_nums"][1]*2, CFG["channel_nums"][2])
        self.UpConv_2 = UpConv(CFG["channel_nums"][2]*2, CFG["channel_nums"][3])
        self.UpConv_3 = UpConv(CFG["channel_nums"][3]*2, CFG["channel_nums"][4])
        # self.UpConv_4 = UpConv(CFG["channel_nums"][4]*2, CFG["channel_nums"][4])
    
    def forward(self, skip_connection_list):
        emb = self.UpConv_0(skip_connection_list[4]) # emb.shape = (None, 160, 14, 14)
        emb_cat = torch.cat([skip_connection_list[3], emb], dim = 1)
        
        emb = self.UpConv_1(emb_cat)
        emb_cat = torch.cat([skip_connection_list[2], emb], dim = 1)
        
        emb = self.UpConv_2(emb_cat)
        emb_cat = torch.cat([skip_connection_list[1], emb], dim = 1)
        
        emb = self.UpConv_3(emb_cat)
        emb_cat = torch.cat([skip_connection_list[0], emb], dim = 1)

        # emb_cat = self.UpConv_4(emb_cat)
        
        return emb_cat

class SegModel(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = Encoder(CFG)
        self.decoder = Decoder()
        self.head = nn.Sequential(
            nn.Conv2d(CFG["channel_nums"][-1]*2, CFG["out_channels"], kernel_size=1, stride=1, padding=0),
            nn.Sigmoid()
        )
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        emb = self.decoder(skip_connection_list)
        output = self.head(emb)
        return output

# %% [markdown]
# # Dataset

# %%
train_transforms = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.RandomCrop(int(CFG["img_size"][0]*0.8), int(CFG["img_size"][1]*0.8), p=0.3),
    A.Blur(blur_limit=3, p=0.3),
    A.Resize(CFG["img_size"][0], CFG["img_size"][1]),
    ToTensorV2(),
])

valid_transforms = A.Compose([
    ToTensorV2(),
])

# %%
class VCID_Dataset(Dataset):
    def __init__(self, CFG, data_dir_list, surface_list, surface_volumes=None, slide_pos=[0,0], mode="train", transform=None):
        # get config
        self.mode = mode
        self.RANDOM_SLIDE = CFG["RANDOM_SLIDE"]
        self.img_size = CFG["img_size"]
        if self.mode=="train":  self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode=="valid":    self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode == "test":   self.DATADIR = CFG["TEST_DIR"]
        self.data_dir_list = data_dir_list
        self.surface_list = surface_list
        self.slide_pos = slide_pos
        self.transform = transform
        
        # get imgs
        # print("initializing dataset...")
        self.imgs = []
        for data_dir in self.data_dir_list:
            img_path = os.path.join(self.DATADIR, data_dir, "mask.png")
            # print(img_path)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            img = img.reshape(img.shape[0], img.shape[1], 1) # (h, w, channel=1)
            assert img is not None, "img is None. data path is wrong"
        
            # mask erosion
            kernel_size = (img.shape[0]+img.shape[1])//2//100
            kernel = np.ones((kernel_size, kernel_size), np.uint8)
            img = cv2.erode(img, kernel,iterations = 3)
            self.imgs.append(img[:,:,np.newaxis])    
        
        # get and split surface
        if surface_volumes is None:
            self.surface_vols = self.read_surfacevols()
        else:
            # print("using loaded surface_vols")
            self.surface_vols = surface_volumes
        for surface_idx, surface_vol in enumerate(self.surface_vols):
            self.surface_vols[surface_idx] = self.get_masked_img(surface_vol, self.imgs[surface_idx])
       
        # split grid
        self.get_all_grid()
        self.fileter_grid()
        self.get_flatten_grid()
        # print("split grid done.") 
       
        # get label imgs
        if self.mode == "train" or self.mode == "valid":
            self.labels = []
            for data_dir in self.data_dir_list:
                label_path = os.path.join(self.DATADIR, data_dir, "inklabels.png")
                assert os.path.exists(label_path), f"{label_path} is not exist."
                # read label
                label = cv2.imread(label_path, cv2.IMREAD_GRAYSCALE)
                label = label.reshape(label.shape[0], label.shape[1], 1) # (h, w, channel=1)
                self.labels.append(label)# 画像サイズがそれぞれ違うので単純にconcatできずlist化しているs
        # print("initializing dataset done.")

    def get_surface_volumes(self):
        return self.surface_vols

    def read_surfacevols(self):
        """ read surface volume by data_dir_list and surface_list 
            Returns:surface_vuls (list): surface volume list [array(h,w,channel=surface_num), array(), ...]
        """
        surface_vols = []
        # print("reading surface volume...")
        for data_dir in self.data_dir_list:
            surface_vol_ = None
            for read_idx, surface_idx in enumerate(self.surface_list):
                # print("\r", f"reading idx : {read_idx+1}/{len(self.surface_list)}", end="")
                surface_path = os.path.join(self.DATADIR, data_dir, "surface_volume", f"{surface_idx:02}.tif")
                surface_vol = cv2.imread(surface_path, cv2.IMREAD_GRAYSCALE)
                surface_vol = surface_vol.reshape(surface_vol.shape[0], surface_vol.shape[1], 1) # (h, w, channel=1)
                if surface_vol_ is None:
                    surface_vol_ = surface_vol
                else:
                    surface_vol_ = np.concatenate([surface_vol_, surface_vol], axis=2) # (h, w, channel=surface_num)
            surface_vols.append(surface_vol_)
            # print(f"  => read surface volume done. [{data_dir}]")
        return surface_vols


    def get_grid_img(self, img, grid_idx):
        """ crop grid img from original img"""
        img_grid = img[(grid_idx[0]*self.img_size[0]) + self.slide_pos[0] : ((grid_idx[0]+1)*self.img_size[0]) + self.slide_pos[0],
                        (grid_idx[1]*self.img_size[1]) + self.slide_pos[1] : ((grid_idx[1]+1)*self.img_size[1]) + self.slide_pos[1]]
        return img_grid
    
    def get_grid_img_and_mask(self, img, mask, grid_idx):
        """ crop grid img from original img"""
        if self.RANDOM_SLIDE and self.mode=="train" and random.random() < 0.5:
            if (grid_idx[0]!=0 and grid_idx[1]!=0) and (grid_idx[0]!=img.shape[0]//self.img_size[0] and grid_idx[1]!=img.shape[1]//self.img_size[1]):
                rand_pos = [np.random.randint(0, self.img_size[0]//4) - self.img_size[0]//4, np.random.randint(0, self.img_size[1]//4)-self.img_size[1]//4]
            else:
                rand_pos = [0, 0]
        else:
            rand_pos = [0, 0]
        img_grid = img[(grid_idx[0]*self.img_size[0]) + self.slide_pos[0] + rand_pos[0] : ((grid_idx[0]+1)*self.img_size[0]) + self.slide_pos[0] + rand_pos[0],
                        (grid_idx[1]*self.img_size[1]) + self.slide_pos[1] + rand_pos[1] : ((grid_idx[1]+1)*self.img_size[1]) + self.slide_pos[1] + rand_pos[1]]
        mask_grid = mask[(grid_idx[0]*self.img_size[0]) + self.slide_pos[0] + rand_pos[0] : ((grid_idx[0]+1)*self.img_size[0]) + self.slide_pos[0] + rand_pos[0],
                         (grid_idx[1]*self.img_size[1]) + self.slide_pos[1] + rand_pos[1] : ((grid_idx[1]+1)*self.img_size[1]) + self.slide_pos[1] + rand_pos[1]]
        return img_grid/255., mask_grid/255.
    
    def get_masked_img(self, img, mask):
        """ multiply mask to surface_volumes """
        masked_img = None
        for channel in range(img.shape[2]):
            img_channel = img[:,:,channel].reshape(img.shape[0], img.shape[1],1)
            masked = img_channel*mask
            if masked_img is None:
                masked_img = masked.reshape(masked.shape[0], masked.shape[1], 1)
            else:
                masked = masked.reshape(masked.shape[0], masked.shape[1], 1)
                masked_img = np.concatenate([masked_img, masked], axis=2)
        return masked_img
    
    
    def get_all_grid(self):
        """ get all grid indices by img size and grid size
        """
        self.grid_indices = []
        for img in self.imgs:
            self.x_grid_size = (img.shape[0] - self.slide_pos[0]) // self.img_size[0]
            self.y_grid_size = (img.shape[1] - self.slide_pos[1]) // self.img_size[1]
            grid_img = []
            for i in range(self.x_grid_size):
                for j in range(self.y_grid_size):
                    grid_img.append([i, j])
            self.grid_indices.append(grid_img)
        return self.grid_indices
          
    def fileter_grid(self):
        """ get grid indices which mask is not 0 by all grid indices"""
        grid_indices_all = []
        for img, grid_indices in zip(self.imgs, self.grid_indices):
            grid_indices_copy = grid_indices.copy()
            for grid_idx in grid_indices:
                img_grid = self.get_grid_img(img, grid_idx)
                if img_grid.sum() == 0:
                    grid_indices_copy.remove(grid_idx)
            grid_indices_all.append(grid_indices_copy)
        self.grid_indices = grid_indices_all
        return self.grid_indices

    def get_flatten_grid(self):
        """ get flatten index list by grid indices
            Returns:flatten_grid (list): flatten index list [[img_idx, grid_idx], [img_idx, grid_idx], ...]
        """
        flatten_grid = []
        for img_idx, grid_indices in enumerate(self.grid_indices):
            for grid_idx in grid_indices:
                grid_imgidx_list = [img_idx]
                grid_imgidx_list.extend(grid_idx)
                flatten_grid.append(grid_imgidx_list)
        self.flatten_grid = flatten_grid
        return self.flatten_grid
    
    def channel_shuffle(self, img):
        img = img.transpose(2, 0, 1)
        np.random.shuffle(img)
        return img.transpose(1, 2, 0)

    def __len__(self):
        return len(self.flatten_grid)

    def __getitem__(self, idx):
        # get indices
        img_grid_idx = self.flatten_grid[idx]
        img_idx = img_grid_idx[0]
        grid_idx = img_grid_idx[1:]
        # get img & surface_vol
        mask = self.imgs[img_idx]
        surface_vol = self.surface_vols[img_idx]
        # mask = self.get_grid_img(mask, grid_idx)/255.
        # surface_vol = self.get_grid_img(surface_vol, grid_idx)/255.
        mask, surface_vol = self.get_grid_img_and_mask(mask, surface_vol, grid_idx)
        # multiple small mask 
        assert surface_vol.shape[0]==mask.shape[0] and surface_vol.shape[1]==mask.shape[1] , "surface_vol_list shape is not same as img shape"
        img = surface_vol
        # transform
        if self.mode == "test":
            if self.transform:
                img = self.transform(image=img)["image"]
            else:
                img = img.transpose(2, 0, 1)
                img = torch.tensor(img, dtype=torch.float32)
            return img, grid_idx
        elif self.mode == "train" or self.mode=="valid":
            # get label(segmentation mask)
            label = self.labels[img_idx]
            label = self.get_grid_img(label, grid_idx)
            if self.mode == "train":
                img = self.channel_shuffle(img)
            if self.transform:
                transformed = self.transform(image=img, mask=label)
                img = transformed["image"]
                label = transformed["mask"]
                label = label.permute(2, 0, 1)/255. # (channel, h, w)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            else:
                img = img.transpose(2, 0, 1) # (channel, h, w)
                label = label.transpose(2, 0, 1)/255. # (channel, h, w){}
                img = torch.tensor(img, dtype=torch.float32)
                label = torch.tensor(label, dtype=torch.float32)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            return img, label, grid_idx

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train")
# surface_volumes = dataset_notrans.surface_vols
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx < 2:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
        
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train")
# surface_volumes = dataset_notrans.surface_vols
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx < 2:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos=[0,50],mode="train")
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 1:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train", transform=train_transforms)
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)


# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 0:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %% [markdown]
# # train valid fn

# %%
def train_fn(train_loader, model, criterion, epoch ,optimizer, scheduler):
    model.train()
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, _) in enumerate(train_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()     
        preds = model(images)
        preds = TF.resize(img=preds, size=(CFG["img_size"][0], CFG["img_size"][1]))
        # preds = torch.sigmoid(preds)
        loss = criterion(preds, targets)
        
        losses.update(loss.item(), CFG["batch_size"]) 
        targets = targets.detach().cpu().numpy().ravel().tolist()
        preds = preds.detach().cpu().numpy().ravel().tolist()
        loss.backward() # パラメータの勾配を計算
        optimizer.step() # モデル更新
        optimizer.zero_grad() # 勾配の初期化
                
        batch_time.update(time.time() - end)
        end = time.time()
        if batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(train_loader)-1):
            print('Epoch: [{0}][{1}/{2}] '
                    'Elapsed {remain:s} '
                    'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                    .format(
                        epoch, batch_idx, len(train_loader), batch_time=batch_time, loss=losses,
                        remain=timeSince(start, float(batch_idx+1)/len(train_loader)),
            ))
        del preds, images, targets
    gc.collect()
    torch.cuda.empty_cache()
    return losses.avg

# %%
def valid_fn(model, valid_loader, criterion=None):
    model.eval()# モデルを検証モードに設定
    test_targets = []
    test_preds = []
    test_grid_idx = []
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, grid_idx) in enumerate(valid_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()
        with torch.no_grad():
            preds = model(images)
            preds = TF.resize(img=preds, size=(CFG["img_size"][0], CFG["img_size"][1]))
            if not criterion is None:
                loss = criterion(preds, targets)
        if not criterion is None:
            losses.update(loss.item(), CFG["batch_size"])
        batch_time.update(time.time() - end)

        targets = targets.detach().cpu().numpy()
        preds = preds.detach().cpu().numpy()
        
        test_preds.extend([preds[idx, :,:,:].transpose(1,2,0) for idx in range(preds.shape[0])])
        test_targets.extend([targets[idx, :,:,:].transpose(1,2,0) for idx in range(targets.shape[0])])
        test_grid_idx.extend([[x_idx, y_idx] for x_idx, y_idx in zip(grid_idx[0].tolist(), grid_idx[1].tolist())])

        if (batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(valid_loader)-1)) and (not criterion is None):
            print('EVAL: [{0}/{1}] '
                'Elapsed {remain:s} '
                'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                .format(
                    batch_idx, len(valid_loader), batch_time=batch_time, loss=losses,
                    remain=timeSince(start, float(batch_idx+1)/len(valid_loader)),
                ))
        del preds, images, targets
        gc.collect()
        torch.cuda.empty_cache()
    if criterion is None:
        return test_targets, test_preds, test_grid_idx
    else:
        return test_targets, test_preds, test_grid_idx, losses.avg

# %% [markdown]
# # training loop

# %%
# def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list):
#     # concat pred img and label to original size
#     img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
#     img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
#     img = img.reshape(img.shape[0], img.shape[1], 1)
#     pred_img = np.zeros_like(img).astype(np.float32)
#     label_img = np.zeros_like(img).astype(np.float32)
#     for img_idx, grid_idx in enumerate(grid_idx_list):
#         pred_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += img_list[img_idx]
        
#         label_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += label_list[img_idx]
#     return pred_img, label_img

# %%
def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list, slide_pos=[0,0]):
    # concat pred img and label to original size
    img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    img = img.reshape(img.shape[0], img.shape[1], 1)
    pred_img = np.zeros_like(img).astype(np.float32)
    label_img = np.zeros_like(img).astype(np.float32)
    for img_idx, grid_idx in enumerate(grid_idx_list):
        pred_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += img_list[img_idx]
        
        label_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += label_list[img_idx]
    return pred_img, label_img

# %%
def save_and_plot_oof(mode, fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary):
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_pred_img.png"), valid_preds_img*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_predbin_img.png"), valid_preds_binary*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_targets_img.png"), valid_targets_img*255)
    
    # plot preds & binary preds
    # plt.figure(dpi=100)
    # plt.subplot(1,3,1)
    # plt.imshow(valid_preds_img)
    # plt.subplot(1,3,2)
    # plt.imshow(valid_preds_binary)
    # plt.subplot(1,3,3)
    # plt.imshow(valid_targets_img)
    # plt.show()

# %%
def training_loop(CFG):
    best_score_list = []
    best_threshold_list = []
    best_epoch_list = []
    slice_ave_score_list = []
    slice_ave_auc_list = []
    slice_ave_score_threshold_list = []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} training start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        model = model.to(device)
        valid_img_slice = []
        criterion = nn.BCELoss()
        optimizer = AdamW(model.parameters(), lr=CFG["lr"], weight_decay=CFG["weight_decay"], amsgrad=False)
        scheduler = CosineAnnealingLR(optimizer, T_max=CFG["T_max"], eta_min=CFG["min_lr"], last_epoch=-1)
        # scheduler = ExponentialLR(optimizer, gamma=0.60)
        
        # training
        best_score = -np.inf
        best_auc = -np.inf
        best_valloss = np.inf
        best_auc_valloss = np.inf
        best_threshold = -1
        start_time = time.time()
        best_epoch = -1
        best_auc_epoch = -1
        valid_slice_ave = None       
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            # separate train/valid data 
            train_dirs = CFG["TRAIN_DIR_LIST"][fold]
            valid_dirs = CFG["VALID_DIR_LIST"][fold]
            train_dataset = VCID_Dataset(CFG, train_dirs, surface_list, mode="train", transform=train_transforms)
            valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, mode="valid", transform=valid_transforms)
            train_loader = DataLoader(train_dataset, batch_size=CFG["batch_size"], shuffle = True,
                                        num_workers = CFG["num_workers"], pin_memory = True)
            valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                        num_workers = CFG["num_workers"], pin_memory = True)
            for epoch in range(1, CFG["n_epoch"] + 1):
                epochs_ = epoch + CFG["n_epoch"] * slice_idx
                print(f'- epoch:{epochs_} -')
                train_loss_avg = train_fn(train_loader, model, criterion, epochs_ ,optimizer, scheduler)
                valid_targets, valid_preds, valid_grid_idx, valid_loss_avg = valid_fn(model, valid_loader, criterion)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                
                elapsed = time.time() - start_time
                print(f"\t epoch:{epochs_}, avg train loss:{train_loss_avg:.4f}, avg valid loss:{valid_loss_avg:.4f}")
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                if not CFG["DEBUG"]:
                    logging_metrics_epoch(CFG, fold, epoch, slice_idx, train_loss_avg, valid_loss_avg, valid_score, valid_threshold, auc)
                scheduler.step()
                # validationスコアがbestを更新したらモデルを保存する
                if valid_score > best_score:
                    best_epoch = epochs_
                    best_valloss = valid_loss_avg
                    best_score = valid_score
                    best_threshold = valid_threshold
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epochs_} - Save Best Score: {best_score:.4f}. Model is saved.')
                    print("dice_list: ", dice_list)
                    # save oof
                    save_and_plot_oof("score", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
                
                if auc > best_auc:
                    best_auc = auc
                    best_auc_epoch = epochs_
                    best_auc_valloss = valid_loss_avg
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_auc_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epochs_} - Save Best AUC: {best_auc:.4f}. Model is saved.')
                    # save oof
                    save_and_plot_oof("auc", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
            # valid_img_slice.append(valid_preds_img)
            if valid_slice_ave is None:
                valid_slice_ave = valid_preds_img
            else:
                valid_slice_ave += valid_preds_img
        # valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        # for idx in range(len(SURFACE_LIST)):
        #     valid_pred_slice = valid_img_slice[idx]
        #     valid_slice_ave += valid_pred_slice
        valid_slice_ave /= len(SURFACE_LIST)
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_slice_ave)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)
 
        valid_slice_binary = (valid_slice_ave > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 999, valid_slice_ave, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
        
        print(f'[fold{fold}] BEST Epoch {best_epoch} - Save Best Score:{best_score:.4f}. Best loss:{best_valloss:.4f}')
        print(f'[fold{fold}] BEST AUC Epoch {best_auc_epoch} - Save Best Score:{best_auc:.4f}. Best loss:{best_auc_valloss:.4f}')
            
        best_score_list.append(best_score)
        best_threshold_list.append(best_threshold)
        best_epoch_list.append(best_epoch)
        del model, train_loader, train_dataset, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
        
    for fold, (best_score, best_threshold, best_epoch) in enumerate(zip(best_score_list, best_threshold_list, best_epoch_list)):
        print(f"fold[{fold}] BEST SCORE = {best_score:.4f} thr={best_threshold} (epoch={best_epoch})")
        print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    return best_score_list, best_threshold_list, best_epoch_list

# %% [markdown]
# # slice inference

# %%
def slide_inference(CFG):
    start_time = time.time()
    slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list = [], [], []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} slide inference start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        # model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_fold{fold}.pth')
        model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_auc_fold{fold}.pth')
        model.load_state_dict(torch.load(model_path))
        model = model.to(device)
        valid_img_slice = None
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            surface_volumes = None
            for slide_pos in CFG["slide_pos_list"]:
                print("slide pos:", slide_pos)
                valid_dirs = CFG["VALID_DIR_LIST"][fold]
                valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos, mode="valid", transform=valid_transforms)
                surface_volumes = valid_dataset.get_surface_volumes()
                valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                            num_workers = CFG["num_workers"], pin_memory = True)

                valid_targets, valid_preds, valid_grid_idx = valid_fn(model, valid_loader)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs, slide_pos)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                save_and_plot_oof("slide", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary) 
                
                elapsed = time.time() - start_time
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                # valid_img_slice.append(valid_preds_img)
                if valid_img_slice is None:
                    valid_img_slice = valid_preds_img
                else:
                    valid_img_slice += valid_preds_img
            # valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        # for idx in range(len(SURFACE_LIST)*len(CFG["slide_pos_list"])):
        #     valid_pred_slice = valid_img_slice[idx]
        #     valid_slice_ave += valid_pred_slice
        valid_img_slice /= len(SURFACE_LIST)*len(CFG["slide_pos_list"])
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_img_slice)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)

        valid_slice_binary = (valid_img_slice > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 555, valid_img_slice, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
         
        del model, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
    return slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list

# %% [markdown]
# # main

# %%
# %%time
best_score_list, best_threshold_list, best_epoch_list = training_loop(CFG)
# Out:
# -- fold0 training start --
# surface_list:  [26, 29, 32, 35]
# - epoch:1 -
# Epoch: [1][0/61] Elapsed 0m 1s (remain 1m 25s) Loss: 0.7876(0.7876)
# Epoch: [1][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.4500(0.4791)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.5017(0.5017)
# EVAL: [13/14] Elapsed 0m 2s (remain 0m 0s) Loss: 0.4608(0.4965)
# 	 epoch:1, avg train loss:0.4791, avg valid loss:0.4965
# 	 score:0.3084(th=0.550000), auc=0.838795::: time:79.41s
# Epoch 1 - Save Best Score: 0.3084. Model is saved.
# dice_list:  [0.2289750357493457, 0.25333796881560194, 0.2696399577009194, 0.2821104605680843, 0.2919709775895656, 0.299150083311964, 0.30409312614999856, 0.3070020785099943, 0.30830527611201025, 0.30836102973262614, 0.3076633240361502, 0.3063797536115954, 0.304162919056984, 0.3010474667536428, 0.29713084070059426, 0.29163996303288675, 0.2842142921162161, 0.27251266001224866, 0.0]
# Epoch 1 - Save Best AUC: 0.8388. Model is saved.
# - epoch:2 -
# Epoch: [2][0/61] Elapsed 0m 1s (remain 1m 13s) Loss: 0.4752(0.4752)
# Epoch: [2][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.4510(0.4140)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1807(0.1807)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4091(0.3280)
# 	 epoch:2, avg train loss:0.4140, avg valid loss:0.3280
# 	 score:0.4303(th=0.600000), auc=0.859321::: time:127.04s
# Epoch 2 - Save Best Score: 0.4303. Model is saved.
# dice_list:  [0.18720242165639073, 0.2176967432727338, 0.2538376921842731, 0.2906997540155794, 0.3247340790361566, 0.3541075428573276, 0.37904007388880046, 0.4004605382075912, 0.4176095686905784, 0.4284467666041683, 0.43025314723600594, 0.4184158534191565, 0.38928770807506224, 0.3431617553592762, 0.28132824172723614, 0.20942354502421776, 0.130664958421081, 0.05485804175192634, 0.0]
# Epoch 2 - Save Best AUC: 0.8593. Model is saved.
# - epoch:3 -
# Epoch: [3][0/61] Elapsed 0m 1s (remain 1m 13s) Loss: 0.3204(0.3204)
# Epoch: [3][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.5143(0.3965)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1272(0.1272)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4179(0.2873)
# 	 epoch:3, avg train loss:0.3965, avg valid loss:0.2873
# 	 score:0.4366(th=0.350000), auc=0.867531::: time:173.78s
# Epoch 3 - Save Best Score: 0.4366. Model is saved.
# dice_list:  [0.23749497246443033, 0.3151031585007046, 0.37379687958539926, 0.40987588516710616, 0.42955291500277737, 0.436575434770398, 0.43442297870463475, 0.42308349189003247, 0.40402472450019244, 0.3800405596650122, 0.3508387768806043, 0.3124475839208286, 0.2668204306263627, 0.21697819146605593, 0.16745470991553807, 0.11128142428012112, 0.051149004925869525, 0.007021611334690663, 0.0]
# Epoch 3 - Save Best AUC: 0.8675. Model is saved.
# - epoch:4 -
# Epoch: [4][0/61] Elapsed 0m 1s (remain 1m 17s) Loss: 0.3351(0.3351)
# Epoch: [4][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3629(0.3755)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1419(0.1419)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4103(0.2807)
# 	 epoch:4, avg train loss:0.3755, avg valid loss:0.2807
# 	 score:0.4881(th=0.450000), auc=0.883111::: time:220.62s
# Epoch 4 - Save Best Score: 0.4881. Model is saved.
# dice_list:  [0.2360162024046695, 0.2931063907464809, 0.34638012210375607, 0.39287554830449123, 0.4301312137694351, 0.45886907224013834, 0.4790914072443415, 0.48810343876667495, 0.4847189888677789, 0.4681121685189348, 0.4378266659681466, 0.3936017641954314, 0.3304889509996083, 0.24366789423525298, 0.14902836898878455, 0.0733662702385965, 0.020442262569872693, 0.0005246869900466551, 0.0]
# Epoch 4 - Save Best AUC: 0.8831. Model is saved.
# - epoch:5 -
# Epoch: [5][0/61] Elapsed 0m 1s (remain 1m 21s) Loss: 0.4107(0.4107)
# Epoch: [5][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2400(0.3571)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1738(0.1738)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3864(0.2966)
# 	 epoch:5, avg train loss:0.3571, avg valid loss:0.2966
# 	 score:0.4935(th=0.600000), auc=0.880278::: time:267.54s
# Epoch 5 - Save Best Score: 0.4935. Model is saved.
# dice_list:  [0.22908465355151783, 0.2689308211547653, 0.3031537278757708, 0.33717048855161635, 0.3696840470627343, 0.39996032746514126, 0.42939647405384657, 0.4557187692126102, 0.4770060486471631, 0.49084919823443374, 0.49349153369319076, 0.48229248759748744, 0.4556281809947107, 0.41344969726297387, 0.35205027892744534, 0.2612962015882675, 0.1379990194077856, 0.028213585196169705, 0.0]
# - epoch:6 -
# Epoch: [6][0/61] Elapsed 0m 1s (remain 1m 12s) Loss: 0.3846(0.3846)
# Epoch: [6][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3259(0.3484)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1679(0.1679)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3913(0.2944)
# 	 epoch:6, avg train loss:0.3484, avg valid loss:0.2944
# 	 score:0.4931(th=0.550000), auc=0.880382::: time:312.60s
# - epoch:7 -
# Epoch: [7][0/61] Elapsed 0m 1s (remain 1m 24s) Loss: 0.2201(0.2201)
# Epoch: [7][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2154(0.3470)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1438(0.1438)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4230(0.2853)
# 	 epoch:7, avg train loss:0.3470, avg valid loss:0.2853
# 	 score:0.5044(th=0.600000), auc=0.884832::: time:356.37s
# Epoch 7 - Save Best Score: 0.5044. Model is saved.
# dice_list:  [0.24327379122720066, 0.2931539882348816, 0.3343051646459967, 0.3710561478522311, 0.4039463953636209, 0.43258293733181513, 0.45704518634929364, 0.4763300248293743, 0.49150159078236677, 0.5013090992825849, 0.5043819160525846, 0.49511982342451416, 0.4663819803852009, 0.42114852223674326, 0.35965507397571006, 0.26949859695849854, 0.14916540375469048, 0.035097997783253045, 0.0]
# Epoch 7 - Save Best AUC: 0.8848. Model is saved.
# - epoch:8 -
# Epoch: [8][0/61] Elapsed 0m 1s (remain 1m 11s) Loss: 0.2553(0.2553)
# Epoch: [8][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.4117(0.3477)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1488(0.1488)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4205(0.2937)
# 	 epoch:8, avg train loss:0.3477, avg valid loss:0.2937
# 	 score:0.5272(th=0.650000), auc=0.891060::: time:402.28s
# Epoch 8 - Save Best Score: 0.5272. Model is saved.
# dice_list:  [0.23933722330055332, 0.27342418083573267, 0.30351313421885184, 0.3331861131329021, 0.36382934409569717, 0.3953576852095599, 0.42643538288286825, 0.4558205202082029, 0.4824906350653314, 0.5056825467064303, 0.5229213457964186, 0.5271512338291532, 0.5087813013003234, 0.46246864382953246, 0.38570598812348034, 0.27359529565405016, 0.14150675048537703, 0.026934273256344454, 0.0]
# Epoch 8 - Save Best AUC: 0.8911. Model is saved.
# - epoch:9 -
# Epoch: [9][0/61] Elapsed 0m 1s (remain 1m 19s) Loss: 0.4029(0.4029)
# Epoch: [9][60/61] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2503(0.3646)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1091(0.1091)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4535(0.2786)
# 	 epoch:9, avg train loss:0.3646, avg valid loss:0.2786
# 	 score:0.4952(th=0.450000), auc=0.879302::: time:448.23s
# - epoch:10 -
# Epoch: [10][0/61] Elapsed 0m 1s (remain 1m 18s) Loss: 0.3464(0.3464)
# Epoch: [10][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.4157(0.3597)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1501(0.1501)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3951(0.2901)
# 	 epoch:10, avg train loss:0.3597, avg valid loss:0.2901
# 	 score:0.4709(th=0.650000), auc=0.887531::: time:490.70s
# - epoch:11 -
# Epoch: [11][0/61] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2978(0.2978)
# Epoch: [11][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.4444(0.3551)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1321(0.1321)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4112(0.2798)
# 	 epoch:11, avg train loss:0.3551, avg valid loss:0.2798
# 	 score:0.4735(th=0.300000), auc=0.878451::: time:533.16s
# - epoch:12 -
# Epoch: [12][0/61] Elapsed 0m 1s (remain 1m 24s) Loss: 0.4403(0.4403)
# Epoch: [12][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2974(0.3428)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1946(0.1946)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3925(0.3175)
# 	 epoch:12, avg train loss:0.3428, avg valid loss:0.3175
# 	 score:0.4625(th=0.700000), auc=0.877640::: time:575.39s
# - epoch:13 -
# Epoch: [13][0/61] Elapsed 0m 1s (remain 1m 18s) Loss: 0.3451(0.3451)
# Epoch: [13][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3559(0.3301)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1251(0.1251)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3629(0.2645)
# 	 epoch:13, avg train loss:0.3301, avg valid loss:0.2645
# 	 score:0.5336(th=0.450000), auc=0.892384::: time:617.32s
# Epoch 13 - Save Best Score: 0.5336. Model is saved.
# dice_list:  [0.28812575910097643, 0.3505752304605031, 0.4055281387579718, 0.4518675394697486, 0.4853756878842043, 0.5089790643203701, 0.5246093488397854, 0.533551204603769, 0.5334707212716356, 0.5269624503930205, 0.5186557110073441, 0.508281409078844, 0.49143960838394707, 0.4610480901818534, 0.4151202933373009, 0.34995116746850635, 0.2588572233093826, 0.12823743299736495, 0.0]
# Epoch 13 - Save Best AUC: 0.8924. Model is saved.
# - epoch:14 -
# Epoch: [14][0/61] Elapsed 0m 1s (remain 1m 22s) Loss: 0.3540(0.3540)
# Epoch: [14][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3209(0.3161)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1397(0.1397)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3726(0.2845)
# 	 epoch:14, avg train loss:0.3161, avg valid loss:0.2845
# 	 score:0.4947(th=0.550000), auc=0.887116::: time:662.19s
# - epoch:15 -
# Epoch: [15][0/61] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2732(0.2732)
# Epoch: [15][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2843(0.2904)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1255(0.1255)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3718(0.2753)
# 	 epoch:15, avg train loss:0.2904, avg valid loss:0.2753
# 	 score:0.5264(th=0.550000), auc=0.894024::: time:704.06s
# Epoch 15 - Save Best AUC: 0.8940. Model is saved.
# - epoch:16 -
# Epoch: [16][0/61] Elapsed 0m 1s (remain 1m 18s) Loss: 0.3726(0.3726)
# Epoch: [16][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3627(0.2828)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1317(0.1317)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3672(0.2738)
# 	 epoch:16, avg train loss:0.2828, avg valid loss:0.2738
# 	 score:0.5256(th=0.550000), auc=0.894730::: time:747.26s
# Epoch 16 - Save Best AUC: 0.8947. Model is saved.
# - epoch:17 -
# Epoch: [17][0/61] Elapsed 0m 1s (remain 1m 14s) Loss: 0.2576(0.2576)
# Epoch: [17][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2656(0.2802)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1288(0.1288)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3919(0.2852)
# 	 epoch:17, avg train loss:0.2802, avg valid loss:0.2852
# 	 score:0.5303(th=0.650000), auc=0.891180::: time:790.40s
# - epoch:18 -
# Epoch: [18][0/61] Elapsed 0m 1s (remain 1m 16s) Loss: 0.2915(0.2915)
# Epoch: [18][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2814(0.2856)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1237(0.1237)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4611(0.3017)
# 	 epoch:18, avg train loss:0.2856, avg valid loss:0.3017
# 	 score:0.4887(th=0.700000), auc=0.886123::: time:831.85s
# - epoch:19 -
# Epoch: [19][0/61] Elapsed 0m 1s (remain 1m 23s) Loss: 0.2626(0.2626)
# Epoch: [19][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3853(0.3064)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1725(0.1725)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3857(0.3039)
# 	 epoch:19, avg train loss:0.3064, avg valid loss:0.3039
# 	 score:0.5183(th=0.750000), auc=0.890766::: time:873.43s
# - epoch:20 -
# Epoch: [20][0/61] Elapsed 0m 1s (remain 1m 22s) Loss: 0.4162(0.4162)
# Epoch: [20][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3916(0.3221)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.2042(0.2042)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4101(0.3060)
# 	 epoch:20, avg train loss:0.3221, avg valid loss:0.3060
# 	 score:0.4253(th=0.550000), auc=0.864503::: time:914.78s
# surface_list:  [27, 30, 33, 36]
# - epoch:21 -
# Epoch: [21][0/61] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2402(0.2402)
# Epoch: [21][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3019(0.3176)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 3s) Loss: 0.1567(0.1567)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3967(0.2884)
# 	 epoch:21, avg train loss:0.3176, avg valid loss:0.2884
# 	 score:0.5137(th=0.550000), auc=0.874930::: time:991.00s
# - epoch:22 -
# Epoch: [22][0/61] Elapsed 0m 1s (remain 1m 21s) Loss: 0.2373(0.2373)
# Epoch: [22][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.6379(0.3203)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1205(0.1205)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3611(0.2792)
# 	 epoch:22, avg train loss:0.3203, avg valid loss:0.2792
# 	 score:0.5092(th=0.650000), auc=0.893506::: time:1033.39s
# - epoch:23 -
# Epoch: [23][0/61] Elapsed 0m 1s (remain 1m 23s) Loss: 0.1878(0.1878)
# Epoch: [23][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2643(0.2989)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0973(0.0973)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3792(0.2712)
# 	 epoch:23, avg train loss:0.2989, avg valid loss:0.2712
# 	 score:0.5371(th=0.500000), auc=0.882807::: time:1075.17s
# Epoch 23 - Save Best Score: 0.5371. Model is saved.
# dice_list:  [0.33057932991342925, 0.37562152874007537, 0.4142991145467316, 0.4507809000682625, 0.47850416773060644, 0.49672330061056746, 0.5141222506901013, 0.5284921783415283, 0.5371470168214835, 0.5355950500216673, 0.5246672528126288, 0.5044911044200678, 0.47295260573313425, 0.4334136823033393, 0.3856335792880095, 0.3251706981388508, 0.24500609637290063, 0.13574066265283907, 0.0]
# - epoch:24 -
# Epoch: [24][0/61] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2391(0.2391)
# Epoch: [24][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1784(0.2714)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1170(0.1170)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3649(0.2736)
# 	 epoch:24, avg train loss:0.2714, avg valid loss:0.2736
# 	 score:0.5239(th=0.650000), auc=0.891232::: time:1118.18s
# - epoch:25 -
# Epoch: [25][0/61] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2570(0.2570)
# Epoch: [25][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2321(0.2586)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1363(0.1363)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3283(0.2794)
# 	 epoch:25, avg train loss:0.2586, avg valid loss:0.2794
# 	 score:0.5144(th=0.650000), auc=0.890556::: time:1159.72s
# - epoch:26 -
# Epoch: [26][0/61] Elapsed 0m 1s (remain 1m 14s) Loss: 0.4503(0.4503)
# Epoch: [26][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3778(0.2492)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1370(0.1370)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3301(0.2818)
# 	 epoch:26, avg train loss:0.2492, avg valid loss:0.2818
# 	 score:0.5086(th=0.650000), auc=0.889461::: time:1201.19s
# - epoch:27 -
# Epoch: [27][0/61] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2389(0.2389)
# Epoch: [27][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2789(0.2498)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1277(0.1277)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3440(0.2823)
# 	 epoch:27, avg train loss:0.2498, avg valid loss:0.2823
# 	 score:0.5080(th=0.700000), auc=0.890337::: time:1242.58s
# - epoch:28 -
# Epoch: [28][0/61] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2894(0.2894)
# Epoch: [28][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2227(0.2385)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1180(0.1180)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3736(0.2954)
# 	 epoch:28, avg train loss:0.2385, avg valid loss:0.2954
# 	 score:0.5041(th=0.700000), auc=0.887483::: time:1284.00s
# - epoch:29 -
# Epoch: [29][0/61] Elapsed 0m 1s (remain 1m 18s) Loss: 0.1664(0.1664)
# Epoch: [29][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2678(0.2661)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0886(0.0886)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3813(0.2797)
# 	 epoch:29, avg train loss:0.2661, avg valid loss:0.2797
# 	 score:0.4829(th=0.550000), auc=0.886249::: time:1325.55s
# - epoch:30 -
# Epoch: [30][0/61] Elapsed 0m 1s (remain 1m 16s) Loss: 0.3002(0.3002)
# Epoch: [30][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2750(0.2723)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1896(0.1896)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4303(0.3398)
# 	 epoch:30, avg train loss:0.2723, avg valid loss:0.3398
# 	 score:0.4618(th=0.750000), auc=0.877756::: time:1367.06s
# - epoch:31 -
# Epoch: [31][0/61] Elapsed 0m 1s (remain 1m 21s) Loss: 0.3070(0.3070)
# Epoch: [31][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2931(0.2835)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1720(0.1720)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3787(0.3216)
# 	 epoch:31, avg train loss:0.2835, avg valid loss:0.3216
# 	 score:0.5089(th=0.700000), auc=0.871399::: time:1408.46s
# - epoch:32 -
# Epoch: [32][0/61] Elapsed 0m 1s (remain 1m 24s) Loss: 0.2177(0.2177)
# Epoch: [32][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2217(0.2737)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1112(0.1112)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4435(0.3288)
# 	 epoch:32, avg train loss:0.2737, avg valid loss:0.3288
# 	 score:0.4768(th=0.750000), auc=0.872705::: time:1450.09s
# - epoch:33 -
# Epoch: [33][0/61] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2230(0.2230)
# Epoch: [33][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2457(0.2634)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1716(0.1716)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3496(0.3016)
# 	 epoch:33, avg train loss:0.2634, avg valid loss:0.3016
# 	 score:0.4817(th=0.700000), auc=0.875273::: time:1491.86s
# - epoch:34 -
# Epoch: [34][0/61] Elapsed 0m 1s (remain 1m 24s) Loss: 0.2844(0.2844)
# Epoch: [34][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2262(0.2351)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1437(0.1437)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3472(0.3022)
# 	 epoch:34, avg train loss:0.2351, avg valid loss:0.3022
# 	 score:0.4659(th=0.700000), auc=0.873677::: time:1534.16s
# - epoch:35 -
# Epoch: [35][0/61] Elapsed 0m 1s (remain 1m 14s) Loss: 0.3008(0.3008)
# Epoch: [35][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2408(0.2227)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1478(0.1478)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3538(0.3041)
# 	 epoch:35, avg train loss:0.2227, avg valid loss:0.3041
# 	 score:0.4908(th=0.750000), auc=0.876749::: time:1576.05s
# - epoch:36 -
# Epoch: [36][0/61] Elapsed 0m 1s (remain 1m 17s) Loss: 0.1757(0.1757)
# Epoch: [36][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2081(0.2183)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1340(0.1340)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3597(0.2999)
# 	 epoch:36, avg train loss:0.2183, avg valid loss:0.2999
# 	 score:0.4896(th=0.700000), auc=0.875756::: time:1617.99s
# - epoch:37 -
# Epoch: [37][0/61] Elapsed 0m 1s (remain 1m 21s) Loss: 0.1759(0.1759)
# Epoch: [37][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2027(0.2215)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1720(0.1720)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3518(0.3169)
# 	 epoch:37, avg train loss:0.2215, avg valid loss:0.3169
# 	 score:0.4744(th=0.800000), auc=0.880668::: time:1659.57s
# - epoch:38 -
# Epoch: [38][0/61] Elapsed 0m 1s (remain 1m 22s) Loss: 0.4295(0.4295)
# Epoch: [38][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3270(0.2208)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1441(0.1441)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3795(0.3001)
# 	 epoch:38, avg train loss:0.2208, avg valid loss:0.3001
# 	 score:0.4652(th=0.600000), auc=0.870225::: time:1701.34s
# - epoch:39 -
# Epoch: [39][0/61] Elapsed 0m 1s (remain 1m 26s) Loss: 0.2465(0.2465)
# Epoch: [39][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2521(0.2320)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1267(0.1267)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4199(0.3090)
# 	 epoch:39, avg train loss:0.2320, avg valid loss:0.3090
# 	 score:0.4616(th=0.650000), auc=0.873539::: time:1743.04s
# - epoch:40 -
# Epoch: [40][0/61] Elapsed 0m 1s (remain 1m 16s) Loss: 0.2036(0.2036)
# Epoch: [40][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2883(0.2508)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1950(0.1950)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4382(0.3287)
# 	 epoch:40, avg train loss:0.2508, avg valid loss:0.3287
# 	 score:0.4305(th=0.700000), auc=0.874287::: time:1784.79s
# surface_list:  [25, 28, 31, 34]
# - epoch:41 -
# Epoch: [41][0/61] Elapsed 0m 1s (remain 1m 22s) Loss: 0.2844(0.2844)
# Epoch: [41][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2360(0.2838)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1172(0.1172)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4340(0.2950)
# 	 epoch:41, avg train loss:0.2838, avg valid loss:0.2950
# 	 score:0.5088(th=0.700000), auc=0.877495::: time:1862.49s
# - epoch:42 -
# Epoch: [42][0/61] Elapsed 0m 1s (remain 1m 24s) Loss: 0.1798(0.1798)
# Epoch: [42][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2721(0.2726)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1341(0.1341)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4074(0.3063)
# 	 epoch:42, avg train loss:0.2726, avg valid loss:0.3063
# 	 score:0.4997(th=0.700000), auc=0.861143::: time:1904.63s
# - epoch:43 -
# Epoch: [43][0/61] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2770(0.2770)
# Epoch: [43][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2168(0.2588)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1371(0.1371)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3950(0.3178)
# 	 epoch:43, avg train loss:0.2588, avg valid loss:0.3178
# 	 score:0.4636(th=0.750000), auc=0.873838::: time:1946.37s
# - epoch:44 -
# Epoch: [44][0/61] Elapsed 0m 1s (remain 1m 16s) Loss: 0.2054(0.2054)
# Epoch: [44][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2593(0.2307)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1299(0.1299)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3849(0.3176)
# 	 epoch:44, avg train loss:0.2307, avg valid loss:0.3176
# 	 score:0.4991(th=0.800000), auc=0.878787::: time:1988.19s
# - epoch:45 -
# Epoch: [45][0/61] Elapsed 0m 1s (remain 1m 16s) Loss: 0.1557(0.1557)
# Epoch: [45][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1782(0.2172)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1257(0.1257)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3862(0.3120)
# 	 epoch:45, avg train loss:0.2172, avg valid loss:0.3120
# 	 score:0.5220(th=0.800000), auc=0.882553::: time:2029.74s
# - epoch:46 -
# Epoch: [46][0/61] Elapsed 0m 1s (remain 1m 16s) Loss: 0.2890(0.2890)
# Epoch: [46][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2434(0.2096)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1112(0.1112)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3910(0.2995)
# 	 epoch:46, avg train loss:0.2096, avg valid loss:0.2995
# 	 score:0.5245(th=0.700000), auc=0.880357::: time:2071.25s
# - epoch:47 -
# Epoch: [47][0/61] Elapsed 0m 1s (remain 1m 21s) Loss: 0.2261(0.2261)
# Epoch: [47][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1864(0.2214)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1438(0.1438)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3755(0.3141)
# 	 epoch:47, avg train loss:0.2214, avg valid loss:0.3141
# 	 score:0.5210(th=0.800000), auc=0.882472::: time:2112.95s
# - epoch:48 -
# Epoch: [48][0/61] Elapsed 0m 1s (remain 1m 15s) Loss: 0.1930(0.1930)
# Epoch: [48][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2071(0.2109)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1481(0.1481)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3848(0.3136)
# 	 epoch:48, avg train loss:0.2109, avg valid loss:0.3136
# 	 score:0.5214(th=0.800000), auc=0.877882::: time:2154.49s
# - epoch:49 -
# Epoch: [49][0/61] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2431(0.2431)
# Epoch: [49][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1599(0.2268)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1302(0.1302)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3883(0.3135)
# 	 epoch:49, avg train loss:0.2268, avg valid loss:0.3135
# 	 score:0.4932(th=0.750000), auc=0.873280::: time:2195.95s
# - epoch:50 -
# Epoch: [50][0/61] Elapsed 0m 1s (remain 1m 23s) Loss: 0.1745(0.1745)
# Epoch: [50][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2126(0.2371)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1180(0.1180)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4471(0.3082)
# 	 epoch:50, avg train loss:0.2371, avg valid loss:0.3082
# 	 score:0.4834(th=0.650000), auc=0.876735::: time:2238.07s
# - epoch:51 -
# Epoch: [51][0/61] Elapsed 0m 1s (remain 1m 14s) Loss: 0.2474(0.2474)
# Epoch: [51][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2179(0.2425)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1981(0.1981)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4483(0.3611)
# 	 epoch:51, avg train loss:0.2425, avg valid loss:0.3611
# 	 score:0.4912(th=0.850000), auc=0.884698::: time:2280.03s
# - epoch:52 -
# Epoch: [52][0/61] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2102(0.2102)
# Epoch: [52][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2339(0.2462)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2101(0.2101)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4555(0.3473)
# 	 epoch:52, avg train loss:0.2462, avg valid loss:0.3473
# 	 score:0.5208(th=0.800000), auc=0.881097::: time:2321.61s
# - epoch:53 -
# Epoch: [53][0/61] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2591(0.2591)
# Epoch: [53][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1701(0.2327)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1718(0.1718)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3777(0.3428)
# 	 epoch:53, avg train loss:0.2327, avg valid loss:0.3428
# 	 score:0.4941(th=0.850000), auc=0.878255::: time:2363.27s
# - epoch:54 -
# Epoch: [54][0/61] Elapsed 0m 1s (remain 1m 24s) Loss: 0.1678(0.1678)
# Epoch: [54][60/61] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2071(0.2097)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1370(0.1370)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4239(0.3217)
# 	 epoch:54, avg train loss:0.2097, avg valid loss:0.3217
# 	 score:0.5381(th=0.850000), auc=0.877720::: time:2405.15s
# Epoch 54 - Save Best Score: 0.5381. Model is saved.
# dice_list:  [0.2761263370200899, 0.3088209643266756, 0.3341360590146087, 0.3572224731176684, 0.3778279524554785, 0.39604734756218835, 0.4143408819830915, 0.432662083567315, 0.45112659509268066, 0.46921522698042917, 0.4869114711103669, 0.5024476663947518, 0.5152589910087959, 0.5261102373806885, 0.5342278492269481, 0.5381198333368031, 0.5231570691754522, 0.4412442422858851, 0.0]
# - epoch:55 -
# Epoch: [55][0/61] Elapsed 0m 1s (remain 1m 21s) Loss: 0.1679(0.1679)
# Epoch: [55][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1545(0.2000)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1412(0.1412)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4294(0.3419)
# 	 epoch:55, avg train loss:0.2000, avg valid loss:0.3419
# 	 score:0.5356(th=0.900000), auc=0.882812::: time:2448.17s
# - epoch:56 -
# Epoch: [56][0/61] Elapsed 0m 1s (remain 1m 19s) Loss: 0.3065(0.3065)
# Epoch: [56][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1496(0.1931)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1080(0.1080)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4321(0.3068)
# 	 epoch:56, avg train loss:0.1931, avg valid loss:0.3068
# 	 score:0.5419(th=0.800000), auc=0.881909::: time:2490.00s
# Epoch 56 - Save Best Score: 0.5419. Model is saved.
# dice_list:  [0.29561333998151007, 0.3291914106822946, 0.3544025461060685, 0.3779624726104427, 0.40040568455886744, 0.42017282364666936, 0.43852906277061293, 0.45415179363963804, 0.4690780725430554, 0.4834515567864005, 0.4989547642230014, 0.5148269895121166, 0.5285931891180747, 0.5388254899085012, 0.5419450920417281, 0.533506181887154, 0.493077268302978, 0.3928145633446751, 0.0]
# - epoch:57 -
# Epoch: [57][0/61] Elapsed 0m 1s (remain 1m 16s) Loss: 0.1660(0.1660)
# Epoch: [57][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2557(0.1871)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1183(0.1183)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4199(0.3108)
# 	 epoch:57, avg train loss:0.1871, avg valid loss:0.3108
# 	 score:0.5349(th=0.800000), auc=0.880039::: time:2532.78s
# - epoch:58 -
# Epoch: [58][0/61] Elapsed 0m 1s (remain 1m 15s) Loss: 0.1624(0.1624)
# Epoch: [58][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1920(0.1932)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2008(0.2008)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4202(0.3457)
# 	 epoch:58, avg train loss:0.1932, avg valid loss:0.3457
# 	 score:0.5269(th=0.850000), auc=0.881030::: time:2574.68s
# - epoch:59 -
# Epoch: [59][0/61] Elapsed 0m 1s (remain 1m 19s) Loss: 0.2354(0.2354)
# Epoch: [59][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2076(0.1944)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0956(0.0956)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.5108(0.3309)
# 	 epoch:59, avg train loss:0.1944, avg valid loss:0.3309
# 	 score:0.5280(th=0.800000), auc=0.879642::: time:2616.68s
# - epoch:60 -
# Epoch: [60][0/61] Elapsed 0m 1s (remain 1m 19s) Loss: 0.1895(0.1895)
# Epoch: [60][60/61] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2087(0.2117)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1306(0.1306)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4830(0.3116)
# 	 epoch:60, avg train loss:0.2117, avg valid loss:0.3116
# 	 score:0.4605(th=0.650000), auc=0.874771::: time:2658.66s
# [fold0] slice ave score:0.4717(th=0.600000), auc=0.883583
# [fold0] BEST Epoch 56 - Save Best Score:0.5419. Best loss:0.3068
# [fold0] BEST AUC Epoch 16 - Save Best Score:0.8947. Best loss:0.2738
# -- fold1 training start --
# surface_list:  [26, 29, 32, 35]
# - epoch:1 -
# Epoch: [1][0/57] Elapsed 0m 1s (remain 1m 13s) Loss: 1.7093(1.7093)
# Epoch: [1][56/57] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3584(0.8228)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.7442(0.7442)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2369(0.4765)
# 	 epoch:1, avg train loss:0.8228, avg valid loss:0.4765
# 	 score:0.2588(th=0.200000), auc=0.668187::: time:82.09s
# Epoch 1 - Save Best Score: 0.2588. Model is saved.
# dice_list:  [0.22547676711333714, 0.2500630560440036, 0.2587821966332292, 0.25109372281384995, 0.23387813477058403, 0.21069362623111398, 0.1835430534310888, 0.15322051830773986, 0.12203271442262392, 0.09115483136878501, 0.0630175740051652, 0.03993233379524647, 0.023032071312118884, 0.01208192647516784, 0.005953819907226779, 0.003075449048619758, 0.0017497387953176059, 0.0007839903743757451, 0.0]
# Epoch 1 - Save Best AUC: 0.6682. Model is saved.
# - epoch:2 -
# Epoch: [2][0/57] Elapsed 0m 1s (remain 1m 8s) Loss: 0.3731(0.3731)
# Epoch: [2][56/57] Elapsed 0m 26s (remain 0m 0s) Loss: 0.5091(0.4044)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5746(0.5746)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1134(0.4141)
# 	 epoch:2, avg train loss:0.4044, avg valid loss:0.4141
# 	 score:0.4159(th=0.350000), auc=0.787059::: time:132.49s
# Epoch 2 - Save Best Score: 0.4159. Model is saved.
# dice_list:  [0.29077127700581645, 0.3339459385966556, 0.3683345154161676, 0.39354882026983085, 0.4091968134674651, 0.4159331713755819, 0.41384811043099684, 0.40431581052082066, 0.38814666284288546, 0.366161340765693, 0.338099211853503, 0.3039620212978582, 0.26293794752170374, 0.2160731574219363, 0.1648390619131562, 0.1124701144885892, 0.06400588920094424, 0.021122774681031225, 0.0]
# Epoch 2 - Save Best AUC: 0.7871. Model is saved.
# - epoch:3 -
# Epoch: [3][0/57] Elapsed 0m 1s (remain 1m 17s) Loss: 0.4719(0.4719)
# Epoch: [3][56/57] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3999(0.3783)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5729(0.5729)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1351(0.4172)
# 	 epoch:3, avg train loss:0.3783, avg valid loss:0.4172
# 	 score:0.4171(th=0.250000), auc=0.783249::: time:182.54s
# Epoch 3 - Save Best Score: 0.4171. Model is saved.
# dice_list:  [0.31091612893055015, 0.3684688375673568, 0.40376993064071903, 0.4170738274335138, 0.4133424046657086, 0.39655483721307294, 0.3701010537942857, 0.33421058858881875, 0.2902497747345467, 0.24025537138890352, 0.18777183322903926, 0.13667906548191086, 0.09237669822948893, 0.05646861978938247, 0.029319324578592845, 0.010807008994202809, 0.0018778790269596217, 0.00015415960797044202, 0.0]
# - epoch:4 -
# Epoch: [4][0/57] Elapsed 0m 1s (remain 1m 11s) Loss: 0.3241(0.3241)
# Epoch: [4][56/57] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2575(0.3580)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5125(0.5125)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1011(0.3978)
# 	 epoch:4, avg train loss:0.3580, avg valid loss:0.3978
# 	 score:0.4542(th=0.500000), auc=0.801039::: time:230.67s
# Epoch 4 - Save Best Score: 0.4542. Model is saved.
# dice_list:  [0.27011512187951936, 0.30808812679662506, 0.34457000323425213, 0.3761202048902235, 0.4025007523012324, 0.42486522670764443, 0.44286941699036325, 0.4536536760722249, 0.4541901951389808, 0.44291037519835, 0.4211776656760103, 0.3915884393428533, 0.35685704370452787, 0.31752909279597086, 0.2738023213070373, 0.2253633426217119, 0.1683991267474132, 0.08797957729603999, 0.0]
# Epoch 4 - Save Best AUC: 0.8010. Model is saved.
# - epoch:5 -
# Epoch: [5][0/57] Elapsed 0m 1s (remain 1m 15s) Loss: 0.3913(0.3913)
# Epoch: [5][56/57] Elapsed 0m 26s (remain 0m 0s) Loss: 0.7237(0.3528)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5129(0.5129)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1060(0.3880)
# 	 epoch:5, avg train loss:0.3528, avg valid loss:0.3880
# 	 score:0.4721(th=0.400000), auc=0.814656::: time:280.89s
# Epoch 5 - Save Best Score: 0.4721. Model is saved.
# dice_list:  [0.3144054532980889, 0.3706521025605117, 0.41190321465080737, 0.43930243621721526, 0.4575841788918647, 0.4682750989181533, 0.4721448974018609, 0.4694639883101755, 0.4602241482415004, 0.4450912345043414, 0.4230016883070529, 0.3922194487074782, 0.35037579656898765, 0.29781766381639824, 0.23754147597092298, 0.1716630224392621, 0.09953877692044928, 0.023348876630872397, 0.0]
# Epoch 5 - Save Best AUC: 0.8147. Model is saved.
# - epoch:6 -
# Epoch: [6][0/57] Elapsed 0m 1s (remain 1m 11s) Loss: 0.3020(0.3020)
# Epoch: [6][56/57] Elapsed 0m 26s (remain 0m 0s) Loss: 0.5339(0.3443)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5131(0.5131)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1092(0.3884)
# 	 epoch:6, avg train loss:0.3443, avg valid loss:0.3884
# 	 score:0.4780(th=0.400000), auc=0.814338::: time:330.76s
# Epoch 6 - Save Best Score: 0.4780. Model is saved.
# dice_list:  [0.31996119951689184, 0.37675495250462043, 0.4184390516917896, 0.44684721044916736, 0.46530793336907256, 0.4754126245567162, 0.47798133697636797, 0.4741815324416152, 0.46514264939226735, 0.4501788809189965, 0.42785538897318703, 0.39658556522033556, 0.35508373973513796, 0.3040349889237685, 0.24559838694634123, 0.1826475899870989, 0.11424111632345439, 0.0338529897338614, 0.0]
# - epoch:7 -
# Epoch: [7][0/57] Elapsed 0m 1s (remain 1m 12s) Loss: 0.4210(0.4210)
# Epoch: [7][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2015(0.3402)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5336(0.5336)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1318(0.3926)
# 	 epoch:7, avg train loss:0.3402, avg valid loss:0.3926
# 	 score:0.4957(th=0.350000), auc=0.818658::: time:378.49s
# Epoch 7 - Save Best Score: 0.4957. Model is saved.
# dice_list:  [0.35898289278984413, 0.4163292659449226, 0.4543061359670124, 0.478738124530624, 0.4920661867299582, 0.4956907409695897, 0.48980826693506, 0.474638065992808, 0.4504550026571702, 0.41730545641852984, 0.37372068040603607, 0.31789494687946446, 0.2504202384872114, 0.17779094249564034, 0.1073560433460356, 0.046269165990493355, 0.008577965663780862, 0.00024131762831999302, 0.0]
# Epoch 7 - Save Best AUC: 0.8187. Model is saved.
# - epoch:8 -
# Epoch: [8][0/57] Elapsed 0m 1s (remain 1m 11s) Loss: 0.2357(0.2357)
# Epoch: [8][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2023(0.3415)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5219(0.5219)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0714(0.3889)
# 	 epoch:8, avg train loss:0.3415, avg valid loss:0.3889
# 	 score:0.4971(th=0.550000), auc=0.830094::: time:427.78s
# Epoch 8 - Save Best Score: 0.4971. Model is saved.
# dice_list:  [0.3018300295653269, 0.3422396188667741, 0.3763370994640418, 0.4054983636349738, 0.43112978354088266, 0.4537834024494144, 0.4723966222194933, 0.4862412349189483, 0.4947083432707348, 0.4971043838373309, 0.49129429492317, 0.4752322381950695, 0.4467256456728034, 0.400627206290758, 0.3298147508613095, 0.2312052430117515, 0.11499924831624056, 0.015726532492620952, 0.0]
# Epoch 8 - Save Best AUC: 0.8301. Model is saved.
# - epoch:9 -
# Epoch: [9][0/57] Elapsed 0m 1s (remain 1m 14s) Loss: 0.3231(0.3231)
# Epoch: [9][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2770(0.3402)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5816(0.5816)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0927(0.4218)
# 	 epoch:9, avg train loss:0.3402, avg valid loss:0.4218
# 	 score:0.4668(th=0.450000), auc=0.805517::: time:476.78s
# - epoch:10 -
# Epoch: [10][0/57] Elapsed 0m 1s (remain 1m 10s) Loss: 0.4264(0.4264)
# Epoch: [10][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2675(0.3442)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5095(0.5095)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1161(0.3925)
# 	 epoch:10, avg train loss:0.3442, avg valid loss:0.3925
# 	 score:0.5101(th=0.500000), auc=0.822048::: time:521.73s
# Epoch 10 - Save Best Score: 0.5101. Model is saved.
# dice_list:  [0.33718598076378775, 0.3830246193084431, 0.41580706882809854, 0.4419888538634376, 0.46501382043503675, 0.4839540848852608, 0.4974878860233924, 0.5064332952078139, 0.5100812127477273, 0.5092553434404732, 0.5026533866009374, 0.4869971879577462, 0.46268361100968586, 0.42802624547034523, 0.3783484966119723, 0.3061169979516268, 0.19486086258079235, 0.05850730883508721, 0.0]
# - epoch:11 -
# Epoch: [11][0/57] Elapsed 0m 1s (remain 1m 19s) Loss: 0.3481(0.3481)
# Epoch: [11][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2348(0.3408)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5232(0.5232)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1029(0.4178)
# 	 epoch:11, avg train loss:0.3408, avg valid loss:0.4178
# 	 score:0.4555(th=0.550000), auc=0.805553::: time:568.95s
# - epoch:12 -
# Epoch: [12][0/57] Elapsed 0m 1s (remain 1m 9s) Loss: 0.3842(0.3842)
# Epoch: [12][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.3393(0.3338)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5440(0.5440)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0734(0.3822)
# 	 epoch:12, avg train loss:0.3338, avg valid loss:0.3822
# 	 score:0.4996(th=0.550000), auc=0.826784::: time:614.26s
# - epoch:13 -
# Epoch: [13][0/57] Elapsed 0m 1s (remain 1m 12s) Loss: 0.3609(0.3609)
# Epoch: [13][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.3971(0.3268)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5507(0.5507)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0853(0.3745)
# 	 epoch:13, avg train loss:0.3268, avg valid loss:0.3745
# 	 score:0.5420(th=0.350000), auc=0.836123::: time:659.60s
# Epoch 13 - Save Best Score: 0.5420. Model is saved.
# dice_list:  [0.3560902237823944, 0.4272099747468505, 0.48427311067423573, 0.5209939419517154, 0.5398761767561794, 0.5419810051522932, 0.5317788076008845, 0.5138656643289387, 0.4891184366766597, 0.4567473261475681, 0.41491692567021227, 0.36181584584731447, 0.3010218938840301, 0.24008582162738978, 0.18629271979994094, 0.1375213326612874, 0.08708607092766586, 0.028861857916361026, 0.0]
# Epoch 13 - Save Best AUC: 0.8361. Model is saved.
# - epoch:14 -
# Epoch: [14][0/57] Elapsed 0m 1s (remain 1m 14s) Loss: 0.3874(0.3874)
# Epoch: [14][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.3288(0.2982)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.4979(0.4979)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0836(0.3697)
# 	 epoch:14, avg train loss:0.2982, avg valid loss:0.3697
# 	 score:0.5399(th=0.500000), auc=0.836180::: time:707.78s
# Epoch 14 - Save Best AUC: 0.8362. Model is saved.
# - epoch:15 -
# Epoch: [15][0/57] Elapsed 0m 1s (remain 1m 14s) Loss: 0.4184(0.4184)
# Epoch: [15][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2305(0.2881)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5017(0.5017)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0818(0.3562)
# 	 epoch:15, avg train loss:0.2881, avg valid loss:0.3562
# 	 score:0.5737(th=0.450000), auc=0.850960::: time:753.97s
# Epoch 15 - Save Best Score: 0.5737. Model is saved.
# dice_list:  [0.3685519415570579, 0.422367245821435, 0.4686619189748486, 0.508281411397052, 0.5374013925631257, 0.5570664120453913, 0.569366062269367, 0.5737438239113096, 0.571346286490381, 0.5616381148718387, 0.5429418724758516, 0.5138465609101095, 0.4721456248370457, 0.4149605829177816, 0.3449377782378212, 0.2593393078732586, 0.15516991340307587, 0.04918829197533696, 0.0]
# Epoch 15 - Save Best AUC: 0.8510. Model is saved.
# - epoch:16 -
# Epoch: [16][0/57] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2310(0.2310)
# Epoch: [16][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2311(0.2779)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.4804(0.4804)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0882(0.3556)
# 	 epoch:16, avg train loss:0.2779, avg valid loss:0.3556
# 	 score:0.5749(th=0.500000), auc=0.849890::: time:801.85s
# Epoch 16 - Save Best Score: 0.5749. Model is saved.
# dice_list:  [0.3447378326971438, 0.39423549356247595, 0.4365514001901574, 0.4744400085068593, 0.5071141900734719, 0.5338066805405735, 0.5543252217705523, 0.5686039535022139, 0.5749470795820754, 0.5733142112737228, 0.5646557893367141, 0.5475407002411752, 0.5172346804673866, 0.46983906918455, 0.40548328864657457, 0.31939605695365264, 0.20487214156927136, 0.08029519788403275, 0.0]
# - epoch:17 -
# Epoch: [17][0/57] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2359(0.2359)
# Epoch: [17][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2159(0.2697)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5168(0.5168)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0785(0.3620)
# 	 epoch:17, avg train loss:0.2697, avg valid loss:0.3620
# 	 score:0.5646(th=0.550000), auc=0.850115::: time:848.11s
# - epoch:18 -
# Epoch: [18][0/57] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2410(0.2410)
# Epoch: [18][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.2330(0.2742)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5114(0.5114)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0881(0.3770)
# 	 epoch:18, avg train loss:0.2742, avg valid loss:0.3770
# 	 score:0.5706(th=0.650000), auc=0.841644::: time:892.44s
# - epoch:19 -
# Epoch: [19][0/57] Elapsed 0m 1s (remain 1m 11s) Loss: 0.2190(0.2190)
# Epoch: [19][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2092(0.3031)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5684(0.5684)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0796(0.4063)
# 	 epoch:19, avg train loss:0.3031, avg valid loss:0.4063
# 	 score:0.5378(th=0.700000), auc=0.833912::: time:937.29s
# - epoch:20 -
# Epoch: [20][0/57] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2777(0.2777)
# Epoch: [20][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.5478(0.3100)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5592(0.5592)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0988(0.4100)
# 	 epoch:20, avg train loss:0.3100, avg valid loss:0.4100
# 	 score:0.5285(th=0.450000), auc=0.829291::: time:981.90s
# surface_list:  [27, 30, 33, 36]
# - epoch:21 -
# Epoch: [21][0/57] Elapsed 0m 1s (remain 1m 14s) Loss: 0.3184(0.3184)
# Epoch: [21][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2890(0.2938)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6170(0.6170)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0642(0.4029)
# 	 epoch:21, avg train loss:0.2938, avg valid loss:0.4029
# 	 score:0.4732(th=0.400000), auc=0.821922::: time:1061.88s
# - epoch:22 -
# Epoch: [22][0/57] Elapsed 0m 1s (remain 1m 15s) Loss: 0.3612(0.3612)
# Epoch: [22][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2153(0.3048)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5829(0.5829)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1460(0.3859)
# 	 epoch:22, avg train loss:0.3048, avg valid loss:0.3859
# 	 score:0.4881(th=0.400000), auc=0.821762::: time:1105.98s
# - epoch:23 -
# Epoch: [23][0/57] Elapsed 0m 1s (remain 1m 8s) Loss: 0.2310(0.2310)
# Epoch: [23][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.3763(0.2824)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.4481(0.4481)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0797(0.3834)
# 	 epoch:23, avg train loss:0.2824, avg valid loss:0.3834
# 	 score:0.5666(th=0.450000), auc=0.839716::: time:1150.23s
# - epoch:24 -
# Epoch: [24][0/57] Elapsed 0m 1s (remain 1m 16s) Loss: 0.2227(0.2227)
# Epoch: [24][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.3672(0.2576)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.4781(0.4781)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0820(0.3693)
# 	 epoch:24, avg train loss:0.2576, avg valid loss:0.3693
# 	 score:0.5737(th=0.550000), auc=0.859129::: time:1194.42s
# Epoch 24 - Save Best AUC: 0.8591. Model is saved.
# - epoch:25 -
# Epoch: [25][0/57] Elapsed 0m 1s (remain 1m 13s) Loss: 0.2331(0.2331)
# Epoch: [25][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.3320(0.2481)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5471(0.5471)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0809(0.3901)
# 	 epoch:25, avg train loss:0.2481, avg valid loss:0.3901
# 	 score:0.5678(th=0.450000), auc=0.849229::: time:1240.51s
# - epoch:26 -
# Epoch: [26][0/57] Elapsed 0m 1s (remain 1m 11s) Loss: 0.2539(0.2539)
# Epoch: [26][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.1885(0.2414)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5099(0.5099)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0821(0.3781)
# 	 epoch:26, avg train loss:0.2414, avg valid loss:0.3781
# 	 score:0.5764(th=0.500000), auc=0.852662::: time:1284.58s
# Epoch 26 - Save Best Score: 0.5764. Model is saved.
# dice_list:  [0.44698637292330246, 0.49217489777264495, 0.5215995435507004, 0.542132685815088, 0.5557348446597443, 0.5649405871839895, 0.5712730924393417, 0.5757780852084668, 0.5763700849678828, 0.5708174709981562, 0.5598760698658476, 0.5441370946253805, 0.5210010980318007, 0.4912967445279648, 0.44642361144336573, 0.37971406134415253, 0.28625682097562544, 0.14743488723630369, 0.0]
# - epoch:27 -
# Epoch: [27][0/57] Elapsed 0m 1s (remain 1m 12s) Loss: 0.3161(0.3161)
# Epoch: [27][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 1.0142(0.2497)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.4998(0.4998)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0922(0.3738)
# 	 epoch:27, avg train loss:0.2497, avg valid loss:0.3738
# 	 score:0.5749(th=0.550000), auc=0.857543::: time:1331.09s
# - epoch:28 -
# Epoch: [28][0/57] Elapsed 0m 1s (remain 1m 19s) Loss: 0.2164(0.2164)
# Epoch: [28][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.3756(0.2529)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5861(0.5861)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1182(0.3928)
# 	 epoch:28, avg train loss:0.2529, avg valid loss:0.3928
# 	 score:0.5549(th=0.550000), auc=0.843651::: time:1375.79s
# - epoch:29 -
# Epoch: [29][0/57] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2107(0.2107)
# Epoch: [29][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2198(0.2673)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.4969(0.4969)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1334(0.3839)
# 	 epoch:29, avg train loss:0.2673, avg valid loss:0.3839
# 	 score:0.5411(th=0.650000), auc=0.840359::: time:1420.19s
# - epoch:30 -
# Epoch: [30][0/57] Elapsed 0m 1s (remain 1m 13s) Loss: 0.1479(0.1479)
# Epoch: [30][56/57] Elapsed 0m 24s (remain 0m 0s) Loss: 0.2045(0.2670)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5894(0.5894)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0726(0.3901)
# 	 epoch:30, avg train loss:0.2670, avg valid loss:0.3901
# 	 score:0.5271(th=0.400000), auc=0.836420::: time:1464.30s
# - epoch:31 -
# Epoch: [31][0/57] Elapsed 0m 1s (remain 1m 16s) Loss: 0.1561(0.1561)
# Epoch: [31][56/57] Elapsed 0m 25s (remain 0m 0s) Loss: 0.4821(0.2725)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5299(0.5299)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0633(0.3599)
# 	 epoch:31, avg train loss:0.2725, avg valid loss:0.3599
# ...
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4121(0.4040)
# 	 epoch:26, avg train loss:0.2344, avg valid loss:0.4040
# 	 score:0.4867(th=0.700000), auc=0.877004::: time:1279.82s
# - epoch:27 -
# Epoch: [27][0/60] Elapsed 0m 1s (remain 1m 15s) Loss: 0.1831(0.1831)
# Epoch: [27][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1858(0.2424)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2452(0.2452)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3957(0.3959)
# 	 epoch:27, avg train loss:0.2424, avg valid loss:0.3959
# 	 score:0.4867(th=0.650000), auc=0.880387::: time:1324.72s
# - epoch:28 -
# Epoch: [28][0/60] Elapsed 0m 1s (remain 1m 21s) Loss: 0.2306(0.2306)
# Epoch: [28][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1930(0.2275)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2787(0.2787)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3841(0.4045)
# 	 epoch:28, avg train loss:0.2275, avg valid loss:0.4045
# 	 score:0.4906(th=0.700000), auc=0.879976::: time:1369.09s
# Epoch 28 - Save Best Score: 0.4906. Model is saved.
# dice_list:  [0.3452841991964611, 0.37456077795299336, 0.3967380408628108, 0.4118718997800125, 0.4245221300370217, 0.43579146111395045, 0.44615073917410886, 0.45583628070235255, 0.4665171304540602, 0.47657577816948044, 0.4848913607519179, 0.4903521581581176, 0.4905518976820958, 0.4808482507378958, 0.45926407021964755, 0.411595006334021, 0.3303854655757419, 0.193466831505443, 0.0]
# - epoch:29 -
# Epoch: [29][0/60] Elapsed 0m 1s (remain 1m 25s) Loss: 0.3991(0.3991)
# Epoch: [29][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1693(0.2529)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1950(0.1950)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3709(0.3792)
# 	 epoch:29, avg train loss:0.2529, avg valid loss:0.3792
# 	 score:0.4780(th=0.450000), auc=0.879491::: time:1415.40s
# - epoch:30 -
# Epoch: [30][0/60] Elapsed 0m 1s (remain 1m 24s) Loss: 0.2591(0.2591)
# Epoch: [30][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4000(0.2612)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1928(0.1928)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3861(0.4288)
# 	 epoch:30, avg train loss:0.2612, avg valid loss:0.4288
# 	 score:0.4506(th=0.700000), auc=0.869036::: time:1460.02s
# - epoch:31 -
# Epoch: [31][0/60] Elapsed 0m 1s (remain 1m 22s) Loss: 0.4309(0.4309)
# Epoch: [31][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3650(0.2806)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2903(0.2903)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3818(0.4275)
# 	 epoch:31, avg train loss:0.2806, avg valid loss:0.4275
# 	 score:0.4793(th=0.700000), auc=0.880710::: time:1505.12s
# - epoch:32 -
# Epoch: [32][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.1855(0.1855)
# Epoch: [32][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1474(0.2736)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2087(0.2087)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3567(0.3844)
# 	 epoch:32, avg train loss:0.2736, avg valid loss:0.3844
# 	 score:0.4926(th=0.600000), auc=0.885329::: time:1549.69s
# Epoch 32 - Save Best Score: 0.4926. Model is saved.
# dice_list:  [0.28169572400527637, 0.31105239201306945, 0.3390042687532428, 0.36461353686708425, 0.3904583538627431, 0.4168428788904474, 0.44341343576792375, 0.4650025032193922, 0.4815587610523334, 0.49221755405288725, 0.4926054367736354, 0.48379961696884966, 0.4616988875796868, 0.4170006473490173, 0.3504710918418231, 0.26173878819160346, 0.1476517474009699, 0.05718422216547149, 0.0]
# - epoch:33 -
# Epoch: [33][0/60] Elapsed 0m 1s (remain 1m 12s) Loss: 0.2164(0.2164)
# Epoch: [33][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1789(0.2544)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2356(0.2356)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3748(0.3893)
# 	 epoch:33, avg train loss:0.2544, avg valid loss:0.3893
# 	 score:0.5210(th=0.650000), auc=0.888869::: time:1595.95s
# Epoch 33 - Save Best Score: 0.5210. Model is saved.
# dice_list:  [0.33458416440053734, 0.3705375204043479, 0.39843368632000215, 0.4217238071542614, 0.44125216887072854, 0.457278843831718, 0.471969876059188, 0.487094746253298, 0.5007509614895527, 0.5105138270129347, 0.5179378106603038, 0.5209895210445612, 0.5206688841754717, 0.5197736199926415, 0.5095743421154545, 0.4856572176147952, 0.43079085320896043, 0.3193061527386519, 0.0]
# Epoch 33 - Save Best AUC: 0.8889. Model is saved.
# - epoch:34 -
# Epoch: [34][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.3978(0.3978)
# Epoch: [34][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2834(0.2356)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2764(0.2764)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4068(0.3987)
# 	 epoch:34, avg train loss:0.2356, avg valid loss:0.3987
# 	 score:0.4965(th=0.500000), auc=0.875727::: time:1643.73s
# - epoch:35 -
# Epoch: [35][0/60] Elapsed 0m 1s (remain 1m 14s) Loss: 0.1764(0.1764)
# Epoch: [35][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2180(0.2145)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2611(0.2611)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3851(0.3992)
# 	 epoch:35, avg train loss:0.2145, avg valid loss:0.3992
# 	 score:0.5061(th=0.600000), auc=0.878622::: time:1688.32s
# - epoch:36 -
# Epoch: [36][0/60] Elapsed 0m 1s (remain 1m 15s) Loss: 0.1916(0.1916)
# Epoch: [36][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2148(0.2142)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2612(0.2612)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3880(0.3982)
# 	 epoch:36, avg train loss:0.2142, avg valid loss:0.3982
# 	 score:0.5045(th=0.600000), auc=0.877946::: time:1733.38s
# - epoch:37 -
# Epoch: [37][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2969(0.2969)
# Epoch: [37][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1394(0.2088)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2637(0.2637)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3846(0.3988)
# 	 epoch:37, avg train loss:0.2088, avg valid loss:0.3988
# 	 score:0.5013(th=0.600000), auc=0.879763::: time:1777.96s
# - epoch:38 -
# Epoch: [38][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.1775(0.1775)
# Epoch: [38][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2639(0.2183)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2117(0.2117)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3686(0.3862)
# 	 epoch:38, avg train loss:0.2183, avg valid loss:0.3862
# 	 score:0.5097(th=0.650000), auc=0.891313::: time:1823.10s
# Epoch 38 - Save Best AUC: 0.8913. Model is saved.
# - epoch:39 -
# Epoch: [39][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.2901(0.2901)
# Epoch: [39][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2492(0.2161)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2610(0.2610)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3886(0.4180)
# 	 epoch:39, avg train loss:0.2161, avg valid loss:0.4180
# 	 score:0.4840(th=0.600000), auc=0.874217::: time:1869.15s
# - epoch:40 -
# Epoch: [40][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.1183(0.1183)
# Epoch: [40][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2418(0.2212)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2875(0.2875)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4295(0.4673)
# 	 epoch:40, avg train loss:0.2212, avg valid loss:0.4673
# 	 score:0.4245(th=0.650000), auc=0.860231::: time:1913.51s
# surface_list:  [25, 28, 31, 34]
# - epoch:41 -
# Epoch: [41][0/60] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2260(0.2260)
# Epoch: [41][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2434(0.2764)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2534(0.2534)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3688(0.3987)
# 	 epoch:41, avg train loss:0.2764, avg valid loss:0.3987
# 	 score:0.4207(th=0.450000), auc=0.871780::: time:1991.75s
# - epoch:42 -
# Epoch: [42][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.3641(0.3641)
# Epoch: [42][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4012(0.2652)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.3165(0.3165)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3905(0.4070)
# 	 epoch:42, avg train loss:0.2652, avg valid loss:0.4070
# 	 score:0.4331(th=0.400000), auc=0.868814::: time:2036.63s
# - epoch:43 -
# Epoch: [43][0/60] Elapsed 0m 1s (remain 1m 24s) Loss: 0.3129(0.3129)
# Epoch: [43][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2488(0.2407)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2400(0.2400)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3826(0.4539)
# 	 epoch:43, avg train loss:0.2407, avg valid loss:0.4539
# 	 score:0.4373(th=0.650000), auc=0.871976::: time:2081.77s
# - epoch:44 -
# Epoch: [44][0/60] Elapsed 0m 1s (remain 1m 14s) Loss: 0.1680(0.1680)
# Epoch: [44][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2750(0.2273)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2914(0.2914)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3730(0.4288)
# 	 epoch:44, avg train loss:0.2273, avg valid loss:0.4288
# 	 score:0.4390(th=0.400000), auc=0.861978::: time:2126.77s
# - epoch:45 -
# Epoch: [45][0/60] Elapsed 0m 1s (remain 1m 24s) Loss: 0.1374(0.1374)
# Epoch: [45][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1850(0.1959)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2901(0.2901)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3747(0.4329)
# 	 epoch:45, avg train loss:0.1959, avg valid loss:0.4329
# 	 score:0.4423(th=0.450000), auc=0.863789::: time:2171.93s
# - epoch:46 -
# Epoch: [46][0/60] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2298(0.2298)
# Epoch: [46][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2130(0.2050)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 5s) Loss: 0.3020(0.3020)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3876(0.4384)
# 	 epoch:46, avg train loss:0.2050, avg valid loss:0.4384
# 	 score:0.4349(th=0.400000), auc=0.860565::: time:2216.97s
# - epoch:47 -
# Epoch: [47][0/60] Elapsed 0m 1s (remain 1m 21s) Loss: 0.1408(0.1408)
# Epoch: [47][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1951(0.1980)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2992(0.2992)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3678(0.4265)
# 	 epoch:47, avg train loss:0.1980, avg valid loss:0.4265
# 	 score:0.4374(th=0.400000), auc=0.866556::: time:2262.11s
# - epoch:48 -
# Epoch: [48][0/60] Elapsed 0m 1s (remain 1m 24s) Loss: 0.3070(0.3070)
# Epoch: [48][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2333(0.2097)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2741(0.2741)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3594(0.4251)
# 	 epoch:48, avg train loss:0.2097, avg valid loss:0.4251
# 	 score:0.4651(th=0.600000), auc=0.875744::: time:2307.41s
# - epoch:49 -
# Epoch: [49][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.1640(0.1640)
# Epoch: [49][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1960(0.2195)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2461(0.2461)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3952(0.4299)
# 	 epoch:49, avg train loss:0.2195, avg valid loss:0.4299
# 	 score:0.4468(th=0.550000), auc=0.866354::: time:2352.54s
# - epoch:50 -
# Epoch: [50][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.2061(0.2061)
# Epoch: [50][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2371(0.2191)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2886(0.2886)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4781(0.4664)
# 	 epoch:50, avg train loss:0.2191, avg valid loss:0.4664
# 	 score:0.4370(th=0.650000), auc=0.873053::: time:2397.58s
# - epoch:51 -
# Epoch: [51][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.1285(0.1285)
# Epoch: [51][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1788(0.2451)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.3552(0.3552)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4385(0.4456)
# 	 epoch:51, avg train loss:0.2451, avg valid loss:0.4456
# 	 score:0.4211(th=0.350000), auc=0.859125::: time:2442.54s
# - epoch:52 -
# Epoch: [52][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.1718(0.1718)
# Epoch: [52][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1724(0.2287)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2407(0.2407)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3767(0.4650)
# 	 epoch:52, avg train loss:0.2287, avg valid loss:0.4650
# 	 score:0.4310(th=0.700000), auc=0.873321::: time:2487.60s
# - epoch:53 -
# Epoch: [53][0/60] Elapsed 0m 1s (remain 1m 14s) Loss: 0.1470(0.1470)
# Epoch: [53][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2753(0.2202)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2559(0.2559)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3667(0.4243)
# 	 epoch:53, avg train loss:0.2202, avg valid loss:0.4243
# 	 score:0.4437(th=0.600000), auc=0.878084::: time:2532.77s
# - epoch:54 -
# Epoch: [54][0/60] Elapsed 0m 1s (remain 1m 16s) Loss: 0.1857(0.1857)
# Epoch: [54][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1252(0.1941)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2647(0.2647)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3696(0.4396)
# 	 epoch:54, avg train loss:0.1941, avg valid loss:0.4396
# 	 score:0.4419(th=0.650000), auc=0.875364::: time:2577.53s
# - epoch:55 -
# Epoch: [55][0/60] Elapsed 0m 1s (remain 1m 16s) Loss: 0.1572(0.1572)
# Epoch: [55][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1765(0.1846)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2712(0.2712)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3600(0.4454)
# 	 epoch:55, avg train loss:0.1846, avg valid loss:0.4454
# 	 score:0.4414(th=0.650000), auc=0.873379::: time:2622.47s
# - epoch:56 -
# Epoch: [56][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2693(0.2693)
# Epoch: [56][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3045(0.1791)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2673(0.2673)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3571(0.4399)
# 	 epoch:56, avg train loss:0.1791, avg valid loss:0.4399
# 	 score:0.4373(th=0.650000), auc=0.871857::: time:2667.56s
# - epoch:57 -
# Epoch: [57][0/60] Elapsed 0m 1s (remain 1m 14s) Loss: 0.2225(0.2225)
# Epoch: [57][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1706(0.1771)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2714(0.2714)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3542(0.4353)
# 	 epoch:57, avg train loss:0.1771, avg valid loss:0.4353
# 	 score:0.4550(th=0.650000), auc=0.875642::: time:2712.68s
# - epoch:58 -
# Epoch: [58][0/60] Elapsed 0m 1s (remain 1m 16s) Loss: 0.1402(0.1402)
# Epoch: [58][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1649(0.1816)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.3110(0.3110)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3475(0.4645)
# 	 epoch:58, avg train loss:0.1816, avg valid loss:0.4645
# 	 score:0.4378(th=0.750000), auc=0.869188::: time:2757.25s
# - epoch:59 -
# Epoch: [59][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.1819(0.1819)
# Epoch: [59][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1715(0.1846)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 4s) Loss: 0.3104(0.3104)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4325(0.4434)
# 	 epoch:59, avg train loss:0.1846, avg valid loss:0.4434
# 	 score:0.4708(th=0.500000), auc=0.874731::: time:2802.44s
# - epoch:60 -
# Epoch: [60][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.1205(0.1205)
# Epoch: [60][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3341(0.1969)
# EVAL: [0/15] Elapsed 0m 0s (remain 0m 5s) Loss: 0.3337(0.3337)
# EVAL: [14/15] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4498(0.4732)
# 	 epoch:60, avg train loss:0.1969, avg valid loss:0.4732
# 	 score:0.4414(th=0.500000), auc=0.870036::: time:2847.05s
# [fold4] slice ave score:0.4388(th=0.600000), auc=0.865750
# [fold4] BEST Epoch 33 - Save Best Score:0.5210. Best loss:0.3893
# [fold4] BEST AUC Epoch 38 - Save Best Score:0.8913. Best loss:0.3862
# fold[0] BEST SCORE = 0.5419 thr=0.8 (epoch=56)
# fold[0] slice ave score:0.4717(th=0.600000), auc=0.883583
# fold[1] BEST SCORE = 0.5764 thr=0.5 (epoch=26)
# fold[1] slice ave score:0.6022(th=0.450000), auc=0.853786
# fold[2] BEST SCORE = 0.5653 thr=0.6 (epoch=26)
# fold[2] slice ave score:0.5490(th=0.550000), auc=0.850002
# fold[3] BEST SCORE = 0.5553 thr=0.6 (epoch=25)
# fold[3] slice ave score:0.5246(th=0.400000), auc=0.928211
# fold[4] BEST SCORE = 0.5210 thr=0.65 (epoch=33)
# fold[4] slice ave score:0.4388(th=0.600000), auc=0.865750
# CPU times: user 2h 45min 38s, sys: 1h 17s, total: 3h 45min 56s
# Wall time: 3h 53min 10s

# %% [markdown]
# ---
# # OOF SCORE INFER

# %%
# %%time
slice_ave_score_list, slice_ave_score_threshold_list, slice_ave_auc_list = slide_inference(CFG)
for fold in CFG["folds"]:
    print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    wandb.log({"OOF SCORE" : {f"slice average score":slice_ave_score_list[fold],
                            f"slice average threshold":slice_ave_score_threshold_list[fold],
                            f"slice_average auc":slice_ave_auc_list[fold],
                            }})
# Out:
# -- fold0 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.5256(th=0.550000), auc=0.894730::: time:25.41s
# slide pos: [256, 0]
# 	 score:0.3482(th=0.500000), auc=0.852234::: time:42.44s
# slide pos: [0, 256]
# 	 score:0.5241(th=0.550000), auc=0.898060::: time:59.19s
# slide pos: [256, 256]
# 	 score:0.3418(th=0.450000), auc=0.853088::: time:76.26s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.5224(th=0.550000), auc=0.894214::: time:100.72s
# slide pos: [256, 0]
# 	 score:0.3445(th=0.500000), auc=0.851398::: time:118.12s
# slide pos: [0, 256]
# 	 score:0.5275(th=0.550000), auc=0.898073::: time:135.13s
# slide pos: [256, 256]
# 	 score:0.3361(th=0.500000), auc=0.855679::: time:152.11s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.5410(th=0.650000), auc=0.893020::: time:177.38s
# slide pos: [256, 0]
# 	 score:0.3510(th=0.450000), auc=0.847827::: time:194.57s
# slide pos: [0, 256]
# 	 score:0.5246(th=0.550000), auc=0.896157::: time:211.72s
# slide pos: [256, 256]
# 	 score:0.3409(th=0.500000), auc=0.848334::: time:228.66s
# [fold0] slice ave score:0.5152(th=0.450000), auc=0.898420
# -- fold1 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.5775(th=0.600000), auc=0.858095::: time:269.91s
# slide pos: [256, 0]
# 	 score:0.3522(th=0.300000), auc=0.783320::: time:292.37s
# slide pos: [0, 256]
# 	 score:0.5720(th=0.550000), auc=0.854200::: time:315.68s
# slide pos: [256, 256]
# 	 score:0.3381(th=0.300000), auc=0.776397::: time:339.16s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.5737(th=0.550000), auc=0.859129::: time:366.26s
# slide pos: [256, 0]
# 	 score:0.3509(th=0.300000), auc=0.785318::: time:388.56s
# slide pos: [0, 256]
# 	 score:0.5769(th=0.500000), auc=0.856117::: time:411.53s
# slide pos: [256, 256]
# 	 score:0.3310(th=0.300000), auc=0.778675::: time:434.57s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.5717(th=0.600000), auc=0.855360::: time:462.14s
# slide pos: [256, 0]
# 	 score:0.3571(th=0.300000), auc=0.776626::: time:484.98s
# slide pos: [0, 256]
# 	 score:0.5570(th=0.550000), auc=0.849711::: time:508.01s
# slide pos: [256, 256]
# 	 score:0.3332(th=0.300000), auc=0.769077::: time:531.21s
# [fold1] slice ave score:0.5355(th=0.400000), auc=0.837117
# -- fold2 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.5553(th=0.550000), auc=0.844785::: time:575.65s
# slide pos: [256, 0]
# 	 score:0.3143(th=0.250000), auc=0.760377::: time:597.38s
# slide pos: [0, 256]
# 	 score:0.5210(th=0.550000), auc=0.849167::: time:620.14s
# slide pos: [256, 256]
# 	 score:0.3261(th=0.300000), auc=0.760264::: time:642.77s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.5653(th=0.600000), auc=0.847908::: time:669.38s
# slide pos: [256, 0]
# 	 score:0.3203(th=0.250000), auc=0.763194::: time:691.45s
# slide pos: [0, 256]
# 	 score:0.5352(th=0.600000), auc=0.851069::: time:713.86s
# slide pos: [256, 256]
# 	 score:0.3284(th=0.350000), auc=0.759303::: time:736.22s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.5470(th=0.500000), auc=0.843383::: time:762.79s
# slide pos: [256, 0]
# 	 score:0.3095(th=0.250000), auc=0.755159::: time:785.07s
# slide pos: [0, 256]
# 	 score:0.5116(th=0.500000), auc=0.848975::: time:807.31s
# slide pos: [256, 256]
# 	 score:0.3251(th=0.300000), auc=0.758925::: time:830.13s
# [fold2] slice ave score:0.4837(th=0.450000), auc=0.817041
# -- fold3 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.5257(th=0.600000), auc=0.936847::: time:868.76s
# slide pos: [256, 0]
# 	 score:0.3736(th=0.600000), auc=0.902629::: time:887.20s
# slide pos: [0, 256]
# 	 score:0.5167(th=0.550000), auc=0.931999::: time:904.54s
# slide pos: [256, 256]
# 	 score:0.3586(th=0.500000), auc=0.901180::: time:923.10s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.5426(th=0.600000), auc=0.937837::: time:944.24s
# slide pos: [256, 0]
# 	 score:0.3679(th=0.600000), auc=0.899438::: time:962.12s
# slide pos: [0, 256]
# 	 score:0.5274(th=0.550000), auc=0.931872::: time:980.48s
# slide pos: [256, 256]
# 	 score:0.3580(th=0.550000), auc=0.898877::: time:998.44s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.4870(th=0.550000), auc=0.931759::: time:1019.49s
# slide pos: [256, 0]
# 	 score:0.3605(th=0.500000), auc=0.898583::: time:1037.93s
# slide pos: [0, 256]
# 	 score:0.4755(th=0.500000), auc=0.926301::: time:1055.53s
# slide pos: [256, 256]
# 	 score:0.3440(th=0.500000), auc=0.893783::: time:1073.96s
# [fold3] slice ave score:0.5509(th=0.500000), auc=0.931391
# -- fold4 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.5118(th=0.650000), auc=0.888598::: time:1118.62s
# slide pos: [256, 0]
# 	 score:0.3986(th=0.400000), auc=0.874177::: time:1140.35s
# slide pos: [0, 256]
# 	 score:0.5196(th=0.650000), auc=0.888675::: time:1161.31s
# slide pos: [256, 256]
# 	 score:0.3884(th=0.450000), auc=0.872005::: time:1182.03s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.5097(th=0.650000), auc=0.891313::: time:1212.85s
# slide pos: [256, 0]
# 	 score:0.3930(th=0.400000), auc=0.873691::: time:1234.03s
# slide pos: [0, 256]
# 	 score:0.5261(th=0.700000), auc=0.893244::: time:1255.36s
# slide pos: [256, 256]
# 	 score:0.3908(th=0.350000), auc=0.871602::: time:1276.60s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.5067(th=0.650000), auc=0.882025::: time:1307.19s
# slide pos: [256, 0]
# 	 score:0.3987(th=0.400000), auc=0.870213::: time:1328.53s
# slide pos: [0, 256]
# 	 score:0.5052(th=0.650000), auc=0.882991::: time:1350.09s
# slide pos: [256, 256]
# 	 score:0.4079(th=0.450000), auc=0.870961::: time:1371.60s
# [fold4] slice ave score:0.5203(th=0.500000), auc=0.897340
# fold[0] slice ave score:0.5152(th=0.898420), auc=0.450000
# fold[1] slice ave score:0.5355(th=0.837117), auc=0.400000
# fold[2] slice ave score:0.4837(th=0.817041), auc=0.450000
# fold[3] slice ave score:0.5509(th=0.931391), auc=0.500000
# fold[4] slice ave score:0.5203(th=0.897340), auc=0.500000
# CPU times: user 18min 22s, sys: 3min 26s, total: 21min 48s
# Wall time: 23min 7s

# %%
import yaml
with open(os.path.join(CFG["OUTPUT_DIR"], "Config.yaml"), "w") as f:
    yaml.dump(CFG, f)

# %%
if not CFG["DEBUG"]:
    wandb.finish()
