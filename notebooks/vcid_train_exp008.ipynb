# %% [markdown]
# exp008
#
# slide inference

# %%
import gc
import os
import random
import time
import math

import cv2
import numpy as np
import matplotlib.pyplot as plt

# model
import torch
import torchvision
import torch.nn as nn
import timm
from torchvision.models.feature_extraction import create_feature_extractor
import torchvision.transforms.functional as TF

# data loader
import albumentations as A
from albumentations.pytorch import ToTensorV2
from torch.utils.data import DataLoader, Dataset

# training
from torch.optim import SGD, Adam, AdamW
from torch.optim.lr_scheduler import CosineAnnealingLR, CosineAnnealingWarmRestarts, ReduceLROnPlateau

# metric
from sklearn.metrics import fbeta_score, roc_auc_score

import wandb

# %% [markdown]
# # config

# %%
BASE_DIR = "/working/"
INPUT_DIR = os.path.join(BASE_DIR, "input", "vesuvius-challenge-ink-detection")
TRAIN_DIR = os.path.join(INPUT_DIR, "train")
TEST_DIR = os.path.join(INPUT_DIR, "test")
IMG_SIZE = [256, 256]
SURFACE_LIST = [
                range(26, 36, 3),
                range(27, 37, 3),                
                range(25, 35, 3),
                ]
print(len(SURFACE_LIST[0]))
print(SURFACE_LIST)

SURFACE_NUM = len(SURFACE_LIST[0])
# print("Start surface idx =",START_SURFACE)

# SLIDE_POS_LIST = [[idx*(IMG_SIZE[0]//6), idx*(IMG_SIZE[1]//6)] for idx in range(0, 3)]
SLIDE_POS_LIST = [[0,0], [IMG_SIZE[0]//2, 0], [0, IMG_SIZE[1]//2], [IMG_SIZE[0]//2, IMG_SIZE[1]//2]]
print("SLIDE_POS_LIST =", SLIDE_POS_LIST)
CFG = {
    "DEBUG" : False,
    # exp setting
    "EXP_CATEGORY" : "makebase",
    "EXP_NAME" : "exp008",
    "folds" : [0, 1, 2],

    # model
    # "model_name" : "tf_efficientnet_b0",
    "model_name" : "tf_efficientnet_b6",
    "inp_channels" : SURFACE_NUM,
    "out_channels" : 1,
    "pretrained" : True,
    "out_indices" : [0,1,2,3,4],
 
    # data   
    "img_size": IMG_SIZE,
    # "batch_size": 64,
    "batch_size": 16,#batch normの関係か？16の方が64より安定してそう？？
    "INPUT_DIR": INPUT_DIR,
    "TRAIN_DIR": TRAIN_DIR,
    "TEST_DIR": TEST_DIR,
    "surface_num": SURFACE_NUM,
    "surface_list": SURFACE_LIST,
    "slide_pos_list": SLIDE_POS_LIST,
#     "surface_start_idx": START_SURFACE,
    "TRAIN_DIR_LIST": [["1", "2"], ["1", "3"], ["2", "3"]],
#     "TRAIN_IDX_LIST" : ["1"],
    "VALID_DIR_LIST": [["3"],["2"],["1"]],
    "TEST_DIR_LIST": ["a", "b"],

    # learning
    "n_epoch" : 10,
    "lr" : 5e-3,
    "T_max" : 5,
    "min_lr" : 1e-8,
    "weight_decay" : 1e-6,

    # etc
    "print_freq" : 1000,
    "random_seed" : 21,
    "num_workers": 2,
}


if CFG["model_name"]=="tf_efficientnet_b0":
    CFG["channel_nums"] = [320, 112, 40, 24, 16]
elif CFG["model_name"]=="tf_efficientnet_b4":
    CFG["channel_nums"] = [448, 160, 56, 32, 24]
elif CFG["model_name"]=="tf_efficientnet_b6":
    CFG["channel_nums"] = [576, 200, 72, 40, 32]


if CFG["DEBUG"]:
    CFG["n_epoch"] = 1
    CFG["EXP_NAME"] = "DEBUG"
    

CFG["OUTPUT_DIR"] = os.path.join(BASE_DIR, "output", CFG["EXP_NAME"])
# Out:
# 4
# [range(26, 36, 3), range(27, 37, 3), range(25, 35, 3)]
# SLIDE_POS_LIST = [[0, 0], [128, 0], [0, 128], [128, 128]]

# %%
if not CFG["DEBUG"]:
    os.makedirs(CFG["OUTPUT_DIR"])
    os.makedirs(os.path.join(CFG["OUTPUT_DIR"], "imgs"))

# %%
if not CFG["DEBUG"]:
    WANDB_CONFIG = {'competition': 'vcid', '_wandb_kernel': 'taro'}
    os.environ["WANDB_SILENT"] = "true"
    wandb.init(project=WANDB_CONFIG["competition"], config=CFG, group=CFG["EXP_CATEGORY"], name=CFG["EXP_NAME"])
# Out:
# 2023-04-16 06:56:12.826451: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-16 06:56:12.904983: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-16 06:56:13.526152: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-16 06:56:13.526241: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-16 06:56:13.526247: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# # utils

# %%
def logging_metrics_epoch(CFG, fold, epoch, slice_idx,train_loss_avg, valid_loss_avg, score, threshold, auc_score):
    wandb.log({f"train/fold{fold}": train_loss_avg,
            f"valid/fold{fold}": valid_loss_avg}, step=epoch+slice_idx*CFG["n_epoch"])
    wandb.log({f"score/fold{fold}":score,
                f"score threshold/fold{fold}":threshold,
                f"auc/fold{fold}":auc_score,
                }, step=epoch+slice_idx*CFG["n_epoch"])

    # wandb.log({"loss avg":{f"train/fold{fold}": train_loss_avg,
    #                         f"valid/fold{fold}": valid_loss_avg}}, step=epoch+slice_idx*CFG["n_epoch"])
    # wandb.log({"Metircs" : {f"score/fold{fold}":score,
    #                         f"score threshold/fold{fold}":threshold,
    #                         f"auc/fold{fold}":auc_score,
    #                         }}, step=epoch+slice_idx*CFG["n_epoch"])

# %%
def seed_everything(seed=CFG["random_seed"]):
    #os.environ['PYTHONSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic =True
    torch.backends.cudnn.benchmark = False
seed_everything()

# device optimization
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
def asMinutes(s):
    """Convert Seconds to Minutes."""
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    """Accessing and Converting Time Data."""
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))

class AverageMeter(object):
    """Computes and stores the average and current value."""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# # metric

# %%
def fbeta_numpy(targets, preds, beta=0.5, smooth=1e-5):
    y_true_count = targets.sum()
    ctp = preds[targets==1].sum()
    cfp = preds[targets==0].sum()
    beta_squared = beta * beta

    c_precision = ctp / (ctp + cfp + smooth)
    c_recall = ctp / (y_true_count + smooth)
    dice = (1 + beta_squared) * (c_precision * c_recall) / (beta_squared * c_precision + c_recall + smooth)

    return dice

def calc_fbeta_auc(mask, mask_pred):
    mask = mask.astype(int).flatten()
    mask_pred = mask_pred.flatten()

    best_th = 0
    best_dice = 0
    dice_list = [] 
    # for th in np.array(range(10, 50+1, 5)) / 100:
    for th in np.array(range(10, 100+1, 5)) / 100:
        # dice = fbeta_score(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice = fbeta_numpy(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice_list.append(dice)
        # print(f'\t th: {th}, fbeta: {dice}')
        if dice > best_dice:
            best_dice = dice
            best_th = th
    
    auc = roc_auc_score(mask, mask_pred)
    # Logger.info(f'best_th: {best_th}, fbeta: {best_dice}')
    return best_dice, best_th, auc, dice_list


def calc_cv(mask_gt, mask_pred):
    best_dice, best_th, auc, dice_list = calc_fbeta_auc(mask_gt, mask_pred)

    return best_dice, best_th, auc, dice_list

# %% [markdown]
# # model

# %%
class Encoder(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = timm.create_model(CFG["model_name"], in_chans=CFG["inp_channels"], features_only=True, out_indices=CFG["out_indices"], pretrained=CFG["pretrained"])
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        return skip_connection_list

class UpConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.bn1 = nn.BatchNorm2d(in_channels)
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size = 2, padding="same")
        self.bn2 = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        x = self.up(x)
        x = self.bn1(x)
        x = self.conv(x)
        x = self.bn2(x)
        return x


class Decoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.UpConv_0 = UpConv(CFG["channel_nums"][0], CFG["channel_nums"][1])
        self.UpConv_1 = UpConv(CFG["channel_nums"][1]*2, CFG["channel_nums"][2])
        self.UpConv_2 = UpConv(CFG["channel_nums"][2]*2, CFG["channel_nums"][3])
        self.UpConv_3 = UpConv(CFG["channel_nums"][3]*2, CFG["channel_nums"][4])
        self.UpConv_4 = UpConv(CFG["channel_nums"][4]*2, CFG["channel_nums"][4])
    
    def forward(self, skip_connection_list):
        emb = self.UpConv_0(skip_connection_list[4]) # emb.shape = (None, 160, 14, 14)
        emb_cat = torch.cat([skip_connection_list[3], emb], dim = 1)
        
        emb = self.UpConv_1(emb_cat)
        emb_cat = torch.cat([skip_connection_list[2], emb], dim = 1)
        
        emb = self.UpConv_2(emb_cat)
        emb_cat = torch.cat([skip_connection_list[1], emb], dim = 1)
        
        emb = self.UpConv_3(emb_cat)
        emb_cat = torch.cat([skip_connection_list[0], emb], dim = 1)

        emb_cat = self.UpConv_4(emb_cat)
        
        return emb_cat

class SegModel(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = Encoder(CFG)
        self.decoder = Decoder()
        self.head = nn.Sequential(
            nn.Conv2d(CFG["channel_nums"][-1], CFG["out_channels"], kernel_size=1, stride=1, padding=0),
            nn.Sigmoid()
        )
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        emb = self.decoder(skip_connection_list)
        output = self.head(emb)
        return output

# %% [markdown]
# # Dataset

# %%
train_transforms = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.RandomCrop(int(CFG["img_size"][0]*0.8), int(CFG["img_size"][1]*0.8), p=0.5),
    A.Blur(blur_limit=3, p=0.3),
    A.Resize(CFG["img_size"][0], CFG["img_size"][1]),
    ToTensorV2(),
])

valid_transforms = A.Compose([
    ToTensorV2(),
])

# %%
def fft_transform(img):
    eps = 1e-7
    f = np.fft.fft2(img)
    fshift = np.fft.fftshift(f)
    fshift = np.nan_to_num(fshift)+eps#nanを0埋め
    magnitude_spectrum = 20*np.log(np.abs(fshift))
    return magnitude_spectrum

def highpass_filter(img):
    frange = 1
    dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
    dft_shift = np.fft.fftshift(dft)

    rows, cols = img.shape
    crow,ccol = rows//2 , cols//2

    # create a mask first, center square is 1, remaining all zeros
    mask = np.ones((rows,cols,2),np.uint8)
    mask[crow-frange:crow+frange, ccol-frange:ccol+frange] = 0

    # apply mask and inverse DFT
    fshift = dft_shift*mask
    f_ishift = np.fft.ifftshift(fshift)
    img_back = cv2.idft(f_ishift)
    img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

    return img_back

def lowpass_filter(img):
    frange = 5
    dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
    dft_shift = np.fft.fftshift(dft)

    rows, cols = img.shape
    crow,ccol = rows//2 , cols//2

    # create a mask first, center square is 1, remaining all zeros
    mask = np.zeros((rows,cols,2),np.uint8)
    mask[crow-frange:crow+frange, ccol-frange:ccol+frange] = 1

    # apply mask and inverse DFT
    fshift = dft_shift*mask
    f_ishift = np.fft.ifftshift(fshift)
    img_back = cv2.idft(f_ishift)
    img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

    return img_back

# %%
class VCID_Dataset(Dataset):
    def __init__(self, CFG, data_dir_list, surface_list, surface_volumes=None, slide_pos=[0,0], mode="train", transform=None):
        # get config
        self.mode = mode
        self.img_size = CFG["img_size"]
        if self.mode=="train":  self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode=="valid":    self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode == "test":   self.DATADIR = CFG["TEST_DIR"]
        self.data_dir_list = data_dir_list
        self.surface_list = surface_list
        self.slide_pos = slide_pos
        self.transform = transform
        
        # get imgs
        # print("initializing dataset...")
        self.imgs = []
        for data_dir in self.data_dir_list:
            img_path = os.path.join(self.DATADIR, data_dir, "mask.png")
            # print(img_path)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            img = img.reshape(img.shape[0], img.shape[1], 1) # (h, w, channel=1)
            self.imgs.append(img)
        
        # check imgs
        for img in self.imgs:
            assert img is not None, "img is None. data path is wrong"
        # get and split surface
        if surface_volumes is None:
            self.surface_vols = self.read_surfacevols()
        else:
            # print("using loaded surface_vols")
            self.surface_vols = surface_volumes
        for surface_vol in self.surface_vols:
            assert surface_vol is not None, "surface_vol is None. data path is wrong"
       
        # split grid
        self.get_all_grid()
        self.fileter_grid()
        self.get_flatten_grid()
        # print("split grid done.") 
       
        # get label imgs
        if self.mode == "train" or self.mode == "valid":
            self.labels = []
            for data_dir in self.data_dir_list:
                label_path = os.path.join(self.DATADIR, data_dir, "inklabels.png")
                assert os.path.exists(label_path), f"{label_path} is not exist."
                
                # read label
                label = cv2.imread(label_path, cv2.IMREAD_GRAYSCALE)
                # mask erosion
                kernel_size = (img.shape[0]+img.shape[1])//2//100
                kernel = np.ones((kernel_size, kernel_size), np.uint8)
                img = cv2.erode(img, kernel,iterations = 3)
                
                label = label.reshape(label.shape[0], label.shape[1], 1) # (h, w, channel=1)
                self.labels.append(label)# 画像サイズがそれぞれ違うので単純にconcatできずlist化しているs
        # print("initializing dataset done.")

    def get_surface_volumes(self):
        return self.surface_vols

    def read_surfacevols(self):
        """ read surface volume by data_dir_list and surface_list 
            Returns:surface_vuls (list): surface volume list [array(h,w,channel=surface_num), array(), ...]
        """
        surface_vols = []
        # print("reading surface volume...")
        for data_dir in self.data_dir_list:
            surface_vol_ = None
            for read_idx, surface_idx in enumerate(self.surface_list):
                # print("\r", f"reading idx : {read_idx+1}/{len(self.surface_list)}", end="")
                surface_path = os.path.join(self.DATADIR, data_dir, "surface_volume", f"{surface_idx:02}.tif")
                surface_vol = cv2.imread(surface_path, cv2.IMREAD_GRAYSCALE)
                surface_vol = surface_vol.reshape(surface_vol.shape[0], surface_vol.shape[1], 1) # (h, w, channel=1)
                if surface_vol_ is None:
                    surface_vol_ = surface_vol
                else:
                    surface_vol_ = np.concatenate([surface_vol_, surface_vol], axis=2) # (h, w, channel=surface_num)
            surface_vols.append(surface_vol_)
            # print(f"  => read surface volume done. [{data_dir}]")
        return surface_vols


    def get_grid_img(self, img, grid_idx):
        """ crop grid img from original img"""
        img_grid = img[grid_idx[0]*self.img_size[0] + self.slide_pos[0] : (grid_idx[0]+1)*self.img_size[0] + self.slide_pos[0],
                        grid_idx[1]*self.img_size[1] + self.slide_pos[1] : (grid_idx[1]+1)*self.img_size[1] + self.slide_pos[1]]
        return img_grid
    
    
    def get_masked_img(self, img, mask):
        """ multiply mask to surface_volumes """
        masked_img = None
        for channel in range(img.shape[2]):
            img_channel = img[:,:,channel].reshape(img.shape[0], img.shape[1],1)
            masked = img_channel*mask
            if masked_img is None:
                masked_img = masked.reshape(masked.shape[0], masked.shape[1], 1)
            else:
                masked = masked.reshape(masked.shape[0], masked.shape[1], 1)
                masked_img = np.concatenate([masked_img, masked], axis=2)
        return masked_img
    
    def get_grid_hpfimg(self, img, grid_idx):
        """ crop grid img from original img and hpf filter """
        img_grid = self.get_grid_img(img, grid_idx)
        img_transformed = None
        for channel in range(img_grid.shape[2]):
            img_grid_trans = highpass_filter(img_grid[:,:,channel])
            if img_transformed is None:
                img_transformed = img_grid_trans.reshape(img_grid_trans.shape[0], img_grid_trans.shape[1], 1)
            else:
                img_transformed = np.concatenate([img_transformed, img_grid_trans.reshape(img_grid_trans.shape[0], img_grid_trans.shape[1], 1)], axis=2)
        return img_transformed
    
    def get_all_grid(self):
        """ get all grid indices by img size and grid size
        """
        self.grid_indices = []
        for img in self.imgs:
            self.x_grid_size = (img.shape[0] - self.slide_pos[0]) // self.img_size[0]
            self.y_grid_size = (img.shape[1] - self.slide_pos[1]) // self.img_size[1]
            grid_img = []
            for i in range(self.x_grid_size):
                for j in range(self.y_grid_size):
                    grid_img.append([i, j])
            self.grid_indices.append(grid_img)
        return self.grid_indices
          
    def fileter_grid(self):
        """ get grid indices which mask is not 0 by all grid indices"""
        grid_indices_all = []
        for img, grid_indices in zip(self.imgs, self.grid_indices):
            grid_indices_copy = grid_indices.copy()
            for grid_idx in grid_indices:
                img_grid = self.get_grid_img(img, grid_idx)
                if img_grid.sum() == 0:
                    grid_indices_copy.remove(grid_idx)
            grid_indices_all.append(grid_indices_copy)
        self.grid_indices = grid_indices_all
        return self.grid_indices

    def get_flatten_grid(self):
        """ get flatten index list by grid indices
            Returns:flatten_grid (list): flatten index list [[img_idx, grid_idx], [img_idx, grid_idx], ...]
        """
        flatten_grid = []
        for img_idx, grid_indices in enumerate(self.grid_indices):
            for grid_idx in grid_indices:
                grid_imgidx_list = [img_idx]
                grid_imgidx_list.extend(grid_idx)
                flatten_grid.append(grid_imgidx_list)
        self.flatten_grid = flatten_grid
        return self.flatten_grid

    def __len__(self):
        return len(self.flatten_grid)

    def __getitem__(self, idx):
        # get indices
        img_grid_idx = self.flatten_grid[idx]
        img_idx = img_grid_idx[0]
        grid_idx = img_grid_idx[1:]
        # get img & surface_vol
        img = self.imgs[img_idx]
        surface_vol = self.surface_vols[img_idx]
        img = self.get_grid_img(img, grid_idx)/255.
        surface_vol = self.get_grid_img(surface_vol, grid_idx)/255.
        
        # multiple small mask 
        surface_vol = self.get_masked_img(surface_vol, img)
        assert surface_vol.shape[0]==img.shape[0] and surface_vol.shape[1]==img.shape[1] , "surface_vol_list shape is not same as img shape"
        img = surface_vol

        # transform
        if self.mode == "test":
            if self.transform:
                img = self.transform(image=img)["image"]
            else:
                img = img.transpose(2, 0, 1)
                img = torch.tensor(img, dtype=torch.float32)
            return img, grid_idx
        elif self.mode == "train" or self.mode=="valid":
            # get label(segmentation mask)
            label = self.labels[img_idx]
            label = self.get_grid_img(label, grid_idx)
            if self.transform:
                transformed = self.transform(image=img, mask=label)
                img = transformed["image"]
                label = transformed["mask"]
                label = label.permute(2, 0, 1)/255. # (channel, h, w)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            else:
                img = img.transpose(2, 0, 1) # (channel, h, w)
                label = label.transpose(2, 0, 1)/255. # (channel, h, w){}
                img = torch.tensor(img, dtype=torch.float32)
                label = torch.tensor(label, dtype=torch.float32)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            return img, label, grid_idx

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train")
# surface_volumes = dataset_notrans.surface_vols
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 1:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos=[0,50],mode="train")
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 1:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train", transform=train_transforms)
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)


# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 0:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %% [markdown]
# # train valid fn

# %%
def train_fn(train_loader, model, criterion, epoch ,optimizer, scheduler):
    model.train()
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, _) in enumerate(train_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()     
        preds = model(images)
        
        # preds = torch.sigmoid(preds)
        loss = criterion(preds, targets)
        
        losses.update(loss.item(), CFG["batch_size"]) 
        targets = targets.detach().cpu().numpy().ravel().tolist()
        preds = preds.detach().cpu().numpy().ravel().tolist()
        loss.backward() # パラメータの勾配を計算
        optimizer.step() # モデル更新
        optimizer.zero_grad() # 勾配の初期化
                
        batch_time.update(time.time() - end)
        end = time.time()
        if batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(train_loader)-1):
            print('Epoch: [{0}][{1}/{2}] '
                    'Elapsed {remain:s} '
                    'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                    .format(
                        epoch, batch_idx, len(train_loader), batch_time=batch_time, loss=losses,
                        remain=timeSince(start, float(batch_idx+1)/len(train_loader)),
            ))
        del preds, images, targets
    gc.collect()
    torch.cuda.empty_cache()
    return losses.avg

# %%
def valid_fn(model, valid_loader, criterion=None):
    model.eval()# モデルを検証モードに設定
    test_targets = []
    test_preds = []
    test_grid_idx = []
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, grid_idx) in enumerate(valid_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()
        with torch.no_grad():
            preds = model(images)
            if not criterion is None:
                loss = criterion(preds, targets)
        if not criterion is None:
            losses.update(loss.item(), CFG["batch_size"])
        batch_time.update(time.time() - end)

        targets = targets.detach().cpu().numpy()
        preds = preds.detach().cpu().numpy()
        
        test_preds.extend([preds[idx, :,:,:].transpose(1,2,0) for idx in range(preds.shape[0])])
        test_targets.extend([targets[idx, :,:,:].transpose(1,2,0) for idx in range(targets.shape[0])])
        test_grid_idx.extend([[x_idx, y_idx] for x_idx, y_idx in zip(grid_idx[0].tolist(), grid_idx[1].tolist())])

        if (batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(valid_loader)-1)) and (not criterion is None):
            print('EVAL: [{0}/{1}] '
                'Elapsed {remain:s} '
                'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                .format(
                    batch_idx, len(valid_loader), batch_time=batch_time, loss=losses,
                    remain=timeSince(start, float(batch_idx+1)/len(valid_loader)),
                ))
        del preds, images, targets
        gc.collect()
        torch.cuda.empty_cache()
    if criterion is None:
        return test_targets, test_preds, test_grid_idx
    else:
        return test_targets, test_preds, test_grid_idx, losses.avg

# %% [markdown]
# # training loop

# %%
# def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list):
#     # concat pred img and label to original size
#     img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
#     img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
#     img = img.reshape(img.shape[0], img.shape[1], 1)
#     pred_img = np.zeros_like(img).astype(np.float32)
#     label_img = np.zeros_like(img).astype(np.float32)
#     for img_idx, grid_idx in enumerate(grid_idx_list):
#         pred_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += img_list[img_idx]
        
#         label_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += label_list[img_idx]
#     return pred_img, label_img

# %%
def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list, slide_pos=[0,0]):
    # concat pred img and label to original size
    img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    img = img.reshape(img.shape[0], img.shape[1], 1)
    pred_img = np.zeros_like(img).astype(np.float32)
    label_img = np.zeros_like(img).astype(np.float32)
    for img_idx, grid_idx in enumerate(grid_idx_list):
        pred_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += img_list[img_idx]
        
        label_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += label_list[img_idx]
    return pred_img, label_img

# %%
def save_and_plot_oof(mode, fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary):
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_pred_img.png"), valid_preds_img*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_predbin_img.png"), valid_preds_binary*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_targets_img.png"), valid_targets_img*255)
    
    # plot preds & binary preds
    # plt.figure(dpi=100)
    # plt.subplot(1,3,1)
    # plt.imshow(valid_preds_img)
    # plt.subplot(1,3,2)
    # plt.imshow(valid_preds_binary)
    # plt.subplot(1,3,3)
    # plt.imshow(valid_targets_img)
    # plt.show()

# %%
def training_loop(CFG):
    best_score_list = []
    best_threshold_list = []
    best_epoch_list = []
    slice_ave_score_list = []
    slice_ave_auc_list = []
    slice_ave_score_threshold_list = []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} training start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        model = model.to(device)
        valid_img_slice = []
        criterion = nn.BCELoss()
        optimizer = AdamW(model.parameters(), lr=CFG["lr"], weight_decay=CFG["weight_decay"], amsgrad=False)
        scheduler = CosineAnnealingLR(optimizer, T_max=CFG["T_max"], eta_min=CFG["min_lr"], last_epoch=-1)
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            # separate train/valid data 
            train_dirs = CFG["TRAIN_DIR_LIST"][fold]
            valid_dirs = CFG["VALID_DIR_LIST"][fold]
            train_dataset = VCID_Dataset(CFG, train_dirs, surface_list, mode="train", transform=train_transforms)
            valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, mode="valid", transform=valid_transforms)
            train_loader = DataLoader(train_dataset, batch_size=CFG["batch_size"], shuffle = True,
                                        num_workers = CFG["num_workers"], pin_memory = True)
            valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                        num_workers = CFG["num_workers"], pin_memory = True)

            # training
            best_score = -np.inf
            best_auc = -np.inf
            best_valloss = np.inf
            best_auc_valloss = np.inf
            best_threshold = -1
            start_time = time.time()
            best_epoch = -1
            best_auc_epoch = -1
            for epoch in range(1, CFG["n_epoch"] + 1):
                print(f'- epoch:{epoch} -')
                train_loss_avg = train_fn(train_loader, model, criterion, epoch ,optimizer, scheduler)
                valid_targets, valid_preds, valid_grid_idx, valid_loss_avg = valid_fn(model, valid_loader, criterion)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                
                elapsed = time.time() - start_time
                print(f"\t epoch:{epoch}, avg train loss:{train_loss_avg:.4f}, avg valid loss:{valid_loss_avg:.4f}")
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                if not CFG["DEBUG"]:
                    logging_metrics_epoch(CFG, fold, epoch, slice_idx, train_loss_avg, valid_loss_avg, valid_score, valid_threshold, auc)
                scheduler.step()
                # validationスコアがbestを更新したらモデルを保存する
                if valid_score > best_score:
                    best_epoch = epoch + slice_idx*CFG["n_epoch"]
                    best_valloss = valid_loss_avg
                    best_score = valid_score
                    best_threshold = valid_threshold
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epoch} - Save Best Score: {best_score:.4f}. Model is saved.')
                    print("dice_list: ", dice_list)
                    # save oof
                    save_and_plot_oof("score", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
                
                if auc > best_auc:
                    best_auc = auc
                    best_auc_epoch = epoch + slice_idx*CFG["n_epoch"]
                    best_auc_valloss = valid_loss_avg
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_auc_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epoch} - Save Best AUC: {best_auc:.4f}. Model is saved.')
                    # save oof
                    save_and_plot_oof("auc", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
            valid_img_slice.append(valid_preds_img)
        valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        for idx in range(len(SURFACE_LIST)):
            valid_pred_slice = valid_img_slice[idx]
            valid_slice_ave += valid_pred_slice
        valid_slice_ave /= len(CFG["folds"])
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_slice_ave)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)
 
        valid_slice_binary = (valid_slice_ave > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 999, valid_slice_ave, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
        
        print(f'[fold{fold}] BEST Epoch {best_epoch} - Save Best Score:{best_score:.4f}. Best loss:{best_valloss:.4f}')
        print(f'[fold{fold}] BEST AUC Epoch {best_auc_epoch} - Save Best Score:{best_auc:.4f}. Best loss:{best_auc_valloss:.4f}')
            
        best_score_list.append(best_score)
        best_threshold_list.append(best_threshold)
        best_epoch_list.append(best_epoch)
        del model, train_loader, train_dataset, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        # gc.collect()
        # torch.cuda.empty_cache()
        
    for fold, (best_score, best_threshold, best_epoch) in enumerate(zip(best_score_list, best_threshold_list, best_epoch_list)):
        print(f"fold[{fold}] BEST SCORE = {best_score:.4f} thr={best_threshold} (epoch={best_epoch})")
        print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    return best_score_list, best_threshold_list, best_epoch_list

# %% [markdown]
# # slice inference

# %%
def slide_inference(CFG):
    start_time = time.time()
    slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list = [], [], []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} slide inference start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        # model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_fold{fold}.pth')
        model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_auc_fold{fold}.pth')
        model.load_state_dict(torch.load(model_path))
        model = model.to(device)
        valid_img_slice = []
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            surface_volumes = None
            for slide_pos in CFG["slide_pos_list"]:
                print("slide pos:", slide_pos)
                valid_dirs = CFG["VALID_DIR_LIST"][fold]
                valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos, mode="valid", transform=valid_transforms)
                surface_volumes = valid_dataset.get_surface_volumes()
                valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                            num_workers = CFG["num_workers"], pin_memory = True)

                valid_targets, valid_preds, valid_grid_idx = valid_fn(model, valid_loader)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs, slide_pos)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                save_and_plot_oof("slide", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary) 
                
                elapsed = time.time() - start_time
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                valid_img_slice.append(valid_preds_img)
            valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        for idx in range(len(SURFACE_LIST)*len(CFG["slide_pos_list"])):
            valid_pred_slice = valid_img_slice[idx]
            valid_slice_ave += valid_pred_slice
        valid_slice_ave /= len(SURFACE_LIST)*len(CFG["slide_pos_list"])
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_slice_ave)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)

        valid_slice_binary = (valid_slice_ave > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 555, valid_slice_ave, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
         
        del model, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
    return slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list

# %% [markdown]
# # main

# %%
# %%time
best_score_list, best_threshold_list, best_epoch_list = training_loop(CFG)
# Out:
# -- fold0 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/conv.py:444: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at  ../aten/src/ATen/native/Convolution.cpp:744.)
#   self.padding, self.dilation, self.groups)
# Epoch: [1][0/130] Elapsed 0m 0s (remain 2m 4s) Loss: 0.7242(0.7242)
# Epoch: [1][129/130] Elapsed 0m 37s (remain 0m 0s) Loss: 0.2660(0.4830)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.2003(0.2003)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2862(0.3936)
# 	 epoch:1, avg train loss:0.4830, avg valid loss:0.3936
# 	 score:0.2513(th=0.450000), auc=0.778604::: time:54.03s
# Epoch 1 - Save Best Score: 0.2513. Model is saved.
# dice_list:  [0.16979264240864297, 0.18946133684104294, 0.2054010436234242, 0.21724331765570856, 0.22785026946986803, 0.23821723756600582, 0.24775464158939414, 0.2512865231514835, 0.24453976220487486, 0.22306909504879482, 0.1859697195052523, 0.14005430797230967, 0.08858762464313273, 0.04349005996791652, 0.015934247663286612, 0.004976636432185305, 0.0011116217398416841, 3.152345469626642e-06, 0.0]
# Epoch 1 - Save Best AUC: 0.7786. Model is saved.
# - epoch:2 -
# Epoch: [2][0/130] Elapsed 0m 0s (remain 1m 50s) Loss: 0.4604(0.4604)
# Epoch: [2][129/130] Elapsed 0m 37s (remain 0m 0s) Loss: 0.8913(0.4181)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 1.0228(1.0228)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5810(0.9418)
# 	 epoch:2, avg train loss:0.4181, avg valid loss:0.9418
# 	 score:0.1865(th=0.150000), auc=0.762300::: time:111.28s
# - epoch:3 -
# Epoch: [3][0/130] Elapsed 0m 0s (remain 1m 45s) Loss: 0.3382(0.3382)
# Epoch: [3][129/130] Elapsed 0m 37s (remain 0m 0s) Loss: 0.2407(0.4137)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.0819(0.0819)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3297(0.3400)
# 	 epoch:3, avg train loss:0.4137, avg valid loss:0.3400
# 	 score:0.2102(th=0.150000), auc=0.757163::: time:165.04s
# - epoch:4 -
# Epoch: [4][0/130] Elapsed 0m 0s (remain 1m 49s) Loss: 0.5685(0.5685)
# Epoch: [4][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.1578(0.4074)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1581(0.1581)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2804(0.3245)
# 	 epoch:4, avg train loss:0.4074, avg valid loss:0.3245
# 	 score:0.2655(th=0.300000), auc=0.813199::: time:218.12s
# Epoch 4 - Save Best Score: 0.2655. Model is saved.
# dice_list:  [0.20724380332370845, 0.2423439556502781, 0.2566994926442211, 0.2622676650171433, 0.26546792508146927, 0.2643580082547333, 0.25587656993861485, 0.24489528780209924, 0.2303833164103479, 0.21131392584850292, 0.18913673253851124, 0.16426545323117456, 0.13177932343023077, 0.09904675879537718, 0.06262657308663508, 0.03406213249408744, 0.019087678494257663, 0.006046486358584618, 0.0]
# Epoch 4 - Save Best AUC: 0.8132. Model is saved.
# - epoch:5 -
# Epoch: [5][0/130] Elapsed 0m 0s (remain 1m 44s) Loss: 0.2800(0.2800)
# Epoch: [5][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.5698(0.3944)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1562(0.1562)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2498(0.3095)
# 	 epoch:5, avg train loss:0.3944, avg valid loss:0.3095
# 	 score:0.3440(th=0.300000), auc=0.837366::: time:274.78s
# Epoch 5 - Save Best Score: 0.3440. Model is saved.
# dice_list:  [0.22227078039898893, 0.27603150990833, 0.3117525151024414, 0.33301737588701386, 0.3440037822272127, 0.34399891764798074, 0.33786546596290407, 0.3281517621195508, 0.31368141278849665, 0.2889839273217808, 0.2613811464195445, 0.2307915647299765, 0.1954483104942008, 0.15860465144571526, 0.1255427550555028, 0.09031058911079375, 0.04715861907660094, 0.021010464063220224, 0.0]
# Epoch 5 - Save Best AUC: 0.8374. Model is saved.
# - epoch:6 -
# Epoch: [6][0/130] Elapsed 0m 0s (remain 1m 57s) Loss: 0.4265(0.4265)
# Epoch: [6][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2667(0.3868)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1966(0.1966)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2446(0.3184)
# 	 epoch:6, avg train loss:0.3868, avg valid loss:0.3184
# 	 score:0.3386(th=0.400000), auc=0.834093::: time:330.22s
# - epoch:7 -
# Epoch: [7][0/130] Elapsed 0m 0s (remain 1m 44s) Loss: 0.6151(0.6151)
# Epoch: [7][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2056(0.3861)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1392(0.1392)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2476(0.3036)
# 	 epoch:7, avg train loss:0.3861, avg valid loss:0.3036
# 	 score:0.4069(th=0.350000), auc=0.856663::: time:382.41s
# Epoch 7 - Save Best Score: 0.4069. Model is saved.
# dice_list:  [0.18670858129130055, 0.2514109275706774, 0.31234615001573407, 0.3626397752193968, 0.4029398740723663, 0.4068802471635704, 0.35695423832701556, 0.2715396876591433, 0.1775899029361267, 0.09582369972335908, 0.0446938724801546, 0.02255736041033969, 0.015806910828369825, 0.007435822740538052, 0.0008869463640206171, 0.0, 0.0, 0.0, 0.0]
# Epoch 7 - Save Best AUC: 0.8567. Model is saved.
# - epoch:8 -
# Epoch: [8][0/130] Elapsed 0m 0s (remain 1m 59s) Loss: 0.3834(0.3834)
# Epoch: [8][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2300(0.3877)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1729(0.1729)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2602(0.3186)
# 	 epoch:8, avg train loss:0.3877, avg valid loss:0.3186
# 	 score:0.3328(th=0.400000), auc=0.824908::: time:438.17s
# - epoch:9 -
# Epoch: [9][0/130] Elapsed 0m 0s (remain 1m 45s) Loss: 0.3732(0.3732)
# Epoch: [9][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2630(0.3973)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0988(0.0988)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2779(0.3301)
# 	 epoch:9, avg train loss:0.3973, avg valid loss:0.3301
# 	 score:0.2496(th=0.200000), auc=0.797219::: time:490.38s
# - epoch:10 -
# Epoch: [10][0/130] Elapsed 0m 0s (remain 2m 4s) Loss: 0.5130(0.5130)
# Epoch: [10][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.1660(0.4229)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1075(0.1075)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2837(0.3204)
# 	 epoch:10, avg train loss:0.4229, avg valid loss:0.3204
# 	 score:0.2869(th=0.200000), auc=0.805021::: time:543.15s
# surface_list:  range(27, 37, 3)
# - epoch:1 -
# Epoch: [1][0/130] Elapsed 0m 0s (remain 2m 2s) Loss: 0.3537(0.3537)
# Epoch: [1][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.3728(0.4074)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1706(0.1706)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2715(0.3360)
# 	 epoch:1, avg train loss:0.4074, avg valid loss:0.3360
# 	 score:0.2927(th=0.350000), auc=0.819182::: time:52.48s
# Epoch 1 - Save Best Score: 0.2927. Model is saved.
# dice_list:  [0.16603703693954813, 0.18985276308172244, 0.22126900708570313, 0.2542134648675639, 0.28724084177369197, 0.2927488926537956, 0.24113352296381343, 0.14788836730942748, 0.07510680344608432, 0.03214662181190558, 0.012741398097314624, 0.004859922514286191, 0.0018606631785662998, 0.00044756904267591937, 0.00011665098708503273, 0.0, 0.0, 0.0, 0.0]
# Epoch 1 - Save Best AUC: 0.8192. Model is saved.
# - epoch:2 -
# Epoch: [2][0/130] Elapsed 0m 0s (remain 2m 8s) Loss: 0.4672(0.4672)
# Epoch: [2][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.4972(0.3980)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1362(0.1362)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2741(0.3082)
# 	 epoch:2, avg train loss:0.3980, avg valid loss:0.3082
# 	 score:0.3722(th=0.350000), auc=0.827696::: time:107.69s
# Epoch 2 - Save Best Score: 0.3722. Model is saved.
# dice_list:  [0.21578003947071084, 0.27732838159319173, 0.32144043295933444, 0.3482997251689893, 0.3664016240480295, 0.37217269206045506, 0.3656312098565473, 0.3491204229899695, 0.31891051517087043, 0.27354953038879243, 0.21426311434188924, 0.1554281288014646, 0.10125547890424808, 0.06231879558546349, 0.034663704021641095, 0.019965275365345776, 0.011901751820384282, 0.002294199553152442, 0.0]
# Epoch 2 - Save Best AUC: 0.8277. Model is saved.
# - epoch:3 -
# Epoch: [3][0/130] Elapsed 0m 0s (remain 1m 50s) Loss: 0.3444(0.3444)
# Epoch: [3][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.5833(0.3942)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1601(0.1601)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2601(0.3168)
# 	 epoch:3, avg train loss:0.3942, avg valid loss:0.3168
# 	 score:0.3321(th=0.350000), auc=0.820034::: time:164.22s
# - epoch:4 -
# Epoch: [4][0/130] Elapsed 0m 0s (remain 1m 54s) Loss: 0.3122(0.3122)
# Epoch: [4][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2258(0.3801)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1322(0.1322)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2333(0.2917)
# 	 epoch:4, avg train loss:0.3801, avg valid loss:0.2917
# 	 score:0.4316(th=0.400000), auc=0.865289::: time:216.35s
# Epoch 4 - Save Best Score: 0.4316. Model is saved.
# dice_list:  [0.22291689888700747, 0.29103511655715797, 0.3385838038229102, 0.37370303447150655, 0.4003630206833527, 0.4246511423307384, 0.43155771392569, 0.4157370670174984, 0.3767920218432778, 0.31509029666442046, 0.24466881028484794, 0.1705033326154838, 0.09908855254886327, 0.05241483753168877, 0.026852642982680475, 0.011917106375805854, 0.00043023958871627626, 0.0, 0.0]
# Epoch 4 - Save Best AUC: 0.8653. Model is saved.
# - epoch:5 -
# Epoch: [5][0/130] Elapsed 0m 0s (remain 2m 4s) Loss: 0.3275(0.3275)
# Epoch: [5][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.4149(0.3620)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.2188(0.2188)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2185(0.3212)
# 	 epoch:5, avg train loss:0.3620, avg valid loss:0.3212
# 	 score:0.4517(th=0.600000), auc=0.862980::: time:271.21s
# Epoch 5 - Save Best Score: 0.4517. Model is saved.
# dice_list:  [0.20550168347393502, 0.2471023211105111, 0.28032393020945584, 0.3050328070937826, 0.3289228171197862, 0.3534353084594261, 0.3760509850602424, 0.40084046691197756, 0.42291171456317506, 0.4423555064022687, 0.4517057671701594, 0.44390449372597396, 0.4219756204677965, 0.3884467341527246, 0.330677472591456, 0.24235841997918361, 0.14206744444013325, 0.05895854792851273, 0.0]
# - epoch:6 -
# Epoch: [6][0/130] Elapsed 0m 0s (remain 2m 1s) Loss: 0.4223(0.4223)
# Epoch: [6][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 1.2884(0.3737)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1409(0.1409)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2080(0.2926)
# 	 epoch:6, avg train loss:0.3737, avg valid loss:0.2926
# 	 score:0.4618(th=0.500000), auc=0.863027::: time:325.70s
# Epoch 6 - Save Best Score: 0.4618. Model is saved.
# dice_list:  [0.24484160139963013, 0.2944033370735574, 0.33000765463029824, 0.36139374986841344, 0.3900937495127844, 0.4171753366332593, 0.4418870611620836, 0.45814650825434894, 0.4618355151726927, 0.45373554100929203, 0.43258143874045335, 0.4012114278954715, 0.3563926123873979, 0.30265972000225183, 0.23128287189958113, 0.16023546928292273, 0.09716802040508762, 0.038976024986915755, 0.0]
# - epoch:7 -
# Epoch: [7][0/130] Elapsed 0m 0s (remain 2m 3s) Loss: 0.3882(0.3882)
# Epoch: [7][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2332(0.3636)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1371(0.1371)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2146(0.2920)
# 	 epoch:7, avg train loss:0.3636, avg valid loss:0.2920
# 	 score:0.4547(th=0.500000), auc=0.868816::: time:379.38s
# Epoch 7 - Save Best AUC: 0.8688. Model is saved.
# - epoch:8 -
# Epoch: [8][0/130] Elapsed 0m 0s (remain 1m 50s) Loss: 0.3247(0.3247)
# Epoch: [8][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.4002(0.3736)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.2228(0.2228)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2226(0.3402)
# 	 epoch:8, avg train loss:0.3736, avg valid loss:0.3402
# 	 score:0.4441(th=0.650000), auc=0.869040::: time:433.30s
# Epoch 8 - Save Best AUC: 0.8690. Model is saved.
# - epoch:9 -
# Epoch: [9][0/130] Elapsed 0m 0s (remain 1m 56s) Loss: 0.2673(0.2673)
# Epoch: [9][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.1851(0.3782)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1498(0.1498)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2244(0.2935)
# 	 epoch:9, avg train loss:0.3782, avg valid loss:0.2935
# 	 score:0.4467(th=0.400000), auc=0.869858::: time:487.55s
# Epoch 9 - Save Best AUC: 0.8699. Model is saved.
# - epoch:10 -
# Epoch: [10][0/130] Elapsed 0m 0s (remain 2m 5s) Loss: 0.3039(0.3039)
# Epoch: [10][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.5315(0.3823)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0992(0.0992)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2524(0.2874)
# 	 epoch:10, avg train loss:0.3823, avg valid loss:0.2874
# 	 score:0.4470(th=0.300000), auc=0.858814::: time:541.55s
# surface_list:  range(25, 35, 3)
# - epoch:1 -
# Epoch: [1][0/130] Elapsed 0m 0s (remain 1m 57s) Loss: 0.3157(0.3157)
# Epoch: [1][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2880(0.3875)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1009(0.1009)
# EVAL: [26/27] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2193(0.2880)
# 	 epoch:1, avg train loss:0.3875, avg valid loss:0.2880
# 	 score:0.4361(th=0.300000), auc=0.861722::: time:53.01s
# Epoch 1 - Save Best Score: 0.4361. Model is saved.
# dice_list:  [0.2422457541805839, 0.3031663405537853, 0.361423567457301, 0.41061753382999444, 0.43605283316968335, 0.4320655721433669, 0.41871868722071975, 0.3799563380806204, 0.3345589554527097, 0.28644326044808816, 0.23300599392205007, 0.1852667496703649, 0.14106622746930014, 0.10158282950777842, 0.06487320277843715, 0.03623502225603078, 0.022263410167644496, 0.007764659117311186, 0.0]
# Epoch 1 - Save Best AUC: 0.8617. Model is saved.
# - epoch:2 -
# Epoch: [2][0/130] Elapsed 0m 0s (remain 1m 49s) Loss: 0.3651(0.3651)
# Epoch: [2][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2759(0.3789)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1308(0.1308)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2328(0.2920)
# 	 epoch:2, avg train loss:0.3789, avg valid loss:0.2920
# 	 score:0.4867(th=0.500000), auc=0.867143::: time:108.28s
# Epoch 2 - Save Best Score: 0.4867. Model is saved.
# dice_list:  [0.24371850761883834, 0.3002136308230227, 0.34263550683534166, 0.38145034190291166, 0.41541534700687827, 0.441806678991883, 0.4648241869839803, 0.4801815704531182, 0.4866792256858874, 0.4839353093782598, 0.473670363283136, 0.45253961646482554, 0.4180180449303543, 0.36933734940201624, 0.3068626752722877, 0.23092219402764425, 0.13895980569766783, 0.057404455680674954, 0.0]
# Epoch 2 - Save Best AUC: 0.8671. Model is saved.
# - epoch:3 -
# Epoch: [3][0/130] Elapsed 0m 0s (remain 1m 54s) Loss: 0.2063(0.2063)
# Epoch: [3][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.9602(0.3725)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.0826(0.0826)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2641(0.3080)
# 	 epoch:3, avg train loss:0.3725, avg valid loss:0.3080
# 	 score:0.4117(th=0.300000), auc=0.837523::: time:164.15s
# - epoch:4 -
# Epoch: [4][0/130] Elapsed 0m 0s (remain 1m 57s) Loss: 0.3503(0.3503)
# Epoch: [4][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.5157(0.3657)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0773(0.0773)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2084(0.2756)
# 	 epoch:4, avg train loss:0.3657, avg valid loss:0.2756
# 	 score:0.4909(th=0.350000), auc=0.875634::: time:216.56s
# Epoch 4 - Save Best Score: 0.4909. Model is saved.
# dice_list:  [0.29778349794436365, 0.368799686313315, 0.42250275151378086, 0.45944461525895613, 0.4812836976120731, 0.4909356604210148, 0.48887214711718047, 0.471310317029324, 0.44060841349171354, 0.39551165322427156, 0.34681855998605127, 0.28793572001101825, 0.22823374187923104, 0.17167899306161627, 0.11896438921385549, 0.06937111783990979, 0.03814696256125297, 0.013438202823051587, 0.0]
# Epoch 4 - Save Best AUC: 0.8756. Model is saved.
# - epoch:5 -
# Epoch: [5][0/130] Elapsed 0m 0s (remain 1m 51s) Loss: 0.3153(0.3153)
# Epoch: [5][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3891(0.3452)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1103(0.1103)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2003(0.2784)
# 	 epoch:5, avg train loss:0.3452, avg valid loss:0.2784
# 	 score:0.4922(th=0.500000), auc=0.882242::: time:272.92s
# Epoch 5 - Save Best Score: 0.4922. Model is saved.
# dice_list:  [0.2546121630708453, 0.310465806429543, 0.35611015562129883, 0.3911779624274533, 0.41859739582244, 0.4422087981118289, 0.4662311494139047, 0.4853215729997637, 0.4921544483621055, 0.49139960501372115, 0.47649356762899453, 0.4424944384755332, 0.39279030835892914, 0.3236064769702034, 0.2440156883389745, 0.16429167693555127, 0.08438222776815901, 0.03260321004928154, 0.0]
# Epoch 5 - Save Best AUC: 0.8822. Model is saved.
# - epoch:6 -
# Epoch: [6][0/130] Elapsed 0m 0s (remain 1m 53s) Loss: 0.3600(0.3600)
# Epoch: [6][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.4027(0.3498)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0995(0.0995)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1975(0.2759)
# 	 epoch:6, avg train loss:0.3498, avg valid loss:0.2759
# 	 score:0.4935(th=0.500000), auc=0.882132::: time:328.29s
# Epoch 6 - Save Best Score: 0.4935. Model is saved.
# dice_list:  [0.2725865128334897, 0.3273744952944081, 0.3683567480535283, 0.40277504870248454, 0.4283160416659624, 0.45184094653454354, 0.4753153734323892, 0.4905535999261952, 0.4934872287901597, 0.4933364672958483, 0.48124682791083684, 0.4528794340976216, 0.4099545386392689, 0.35150883559463914, 0.2765795785865596, 0.19599343288067825, 0.11299399065257888, 0.041536374882543005, 0.0]
# - epoch:7 -
# Epoch: [7][0/130] Elapsed 0m 0s (remain 2m 0s) Loss: 0.2900(0.2900)
# Epoch: [7][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3842(0.3467)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1071(0.1071)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2010(0.2777)
# 	 epoch:7, avg train loss:0.3467, avg valid loss:0.2777
# 	 score:0.4897(th=0.500000), auc=0.878153::: time:382.41s
# - epoch:8 -
# Epoch: [8][0/130] Elapsed 0m 0s (remain 2m 7s) Loss: 0.3094(0.3094)
# Epoch: [8][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.5376(0.3543)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1067(0.1067)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1825(0.2886)
# 	 epoch:8, avg train loss:0.3543, avg valid loss:0.2886
# 	 score:0.4560(th=0.500000), auc=0.870310::: time:435.18s
# - epoch:9 -
# Epoch: [9][0/130] Elapsed 0m 0s (remain 2m 8s) Loss: 0.2788(0.2788)
# Epoch: [9][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.3784(0.3592)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.0695(0.0695)
# EVAL: [26/27] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2248(0.2875)
# 	 epoch:9, avg train loss:0.3592, avg valid loss:0.2875
# 	 score:0.4588(th=0.350000), auc=0.862215::: time:488.42s
# - epoch:10 -
# Epoch: [10][0/130] Elapsed 0m 0s (remain 1m 57s) Loss: 0.4689(0.4689)
# Epoch: [10][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.4023(0.3707)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1156(0.1156)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2308(0.2843)
# 	 epoch:10, avg train loss:0.3707, avg valid loss:0.2843
# 	 score:0.4404(th=0.350000), auc=0.870761::: time:541.67s
# [fold0] slice ave score:0.4678(th=0.300000), auc=0.867496
# [fold0] BEST Epoch 6 - Save Best Score:0.4935. Best loss:0.2759
# [fold0] BEST AUC Epoch 5 - Save Best Score:0.8822. Best loss:0.2784
# -- fold1 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# Epoch: [1][0/58] Elapsed 0m 0s (remain 0m 48s) Loss: 0.7661(0.7661)
# Epoch: [1][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.4313(0.5441)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 27s) Loss: 0.0291(0.0291)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0308(0.4430)
# 	 epoch:1, avg train loss:0.5441, avg valid loss:0.4430
# 	 score:0.2679(th=0.150000), auc=0.745100::: time:84.23s
# Epoch 1 - Save Best Score: 0.2679. Model is saved.
# dice_list:  [0.2434702559354179, 0.2678515562821861, 0.25930143800619204, 0.21996377141216022, 0.16964495328023377, 0.12453496306641675, 0.08878949413387048, 0.062260530763731135, 0.04293165073784286, 0.028885981558110438, 0.01833091795891884, 0.011088050097372121, 0.006283877499487739, 0.003031617858827691, 0.0011563723195422426, 0.00025454249469231393, 7.075858888096986e-06, 0.0, 0.0]
# Epoch 1 - Save Best AUC: 0.7451. Model is saved.
# - epoch:2 -
# Epoch: [2][0/58] Elapsed 0m 0s (remain 0m 48s) Loss: 0.2859(0.2859)
# Epoch: [2][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.4048(0.3702)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 27s) Loss: 0.0103(0.0103)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0112(0.4621)
# 	 epoch:2, avg train loss:0.3702, avg valid loss:0.4621
# 	 score:0.3057(th=0.200000), auc=0.766192::: time:173.35s
# Epoch 2 - Save Best Score: 0.3057. Model is saved.
# dice_list:  [0.2661073607684401, 0.29212456312683555, 0.30565804766204524, 0.30440365912803924, 0.29370619228816064, 0.2772354379971586, 0.25797746259227305, 0.23789476021630968, 0.21737956702741038, 0.19544589037822419, 0.17267041209935483, 0.14940247141649096, 0.12624195188784626, 0.10306652181156335, 0.07957855361408041, 0.056684163178800664, 0.034115468100864604, 0.01334127717815893, 0.0]
# Epoch 2 - Save Best AUC: 0.7662. Model is saved.
# - epoch:3 -
# Epoch: [3][0/58] Elapsed 0m 0s (remain 0m 53s) Loss: 0.3356(0.3356)
# Epoch: [3][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.4435(0.3532)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0180(0.0180)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0200(0.4837)
# 	 epoch:3, avg train loss:0.3532, avg valid loss:0.4837
# 	 score:0.3106(th=0.150000), auc=0.756763::: time:262.64s
# Epoch 3 - Save Best Score: 0.3106. Model is saved.
# dice_list:  [0.2940485223463946, 0.31064313695820284, 0.30169796458581355, 0.27338199958064896, 0.23915462551974287, 0.20528796380767872, 0.174825309444161, 0.1472267106773355, 0.12181847704892036, 0.09908158800946723, 0.07843628258082908, 0.06072407781913741, 0.044903514294666276, 0.030402858278738624, 0.018248306947599283, 0.009179433515078855, 0.0028152467374500307, 0.0002286436756380769, 0.0]
# - epoch:4 -
# Epoch: [4][0/58] Elapsed 0m 0s (remain 0m 54s) Loss: 0.1775(0.1775)
# Epoch: [4][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.3031(0.3375)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0062(0.0062)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0063(0.4593)
# 	 epoch:4, avg train loss:0.3375, avg valid loss:0.4593
# 	 score:0.3432(th=0.200000), auc=0.775302::: time:347.79s
# Epoch 4 - Save Best Score: 0.3432. Model is saved.
# dice_list:  [0.2983435186868684, 0.33471751984385967, 0.3432165666723394, 0.32852024484874814, 0.2915483449970177, 0.2410875363538224, 0.18929758473379696, 0.14278780597130955, 0.10638159163517553, 0.07962384518171926, 0.059419764666726396, 0.0439690923158116, 0.03088077190331443, 0.020183419282828872, 0.012930845054105187, 0.007324161261501458, 0.0030027770128527574, 0.0005403202354602194, 0.0]
# Epoch 4 - Save Best AUC: 0.7753. Model is saved.
# - epoch:5 -
# Epoch: [5][0/58] Elapsed 0m 0s (remain 0m 54s) Loss: 0.3722(0.3722)
# Epoch: [5][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.2185(0.3200)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0079(0.0079)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0099(0.4650)
# 	 epoch:5, avg train loss:0.3200, avg valid loss:0.4650
# 	 score:0.3729(th=0.200000), auc=0.780515::: time:434.96s
# Epoch 5 - Save Best Score: 0.3729. Model is saved.
# dice_list:  [0.32027762103636975, 0.3671271058163278, 0.3728517324998469, 0.34550610529998715, 0.30348067047470784, 0.2572368816999362, 0.2125765998843107, 0.1693080342471726, 0.13005420938023898, 0.09694923194844991, 0.06895031460446963, 0.046473394213721465, 0.030067034168565647, 0.019122220194292938, 0.012286799006237942, 0.006655181503553354, 0.0028105789598650726, 0.0, 0.0]
# Epoch 5 - Save Best AUC: 0.7805. Model is saved.
# - epoch:6 -
# Epoch: [6][0/58] Elapsed 0m 0s (remain 0m 49s) Loss: 0.3415(0.3415)
# Epoch: [6][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.4901(0.3128)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.0062(0.0062)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0064(0.4874)
# 	 epoch:6, avg train loss:0.3128, avg valid loss:0.4874
# 	 score:0.3695(th=0.150000), auc=0.778941::: time:523.52s
# - epoch:7 -
# Epoch: [7][0/58] Elapsed 0m 0s (remain 0m 56s) Loss: 0.3116(0.3116)
# Epoch: [7][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.1796(0.3059)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0143(0.0143)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0118(0.4442)
# 	 epoch:7, avg train loss:0.3059, avg valid loss:0.4442
# 	 score:0.3636(th=0.250000), auc=0.782790::: time:605.73s
# Epoch 7 - Save Best AUC: 0.7828. Model is saved.
# - epoch:8 -
# Epoch: [8][0/58] Elapsed 0m 0s (remain 0m 50s) Loss: 0.2318(0.2318)
# Epoch: [8][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2213(0.3129)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0137(0.0137)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0230(0.4537)
# 	 epoch:8, avg train loss:0.3129, avg valid loss:0.4537
# 	 score:0.3875(th=0.200000), auc=0.785540::: time:691.48s
# Epoch 8 - Save Best Score: 0.3875. Model is saved.
# dice_list:  [0.3417850729362878, 0.37980009878774673, 0.3874763687234711, 0.3829676836594107, 0.36966508665175063, 0.3512978458645725, 0.33185298555799236, 0.31247337033820566, 0.29145338736708976, 0.2694312883314686, 0.24740281913177367, 0.22642572911632622, 0.20551199201436823, 0.1825225969957649, 0.1584746378511953, 0.13191042288524135, 0.10339008606395626, 0.07087369182019994, 0.0]
# Epoch 8 - Save Best AUC: 0.7855. Model is saved.
# - epoch:9 -
# Epoch: [9][0/58] Elapsed 0m 0s (remain 0m 50s) Loss: 0.2328(0.2328)
# Epoch: [9][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2352(0.3285)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.0139(0.0139)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0121(0.4373)
# 	 epoch:9, avg train loss:0.3285, avg valid loss:0.4373
# 	 score:0.3697(th=0.250000), auc=0.788765::: time:778.19s
# Epoch 9 - Save Best AUC: 0.7888. Model is saved.
# - epoch:10 -
# Epoch: [10][0/58] Elapsed 0m 0s (remain 0m 53s) Loss: 0.4153(0.4153)
# Epoch: [10][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2776(0.3297)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0152(0.0152)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0139(0.4625)
# 	 epoch:10, avg train loss:0.3297, avg valid loss:0.4625
# 	 score:0.3734(th=0.250000), auc=0.791360::: time:863.18s
# Epoch 10 - Save Best AUC: 0.7914. Model is saved.
# surface_list:  range(27, 37, 3)
# - epoch:1 -
# Epoch: [1][0/58] Elapsed 0m 0s (remain 0m 51s) Loss: 0.2281(0.2281)
# Epoch: [1][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2086(0.3240)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 27s) Loss: 0.0060(0.0060)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0032(0.4444)
# 	 epoch:1, avg train loss:0.3240, avg valid loss:0.4444
# 	 score:0.3559(th=0.350000), auc=0.790035::: time:80.19s
# Epoch 1 - Save Best Score: 0.3559. Model is saved.
# dice_list:  [0.2913706045166475, 0.31495952427460094, 0.3320307684382526, 0.34404492869694775, 0.35257257495593264, 0.35591880932472014, 0.353159714393924, 0.3447545288921936, 0.3295460538626239, 0.30642374021125246, 0.2720760764265023, 0.2273567895893171, 0.17547242479909303, 0.12284760085384577, 0.07506706181164731, 0.037413121303544156, 0.01399948353871858, 0.0030291614145791903, 0.0]
# Epoch 1 - Save Best AUC: 0.7900. Model is saved.
# - epoch:2 -
# Epoch: [2][0/58] Elapsed 0m 0s (remain 0m 54s) Loss: 0.5119(0.5119)
# Epoch: [2][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1971(0.3223)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 26s) Loss: 0.0174(0.0174)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0241(0.4481)
# 	 epoch:2, avg train loss:0.3223, avg valid loss:0.4481
# 	 score:0.3808(th=0.200000), auc=0.798177::: time:166.53s
# Epoch 2 - Save Best Score: 0.3808. Model is saved.
# dice_list:  [0.3564739345099162, 0.38014917748901206, 0.38084060676342285, 0.3633942539437539, 0.3381544505225878, 0.31026874588597214, 0.2819721184589915, 0.25440556982401114, 0.22711849953811927, 0.19967596453003755, 0.1724042298917587, 0.14597885414576225, 0.1195593266975459, 0.09406897834475435, 0.0709907585829955, 0.04875106497228856, 0.02892313211317344, 0.010101983637662288, 0.0]
# Epoch 2 - Save Best AUC: 0.7982. Model is saved.
# - epoch:3 -
# Epoch: [3][0/58] Elapsed 0m 0s (remain 0m 53s) Loss: 0.1927(0.1927)
# Epoch: [3][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2178(0.3137)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0093(0.0093)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0097(0.4966)
# 	 epoch:3, avg train loss:0.3137, avg valid loss:0.4966
# 	 score:0.3520(th=0.100000), auc=0.785683::: time:254.98s
# - epoch:4 -
# Epoch: [4][0/58] Elapsed 0m 1s (remain 1m 0s) Loss: 0.2237(0.2237)
# Epoch: [4][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.4313(0.3048)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 36s) Loss: 0.0149(0.0149)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0058(0.5164)
# 	 epoch:4, avg train loss:0.3048, avg valid loss:0.5164
# 	 score:0.3943(th=0.150000), auc=0.791782::: time:334.59s
# Epoch 4 - Save Best Score: 0.3943. Model is saved.
# dice_list:  [0.361658995444011, 0.3943441723973252, 0.38418911608964484, 0.3488176327112444, 0.300228197186659, 0.24798422397428838, 0.20041619904529961, 0.15996636584324944, 0.12621193351760795, 0.09729612969730235, 0.07190309249124326, 0.049471216636975734, 0.030042704451041343, 0.016980173659834924, 0.008737806980720932, 0.004559387208796394, 0.002713131719573862, 0.0011064455372953013, 0.0]
# - epoch:5 -
# Epoch: [5][0/58] Elapsed 0m 1s (remain 0m 57s) Loss: 0.2705(0.2705)
# Epoch: [5][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3395(0.2942)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 31s) Loss: 0.0188(0.0188)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0082(0.5082)
# 	 epoch:5, avg train loss:0.2942, avg valid loss:0.5082
# 	 score:0.3922(th=0.150000), auc=0.791202::: time:418.20s
# - epoch:6 -
# Epoch: [6][0/58] Elapsed 0m 0s (remain 0m 55s) Loss: 0.3142(0.3142)
# Epoch: [6][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2072(0.2807)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.0168(0.0168)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0066(0.5265)
# 	 epoch:6, avg train loss:0.2807, avg valid loss:0.5265
# 	 score:0.3922(th=0.150000), auc=0.792228::: time:498.60s
# - epoch:7 -
# Epoch: [7][0/58] Elapsed 0m 0s (remain 0m 54s) Loss: 0.2312(0.2312)
# Epoch: [7][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3472(0.2864)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0124(0.0124)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0050(0.5638)
# 	 epoch:7, avg train loss:0.2864, avg valid loss:0.5638
# 	 score:0.3922(th=0.100000), auc=0.789799::: time:580.35s
# - epoch:8 -
# Epoch: [8][0/58] Elapsed 0m 0s (remain 0m 55s) Loss: 0.4439(0.4439)
# Epoch: [8][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2336(0.2832)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 36s) Loss: 0.0102(0.0102)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0141(0.4846)
# 	 epoch:8, avg train loss:0.2832, avg valid loss:0.4846
# 	 score:0.3949(th=0.150000), auc=0.799985::: time:660.86s
# Epoch 8 - Save Best Score: 0.3949. Model is saved.
# dice_list:  [0.38474993759168347, 0.39487034025788686, 0.3563544467979131, 0.2981937212458649, 0.2358460993716255, 0.17433413238437417, 0.12427243352079097, 0.0851900630718281, 0.056193335467469505, 0.0348729901260611, 0.020974135106119736, 0.012744927651747253, 0.0079799457345313, 0.005014523942656077, 0.0034531726139163067, 0.0017944367105931485, 0.00027228757600407676, 0.0, 0.0]
# Epoch 8 - Save Best AUC: 0.8000. Model is saved.
# - epoch:9 -
# Epoch: [9][0/58] Elapsed 0m 0s (remain 0m 51s) Loss: 0.2277(0.2277)
# Epoch: [9][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2692(0.3055)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0097(0.0097)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0095(0.4471)
# 	 epoch:9, avg train loss:0.3055, avg valid loss:0.4471
# 	 score:0.3701(th=0.200000), auc=0.797024::: time:746.86s
# - epoch:10 -
# Epoch: [10][0/58] Elapsed 0m 1s (remain 0m 57s) Loss: 0.3878(0.3878)
# Epoch: [10][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3765(0.3055)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0043(0.0043)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0037(0.5718)
# 	 epoch:10, avg train loss:0.3055, avg valid loss:0.5718
# 	 score:0.3293(th=0.100000), auc=0.782410::: time:826.75s
# surface_list:  range(25, 35, 3)
# - epoch:1 -
# Epoch: [1][0/58] Elapsed 0m 0s (remain 0m 55s) Loss: 0.2401(0.2401)
# Epoch: [1][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2058(0.3214)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 31s) Loss: 0.0055(0.0055)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0090(0.4517)
# 	 epoch:1, avg train loss:0.3214, avg valid loss:0.4517
# 	 score:0.3581(th=0.200000), auc=0.787256::: time:80.29s
# Epoch 1 - Save Best Score: 0.3581. Model is saved.
# dice_list:  [0.3069447642245195, 0.34337288291396184, 0.3580955866289363, 0.35245170563773714, 0.331182931338094, 0.29930832782407923, 0.260547687469519, 0.2170376504540188, 0.17121634508745623, 0.12847003128057832, 0.09147276149596055, 0.06143026002650664, 0.03823138616246343, 0.02110344212644924, 0.009710984706725522, 0.003090751369902968, 0.0003919611507286793, 3.2527775449749187e-06, 0.0]
# Epoch 1 - Save Best AUC: 0.7873. Model is saved.
# - epoch:2 -
# Epoch: [2][0/58] Elapsed 0m 0s (remain 0m 51s) Loss: 0.1932(0.1932)
# Epoch: [2][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2568(0.3077)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0109(0.0109)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0056(0.4816)
# 	 epoch:2, avg train loss:0.3077, avg valid loss:0.4816
# 	 score:0.3740(th=0.200000), auc=0.788052::: time:166.66s
# Epoch 2 - Save Best Score: 0.3740. Model is saved.
# dice_list:  [0.34093611287673903, 0.3693988679040131, 0.3739594805917847, 0.3551089773063459, 0.31657464421666387, 0.26596527145160687, 0.2118927568353415, 0.15991381171598823, 0.11271106016364693, 0.07476761747848087, 0.047604494904295074, 0.028042901272784863, 0.014140275359780723, 0.005422481933597738, 0.0011695921552358497, 0.00010018825040220128, 0.0, 0.0, 0.0]
# Epoch 2 - Save Best AUC: 0.7881. Model is saved.
# - epoch:3 -
# Epoch: [3][0/58] Elapsed 0m 1s (remain 1m 0s) Loss: 0.3466(0.3466)
# Epoch: [3][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.7217(0.3189)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0193(0.0193)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0119(0.4403)
# 	 epoch:3, avg train loss:0.3189, avg valid loss:0.4403
# 	 score:0.3961(th=0.350000), auc=0.799861::: time:251.75s
# Epoch 3 - Save Best Score: 0.3961. Model is saved.
# dice_list:  [0.31292397781363174, 0.3459828118581862, 0.37065104579874486, 0.3858594418710665, 0.3938277192205955, 0.39608316769601204, 0.3916925825425221, 0.38097836253080763, 0.3656806594266718, 0.34621661562979306, 0.3211557624652376, 0.28947543042002527, 0.2529535037708688, 0.2122959411751281, 0.16671288255488775, 0.11693218469589182, 0.07117876327699714, 0.032165650570740674, 0.0]
# Epoch 3 - Save Best AUC: 0.7999. Model is saved.
# - epoch:4 -
# Epoch: [4][0/58] Elapsed 0m 0s (remain 0m 51s) Loss: 0.2933(0.2933)
# Epoch: [4][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2360(0.2857)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0159(0.0159)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0123(0.4874)
# 	 epoch:4, avg train loss:0.2857, avg valid loss:0.4874
# 	 score:0.4210(th=0.200000), auc=0.802256::: time:337.47s
# Epoch 4 - Save Best Score: 0.4210. Model is saved.
# dice_list:  [0.39696950861880204, 0.418662303437772, 0.42104493419957106, 0.40790075663647557, 0.37969693487469497, 0.34056339935942403, 0.297940995486101, 0.2529524847002338, 0.21073668666637121, 0.1731015279107146, 0.1385859097503155, 0.10907965707359937, 0.08605092496365685, 0.06690818282308748, 0.04772620170301451, 0.02759363838163611, 0.011593599037841412, 0.0020447905441690465, 0.0]
# Epoch 4 - Save Best AUC: 0.8023. Model is saved.
# - epoch:5 -
# Epoch: [5][0/58] Elapsed 0m 1s (remain 0m 59s) Loss: 0.2268(0.2268)
# Epoch: [5][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3897(0.2790)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0123(0.0123)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0087(0.5101)
# 	 epoch:5, avg train loss:0.2790, avg valid loss:0.5101
# 	 score:0.4334(th=0.150000), auc=0.805335::: time:423.70s
# Epoch 5 - Save Best Score: 0.4334. Model is saved.
# dice_list:  [0.42732952095663784, 0.43344273787891935, 0.408953481037621, 0.36993843567172247, 0.3201680461576612, 0.26790541504069004, 0.217679393507873, 0.1730701858271948, 0.1369001932011748, 0.10571088364733107, 0.08077309772872276, 0.05988799984443103, 0.043485047487878785, 0.02870357168122693, 0.015426888880648023, 0.006524338894021744, 0.0019382843236120458, 7.88517642740741e-05, 0.0]
# Epoch 5 - Save Best AUC: 0.8053. Model is saved.
# - epoch:6 -
# Epoch: [6][0/58] Elapsed 0m 1s (remain 0m 57s) Loss: 0.2530(0.2530)
# Epoch: [6][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2766(0.2634)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0138(0.0138)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0091(0.4801)
# 	 epoch:6, avg train loss:0.2634, avg valid loss:0.4801
# 	 score:0.4398(th=0.200000), auc=0.808628::: time:507.85s
# Epoch 6 - Save Best Score: 0.4398. Model is saved.
# dice_list:  [0.4023024806948962, 0.4347157277178454, 0.43978137493662167, 0.42643172617666897, 0.39806908888398956, 0.3599762737384758, 0.3144947564639256, 0.2670579712336755, 0.22076922038483532, 0.17672142856436637, 0.13781703908899517, 0.10563917762022319, 0.07847575262067066, 0.055469599626640824, 0.037026915654400555, 0.019774867387868607, 0.00648687785355036, 0.0012995459757356412, 0.0]
# Epoch 6 - Save Best AUC: 0.8086. Model is saved.
# - epoch:7 -
# Epoch: [7][0/58] Elapsed 0m 0s (remain 0m 54s) Loss: 0.2538(0.2538)
# Epoch: [7][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2239(0.2823)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.0109(0.0109)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0088(0.4872)
# 	 epoch:7, avg train loss:0.2823, avg valid loss:0.4872
# 	 score:0.4389(th=0.200000), auc=0.808732::: time:593.03s
# Epoch 7 - Save Best AUC: 0.8087. Model is saved.
# - epoch:8 -
# Epoch: [8][0/58] Elapsed 0m 0s (remain 0m 56s) Loss: 0.2719(0.2719)
# Epoch: [8][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2562(0.2816)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 32s) Loss: 0.0118(0.0118)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0032(0.5154)
# 	 epoch:8, avg train loss:0.2816, avg valid loss:0.5154
# 	 score:0.4232(th=0.150000), auc=0.808604::: time:676.69s
# - epoch:9 -
# Epoch: [9][0/58] Elapsed 0m 0s (remain 0m 54s) Loss: 0.2219(0.2219)
# Epoch: [9][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3797(0.2948)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0213(0.0213)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0122(0.4843)
# 	 epoch:9, avg train loss:0.2948, avg valid loss:0.4843
# 	 score:0.4164(th=0.150000), auc=0.806387::: time:757.24s
# - epoch:10 -
# Epoch: [10][0/58] Elapsed 0m 0s (remain 0m 56s) Loss: 0.2587(0.2587)
# Epoch: [10][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.4632(0.2848)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.0072(0.0072)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0069(0.5013)
# 	 epoch:10, avg train loss:0.2848, avg valid loss:0.5013
# 	 score:0.3938(th=0.150000), auc=0.791396::: time:836.91s
# [fold1] slice ave score:0.4029(th=0.200000), auc=0.800167
# [fold1] BEST Epoch 6 - Save Best Score:0.4398. Best loss:0.4801
# [fold1] BEST AUC Epoch 7 - Save Best Score:0.8087. Best loss:0.4872
# -- fold2 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# Epoch: [1][0/125] Elapsed 0m 0s (remain 1m 59s) Loss: 0.7180(0.7180)
# Epoch: [1][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3145(0.4631)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1528(0.1528)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1364(0.4065)
# 	 epoch:1, avg train loss:0.4631, avg valid loss:0.4065
# 	 score:0.3196(th=0.200000), auc=0.827127::: time:57.18s
# Epoch 1 - Save Best Score: 0.3196. Model is saved.
# dice_list:  [0.24303691820591847, 0.28748810291997, 0.3196480378163457, 0.3145410549587593, 0.2775594185858419, 0.20913058562452452, 0.13271287044806737, 0.07521542594163097, 0.048234241662254804, 0.03622580031857015, 0.02756944913434097, 0.020331653329732666, 0.013758714776673623, 0.008855153282702923, 0.003811080779360727, 0.0008470937472744084, 7.404684796520137e-06, 0.0, 0.0]
# Epoch 1 - Save Best AUC: 0.8271. Model is saved.
# - epoch:2 -
# Epoch: [2][0/125] Elapsed 0m 1s (remain 2m 6s) Loss: 0.3400(0.3400)
# Epoch: [2][124/125] Elapsed 0m 36s (remain 0m 0s) Loss: 0.3686(0.4062)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 10s) Loss: 0.1683(0.1683)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1590(0.4111)
# 	 epoch:2, avg train loss:0.4062, avg valid loss:0.4111
# 	 score:0.2825(th=0.200000), auc=0.813322::: time:118.56s
# - epoch:3 -
# Epoch: [3][0/125] Elapsed 0m 0s (remain 1m 57s) Loss: 0.3371(0.3371)
# Epoch: [3][124/125] Elapsed 0m 36s (remain 0m 0s) Loss: 0.4325(0.4069)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.3624(0.3624)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1926(0.4645)
# 	 epoch:3, avg train loss:0.4069, avg valid loss:0.4645
# 	 score:0.2799(th=0.150000), auc=0.796468::: time:175.71s
# - epoch:4 -
# Epoch: [4][0/125] Elapsed 0m 0s (remain 2m 2s) Loss: 0.3013(0.3013)
# Epoch: [4][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3676(0.3922)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1768(0.1768)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1504(0.4139)
# 	 epoch:4, avg train loss:0.3922, avg valid loss:0.4139
# 	 score:0.3577(th=0.400000), auc=0.839597::: time:232.24s
# Epoch 4 - Save Best Score: 0.3577. Model is saved.
# dice_list:  [0.24702267099553424, 0.2678386171920772, 0.29249682145679046, 0.3175955236819948, 0.3377669233536483, 0.3513986973842109, 0.35773708034783963, 0.3571027268287501, 0.3551367251108988, 0.35153768611452774, 0.3401200785693777, 0.3211495111102822, 0.29214262354314474, 0.25419602528340435, 0.20502061383553066, 0.15211870810878536, 0.090307847153217, 0.0308179765782634, 0.0]
# Epoch 4 - Save Best AUC: 0.8396. Model is saved.
# - epoch:5 -
# Epoch: [5][0/125] Elapsed 0m 0s (remain 1m 55s) Loss: 0.4223(0.4223)
# Epoch: [5][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3868(0.3719)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1482(0.1482)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0985(0.4611)
# 	 epoch:5, avg train loss:0.3719, avg valid loss:0.4611
# 	 score:0.3635(th=0.200000), auc=0.814818::: time:290.83s
# Epoch 5 - Save Best Score: 0.3635. Model is saved.
# dice_list:  [0.3180754397743168, 0.34550883986080294, 0.36346966328396135, 0.35684217443399635, 0.33863109597477487, 0.3021788275955005, 0.2624536822204136, 0.20902613925754981, 0.15715565226849543, 0.1076147078360787, 0.06793074360000655, 0.04071841102057308, 0.026446728415947487, 0.021264824775626412, 0.016924466892251546, 0.012566276134267855, 0.006856918832053967, 8.23980904336431e-05, 0.0]
# - epoch:6 -
# Epoch: [6][0/125] Elapsed 0m 0s (remain 1m 57s) Loss: 0.3254(0.3254)
# Epoch: [6][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3576(0.3689)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1488(0.1488)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1041(0.4365)
# 	 epoch:6, avg train loss:0.3689, avg valid loss:0.4365
# 	 score:0.3689(th=0.250000), auc=0.821522::: time:347.67s
# Epoch 6 - Save Best Score: 0.3689. Model is saved.
# dice_list:  [0.3028262649029908, 0.33508702084141445, 0.35695100331677293, 0.36892362392326755, 0.36352798297449174, 0.3447474753428112, 0.3121816109090075, 0.26772102453973146, 0.21002574793540163, 0.1486199887669083, 0.09575576479896465, 0.058197602176849245, 0.03535783404534719, 0.0269736141782604, 0.02463368162248328, 0.02036088913454694, 0.015325967962812107, 0.007667704524859748, 0.0]
# - epoch:7 -
# Epoch: [7][0/125] Elapsed 0m 1s (remain 2m 9s) Loss: 0.2985(0.2985)
# Epoch: [7][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3571(0.3628)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 10s) Loss: 0.1453(0.1453)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1057(0.3799)
# 	 epoch:7, avg train loss:0.3628, avg valid loss:0.3799
# 	 score:0.4271(th=0.400000), auc=0.861985::: time:406.01s
# Epoch 7 - Save Best Score: 0.4271. Model is saved.
# dice_list:  [0.29211838216822067, 0.3339005332302599, 0.3662732005921449, 0.39288510789589987, 0.4104493409550746, 0.4217731444394707, 0.42712622573840336, 0.4187067007964703, 0.395396724458139, 0.3563127528228852, 0.29802083270227214, 0.21475502992124942, 0.1200315170350763, 0.04176888389517957, 0.007653171367058261, 0.00042685425691186196, 0.0, 0.0, 0.0]
# Epoch 7 - Save Best AUC: 0.8620. Model is saved.
# - epoch:8 -
# Epoch: [8][0/125] Elapsed 0m 1s (remain 2m 12s) Loss: 0.4271(0.4271)
# Epoch: [8][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3910(0.3724)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1447(0.1447)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1034(0.3779)
# 	 epoch:8, avg train loss:0.3724, avg valid loss:0.3779
# 	 score:0.4700(th=0.450000), auc=0.864110::: time:465.58s
# Epoch 8 - Save Best Score: 0.4700. Model is saved.
# dice_list:  [0.30277459545553764, 0.3421381856233707, 0.3729675841217935, 0.39792135671244805, 0.42110665352531146, 0.4426595088544002, 0.46005197293284444, 0.46999583121397626, 0.46870103636024607, 0.45487044528201, 0.4328148376844303, 0.40266618618146394, 0.3631154792968158, 0.31422428479793, 0.2609552495571748, 0.20863893253035887, 0.1486387662333596, 0.0846173318564344, 0.0]
# Epoch 8 - Save Best AUC: 0.8641. Model is saved.
# - epoch:9 -
# Epoch: [9][0/125] Elapsed 0m 0s (remain 1m 45s) Loss: 0.4466(0.4466)
# Epoch: [9][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2911(0.3781)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 11s) Loss: 0.1292(0.1292)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1086(0.3993)
# 	 epoch:9, avg train loss:0.3781, avg valid loss:0.3993
# 	 score:0.4070(th=0.350000), auc=0.855689::: time:524.73s
# - epoch:10 -
# Epoch: [10][0/125] Elapsed 0m 1s (remain 2m 12s) Loss: 0.3950(0.3950)
# Epoch: [10][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.4454(0.3811)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1327(0.1327)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0916(0.4662)
# 	 epoch:10, avg train loss:0.3811, avg valid loss:0.4662
# 	 score:0.3923(th=0.150000), auc=0.831922::: time:580.92s
# surface_list:  range(27, 37, 3)
# - epoch:1 -
# Epoch: [1][0/125] Elapsed 0m 1s (remain 2m 10s) Loss: 0.4508(0.4508)
# Epoch: [1][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3173(0.3789)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1278(0.1278)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0844(0.4490)
# 	 epoch:1, avg train loss:0.3789, avg valid loss:0.4490
# 	 score:0.3490(th=0.150000), auc=0.840536::: time:55.43s
# Epoch 1 - Save Best Score: 0.3490. Model is saved.
# dice_list:  [0.3420727509077561, 0.34904927614957065, 0.32684138526865825, 0.29269063278175317, 0.24965527455341538, 0.20654613327493013, 0.16961965261100156, 0.1382401678732856, 0.10907817335231816, 0.08175906049469335, 0.060608021191386724, 0.04313863568663745, 0.0281421244855163, 0.015845387031790375, 0.0073248847720991245, 0.0015794433358511917, 1.123674294379385e-05, 0.0, 0.0]
# Epoch 1 - Save Best AUC: 0.8405. Model is saved.
# - epoch:2 -
# Epoch: [2][0/125] Elapsed 0m 0s (remain 1m 48s) Loss: 0.3279(0.3279)
# Epoch: [2][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2914(0.3663)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1368(0.1368)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0935(0.3977)
# 	 epoch:2, avg train loss:0.3663, avg valid loss:0.3977
# 	 score:0.4509(th=0.250000), auc=0.867643::: time:114.95s
# Epoch 2 - Save Best Score: 0.4509. Model is saved.
# dice_list:  [0.3708241400113239, 0.42473258665244334, 0.4480877348213729, 0.45085634984027767, 0.4411717315626223, 0.4228150054689775, 0.40484037259919714, 0.3872156551449129, 0.3729516602283683, 0.3593311436765, 0.3457511739384709, 0.3325221392449829, 0.31797237762887864, 0.302714684588653, 0.28345570823326144, 0.2572919231240369, 0.22126777222396984, 0.15787835595485625, 0.0]
# Epoch 2 - Save Best AUC: 0.8676. Model is saved.
# - epoch:3 -
# Epoch: [3][0/125] Elapsed 0m 1s (remain 2m 9s) Loss: 0.4180(0.4180)
# Epoch: [3][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2558(0.3582)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1679(0.1679)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1595(0.4228)
# 	 epoch:3, avg train loss:0.3582, avg valid loss:0.4228
# 	 score:0.4531(th=0.600000), auc=0.878592::: time:173.43s
# Epoch 3 - Save Best Score: 0.4531. Model is saved.
# dice_list:  [0.2735468886128245, 0.3047316922282128, 0.33177901282327865, 0.35611729537057435, 0.38037163357106907, 0.403136659688549, 0.42273867390159897, 0.4383264743945034, 0.447955558936331, 0.4525360669958556, 0.4530878576751047, 0.44985236488480557, 0.44500535978800104, 0.43895473090548365, 0.4279374121281468, 0.4087792454360542, 0.3681080740824088, 0.28654677872190487, 0.0]
# Epoch 3 - Save Best AUC: 0.8786. Model is saved.
# - epoch:4 -
# Epoch: [4][0/125] Elapsed 0m 0s (remain 1m 54s) Loss: 0.4298(0.4298)
# Epoch: [4][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2748(0.3448)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1170(0.1170)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0851(0.4859)
# 	 epoch:4, avg train loss:0.3448, avg valid loss:0.4859
# 	 score:0.4089(th=0.150000), auc=0.834486::: time:232.23s
# - epoch:5 -
# Epoch: [5][0/125] Elapsed 0m 0s (remain 1m 50s) Loss: 0.3445(0.3445)
# Epoch: [5][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.4200(0.3339)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.0954(0.0954)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0837(0.4229)
# 	 epoch:5, avg train loss:0.3339, avg valid loss:0.4229
# 	 score:0.4551(th=0.200000), auc=0.867654::: time:287.79s
# Epoch 5 - Save Best Score: 0.4551. Model is saved.
# dice_list:  [0.41469323592986557, 0.4492900800927917, 0.45508368226837004, 0.4537828031828571, 0.4503326569917991, 0.4407149377481252, 0.4289882355709112, 0.41529089109628015, 0.4000622725178468, 0.3828726245741113, 0.36273166342630636, 0.3391957098327829, 0.31369638200820016, 0.2854600865009033, 0.25120899044243417, 0.20112350332285842, 0.13725811238600352, 0.04706190049370101, 0.0]
# - epoch:6 -
# Epoch: [6][0/125] Elapsed 0m 0s (remain 1m 47s) Loss: 0.2740(0.2740)
# Epoch: [6][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2928(0.3301)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.0947(0.0947)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0841(0.4243)
# 	 epoch:6, avg train loss:0.3301, avg valid loss:0.4243
# 	 score:0.4558(th=0.200000), auc=0.868869::: time:344.25s
# Epoch 6 - Save Best Score: 0.4558. Model is saved.
# dice_list:  [0.4184559701559172, 0.4506847503639534, 0.45575447729382434, 0.4541295814721274, 0.45238553800666403, 0.44393740825120875, 0.43112554893652594, 0.4188576392102604, 0.4045415065732603, 0.38712936321954666, 0.36760652207468625, 0.3465113764994051, 0.32075601712788904, 0.2914484135315761, 0.2571131007666918, 0.2075617595517556, 0.14126330630111775, 0.04919810693416292, 0.0]
# - epoch:7 -
# Epoch: [7][0/125] Elapsed 0m 0s (remain 2m 3s) Loss: 0.3617(0.3617)
# Epoch: [7][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3004(0.3319)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1079(0.1079)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0900(0.3808)
# 	 epoch:7, avg train loss:0.3319, avg valid loss:0.3808
# 	 score:0.4548(th=0.300000), auc=0.877104::: time:401.80s
# - epoch:8 -
# Epoch: [8][0/125] Elapsed 0m 0s (remain 1m 47s) Loss: 0.4507(0.4507)
# Epoch: [8][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2891(0.3375)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 10s) Loss: 0.0997(0.0997)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0757(0.4208)
# 	 epoch:8, avg train loss:0.3375, avg valid loss:0.4208
# 	 score:0.4611(th=0.200000), auc=0.868659::: time:457.80s
# Epoch 8 - Save Best Score: 0.4611. Model is saved.
# dice_list:  [0.40899188702546374, 0.4531620835027425, 0.461073760538249, 0.4545702706571662, 0.4381619493048261, 0.41866459169604675, 0.39569103827179025, 0.37108320002513445, 0.34579263350612743, 0.31863557214198435, 0.2884784895596925, 0.25214519283238274, 0.21199501521415887, 0.1685499939586749, 0.12080908052934577, 0.07687112622090612, 0.04342489470143464, 0.017402930221397505, 0.0]
# - epoch:9 -
# Epoch: [9][0/125] Elapsed 0m 0s (remain 1m 58s) Loss: 0.3914(0.3914)
# Epoch: [9][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.4123(0.3448)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1757(0.1757)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0958(0.3853)
# 	 epoch:9, avg train loss:0.3448, avg valid loss:0.3853
# 	 score:0.4399(th=0.350000), auc=0.877447::: time:514.83s
# - epoch:10 -
# Epoch: [10][0/125] Elapsed 0m 0s (remain 1m 59s) Loss: 0.3482(0.3482)
# Epoch: [10][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3149(0.3534)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 10s) Loss: 0.2515(0.2515)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1697(0.4182)
# 	 epoch:10, avg train loss:0.3534, avg valid loss:0.4182
# 	 score:0.4419(th=0.650000), auc=0.870794::: time:571.00s
# surface_list:  range(25, 35, 3)
# - epoch:1 -
# Epoch: [1][0/125] Elapsed 0m 0s (remain 1m 55s) Loss: 0.2589(0.2589)
# Epoch: [1][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.4585(0.3570)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1354(0.1354)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1037(0.4114)
# 	 epoch:1, avg train loss:0.3570, avg valid loss:0.4114
# 	 score:0.4375(th=0.300000), auc=0.841723::: time:54.76s
# Epoch 1 - Save Best Score: 0.4375. Model is saved.
# dice_list:  [0.3083404317484036, 0.3671470257420736, 0.40916850504066676, 0.42978907743503103, 0.4375459050318529, 0.4331064652370846, 0.4180065903053417, 0.3942556220550992, 0.3626407627816, 0.320493658918313, 0.2748737786407015, 0.22748769635427168, 0.18054371696550173, 0.13084417269331935, 0.07810988984380483, 0.034306218190182466, 0.009419070346215998, 0.001695043962945763, 0.0]
# Epoch 1 - Save Best AUC: 0.8417. Model is saved.
# - epoch:2 -
# Epoch: [2][0/125] Elapsed 0m 0s (remain 2m 3s) Loss: 0.3133(0.3133)
# Epoch: [2][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2814(0.3542)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1600(0.1600)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1132(0.3751)
# 	 epoch:2, avg train loss:0.3542, avg valid loss:0.3751
# 	 score:0.4653(th=0.450000), auc=0.873247::: time:114.26s
# Epoch 2 - Save Best Score: 0.4653. Model is saved.
# dice_list:  [0.2641699264003529, 0.2911115220086464, 0.3259722735128758, 0.3645737285717661, 0.40033001708901816, 0.4331995722429768, 0.45723969145198445, 0.46529440248834086, 0.4495716435502945, 0.4148608308824418, 0.3576876164374008, 0.279192387583394, 0.18245363151026275, 0.0966964190551612, 0.031844104257694815, 0.004616214585611653, 2.715511629496279e-05, 0.0, 0.0]
# Epoch 2 - Save Best AUC: 0.8732. Model is saved.
# - epoch:3 -
# Epoch: [3][0/125] Elapsed 0m 0s (remain 1m 56s) Loss: 0.4474(0.4474)
# Epoch: [3][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3432(0.3425)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.0947(0.0947)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0835(0.4171)
# 	 epoch:3, avg train loss:0.3425, avg valid loss:0.4171
# 	 score:0.4764(th=0.250000), auc=0.856855::: time:173.01s
# Epoch 3 - Save Best Score: 0.4764. Model is saved.
# dice_list:  [0.3963573092456378, 0.4508913244156795, 0.47090139308754714, 0.4764229150768915, 0.4656475281396926, 0.44654520829164934, 0.4207601665381664, 0.39224482286922396, 0.3587110477115268, 0.3191810876226458, 0.27675714480570923, 0.2252062398007684, 0.1678931604584096, 0.11224477851136978, 0.05950410589073221, 0.02186206721198659, 0.003344135415106247, 0.0, 0.0]
# - epoch:4 -
# Epoch: [4][0/125] Elapsed 0m 0s (remain 2m 0s) Loss: 0.2961(0.2961)
# Epoch: [4][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3010(0.3337)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1489(0.1489)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1249(0.4101)
# 	 epoch:4, avg train loss:0.3337, avg valid loss:0.4101
# 	 score:0.4911(th=0.700000), auc=0.877861::: time:230.50s
# Epoch 4 - Save Best Score: 0.4911. Model is saved.
# dice_list:  [0.2994988027020012, 0.3291015042962348, 0.35359860310196384, 0.37545809116044276, 0.395885511969587, 0.4148536050630913, 0.43290490208793936, 0.44961709552648244, 0.46379493368270036, 0.47488060606491755, 0.48388578455328307, 0.48929879023873313, 0.4910958054569333, 0.4869586525451478, 0.4747453627256152, 0.4433057943966579, 0.3733236244131203, 0.21770253500974873, 0.0]
# Epoch 4 - Save Best AUC: 0.8779. Model is saved.
# - epoch:5 -
# Epoch: [5][0/125] Elapsed 0m 1s (remain 2m 5s) Loss: 0.2888(0.2888)
# Epoch: [5][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3006(0.3256)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1097(0.1097)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0830(0.3893)
# 	 epoch:5, avg train loss:0.3256, avg valid loss:0.3893
# 	 score:0.4926(th=0.350000), auc=0.871737::: time:289.28s
# Epoch 5 - Save Best Score: 0.4926. Model is saved.
# dice_list:  [0.39553605546958315, 0.43793444422533173, 0.46416825801496786, 0.4865083502190893, 0.4922155380049073, 0.49255772880364773, 0.4882812481007493, 0.4818452029836212, 0.47310005307630104, 0.4557086493026714, 0.42393906211592935, 0.3808203226969268, 0.3304357321915941, 0.2706852066624095, 0.1947803722414621, 0.09666436379859175, 0.021026290592562977, 0.0, 0.0]
# - epoch:6 -
# Epoch: [6][0/125] Elapsed 0m 0s (remain 1m 54s) Loss: 0.3130(0.3130)
# Epoch: [6][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3365(0.3216)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1314(0.1314)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0881(0.3762)
# 	 epoch:6, avg train loss:0.3216, avg valid loss:0.3762
# 	 score:0.4904(th=0.400000), auc=0.872059::: time:346.21s
# - epoch:7 -
# Epoch: [7][0/125] Elapsed 0m 0s (remain 2m 1s) Loss: 0.3417(0.3417)
# Epoch: [7][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3116(0.3163)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1142(0.1142)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0859(0.3818)
# 	 epoch:7, avg train loss:0.3163, avg valid loss:0.3818
# 	 score:0.4960(th=0.350000), auc=0.873805::: time:401.28s
# Epoch 7 - Save Best Score: 0.4960. Model is saved.
# dice_list:  [0.38996931723013906, 0.4354808882187924, 0.46447914422494024, 0.4831279525610367, 0.49284946967131266, 0.4960245934513984, 0.49392404606732593, 0.48445625072465925, 0.466262199368827, 0.43611286441762503, 0.39624554898021297, 0.3451352388822569, 0.287194919732572, 0.2171125508145548, 0.1296369984667165, 0.04884385475665884, 0.006901977848401548, 0.0, 0.0]
# - epoch:8 -
# Epoch: [8][0/125] Elapsed 0m 1s (remain 2m 9s) Loss: 0.2576(0.2576)
# Epoch: [8][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2859(0.3237)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1511(0.1511)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0886(0.3699)
# 	 epoch:8, avg train loss:0.3237, avg valid loss:0.3699
# 	 score:0.5054(th=0.450000), auc=0.876692::: time:459.25s
# Epoch 8 - Save Best Score: 0.5054. Model is saved.
# dice_list:  [0.3489005337692117, 0.3963164197950544, 0.4311223540273916, 0.4586730958871545, 0.47857627630257005, 0.49133286641965634, 0.5019944499053793, 0.5054049885982623, 0.5024059445297153, 0.4908042256804967, 0.4737390294006618, 0.44853643579757957, 0.4181645278848583, 0.37967756142634557, 0.3315498348189128, 0.2677304976199044, 0.1726422001489838, 0.04322495447522102, 0.0]
# - epoch:9 -
# Epoch: [9][0/125] Elapsed 0m 1s (remain 2m 6s) Loss: 0.2447(0.2447)
# Epoch: [9][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2578(0.3377)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1617(0.1617)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0818(0.3900)
# 	 epoch:9, avg train loss:0.3377, avg valid loss:0.3900
# 	 score:0.4758(th=0.450000), auc=0.866067::: time:516.16s
# - epoch:10 -
# Epoch: [10][0/125] Elapsed 0m 0s (remain 2m 2s) Loss: 0.3577(0.3577)
# Epoch: [10][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2820(0.3382)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 8s) Loss: 0.1833(0.1833)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1585(0.4029)
# 	 epoch:10, avg train loss:0.3382, avg valid loss:0.4029
# 	 score:0.4605(th=0.600000), auc=0.868343::: time:571.70s
# [fold2] slice ave score:0.4842(th=0.450000), auc=0.877683
# [fold2] BEST Epoch 8 - Save Best Score:0.5054. Best loss:0.3699
# [fold2] BEST AUC Epoch 4 - Save Best Score:0.8779. Best loss:0.4101
# fold[0] BEST SCORE = 0.4935 thr=0.5 (epoch=6)
# fold[0] slice ave score:0.4678(th=0.300000), auc=0.867496
# fold[1] BEST SCORE = 0.4398 thr=0.2 (epoch=6)
# fold[1] slice ave score:0.4029(th=0.200000), auc=0.800167
# fold[2] BEST SCORE = 0.5054 thr=0.45 (epoch=8)
# fold[2] slice ave score:0.4842(th=0.450000), auc=0.877683
# CPU times: user 1h 18min 43s, sys: 20min 41s, total: 1h 39min 25s
# Wall time: 1h 46min 45s

# %% [markdown]
# ---
# # OOF SCORE CHECK

# %%
# %%time
slice_ave_score_list, slice_ave_score_threshold_list, slice_ave_auc_list = slide_inference(CFG)
for fold in CFG["folds"]:
    print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    wandb.log({"OOF SCORE" : {f"slice average score":slice_ave_score_list[fold],
                            f"slice average threshold":slice_ave_score_threshold_list[fold],
                            f"slice_average auc":slice_ave_auc_list[fold],
                            }}, step=fold)
# Out:
# -- fold0 slide inference start --
# surface_list:  range(26, 36, 3)
# slide pos: [0, 0]
# 	 score:0.4916(th=0.550000), auc=0.884610::: time:26.20s
# slide pos: [128, 0]
# 	 score:0.4960(th=0.550000), auc=0.887160::: time:44.14s
# slide pos: [0, 128]
# 	 score:0.4713(th=0.500000), auc=0.887017::: time:62.54s
# slide pos: [128, 128]
# 	 score:0.5008(th=0.550000), auc=0.887237::: time:80.91s
# surface_list:  range(27, 37, 3)
# slide pos: [0, 0]
# 	 score:0.4638(th=0.500000), auc=0.875231::: time:106.84s
# slide pos: [128, 0]
# 	 score:0.4594(th=0.500000), auc=0.878494::: time:126.60s
# slide pos: [0, 128]
# 	 score:0.4427(th=0.450000), auc=0.878282::: time:145.41s
# slide pos: [128, 128]
# 	 score:0.4596(th=0.550000), auc=0.878568::: time:163.51s
# surface_list:  range(25, 35, 3)
# slide pos: [0, 0]
# 	 score:0.4922(th=0.500000), auc=0.882242::: time:189.31s
# slide pos: [128, 0]
# 	 score:0.4990(th=0.500000), auc=0.885222::: time:207.37s
# slide pos: [0, 128]
# 	 score:0.4812(th=0.500000), auc=0.882607::: time:225.17s
# slide pos: [128, 128]
# 	 score:0.5018(th=0.450000), auc=0.884728::: time:243.59s
# [fold0] slice ave score:0.5152(th=0.500000), auc=0.895161
# -- fold1 slide inference start --
# surface_list:  range(26, 36, 3)
# slide pos: [0, 0]
# 	 score:0.4331(th=0.150000), auc=0.810572::: time:360.38s
# slide pos: [128, 0]
# wandb: Network error (ConnectionError), entering retry loop.
# 	 score:0.4353(th=0.200000), auc=0.810134::: time:429.51s
# slide pos: [0, 128]
# wandb: Network error (ConnectionError), entering retry loop.
# 	 score:0.4351(th=0.200000), auc=0.811218::: time:497.65s
# slide pos: [128, 128]
# wandb: Network error (ConnectionError), entering retry loop.
# 	 score:0.4292(th=0.200000), auc=0.812641::: time:566.22s
# surface_list:  range(27, 37, 3)
# slide pos: [0, 0]
# 	 score:0.4286(th=0.200000), auc=0.808147::: time:661.81s
# slide pos: [128, 0]
# wandb: Network error (ConnectionError), entering retry loop.
# 	 score:0.4359(th=0.200000), auc=0.807122::: time:732.38s
# slide pos: [0, 128]
# 	 score:0.4230(th=0.150000), auc=0.809622::: time:801.23s
# slide pos: [128, 128]
# wandb: Network error (ConnectionError), entering retry loop.
# 	 score:0.4285(th=0.150000), auc=0.808854::: time:869.56s
# surface_list:  range(25, 35, 3)
# slide pos: [0, 0]
# 	 score:0.4389(th=0.200000), auc=0.808732::: time:967.58s
# slide pos: [128, 0]
# 	 score:0.4324(th=0.150000), auc=0.810313::: time:1037.67s
# slide pos: [0, 128]
# 	 score:0.4363(th=0.200000), auc=0.808063::: time:1107.72s
# slide pos: [128, 128]
# 	 score:0.4268(th=0.150000), auc=0.811132::: time:1175.79s
# [fold1] slice ave score:0.4674(th=0.150000), auc=0.822831
# -- fold2 slide inference start --
# surface_list:  range(26, 36, 3)
# slide pos: [0, 0]
# 	 score:0.4824(th=0.700000), auc=0.879372::: time:1265.94s
# slide pos: [128, 0]
# 	 score:0.4733(th=0.650000), auc=0.881135::: time:1288.18s
# slide pos: [0, 128]
# 	 score:0.4849(th=0.700000), auc=0.876432::: time:1310.03s
# slide pos: [128, 128]
# 	 score:0.4660(th=0.650000), auc=0.879649::: time:1332.14s
# surface_list:  range(27, 37, 3)
# slide pos: [0, 0]
# 	 score:0.4584(th=0.600000), auc=0.876205::: time:1362.48s
# slide pos: [128, 0]
# 	 score:0.4580(th=0.600000), auc=0.880074::: time:1384.40s
# slide pos: [0, 128]
# 	 score:0.4538(th=0.600000), auc=0.874256::: time:1406.32s
# slide pos: [128, 128]
# 	 score:0.4524(th=0.650000), auc=0.877968::: time:1428.45s
# surface_list:  range(25, 35, 3)
# slide pos: [0, 0]
# 	 score:0.4911(th=0.700000), auc=0.877861::: time:1458.80s
# slide pos: [128, 0]
# 	 score:0.4793(th=0.700000), auc=0.878650::: time:1480.95s
# slide pos: [0, 128]
# 	 score:0.4962(th=0.700000), auc=0.876289::: time:1502.55s
# slide pos: [128, 128]
# 	 score:0.4725(th=0.700000), auc=0.877891::: time:1524.39s
# [fold2] slice ave score:0.5032(th=0.650000), auc=0.889456
# fold[0] slice ave score:0.5152(th=0.895161), auc=0.500000
# fold[1] slice ave score:0.4674(th=0.822831), auc=0.150000
# fold[2] slice ave score:0.5032(th=0.889456), auc=0.650000
# CPU times: user 19min 56s, sys: 3min 40s, total: 23min 36s
# Wall time: 25min 41s

# %%
import yaml
with open(os.path.join(CFG["OUTPUT_DIR"], "Config.yaml"), "w") as f:
    yaml.dump(CFG, f)

# %%
if not CFG["DEBUG"]:
    wandb.finish()
