# %% [markdown]
# # ex012
# img size 128

# %%
import gc
import os
import random
import time
import math

import cv2
import numpy as np
import matplotlib.pyplot as plt

# model
import torch
import torchvision
import torch.nn as nn
import timm
from torchvision.models.feature_extraction import create_feature_extractor
import torchvision.transforms.functional as TF

# data loader
import albumentations as A
from albumentations.pytorch import ToTensorV2
from torch.utils.data import DataLoader, Dataset

# training
from torch.optim import SGD, Adam, AdamW
from torch.optim.lr_scheduler import CosineAnnealingLR, CosineAnnealingWarmRestarts, ReduceLROnPlateau

# metric
from sklearn.metrics import fbeta_score, roc_auc_score

import wandb

# %% [markdown]
# # config

# %%
BASE_DIR = "/working/"
INPUT_DIR = os.path.join(BASE_DIR, "input", "vesuvius-challenge-ink-detection")
TRAIN_DIR = os.path.join(INPUT_DIR, "train")
TEST_DIR = os.path.join(INPUT_DIR, "test")
# IMG_SIZE = [256, 256]
IMG_SIZE = [128, 128]
SURFACE_LIST = [
                range(26, 36, 3),
                range(27, 37, 3),                
                range(25, 35, 3),
                ]
print(len(SURFACE_LIST[0]))
print(SURFACE_LIST)

SURFACE_NUM = len(SURFACE_LIST[0])
# print("Start surface idx =",START_SURFACE)

# SLIDE_POS_LIST = [[idx*(IMG_SIZE[0]//6), idx*(IMG_SIZE[1]//6)] for idx in range(0, 3)]
SLIDE_POS_LIST = [[0,0], [IMG_SIZE[0]//2, 0], [0, IMG_SIZE[1]//2], [IMG_SIZE[0]//2, IMG_SIZE[1]//2]]
print("SLIDE_POS_LIST =", SLIDE_POS_LIST)
CFG = {
    "DEBUG" : False,
    # exp setting
    "EXP_CATEGORY" : "makebase",
    "EXP_NAME" : "exp012",
    "folds" : [0, 1, 2],

    # model
    # "model_name" : "tf_efficientnet_b0",
    "model_name" : "tf_efficientnet_b6",
    "inp_channels" : SURFACE_NUM,
    "out_channels" : 1,
    "pretrained" : True,
    "out_indices" : [0,1,2,3,4],
 
    # data   
    "img_size": IMG_SIZE,
    "batch_size": 64,
    # "batch_size": 16,#batch normの関係か？16の方が64より安定してそう？？
    "INPUT_DIR": INPUT_DIR,
    "TRAIN_DIR": TRAIN_DIR,
    "TEST_DIR": TEST_DIR,
    "surface_num": SURFACE_NUM,
    "surface_list": SURFACE_LIST,
    "slide_pos_list": SLIDE_POS_LIST,
#     "surface_start_idx": START_SURFACE,
    "TRAIN_DIR_LIST": [["1", "2"], ["1", "3"], ["2", "3"]],
#     "TRAIN_IDX_LIST" : ["1"],
    "VALID_DIR_LIST": [["3"],["2"],["1"]],
    "TEST_DIR_LIST": ["a", "b"],

    # learning
    "n_epoch" : 15,
    "lr" : 1e-3,
    "T_max" : 5,
    "min_lr" : 1e-8,
    "weight_decay" : 1e-6,

    # etc
    "print_freq" : 1000,
    "random_seed" : 21,
    "num_workers": 2,
}


if CFG["model_name"]=="tf_efficientnet_b0":
    CFG["channel_nums"] = [320, 112, 40, 24, 16]
elif CFG["model_name"]=="tf_efficientnet_b4":
    CFG["channel_nums"] = [448, 160, 56, 32, 24]
elif CFG["model_name"]=="tf_efficientnet_b6":
    CFG["channel_nums"] = [576, 200, 72, 40, 32]


if CFG["DEBUG"]:
    CFG["n_epoch"] = 1
    CFG["EXP_NAME"] = "DEBUG"
    

CFG["OUTPUT_DIR"] = os.path.join(BASE_DIR, "output", CFG["EXP_NAME"])
# Out:
# 4
# [range(26, 36, 3), range(27, 37, 3), range(25, 35, 3)]
# SLIDE_POS_LIST = [[0, 0], [64, 0], [0, 64], [64, 64]]

# %%
if not CFG["DEBUG"]:
    os.makedirs(CFG["OUTPUT_DIR"])
    os.makedirs(os.path.join(CFG["OUTPUT_DIR"], "imgs"))

# %%
if not CFG["DEBUG"]:
    WANDB_CONFIG = {'competition': 'vcid', '_wandb_kernel': 'taro'}
    os.environ["WANDB_SILENT"] = "true"
    wandb.init(project=WANDB_CONFIG["competition"], config=CFG, group=CFG["EXP_CATEGORY"], name=CFG["EXP_NAME"], reinit=True)
# Out:
# 2023-04-17 02:45:04.053492: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-17 02:45:04.133566: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-17 02:45:04.714251: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-17 02:45:04.714320: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-17 02:45:04.714327: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# # utils

# %%
def logging_metrics_epoch(CFG, fold, epoch, slice_idx,train_loss_avg, valid_loss_avg, score, threshold, auc_score):
    wandb.log({f"train/fold{fold}": train_loss_avg,
                f"valid/fold{fold}": valid_loss_avg,
                f"score/fold{fold}":score,
                f"score threshold/fold{fold}":threshold,
                f"auc/fold{fold}":auc_score,
                f"epoch/fold{fold}":epoch+slice_idx*CFG["n_epoch"],
                })

#     wandb.log({f"train/fold{fold}": train_loss_avg,
#             f"valid/fold{fold}": valid_loss_avg}, step=epoch+slice_idx*CFG["n_epoch"])
#     wandb.log({f"score/fold{fold}":score,
#                 f"score threshold/fold{fold}":threshold,
#                 f"auc/fold{fold}":auc_score,
#                 }, step=epoch+slice_idx*CFG["n_epoch"])

    # wandb.log({"loss avg":{f"train/fold{fold}": train_loss_avg,
    #                         f"valid/fold{fold}": valid_loss_avg}}, step=epoch+slice_idx*CFG["n_epoch"])
    # wandb.log({"Metircs" : {f"score/fold{fold}":score,
    #                         f"score threshold/fold{fold}":threshold,
    #                         f"auc/fold{fold}":auc_score,
    #                         }}, step=epoch+slice_idx*CFG["n_epoch"])

# %%
def seed_everything(seed=CFG["random_seed"]):
    #os.environ['PYTHONSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic =True
    torch.backends.cudnn.benchmark = False
seed_everything()

# device optimization
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
def asMinutes(s):
    """Convert Seconds to Minutes."""
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    """Accessing and Converting Time Data."""
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))

class AverageMeter(object):
    """Computes and stores the average and current value."""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# # metric

# %%
def fbeta_numpy(targets, preds, beta=0.5, smooth=1e-5):
    y_true_count = targets.sum()
    ctp = preds[targets==1].sum()
    cfp = preds[targets==0].sum()
    beta_squared = beta * beta

    c_precision = ctp / (ctp + cfp + smooth)
    c_recall = ctp / (y_true_count + smooth)
    dice = (1 + beta_squared) * (c_precision * c_recall) / (beta_squared * c_precision + c_recall + smooth)

    return dice

def calc_fbeta_auc(mask, mask_pred):
    mask = mask.astype(int).flatten()
    mask_pred = mask_pred.flatten()

    best_th = 0
    best_dice = 0
    dice_list = [] 
    # for th in np.array(range(10, 50+1, 5)) / 100:
    for th in np.array(range(10, 100+1, 5)) / 100:
        # dice = fbeta_score(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice = fbeta_numpy(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice_list.append(dice)
        # print(f'\t th: {th}, fbeta: {dice}')
        if dice > best_dice:
            best_dice = dice
            best_th = th
    
    auc = roc_auc_score(mask, mask_pred)
    # Logger.info(f'best_th: {best_th}, fbeta: {best_dice}')
    return best_dice, best_th, auc, dice_list


def calc_cv(mask_gt, mask_pred):
    best_dice, best_th, auc, dice_list = calc_fbeta_auc(mask_gt, mask_pred)

    return best_dice, best_th, auc, dice_list

# %% [markdown]
# # model

# %%
class Encoder(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = timm.create_model(CFG["model_name"], in_chans=CFG["inp_channels"], features_only=True, out_indices=CFG["out_indices"], pretrained=CFG["pretrained"])
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        return skip_connection_list

class UpConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.bn1 = nn.BatchNorm2d(in_channels)
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size = 2, padding="same")
        self.bn2 = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        x = self.up(x)
        x = self.bn1(x)
        x = self.conv(x)
        x = self.bn2(x)
        return x


class Decoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.UpConv_0 = UpConv(CFG["channel_nums"][0], CFG["channel_nums"][1])
        self.UpConv_1 = UpConv(CFG["channel_nums"][1]*2, CFG["channel_nums"][2])
        self.UpConv_2 = UpConv(CFG["channel_nums"][2]*2, CFG["channel_nums"][3])
        self.UpConv_3 = UpConv(CFG["channel_nums"][3]*2, CFG["channel_nums"][4])
        self.UpConv_4 = UpConv(CFG["channel_nums"][4]*2, CFG["channel_nums"][4])
    
    def forward(self, skip_connection_list):
        emb = self.UpConv_0(skip_connection_list[4]) # emb.shape = (None, 160, 14, 14)
        emb_cat = torch.cat([skip_connection_list[3], emb], dim = 1)
        
        emb = self.UpConv_1(emb_cat)
        emb_cat = torch.cat([skip_connection_list[2], emb], dim = 1)
        
        emb = self.UpConv_2(emb_cat)
        emb_cat = torch.cat([skip_connection_list[1], emb], dim = 1)
        
        emb = self.UpConv_3(emb_cat)
        emb_cat = torch.cat([skip_connection_list[0], emb], dim = 1)

        emb_cat = self.UpConv_4(emb_cat)
        
        return emb_cat

class SegModel(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = Encoder(CFG)
        self.decoder = Decoder()
        self.head = nn.Sequential(
            nn.Conv2d(CFG["channel_nums"][-1], CFG["out_channels"], kernel_size=1, stride=1, padding=0),
            nn.Sigmoid()
        )
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        emb = self.decoder(skip_connection_list)
        output = self.head(emb)
        return output

# %% [markdown]
# # Dataset

# %%
train_transforms = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.RandomCrop(int(CFG["img_size"][0]*0.8), int(CFG["img_size"][1]*0.8), p=0.5),
    A.Blur(blur_limit=3, p=0.3),
    A.Resize(CFG["img_size"][0], CFG["img_size"][1]),
    ToTensorV2(),
])

valid_transforms = A.Compose([
    ToTensorV2(),
])

# %%
def fft_transform(img):
    eps = 1e-7
    f = np.fft.fft2(img)
    fshift = np.fft.fftshift(f)
    fshift = np.nan_to_num(fshift)+eps#nanを0埋め
    magnitude_spectrum = 20*np.log(np.abs(fshift))
    return magnitude_spectrum

def highpass_filter(img):
    frange = 1
    dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
    dft_shift = np.fft.fftshift(dft)

    rows, cols = img.shape
    crow,ccol = rows//2 , cols//2

    # create a mask first, center square is 1, remaining all zeros
    mask = np.ones((rows,cols,2),np.uint8)
    mask[crow-frange:crow+frange, ccol-frange:ccol+frange] = 0

    # apply mask and inverse DFT
    fshift = dft_shift*mask
    f_ishift = np.fft.ifftshift(fshift)
    img_back = cv2.idft(f_ishift)
    img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

    return img_back

def lowpass_filter(img):
    frange = 5
    dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
    dft_shift = np.fft.fftshift(dft)

    rows, cols = img.shape
    crow,ccol = rows//2 , cols//2

    # create a mask first, center square is 1, remaining all zeros
    mask = np.zeros((rows,cols,2),np.uint8)
    mask[crow-frange:crow+frange, ccol-frange:ccol+frange] = 1

    # apply mask and inverse DFT
    fshift = dft_shift*mask
    f_ishift = np.fft.ifftshift(fshift)
    img_back = cv2.idft(f_ishift)
    img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

    return img_back

# %%
class VCID_Dataset(Dataset):
    def __init__(self, CFG, data_dir_list, surface_list, surface_volumes=None, slide_pos=[0,0], mode="train", transform=None):
        # get config
        self.mode = mode
        self.img_size = CFG["img_size"]
        if self.mode=="train":  self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode=="valid":    self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode == "test":   self.DATADIR = CFG["TEST_DIR"]
        self.data_dir_list = data_dir_list
        self.surface_list = surface_list
        self.slide_pos = slide_pos
        self.transform = transform
        
        # get imgs
        # print("initializing dataset...")
        self.imgs = []
        for data_dir in self.data_dir_list:
            img_path = os.path.join(self.DATADIR, data_dir, "mask.png")
            # print(img_path)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            img = img.reshape(img.shape[0], img.shape[1], 1) # (h, w, channel=1)
            self.imgs.append(img)
        
        # check imgs
        for img in self.imgs:
            assert img is not None, "img is None. data path is wrong"
        # get and split surface
        if surface_volumes is None:
            self.surface_vols = self.read_surfacevols()
        else:
            # print("using loaded surface_vols")
            self.surface_vols = surface_volumes
        for surface_vol in self.surface_vols:
            assert surface_vol is not None, "surface_vol is None. data path is wrong"
       
        # split grid
        self.get_all_grid()
        self.fileter_grid()
        self.get_flatten_grid()
        # print("split grid done.") 
       
        # get label imgs
        if self.mode == "train" or self.mode == "valid":
            self.labels = []
            for data_dir in self.data_dir_list:
                label_path = os.path.join(self.DATADIR, data_dir, "inklabels.png")
                assert os.path.exists(label_path), f"{label_path} is not exist."
                
                # read label
                label = cv2.imread(label_path, cv2.IMREAD_GRAYSCALE)
                # mask erosion
                kernel_size = (img.shape[0]+img.shape[1])//2//100
                kernel = np.ones((kernel_size, kernel_size), np.uint8)
                img = cv2.erode(img, kernel,iterations = 3)
                
                label = label.reshape(label.shape[0], label.shape[1], 1) # (h, w, channel=1)
                self.labels.append(label)# 画像サイズがそれぞれ違うので単純にconcatできずlist化しているs
        # print("initializing dataset done.")

    def get_surface_volumes(self):
        return self.surface_vols

    def read_surfacevols(self):
        """ read surface volume by data_dir_list and surface_list 
            Returns:surface_vuls (list): surface volume list [array(h,w,channel=surface_num), array(), ...]
        """
        surface_vols = []
        # print("reading surface volume...")
        for data_dir in self.data_dir_list:
            surface_vol_ = None
            for read_idx, surface_idx in enumerate(self.surface_list):
                # print("\r", f"reading idx : {read_idx+1}/{len(self.surface_list)}", end="")
                surface_path = os.path.join(self.DATADIR, data_dir, "surface_volume", f"{surface_idx:02}.tif")
                surface_vol = cv2.imread(surface_path, cv2.IMREAD_GRAYSCALE)
                surface_vol = surface_vol.reshape(surface_vol.shape[0], surface_vol.shape[1], 1) # (h, w, channel=1)
                if surface_vol_ is None:
                    surface_vol_ = surface_vol
                else:
                    surface_vol_ = np.concatenate([surface_vol_, surface_vol], axis=2) # (h, w, channel=surface_num)
            surface_vols.append(surface_vol_)
            # print(f"  => read surface volume done. [{data_dir}]")
        return surface_vols


    def get_grid_img(self, img, grid_idx):
        """ crop grid img from original img"""
        img_grid = img[grid_idx[0]*self.img_size[0] + self.slide_pos[0] : (grid_idx[0]+1)*self.img_size[0] + self.slide_pos[0],
                        grid_idx[1]*self.img_size[1] + self.slide_pos[1] : (grid_idx[1]+1)*self.img_size[1] + self.slide_pos[1]]
        return img_grid
    
    
    def get_masked_img(self, img, mask):
        """ multiply mask to surface_volumes """
        masked_img = None
        for channel in range(img.shape[2]):
            img_channel = img[:,:,channel].reshape(img.shape[0], img.shape[1],1)
            masked = img_channel*mask
            if masked_img is None:
                masked_img = masked.reshape(masked.shape[0], masked.shape[1], 1)
            else:
                masked = masked.reshape(masked.shape[0], masked.shape[1], 1)
                masked_img = np.concatenate([masked_img, masked], axis=2)
        return masked_img
    
    def get_grid_hpfimg(self, img, grid_idx):
        """ crop grid img from original img and hpf filter """
        img_grid = self.get_grid_img(img, grid_idx)
        img_transformed = None
        for channel in range(img_grid.shape[2]):
            img_grid_trans = highpass_filter(img_grid[:,:,channel])
            if img_transformed is None:
                img_transformed = img_grid_trans.reshape(img_grid_trans.shape[0], img_grid_trans.shape[1], 1)
            else:
                img_transformed = np.concatenate([img_transformed, img_grid_trans.reshape(img_grid_trans.shape[0], img_grid_trans.shape[1], 1)], axis=2)
        return img_transformed
    
    def get_all_grid(self):
        """ get all grid indices by img size and grid size
        """
        self.grid_indices = []
        for img in self.imgs:
            self.x_grid_size = (img.shape[0] - self.slide_pos[0]) // self.img_size[0]
            self.y_grid_size = (img.shape[1] - self.slide_pos[1]) // self.img_size[1]
            grid_img = []
            for i in range(self.x_grid_size):
                for j in range(self.y_grid_size):
                    grid_img.append([i, j])
            self.grid_indices.append(grid_img)
        return self.grid_indices
          
    def fileter_grid(self):
        """ get grid indices which mask is not 0 by all grid indices"""
        grid_indices_all = []
        for img, grid_indices in zip(self.imgs, self.grid_indices):
            grid_indices_copy = grid_indices.copy()
            for grid_idx in grid_indices:
                img_grid = self.get_grid_img(img, grid_idx)
                if img_grid.sum() == 0:
                    grid_indices_copy.remove(grid_idx)
            grid_indices_all.append(grid_indices_copy)
        self.grid_indices = grid_indices_all
        return self.grid_indices

    def get_flatten_grid(self):
        """ get flatten index list by grid indices
            Returns:flatten_grid (list): flatten index list [[img_idx, grid_idx], [img_idx, grid_idx], ...]
        """
        flatten_grid = []
        for img_idx, grid_indices in enumerate(self.grid_indices):
            for grid_idx in grid_indices:
                grid_imgidx_list = [img_idx]
                grid_imgidx_list.extend(grid_idx)
                flatten_grid.append(grid_imgidx_list)
        self.flatten_grid = flatten_grid
        return self.flatten_grid

    def __len__(self):
        return len(self.flatten_grid)

    def __getitem__(self, idx):
        # get indices
        img_grid_idx = self.flatten_grid[idx]
        img_idx = img_grid_idx[0]
        grid_idx = img_grid_idx[1:]
        # get img & surface_vol
        img = self.imgs[img_idx]
        surface_vol = self.surface_vols[img_idx]
        img = self.get_grid_img(img, grid_idx)/255.
        surface_vol = self.get_grid_img(surface_vol, grid_idx)/255.
        
        # multiple small mask 
        surface_vol = self.get_masked_img(surface_vol, img)
        assert surface_vol.shape[0]==img.shape[0] and surface_vol.shape[1]==img.shape[1] , "surface_vol_list shape is not same as img shape"
        img = surface_vol

        # transform
        if self.mode == "test":
            if self.transform:
                img = self.transform(image=img)["image"]
            else:
                img = img.transpose(2, 0, 1)
                img = torch.tensor(img, dtype=torch.float32)
            return img, grid_idx
        elif self.mode == "train" or self.mode=="valid":
            # get label(segmentation mask)
            label = self.labels[img_idx]
            label = self.get_grid_img(label, grid_idx)
            if self.transform:
                transformed = self.transform(image=img, mask=label)
                img = transformed["image"]
                label = transformed["mask"]
                label = label.permute(2, 0, 1)/255. # (channel, h, w)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            else:
                img = img.transpose(2, 0, 1) # (channel, h, w)
                label = label.transpose(2, 0, 1)/255. # (channel, h, w){}
                img = torch.tensor(img, dtype=torch.float32)
                label = torch.tensor(label, dtype=torch.float32)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            return img, label, grid_idx

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train")
# surface_volumes = dataset_notrans.surface_vols
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 1:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos=[0,50],mode="train")
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 1:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train", transform=train_transforms)
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)


# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 0:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %% [markdown]
# # train valid fn

# %%
def train_fn(train_loader, model, criterion, epoch ,optimizer, scheduler):
    model.train()
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, _) in enumerate(train_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()     
        preds = model(images)
        
        # preds = torch.sigmoid(preds)
        loss = criterion(preds, targets)
        
        losses.update(loss.item(), CFG["batch_size"]) 
        targets = targets.detach().cpu().numpy().ravel().tolist()
        preds = preds.detach().cpu().numpy().ravel().tolist()
        loss.backward() # パラメータの勾配を計算
        optimizer.step() # モデル更新
        optimizer.zero_grad() # 勾配の初期化
                
        batch_time.update(time.time() - end)
        end = time.time()
        if batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(train_loader)-1):
            print('Epoch: [{0}][{1}/{2}] '
                    'Elapsed {remain:s} '
                    'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                    .format(
                        epoch, batch_idx, len(train_loader), batch_time=batch_time, loss=losses,
                        remain=timeSince(start, float(batch_idx+1)/len(train_loader)),
            ))
        del preds, images, targets
    gc.collect()
    torch.cuda.empty_cache()
    return losses.avg

# %%
def valid_fn(model, valid_loader, criterion=None):
    model.eval()# モデルを検証モードに設定
    test_targets = []
    test_preds = []
    test_grid_idx = []
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, grid_idx) in enumerate(valid_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()
        with torch.no_grad():
            preds = model(images)
            if not criterion is None:
                loss = criterion(preds, targets)
        if not criterion is None:
            losses.update(loss.item(), CFG["batch_size"])
        batch_time.update(time.time() - end)

        targets = targets.detach().cpu().numpy()
        preds = preds.detach().cpu().numpy()
        
        test_preds.extend([preds[idx, :,:,:].transpose(1,2,0) for idx in range(preds.shape[0])])
        test_targets.extend([targets[idx, :,:,:].transpose(1,2,0) for idx in range(targets.shape[0])])
        test_grid_idx.extend([[x_idx, y_idx] for x_idx, y_idx in zip(grid_idx[0].tolist(), grid_idx[1].tolist())])

        if (batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(valid_loader)-1)) and (not criterion is None):
            print('EVAL: [{0}/{1}] '
                'Elapsed {remain:s} '
                'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                .format(
                    batch_idx, len(valid_loader), batch_time=batch_time, loss=losses,
                    remain=timeSince(start, float(batch_idx+1)/len(valid_loader)),
                ))
        del preds, images, targets
        gc.collect()
        torch.cuda.empty_cache()
    if criterion is None:
        return test_targets, test_preds, test_grid_idx
    else:
        return test_targets, test_preds, test_grid_idx, losses.avg

# %% [markdown]
# # training loop

# %%
# def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list):
#     # concat pred img and label to original size
#     img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
#     img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
#     img = img.reshape(img.shape[0], img.shape[1], 1)
#     pred_img = np.zeros_like(img).astype(np.float32)
#     label_img = np.zeros_like(img).astype(np.float32)
#     for img_idx, grid_idx in enumerate(grid_idx_list):
#         pred_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += img_list[img_idx]
        
#         label_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += label_list[img_idx]
#     return pred_img, label_img

# %%
def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list, slide_pos=[0,0]):
    # concat pred img and label to original size
    img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    img = img.reshape(img.shape[0], img.shape[1], 1)
    pred_img = np.zeros_like(img).astype(np.float32)
    label_img = np.zeros_like(img).astype(np.float32)
    for img_idx, grid_idx in enumerate(grid_idx_list):
        pred_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += img_list[img_idx]
        
        label_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += label_list[img_idx]
    return pred_img, label_img

# %%
def save_and_plot_oof(mode, fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary):
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_pred_img.png"), valid_preds_img*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_predbin_img.png"), valid_preds_binary*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_targets_img.png"), valid_targets_img*255)
    
    # plot preds & binary preds
    # plt.figure(dpi=100)
    # plt.subplot(1,3,1)
    # plt.imshow(valid_preds_img)
    # plt.subplot(1,3,2)
    # plt.imshow(valid_preds_binary)
    # plt.subplot(1,3,3)
    # plt.imshow(valid_targets_img)
    # plt.show()

# %%
def training_loop(CFG):
    best_score_list = []
    best_threshold_list = []
    best_epoch_list = []
    slice_ave_score_list = []
    slice_ave_auc_list = []
    slice_ave_score_threshold_list = []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} training start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        model = model.to(device)
        valid_img_slice = []
        criterion = nn.BCELoss()
        optimizer = AdamW(model.parameters(), lr=CFG["lr"], weight_decay=CFG["weight_decay"], amsgrad=False)
        scheduler = CosineAnnealingLR(optimizer, T_max=CFG["T_max"], eta_min=CFG["min_lr"], last_epoch=-1)
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            # separate train/valid data 
            train_dirs = CFG["TRAIN_DIR_LIST"][fold]
            valid_dirs = CFG["VALID_DIR_LIST"][fold]
            train_dataset = VCID_Dataset(CFG, train_dirs, surface_list, mode="train", transform=train_transforms)
            valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, mode="valid", transform=valid_transforms)
            train_loader = DataLoader(train_dataset, batch_size=CFG["batch_size"], shuffle = True,
                                        num_workers = CFG["num_workers"], pin_memory = True)
            valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                        num_workers = CFG["num_workers"], pin_memory = True)

            # training
            best_score = -np.inf
            best_auc = -np.inf
            best_valloss = np.inf
            best_auc_valloss = np.inf
            best_threshold = -1
            start_time = time.time()
            best_epoch = -1
            best_auc_epoch = -1
            for epoch in range(1, CFG["n_epoch"] + 1):
                epochs_ = epoch + CFG["n_epoch"] * slice_idx
                print(f'- epoch:{epochs_} -')
                train_loss_avg = train_fn(train_loader, model, criterion, epochs_ ,optimizer, scheduler)
                valid_targets, valid_preds, valid_grid_idx, valid_loss_avg = valid_fn(model, valid_loader, criterion)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                
                elapsed = time.time() - start_time
                print(f"\t epoch:{epochs_}, avg train loss:{train_loss_avg:.4f}, avg valid loss:{valid_loss_avg:.4f}")
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                if not CFG["DEBUG"]:
                    logging_metrics_epoch(CFG, fold, epoch, slice_idx, train_loss_avg, valid_loss_avg, valid_score, valid_threshold, auc)
                scheduler.step()
                # validationスコアがbestを更新したらモデルを保存する
                if valid_score > best_score:
                    best_epoch = epochs_
                    best_valloss = valid_loss_avg
                    best_score = valid_score
                    best_threshold = valid_threshold
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epochs_} - Save Best Score: {best_score:.4f}. Model is saved.')
                    print("dice_list: ", dice_list)
                    # save oof
                    save_and_plot_oof("score", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
                
                if auc > best_auc:
                    best_auc = auc
                    best_auc_epoch = epochs_
                    best_auc_valloss = valid_loss_avg
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_auc_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epochs_} - Save Best AUC: {best_auc:.4f}. Model is saved.')
                    # save oof
                    save_and_plot_oof("auc", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
            valid_img_slice.append(valid_preds_img)
        valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        for idx in range(len(SURFACE_LIST)):
            valid_pred_slice = valid_img_slice[idx]
            valid_slice_ave += valid_pred_slice
        valid_slice_ave /= len(CFG["folds"])
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_slice_ave)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)
 
        valid_slice_binary = (valid_slice_ave > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 999, valid_slice_ave, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
        
        print(f'[fold{fold}] BEST Epoch {best_epoch} - Save Best Score:{best_score:.4f}. Best loss:{best_valloss:.4f}')
        print(f'[fold{fold}] BEST AUC Epoch {best_auc_epoch} - Save Best Score:{best_auc:.4f}. Best loss:{best_auc_valloss:.4f}')
            
        best_score_list.append(best_score)
        best_threshold_list.append(best_threshold)
        best_epoch_list.append(best_epoch)
        del model, train_loader, train_dataset, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
        
    for fold, (best_score, best_threshold, best_epoch) in enumerate(zip(best_score_list, best_threshold_list, best_epoch_list)):
        print(f"fold[{fold}] BEST SCORE = {best_score:.4f} thr={best_threshold} (epoch={best_epoch})")
        print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    return best_score_list, best_threshold_list, best_epoch_list

# %% [markdown]
# # slice inference

# %%
def slide_inference(CFG):
    start_time = time.time()
    slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list = [], [], []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} slide inference start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        # model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_fold{fold}.pth')
        model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_auc_fold{fold}.pth')
        model.load_state_dict(torch.load(model_path))
        model = model.to(device)
        valid_img_slice = []
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            surface_volumes = None
            for slide_pos in CFG["slide_pos_list"]:
                print("slide pos:", slide_pos)
                valid_dirs = CFG["VALID_DIR_LIST"][fold]
                valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos, mode="valid", transform=valid_transforms)
                surface_volumes = valid_dataset.get_surface_volumes()
                valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                            num_workers = CFG["num_workers"], pin_memory = True)

                valid_targets, valid_preds, valid_grid_idx = valid_fn(model, valid_loader)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs, slide_pos)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                save_and_plot_oof("slide", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary) 
                
                elapsed = time.time() - start_time
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                valid_img_slice.append(valid_preds_img)
            valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        for idx in range(len(SURFACE_LIST)*len(CFG["slide_pos_list"])):
            valid_pred_slice = valid_img_slice[idx]
            valid_slice_ave += valid_pred_slice
        valid_slice_ave /= len(SURFACE_LIST)*len(CFG["slide_pos_list"])
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_slice_ave)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)

        valid_slice_binary = (valid_slice_ave > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 555, valid_slice_ave, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
         
        del model, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
    return slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list

# %% [markdown]
# # main

# %%
# %%time
best_score_list, best_threshold_list, best_epoch_list = training_loop(CFG)
# Out:
# -- fold0 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/conv.py:444: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at  ../aten/src/ATen/native/Convolution.cpp:744.)
#   self.padding, self.dilation, self.groups)
# Epoch: [1][0/127] Elapsed 0m 1s (remain 2m 7s) Loss: 0.6982(0.6982)
# Epoch: [1][126/127] Elapsed 0m 38s (remain 0m 0s) Loss: 0.4720(0.5891)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.4977(0.4977)
# EVAL: [25/26] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4108(0.4766)
# 	 epoch:1, avg train loss:0.5891, avg valid loss:0.4766
# 	 score:0.3561(th=0.600000), auc=0.830787::: time:55.43s
# Epoch 1 - Save Best Score: 0.3561. Model is saved.
# dice_list:  [0.14293003087988176, 0.14299185618591317, 0.1514844232780552, 0.16868966201948185, 0.2094987160255293, 0.25247392032857663, 0.2893944406455187, 0.31605805338398835, 0.33621516289627007, 0.35184007566168485, 0.35609566150541433, 0.34538672316593255, 0.32078455096498315, 0.27534276385350465, 0.20285963451557587, 0.11186428679978755, 0.04575846140914602, 0.010359935880763442, 0.0]
# Epoch 1 - Save Best AUC: 0.8308. Model is saved.
# - epoch:2 -
# Epoch: [2][0/127] Elapsed 0m 0s (remain 1m 59s) Loss: 0.5482(0.5482)
# Epoch: [2][126/127] Elapsed 0m 38s (remain 0m 0s) Loss: 0.4042(0.4378)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1754(0.1754)
# EVAL: [25/26] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2557(0.3095)
# 	 epoch:2, avg train loss:0.4378, avg valid loss:0.3095
# 	 score:0.4527(th=0.500000), auc=0.860896::: time:114.40s
# Epoch 2 - Save Best Score: 0.4527. Model is saved.
# dice_list:  [0.21044502097950837, 0.2748266889465554, 0.32818116286840665, 0.37178111362910865, 0.4031990149380509, 0.42333122160057146, 0.4347215367633648, 0.4439908822426542, 0.45272783583778076, 0.4462517257632839, 0.4138105009299343, 0.35160937524426633, 0.27280010585308173, 0.19262797339851506, 0.11929908649271966, 0.056458035479009246, 0.017351541323551843, 0.0029295763685775254, 0.0]
# Epoch 2 - Save Best AUC: 0.8609. Model is saved.
# - epoch:3 -
# Epoch: [3][0/127] Elapsed 0m 0s (remain 1m 41s) Loss: 0.3864(0.3864)
# Epoch: [3][126/127] Elapsed 0m 38s (remain 0m 0s) Loss: 0.3588(0.3826)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1552(0.1552)
# EVAL: [25/26] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2519(0.2987)
# 	 epoch:3, avg train loss:0.3826, avg valid loss:0.2987
# 	 score:0.4657(th=0.500000), auc=0.869593::: time:173.23s
# Epoch 3 - Save Best Score: 0.4657. Model is saved.
# dice_list:  [0.23573144889860623, 0.29871610530286574, 0.350856280528807, 0.3882245227833358, 0.4151822183529025, 0.4338582644057472, 0.44733958208026137, 0.4591863290544966, 0.46572246201249906, 0.46314140738568216, 0.44538685236286085, 0.41408792156404484, 0.3570443800516761, 0.2607949638966672, 0.1418581431382311, 0.05439955232285489, 0.010815410226754498, 9.612796859589432e-05, 0.0]
# Epoch 3 - Save Best AUC: 0.8696. Model is saved.
# - epoch:4 -
# Epoch: [4][0/127] Elapsed 0m 0s (remain 2m 4s) Loss: 0.3648(0.3648)
# Epoch: [4][126/127] Elapsed 0m 37s (remain 0m 0s) Loss: 0.4370(0.3564)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1144(0.1144)
# EVAL: [25/26] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2286(0.2894)
# 	 epoch:4, avg train loss:0.3564, avg valid loss:0.2894
# 	 score:0.4960(th=0.450000), auc=0.871316::: time:231.72s
# Epoch 4 - Save Best Score: 0.4960. Model is saved.
# dice_list:  [0.26095616868545224, 0.3338589551165759, 0.3879213786387478, 0.42928838299706595, 0.4583665808623424, 0.47739801385802794, 0.4907003357710997, 0.4959713353226498, 0.49032763039104643, 0.47204611588637435, 0.4466286078730446, 0.40389907778859896, 0.3519028411553955, 0.2911768765210871, 0.21337337288365177, 0.13322497642488243, 0.06202385647455997, 0.015526156054433216, 0.0]
# Epoch 4 - Save Best AUC: 0.8713. Model is saved.
# - epoch:5 -
# Epoch: [5][0/127] Elapsed 0m 0s (remain 2m 3s) Loss: 0.3901(0.3901)
# Epoch: [5][126/127] Elapsed 0m 36s (remain 0m 0s) Loss: 0.3330(0.3387)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0921(0.0921)
# EVAL: [25/26] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2448(0.2858)
# 	 epoch:5, avg train loss:0.3387, avg valid loss:0.2858
# 	 score:0.5121(th=0.550000), auc=0.874983::: time:287.96s
# Epoch 5 - Save Best Score: 0.5121. Model is saved.
# dice_list:  [0.3313727197567486, 0.3899143529451368, 0.42751803917448516, 0.4526497536845846, 0.47041684067135303, 0.4831064933465251, 0.4943571848343107, 0.5041662013508826, 0.5118513778296515, 0.5120943475260992, 0.5006211487591994, 0.47835219369233756, 0.44050079840764705, 0.38937567910173226, 0.31901531620333146, 0.23069810893177334, 0.13413815347336813, 0.03435703613285854, 0.0]
# Epoch 5 - Save Best AUC: 0.8750. Model is saved.
# - epoch:6 -
# Epoch: [6][0/127] Elapsed 0m 0s (remain 2m 3s) Loss: 0.3141(0.3141)
# Epoch: [6][126/127] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2813(0.3297)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0975(0.0975)
# EVAL: [25/26] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2419(0.2853)
# 	 epoch:6, avg train loss:0.3297, avg valid loss:0.2853
# 	 score:0.5130(th=0.550000), auc=0.875729::: time:343.87s
# Epoch 6 - Save Best Score: 0.5130. Model is saved.
# dice_list:  [0.32302536457411807, 0.3833878955659803, 0.4209627535822099, 0.44588716928185645, 0.4651263597419044, 0.4801931105804159, 0.4918430704815597, 0.5025534390255204, 0.5113482276537966, 0.5130171920080088, 0.5052011003901183, 0.48522061316198106, 0.4508443244065819, 0.3994105599230247, 0.33184227452280274, 0.2416403435027614, 0.14196190401055528, 0.03689942423551576, 0.0]
# Epoch 6 - Save Best AUC: 0.8757. Model is saved.
# - epoch:7 -
# Epoch: [7][0/127] Elapsed 0m 0s (remain 1m 51s) Loss: 0.3939(0.3939)
# Epoch: [7][126/127] Elapsed 0m 36s (remain 0m 0s) Loss: 0.4465(0.3247)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1149(0.1149)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2480(0.2925)
# 	 epoch:7, avg train loss:0.3247, avg valid loss:0.2925
# 	 score:0.4933(th=0.550000), auc=0.869620::: time:399.95s
# - epoch:8 -
# Epoch: [8][0/127] Elapsed 0m 0s (remain 1m 55s) Loss: 0.3104(0.3104)
# Epoch: [8][126/127] Elapsed 0m 36s (remain 0m 0s) Loss: 0.3353(0.3307)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0862(0.0862)
# EVAL: [25/26] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2690(0.3001)
# 	 epoch:8, avg train loss:0.3307, avg valid loss:0.3001
# 	 score:0.4868(th=0.500000), auc=0.868005::: time:453.20s
# - epoch:9 -
# Epoch: [9][0/127] Elapsed 0m 0s (remain 1m 50s) Loss: 0.3280(0.3280)
# Epoch: [9][126/127] Elapsed 0m 37s (remain 0m 0s) Loss: 0.3216(0.3415)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1204(0.1204)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2400(0.2888)
# 	 epoch:9, avg train loss:0.3415, avg valid loss:0.2888
# 	 score:0.4928(th=0.450000), auc=0.874233::: time:507.35s
# - epoch:10 -
# Epoch: [10][0/127] Elapsed 0m 0s (remain 1m 53s) Loss: 0.3012(0.3012)
# Epoch: [10][126/127] Elapsed 0m 36s (remain 0m 0s) Loss: 0.3941(0.3402)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0338(0.0338)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.3360(0.3305)
# 	 epoch:10, avg train loss:0.3402, avg valid loss:0.3305
# 	 score:0.4613(th=0.200000), auc=0.853551::: time:560.79s
# - epoch:11 -
# Epoch: [11][0/127] Elapsed 0m 0s (remain 1m 44s) Loss: 0.3682(0.3682)
# Epoch: [11][126/127] Elapsed 0m 37s (remain 0m 0s) Loss: 0.3879(0.3315)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0620(0.0620)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2359(0.2916)
# 	 epoch:11, avg train loss:0.3315, avg valid loss:0.2916
# 	 score:0.4968(th=0.450000), auc=0.871323::: time:615.44s
# - epoch:12 -
# Epoch: [12][0/127] Elapsed 0m 0s (remain 2m 0s) Loss: 0.2395(0.2395)
# Epoch: [12][126/127] Elapsed 0m 37s (remain 0m 0s) Loss: 0.3116(0.3196)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0792(0.0792)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2414(0.2968)
# 	 epoch:12, avg train loss:0.3196, avg valid loss:0.2968
# 	 score:0.4857(th=0.400000), auc=0.863821::: time:669.40s
# - epoch:13 -
# Epoch: [13][0/127] Elapsed 0m 1s (remain 2m 10s) Loss: 0.3658(0.3658)
# Epoch: [13][126/127] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2646(0.2998)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0544(0.0544)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2274(0.2945)
# 	 epoch:13, avg train loss:0.2998, avg valid loss:0.2945
# 	 score:0.5107(th=0.350000), auc=0.870933::: time:722.84s
# - epoch:14 -
# Epoch: [14][0/127] Elapsed 0m 0s (remain 1m 57s) Loss: 0.2975(0.2975)
# Epoch: [14][126/127] Elapsed 0m 36s (remain 0m 0s) Loss: 0.4034(0.2779)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0499(0.0499)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2664(0.3061)
# 	 epoch:14, avg train loss:0.2779, avg valid loss:0.3061
# 	 score:0.5007(th=0.400000), auc=0.870553::: time:775.94s
# - epoch:15 -
# Epoch: [15][0/127] Elapsed 0m 1s (remain 2m 17s) Loss: 0.2078(0.2078)
# Epoch: [15][126/127] Elapsed 0m 37s (remain 0m 0s) Loss: 0.3861(0.2559)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0768(0.0768)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2387(0.2936)
# 	 epoch:15, avg train loss:0.2559, avg valid loss:0.2936
# 	 score:0.5050(th=0.450000), auc=0.874914::: time:829.63s
# surface_list:  range(27, 37, 3)
# - epoch:16 -
# Epoch: [16][0/127] Elapsed 0m 0s (remain 1m 47s) Loss: 0.2927(0.2927)
# Epoch: [16][126/127] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2837(0.2661)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0609(0.0609)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2461(0.2935)
# 	 epoch:16, avg train loss:0.2661, avg valid loss:0.2935
# 	 score:0.5047(th=0.450000), auc=0.871885::: time:53.27s
# Epoch 16 - Save Best Score: 0.5047. Model is saved.
# dice_list:  [0.34605701550239054, 0.4034080994229854, 0.43895447961028744, 0.4626301283995059, 0.4828099896393401, 0.4937136099407145, 0.500916058777727, 0.5047233927955698, 0.5003176220988275, 0.49426242278793664, 0.48445393088797517, 0.46923223625788435, 0.44928057049521836, 0.4177270653011871, 0.37251625442285463, 0.3151581565719692, 0.23927572079262102, 0.1266674659913748, 0.0]
# Epoch 16 - Save Best AUC: 0.8719. Model is saved.
# - epoch:17 -
# Epoch: [17][0/127] Elapsed 0m 1s (remain 2m 7s) Loss: 0.1852(0.1852)
# Epoch: [17][126/127] Elapsed 0m 38s (remain 0m 0s) Loss: 0.2388(0.2631)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0784(0.0784)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2405(0.2902)
# 	 epoch:17, avg train loss:0.2631, avg valid loss:0.2902
# 	 score:0.4991(th=0.500000), auc=0.877517::: time:110.66s
# Epoch 17 - Save Best AUC: 0.8775. Model is saved.
# - epoch:18 -
# Epoch: [18][0/127] Elapsed 0m 0s (remain 1m 51s) Loss: 0.2531(0.2531)
# Epoch: [18][126/127] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2467(0.2645)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0654(0.0654)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2354(0.2906)
# 	 epoch:18, avg train loss:0.2645, avg valid loss:0.2906
# 	 score:0.4956(th=0.550000), auc=0.881385::: time:165.74s
# Epoch 18 - Save Best AUC: 0.8814. Model is saved.
# - epoch:19 -
# Epoch: [19][0/127] Elapsed 0m 0s (remain 1m 48s) Loss: 0.2488(0.2488)
# Epoch: [19][126/127] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2524(0.2746)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0693(0.0693)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2582(0.3062)
# 	 epoch:19, avg train loss:0.2746, avg valid loss:0.3062
# 	 score:0.4894(th=0.600000), auc=0.870073::: time:220.46s
# - epoch:20 -
# Epoch: [20][0/127] Elapsed 0m 0s (remain 1m 53s) Loss: 0.2211(0.2211)
# Epoch: [20][126/127] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2140(0.2819)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0467(0.0467)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2329(0.2918)
# 	 epoch:20, avg train loss:0.2819, avg valid loss:0.2918
# 	 score:0.4958(th=0.550000), auc=0.876531::: time:274.01s
# - epoch:21 -
# Epoch: [21][0/127] Elapsed 0m 0s (remain 2m 0s) Loss: 0.1687(0.1687)
# Epoch: [21][126/127] Elapsed 0m 37s (remain 0m 0s) Loss: 0.2506(0.2819)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 7s) Loss: 0.0654(0.0654)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.3078(0.3025)
# 	 epoch:21, avg train loss:0.2819, avg valid loss:0.3025
# 	 score:0.4627(th=0.450000), auc=0.863751::: time:328.15s
# - epoch:22 -
# Epoch: [22][0/127] Elapsed 0m 0s (remain 2m 0s) Loss: 0.2259(0.2259)
# Epoch: [22][126/127] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2146(0.2715)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0960(0.0960)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2318(0.3045)
# 	 epoch:22, avg train loss:0.2715, avg valid loss:0.3045
# 	 score:0.4955(th=0.700000), auc=0.871244::: time:381.64s
# - epoch:23 -
# Epoch: [23][0/127] Elapsed 0m 0s (remain 1m 59s) Loss: 0.2343(0.2343)
# Epoch: [23][126/127] Elapsed 0m 37s (remain 0m 0s) Loss: 0.2145(0.2496)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0395(0.0395)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.3263(0.3469)
# 	 epoch:23, avg train loss:0.2496, avg valid loss:0.3469
# 	 score:0.4040(th=0.450000), auc=0.847116::: time:435.57s
# - epoch:24 -
# Epoch: [24][0/127] Elapsed 0m 0s (remain 1m 56s) Loss: 0.1813(0.1813)
# Epoch: [24][126/127] Elapsed 0m 37s (remain 0m 0s) Loss: 0.2146(0.2264)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0544(0.0544)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2391(0.3214)
# 	 epoch:24, avg train loss:0.2264, avg valid loss:0.3214
# 	 score:0.4526(th=0.500000), auc=0.854402::: time:489.78s
# - epoch:25 -
# Epoch: [25][0/127] Elapsed 0m 0s (remain 1m 52s) Loss: 0.1819(0.1819)
# Epoch: [25][126/127] Elapsed 0m 36s (remain 0m 0s) Loss: 0.1527(0.2113)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0595(0.0595)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2371(0.3128)
# 	 epoch:25, avg train loss:0.2113, avg valid loss:0.3128
# 	 score:0.4748(th=0.550000), auc=0.864342::: time:543.68s
# - epoch:26 -
# Epoch: [26][0/127] Elapsed 0m 1s (remain 2m 6s) Loss: 0.2110(0.2110)
# Epoch: [26][126/127] Elapsed 0m 37s (remain 0m 0s) Loss: 0.1786(0.2050)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0606(0.0606)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2423(0.3163)
# 	 epoch:26, avg train loss:0.2050, avg valid loss:0.3163
# 	 score:0.4673(th=0.550000), auc=0.860894::: time:597.32s
# - epoch:27 -
# Epoch: [27][0/127] Elapsed 0m 0s (remain 1m 53s) Loss: 0.2046(0.2046)
# Epoch: [27][126/127] Elapsed 0m 36s (remain 0m 0s) Loss: 0.1297(0.2065)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0670(0.0670)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2308(0.3214)
# 	 epoch:27, avg train loss:0.2065, avg valid loss:0.3214
# 	 score:0.4653(th=0.600000), auc=0.860029::: time:650.69s
# - epoch:28 -
# Epoch: [28][0/127] Elapsed 0m 0s (remain 1m 55s) Loss: 0.1892(0.1892)
# Epoch: [28][126/127] Elapsed 0m 37s (remain 0m 0s) Loss: 0.2286(0.2086)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0537(0.0537)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2742(0.3289)
# 	 epoch:28, avg train loss:0.2086, avg valid loss:0.3289
# 	 score:0.4611(th=0.500000), auc=0.854672::: time:704.89s
# - epoch:29 -
# Epoch: [29][0/127] Elapsed 0m 0s (remain 1m 52s) Loss: 0.3305(0.3305)
# Epoch: [29][126/127] Elapsed 0m 37s (remain 0m 0s) Loss: 0.2413(0.2220)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1034(0.1034)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2531(0.3315)
# 	 epoch:29, avg train loss:0.2220, avg valid loss:0.3315
# 	 score:0.4550(th=0.700000), auc=0.870824::: time:758.64s
# - epoch:30 -
# Epoch: [30][0/127] Elapsed 0m 0s (remain 1m 56s) Loss: 0.1485(0.1485)
# Epoch: [30][126/127] Elapsed 0m 37s (remain 0m 0s) Loss: 0.2949(0.2356)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0376(0.0376)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2847(0.3206)
# 	 epoch:30, avg train loss:0.2356, avg valid loss:0.3206
# 	 score:0.4986(th=0.400000), auc=0.862716::: time:813.03s
# surface_list:  range(25, 35, 3)
# - epoch:31 -
# Epoch: [31][0/127] Elapsed 0m 0s (remain 1m 54s) Loss: 0.3476(0.3476)
# Epoch: [31][126/127] Elapsed 0m 36s (remain 0m 0s) Loss: 0.3458(0.2815)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0540(0.0540)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2249(0.3130)
# 	 epoch:31, avg train loss:0.2815, avg valid loss:0.3130
# 	 score:0.4858(th=0.650000), auc=0.868332::: time:53.61s
# Epoch 31 - Save Best Score: 0.4858. Model is saved.
# dice_list:  [0.3169153675730549, 0.35775819666494446, 0.38965815363591083, 0.41617535235815534, 0.43764005351255275, 0.4538194433742602, 0.4657876767886322, 0.47477461148217526, 0.48011876742691245, 0.48340709859248004, 0.4852827132591999, 0.4857760559936783, 0.4819157763329685, 0.4707057139634608, 0.45037573781450524, 0.41311964296253606, 0.34569427293710053, 0.23809345949130586, 0.0]
# Epoch 31 - Save Best AUC: 0.8683. Model is saved.
# - epoch:32 -
# Epoch: [32][0/127] Elapsed 0m 0s (remain 2m 1s) Loss: 0.2532(0.2532)
# Epoch: [32][126/127] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2203(0.2537)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0587(0.0587)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.3134(0.3194)
# 	 epoch:32, avg train loss:0.2537, avg valid loss:0.3194
# 	 score:0.4867(th=0.500000), auc=0.865883::: time:109.51s
# Epoch 32 - Save Best Score: 0.4867. Model is saved.
# dice_list:  [0.35401018699984993, 0.3897012806481584, 0.4170081423247577, 0.4403967422401094, 0.4591779357712476, 0.47437645672090706, 0.48199113242913394, 0.484286650478225, 0.4867194240685393, 0.4861275046765527, 0.4825064505244399, 0.4748301147142507, 0.459530851799861, 0.439271792844333, 0.4097562435891776, 0.3676046137708137, 0.30360136936548276, 0.18840995421775536, 0.0]
# - epoch:33 -
# Epoch: [33][0/127] Elapsed 0m 0s (remain 1m 47s) Loss: 0.3019(0.3019)
# Epoch: [33][126/127] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2009(0.2296)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0587(0.0587)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2971(0.3303)
# 	 epoch:33, avg train loss:0.2296, avg valid loss:0.3303
# 	 score:0.4763(th=0.650000), auc=0.858132::: time:163.94s
# - epoch:34 -
# Epoch: [34][0/127] Elapsed 0m 0s (remain 2m 2s) Loss: 0.1853(0.1853)
# Epoch: [34][126/127] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2331(0.2127)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0634(0.0634)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2426(0.3164)
# 	 epoch:34, avg train loss:0.2127, avg valid loss:0.3164
# 	 score:0.4962(th=0.650000), auc=0.863650::: time:217.30s
# Epoch 34 - Save Best Score: 0.4962. Model is saved.
# dice_list:  [0.30893828538619383, 0.34865615557680635, 0.3816433593620819, 0.4090529084624484, 0.43291774097630253, 0.4496630252102907, 0.46070267521167385, 0.46965388338592623, 0.4779749493224544, 0.4846812809479973, 0.49273212542925193, 0.4961999955819137, 0.4928067054219881, 0.48680805205344263, 0.4739565719676159, 0.44670695281250267, 0.40357284286403605, 0.3299942783148132, 0.0]
# - epoch:35 -
# Epoch: [35][0/127] Elapsed 0m 0s (remain 1m 54s) Loss: 0.2142(0.2142)
# Epoch: [35][126/127] Elapsed 0m 37s (remain 0m 0s) Loss: 0.2195(0.1908)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0620(0.0620)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2587(0.3199)
# 	 epoch:35, avg train loss:0.1908, avg valid loss:0.3199
# 	 score:0.5044(th=0.650000), auc=0.863021::: time:272.08s
# Epoch 35 - Save Best Score: 0.5044. Model is saved.
# dice_list:  [0.3256364271247192, 0.365671112380962, 0.3933818334569573, 0.4176090746465428, 0.4381162358227716, 0.4538852687775433, 0.46871712266622734, 0.4809615180724829, 0.4893292817885236, 0.49681640671567273, 0.5017726797940049, 0.504392985910445, 0.5026664408181182, 0.4941083489411413, 0.48163919319888016, 0.4527580182023094, 0.403014027975076, 0.32675693982207843, 0.0]
# - epoch:36 -
# Epoch: [36][0/127] Elapsed 0m 0s (remain 1m 51s) Loss: 0.1556(0.1556)
# Epoch: [36][126/127] Elapsed 0m 37s (remain 0m 0s) Loss: 0.2378(0.1884)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 7s) Loss: 0.0710(0.0710)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2517(0.3276)
# 	 epoch:36, avg train loss:0.1884, avg valid loss:0.3276
# 	 score:0.5058(th=0.750000), auc=0.863062::: time:327.69s
# Epoch 36 - Save Best Score: 0.5058. Model is saved.
# dice_list:  [0.31765613351181476, 0.35590381320908365, 0.3834727194102414, 0.4058829612506679, 0.42644805082717524, 0.4433247589601593, 0.4587218200070166, 0.4724663133779004, 0.4840638562043607, 0.49208718319450445, 0.4986688940532739, 0.5030798156391257, 0.5056573506351111, 0.5058366948478226, 0.4997951714965675, 0.4850548678248981, 0.4400889523567889, 0.3673332170243053, 0.0]
# - epoch:37 -
# Epoch: [37][0/127] Elapsed 0m 0s (remain 1m 47s) Loss: 0.1479(0.1479)
# Epoch: [37][126/127] Elapsed 0m 37s (remain 0m 0s) Loss: 0.2041(0.1850)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0756(0.0756)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2490(0.3249)
# 	 epoch:37, avg train loss:0.1850, avg valid loss:0.3249
# 	 score:0.5160(th=0.700000), auc=0.864626::: time:382.69s
# Epoch 37 - Save Best Score: 0.5160. Model is saved.
# dice_list:  [0.3284312068774585, 0.36772831267595546, 0.3925722843886125, 0.4140844768995188, 0.43425495012609927, 0.45225936807147465, 0.46671475662276246, 0.47691243482480977, 0.4866921601514355, 0.4955658860151227, 0.5042308669734968, 0.5121817898060139, 0.5159804318588775, 0.5128998653076894, 0.5030759388596416, 0.4851733298280203, 0.4495971808405477, 0.37769032691843657, 0.0]
# - epoch:38 -
# Epoch: [38][0/127] Elapsed 0m 1s (remain 2m 8s) Loss: 0.2088(0.2088)
# Epoch: [38][126/127] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2182(0.1882)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0809(0.0809)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2312(0.3255)
# 	 epoch:38, avg train loss:0.1882, avg valid loss:0.3255
# 	 score:0.5169(th=0.700000), auc=0.860643::: time:437.47s
# Epoch 38 - Save Best Score: 0.5169. Model is saved.
# dice_list:  [0.3163840747994267, 0.35278824239815954, 0.3808126903744007, 0.40449270609406507, 0.425542920560464, 0.44420802471644155, 0.4613118332607895, 0.47679665891810663, 0.4878020636453973, 0.4969070915449359, 0.5044896588750567, 0.5116638176372152, 0.5169422864829883, 0.5096008759745886, 0.4927175900693475, 0.4641666317127856, 0.409482100500948, 0.30555705072426004, 0.0]
# - epoch:39 -
# Epoch: [39][0/127] Elapsed 0m 0s (remain 1m 56s) Loss: 0.2142(0.2142)
# Epoch: [39][126/127] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2300(0.2021)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0290(0.0290)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2726(0.3501)
# 	 epoch:39, avg train loss:0.2021, avg valid loss:0.3501
# 	 score:0.4849(th=0.500000), auc=0.857725::: time:492.32s
# - epoch:40 -
# Epoch: [40][0/127] Elapsed 0m 1s (remain 2m 16s) Loss: 0.1550(0.1550)
# Epoch: [40][126/127] Elapsed 0m 37s (remain 0m 0s) Loss: 0.2318(0.2165)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 7s) Loss: 0.0411(0.0411)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2904(0.3226)
# 	 epoch:40, avg train loss:0.2165, avg valid loss:0.3226
# 	 score:0.5012(th=0.600000), auc=0.869619::: time:546.30s
# Epoch 40 - Save Best AUC: 0.8696. Model is saved.
# - epoch:41 -
# Epoch: [41][0/127] Elapsed 0m 0s (remain 1m 48s) Loss: 0.1801(0.1801)
# Epoch: [41][126/127] Elapsed 0m 37s (remain 0m 0s) Loss: 0.3009(0.2172)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1092(0.1092)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1905(0.3375)
# 	 epoch:41, avg train loss:0.2172, avg valid loss:0.3375
# 	 score:0.4884(th=0.700000), auc=0.850653::: time:601.16s
# - epoch:42 -
# Epoch: [42][0/127] Elapsed 0m 0s (remain 2m 1s) Loss: 0.1901(0.1901)
# Epoch: [42][126/127] Elapsed 0m 37s (remain 0m 0s) Loss: 0.1869(0.2139)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0432(0.0432)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.3838(0.3661)
# 	 epoch:42, avg train loss:0.2139, avg valid loss:0.3661
# 	 score:0.4262(th=0.500000), auc=0.833500::: time:655.46s
# - epoch:43 -
# Epoch: [43][0/127] Elapsed 0m 1s (remain 2m 20s) Loss: 0.2297(0.2297)
# Epoch: [43][126/127] Elapsed 0m 38s (remain 0m 0s) Loss: 0.1712(0.1980)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1074(0.1074)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2643(0.3434)
# 	 epoch:43, avg train loss:0.1980, avg valid loss:0.3434
# 	 score:0.5126(th=0.750000), auc=0.867209::: time:709.95s
# - epoch:44 -
# Epoch: [44][0/127] Elapsed 0m 0s (remain 1m 54s) Loss: 0.1336(0.1336)
# Epoch: [44][126/127] Elapsed 0m 37s (remain 0m 0s) Loss: 0.1798(0.1730)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0800(0.0800)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.3195(0.3340)
# 	 epoch:44, avg train loss:0.1730, avg valid loss:0.3340
# 	 score:0.4935(th=0.650000), auc=0.863628::: time:764.08s
# - epoch:45 -
# Epoch: [45][0/127] Elapsed 0m 0s (remain 2m 5s) Loss: 0.1373(0.1373)
# Epoch: [45][126/127] Elapsed 0m 37s (remain 0m 0s) Loss: 0.1451(0.1620)
# EVAL: [0/26] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0843(0.0843)
# EVAL: [25/26] Elapsed 0m 5s (remain 0m 0s) Loss: 0.3214(0.3442)
# 	 epoch:45, avg train loss:0.1620, avg valid loss:0.3442
# 	 score:0.4837(th=0.650000), auc=0.860587::: time:817.68s
# [fold0] slice ave score:0.5316(th=0.450000), auc=0.874596
# [fold0] BEST Epoch 38 - Save Best Score:0.5169. Best loss:0.3255
# [fold0] BEST AUC Epoch 40 - Save Best Score:0.8696. Best loss:0.3226
# -- fold1 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# Epoch: [1][0/56] Elapsed 0m 0s (remain 0m 50s) Loss: 0.6739(0.6739)
# Epoch: [1][55/56] Elapsed 0m 17s (remain 0m 0s) Loss: 0.5332(0.5915)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 26s) Loss: 0.4024(0.4024)
# EVAL: [96/97] Elapsed 0m 17s (remain 0m 0s) Loss: 0.3044(0.4859)
# 	 epoch:1, avg train loss:0.5915, avg valid loss:0.4859
# 	 score:0.3518(th=0.450000), auc=0.753988::: time:81.76s
# Epoch 1 - Save Best Score: 0.3518. Model is saved.
# dice_list:  [0.20000026590816603, 0.20312938932515923, 0.21284181187204662, 0.23667517388944262, 0.2800488098849397, 0.3170282335502292, 0.3458686493418222, 0.35181429470760095, 0.3419423888596401, 0.32170728926053715, 0.2970422543458083, 0.2725063813298253, 0.24819600604889908, 0.2212008083261455, 0.1916730887697438, 0.16131391144476945, 0.12325549133307073, 0.07304701764139589, 0.0]
# Epoch 1 - Save Best AUC: 0.7540. Model is saved.
# - epoch:2 -
# Epoch: [2][0/56] Elapsed 0m 0s (remain 0m 51s) Loss: 0.5595(0.5595)
# Epoch: [2][55/56] Elapsed 0m 17s (remain 0m 0s) Loss: 0.4259(0.5066)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.2960(0.2960)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.2371(0.4488)
# 	 epoch:2, avg train loss:0.5066, avg valid loss:0.4488
# 	 score:0.3501(th=0.350000), auc=0.766349::: time:169.52s
# Epoch 2 - Save Best AUC: 0.7663. Model is saved.
# - epoch:3 -
# Epoch: [3][0/56] Elapsed 0m 1s (remain 0m 56s) Loss: 0.4374(0.4374)
# Epoch: [3][55/56] Elapsed 0m 17s (remain 0m 0s) Loss: 0.5108(0.4296)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 26s) Loss: 0.2662(0.2662)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.1917(0.4465)
# 	 epoch:3, avg train loss:0.4296, avg valid loss:0.4465
# 	 score:0.3193(th=0.300000), auc=0.766149::: time:253.94s
# - epoch:4 -
# Epoch: [4][0/56] Elapsed 0m 0s (remain 0m 48s) Loss: 0.3824(0.3824)
# Epoch: [4][55/56] Elapsed 0m 17s (remain 0m 0s) Loss: 0.4288(0.3794)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 26s) Loss: 0.2680(0.2680)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.1339(0.4230)
# 	 epoch:4, avg train loss:0.3794, avg valid loss:0.4230
# 	 score:0.3628(th=0.300000), auc=0.767555::: time:333.44s
# Epoch 4 - Save Best Score: 0.3628. Model is saved.
# dice_list:  [0.2068025548462608, 0.2736187491703148, 0.3243135658313189, 0.3618239145212728, 0.36281199050128216, 0.3395488783722483, 0.31120844357360017, 0.28273924197281386, 0.2568349029898906, 0.2312878097882533, 0.20367638107579547, 0.17503687304895474, 0.14518820023655732, 0.11836836344346648, 0.09254372067424677, 0.06955582227588085, 0.051861274058996196, 0.03240190879498692, 0.0]
# Epoch 4 - Save Best AUC: 0.7676. Model is saved.
# - epoch:5 -
# Epoch: [5][0/56] Elapsed 0m 0s (remain 0m 51s) Loss: 0.3455(0.3455)
# Epoch: [5][55/56] Elapsed 0m 17s (remain 0m 0s) Loss: 0.3589(0.3501)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 27s) Loss: 0.2201(0.2201)
# EVAL: [96/97] Elapsed 0m 17s (remain 0m 0s) Loss: 0.1198(0.4217)
# 	 epoch:5, avg train loss:0.3501, avg valid loss:0.4217
# 	 score:0.3574(th=0.250000), auc=0.772724::: time:419.56s
# Epoch 5 - Save Best AUC: 0.7727. Model is saved.
# - epoch:6 -
# Epoch: [6][0/56] Elapsed 0m 0s (remain 0m 53s) Loss: 0.3594(0.3594)
# Epoch: [6][55/56] Elapsed 0m 17s (remain 0m 0s) Loss: 0.4045(0.3406)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.2272(0.2272)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.1223(0.4219)
# 	 epoch:6, avg train loss:0.3406, avg valid loss:0.4219
# 	 score:0.3566(th=0.250000), auc=0.772569::: time:502.59s
# - epoch:7 -
# Epoch: [7][0/56] Elapsed 0m 0s (remain 0m 54s) Loss: 0.4274(0.4274)
# Epoch: [7][55/56] Elapsed 0m 17s (remain 0m 0s) Loss: 0.3492(0.3341)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 30s) Loss: 0.2402(0.2402)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.1011(0.4217)
# 	 epoch:7, avg train loss:0.3341, avg valid loss:0.4217
# 	 score:0.3666(th=0.250000), auc=0.773264::: time:582.20s
# Epoch 7 - Save Best Score: 0.3666. Model is saved.
# dice_list:  [0.2244627473087021, 0.28644958058546055, 0.33881621263785483, 0.36655344217531177, 0.34956251076204603, 0.31700636089181067, 0.2810326235994513, 0.24274368233479698, 0.20719553448342912, 0.1737319397823704, 0.14206561353880212, 0.1132072781621585, 0.08864153355083139, 0.06927995812182922, 0.05495762191490345, 0.04272716802078405, 0.03184913611930373, 0.020347371576619217, 0.0]
# Epoch 7 - Save Best AUC: 0.7733. Model is saved.
# - epoch:8 -
# Epoch: [8][0/56] Elapsed 0m 0s (remain 0m 49s) Loss: 0.3295(0.3295)
# Epoch: [8][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3420(0.3332)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 27s) Loss: 0.3240(0.3240)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.1022(0.4303)
# 	 epoch:8, avg train loss:0.3332, avg valid loss:0.4303
# 	 score:0.3572(th=0.200000), auc=0.768607::: time:668.49s
# - epoch:9 -
# Epoch: [9][0/56] Elapsed 0m 0s (remain 0m 54s) Loss: 0.3103(0.3103)
# Epoch: [9][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.4148(0.3136)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.8248(0.8248)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0577(0.4520)
# 	 epoch:9, avg train loss:0.3136, avg valid loss:0.4520
# 	 score:0.3584(th=0.200000), auc=0.781782::: time:747.19s
# Epoch 9 - Save Best AUC: 0.7818. Model is saved.
# - epoch:10 -
# Epoch: [10][0/56] Elapsed 0m 1s (remain 0m 55s) Loss: 0.3733(0.3733)
# Epoch: [10][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2706(0.3023)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0795(0.0795)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0368(0.4406)
# 	 epoch:10, avg train loss:0.3023, avg valid loss:0.4406
# 	 score:0.3643(th=0.200000), auc=0.776814::: time:830.54s
# - epoch:11 -
# Epoch: [11][0/56] Elapsed 0m 0s (remain 0m 49s) Loss: 0.3100(0.3100)
# Epoch: [11][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2880(0.2839)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.1154(0.1154)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0234(0.5154)
# 	 epoch:11, avg train loss:0.2839, avg valid loss:0.5154
# 	 score:0.3623(th=0.100000), auc=0.768447::: time:909.37s
# - epoch:12 -
# Epoch: [12][0/56] Elapsed 0m 0s (remain 0m 47s) Loss: 0.2228(0.2228)
# Epoch: [12][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1744(0.2620)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.1940(0.1940)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0261(0.5045)
# 	 epoch:12, avg train loss:0.2620, avg valid loss:0.5045
# 	 score:0.3517(th=0.150000), auc=0.750456::: time:988.46s
# - epoch:13 -
# Epoch: [13][0/56] Elapsed 0m 1s (remain 0m 55s) Loss: 0.2609(0.2609)
# Epoch: [13][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3530(0.2510)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.1499(0.1499)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0204(0.5313)
# 	 epoch:13, avg train loss:0.2510, avg valid loss:0.5313
# 	 score:0.3359(th=0.100000), auc=0.756223::: time:1067.83s
# - epoch:14 -
# Epoch: [14][0/56] Elapsed 0m 0s (remain 0m 49s) Loss: 0.2285(0.2285)
# Epoch: [14][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1830(0.2299)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.1211(0.1211)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0138(0.5549)
# 	 epoch:14, avg train loss:0.2299, avg valid loss:0.5549
# 	 score:0.3363(th=0.100000), auc=0.750301::: time:1146.70s
# - epoch:15 -
# Epoch: [15][0/56] Elapsed 0m 1s (remain 0m 56s) Loss: 0.2104(0.2104)
# Epoch: [15][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1583(0.2077)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 27s) Loss: 0.1357(0.1357)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0200(0.5394)
# 	 epoch:15, avg train loss:0.2077, avg valid loss:0.5394
# 	 score:0.3326(th=0.100000), auc=0.750940::: time:1224.96s
# surface_list:  range(27, 37, 3)
# - epoch:16 -
# Epoch: [16][0/56] Elapsed 0m 0s (remain 0m 49s) Loss: 0.2454(0.2454)
# Epoch: [16][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2116(0.2262)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 27s) Loss: 0.1248(0.1248)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0205(0.5189)
# 	 epoch:16, avg train loss:0.2262, avg valid loss:0.5189
# 	 score:0.3392(th=0.200000), auc=0.756962::: time:78.65s
# Epoch 16 - Save Best Score: 0.3392. Model is saved.
# dice_list:  [0.3245990424459885, 0.3363558762289, 0.33924712796860906, 0.3370468305538186, 0.3308599173024027, 0.32162640721685204, 0.3089947722205331, 0.29395945752798375, 0.2747404753246536, 0.2514903296343231, 0.22576081540025886, 0.2015345666002273, 0.17662350315086522, 0.15053250047523156, 0.12072175772734997, 0.08866805438025094, 0.05701626477031005, 0.026069018201172023, 0.0]
# Epoch 16 - Save Best AUC: 0.7570. Model is saved.
# - epoch:17 -
# Epoch: [17][0/56] Elapsed 0m 0s (remain 0m 53s) Loss: 0.1715(0.1715)
# Epoch: [17][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2261(0.2201)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0908(0.0908)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0179(0.5488)
# 	 epoch:17, avg train loss:0.2201, avg valid loss:0.5488
# 	 score:0.3360(th=0.150000), auc=0.751725::: time:163.03s
# - epoch:18 -
# Epoch: [18][0/56] Elapsed 0m 1s (remain 0m 55s) Loss: 0.2025(0.2025)
# Epoch: [18][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2769(0.2160)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1798(0.1798)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0202(0.5636)
# 	 epoch:18, avg train loss:0.2160, avg valid loss:0.5636
# 	 score:0.3346(th=0.100000), auc=0.745255::: time:241.45s
# - epoch:19 -
# Epoch: [19][0/56] Elapsed 0m 0s (remain 0m 51s) Loss: 0.2312(0.2312)
# Epoch: [19][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1999(0.2206)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 27s) Loss: 0.0265(0.0265)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0081(0.5563)
# 	 epoch:19, avg train loss:0.2206, avg valid loss:0.5563
# 	 score:0.3400(th=0.150000), auc=0.760919::: time:320.23s
# Epoch 19 - Save Best Score: 0.3400. Model is saved.
# dice_list:  [0.33445497889920117, 0.33995990921186664, 0.33857381400224595, 0.3313992633851228, 0.32036181448538065, 0.3041589974952415, 0.2845164970643014, 0.2629412344633044, 0.2402573387530483, 0.21698133524471797, 0.19338297651113223, 0.16804405501922653, 0.14251003147887065, 0.11681349246729296, 0.0903326201563425, 0.06375439500652083, 0.039580118873932146, 0.017906672310577583, 0.0]
# Epoch 19 - Save Best AUC: 0.7609. Model is saved.
# - epoch:20 -
# Epoch: [20][0/56] Elapsed 0m 0s (remain 0m 50s) Loss: 0.2531(0.2531)
# Epoch: [20][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2033(0.2250)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 27s) Loss: 0.1236(0.1236)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0057(0.6459)
# 	 epoch:20, avg train loss:0.2250, avg valid loss:0.6459
# 	 score:0.3411(th=0.150000), auc=0.751933::: time:404.52s
# Epoch 20 - Save Best Score: 0.3411. Model is saved.
# dice_list:  [0.34000097141172925, 0.3410719959213168, 0.33517169989847323, 0.3266112866627111, 0.31656085722117855, 0.3040458399804637, 0.29016295394171254, 0.27495586871374583, 0.2587096428283376, 0.2403318759755948, 0.22035794641762227, 0.19786290739640539, 0.171961105813621, 0.14421156158355897, 0.11434648093898032, 0.08310591229353878, 0.05184258437524144, 0.023294079728790548, 0.0]
# - epoch:21 -
# Epoch: [21][0/56] Elapsed 0m 1s (remain 0m 56s) Loss: 0.2007(0.2007)
# Epoch: [21][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2284(0.2191)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1016(0.1016)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0072(0.7180)
# 	 epoch:21, avg train loss:0.2191, avg valid loss:0.7180
# 	 score:0.2549(th=0.100000), auc=0.738658::: time:486.79s
# - epoch:22 -
# Epoch: [22][0/56] Elapsed 0m 0s (remain 0m 50s) Loss: 0.1972(0.1972)
# Epoch: [22][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2415(0.2152)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0545(0.0545)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0069(0.6917)
# 	 epoch:22, avg train loss:0.2152, avg valid loss:0.6917
# 	 score:0.3032(th=0.100000), auc=0.741938::: time:565.40s
# - epoch:23 -
# Epoch: [23][0/56] Elapsed 0m 0s (remain 0m 53s) Loss: 0.1791(0.1791)
# Epoch: [23][55/56] Elapsed 0m 17s (remain 0m 0s) Loss: 0.3495(0.2011)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0950(0.0950)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0096(0.6112)
# 	 epoch:23, avg train loss:0.2011, avg valid loss:0.6112
# 	 score:0.3282(th=0.100000), auc=0.770080::: time:645.33s
# Epoch 23 - Save Best AUC: 0.7701. Model is saved.
# - epoch:24 -
# Epoch: [24][0/56] Elapsed 0m 0s (remain 0m 52s) Loss: 0.1655(0.1655)
# Epoch: [24][55/56] Elapsed 0m 17s (remain 0m 0s) Loss: 0.1667(0.1777)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0858(0.0858)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0092(0.6621)
# 	 epoch:24, avg train loss:0.1777, avg valid loss:0.6621
# 	 score:0.2842(th=0.100000), auc=0.753054::: time:726.69s
# - epoch:25 -
# Epoch: [25][0/56] Elapsed 0m 0s (remain 0m 52s) Loss: 0.1841(0.1841)
# Epoch: [25][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1387(0.1630)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 27s) Loss: 0.0676(0.0676)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0094(0.6512)
# 	 epoch:25, avg train loss:0.1630, avg valid loss:0.6512
# 	 score:0.3092(th=0.100000), auc=0.754074::: time:806.00s
# - epoch:26 -
# Epoch: [26][0/56] Elapsed 0m 0s (remain 0m 54s) Loss: 0.1659(0.1659)
# Epoch: [26][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1256(0.1619)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0651(0.0651)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0096(0.6588)
# 	 epoch:26, avg train loss:0.1619, avg valid loss:0.6588
# 	 score:0.3005(th=0.100000), auc=0.752228::: time:884.22s
# - epoch:27 -
# Epoch: [27][0/56] Elapsed 0m 0s (remain 0m 54s) Loss: 0.1434(0.1434)
# Epoch: [27][55/56] Elapsed 0m 17s (remain 0m 0s) Loss: 0.1169(0.1619)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0760(0.0760)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0105(0.6405)
# 	 epoch:27, avg train loss:0.1619, avg valid loss:0.6405
# 	 score:0.3137(th=0.100000), auc=0.754455::: time:963.31s
# - epoch:28 -
# Epoch: [28][0/56] Elapsed 0m 1s (remain 0m 56s) Loss: 0.2059(0.2059)
# Epoch: [28][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1539(0.1604)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0488(0.0488)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0108(0.6601)
# 	 epoch:28, avg train loss:0.1604, avg valid loss:0.6601
# 	 score:0.2978(th=0.100000), auc=0.747930::: time:1042.13s
# - epoch:29 -
# Epoch: [29][0/56] Elapsed 0m 1s (remain 0m 55s) Loss: 0.1400(0.1400)
# Epoch: [29][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1805(0.1656)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1266(0.1266)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0050(0.7470)
# 	 epoch:29, avg train loss:0.1656, avg valid loss:0.7470
# 	 score:0.3032(th=0.100000), auc=0.738836::: time:1120.71s
# - epoch:30 -
# Epoch: [30][0/56] Elapsed 0m 0s (remain 0m 53s) Loss: 0.1184(0.1184)
# Epoch: [30][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1228(0.1752)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0777(0.0777)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0070(0.6641)
# 	 epoch:30, avg train loss:0.1752, avg valid loss:0.6641
# 	 score:0.3093(th=0.100000), auc=0.743350::: time:1199.58s
# surface_list:  range(25, 35, 3)
# - epoch:31 -
# Epoch: [31][0/56] Elapsed 0m 1s (remain 0m 59s) Loss: 0.2271(0.2271)
# Epoch: [31][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2267(0.2399)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0754(0.0754)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0064(0.6628)
# 	 epoch:31, avg train loss:0.2399, avg valid loss:0.6628
# 	 score:0.3453(th=0.100000), auc=0.758755::: time:79.68s
# Epoch 31 - Save Best Score: 0.3453. Model is saved.
# dice_list:  [0.34530778112617805, 0.34218882626264907, 0.3343807823358924, 0.32348807587402817, 0.3083417566617873, 0.29039536794212284, 0.2690773518835886, 0.24451117894227764, 0.21924200997974203, 0.19423511406958818, 0.16884476425485703, 0.14128426319305953, 0.1139676688132299, 0.08683894894504966, 0.060399040254532396, 0.03844713819085889, 0.022056858637597706, 0.009659819437686379, 0.0]
# Epoch 31 - Save Best AUC: 0.7588. Model is saved.
# - epoch:32 -
# Epoch: [32][0/56] Elapsed 0m 1s (remain 0m 57s) Loss: 0.1983(0.1983)
# Epoch: [32][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1157(0.2058)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0290(0.0290)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0024(0.6220)
# 	 epoch:32, avg train loss:0.2058, avg valid loss:0.6220
# 	 score:0.3149(th=0.150000), auc=0.766405::: time:164.06s
# Epoch 32 - Save Best AUC: 0.7664. Model is saved.
# - epoch:33 -
# Epoch: [33][0/56] Elapsed 0m 1s (remain 0m 56s) Loss: 0.2298(0.2298)
# Epoch: [33][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1123(0.1886)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0962(0.0962)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0066(0.6868)
# 	 epoch:33, avg train loss:0.1886, avg valid loss:0.6868
# 	 score:0.3335(th=0.100000), auc=0.767116::: time:245.53s
# Epoch 33 - Save Best AUC: 0.7671. Model is saved.
# - epoch:34 -
# Epoch: [34][0/56] Elapsed 0m 1s (remain 0m 59s) Loss: 0.2244(0.2244)
# Epoch: [34][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1623(0.1716)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0680(0.0680)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0063(0.6689)
# 	 epoch:34, avg train loss:0.1716, avg valid loss:0.6689
# 	 score:0.3274(th=0.100000), auc=0.755659::: time:326.91s
# - epoch:35 -
# Epoch: [35][0/56] Elapsed 0m 0s (remain 0m 54s) Loss: 0.1596(0.1596)
# Epoch: [35][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1813(0.1593)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0697(0.0697)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0066(0.6923)
# 	 epoch:35, avg train loss:0.1593, avg valid loss:0.6923
# 	 score:0.3235(th=0.100000), auc=0.748520::: time:405.49s
# - epoch:36 -
# Epoch: [36][0/56] Elapsed 0m 1s (remain 1m 0s) Loss: 0.1686(0.1686)
# Epoch: [36][55/56] Elapsed 0m 17s (remain 0m 0s) Loss: 0.0990(0.1463)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0649(0.0649)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0070(0.6746)
# 	 epoch:36, avg train loss:0.1463, avg valid loss:0.6746
# 	 score:0.3291(th=0.100000), auc=0.753333::: time:485.40s
# - epoch:37 -
# Epoch: [37][0/56] Elapsed 0m 1s (remain 0m 58s) Loss: 0.0984(0.0984)
# Epoch: [37][55/56] Elapsed 0m 17s (remain 0m 0s) Loss: 0.2048(0.1507)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0502(0.0502)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0061(0.7146)
# 	 epoch:37, avg train loss:0.1507, avg valid loss:0.7146
# 	 score:0.3023(th=0.100000), auc=0.746897::: time:564.59s
# - epoch:38 -
# Epoch: [38][0/56] Elapsed 0m 1s (remain 0m 56s) Loss: 0.1039(0.1039)
# Epoch: [38][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1524(0.1466)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0643(0.0643)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0085(0.6626)
# 	 epoch:38, avg train loss:0.1466, avg valid loss:0.6626
# 	 score:0.3265(th=0.100000), auc=0.750102::: time:644.41s
# - epoch:39 -
# Epoch: [39][0/56] Elapsed 0m 1s (remain 0m 56s) Loss: 0.1321(0.1321)
# Epoch: [39][55/56] Elapsed 0m 17s (remain 0m 0s) Loss: 0.1431(0.1550)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0859(0.0859)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0040(0.7275)
# 	 epoch:39, avg train loss:0.1550, avg valid loss:0.7275
# 	 score:0.2704(th=0.100000), auc=0.745209::: time:724.11s
# - epoch:40 -
# Epoch: [40][0/56] Elapsed 0m 0s (remain 0m 47s) Loss: 0.1709(0.1709)
# Epoch: [40][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1830(0.1567)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0394(0.0394)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0059(0.7345)
# 	 epoch:40, avg train loss:0.1567, avg valid loss:0.7345
# 	 score:0.3161(th=0.100000), auc=0.741448::: time:802.93s
# - epoch:41 -
# Epoch: [41][0/56] Elapsed 0m 1s (remain 0m 56s) Loss: 0.2251(0.2251)
# Epoch: [41][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1969(0.1767)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0265(0.0265)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0043(0.6910)
# 	 epoch:41, avg train loss:0.1767, avg valid loss:0.6910
# 	 score:0.2874(th=0.100000), auc=0.757384::: time:882.02s
# - epoch:42 -
# Epoch: [42][0/56] Elapsed 0m 0s (remain 0m 50s) Loss: 0.2042(0.2042)
# Epoch: [42][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1568(0.1696)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0144(0.0144)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0024(0.6804)
# 	 epoch:42, avg train loss:0.1696, avg valid loss:0.6804
# 	 score:0.3117(th=0.100000), auc=0.753870::: time:961.72s
# - epoch:43 -
# Epoch: [43][0/56] Elapsed 0m 0s (remain 0m 53s) Loss: 0.1428(0.1428)
# Epoch: [43][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2382(0.1539)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0117(0.0117)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0036(0.7194)
# 	 epoch:43, avg train loss:0.1539, avg valid loss:0.7194
# 	 score:0.3054(th=0.100000), auc=0.751254::: time:1041.04s
# - epoch:44 -
# Epoch: [44][0/56] Elapsed 0m 1s (remain 0m 56s) Loss: 0.1923(0.1923)
# Epoch: [44][55/56] Elapsed 0m 17s (remain 0m 0s) Loss: 0.1560(0.1358)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0445(0.0445)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0063(0.7314)
# 	 epoch:44, avg train loss:0.1358, avg valid loss:0.7314
# 	 score:0.3134(th=0.100000), auc=0.739876::: time:1118.55s
# - epoch:45 -
# Epoch: [45][0/56] Elapsed 0m 0s (remain 0m 50s) Loss: 0.1294(0.1294)
# Epoch: [45][55/56] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1000(0.1241)
# EVAL: [0/97] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0523(0.0523)
# EVAL: [96/97] Elapsed 0m 18s (remain 0m 0s) Loss: 0.0066(0.7106)
# 	 epoch:45, avg train loss:0.1241, avg valid loss:0.7106
# 	 score:0.3241(th=0.100000), auc=0.742932::: time:1197.50s
# [fold1] slice ave score:0.3467(th=0.100000), auc=0.757312
# [fold1] BEST Epoch 31 - Save Best Score:0.3453. Best loss:0.6628
# [fold1] BEST AUC Epoch 33 - Save Best Score:0.7671. Best loss:0.6868
# -- fold2 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# Epoch: [1][0/123] Elapsed 0m 0s (remain 2m 1s) Loss: 0.7866(0.7866)
# Epoch: [1][122/123] Elapsed 0m 37s (remain 0m 0s) Loss: 0.5328(0.6361)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 8s) Loss: 0.4465(0.4465)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.4454(0.5564)
# 	 epoch:1, avg train loss:0.6361, avg valid loss:0.5564
# 	 score:0.3723(th=0.450000), auc=0.833598::: time:57.61s
# Epoch 1 - Save Best Score: 0.3723. Model is saved.
# ...
# - epoch:18 -
# Epoch: [18][0/123] Elapsed 0m 0s (remain 1m 56s) Loss: 0.2096(0.2096)
# Epoch: [18][122/123] Elapsed 0m 36s (remain 0m 0s) Loss: 0.3398(0.2512)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2009(0.2009)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0924(0.4140)
# 	 epoch:18, avg train loss:0.2512, avg valid loss:0.4140
# 	 score:0.4722(th=0.650000), auc=0.879146::: time:175.21s
# Epoch 18 - Save Best Score: 0.4722. Model is saved.
# dice_list:  [0.3221383760402293, 0.34870855231187126, 0.3724561400485461, 0.3927320306288536, 0.40920565670059306, 0.42367911319252255, 0.43642575408573175, 0.44744828777504736, 0.4573311098816731, 0.46459694283883984, 0.4704406036525906, 0.47221291527392645, 0.46621381277627794, 0.45623444621527864, 0.43515448683400615, 0.3895127447865783, 0.30564495014774706, 0.16399652773406406, 0.0]
# Epoch 18 - Save Best AUC: 0.8791. Model is saved.
# - epoch:19 -
# Epoch: [19][0/123] Elapsed 0m 1s (remain 2m 9s) Loss: 0.2005(0.2005)
# Epoch: [19][122/123] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2095(0.2578)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 8s) Loss: 0.1571(0.1571)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0895(0.4011)
# 	 epoch:19, avg train loss:0.2578, avg valid loss:0.4011
# 	 score:0.4484(th=0.450000), auc=0.871685::: time:234.82s
# - epoch:20 -
# Epoch: [20][0/123] Elapsed 0m 0s (remain 1m 49s) Loss: 0.1928(0.1928)
# Epoch: [20][122/123] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2979(0.2611)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 8s) Loss: 0.1513(0.1513)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0782(0.4121)
# 	 epoch:20, avg train loss:0.2611, avg valid loss:0.4121
# 	 score:0.4874(th=0.650000), auc=0.877986::: time:290.89s
# Epoch 20 - Save Best Score: 0.4874. Model is saved.
# dice_list:  [0.3656677861588409, 0.39593251425148435, 0.4171886309366659, 0.43798991930354114, 0.45283248212471233, 0.4634525174564636, 0.4719011494984079, 0.47970668654641824, 0.48428548669464877, 0.48700969767146796, 0.48734888365958884, 0.4874437882951825, 0.4818525445154517, 0.4687230657805189, 0.4455903561889997, 0.4047840280064875, 0.33784795267036105, 0.21515312099215572, 0.0]
# - epoch:21 -
# Epoch: [21][0/123] Elapsed 0m 0s (remain 1m 47s) Loss: 0.2275(0.2275)
# Epoch: [21][122/123] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2936(0.2667)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2318(0.2318)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0909(0.4287)
# 	 epoch:21, avg train loss:0.2667, avg valid loss:0.4287
# 	 score:0.4664(th=0.650000), auc=0.873965::: time:348.71s
# - epoch:22 -
# Epoch: [22][0/123] Elapsed 0m 0s (remain 1m 57s) Loss: 0.2864(0.2864)
# Epoch: [22][122/123] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2666(0.2604)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 8s) Loss: 0.1260(0.1260)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0865(0.4208)
# 	 epoch:22, avg train loss:0.2604, avg valid loss:0.4208
# 	 score:0.4497(th=0.500000), auc=0.867870::: time:404.90s
# - epoch:23 -
# Epoch: [23][0/123] Elapsed 0m 0s (remain 1m 57s) Loss: 0.1800(0.1800)
# Epoch: [23][122/123] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2580(0.2392)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 8s) Loss: 0.3154(0.3154)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1545(0.5947)
# 	 epoch:23, avg train loss:0.2392, avg valid loss:0.5947
# 	 score:0.4674(th=0.900000), auc=0.885506::: time:461.06s
# Epoch 23 - Save Best AUC: 0.8855. Model is saved.
# - epoch:24 -
# Epoch: [24][0/123] Elapsed 0m 1s (remain 2m 2s) Loss: 0.2780(0.2780)
# Epoch: [24][122/123] Elapsed 0m 36s (remain 0m 0s) Loss: 0.1993(0.2149)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1879(0.1879)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0990(0.4477)
# 	 epoch:24, avg train loss:0.2149, avg valid loss:0.4477
# 	 score:0.4478(th=0.650000), auc=0.872478::: time:519.47s
# - epoch:25 -
# Epoch: [25][0/123] Elapsed 0m 0s (remain 1m 57s) Loss: 0.1880(0.1880)
# Epoch: [25][122/123] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2382(0.1962)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2049(0.2049)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1055(0.4457)
# 	 epoch:25, avg train loss:0.1962, avg valid loss:0.4457
# 	 score:0.4791(th=0.750000), auc=0.883196::: time:575.80s
# - epoch:26 -
# Epoch: [26][0/123] Elapsed 0m 0s (remain 2m 0s) Loss: 0.1566(0.1566)
# Epoch: [26][122/123] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2348(0.1915)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2129(0.2129)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1096(0.4566)
# 	 epoch:26, avg train loss:0.1915, avg valid loss:0.4566
# 	 score:0.4773(th=0.750000), auc=0.882337::: time:632.32s
# - epoch:27 -
# Epoch: [27][0/123] Elapsed 0m 1s (remain 2m 15s) Loss: 0.1545(0.1545)
# Epoch: [27][122/123] Elapsed 0m 35s (remain 0m 0s) Loss: 0.1662(0.1942)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 8s) Loss: 0.1966(0.1966)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1004(0.4541)
# 	 epoch:27, avg train loss:0.1942, avg valid loss:0.4541
# 	 score:0.4729(th=0.750000), auc=0.880601::: time:688.45s
# - epoch:28 -
# Epoch: [28][0/123] Elapsed 0m 0s (remain 1m 54s) Loss: 0.1739(0.1739)
# Epoch: [28][122/123] Elapsed 0m 36s (remain 0m 0s) Loss: 0.3324(0.1986)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2363(0.2363)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0841(0.4757)
# 	 epoch:28, avg train loss:0.1986, avg valid loss:0.4757
# 	 score:0.4978(th=0.800000), auc=0.886525::: time:744.56s
# Epoch 28 - Save Best Score: 0.4978. Model is saved.
# dice_list:  [0.3345641910544911, 0.3542092157677842, 0.36957475620927566, 0.3829924824961796, 0.39475494281301227, 0.4056498175272871, 0.4176721084293188, 0.4296182918273006, 0.4398355556532094, 0.44938814827910284, 0.4592593818566734, 0.4694192217153676, 0.4809247022550001, 0.49197729320287975, 0.4977512702625854, 0.49632854217184336, 0.4834362243755809, 0.4309298438238158, 0.0]
# Epoch 28 - Save Best AUC: 0.8865. Model is saved.
# - epoch:29 -
# Epoch: [29][0/123] Elapsed 0m 0s (remain 2m 1s) Loss: 0.1998(0.1998)
# Epoch: [29][122/123] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2384(0.2075)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 8s) Loss: 0.3233(0.3233)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1279(0.5125)
# 	 epoch:29, avg train loss:0.2075, avg valid loss:0.5125
# 	 score:0.4876(th=0.850000), auc=0.882877::: time:804.06s
# - epoch:30 -
# Epoch: [30][0/123] Elapsed 0m 1s (remain 2m 7s) Loss: 0.2266(0.2266)
# Epoch: [30][122/123] Elapsed 0m 37s (remain 0m 0s) Loss: 0.1742(0.2238)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2590(0.2590)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1076(0.4480)
# 	 epoch:30, avg train loss:0.2238, avg valid loss:0.4480
# 	 score:0.4899(th=0.750000), auc=0.882161::: time:861.51s
# surface_list:  range(25, 35, 3)
# - epoch:31 -
# Epoch: [31][0/123] Elapsed 0m 1s (remain 2m 5s) Loss: 0.3339(0.3339)
# Epoch: [31][122/123] Elapsed 0m 36s (remain 0m 0s) Loss: 0.3028(0.2674)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2680(0.2680)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1298(0.5113)
# 	 epoch:31, avg train loss:0.2674, avg valid loss:0.5113
# 	 score:0.4568(th=0.800000), auc=0.866689::: time:56.68s
# Epoch 31 - Save Best Score: 0.4568. Model is saved.
# dice_list:  [0.2956447579064907, 0.3149691376839882, 0.3325164982046159, 0.34842003542352906, 0.3632904901307367, 0.37707879984132664, 0.39104005510128437, 0.4048166594381317, 0.4176302541206088, 0.42799078804444846, 0.4377992316904334, 0.4458677180813944, 0.4513828319331241, 0.45585523269815, 0.4568211885937955, 0.4472547667982938, 0.4240460530110265, 0.3703591441185061, 0.0]
# Epoch 31 - Save Best AUC: 0.8667. Model is saved.
# - epoch:32 -
# Epoch: [32][0/123] Elapsed 0m 0s (remain 1m 52s) Loss: 0.2195(0.2195)
# Epoch: [32][122/123] Elapsed 0m 36s (remain 0m 0s) Loss: 0.1986(0.2324)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2514(0.2514)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1125(0.4543)
# 	 epoch:32, avg train loss:0.2324, avg valid loss:0.4543
# 	 score:0.4668(th=0.650000), auc=0.870151::: time:116.56s
# Epoch 32 - Save Best Score: 0.4668. Model is saved.
# dice_list:  [0.29742742989688997, 0.32000120261705967, 0.33960723367963136, 0.3578379340536377, 0.3733964597848207, 0.3899140663125474, 0.4076613163790785, 0.42440044449935865, 0.43973145799701224, 0.4522117379260061, 0.4616503910819167, 0.4667843515915614, 0.4651170831961322, 0.4588972375452592, 0.44578308485915585, 0.41952782033729646, 0.36886677758254344, 0.2776127114642547, 0.0]
# Epoch 32 - Save Best AUC: 0.8702. Model is saved.
# - epoch:33 -
# Epoch: [33][0/123] Elapsed 0m 1s (remain 2m 6s) Loss: 0.2592(0.2592)
# Epoch: [33][122/123] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2105(0.2138)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2584(0.2584)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1322(0.5048)
# 	 epoch:33, avg train loss:0.2138, avg valid loss:0.5048
# 	 score:0.4668(th=0.800000), auc=0.873547::: time:175.49s
# Epoch 33 - Save Best AUC: 0.8735. Model is saved.
# - epoch:34 -
# Epoch: [34][0/123] Elapsed 0m 0s (remain 1m 50s) Loss: 0.1343(0.1343)
# Epoch: [34][122/123] Elapsed 0m 36s (remain 0m 0s) Loss: 0.1636(0.1948)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2133(0.2133)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0926(0.4731)
# 	 epoch:34, avg train loss:0.1948, avg valid loss:0.4731
# 	 score:0.4608(th=0.700000), auc=0.870120::: time:233.35s
# - epoch:35 -
# Epoch: [35][0/123] Elapsed 0m 0s (remain 2m 1s) Loss: 0.1739(0.1739)
# Epoch: [35][122/123] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2947(0.1786)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2512(0.2512)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0971(0.4919)
# 	 epoch:35, avg train loss:0.1786, avg valid loss:0.4919
# 	 score:0.4746(th=0.800000), auc=0.872576::: time:289.59s
# Epoch 35 - Save Best Score: 0.4746. Model is saved.
# dice_list:  [0.32307885923542196, 0.342767870327999, 0.3607365299729086, 0.37648595447221006, 0.39084504895584155, 0.4043024543666311, 0.4183214947841643, 0.4312849735945183, 0.44180666221172515, 0.45101078229440356, 0.45896969920263186, 0.46533584547465423, 0.46990393151261267, 0.47358006276834247, 0.4746470744349149, 0.47109227652774405, 0.4556867498097715, 0.40528573174816684, 0.0]
# - epoch:36 -
# Epoch: [36][0/123] Elapsed 0m 0s (remain 1m 46s) Loss: 0.1545(0.1545)
# Epoch: [36][122/123] Elapsed 0m 36s (remain 0m 0s) Loss: 0.1824(0.1747)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2081(0.2081)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0834(0.4606)
# 	 epoch:36, avg train loss:0.1747, avg valid loss:0.4606
# 	 score:0.4805(th=0.700000), auc=0.873023::: time:348.05s
# Epoch 36 - Save Best Score: 0.4805. Model is saved.
# dice_list:  [0.3430675436080825, 0.3686622357643966, 0.3884290447985107, 0.40547281577278843, 0.4216344473871728, 0.43447020069418557, 0.44510548761398844, 0.4533174636015015, 0.46141741066213887, 0.46790517286359545, 0.4731289052571145, 0.4777636030063866, 0.4804594791101291, 0.47962256776111634, 0.4751617519708632, 0.46171654643461335, 0.43309482109853936, 0.3658691859126898, 0.0]
# - epoch:37 -
# Epoch: [37][0/123] Elapsed 0m 1s (remain 2m 4s) Loss: 0.2250(0.2250)
# Epoch: [37][122/123] Elapsed 0m 36s (remain 0m 0s) Loss: 0.1728(0.1752)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2462(0.2462)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1001(0.5063)
# 	 epoch:37, avg train loss:0.1752, avg valid loss:0.5063
# 	 score:0.4650(th=0.750000), auc=0.869680::: time:405.89s
# - epoch:38 -
# Epoch: [38][0/123] Elapsed 0m 1s (remain 2m 5s) Loss: 0.1406(0.1406)
# Epoch: [38][122/123] Elapsed 0m 36s (remain 0m 0s) Loss: 0.1275(0.1728)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2117(0.2117)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1008(0.5090)
# 	 epoch:38, avg train loss:0.1728, avg valid loss:0.5090
# 	 score:0.4756(th=0.800000), auc=0.866402::: time:462.34s
# - epoch:39 -
# Epoch: [39][0/123] Elapsed 0m 0s (remain 1m 54s) Loss: 0.1561(0.1561)
# Epoch: [39][122/123] Elapsed 0m 35s (remain 0m 0s) Loss: 0.1763(0.1857)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2716(0.2716)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0961(0.5220)
# 	 epoch:39, avg train loss:0.1857, avg valid loss:0.5220
# 	 score:0.4474(th=0.750000), auc=0.870701::: time:518.23s
# - epoch:40 -
# Epoch: [40][0/123] Elapsed 0m 1s (remain 2m 9s) Loss: 0.1680(0.1680)
# Epoch: [40][122/123] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2825(0.2022)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2321(0.2321)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0951(0.5069)
# 	 epoch:40, avg train loss:0.2022, avg valid loss:0.5069
# 	 score:0.4724(th=0.800000), auc=0.875149::: time:574.75s
# Epoch 40 - Save Best AUC: 0.8751. Model is saved.
# - epoch:41 -
# Epoch: [41][0/123] Elapsed 0m 1s (remain 2m 10s) Loss: 0.2092(0.2092)
# Epoch: [41][122/123] Elapsed 0m 35s (remain 0m 0s) Loss: 0.1436(0.2016)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2860(0.2860)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1960(0.5405)
# 	 epoch:41, avg train loss:0.2016, avg valid loss:0.5405
# 	 score:0.4912(th=0.850000), auc=0.869261::: time:632.13s
# Epoch 41 - Save Best Score: 0.4912. Model is saved.
# dice_list:  [0.29514376620228383, 0.310632210194803, 0.32364079129676093, 0.3374172081064014, 0.3520437877068332, 0.36632749146080923, 0.3798770242884872, 0.3944474779038479, 0.40888490775180847, 0.42390151386411584, 0.43825833885446236, 0.4522396866121973, 0.46620567160133, 0.47810291267628063, 0.48659153053654636, 0.4912247961311922, 0.48238878172870686, 0.42237416032386627, 0.0]
# - epoch:42 -
# Epoch: [42][0/123] Elapsed 0m 0s (remain 1m 51s) Loss: 0.1832(0.1832)
# Epoch: [42][122/123] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2740(0.1972)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2024(0.2024)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1266(0.4843)
# 	 epoch:42, avg train loss:0.1972, avg valid loss:0.4843
# 	 score:0.4603(th=0.700000), auc=0.868486::: time:690.96s
# - epoch:43 -
# Epoch: [43][0/123] Elapsed 0m 1s (remain 2m 5s) Loss: 0.1534(0.1534)
# Epoch: [43][122/123] Elapsed 0m 36s (remain 0m 0s) Loss: 0.1361(0.1815)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2541(0.2541)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0867(0.5787)
# 	 epoch:43, avg train loss:0.1815, avg valid loss:0.5787
# 	 score:0.4483(th=0.850000), auc=0.862477::: time:747.62s
# - epoch:44 -
# Epoch: [44][0/123] Elapsed 0m 0s (remain 1m 55s) Loss: 0.1710(0.1710)
# Epoch: [44][122/123] Elapsed 0m 35s (remain 0m 0s) Loss: 0.1661(0.1616)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2672(0.2672)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0725(0.5296)
# 	 epoch:44, avg train loss:0.1616, avg valid loss:0.5296
# 	 score:0.4632(th=0.800000), auc=0.864045::: time:803.83s
# - epoch:45 -
# Epoch: [45][0/123] Elapsed 0m 0s (remain 1m 56s) Loss: 0.1345(0.1345)
# Epoch: [45][122/123] Elapsed 0m 36s (remain 0m 0s) Loss: 0.1256(0.1493)
# EVAL: [0/30] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2556(0.2556)
# EVAL: [29/30] Elapsed 0m 5s (remain 0m 0s) Loss: 0.0802(0.5198)
# 	 epoch:45, avg train loss:0.1493, avg valid loss:0.5198
# 	 score:0.4671(th=0.750000), auc=0.866753::: time:860.15s
# [fold2] slice ave score:0.4998(th=0.650000), auc=0.885238
# [fold2] BEST Epoch 41 - Save Best Score:0.4912. Best loss:0.5405
# [fold2] BEST AUC Epoch 40 - Save Best Score:0.8751. Best loss:0.5069
# fold[0] BEST SCORE = 0.5169 thr=0.7 (epoch=38)
# fold[0] slice ave score:0.5316(th=0.450000), auc=0.874596
# fold[1] BEST SCORE = 0.3453 thr=0.1 (epoch=31)
# fold[1] slice ave score:0.3467(th=0.100000), auc=0.757312
# fold[2] BEST SCORE = 0.4912 thr=0.85 (epoch=41)
# fold[2] slice ave score:0.4998(th=0.650000), auc=0.885238
# CPU times: user 1h 56min 23s, sys: 29min 11s, total: 2h 25min 34s
# Wall time: 2h 32min 6s

# %% [markdown]
# ---
# # OOF SCORE CHECK

# %%
# %%time
slice_ave_score_list, slice_ave_score_threshold_list, slice_ave_auc_list = slide_inference(CFG)
for fold in CFG["folds"]:
    print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    wandb.log({"OOF SCORE" : {f"slice average score":slice_ave_score_list[fold],
                            f"slice average threshold":slice_ave_score_threshold_list[fold],
                            f"slice_average auc":slice_ave_auc_list[fold],
                            }})
# Out:
# -- fold0 slide inference start --
# surface_list:  range(26, 36, 3)
# slide pos: [0, 0]
# 	 score:0.4959(th=0.600000), auc=0.869850::: time:26.43s
# slide pos: [64, 0]
# 	 score:0.4974(th=0.500000), auc=0.862617::: time:44.55s
# slide pos: [0, 64]
# 	 score:0.5009(th=0.650000), auc=0.875952::: time:62.90s
# slide pos: [64, 64]
# 	 score:0.4877(th=0.600000), auc=0.861425::: time:80.66s
# surface_list:  range(27, 37, 3)
# slide pos: [0, 0]
# 	 score:0.4620(th=0.550000), auc=0.860690::: time:105.29s
# slide pos: [64, 0]
# 	 score:0.4617(th=0.550000), auc=0.857203::: time:123.26s
# slide pos: [0, 64]
# 	 score:0.4683(th=0.550000), auc=0.868990::: time:141.02s
# slide pos: [64, 64]
# 	 score:0.4452(th=0.550000), auc=0.859188::: time:158.84s
# surface_list:  range(25, 35, 3)
# slide pos: [0, 0]
# 	 score:0.5012(th=0.600000), auc=0.869619::: time:183.32s
# slide pos: [64, 0]
# 	 score:0.5094(th=0.600000), auc=0.860822::: time:201.03s
# slide pos: [0, 64]
# 	 score:0.5035(th=0.650000), auc=0.871363::: time:218.59s
# slide pos: [64, 64]
# 	 score:0.4985(th=0.600000), auc=0.860032::: time:236.20s
# [fold0] slice ave score:0.5540(th=0.500000), auc=0.888354
# -- fold1 slide inference start --
# surface_list:  range(26, 36, 3)
# slide pos: [0, 0]
# 	 score:0.3296(th=0.100000), auc=0.766538::: time:342.51s
# slide pos: [64, 0]
# 	 score:0.3347(th=0.100000), auc=0.767849::: time:411.29s
# slide pos: [0, 64]
# 	 score:0.3205(th=0.100000), auc=0.762148::: time:480.73s
# slide pos: [64, 64]
# 	 score:0.3398(th=0.100000), auc=0.766641::: time:551.15s
# surface_list:  range(27, 37, 3)
# slide pos: [0, 0]
# 	 score:0.3205(th=0.100000), auc=0.761781::: time:647.52s
# slide pos: [64, 0]
# 	 score:0.3274(th=0.100000), auc=0.764561::: time:715.83s
# slide pos: [0, 64]
# 	 score:0.3141(th=0.100000), auc=0.757279::: time:786.18s
# slide pos: [64, 64]
# 	 score:0.3300(th=0.100000), auc=0.764526::: time:857.12s
# surface_list:  range(25, 35, 3)
# slide pos: [0, 0]
# 	 score:0.3335(th=0.100000), auc=0.767116::: time:952.90s
# slide pos: [64, 0]
# 	 score:0.3448(th=0.100000), auc=0.765995::: time:1020.70s
# slide pos: [0, 64]
# 	 score:0.3328(th=0.100000), auc=0.761734::: time:1092.47s
# slide pos: [64, 64]
# 	 score:0.3430(th=0.100000), auc=0.764132::: time:1164.84s
# [fold1] slice ave score:0.3775(th=0.100000), auc=0.791786
# -- fold2 slide inference start --
# surface_list:  range(26, 36, 3)
# slide pos: [0, 0]
# 	 score:0.4689(th=0.800000), auc=0.875481::: time:1257.01s
# slide pos: [64, 0]
# 	 score:0.4555(th=0.800000), auc=0.877330::: time:1279.14s
# slide pos: [0, 64]
# 	 score:0.4489(th=0.800000), auc=0.875753::: time:1301.86s
# slide pos: [64, 64]
# 	 score:0.4388(th=0.800000), auc=0.871777::: time:1324.18s
# surface_list:  range(27, 37, 3)
# slide pos: [0, 0]
# 	 score:0.4402(th=0.800000), auc=0.872519::: time:1355.39s
# slide pos: [64, 0]
# 	 score:0.4354(th=0.750000), auc=0.873225::: time:1378.05s
# slide pos: [0, 64]
# 	 score:0.4366(th=0.800000), auc=0.871091::: time:1400.49s
# slide pos: [64, 64]
# 	 score:0.4157(th=0.700000), auc=0.869197::: time:1423.62s
# surface_list:  range(25, 35, 3)
# slide pos: [0, 0]
# 	 score:0.4724(th=0.800000), auc=0.875149::: time:1455.43s
# slide pos: [64, 0]
# 	 score:0.4544(th=0.750000), auc=0.876161::: time:1478.53s
# slide pos: [0, 64]
# 	 score:0.4482(th=0.800000), auc=0.875729::: time:1501.40s
# slide pos: [64, 64]
# 	 score:0.4432(th=0.800000), auc=0.870739::: time:1523.95s
# [fold2] slice ave score:0.5040(th=0.700000), auc=0.892129
# fold[0] slice ave score:0.5540(th=0.888354), auc=0.500000
# fold[1] slice ave score:0.3775(th=0.791786), auc=0.100000
# fold[2] slice ave score:0.5040(th=0.892129), auc=0.700000
# CPU times: user 20min 22s, sys: 3min 29s, total: 23min 52s
# Wall time: 25min 41s

# %%
import yaml
with open(os.path.join(CFG["OUTPUT_DIR"], "Config.yaml"), "w") as f:
    yaml.dump(CFG, f)

# %%
if not CFG["DEBUG"]:
    wandb.finish()
