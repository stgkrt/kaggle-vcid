# %% [markdown]
# # ex011
# LR tuning

# %%
import gc
import os
import random
import time
import math

import cv2
import numpy as np
import matplotlib.pyplot as plt

# model
import torch
import torchvision
import torch.nn as nn
import timm
from torchvision.models.feature_extraction import create_feature_extractor
import torchvision.transforms.functional as TF

# data loader
import albumentations as A
from albumentations.pytorch import ToTensorV2
from torch.utils.data import DataLoader, Dataset

# training
from torch.optim import SGD, Adam, AdamW
from torch.optim.lr_scheduler import CosineAnnealingLR, CosineAnnealingWarmRestarts, ReduceLROnPlateau

# metric
from sklearn.metrics import fbeta_score, roc_auc_score

import wandb

# %% [markdown]
# # config

# %%
BASE_DIR = "/working/"
INPUT_DIR = os.path.join(BASE_DIR, "input", "vesuvius-challenge-ink-detection")
TRAIN_DIR = os.path.join(INPUT_DIR, "train")
TEST_DIR = os.path.join(INPUT_DIR, "test")
IMG_SIZE = [256, 256]
SURFACE_LIST = [
                range(26, 36, 3),
                range(27, 37, 3),                
                range(25, 35, 3),
                ]
print(len(SURFACE_LIST[0]))
print(SURFACE_LIST)

SURFACE_NUM = len(SURFACE_LIST[0])
# print("Start surface idx =",START_SURFACE)

# SLIDE_POS_LIST = [[idx*(IMG_SIZE[0]//6), idx*(IMG_SIZE[1]//6)] for idx in range(0, 3)]
SLIDE_POS_LIST = [[0,0], [IMG_SIZE[0]//2, 0], [0, IMG_SIZE[1]//2], [IMG_SIZE[0]//2, IMG_SIZE[1]//2]]
print("SLIDE_POS_LIST =", SLIDE_POS_LIST)
CFG = {
    "DEBUG" : False,
    # exp setting
    "EXP_CATEGORY" : "makebase",
    "EXP_NAME" : "exp011",
    "folds" : [0, 1, 2],

    # model
    # "model_name" : "tf_efficientnet_b0",
    "model_name" : "tf_efficientnet_b6",
    "inp_channels" : SURFACE_NUM,
    "out_channels" : 1,
    "pretrained" : True,
    "out_indices" : [0,1,2,3,4],
 
    # data   
    "img_size": IMG_SIZE,
    # "batch_size": 64,
    "batch_size": 16,#batch normの関係か？16の方が64より安定してそう？？
    "INPUT_DIR": INPUT_DIR,
    "TRAIN_DIR": TRAIN_DIR,
    "TEST_DIR": TEST_DIR,
    "surface_num": SURFACE_NUM,
    "surface_list": SURFACE_LIST,
    "slide_pos_list": SLIDE_POS_LIST,
#     "surface_start_idx": START_SURFACE,
    "TRAIN_DIR_LIST": [["1", "2"], ["1", "3"], ["2", "3"]],
#     "TRAIN_IDX_LIST" : ["1"],
    "VALID_DIR_LIST": [["3"],["2"],["1"]],
    "TEST_DIR_LIST": ["a", "b"],

    # learning
    "n_epoch" : 15,
    "lr" : 1e-4,
    "T_max" : 5,
    "min_lr" : 1e-8,
    "weight_decay" : 1e-6,

    # etc
    "print_freq" : 1000,
    "random_seed" : 21,
    "num_workers": 2,
}


if CFG["model_name"]=="tf_efficientnet_b0":
    CFG["channel_nums"] = [320, 112, 40, 24, 16]
elif CFG["model_name"]=="tf_efficientnet_b4":
    CFG["channel_nums"] = [448, 160, 56, 32, 24]
elif CFG["model_name"]=="tf_efficientnet_b6":
    CFG["channel_nums"] = [576, 200, 72, 40, 32]


if CFG["DEBUG"]:
    CFG["n_epoch"] = 1
    CFG["EXP_NAME"] = "DEBUG"
    

CFG["OUTPUT_DIR"] = os.path.join(BASE_DIR, "output", CFG["EXP_NAME"])
# Out:
# 4
# [range(26, 36, 3), range(27, 37, 3), range(25, 35, 3)]
# SLIDE_POS_LIST = [[0, 0], [128, 0], [0, 128], [128, 128]]

# %%
if not CFG["DEBUG"]:
    os.makedirs(CFG["OUTPUT_DIR"])
    os.makedirs(os.path.join(CFG["OUTPUT_DIR"], "imgs"))

# %%
if not CFG["DEBUG"]:
    WANDB_CONFIG = {'competition': 'vcid', '_wandb_kernel': 'taro'}
    os.environ["WANDB_SILENT"] = "true"
    wandb.init(project=WANDB_CONFIG["competition"], config=CFG, group=CFG["EXP_CATEGORY"], name=CFG["EXP_NAME"], reinit=True)
# Out:
# 2023-04-16 17:25:30.544576: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-16 17:25:30.626378: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-16 17:25:31.226521: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-16 17:25:31.226602: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-16 17:25:31.226609: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# # utils

# %%
def logging_metrics_epoch(CFG, fold, epoch, slice_idx,train_loss_avg, valid_loss_avg, score, threshold, auc_score):
    wandb.log({f"train/fold{fold}": train_loss_avg,
                f"valid/fold{fold}": valid_loss_avg,
                f"score/fold{fold}":score,
                f"score threshold/fold{fold}":threshold,
                f"auc/fold{fold}":auc_score,
                f"epoch/fold{fold}":epoch+slice_idx*CFG["n_epoch"],
                })

#     wandb.log({f"train/fold{fold}": train_loss_avg,
#             f"valid/fold{fold}": valid_loss_avg}, step=epoch+slice_idx*CFG["n_epoch"])
#     wandb.log({f"score/fold{fold}":score,
#                 f"score threshold/fold{fold}":threshold,
#                 f"auc/fold{fold}":auc_score,
#                 }, step=epoch+slice_idx*CFG["n_epoch"])

    # wandb.log({"loss avg":{f"train/fold{fold}": train_loss_avg,
    #                         f"valid/fold{fold}": valid_loss_avg}}, step=epoch+slice_idx*CFG["n_epoch"])
    # wandb.log({"Metircs" : {f"score/fold{fold}":score,
    #                         f"score threshold/fold{fold}":threshold,
    #                         f"auc/fold{fold}":auc_score,
    #                         }}, step=epoch+slice_idx*CFG["n_epoch"])

# %%
def seed_everything(seed=CFG["random_seed"]):
    #os.environ['PYTHONSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic =True
    torch.backends.cudnn.benchmark = False
seed_everything()

# device optimization
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
def asMinutes(s):
    """Convert Seconds to Minutes."""
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    """Accessing and Converting Time Data."""
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))

class AverageMeter(object):
    """Computes and stores the average and current value."""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# # metric

# %%
def fbeta_numpy(targets, preds, beta=0.5, smooth=1e-5):
    y_true_count = targets.sum()
    ctp = preds[targets==1].sum()
    cfp = preds[targets==0].sum()
    beta_squared = beta * beta

    c_precision = ctp / (ctp + cfp + smooth)
    c_recall = ctp / (y_true_count + smooth)
    dice = (1 + beta_squared) * (c_precision * c_recall) / (beta_squared * c_precision + c_recall + smooth)

    return dice

def calc_fbeta_auc(mask, mask_pred):
    mask = mask.astype(int).flatten()
    mask_pred = mask_pred.flatten()

    best_th = 0
    best_dice = 0
    dice_list = [] 
    # for th in np.array(range(10, 50+1, 5)) / 100:
    for th in np.array(range(10, 100+1, 5)) / 100:
        # dice = fbeta_score(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice = fbeta_numpy(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice_list.append(dice)
        # print(f'\t th: {th}, fbeta: {dice}')
        if dice > best_dice:
            best_dice = dice
            best_th = th
    
    auc = roc_auc_score(mask, mask_pred)
    # Logger.info(f'best_th: {best_th}, fbeta: {best_dice}')
    return best_dice, best_th, auc, dice_list


def calc_cv(mask_gt, mask_pred):
    best_dice, best_th, auc, dice_list = calc_fbeta_auc(mask_gt, mask_pred)

    return best_dice, best_th, auc, dice_list

# %% [markdown]
# # model

# %%
class Encoder(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = timm.create_model(CFG["model_name"], in_chans=CFG["inp_channels"], features_only=True, out_indices=CFG["out_indices"], pretrained=CFG["pretrained"])
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        return skip_connection_list

class UpConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.bn1 = nn.BatchNorm2d(in_channels)
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size = 2, padding="same")
        self.bn2 = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        x = self.up(x)
        x = self.bn1(x)
        x = self.conv(x)
        x = self.bn2(x)
        return x


class Decoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.UpConv_0 = UpConv(CFG["channel_nums"][0], CFG["channel_nums"][1])
        self.UpConv_1 = UpConv(CFG["channel_nums"][1]*2, CFG["channel_nums"][2])
        self.UpConv_2 = UpConv(CFG["channel_nums"][2]*2, CFG["channel_nums"][3])
        self.UpConv_3 = UpConv(CFG["channel_nums"][3]*2, CFG["channel_nums"][4])
        self.UpConv_4 = UpConv(CFG["channel_nums"][4]*2, CFG["channel_nums"][4])
    
    def forward(self, skip_connection_list):
        emb = self.UpConv_0(skip_connection_list[4]) # emb.shape = (None, 160, 14, 14)
        emb_cat = torch.cat([skip_connection_list[3], emb], dim = 1)
        
        emb = self.UpConv_1(emb_cat)
        emb_cat = torch.cat([skip_connection_list[2], emb], dim = 1)
        
        emb = self.UpConv_2(emb_cat)
        emb_cat = torch.cat([skip_connection_list[1], emb], dim = 1)
        
        emb = self.UpConv_3(emb_cat)
        emb_cat = torch.cat([skip_connection_list[0], emb], dim = 1)

        emb_cat = self.UpConv_4(emb_cat)
        
        return emb_cat

class SegModel(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = Encoder(CFG)
        self.decoder = Decoder()
        self.head = nn.Sequential(
            nn.Conv2d(CFG["channel_nums"][-1], CFG["out_channels"], kernel_size=1, stride=1, padding=0),
            nn.Sigmoid()
        )
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        emb = self.decoder(skip_connection_list)
        output = self.head(emb)
        return output

# %% [markdown]
# # Dataset

# %%
train_transforms = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.RandomCrop(int(CFG["img_size"][0]*0.8), int(CFG["img_size"][1]*0.8), p=0.5),
    A.Blur(blur_limit=3, p=0.3),
    A.Resize(CFG["img_size"][0], CFG["img_size"][1]),
    ToTensorV2(),
])

valid_transforms = A.Compose([
    ToTensorV2(),
])

# %%
def fft_transform(img):
    eps = 1e-7
    f = np.fft.fft2(img)
    fshift = np.fft.fftshift(f)
    fshift = np.nan_to_num(fshift)+eps#nanを0埋め
    magnitude_spectrum = 20*np.log(np.abs(fshift))
    return magnitude_spectrum

def highpass_filter(img):
    frange = 1
    dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
    dft_shift = np.fft.fftshift(dft)

    rows, cols = img.shape
    crow,ccol = rows//2 , cols//2

    # create a mask first, center square is 1, remaining all zeros
    mask = np.ones((rows,cols,2),np.uint8)
    mask[crow-frange:crow+frange, ccol-frange:ccol+frange] = 0

    # apply mask and inverse DFT
    fshift = dft_shift*mask
    f_ishift = np.fft.ifftshift(fshift)
    img_back = cv2.idft(f_ishift)
    img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

    return img_back

def lowpass_filter(img):
    frange = 5
    dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
    dft_shift = np.fft.fftshift(dft)

    rows, cols = img.shape
    crow,ccol = rows//2 , cols//2

    # create a mask first, center square is 1, remaining all zeros
    mask = np.zeros((rows,cols,2),np.uint8)
    mask[crow-frange:crow+frange, ccol-frange:ccol+frange] = 1

    # apply mask and inverse DFT
    fshift = dft_shift*mask
    f_ishift = np.fft.ifftshift(fshift)
    img_back = cv2.idft(f_ishift)
    img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

    return img_back

# %%
class VCID_Dataset(Dataset):
    def __init__(self, CFG, data_dir_list, surface_list, surface_volumes=None, slide_pos=[0,0], mode="train", transform=None):
        # get config
        self.mode = mode
        self.img_size = CFG["img_size"]
        if self.mode=="train":  self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode=="valid":    self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode == "test":   self.DATADIR = CFG["TEST_DIR"]
        self.data_dir_list = data_dir_list
        self.surface_list = surface_list
        self.slide_pos = slide_pos
        self.transform = transform
        
        # get imgs
        # print("initializing dataset...")
        self.imgs = []
        for data_dir in self.data_dir_list:
            img_path = os.path.join(self.DATADIR, data_dir, "mask.png")
            # print(img_path)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            img = img.reshape(img.shape[0], img.shape[1], 1) # (h, w, channel=1)
            self.imgs.append(img)
        
        # check imgs
        for img in self.imgs:
            assert img is not None, "img is None. data path is wrong"
        # get and split surface
        if surface_volumes is None:
            self.surface_vols = self.read_surfacevols()
        else:
            # print("using loaded surface_vols")
            self.surface_vols = surface_volumes
        for surface_vol in self.surface_vols:
            assert surface_vol is not None, "surface_vol is None. data path is wrong"
       
        # split grid
        self.get_all_grid()
        self.fileter_grid()
        self.get_flatten_grid()
        # print("split grid done.") 
       
        # get label imgs
        if self.mode == "train" or self.mode == "valid":
            self.labels = []
            for data_dir in self.data_dir_list:
                label_path = os.path.join(self.DATADIR, data_dir, "inklabels.png")
                assert os.path.exists(label_path), f"{label_path} is not exist."
                
                # read label
                label = cv2.imread(label_path, cv2.IMREAD_GRAYSCALE)
                # mask erosion
                kernel_size = (img.shape[0]+img.shape[1])//2//100
                kernel = np.ones((kernel_size, kernel_size), np.uint8)
                img = cv2.erode(img, kernel,iterations = 3)
                
                label = label.reshape(label.shape[0], label.shape[1], 1) # (h, w, channel=1)
                self.labels.append(label)# 画像サイズがそれぞれ違うので単純にconcatできずlist化しているs
        # print("initializing dataset done.")

    def get_surface_volumes(self):
        return self.surface_vols

    def read_surfacevols(self):
        """ read surface volume by data_dir_list and surface_list 
            Returns:surface_vuls (list): surface volume list [array(h,w,channel=surface_num), array(), ...]
        """
        surface_vols = []
        # print("reading surface volume...")
        for data_dir in self.data_dir_list:
            surface_vol_ = None
            for read_idx, surface_idx in enumerate(self.surface_list):
                # print("\r", f"reading idx : {read_idx+1}/{len(self.surface_list)}", end="")
                surface_path = os.path.join(self.DATADIR, data_dir, "surface_volume", f"{surface_idx:02}.tif")
                surface_vol = cv2.imread(surface_path, cv2.IMREAD_GRAYSCALE)
                surface_vol = surface_vol.reshape(surface_vol.shape[0], surface_vol.shape[1], 1) # (h, w, channel=1)
                if surface_vol_ is None:
                    surface_vol_ = surface_vol
                else:
                    surface_vol_ = np.concatenate([surface_vol_, surface_vol], axis=2) # (h, w, channel=surface_num)
            surface_vols.append(surface_vol_)
            # print(f"  => read surface volume done. [{data_dir}]")
        return surface_vols


    def get_grid_img(self, img, grid_idx):
        """ crop grid img from original img"""
        img_grid = img[grid_idx[0]*self.img_size[0] + self.slide_pos[0] : (grid_idx[0]+1)*self.img_size[0] + self.slide_pos[0],
                        grid_idx[1]*self.img_size[1] + self.slide_pos[1] : (grid_idx[1]+1)*self.img_size[1] + self.slide_pos[1]]
        return img_grid
    
    
    def get_masked_img(self, img, mask):
        """ multiply mask to surface_volumes """
        masked_img = None
        for channel in range(img.shape[2]):
            img_channel = img[:,:,channel].reshape(img.shape[0], img.shape[1],1)
            masked = img_channel*mask
            if masked_img is None:
                masked_img = masked.reshape(masked.shape[0], masked.shape[1], 1)
            else:
                masked = masked.reshape(masked.shape[0], masked.shape[1], 1)
                masked_img = np.concatenate([masked_img, masked], axis=2)
        return masked_img
    
    def get_grid_hpfimg(self, img, grid_idx):
        """ crop grid img from original img and hpf filter """
        img_grid = self.get_grid_img(img, grid_idx)
        img_transformed = None
        for channel in range(img_grid.shape[2]):
            img_grid_trans = highpass_filter(img_grid[:,:,channel])
            if img_transformed is None:
                img_transformed = img_grid_trans.reshape(img_grid_trans.shape[0], img_grid_trans.shape[1], 1)
            else:
                img_transformed = np.concatenate([img_transformed, img_grid_trans.reshape(img_grid_trans.shape[0], img_grid_trans.shape[1], 1)], axis=2)
        return img_transformed
    
    def get_all_grid(self):
        """ get all grid indices by img size and grid size
        """
        self.grid_indices = []
        for img in self.imgs:
            self.x_grid_size = (img.shape[0] - self.slide_pos[0]) // self.img_size[0]
            self.y_grid_size = (img.shape[1] - self.slide_pos[1]) // self.img_size[1]
            grid_img = []
            for i in range(self.x_grid_size):
                for j in range(self.y_grid_size):
                    grid_img.append([i, j])
            self.grid_indices.append(grid_img)
        return self.grid_indices
          
    def fileter_grid(self):
        """ get grid indices which mask is not 0 by all grid indices"""
        grid_indices_all = []
        for img, grid_indices in zip(self.imgs, self.grid_indices):
            grid_indices_copy = grid_indices.copy()
            for grid_idx in grid_indices:
                img_grid = self.get_grid_img(img, grid_idx)
                if img_grid.sum() == 0:
                    grid_indices_copy.remove(grid_idx)
            grid_indices_all.append(grid_indices_copy)
        self.grid_indices = grid_indices_all
        return self.grid_indices

    def get_flatten_grid(self):
        """ get flatten index list by grid indices
            Returns:flatten_grid (list): flatten index list [[img_idx, grid_idx], [img_idx, grid_idx], ...]
        """
        flatten_grid = []
        for img_idx, grid_indices in enumerate(self.grid_indices):
            for grid_idx in grid_indices:
                grid_imgidx_list = [img_idx]
                grid_imgidx_list.extend(grid_idx)
                flatten_grid.append(grid_imgidx_list)
        self.flatten_grid = flatten_grid
        return self.flatten_grid

    def __len__(self):
        return len(self.flatten_grid)

    def __getitem__(self, idx):
        # get indices
        img_grid_idx = self.flatten_grid[idx]
        img_idx = img_grid_idx[0]
        grid_idx = img_grid_idx[1:]
        # get img & surface_vol
        img = self.imgs[img_idx]
        surface_vol = self.surface_vols[img_idx]
        img = self.get_grid_img(img, grid_idx)/255.
        surface_vol = self.get_grid_img(surface_vol, grid_idx)/255.
        
        # multiple small mask 
        surface_vol = self.get_masked_img(surface_vol, img)
        assert surface_vol.shape[0]==img.shape[0] and surface_vol.shape[1]==img.shape[1] , "surface_vol_list shape is not same as img shape"
        img = surface_vol

        # transform
        if self.mode == "test":
            if self.transform:
                img = self.transform(image=img)["image"]
            else:
                img = img.transpose(2, 0, 1)
                img = torch.tensor(img, dtype=torch.float32)
            return img, grid_idx
        elif self.mode == "train" or self.mode=="valid":
            # get label(segmentation mask)
            label = self.labels[img_idx]
            label = self.get_grid_img(label, grid_idx)
            if self.transform:
                transformed = self.transform(image=img, mask=label)
                img = transformed["image"]
                label = transformed["mask"]
                label = label.permute(2, 0, 1)/255. # (channel, h, w)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            else:
                img = img.transpose(2, 0, 1) # (channel, h, w)
                label = label.transpose(2, 0, 1)/255. # (channel, h, w){}
                img = torch.tensor(img, dtype=torch.float32)
                label = torch.tensor(label, dtype=torch.float32)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            return img, label, grid_idx

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train")
# surface_volumes = dataset_notrans.surface_vols
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 1:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos=[0,50],mode="train")
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 1:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train", transform=train_transforms)
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)


# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 0:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %% [markdown]
# # train valid fn

# %%
def train_fn(train_loader, model, criterion, epoch ,optimizer, scheduler):
    model.train()
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, _) in enumerate(train_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()     
        preds = model(images)
        
        # preds = torch.sigmoid(preds)
        loss = criterion(preds, targets)
        
        losses.update(loss.item(), CFG["batch_size"]) 
        targets = targets.detach().cpu().numpy().ravel().tolist()
        preds = preds.detach().cpu().numpy().ravel().tolist()
        loss.backward() # パラメータの勾配を計算
        optimizer.step() # モデル更新
        optimizer.zero_grad() # 勾配の初期化
                
        batch_time.update(time.time() - end)
        end = time.time()
        if batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(train_loader)-1):
            print('Epoch: [{0}][{1}/{2}] '
                    'Elapsed {remain:s} '
                    'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                    .format(
                        epoch, batch_idx, len(train_loader), batch_time=batch_time, loss=losses,
                        remain=timeSince(start, float(batch_idx+1)/len(train_loader)),
            ))
        del preds, images, targets
    gc.collect()
    torch.cuda.empty_cache()
    return losses.avg

# %%
def valid_fn(model, valid_loader, criterion=None):
    model.eval()# モデルを検証モードに設定
    test_targets = []
    test_preds = []
    test_grid_idx = []
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, grid_idx) in enumerate(valid_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()
        with torch.no_grad():
            preds = model(images)
            if not criterion is None:
                loss = criterion(preds, targets)
        if not criterion is None:
            losses.update(loss.item(), CFG["batch_size"])
        batch_time.update(time.time() - end)

        targets = targets.detach().cpu().numpy()
        preds = preds.detach().cpu().numpy()
        
        test_preds.extend([preds[idx, :,:,:].transpose(1,2,0) for idx in range(preds.shape[0])])
        test_targets.extend([targets[idx, :,:,:].transpose(1,2,0) for idx in range(targets.shape[0])])
        test_grid_idx.extend([[x_idx, y_idx] for x_idx, y_idx in zip(grid_idx[0].tolist(), grid_idx[1].tolist())])

        if (batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(valid_loader)-1)) and (not criterion is None):
            print('EVAL: [{0}/{1}] '
                'Elapsed {remain:s} '
                'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                .format(
                    batch_idx, len(valid_loader), batch_time=batch_time, loss=losses,
                    remain=timeSince(start, float(batch_idx+1)/len(valid_loader)),
                ))
        del preds, images, targets
        gc.collect()
        torch.cuda.empty_cache()
    if criterion is None:
        return test_targets, test_preds, test_grid_idx
    else:
        return test_targets, test_preds, test_grid_idx, losses.avg

# %% [markdown]
# # training loop

# %%
# def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list):
#     # concat pred img and label to original size
#     img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
#     img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
#     img = img.reshape(img.shape[0], img.shape[1], 1)
#     pred_img = np.zeros_like(img).astype(np.float32)
#     label_img = np.zeros_like(img).astype(np.float32)
#     for img_idx, grid_idx in enumerate(grid_idx_list):
#         pred_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += img_list[img_idx]
        
#         label_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += label_list[img_idx]
#     return pred_img, label_img

# %%
def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list, slide_pos=[0,0]):
    # concat pred img and label to original size
    img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    img = img.reshape(img.shape[0], img.shape[1], 1)
    pred_img = np.zeros_like(img).astype(np.float32)
    label_img = np.zeros_like(img).astype(np.float32)
    for img_idx, grid_idx in enumerate(grid_idx_list):
        pred_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += img_list[img_idx]
        
        label_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += label_list[img_idx]
    return pred_img, label_img

# %%
def save_and_plot_oof(mode, fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary):
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_pred_img.png"), valid_preds_img*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_predbin_img.png"), valid_preds_binary*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_targets_img.png"), valid_targets_img*255)
    
    # plot preds & binary preds
    # plt.figure(dpi=100)
    # plt.subplot(1,3,1)
    # plt.imshow(valid_preds_img)
    # plt.subplot(1,3,2)
    # plt.imshow(valid_preds_binary)
    # plt.subplot(1,3,3)
    # plt.imshow(valid_targets_img)
    # plt.show()

# %%
def training_loop(CFG):
    best_score_list = []
    best_threshold_list = []
    best_epoch_list = []
    slice_ave_score_list = []
    slice_ave_auc_list = []
    slice_ave_score_threshold_list = []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} training start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        model = model.to(device)
        valid_img_slice = []
        criterion = nn.BCELoss()
        optimizer = AdamW(model.parameters(), lr=CFG["lr"], weight_decay=CFG["weight_decay"], amsgrad=False)
        scheduler = CosineAnnealingLR(optimizer, T_max=CFG["T_max"], eta_min=CFG["min_lr"], last_epoch=-1)
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            # separate train/valid data 
            train_dirs = CFG["TRAIN_DIR_LIST"][fold]
            valid_dirs = CFG["VALID_DIR_LIST"][fold]
            train_dataset = VCID_Dataset(CFG, train_dirs, surface_list, mode="train", transform=train_transforms)
            valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, mode="valid", transform=valid_transforms)
            train_loader = DataLoader(train_dataset, batch_size=CFG["batch_size"], shuffle = True,
                                        num_workers = CFG["num_workers"], pin_memory = True)
            valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                        num_workers = CFG["num_workers"], pin_memory = True)

            # training
            best_score = -np.inf
            best_auc = -np.inf
            best_valloss = np.inf
            best_auc_valloss = np.inf
            best_threshold = -1
            start_time = time.time()
            best_epoch = -1
            best_auc_epoch = -1
            for epoch in range(1, CFG["n_epoch"] + 1):
                epochs_ = epoch + CFG["n_epoch"] * slice_idx
                print(f'- epoch:{epochs_} -')
                train_loss_avg = train_fn(train_loader, model, criterion, epochs_ ,optimizer, scheduler)
                valid_targets, valid_preds, valid_grid_idx, valid_loss_avg = valid_fn(model, valid_loader, criterion)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                
                elapsed = time.time() - start_time
                print(f"\t epoch:{epochs_}, avg train loss:{train_loss_avg:.4f}, avg valid loss:{valid_loss_avg:.4f}")
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                if not CFG["DEBUG"]:
                    logging_metrics_epoch(CFG, fold, epoch, slice_idx, train_loss_avg, valid_loss_avg, valid_score, valid_threshold, auc)
                scheduler.step()
                # validationスコアがbestを更新したらモデルを保存する
                if valid_score > best_score:
                    best_epoch = epochs_
                    best_valloss = valid_loss_avg
                    best_score = valid_score
                    best_threshold = valid_threshold
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epochs_} - Save Best Score: {best_score:.4f}. Model is saved.')
                    print("dice_list: ", dice_list)
                    # save oof
                    save_and_plot_oof("score", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
                
                if auc > best_auc:
                    best_auc = auc
                    best_auc_epoch = epochs_
                    best_auc_valloss = valid_loss_avg
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_auc_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epochs_} - Save Best AUC: {best_auc:.4f}. Model is saved.')
                    # save oof
                    save_and_plot_oof("auc", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
            valid_img_slice.append(valid_preds_img)
        valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        for idx in range(len(SURFACE_LIST)):
            valid_pred_slice = valid_img_slice[idx]
            valid_slice_ave += valid_pred_slice
        valid_slice_ave /= len(CFG["folds"])
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_slice_ave)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)
 
        valid_slice_binary = (valid_slice_ave > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 999, valid_slice_ave, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
        
        print(f'[fold{fold}] BEST Epoch {best_epoch} - Save Best Score:{best_score:.4f}. Best loss:{best_valloss:.4f}')
        print(f'[fold{fold}] BEST AUC Epoch {best_auc_epoch} - Save Best Score:{best_auc:.4f}. Best loss:{best_auc_valloss:.4f}')
            
        best_score_list.append(best_score)
        best_threshold_list.append(best_threshold)
        best_epoch_list.append(best_epoch)
        del model, train_loader, train_dataset, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
        
    for fold, (best_score, best_threshold, best_epoch) in enumerate(zip(best_score_list, best_threshold_list, best_epoch_list)):
        print(f"fold[{fold}] BEST SCORE = {best_score:.4f} thr={best_threshold} (epoch={best_epoch})")
        print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    return best_score_list, best_threshold_list, best_epoch_list

# %% [markdown]
# # slice inference

# %%
def slide_inference(CFG):
    start_time = time.time()
    slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list = [], [], []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} slide inference start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        # model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_fold{fold}.pth')
        model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_auc_fold{fold}.pth')
        model.load_state_dict(torch.load(model_path))
        model = model.to(device)
        valid_img_slice = []
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            surface_volumes = None
            for slide_pos in CFG["slide_pos_list"]:
                print("slide pos:", slide_pos)
                valid_dirs = CFG["VALID_DIR_LIST"][fold]
                valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos, mode="valid", transform=valid_transforms)
                surface_volumes = valid_dataset.get_surface_volumes()
                valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                            num_workers = CFG["num_workers"], pin_memory = True)

                valid_targets, valid_preds, valid_grid_idx = valid_fn(model, valid_loader)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs, slide_pos)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                save_and_plot_oof("slide", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary) 
                
                elapsed = time.time() - start_time
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                valid_img_slice.append(valid_preds_img)
            valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        for idx in range(len(SURFACE_LIST)*len(CFG["slide_pos_list"])):
            valid_pred_slice = valid_img_slice[idx]
            valid_slice_ave += valid_pred_slice
        valid_slice_ave /= len(SURFACE_LIST)*len(CFG["slide_pos_list"])
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_slice_ave)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)

        valid_slice_binary = (valid_slice_ave > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 555, valid_slice_ave, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
         
        del model, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
    return slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list

# %% [markdown]
# # main

# %%
# %%time
best_score_list, best_threshold_list, best_epoch_list = training_loop(CFG)
# Out:
# -- fold0 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/conv.py:444: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at  ../aten/src/ATen/native/Convolution.cpp:744.)
#   self.padding, self.dilation, self.groups)
# Epoch: [1][0/130] Elapsed 0m 0s (remain 2m 7s) Loss: 0.7242(0.7242)
# Epoch: [1][129/130] Elapsed 0m 37s (remain 0m 0s) Loss: 0.6737(0.6542)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5729(0.5729)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4796(0.5762)
# 	 epoch:1, avg train loss:0.6542, avg valid loss:0.5762
# 	 score:0.3861(th=0.650000), auc=0.844137::: time:53.96s
# Epoch 1 - Save Best Score: 0.3861. Model is saved.
# dice_list:  [0.1380733941090461, 0.13808724074082537, 0.1382011915196754, 0.13967724366649364, 0.15441777014932656, 0.1729184958535073, 0.2030455402430485, 0.2472257956231142, 0.30001437951148846, 0.34909812573898874, 0.38200292803575947, 0.3860787866996655, 0.3542073159254238, 0.28234223830326377, 0.18617126670245007, 0.08494011920170749, 0.027282595109038577, 0.0018158297192056782, 0.0]
# Epoch 1 - Save Best AUC: 0.8441. Model is saved.
# - epoch:2 -
# Epoch: [2][0/130] Elapsed 0m 0s (remain 2m 5s) Loss: 0.6061(0.6061)
# Epoch: [2][129/130] Elapsed 0m 37s (remain 0m 0s) Loss: 0.7898(0.6121)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5086(0.5086)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4723(0.5519)
# 	 epoch:2, avg train loss:0.6121, avg valid loss:0.5519
# 	 score:0.4462(th=0.650000), auc=0.852211::: time:110.66s
# Epoch 2 - Save Best Score: 0.4462. Model is saved.
# dice_list:  [0.1380734325814245, 0.13808594660840384, 0.13838721369251483, 0.1409245407487103, 0.1590739023243049, 0.18101970580891014, 0.22109770924324287, 0.28441596314926987, 0.35200219732747695, 0.40251943411060503, 0.4328326292272593, 0.4461847650328586, 0.4404314224582361, 0.4165952182610778, 0.3792896320074066, 0.32166520055984554, 0.24011137283970435, 0.12084661895360975, 0.0]
# Epoch 2 - Save Best AUC: 0.8522. Model is saved.
# - epoch:3 -
# Epoch: [3][0/130] Elapsed 0m 0s (remain 1m 55s) Loss: 0.5888(0.5888)
# Epoch: [3][129/130] Elapsed 0m 37s (remain 0m 0s) Loss: 0.6243(0.5800)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5420(0.5420)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4862(0.5534)
# 	 epoch:3, avg train loss:0.5800, avg valid loss:0.5534
# 	 score:0.4334(th=0.750000), auc=0.844230::: time:167.21s
# - epoch:4 -
# Epoch: [4][0/130] Elapsed 0m 0s (remain 1m 55s) Loss: 0.5642(0.5642)
# Epoch: [4][129/130] Elapsed 0m 37s (remain 0m 0s) Loss: 0.7822(0.5587)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.6861(0.6861)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4927(0.6744)
# 	 epoch:4, avg train loss:0.5587, avg valid loss:0.6744
# 	 score:0.4727(th=0.900000), auc=0.866272::: time:220.85s
# Epoch 4 - Save Best Score: 0.4727. Model is saved.
# dice_list:  [0.1380733941090461, 0.13808024733967827, 0.13830958416171776, 0.14119231374698357, 0.1644629396279938, 0.19314664965707679, 0.22799817174363768, 0.2672671622031069, 0.30436779272219444, 0.3384854094814593, 0.3664702509820343, 0.3904008438322945, 0.4105743533435337, 0.4292025593027966, 0.44694503470781055, 0.4643402399285076, 0.4727095836691892, 0.46800012744826786, 0.0058536224228654815]
# Epoch 4 - Save Best AUC: 0.8663. Model is saved.
# - epoch:5 -
# Epoch: [5][0/130] Elapsed 0m 1s (remain 2m 10s) Loss: 0.4956(0.4956)
# Epoch: [5][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.4524(0.5379)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5884(0.5884)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4707(0.5802)
# 	 epoch:5, avg train loss:0.5379, avg valid loss:0.5802
# 	 score:0.4762(th=0.800000), auc=0.859406::: time:276.29s
# Epoch 5 - Save Best Score: 0.4762. Model is saved.
# dice_list:  [0.13807338449095485, 0.13808558130712664, 0.13831738253561557, 0.1437928696492581, 0.16972349388126715, 0.19809052621795908, 0.23777416699313916, 0.2847703679113968, 0.3321575973448161, 0.37154646372945305, 0.402943193653383, 0.4326282493229173, 0.4568082593021826, 0.4714309030856062, 0.47622671067763983, 0.47030270596229773, 0.4498980962215457, 0.40634279932176764, 0.0]
# - epoch:6 -
# Epoch: [6][0/130] Elapsed 0m 0s (remain 2m 5s) Loss: 0.5087(0.5087)
# Epoch: [6][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.6896(0.5297)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.6250(0.6250)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4689(0.6158)
# 	 epoch:6, avg train loss:0.5297, avg valid loss:0.6158
# 	 score:0.4798(th=0.850000), auc=0.864167::: time:330.93s
# Epoch 6 - Save Best Score: 0.4798. Model is saved.
# dice_list:  [0.13807338449095485, 0.13808231926401848, 0.13831449243142047, 0.1445676029995021, 0.16983227890352867, 0.1962501807162722, 0.23079777550541006, 0.27282637230648066, 0.3148706115137163, 0.35224151665396286, 0.38277087984874375, 0.4110031687392554, 0.4372440413859544, 0.46014399742513173, 0.47779739336125265, 0.47976414958403046, 0.47100053669142367, 0.44355416113089596, 0.001763202609147469]
# - epoch:7 -
# Epoch: [7][0/130] Elapsed 0m 0s (remain 2m 2s) Loss: 0.5803(0.5803)
# Epoch: [7][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.8171(0.5354)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.6322(0.6322)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4949(0.6194)
# 	 epoch:7, avg train loss:0.5354, avg valid loss:0.6194
# 	 score:0.4577(th=0.850000), auc=0.854793::: time:384.92s
# - epoch:8 -
# Epoch: [8][0/130] Elapsed 0m 0s (remain 1m 59s) Loss: 0.4477(0.4477)
# Epoch: [8][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.7818(0.5336)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5621(0.5621)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4215(0.5401)
# 	 epoch:8, avg train loss:0.5336, avg valid loss:0.5401
# 	 score:0.4764(th=0.850000), auc=0.861392::: time:437.06s
# - epoch:9 -
# Epoch: [9][0/130] Elapsed 0m 0s (remain 2m 4s) Loss: 0.4861(0.4861)
# Epoch: [9][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.8361(0.5294)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4647(0.4647)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4051(0.5396)
# 	 epoch:9, avg train loss:0.5294, avg valid loss:0.5396
# 	 score:0.4428(th=0.700000), auc=0.848821::: time:489.08s
# - epoch:10 -
# Epoch: [10][0/130] Elapsed 0m 0s (remain 2m 0s) Loss: 0.4550(0.4550)
# Epoch: [10][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.8280(0.5191)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5024(0.5024)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3807(0.5707)
# 	 epoch:10, avg train loss:0.5191, avg valid loss:0.5707
# 	 score:0.4209(th=0.700000), auc=0.845924::: time:541.23s
# - epoch:11 -
# Epoch: [11][0/130] Elapsed 0m 0s (remain 2m 0s) Loss: 0.4637(0.4637)
# Epoch: [11][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 1.3081(0.5186)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 1.4701(1.4701)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5797(1.5770)
# 	 epoch:11, avg train loss:0.5186, avg valid loss:1.5770
# 	 score:0.4147(th=0.950000), auc=0.863991::: time:593.20s
# - epoch:12 -
# Epoch: [12][0/130] Elapsed 0m 0s (remain 2m 5s) Loss: 0.3944(0.3944)
# Epoch: [12][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3409(0.5744)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.7146(0.7146)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3779(0.9877)
# 	 epoch:12, avg train loss:0.5744, avg valid loss:0.9877
# 	 score:0.4534(th=0.950000), auc=0.867336::: time:645.39s
# Epoch 12 - Save Best AUC: 0.8673. Model is saved.
# - epoch:13 -
# Epoch: [13][0/130] Elapsed 0m 0s (remain 2m 7s) Loss: 0.3920(0.3920)
# Epoch: [13][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.4733(0.5065)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.3111(0.3111)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3583(0.4861)
# 	 epoch:13, avg train loss:0.5065, avg valid loss:0.4861
# 	 score:0.4324(th=0.700000), auc=0.849468::: time:699.59s
# - epoch:14 -
# Epoch: [14][0/130] Elapsed 0m 0s (remain 2m 1s) Loss: 0.3601(0.3601)
# Epoch: [14][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 1.3257(0.5445)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.2799(0.2799)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3593(0.5169)
# 	 epoch:14, avg train loss:0.5445, avg valid loss:0.5169
# 	 score:0.4613(th=0.800000), auc=0.836622::: time:751.95s
# - epoch:15 -
# Epoch: [15][0/130] Elapsed 0m 0s (remain 2m 1s) Loss: 0.3026(0.3026)
# Epoch: [15][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 2.2441(0.4829)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.3680(0.3680)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3591(0.6143)
# 	 epoch:15, avg train loss:0.4829, avg valid loss:0.6143
# 	 score:0.4569(th=0.900000), auc=0.851169::: time:804.06s
# surface_list:  range(27, 37, 3)
# - epoch:16 -
# Epoch: [16][0/130] Elapsed 0m 0s (remain 2m 7s) Loss: 0.3677(0.3677)
# Epoch: [16][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.3897(0.5181)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.3610(0.3610)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3426(0.5861)
# 	 epoch:16, avg train loss:0.5181, avg valid loss:0.5861
# 	 score:0.4386(th=0.800000), auc=0.840671::: time:52.76s
# Epoch 16 - Save Best Score: 0.4386. Model is saved.
# dice_list:  [0.14022806303294444, 0.16663368131727999, 0.19541530298322382, 0.22919755557403979, 0.2664150595153598, 0.2996100814680274, 0.3307057105277541, 0.3555034259941355, 0.3746154672685984, 0.391106371796208, 0.40746883640180764, 0.42139981807800364, 0.431898939153637, 0.43833181698977175, 0.4385867068459748, 0.43325968618615013, 0.4190568434809269, 0.3867636405626472, 0.16543726745982051]
# Epoch 16 - Save Best AUC: 0.8407. Model is saved.
# - epoch:17 -
# Epoch: [17][0/130] Elapsed 0m 0s (remain 2m 3s) Loss: 0.4206(0.4206)
# Epoch: [17][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 1.2016(0.4762)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4402(0.4402)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4103(0.8975)
# 	 epoch:17, avg train loss:0.4762, avg valid loss:0.8975
# 	 score:0.4293(th=0.900000), auc=0.840721::: time:107.93s
# Epoch 17 - Save Best AUC: 0.8407. Model is saved.
# - epoch:18 -
# Epoch: [18][0/130] Elapsed 0m 0s (remain 1m 51s) Loss: 0.5670(0.5670)
# Epoch: [18][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.5327(0.5112)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2857(0.2857)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3282(0.5725)
# 	 epoch:18, avg train loss:0.5112, avg valid loss:0.5725
# 	 score:0.4258(th=0.750000), auc=0.840504::: time:161.41s
# - epoch:19 -
# Epoch: [19][0/130] Elapsed 0m 0s (remain 1m 59s) Loss: 1.4747(1.4747)
# Epoch: [19][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 2.3706(0.5777)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.4214(0.4214)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3184(0.8590)
# 	 epoch:19, avg train loss:0.5777, avg valid loss:0.8590
# 	 score:0.4414(th=0.850000), auc=0.838715::: time:213.81s
# Epoch 19 - Save Best Score: 0.4414. Model is saved.
# dice_list:  [0.1431011530010275, 0.16741240010897432, 0.19280370996800614, 0.21843863401070304, 0.24617033869603114, 0.2730448606780607, 0.2996864159513943, 0.32561802516174465, 0.34916646732057555, 0.36921888055711133, 0.3859529032233298, 0.39900321627452756, 0.40960029822972543, 0.42310089925598543, 0.435824351154537, 0.4414213845037258, 0.438348748362233, 0.4249509949425613, 0.28628438859553396]
# - epoch:20 -
# Epoch: [20][0/130] Elapsed 0m 0s (remain 1m 50s) Loss: 0.3491(0.3491)
# Epoch: [20][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.5785(0.4900)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.3862(0.3862)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3071(0.6372)
# 	 epoch:20, avg train loss:0.4900, avg valid loss:0.6372
# 	 score:0.4407(th=0.850000), auc=0.840924::: time:267.54s
# Epoch 20 - Save Best AUC: 0.8409. Model is saved.
# - epoch:21 -
# Epoch: [21][0/130] Elapsed 0m 0s (remain 2m 4s) Loss: 0.9238(0.9238)
# Epoch: [21][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 1.0139(0.5060)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.9760(0.9760)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4593(1.7487)
# 	 epoch:21, avg train loss:0.5060, avg valid loss:1.7487
# 	 score:0.4644(th=0.950000), auc=0.854703::: time:321.15s
# Epoch 21 - Save Best Score: 0.4644. Model is saved.
# dice_list:  [0.17703860724226264, 0.19921930054797973, 0.22001339827236654, 0.2403216711974129, 0.2588362564128667, 0.27489874923437824, 0.290416159531905, 0.30625686471680486, 0.3225489027185545, 0.3374291278500802, 0.3530270414863625, 0.3688633877486913, 0.38475801314968755, 0.40073523532085814, 0.416667207577387, 0.4328352499274024, 0.44868931178437343, 0.4643778787238778, 0.45084063481826053]
# Epoch 21 - Save Best AUC: 0.8547. Model is saved.
# - epoch:22 -
# Epoch: [22][0/130] Elapsed 0m 0s (remain 1m 57s) Loss: 0.4032(0.4032)
# Epoch: [22][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 2.7269(0.6510)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2836(0.2836)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3436(0.4721)
# 	 epoch:22, avg train loss:0.6510, avg valid loss:0.4721
# 	 score:0.4459(th=0.600000), auc=0.843206::: time:375.81s
# - epoch:23 -
# Epoch: [23][0/130] Elapsed 0m 0s (remain 1m 49s) Loss: 1.0428(1.0428)
# Epoch: [23][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.9019(0.4946)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2591(0.2591)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.6420(0.8029)
# 	 epoch:23, avg train loss:0.4946, avg valid loss:0.8029
# 	 score:0.4588(th=0.750000), auc=0.829465::: time:427.95s
# - epoch:24 -
# Epoch: [24][0/130] Elapsed 0m 0s (remain 1m 53s) Loss: 0.3280(0.3280)
# Epoch: [24][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.1752(0.4894)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2724(0.2724)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2599(0.4946)
# 	 epoch:24, avg train loss:0.4894, avg valid loss:0.4946
# 	 score:0.4310(th=0.700000), auc=0.841914::: time:480.61s
# - epoch:25 -
# Epoch: [25][0/130] Elapsed 0m 1s (remain 2m 10s) Loss: 0.2937(0.2937)
# Epoch: [25][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.8304(0.3908)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.3299(0.3299)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2841(0.5601)
# 	 epoch:25, avg train loss:0.3908, avg valid loss:0.5601
# 	 score:0.4314(th=0.750000), auc=0.849306::: time:532.70s
# - epoch:26 -
# Epoch: [26][0/130] Elapsed 0m 0s (remain 2m 0s) Loss: 0.2605(0.2605)
# Epoch: [26][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 2.3475(0.4415)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2917(0.2917)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2977(0.5490)
# 	 epoch:26, avg train loss:0.4415, avg valid loss:0.5490
# 	 score:0.4351(th=0.750000), auc=0.848358::: time:585.86s
# - epoch:27 -
# Epoch: [27][0/130] Elapsed 0m 0s (remain 1m 55s) Loss: 0.2121(0.2121)
# Epoch: [27][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 1.8320(0.4511)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2488(0.2488)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2506(0.4330)
# 	 epoch:27, avg train loss:0.4511, avg valid loss:0.4330
# 	 score:0.4419(th=0.700000), auc=0.845986::: time:638.09s
# - epoch:28 -
# Epoch: [28][0/130] Elapsed 0m 0s (remain 1m 53s) Loss: 1.4114(1.4114)
# Epoch: [28][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.9016(0.4629)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2766(0.2766)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2490(0.4790)
# 	 epoch:28, avg train loss:0.4629, avg valid loss:0.4790
# 	 score:0.4374(th=0.800000), auc=0.845948::: time:690.09s
# - epoch:29 -
# Epoch: [29][0/130] Elapsed 0m 0s (remain 1m 49s) Loss: 0.3370(0.3370)
# Epoch: [29][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 2.3065(0.4209)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.2476(0.2476)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2638(0.6310)
# 	 epoch:29, avg train loss:0.4209, avg valid loss:0.6310
# 	 score:0.4394(th=0.850000), auc=0.836048::: time:741.87s
# - epoch:30 -
# Epoch: [30][0/130] Elapsed 0m 0s (remain 1m 51s) Loss: 0.3228(0.3228)
# Epoch: [30][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 2.2791(0.4416)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1633(0.1633)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2818(0.4441)
# 	 epoch:30, avg train loss:0.4416, avg valid loss:0.4441
# 	 score:0.4478(th=0.650000), auc=0.821707::: time:794.19s
# surface_list:  range(25, 35, 3)
# - epoch:31 -
# Epoch: [31][0/130] Elapsed 0m 0s (remain 2m 7s) Loss: 0.2266(0.2266)
# Epoch: [31][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 2.1982(0.6019)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1205(0.1205)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2898(0.4076)
# 	 epoch:31, avg train loss:0.6019, avg valid loss:0.4076
# 	 score:0.4389(th=0.500000), auc=0.847463::: time:52.25s
# Epoch 31 - Save Best Score: 0.4389. Model is saved.
# dice_list:  [0.21265750527219354, 0.26208139664277974, 0.31007797338076304, 0.35147619964007015, 0.3814091765164988, 0.40453902744069276, 0.42151992967222346, 0.4333264536822903, 0.43888432100942193, 0.43777806828077714, 0.4350703333067122, 0.4275820917158622, 0.41251923123958795, 0.3901221043377359, 0.358830837194923, 0.3237234241081849, 0.2847114874316054, 0.24491843899575402, 0.12949356929724412]
# Epoch 31 - Save Best AUC: 0.8475. Model is saved.
# - epoch:32 -
# Epoch: [32][0/130] Elapsed 0m 1s (remain 2m 13s) Loss: 0.2155(0.2155)
# Epoch: [32][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 2.0288(0.5013)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1199(0.1199)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2759(0.4204)
# 	 epoch:32, avg train loss:0.5013, avg valid loss:0.4204
# 	 score:0.4922(th=0.600000), auc=0.852651::: time:107.78s
# Epoch 32 - Save Best Score: 0.4922. Model is saved.
# dice_list:  [0.23449167129937928, 0.2866953785465414, 0.34121306552678726, 0.38636357353335415, 0.4183492718891342, 0.43995438211920374, 0.45575162077325426, 0.46880582525280984, 0.4792120702078169, 0.48807031794170674, 0.49222146232438274, 0.4899997030511677, 0.48450920340042725, 0.4729208615483595, 0.4553016978700771, 0.4296371141097823, 0.39640543504691006, 0.3485374916984997, 0.14982780129188658]
# Epoch 32 - Save Best AUC: 0.8527. Model is saved.
# - epoch:33 -
# Epoch: [33][0/130] Elapsed 0m 0s (remain 2m 0s) Loss: 0.9974(0.9974)
# Epoch: [33][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.5189(0.5169)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2047(0.2047)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3814(0.7173)
# 	 epoch:33, avg train loss:0.5169, avg valid loss:0.7173
# 	 score:0.4907(th=0.650000), auc=0.855053::: time:162.71s
# Epoch 33 - Save Best AUC: 0.8551. Model is saved.
# - epoch:34 -
# Epoch: [34][0/130] Elapsed 0m 0s (remain 1m 58s) Loss: 0.1969(0.1969)
# Epoch: [34][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 1.8906(0.4521)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1369(0.1369)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3693(0.4925)
# 	 epoch:34, avg train loss:0.4521, avg valid loss:0.4925
# 	 score:0.4917(th=0.600000), auc=0.848305::: time:215.92s
# - epoch:35 -
# Epoch: [35][0/130] Elapsed 0m 1s (remain 2m 10s) Loss: 0.3210(0.3210)
# Epoch: [35][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 2.0769(0.4232)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1517(0.1517)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2685(0.4289)
# 	 epoch:35, avg train loss:0.4232, avg valid loss:0.4289
# 	 score:0.4928(th=0.600000), auc=0.858501::: time:267.98s
# Epoch 35 - Save Best Score: 0.4928. Model is saved.
# dice_list:  [0.22374571173851734, 0.274097185422023, 0.3160419998235353, 0.3525423464811925, 0.38555107833170604, 0.4168287948638564, 0.44190396166934603, 0.4626017577022406, 0.47807360746865063, 0.4880973381509937, 0.49284426995763186, 0.4906797036270365, 0.48294303010396517, 0.4721937109711886, 0.45679790137438514, 0.43333737721294907, 0.40672540771144894, 0.3631341412610114, 0.1712644905543846]
# Epoch 35 - Save Best AUC: 0.8585. Model is saved.
# - epoch:36 -
# Epoch: [36][0/130] Elapsed 0m 0s (remain 1m 58s) Loss: 0.2855(0.2855)
# Epoch: [36][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.5376(0.4180)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1284(0.1284)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2655(0.3762)
# 	 epoch:36, avg train loss:0.4180, avg valid loss:0.3762
# 	 score:0.5012(th=0.500000), auc=0.857738::: time:322.82s
# Epoch 36 - Save Best Score: 0.5012. Model is saved.
# dice_list:  [0.2392049776823657, 0.2980987829228078, 0.35021833413739495, 0.3948188046468879, 0.4317040054997596, 0.46130201447503894, 0.48227033427104554, 0.4958431121527496, 0.5012195404246177, 0.4990185105395058, 0.49112417076758363, 0.4792122325705724, 0.4636650220507621, 0.4408659921399787, 0.41823717782695574, 0.3882598222011038, 0.3433594161107271, 0.27444688222416563, 0.11272141373786726]
# - epoch:37 -
# Epoch: [37][0/130] Elapsed 0m 0s (remain 1m 56s) Loss: 0.3477(0.3477)
# Epoch: [37][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 1.9269(0.4260)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1187(0.1187)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2682(0.4196)
# 	 epoch:37, avg train loss:0.4260, avg valid loss:0.4196
# 	 score:0.5016(th=0.550000), auc=0.859764::: time:376.73s
# Epoch 37 - Save Best Score: 0.5016. Model is saved.
# dice_list:  [0.2489554835127199, 0.3005405943160224, 0.3466519692579653, 0.38612950004191227, 0.4187015139932261, 0.44651061148838556, 0.4696928607124135, 0.4862812726514219, 0.4973584250644533, 0.5016048019886383, 0.5001308279584219, 0.4938507283467708, 0.4862046859149569, 0.47557163197011143, 0.45778294086023097, 0.43755344074073627, 0.4103481488459018, 0.3677860366902099, 0.17208263391661763]
# Epoch 37 - Save Best AUC: 0.8598. Model is saved.
# - epoch:38 -
# Epoch: [38][0/130] Elapsed 0m 1s (remain 2m 12s) Loss: 0.3014(0.3014)
# Epoch: [38][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 2.0513(0.4364)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1112(0.1112)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2767(0.3581)
# 	 epoch:38, avg train loss:0.4364, avg valid loss:0.3581
# 	 score:0.4905(th=0.500000), auc=0.858054::: time:432.36s
# - epoch:39 -
# Epoch: [39][0/130] Elapsed 0m 0s (remain 1m 55s) Loss: 0.7451(0.7451)
# Epoch: [39][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 2.5282(0.4404)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1385(0.1385)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2733(0.3591)
# 	 epoch:39, avg train loss:0.4404, avg valid loss:0.3591
# 	 score:0.4652(th=0.550000), auc=0.846910::: time:485.02s
# - epoch:40 -
# Epoch: [40][0/130] Elapsed 0m 1s (remain 2m 10s) Loss: 0.2391(0.2391)
# Epoch: [40][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.8728(0.4177)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1287(0.1287)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3663(0.4306)
# 	 epoch:40, avg train loss:0.4177, avg valid loss:0.4306
# 	 score:0.4914(th=0.600000), auc=0.844831::: time:537.28s
# - epoch:41 -
# Epoch: [41][0/130] Elapsed 0m 0s (remain 2m 2s) Loss: 0.3794(0.3794)
# Epoch: [41][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 1.8330(0.3977)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2830(0.2830)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5331(0.7252)
# 	 epoch:41, avg train loss:0.3977, avg valid loss:0.7252
# 	 score:0.5055(th=0.850000), auc=0.867376::: time:589.08s
# Epoch 41 - Save Best Score: 0.5055. Model is saved.
# dice_list:  [0.2176442794733484, 0.25406148543585644, 0.2830383172752734, 0.3094038616617646, 0.33392072104722376, 0.356426552040467, 0.37640371064941114, 0.39655304668282587, 0.41641690236715595, 0.4343713992344467, 0.4512844800523431, 0.46658836764066336, 0.47800445870482466, 0.4878924025163326, 0.4967241860906113, 0.5054999762963451, 0.5046530854494686, 0.48745025289658556, 0.3713317744756199]
# Epoch 41 - Save Best AUC: 0.8674. Model is saved.
# - epoch:42 -
# Epoch: [42][0/130] Elapsed 0m 0s (remain 1m 50s) Loss: 0.2277(0.2277)
# Epoch: [42][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 1.7708(0.3945)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2033(0.2033)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5218(0.7981)
# 	 epoch:42, avg train loss:0.3945, avg valid loss:0.7981
# 	 score:0.4928(th=0.800000), auc=0.874681::: time:644.36s
# Epoch 42 - Save Best AUC: 0.8747. Model is saved.
# - epoch:43 -
# Epoch: [43][0/130] Elapsed 0m 0s (remain 1m 51s) Loss: 0.2102(0.2102)
# Epoch: [43][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 2.2092(0.4000)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1641(0.1641)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2434(0.3832)
# 	 epoch:43, avg train loss:0.4000, avg valid loss:0.3832
# 	 score:0.4981(th=0.700000), auc=0.864294::: time:698.05s
# - epoch:44 -
# Epoch: [44][0/130] Elapsed 0m 0s (remain 1m 58s) Loss: 0.1925(0.1925)
# Epoch: [44][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 2.3751(0.3333)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1418(0.1418)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2419(0.3847)
# 	 epoch:44, avg train loss:0.3333, avg valid loss:0.3847
# 	 score:0.5073(th=0.700000), auc=0.870555::: time:750.39s
# Epoch 44 - Save Best Score: 0.5073. Model is saved.
# dice_list:  [0.26356453080712705, 0.3139139817356152, 0.35243844924851836, 0.38139674056289863, 0.4055759260601368, 0.4276660401372929, 0.44791957227867013, 0.46563380815617705, 0.47935206578696166, 0.4903943474363555, 0.49956877800818983, 0.5058081545999685, 0.5073178337252259, 0.5036518152486986, 0.493390666357785, 0.4804320114987976, 0.46248452418590713, 0.4277459062142407, 0.22676931563147604]
# - epoch:45 -
# Epoch: [45][0/130] Elapsed 0m 0s (remain 1m 54s) Loss: 0.7464(0.7464)
# Epoch: [45][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.8800(0.3123)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1510(0.1510)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2466(0.4392)
# 	 epoch:45, avg train loss:0.3123, avg valid loss:0.4392
# 	 score:0.5025(th=0.700000), auc=0.866574::: time:804.04s
# [fold0] slice ave score:0.5175(th=0.650000), auc=0.865916
# [fold0] BEST Epoch 44 - Save Best Score:0.5073. Best loss:0.3847
# [fold0] BEST AUC Epoch 42 - Save Best Score:0.8747. Best loss:0.7981
# -- fold1 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# Epoch: [1][0/58] Elapsed 0m 0s (remain 0m 55s) Loss: 0.6724(0.6724)
# Epoch: [1][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.6547(0.6196)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 27s) Loss: 0.3965(0.3965)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3841(0.5496)
# 	 epoch:1, avg train loss:0.6196, avg valid loss:0.5496
# 	 score:0.3289(th=0.500000), auc=0.759674::: time:79.16s
# Epoch 1 - Save Best Score: 0.3289. Model is saved.
# dice_list:  [0.19682837423528918, 0.19692729105176804, 0.19755553238896947, 0.2011108923974849, 0.21653253923315213, 0.2479228826395457, 0.2793774771169644, 0.3092314972895072, 0.32886212678462323, 0.3240545734751936, 0.2904233618839518, 0.23414133605477813, 0.16822873794920076, 0.10383194613039742, 0.051670886315528054, 0.02041215665937701, 0.007092360534486193, 0.0006180527880178803, 0.0]
# Epoch 1 - Save Best AUC: 0.7597. Model is saved.
# - epoch:2 -
# Epoch: [2][0/58] Elapsed 0m 0s (remain 0m 50s) Loss: 0.6178(0.6178)
# Epoch: [2][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.6598(0.5894)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 27s) Loss: 0.3767(0.3767)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3809(0.5285)
# 	 epoch:2, avg train loss:0.5894, avg valid loss:0.5285
# 	 score:0.3449(th=0.500000), auc=0.765606::: time:167.12s
# Epoch 2 - Save Best Score: 0.3449. Model is saved.
# dice_list:  [0.19682677415609215, 0.19687979822020604, 0.19722192338969577, 0.20033607196376077, 0.2215441723380363, 0.25920900421151055, 0.3000738065180787, 0.33526534357501303, 0.34490314451440035, 0.3181698268822902, 0.2667521221235069, 0.20319884946368585, 0.1390656133909799, 0.08896846075269436, 0.05425210392545824, 0.03047514849860596, 0.012245655397768385, 0.003278530646627757, 0.0]
# Epoch 2 - Save Best AUC: 0.7656. Model is saved.
# - epoch:3 -
# Epoch: [3][0/58] Elapsed 0m 0s (remain 0m 55s) Loss: 0.5289(0.5289)
# Epoch: [3][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.6464(0.5666)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 27s) Loss: 0.3668(0.3668)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3380(0.5097)
# 	 epoch:3, avg train loss:0.5666, avg valid loss:0.5097
# 	 score:0.3686(th=0.500000), auc=0.761526::: time:254.25s
# Epoch 3 - Save Best Score: 0.3686. Model is saved.
# dice_list:  [0.196837709399895, 0.19704348775803943, 0.198474752403782, 0.20641787332058806, 0.23360483206087457, 0.2791360612332973, 0.3216346081448227, 0.3570154405001443, 0.36857089308915936, 0.35266564672428297, 0.31842135049286807, 0.2753695285382039, 0.22797325369978882, 0.17877855073421361, 0.1290685986967124, 0.08514104136550664, 0.052123181053114614, 0.018388306471645674, 0.0]
# - epoch:4 -
# Epoch: [4][0/58] Elapsed 0m 0s (remain 0m 53s) Loss: 0.5404(0.5404)
# Epoch: [4][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.6975(0.5520)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.3820(0.3820)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3619(0.5330)
# 	 epoch:4, avg train loss:0.5520, avg valid loss:0.5330
# 	 score:0.3696(th=0.550000), auc=0.773410::: time:336.58s
# Epoch 4 - Save Best Score: 0.3696. Model is saved.
# dice_list:  [0.1968277812412253, 0.19687825269475387, 0.19737026351254883, 0.2012709319188732, 0.22233272657289338, 0.26615825393173603, 0.30789025951908017, 0.3468098202381691, 0.36939871987566186, 0.36957890361345436, 0.34878786694200153, 0.31461728220507335, 0.27163123625233726, 0.22582079720186177, 0.1817579853582773, 0.13592954925398942, 0.09057806182283773, 0.04271791980497539, 0.0]
# Epoch 4 - Save Best AUC: 0.7734. Model is saved.
# - epoch:5 -
# Epoch: [5][0/58] Elapsed 0m 0s (remain 0m 55s) Loss: 0.5703(0.5703)
# Epoch: [5][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.5072(0.5310)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.3869(0.3869)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3739(0.5161)
# 	 epoch:5, avg train loss:0.5310, avg valid loss:0.5161
# 	 score:0.3612(th=0.500000), auc=0.762140::: time:424.73s
# - epoch:6 -
# Epoch: [6][0/58] Elapsed 0m 0s (remain 0m 52s) Loss: 0.5118(0.5118)
# Epoch: [6][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.6253(0.5364)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.3771(0.3771)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3700(0.5148)
# 	 epoch:6, avg train loss:0.5364, avg valid loss:0.5148
# 	 score:0.3662(th=0.500000), auc=0.762914::: time:502.48s
# - epoch:7 -
# Epoch: [7][0/58] Elapsed 0m 0s (remain 0m 55s) Loss: 0.5921(0.5921)
# Epoch: [7][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.7203(0.5284)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.3643(0.3643)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3539(0.5110)
# 	 epoch:7, avg train loss:0.5284, avg valid loss:0.5110
# 	 score:0.3592(th=0.500000), auc=0.765088::: time:581.59s
# - epoch:8 -
# Epoch: [8][0/58] Elapsed 0m 1s (remain 0m 57s) Loss: 0.4765(0.4765)
# Epoch: [8][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.6391(0.5338)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.3451(0.3451)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3415(0.4893)
# 	 epoch:8, avg train loss:0.5338, avg valid loss:0.4893
# 	 score:0.3458(th=0.450000), auc=0.755728::: time:659.44s
# - epoch:9 -
# Epoch: [9][0/58] Elapsed 0m 0s (remain 0m 52s) Loss: 0.5017(0.5017)
# Epoch: [9][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.4777(0.5088)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.3005(0.3005)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3027(0.4980)
# 	 epoch:9, avg train loss:0.5088, avg valid loss:0.4980
# 	 score:0.3516(th=0.500000), auc=0.757822::: time:738.25s
# - epoch:10 -
# Epoch: [10][0/58] Elapsed 0m 0s (remain 0m 51s) Loss: 0.7446(0.7446)
# Epoch: [10][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3846(0.4994)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.2736(0.2736)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2906(0.4651)
# 	 epoch:10, avg train loss:0.4994, avg valid loss:0.4651
# 	 score:0.3682(th=0.450000), auc=0.778179::: time:817.67s
# Epoch 10 - Save Best AUC: 0.7782. Model is saved.
# - epoch:11 -
# Epoch: [11][0/58] Elapsed 0m 0s (remain 0m 54s) Loss: 0.4453(0.4453)
# Epoch: [11][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.4367(0.4715)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.3064(0.3064)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.2893(0.4757)
# 	 epoch:11, avg train loss:0.4715, avg valid loss:0.4757
# 	 score:0.3542(th=0.400000), auc=0.756568::: time:900.60s
# - epoch:12 -
# Epoch: [12][0/58] Elapsed 0m 0s (remain 0m 51s) Loss: 1.0989(1.0989)
# Epoch: [12][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3473(0.4798)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.2468(0.2468)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.2333(0.4660)
# 	 epoch:12, avg train loss:0.4798, avg valid loss:0.4660
# 	 score:0.3654(th=0.400000), auc=0.758413::: time:979.44s
# - epoch:13 -
# Epoch: [13][0/58] Elapsed 0m 1s (remain 1m 0s) Loss: 0.4795(0.4795)
# Epoch: [13][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.8857(0.4638)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.2554(0.2554)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.2359(0.4583)
# 	 epoch:13, avg train loss:0.4638, avg valid loss:0.4583
# 	 score:0.3979(th=0.450000), auc=0.775050::: time:1057.92s
# Epoch 13 - Save Best Score: 0.3979. Model is saved.
# dice_list:  [0.19698842937537292, 0.19980238284237384, 0.2192538793636879, 0.2661981332935206, 0.3285066766927289, 0.3722445903003157, 0.3966102257898845, 0.3979444072289778, 0.3874741717769578, 0.37230935695284834, 0.3520407864001049, 0.32949380525203986, 0.3049891586703037, 0.27819170467574067, 0.2520381035791208, 0.22499559634002367, 0.1935772767591808, 0.1518369172132517, 0.0022772296324597378]
# - epoch:14 -
# Epoch: [14][0/58] Elapsed 0m 0s (remain 0m 55s) Loss: 0.7939(0.7939)
# Epoch: [14][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 1.6441(0.4573)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.2362(0.2362)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.2202(0.4379)
# 	 epoch:14, avg train loss:0.4573, avg valid loss:0.4379
# 	 score:0.3894(th=0.400000), auc=0.765429::: time:1140.21s
# - epoch:15 -
# Epoch: [15][0/58] Elapsed 0m 0s (remain 0m 56s) Loss: 0.3316(0.3316)
# Epoch: [15][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.4386(0.4020)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.2394(0.2394)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2274(0.4411)
# 	 epoch:15, avg train loss:0.4020, avg valid loss:0.4411
# 	 score:0.3830(th=0.350000), auc=0.763825::: time:1219.84s
# surface_list:  range(27, 37, 3)
# - epoch:16 -
# Epoch: [16][0/58] Elapsed 0m 1s (remain 0m 57s) Loss: 0.3706(0.3706)
# Epoch: [16][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.5493(0.4627)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.2401(0.2401)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2234(0.4453)
# 	 epoch:16, avg train loss:0.4627, avg valid loss:0.4453
# 	 score:0.3905(th=0.400000), auc=0.768251::: time:78.98s
# Epoch 16 - Save Best Score: 0.3905. Model is saved.
# dice_list:  [0.19702167742603166, 0.20052681983098064, 0.22465291186361247, 0.2844432144386612, 0.3415489683766786, 0.3782274504714381, 0.3904896616217169, 0.3812535881197626, 0.3609316556338501, 0.3361276385359369, 0.31182479197898494, 0.2905869086170309, 0.2700779556863488, 0.248852807710122, 0.22562844943131377, 0.19927134811650657, 0.1679413096602955, 0.13156290101343515, 0.00388208225900073]
# Epoch 16 - Save Best AUC: 0.7683. Model is saved.
# - epoch:17 -
# Epoch: [17][0/58] Elapsed 0m 0s (remain 0m 52s) Loss: 0.3761(0.3761)
# Epoch: [17][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.5667(0.4364)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.2452(0.2452)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.2358(0.4559)
# 	 epoch:17, avg train loss:0.4364, avg valid loss:0.4559
# 	 score:0.3921(th=0.450000), auc=0.775009::: time:165.63s
# Epoch 17 - Save Best Score: 0.3921. Model is saved.
# dice_list:  [0.19690927310376077, 0.1989394679815839, 0.21821150604562176, 0.2725007791187767, 0.3297609912961892, 0.36987835125419033, 0.39044880445453495, 0.3920510034577351, 0.3820588256226882, 0.36529448144836074, 0.34499731020137825, 0.32407127486567666, 0.3028848249721614, 0.28233801655743773, 0.26128903514386154, 0.23769870837319074, 0.20928614085376718, 0.1675637079345553, 0.007466700703422787]
# Epoch 17 - Save Best AUC: 0.7750. Model is saved.
# - epoch:18 -
# Epoch: [18][0/58] Elapsed 0m 1s (remain 0m 59s) Loss: 0.3616(0.3616)
# Epoch: [18][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3682(0.4749)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.2021(0.2021)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.2022(0.4345)
# 	 epoch:18, avg train loss:0.4749, avg valid loss:0.4345
# 	 score:0.3736(th=0.400000), auc=0.775738::: time:252.26s
# Epoch 18 - Save Best AUC: 0.7757. Model is saved.
# - epoch:19 -
# Epoch: [19][0/58] Elapsed 0m 1s (remain 1m 3s) Loss: 0.6757(0.6757)
# Epoch: [19][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3846(0.4416)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.2310(0.2310)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.2320(0.4565)
# 	 epoch:19, avg train loss:0.4416, avg valid loss:0.4565
# 	 score:0.3714(th=0.400000), auc=0.762610::: time:335.55s
# - epoch:20 -
# Epoch: [20][0/58] Elapsed 0m 1s (remain 0m 58s) Loss: 0.3781(0.3781)
# Epoch: [20][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3196(0.4619)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1627(0.1627)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1541(0.4423)
# 	 epoch:20, avg train loss:0.4619, avg valid loss:0.4423
# 	 score:0.3606(th=0.400000), auc=0.780825::: time:414.91s
# Epoch 20 - Save Best AUC: 0.7808. Model is saved.
# - epoch:21 -
# Epoch: [21][0/58] Elapsed 0m 0s (remain 0m 56s) Loss: 0.3792(0.3792)
# Epoch: [21][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3137(0.4575)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.2009(0.2009)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.2015(0.4406)
# 	 epoch:21, avg train loss:0.4575, avg valid loss:0.4406
# 	 score:0.3606(th=0.400000), auc=0.765252::: time:497.77s
# - epoch:22 -
# Epoch: [22][0/58] Elapsed 0m 1s (remain 1m 2s) Loss: 0.4150(0.4150)
# Epoch: [22][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3495(0.3692)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1671(0.1671)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.1821(0.4287)
# 	 epoch:22, avg train loss:0.3692, avg valid loss:0.4287
# 	 score:0.3706(th=0.350000), auc=0.770714::: time:576.75s
# - epoch:23 -
# Epoch: [23][0/58] Elapsed 0m 0s (remain 0m 50s) Loss: 0.5106(0.5106)
# Epoch: [23][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 2.2279(0.3942)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 31s) Loss: 0.1793(0.1793)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.1769(0.4239)
# 	 epoch:23, avg train loss:0.3942, avg valid loss:0.4239
# 	 score:0.3594(th=0.300000), auc=0.750752::: time:655.59s
# - epoch:24 -
# Epoch: [24][0/58] Elapsed 0m 1s (remain 1m 0s) Loss: 0.3571(0.3571)
# Epoch: [24][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3831(0.3647)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.1721(0.1721)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.1857(0.4272)
# 	 epoch:24, avg train loss:0.3647, avg valid loss:0.4272
# 	 score:0.3682(th=0.350000), auc=0.764336::: time:734.59s
# - epoch:25 -
# Epoch: [25][0/58] Elapsed 0m 1s (remain 0m 58s) Loss: 0.2681(0.2681)
# Epoch: [25][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.4758(0.3571)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.1678(0.1678)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.1813(0.4275)
# 	 epoch:25, avg train loss:0.3571, avg valid loss:0.4275
# 	 score:0.3667(th=0.350000), auc=0.766218::: time:812.76s
# - epoch:26 -
# Epoch: [26][0/58] Elapsed 0m 1s (remain 0m 58s) Loss: 0.3003(0.3003)
# Epoch: [26][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2402(0.3463)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.1690(0.1690)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.1772(0.4221)
# 	 epoch:26, avg train loss:0.3463, avg valid loss:0.4221
# 	 score:0.3691(th=0.350000), auc=0.766058::: time:891.33s
# - epoch:27 -
# Epoch: [27][0/58] Elapsed 0m 1s (remain 0m 59s) Loss: 0.2890(0.2890)
# Epoch: [27][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3399(0.3628)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1542(0.1542)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.1654(0.4216)
# 	 epoch:27, avg train loss:0.3628, avg valid loss:0.4216
# 	 score:0.3646(th=0.300000), auc=0.766101::: time:971.02s
# - epoch:28 -
# Epoch: [28][0/58] Elapsed 0m 0s (remain 0m 50s) Loss: 0.2984(0.2984)
# Epoch: [28][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.4923(0.3274)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.1473(0.1473)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.1550(0.4236)
# 	 epoch:28, avg train loss:0.3274, avg valid loss:0.4236
# 	 score:0.3585(th=0.350000), auc=0.763547::: time:1049.93s
# - epoch:29 -
# Epoch: [29][0/58] Elapsed 0m 0s (remain 0m 54s) Loss: 0.2617(0.2617)
# Epoch: [29][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2580(0.4016)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.1572(0.1572)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.1633(0.4296)
# 	 epoch:29, avg train loss:0.4016, avg valid loss:0.4296
# 	 score:0.3463(th=0.300000), auc=0.751929::: time:1128.75s
# - epoch:30 -
# Epoch: [30][0/58] Elapsed 0m 0s (remain 0m 52s) Loss: 0.2524(0.2524)
# Epoch: [30][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2623(0.3779)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 31s) Loss: 0.1585(0.1585)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.1649(0.4598)
# 	 epoch:30, avg train loss:0.3779, avg valid loss:0.4598
# 	 score:0.3652(th=0.350000), auc=0.751226::: time:1207.82s
# surface_list:  range(25, 35, 3)
# - epoch:31 -
# Epoch: [31][0/58] Elapsed 0m 1s (remain 0m 57s) Loss: 0.9858(0.9858)
# Epoch: [31][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3294(0.6027)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1598(0.1598)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.1297(0.4464)
# 	 epoch:31, avg train loss:0.6027, avg valid loss:0.4464
# 	 score:0.3120(th=0.300000), auc=0.753134::: time:78.95s
# Epoch 31 - Save Best Score: 0.3120. Model is saved.
# dice_list:  [0.20269246289559842, 0.238674803551855, 0.2833597478074118, 0.31146687270650947, 0.31202681765923757, 0.28977054569651917, 0.2622832929349945, 0.23373848783013357, 0.20394186952413734, 0.17504911764002246, 0.14758819004064172, 0.12456050572775927, 0.10634832365998484, 0.09131747534252266, 0.07846102873194077, 0.06709154156106681, 0.05616612270211475, 0.043346372294568614, 0.006928655938745895]
# Epoch 31 - Save Best AUC: 0.7531. Model is saved.
# - epoch:32 -
# Epoch: [32][0/58] Elapsed 0m 0s (remain 0m 54s) Loss: 1.2433(1.2433)
# Epoch: [32][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2480(0.5191)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1215(0.1215)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.1162(0.4196)
# 	 epoch:32, avg train loss:0.5191, avg valid loss:0.4196
# 	 score:0.3502(th=0.300000), auc=0.773006::: time:164.88s
# Epoch 32 - Save Best Score: 0.3502. Model is saved.
# dice_list:  [0.21144081872036902, 0.26008655034430006, 0.3085540159815556, 0.34275938696680447, 0.3501548590422759, 0.32780520061112706, 0.2951228299707109, 0.2616332165684485, 0.23245709253987576, 0.2051796100181973, 0.17939745704215013, 0.1552041997401455, 0.133057846950086, 0.1117905137238328, 0.09104384463836376, 0.07078860161296426, 0.051676591668837715, 0.0358233695826832, 0.005057460869024075]
# Epoch 32 - Save Best AUC: 0.7730. Model is saved.
# - epoch:33 -
# Epoch: [33][0/58] Elapsed 0m 1s (remain 0m 59s) Loss: 0.2938(0.2938)
# Epoch: [33][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2876(0.5253)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1273(0.1273)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.1114(0.4270)
# 	 epoch:33, avg train loss:0.5253, avg valid loss:0.4270
# 	 score:0.3342(th=0.250000), auc=0.750025::: time:250.83s
# - epoch:34 -
# Epoch: [34][0/58] Elapsed 0m 0s (remain 0m 51s) Loss: 0.3181(0.3181)
# Epoch: [34][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 2.3228(0.4011)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1284(0.1284)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1122(0.4213)
# 	 epoch:34, avg train loss:0.4011, avg valid loss:0.4213
# 	 score:0.3475(th=0.250000), auc=0.761600::: time:328.78s
# - epoch:35 -
# Epoch: [35][0/58] Elapsed 0m 0s (remain 0m 51s) Loss: 0.3437(0.3437)
# Epoch: [35][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2263(0.3882)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1231(0.1231)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.1108(0.4207)
# 	 epoch:35, avg train loss:0.3882, avg valid loss:0.4207
# 	 score:0.3515(th=0.250000), auc=0.763158::: time:407.69s
# Epoch 35 - Save Best Score: 0.3515. Model is saved.
# dice_list:  [0.22142135044306271, 0.29800359156001965, 0.33755034179680143, 0.35154067486821566, 0.3373550867607887, 0.3073709577037011, 0.27704319207072814, 0.2504024448011612, 0.2276677190986111, 0.2070515730885943, 0.18737519404340566, 0.16909697576101493, 0.15175087243752247, 0.1339491825035124, 0.1171020578561439, 0.09973588734015222, 0.08089447443352565, 0.05949813530137936, 0.005382263703463989]
# - epoch:36 -
# Epoch: [36][0/58] Elapsed 0m 0s (remain 0m 56s) Loss: 0.2648(0.2648)
# Epoch: [36][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 1.9952(0.3974)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1366(0.1366)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1127(0.4358)
# 	 epoch:36, avg train loss:0.3974, avg valid loss:0.4358
# 	 score:0.3584(th=0.300000), auc=0.767746::: time:489.56s
# Epoch 36 - Save Best Score: 0.3584. Model is saved.
# dice_list:  [0.21313364126975562, 0.2757909073390316, 0.3215804663765312, 0.3494804613334173, 0.3584322618115867, 0.354507434164757, 0.34269609237573406, 0.3257451514309134, 0.3076802853916965, 0.28851824607203097, 0.2678602009248081, 0.2481409950940203, 0.22928787979821338, 0.20948181484944325, 0.19076537711562846, 0.17114742826089746, 0.15110126144367672, 0.12539913755322474, 0.022030533148944223]
# - epoch:37 -
# Epoch: [37][0/58] Elapsed 0m 1s (remain 0m 59s) Loss: 0.9045(0.9045)
# Epoch: [37][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 1.5957(0.4098)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.1311(0.1311)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.1108(0.4169)
# 	 epoch:37, avg train loss:0.4098, avg valid loss:0.4169
# 	 score:0.3602(th=0.250000), auc=0.769761::: time:572.15s
# Epoch 37 - Save Best Score: 0.3602. Model is saved.
# dice_list:  [0.21431500458021446, 0.28494837336182705, 0.33457649497112096, 0.36020536239807116, 0.3601491686661131, 0.3411013974554083, 0.31597383882723695, 0.2874432681360168, 0.2615465849695835, 0.23830995683641298, 0.21627334846976146, 0.19560965099223623, 0.17547643576158806, 0.15456170154332582, 0.1330325692338423, 0.11179625808581321, 0.08852333525309886, 0.062299367508984016, 0.003474345745539243]
# - epoch:38 -
# Epoch: [38][0/58] Elapsed 0m 1s (remain 0m 59s) Loss: 0.2737(0.2737)
# Epoch: [38][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2430(0.4074)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1380(0.1380)
# EVAL: [98/99] Elapsed 0m 17s (remain 0m 0s) Loss: 0.1069(0.4193)
# 	 epoch:38, avg train loss:0.4074, avg valid loss:0.4193
# 	 score:0.3595(th=0.300000), auc=0.771041::: time:654.58s
# - epoch:39 -
# Epoch: [39][0/58] Elapsed 0m 0s (remain 0m 54s) Loss: 0.2007(0.2007)
# Epoch: [39][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2604(0.3600)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.1024(0.1024)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0803(0.4170)
# 	 epoch:39, avg train loss:0.3600, avg valid loss:0.4170
# 	 score:0.3624(th=0.250000), auc=0.775632::: time:733.19s
# Epoch 39 - Save Best Score: 0.3624. Model is saved.
# ...
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.3908(1.3809)
# 	 epoch:15, avg train loss:0.5968, avg valid loss:1.3809
# 	 score:0.4111(th=0.900000), auc=0.854989::: time:838.75s
# surface_list:  range(27, 37, 3)
# - epoch:16 -
# Epoch: [16][0/125] Elapsed 0m 1s (remain 2m 16s) Loss: 0.3959(0.3959)
# Epoch: [16][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3905(0.5455)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.5205(0.5205)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.3083(1.0290)
# 	 epoch:16, avg train loss:0.5455, avg valid loss:1.0290
# 	 score:0.4064(th=0.800000), auc=0.850959::: time:54.42s
# Epoch 16 - Save Best Score: 0.4064. Model is saved.
# dice_list:  [0.19865971736425236, 0.20563621781454391, 0.2377074334515169, 0.26349485227980396, 0.2847609686392059, 0.30629967576544137, 0.32889692797031994, 0.3484412816175367, 0.3651896369446518, 0.3793264401913091, 0.3894667139334718, 0.39663230759092716, 0.40055572815604146, 0.404124799777686, 0.40643731672917, 0.40477966031470136, 0.3969364789784556, 0.3866891700420888, 0.21310230157395738]
# Epoch 16 - Save Best AUC: 0.8510. Model is saved.
# - epoch:17 -
# Epoch: [17][0/125] Elapsed 0m 0s (remain 1m 58s) Loss: 2.1472(2.1472)
# Epoch: [17][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.5943(0.5839)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 1.1983(1.1983)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.3192(1.6992)
# 	 epoch:17, avg train loss:0.5839, avg valid loss:1.6992
# 	 score:0.4049(th=0.850000), auc=0.850368::: time:112.18s
# - epoch:18 -
# Epoch: [18][0/125] Elapsed 0m 1s (remain 2m 6s) Loss: 0.4330(0.4330)
# Epoch: [18][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.5811(0.5707)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 8s) Loss: 0.4021(0.4021)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2719(1.0836)
# 	 epoch:18, avg train loss:0.5707, avg valid loss:1.0836
# 	 score:0.4167(th=0.650000), auc=0.850802::: time:167.03s
# Epoch 18 - Save Best Score: 0.4167. Model is saved.
# dice_list:  [0.19893244984148375, 0.21672529158245507, 0.24930167502766248, 0.2764901843713984, 0.3043416059301728, 0.3359645572621139, 0.3621536435342321, 0.3848621914089133, 0.4012027991800851, 0.40772854219690025, 0.4131891569455884, 0.4166730690113901, 0.41524482640270793, 0.41207500040754647, 0.40697317335411537, 0.40159606522777525, 0.39444322984988867, 0.38241904978925884, 0.26923370158575166]
# - epoch:19 -
# Epoch: [19][0/125] Elapsed 0m 0s (remain 2m 2s) Loss: 0.4085(0.4085)
# Epoch: [19][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.4488(0.6725)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2903(0.2903)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2890(0.5236)
# 	 epoch:19, avg train loss:0.6725, avg valid loss:0.5236
# 	 score:0.3938(th=0.500000), auc=0.837001::: time:223.92s
# - epoch:20 -
# Epoch: [20][0/125] Elapsed 0m 1s (remain 2m 9s) Loss: 0.7061(0.7061)
# Epoch: [20][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3794(0.6351)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2543(0.2543)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2357(0.4800)
# 	 epoch:20, avg train loss:0.6351, avg valid loss:0.4800
# 	 score:0.3827(th=0.400000), auc=0.824368::: time:279.30s
# - epoch:21 -
# Epoch: [21][0/125] Elapsed 0m 1s (remain 2m 22s) Loss: 0.4322(0.4322)
# Epoch: [21][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3702(0.6117)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.3664(0.3664)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2508(0.6575)
# 	 epoch:21, avg train loss:0.6117, avg valid loss:0.6575
# 	 score:0.4002(th=0.600000), auc=0.844061::: time:334.83s
# - epoch:22 -
# Epoch: [22][0/125] Elapsed 0m 0s (remain 1m 57s) Loss: 0.3424(0.3424)
# Epoch: [22][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3548(0.5387)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2867(0.2867)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2386(0.5757)
# 	 epoch:22, avg train loss:0.5387, avg valid loss:0.5757
# 	 score:0.4077(th=0.600000), auc=0.854375::: time:389.86s
# Epoch 22 - Save Best AUC: 0.8544. Model is saved.
# - epoch:23 -
# Epoch: [23][0/125] Elapsed 0m 0s (remain 1m 50s) Loss: 0.3445(0.3445)
# Epoch: [23][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.7721(0.5465)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.3123(0.3123)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2043(1.1430)
# 	 epoch:23, avg train loss:0.5465, avg valid loss:1.1430
# 	 score:0.4299(th=0.700000), auc=0.850433::: time:446.27s
# Epoch 23 - Save Best Score: 0.4299. Model is saved.
# dice_list:  [0.20549675814332463, 0.24327830970555714, 0.294003187589347, 0.33037700669785075, 0.3561801874400175, 0.37372368786064986, 0.38730667262510543, 0.3993631016949475, 0.4079617357352857, 0.41474696603632905, 0.4223128139293177, 0.42768693851670325, 0.42988414222339094, 0.42708433158414466, 0.420830650023567, 0.4129439282044599, 0.39766588211405385, 0.37395664151347335, 0.2666942809855497]
# - epoch:24 -
# Epoch: [24][0/125] Elapsed 0m 0s (remain 1m 53s) Loss: 0.2748(0.2748)
# Epoch: [24][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3911(0.5478)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.3464(0.3464)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2494(1.7968)
# 	 epoch:24, avg train loss:0.5478, avg valid loss:1.7968
# 	 score:0.4213(th=0.900000), auc=0.856967::: time:503.09s
# Epoch 24 - Save Best AUC: 0.8570. Model is saved.
# - epoch:25 -
# Epoch: [25][0/125] Elapsed 0m 1s (remain 2m 9s) Loss: 1.1362(1.1362)
# Epoch: [25][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.7519(0.5019)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2994(0.2994)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2097(1.0446)
# 	 epoch:25, avg train loss:0.5019, avg valid loss:1.0446
# 	 score:0.4166(th=0.800000), auc=0.859376::: time:559.75s
# Epoch 25 - Save Best AUC: 0.8594. Model is saved.
# - epoch:26 -
# Epoch: [26][0/125] Elapsed 0m 1s (remain 2m 4s) Loss: 0.2939(0.2939)
# Epoch: [26][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2805(0.4642)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2793(0.2793)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2175(0.9110)
# 	 epoch:26, avg train loss:0.4642, avg valid loss:0.9110
# 	 score:0.4038(th=0.750000), auc=0.856481::: time:616.48s
# - epoch:27 -
# Epoch: [27][0/125] Elapsed 0m 0s (remain 1m 56s) Loss: 0.2492(0.2492)
# Epoch: [27][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3837(0.4586)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.3225(0.3225)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2218(1.1174)
# 	 epoch:27, avg train loss:0.4586, avg valid loss:1.1174
# 	 score:0.4223(th=0.850000), auc=0.861348::: time:672.07s
# Epoch 27 - Save Best AUC: 0.8613. Model is saved.
# - epoch:28 -
# Epoch: [28][0/125] Elapsed 0m 0s (remain 1m 56s) Loss: 0.5098(0.5098)
# Epoch: [28][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.6658(0.4371)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2692(0.2692)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2139(1.1041)
# 	 epoch:28, avg train loss:0.4371, avg valid loss:1.1041
# 	 score:0.4124(th=0.800000), auc=0.858092::: time:728.65s
# - epoch:29 -
# Epoch: [29][0/125] Elapsed 0m 0s (remain 1m 57s) Loss: 0.3266(0.3266)
# Epoch: [29][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2499(0.4795)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.3040(0.3040)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2604(1.1093)
# 	 epoch:29, avg train loss:0.4795, avg valid loss:1.1093
# 	 score:0.3828(th=0.700000), auc=0.843492::: time:783.32s
# - epoch:30 -
# Epoch: [30][0/125] Elapsed 0m 1s (remain 2m 12s) Loss: 0.5106(0.5106)
# Epoch: [30][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3462(0.4704)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2489(0.2489)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1906(0.8589)
# 	 epoch:30, avg train loss:0.4704, avg valid loss:0.8589
# 	 score:0.4020(th=0.700000), auc=0.843145::: time:838.11s
# surface_list:  range(25, 35, 3)
# - epoch:31 -
# Epoch: [31][0/125] Elapsed 0m 1s (remain 2m 5s) Loss: 0.5983(0.5983)
# Epoch: [31][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3514(0.5352)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.3759(0.3759)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2049(0.7667)
# 	 epoch:31, avg train loss:0.5352, avg valid loss:0.7667
# 	 score:0.3851(th=0.550000), auc=0.854824::: time:55.11s
# Epoch 31 - Save Best Score: 0.3851. Model is saved.
# dice_list:  [0.2469651997645464, 0.27390389793465464, 0.2993918394784405, 0.3246721765510272, 0.3432735185650543, 0.35894002420823334, 0.3720633079628048, 0.3811742687891478, 0.38464533963446457, 0.3851475702930572, 0.38370749383275393, 0.37990613944452023, 0.372051811243727, 0.3613327168637208, 0.35033357356809425, 0.33477807382527225, 0.30978368986315064, 0.27386955011805064, 0.15339283009739343]
# Epoch 31 - Save Best AUC: 0.8548. Model is saved.
# - epoch:32 -
# Epoch: [32][0/125] Elapsed 0m 1s (remain 2m 12s) Loss: 0.3366(0.3366)
# Epoch: [32][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3325(0.6949)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 1.8792(1.8792)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2010(0.7930)
# 	 epoch:32, avg train loss:0.6949, avg valid loss:0.7930
# 	 score:0.4125(th=0.700000), auc=0.858264::: time:113.41s
# Epoch 32 - Save Best Score: 0.4125. Model is saved.
# dice_list:  [0.2505334513393367, 0.27419196771912224, 0.2993847167913578, 0.320678190004416, 0.33785583142755826, 0.35325837208224437, 0.3690210672536439, 0.3831272604147002, 0.39350845519782285, 0.40121314692256155, 0.40720330043399267, 0.4111604262661105, 0.41254719749548563, 0.40977348046324963, 0.40030490983229355, 0.3807907213238648, 0.34675298009625827, 0.2982654930333138, 0.17020507639445273]
# Epoch 32 - Save Best AUC: 0.8583. Model is saved.
# - epoch:33 -
# Epoch: [33][0/125] Elapsed 0m 0s (remain 2m 3s) Loss: 0.4319(0.4319)
# Epoch: [33][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2908(0.5276)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.5258(0.5258)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2805(1.0331)
# 	 epoch:33, avg train loss:0.5276, avg valid loss:1.0331
# 	 score:0.4298(th=0.800000), auc=0.864529::: time:172.16s
# Epoch 33 - Save Best Score: 0.4298. Model is saved.
# dice_list:  [0.2414204994829646, 0.2588105356891701, 0.276858976470921, 0.2945480900623091, 0.311456853535931, 0.3278541926166353, 0.3434309928500599, 0.3581358616897864, 0.37195472125767076, 0.38426507838150564, 0.39613727662595916, 0.407535504869984, 0.4169699689527408, 0.42444449447586674, 0.4298321602438109, 0.42813361160186175, 0.41766070998681637, 0.38552887892862436, 0.22945570703371984]
# Epoch 33 - Save Best AUC: 0.8645. Model is saved.
# - epoch:34 -
# Epoch: [34][0/125] Elapsed 0m 1s (remain 2m 7s) Loss: 0.2979(0.2979)
# Epoch: [34][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3696(0.5722)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2529(0.2529)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2264(0.6835)
# 	 epoch:34, avg train loss:0.5722, avg valid loss:0.6835
# 	 score:0.4026(th=0.700000), auc=0.858407::: time:229.94s
# - epoch:35 -
# Epoch: [35][0/125] Elapsed 0m 0s (remain 2m 2s) Loss: 0.3044(0.3044)
# Epoch: [35][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3779(0.5088)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2743(0.2743)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2435(0.7810)
# 	 epoch:35, avg train loss:0.5088, avg valid loss:0.7810
# 	 score:0.3997(th=0.700000), auc=0.853982::: time:284.71s
# - epoch:36 -
# Epoch: [36][0/125] Elapsed 0m 0s (remain 2m 1s) Loss: 0.3365(0.3365)
# Epoch: [36][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2026(0.5164)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2866(0.2866)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2599(0.9131)
# 	 epoch:36, avg train loss:0.5164, avg valid loss:0.9131
# 	 score:0.4014(th=0.750000), auc=0.852579::: time:339.46s
# - epoch:37 -
# Epoch: [37][0/125] Elapsed 0m 1s (remain 2m 7s) Loss: 0.8823(0.8823)
# Epoch: [37][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 1.4425(0.4552)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.9124(0.9124)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.9129(1.9315)
# 	 epoch:37, avg train loss:0.4552, avg valid loss:1.9315
# 	 score:0.4108(th=0.850000), auc=0.849695::: time:394.14s
# - epoch:38 -
# Epoch: [38][0/125] Elapsed 0m 0s (remain 1m 55s) Loss: 0.3019(0.3019)
# Epoch: [38][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2416(0.4978)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2452(0.2452)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2353(0.9167)
# 	 epoch:38, avg train loss:0.4978, avg valid loss:0.9167
# 	 score:0.4117(th=0.750000), auc=0.852274::: time:448.63s
# - epoch:39 -
# Epoch: [39][0/125] Elapsed 0m 1s (remain 2m 7s) Loss: 0.8421(0.8421)
# Epoch: [39][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.4539(0.4576)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2625(0.2625)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2325(0.6500)
# 	 epoch:39, avg train loss:0.4576, avg valid loss:0.6500
# 	 score:0.4113(th=0.750000), auc=0.850138::: time:504.11s
# - epoch:40 -
# Epoch: [40][0/125] Elapsed 0m 0s (remain 1m 59s) Loss: 0.2665(0.2665)
# Epoch: [40][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2371(0.5840)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 1.3551(1.3551)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 1.4192(1.4369)
# 	 epoch:40, avg train loss:0.5840, avg valid loss:1.4369
# 	 score:0.4131(th=0.800000), auc=0.852150::: time:558.77s
# - epoch:41 -
# Epoch: [41][0/125] Elapsed 0m 1s (remain 2m 7s) Loss: 0.2809(0.2809)
# Epoch: [41][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.4138(0.5071)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 3.0424(3.0424)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.4756(1.1317)
# 	 epoch:41, avg train loss:0.5071, avg valid loss:1.1317
# 	 score:0.4005(th=0.650000), auc=0.837433::: time:613.28s
# - epoch:42 -
# Epoch: [42][0/125] Elapsed 0m 0s (remain 1m 55s) Loss: 0.6913(0.6913)
# Epoch: [42][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3117(0.4508)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 2.6202(2.6202)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2270(1.1087)
# 	 epoch:42, avg train loss:0.4508, avg valid loss:1.1087
# 	 score:0.4240(th=0.850000), auc=0.855442::: time:667.94s
# - epoch:43 -
# Epoch: [43][0/125] Elapsed 0m 1s (remain 2m 8s) Loss: 0.2586(0.2586)
# Epoch: [43][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.9012(0.4527)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2600(0.2600)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2559(0.7216)
# 	 epoch:43, avg train loss:0.4527, avg valid loss:0.7216
# 	 score:0.3357(th=0.650000), auc=0.808800::: time:722.85s
# - epoch:44 -
# Epoch: [44][0/125] Elapsed 0m 0s (remain 1m 55s) Loss: 0.9652(0.9652)
# Epoch: [44][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2987(0.3863)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2745(0.2745)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2601(0.7118)
# 	 epoch:44, avg train loss:0.3863, avg valid loss:0.7118
# 	 score:0.3545(th=0.650000), auc=0.834277::: time:777.64s
# - epoch:45 -
# Epoch: [45][0/125] Elapsed 0m 0s (remain 1m 53s) Loss: 1.1816(1.1816)
# Epoch: [45][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.6111(0.4024)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2258(0.2258)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2255(0.5540)
# 	 epoch:45, avg train loss:0.4024, avg valid loss:0.5540
# 	 score:0.3598(th=0.550000), auc=0.835925::: time:832.50s
# [fold2] slice ave score:0.4208(th=0.650000), auc=0.863710
# [fold2] BEST Epoch 33 - Save Best Score:0.4298. Best loss:1.0331
# [fold2] BEST AUC Epoch 33 - Save Best Score:0.8645. Best loss:1.0331
# fold[0] BEST SCORE = 0.5073 thr=0.7 (epoch=44)
# fold[0] slice ave score:0.5175(th=0.650000), auc=0.865916
# fold[1] BEST SCORE = 0.3624 thr=0.25 (epoch=39)
# fold[1] slice ave score:0.3962(th=0.300000), auc=0.772234
# fold[2] BEST SCORE = 0.4298 thr=0.8 (epoch=33)
# fold[2] slice ave score:0.4208(th=0.650000), auc=0.863710
# CPU times: user 1h 52min 54s, sys: 29min 48s, total: 2h 22min 43s
# Wall time: 2h 29min 59s

# %%
# %%time
best_score_list, best_threshold_list, best_epoch_list = training_loop(CFG)
# Out:
# -- fold0 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# Epoch: [1][0/130] Elapsed 0m 0s (remain 1m 56s) Loss: 0.6921(0.6921)
# Epoch: [1][129/130] Elapsed 0m 37s (remain 0m 0s) Loss: 0.6669(0.6458)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.6123(0.6123)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5319(0.6273)
# 	 epoch:1, avg train loss:0.6458, avg valid loss:0.6273
# 	 score:0.3992(th=0.700000), auc=0.848477::: time:54.68s
# Epoch 1 - Save Best Score: 0.3992. Model is saved.
# dice_list:  [0.13807337968190972, 0.13807427897917332, 0.13810342351260185, 0.13828297168445178, 0.13982124567040505, 0.15549155829944997, 0.17628316506943253, 0.21427608764250736, 0.2730453705808382, 0.3323838472618981, 0.3739675799434043, 0.3969768357948154, 0.3992223464429098, 0.3697773417818021, 0.3036558623622807, 0.18949649042414776, 0.07137505660534961, 0.006701655939957532, 0.0]
# Epoch 1 - Save Best AUC: 0.8485. Model is saved.
# - epoch:2 -
# Epoch: [2][0/130] Elapsed 0m 0s (remain 1m 58s) Loss: 0.6054(0.6054)
# Epoch: [2][129/130] Elapsed 0m 37s (remain 0m 0s) Loss: 0.6820(0.6137)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.6053(0.6053)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4888(0.5909)
# 	 epoch:2, avg train loss:0.6137, avg valid loss:0.5909
# 	 score:0.4454(th=0.750000), auc=0.868712::: time:111.04s
# Epoch 2 - Save Best Score: 0.4454. Model is saved.
# dice_list:  [0.13807337487286492, 0.13807413951519384, 0.13811996618641023, 0.139099749436328, 0.15261901585966045, 0.17977832427223442, 0.21764189617462065, 0.27103892983500566, 0.32366641282603975, 0.3680638599525078, 0.40149662421738963, 0.425193475325259, 0.4405016779887808, 0.44543566634293036, 0.43537056006851416, 0.40572021640107586, 0.3375569167926056, 0.21972870257292648, 0.0]
# Epoch 2 - Save Best AUC: 0.8687. Model is saved.
# - epoch:3 -
# Epoch: [3][0/130] Elapsed 0m 0s (remain 1m 58s) Loss: 0.5796(0.5796)
# Epoch: [3][129/130] Elapsed 0m 37s (remain 0m 0s) Loss: 0.5648(0.5782)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4915(0.4915)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4546(0.5288)
# 	 epoch:3, avg train loss:0.5782, avg valid loss:0.5288
# 	 score:0.4418(th=0.650000), auc=0.853721::: time:167.62s
# - epoch:4 -
# Epoch: [4][0/130] Elapsed 0m 1s (remain 2m 10s) Loss: 0.5434(0.5434)
# Epoch: [4][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.7561(0.5565)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4922(0.4922)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4443(0.5465)
# 	 epoch:4, avg train loss:0.5565, avg valid loss:0.5465
# 	 score:0.4703(th=0.750000), auc=0.863542::: time:220.82s
# Epoch 4 - Save Best Score: 0.4703. Model is saved.
# dice_list:  [0.13807406737876327, 0.13811801938955193, 0.13854325408704724, 0.14587209503723936, 0.1744382847770631, 0.20823595952574767, 0.2590131202606145, 0.318688271355831, 0.3718824053749635, 0.4081136822591938, 0.4301823296857897, 0.4481113846865407, 0.46143030547188935, 0.4702964372804706, 0.46702564008838904, 0.45516037055767694, 0.43236962451457905, 0.3662637263630796, 0.0]
# - epoch:5 -
# Epoch: [5][0/130] Elapsed 0m 0s (remain 1m 58s) Loss: 0.5180(0.5180)
# Epoch: [5][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.5977(0.5340)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4843(0.4843)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4446(0.5315)
# 	 epoch:5, avg train loss:0.5340, avg valid loss:0.5315
# 	 score:0.4794(th=0.750000), auc=0.862297::: time:275.34s
# Epoch 5 - Save Best Score: 0.4794. Model is saved.
# dice_list:  [0.1380738269245391, 0.13811940020217703, 0.1385999440855146, 0.14528645989173855, 0.17913240421284315, 0.2207886569611018, 0.2769446646985152, 0.3369408080690801, 0.3872343302877397, 0.4198533910476278, 0.43948897844262885, 0.45732711293127815, 0.4713945626837473, 0.47942513852520746, 0.4792595150288115, 0.4696080718542258, 0.4463659860637605, 0.39285975695242975, 0.0]
# - epoch:6 -
# Epoch: [6][0/130] Elapsed 0m 1s (remain 2m 11s) Loss: 0.5052(0.5052)
# Epoch: [6][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.8196(0.5315)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4947(0.4947)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4338(0.5316)
# 	 epoch:6, avg train loss:0.5315, avg valid loss:0.5316
# 	 score:0.4796(th=0.800000), auc=0.864124::: time:330.20s
# Epoch 6 - Save Best Score: 0.4796. Model is saved.
# dice_list:  [0.13807500034908185, 0.13814481907361326, 0.13899777997155857, 0.1490764319864956, 0.18543827125961057, 0.22666993650083178, 0.280820447737573, 0.3379403715731539, 0.3844817513963477, 0.4165512492012095, 0.43703903172022224, 0.4524783915025953, 0.4666747831100353, 0.4769491134809126, 0.47964742624735424, 0.4751614343651067, 0.45983713666720516, 0.4093420600212403, 0.0]
# - epoch:7 -
# Epoch: [7][0/130] Elapsed 0m 0s (remain 1m 54s) Loss: 0.5762(0.5762)
# Epoch: [7][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.7728(0.5320)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4722(0.4722)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4504(0.5290)
# 	 epoch:7, avg train loss:0.5320, avg valid loss:0.5290
# 	 score:0.4680(th=0.750000), auc=0.856901::: time:384.62s
# - epoch:8 -
# Epoch: [8][0/130] Elapsed 0m 0s (remain 2m 4s) Loss: 0.5046(0.5046)
# Epoch: [8][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.7923(0.5239)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 8s) Loss: 0.4302(0.4302)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4147(0.5484)
# 	 epoch:8, avg train loss:0.5239, avg valid loss:0.5484
# 	 score:0.4673(th=0.800000), auc=0.862531::: time:438.28s
# - epoch:9 -
# Epoch: [9][0/130] Elapsed 0m 0s (remain 1m 54s) Loss: 0.6267(0.6267)
# Epoch: [9][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.7157(0.5199)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4337(0.4337)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4035(0.5127)
# 	 epoch:9, avg train loss:0.5199, avg valid loss:0.5127
# 	 score:0.4663(th=0.700000), auc=0.853632::: time:490.62s
# - epoch:10 -
# Epoch: [10][0/130] Elapsed 0m 0s (remain 2m 2s) Loss: 0.4726(0.4726)
# Epoch: [10][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.8546(0.5072)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.3506(0.3506)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5583(0.5916)
# 	 epoch:10, avg train loss:0.5072, avg valid loss:0.5916
# 	 score:0.4708(th=0.900000), auc=0.851587::: time:542.87s
# - epoch:11 -
# Epoch: [11][0/130] Elapsed 0m 0s (remain 1m 51s) Loss: 0.6600(0.6600)
# Epoch: [11][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.7600(0.5064)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.3501(0.3501)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4213(0.4769)
# 	 epoch:11, avg train loss:0.5064, avg valid loss:0.4769
# 	 score:0.4721(th=0.700000), auc=0.859838::: time:594.86s
# - epoch:12 -
# Epoch: [12][0/130] Elapsed 0m 1s (remain 2m 17s) Loss: 0.4108(0.4108)
# Epoch: [12][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2153(0.5163)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.3414(0.3414)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3450(0.4519)
# 	 epoch:12, avg train loss:0.5163, avg valid loss:0.4519
# 	 score:0.4622(th=0.550000), auc=0.842071::: time:647.22s
# - epoch:13 -
# Epoch: [13][0/130] Elapsed 0m 0s (remain 1m 53s) Loss: 0.5311(0.5311)
# Epoch: [13][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 1.3105(0.4965)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.3197(0.3197)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3114(0.5047)
# 	 epoch:13, avg train loss:0.4965, avg valid loss:0.5047
# 	 score:0.4892(th=0.750000), auc=0.865059::: time:700.56s
# Epoch 13 - Save Best Score: 0.4892. Model is saved.
# dice_list:  [0.14353293066582784, 0.1675395322855538, 0.1992277089376949, 0.2390159295067501, 0.28457459185777584, 0.32512065139228996, 0.35782380865537344, 0.3881421327907861, 0.41713401681648965, 0.44226370670271853, 0.46240514045563885, 0.47574144611676167, 0.4855443436792961, 0.48918954324656794, 0.4874344282741504, 0.479202440766462, 0.46338310433032254, 0.43578387374674316, 0.12459910292498434]
# - epoch:14 -
# Epoch: [14][0/130] Elapsed 0m 0s (remain 2m 7s) Loss: 0.4275(0.4275)
# Epoch: [14][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.5054(0.4597)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2803(0.2803)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3229(0.4008)
# 	 epoch:14, avg train loss:0.4597, avg valid loss:0.4008
# 	 score:0.4774(th=0.650000), auc=0.856369::: time:754.99s
# - epoch:15 -
# Epoch: [15][0/130] Elapsed 0m 0s (remain 1m 52s) Loss: 0.3880(0.3880)
# Epoch: [15][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 1.5953(0.4592)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2757(0.2757)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3179(0.4224)
# 	 epoch:15, avg train loss:0.4592, avg valid loss:0.4224
# 	 score:0.4821(th=0.700000), auc=0.863923::: time:807.37s
# surface_list:  range(27, 37, 3)
# - epoch:16 -
# Epoch: [16][0/130] Elapsed 0m 1s (remain 2m 10s) Loss: 0.5960(0.5960)
# Epoch: [16][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.8728(0.4720)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.3153(0.3153)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4208(0.4614)
# 	 epoch:16, avg train loss:0.4720, avg valid loss:0.4614
# 	 score:0.4627(th=0.750000), auc=0.861751::: time:52.23s
# Epoch 16 - Save Best Score: 0.4627. Model is saved.
# dice_list:  [0.14416994851549164, 0.17813267892241874, 0.21419703643959825, 0.25465732296952637, 0.2938623029110657, 0.33088775815126986, 0.3635405813731817, 0.38936848590226436, 0.4107119980757746, 0.4277694098172027, 0.44063312502707547, 0.45074129176217004, 0.46043212688205765, 0.46271726511623684, 0.46024152008229163, 0.46016792584334676, 0.4495171955566399, 0.41725049811195675, 0.14666279489364847]
# Epoch 16 - Save Best AUC: 0.8618. Model is saved.
# - epoch:17 -
# Epoch: [17][0/130] Elapsed 0m 1s (remain 2m 12s) Loss: 1.6787(1.6787)
# Epoch: [17][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 1.2938(0.4877)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.3139(0.3139)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4195(0.5328)
# 	 epoch:17, avg train loss:0.4877, avg valid loss:0.5328
# 	 score:0.4664(th=0.800000), auc=0.857164::: time:107.16s
# Epoch 17 - Save Best Score: 0.4664. Model is saved.
# dice_list:  [0.14101234716676547, 0.16863867237931895, 0.20898227068296843, 0.2515307823382842, 0.29214372439049435, 0.3320635064787599, 0.3640567174903203, 0.38826532320863144, 0.40591716586695, 0.419341656721653, 0.4314349883657601, 0.4449539949408252, 0.4566203563051835, 0.4645717319305203, 0.466431426368657, 0.4643570914325131, 0.45119135700133317, 0.429968051562745, 0.21259956933208382]
# - epoch:18 -
# Epoch: [18][0/130] Elapsed 0m 0s (remain 2m 0s) Loss: 0.3264(0.3264)
# Epoch: [18][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.6943(0.4843)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2766(0.2766)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4282(0.4433)
# 	 epoch:18, avg train loss:0.4843, avg valid loss:0.4433
# 	 score:0.4493(th=0.750000), auc=0.857227::: time:160.79s
# - epoch:19 -
# Epoch: [19][0/130] Elapsed 0m 0s (remain 2m 4s) Loss: 0.3615(0.3615)
# Epoch: [19][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 1.3086(0.4875)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2535(0.2535)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3897(0.4552)
# 	 epoch:19, avg train loss:0.4875, avg valid loss:0.4552
# 	 score:0.3701(th=0.500000), auc=0.841677::: time:213.59s
# - epoch:20 -
# Epoch: [20][0/130] Elapsed 0m 1s (remain 2m 13s) Loss: 0.3172(0.3172)
# Epoch: [20][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 1.8569(0.5281)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 3.0594(3.0594)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4873(1.4760)
# 	 epoch:20, avg train loss:0.5281, avg valid loss:1.4760
# 	 score:0.4411(th=0.900000), auc=0.865551::: time:266.26s
# Epoch 20 - Save Best AUC: 0.8656. Model is saved.
# - epoch:21 -
# Epoch: [21][0/130] Elapsed 0m 0s (remain 1m 59s) Loss: 0.3642(0.3642)
# Epoch: [21][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 2.7079(0.5195)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2482(0.2482)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4537(0.6995)
# 	 epoch:21, avg train loss:0.5195, avg valid loss:0.6995
# 	 score:0.4482(th=0.800000), auc=0.858677::: time:319.54s
# - epoch:22 -
# Epoch: [22][0/130] Elapsed 0m 0s (remain 2m 3s) Loss: 0.4573(0.4573)
# Epoch: [22][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 2.9157(0.4265)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1813(0.1813)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4448(0.4344)
# 	 epoch:22, avg train loss:0.4265, avg valid loss:0.4344
# 	 score:0.4523(th=0.650000), auc=0.859552::: time:372.37s
# - epoch:23 -
# Epoch: [23][0/130] Elapsed 0m 0s (remain 1m 58s) Loss: 0.8309(0.8309)
# Epoch: [23][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 1.4990(0.4955)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2478(0.2478)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4167(0.6848)
# 	 epoch:23, avg train loss:0.4955, avg valid loss:0.6848
# 	 score:0.4484(th=0.750000), auc=0.861183::: time:424.52s
# - epoch:24 -
# Epoch: [24][0/130] Elapsed 0m 0s (remain 2m 0s) Loss: 0.2855(0.2855)
# Epoch: [24][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 1.0315(0.4512)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2383(0.2383)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4309(0.5559)
# 	 epoch:24, avg train loss:0.4512, avg valid loss:0.5559
# 	 score:0.4628(th=0.750000), auc=0.864964::: time:477.20s
# - epoch:25 -
# Epoch: [25][0/130] Elapsed 0m 0s (remain 1m 51s) Loss: 0.3658(0.3658)
# Epoch: [25][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.7352(0.3848)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2077(0.2077)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4093(0.4342)
# 	 epoch:25, avg train loss:0.3848, avg valid loss:0.4342
# 	 score:0.4514(th=0.650000), auc=0.863007::: time:529.45s
# - epoch:26 -
# Epoch: [26][0/130] Elapsed 0m 0s (remain 2m 7s) Loss: 0.2387(0.2387)
# Epoch: [26][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 2.7162(0.3913)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2208(0.2208)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4277(0.4443)
# 	 epoch:26, avg train loss:0.3913, avg valid loss:0.4443
# 	 score:0.4654(th=0.700000), auc=0.869438::: time:582.73s
# Epoch 26 - Save Best AUC: 0.8694. Model is saved.
# - epoch:27 -
# Epoch: [27][0/130] Elapsed 0m 0s (remain 2m 8s) Loss: 0.3280(0.3280)
# Epoch: [27][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 1.7635(0.4070)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2304(0.2304)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4348(0.5080)
# 	 epoch:27, avg train loss:0.4070, avg valid loss:0.5080
# 	 score:0.4675(th=0.750000), auc=0.866048::: time:636.71s
# Epoch 27 - Save Best Score: 0.4675. Model is saved.
# dice_list:  [0.18772671787097667, 0.22876342092838464, 0.27175358294996055, 0.31260652555365814, 0.34785927371183417, 0.3772872885754426, 0.40082890971194396, 0.41971882285523826, 0.4350956648856778, 0.44746582222218567, 0.4561406961072043, 0.4624911719520936, 0.46659583694513646, 0.4675199570420294, 0.4658999508038215, 0.4610819130994686, 0.44636316559730815, 0.4145969218003395, 0.2351697549447248]
# - epoch:28 -
# Epoch: [28][0/130] Elapsed 0m 0s (remain 2m 8s) Loss: 0.4046(0.4046)
# Epoch: [28][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 3.1311(0.4140)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2351(0.2351)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4404(0.4364)
# 	 epoch:28, avg train loss:0.4140, avg valid loss:0.4364
# 	 score:0.4658(th=0.700000), auc=0.866276::: time:689.95s
# - epoch:29 -
# Epoch: [29][0/130] Elapsed 0m 1s (remain 2m 12s) Loss: 0.6877(0.6877)
# Epoch: [29][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 1.1465(0.4118)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1552(0.1552)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4238(0.3800)
# 	 epoch:29, avg train loss:0.4118, avg valid loss:0.3800
# 	 score:0.4626(th=0.550000), auc=0.865405::: time:742.52s
# - epoch:30 -
# Epoch: [30][0/130] Elapsed 0m 1s (remain 2m 15s) Loss: 0.2544(0.2544)
# Epoch: [30][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.8154(0.4580)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1762(0.1762)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4482(0.4386)
# 	 epoch:30, avg train loss:0.4580, avg valid loss:0.4386
# 	 score:0.4744(th=0.650000), auc=0.860898::: time:795.53s
# Epoch 30 - Save Best Score: 0.4744. Model is saved.
# dice_list:  [0.21987778893273577, 0.2736856835621193, 0.3221189312116996, 0.35869024643758546, 0.38723064445975613, 0.41085380317004133, 0.43257103291453197, 0.45116436185813685, 0.4637235261518896, 0.4710916902378222, 0.474181272610219, 0.47442767487440657, 0.47383469356995533, 0.46993994566322067, 0.46013129465299435, 0.44545385202814064, 0.42307973332049187, 0.3864036489131068, 0.16531577694710342]
# surface_list:  range(25, 35, 3)
# - epoch:31 -
# Epoch: [31][0/130] Elapsed 0m 0s (remain 1m 55s) Loss: 0.3258(0.3258)
# Epoch: [31][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 2.6157(0.5224)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1338(0.1338)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2606(0.3143)
# 	 epoch:31, avg train loss:0.5224, avg valid loss:0.3143
# 	 score:0.4399(th=0.550000), auc=0.854689::: time:52.87s
# Epoch 31 - Save Best Score: 0.4399. Model is saved.
# dice_list:  [0.22327398677839258, 0.27688375344190247, 0.32463181945442354, 0.3668200584977055, 0.3972922662343443, 0.41749672504271196, 0.4299546165206335, 0.43610614834136147, 0.4385926042347154, 0.439939193808158, 0.4376691355524576, 0.431180540009789, 0.418458178903238, 0.3961798036290729, 0.36396085043409776, 0.317832473951729, 0.25607075093191356, 0.1981418304372928, 0.02788924506969831]
# Epoch 31 - Save Best AUC: 0.8547. Model is saved.
# - epoch:32 -
# Epoch: [32][0/130] Elapsed 0m 0s (remain 1m 55s) Loss: 0.6149(0.6149)
# Epoch: [32][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 1.5177(0.4890)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1779(0.1779)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2533(0.3976)
# 	 epoch:32, avg train loss:0.4890, avg valid loss:0.3976
# 	 score:0.4672(th=0.800000), auc=0.857122::: time:108.84s
# Epoch 32 - Save Best Score: 0.4672. Model is saved.
# dice_list:  [0.20545815466969888, 0.24266936507777978, 0.2785626753124318, 0.3113888199829341, 0.34094090387451365, 0.36507724235341554, 0.38629554823799006, 0.40472542712123316, 0.42062565379536443, 0.4327339230032029, 0.4431141036486208, 0.45400955960230455, 0.4606151766486327, 0.4647387615648427, 0.46719236698720773, 0.45948019306655197, 0.4368797330385559, 0.3928053353925051, 0.12427620531040208]
# Epoch 32 - Save Best AUC: 0.8571. Model is saved.
# - epoch:33 -
# Epoch: [33][0/130] Elapsed 0m 1s (remain 2m 13s) Loss: 0.3309(0.3309)
# Epoch: [33][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 1.7167(0.3931)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1227(0.1227)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2791(0.4046)
# 	 epoch:33, avg train loss:0.3931, avg valid loss:0.4046
# 	 score:0.4611(th=0.650000), auc=0.858995::: time:163.95s
# Epoch 33 - Save Best AUC: 0.8590. Model is saved.
# - epoch:34 -
# Epoch: [34][0/130] Elapsed 0m 0s (remain 2m 5s) Loss: 0.3174(0.3174)
# Epoch: [34][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2880(0.4054)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1252(0.1252)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2610(0.3410)
# 	 epoch:34, avg train loss:0.4054, avg valid loss:0.3410
# 	 score:0.4609(th=0.650000), auc=0.864081::: time:217.69s
# Epoch 34 - Save Best AUC: 0.8641. Model is saved.
# - epoch:35 -
# Epoch: [35][0/130] Elapsed 0m 0s (remain 1m 54s) Loss: 0.3623(0.3623)
# Epoch: [35][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 2.1990(0.4171)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1247(0.1247)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2753(0.3729)
# 	 epoch:35, avg train loss:0.4171, avg valid loss:0.3729
# 	 score:0.4598(th=0.650000), auc=0.858685::: time:270.98s
# - epoch:36 -
# Epoch: [36][0/130] Elapsed 0m 1s (remain 2m 17s) Loss: 0.5608(0.5608)
# Epoch: [36][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.5330(0.3802)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1233(0.1233)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2668(0.3517)
# 	 epoch:36, avg train loss:0.3802, avg valid loss:0.3517
# 	 score:0.4582(th=0.600000), auc=0.861497::: time:324.14s
# - epoch:37 -
# Epoch: [37][0/130] Elapsed 0m 0s (remain 1m 53s) Loss: 0.5770(0.5770)
# Epoch: [37][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.5201(0.3699)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1187(0.1187)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2706(0.3564)
# 	 epoch:37, avg train loss:0.3699, avg valid loss:0.3564
# 	 score:0.4661(th=0.750000), auc=0.861719::: time:376.47s
# - epoch:38 -
# Epoch: [38][0/130] Elapsed 0m 0s (remain 1m 55s) Loss: 0.4251(0.4251)
# Epoch: [38][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2589(0.3639)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1402(0.1402)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2595(0.3824)
# 	 epoch:38, avg train loss:0.3639, avg valid loss:0.3824
# 	 score:0.4466(th=0.700000), auc=0.859574::: time:429.19s
# - epoch:39 -
# Epoch: [39][0/130] Elapsed 0m 0s (remain 2m 3s) Loss: 0.3068(0.3068)
# Epoch: [39][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.5309(0.3726)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1001(0.1001)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2538(0.3131)
# 	 epoch:39, avg train loss:0.3726, avg valid loss:0.3131
# 	 score:0.4769(th=0.700000), auc=0.868614::: time:481.58s
# Epoch 39 - Save Best Score: 0.4769. Model is saved.
# dice_list:  [0.26575559042318736, 0.3148753887801653, 0.35326919927739076, 0.38430019470472143, 0.4080849390689923, 0.4271745201988849, 0.4419928865959061, 0.4536543877459232, 0.4631117174645868, 0.4695457916080045, 0.47449244897707904, 0.47605222171474104, 0.4769499429684147, 0.4742958540512937, 0.4648158603843452, 0.44980478222313164, 0.4236896501212701, 0.3633045303917486, 0.029587789343962084]
# Epoch 39 - Save Best AUC: 0.8686. Model is saved.
# - epoch:40 -
# Epoch: [40][0/130] Elapsed 0m 0s (remain 2m 2s) Loss: 0.3569(0.3569)
# Epoch: [40][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.7390(0.3884)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1137(0.1137)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3590(0.3627)
# 	 epoch:40, avg train loss:0.3884, avg valid loss:0.3627
# 	 score:0.4593(th=0.550000), auc=0.868148::: time:536.55s
# - epoch:41 -
# Epoch: [41][0/130] Elapsed 0m 0s (remain 2m 7s) Loss: 0.4066(0.4066)
# Epoch: [41][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 0.8556(0.3998)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1045(0.1045)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3942(0.3617)
# 	 epoch:41, avg train loss:0.3998, avg valid loss:0.3617
# 	 score:0.4574(th=0.550000), auc=0.872670::: time:588.75s
# Epoch 41 - Save Best AUC: 0.8727. Model is saved.
# - epoch:42 -
# Epoch: [42][0/130] Elapsed 0m 0s (remain 2m 1s) Loss: 0.1931(0.1931)
# Epoch: [42][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 2.9410(0.3655)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1528(0.1528)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4594(0.4032)
# 	 epoch:42, avg train loss:0.3655, avg valid loss:0.4032
# 	 score:0.4678(th=0.700000), auc=0.872620::: time:642.99s
# - epoch:43 -
# Epoch: [43][0/130] Elapsed 0m 0s (remain 1m 53s) Loss: 0.2061(0.2061)
# Epoch: [43][129/130] Elapsed 0m 35s (remain 0m 0s) Loss: 2.2843(0.3445)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1379(0.1379)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4091(0.3644)
# 	 epoch:43, avg train loss:0.3445, avg valid loss:0.3644
# 	 score:0.4861(th=0.700000), auc=0.870595::: time:695.39s
# Epoch 43 - Save Best Score: 0.4861. Model is saved.
# dice_list:  [0.24693785359193215, 0.2882543025936444, 0.32254137694809115, 0.3519523455974626, 0.3752564686118819, 0.39616030985036554, 0.4164152722475267, 0.43473067820399314, 0.45084851198944154, 0.4646336148887232, 0.47583301577984866, 0.48383407331355216, 0.4860861953038274, 0.4848601338211319, 0.4798433823302166, 0.46865952357883295, 0.4492201282106882, 0.42058538338045204, 0.14707690238674484]
# - epoch:44 -
# Epoch: [44][0/130] Elapsed 0m 0s (remain 2m 3s) Loss: 0.2378(0.2378)
# Epoch: [44][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 1.0592(0.3339)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.0850(0.0850)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2466(0.3133)
# 	 epoch:44, avg train loss:0.3339, avg valid loss:0.3133
# 	 score:0.4780(th=0.550000), auc=0.870123::: time:750.01s
# - epoch:45 -
# Epoch: [45][0/130] Elapsed 0m 1s (remain 2m 15s) Loss: 0.2215(0.2215)
# Epoch: [45][129/130] Elapsed 0m 36s (remain 0m 0s) Loss: 0.3727(0.3306)
# EVAL: [0/27] Elapsed 0m 0s (remain 0m 7s) Loss: 0.1169(0.1169)
# EVAL: [26/27] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2517(0.3234)
# 	 epoch:45, avg train loss:0.3306, avg valid loss:0.3234
# 	 score:0.4730(th=0.700000), auc=0.874363::: time:802.85s
# Epoch 45 - Save Best AUC: 0.8744. Model is saved.
# [fold0] slice ave score:0.5147(th=0.650000), auc=0.882114
# [fold0] BEST Epoch 43 - Save Best Score:0.4861. Best loss:0.3644
# [fold0] BEST AUC Epoch 45 - Save Best Score:0.8744. Best loss:0.3234
# -- fold1 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# Epoch: [1][0/58] Elapsed 0m 1s (remain 0m 59s) Loss: 0.6898(0.6898)
# Epoch: [1][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.6313(0.6404)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.4147(0.4147)
# EVAL: [98/99] Elapsed 0m 15s (remain 0m 0s) Loss: 0.4093(0.5727)
# 	 epoch:1, avg train loss:0.6404, avg valid loss:0.5727
# 	 score:0.3134(th=0.500000), auc=0.761197::: time:79.24s
# Epoch 1 - Save Best Score: 0.3134. Model is saved.
# dice_list:  [0.19682021043660747, 0.19682349196768417, 0.19691328134166028, 0.19775937629172946, 0.20353848534683885, 0.2305110922846761, 0.2593262166120977, 0.2905796231207411, 0.3134254065410443, 0.3057410147956784, 0.2539373523083656, 0.16386968472475755, 0.0768657170776646, 0.028802263492661802, 0.010451464328677128, 0.0029847432210238943, 0.0002483374563907919, 1.4785373462781553e-06, 0.0]
# Epoch 1 - Save Best AUC: 0.7612. Model is saved.
# - epoch:2 -
# Epoch: [2][0/58] Elapsed 0m 0s (remain 0m 56s) Loss: 0.5969(0.5969)
# Epoch: [2][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.5380(0.6019)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 27s) Loss: 0.3880(0.3880)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3678(0.5394)
# 	 epoch:2, avg train loss:0.6019, avg valid loss:0.5394
# 	 score:0.3353(th=0.500000), auc=0.764253::: time:166.50s
# Epoch 2 - Save Best Score: 0.3353. Model is saved.
# dice_list:  [0.19682464803984778, 0.1968908801525376, 0.19757763691468536, 0.20132365874268265, 0.21901657989725465, 0.25239339774693315, 0.2874473424176503, 0.3189390811823289, 0.33531953942460957, 0.32609295939564975, 0.29438452520733066, 0.24669061067677925, 0.19123182106017272, 0.13861294354336323, 0.09281623909531651, 0.05976518626215033, 0.035327570616873964, 0.014012654556880434, 0.0]
# Epoch 2 - Save Best AUC: 0.7643. Model is saved.
# - epoch:3 -
# Epoch: [3][0/58] Elapsed 0m 0s (remain 0m 54s) Loss: 0.5684(0.5684)
# Epoch: [3][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.6436(0.5756)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.3829(0.3829)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3569(0.5381)
# 	 epoch:3, avg train loss:0.5756, avg valid loss:0.5381
# 	 score:0.3769(th=0.550000), auc=0.780295::: time:253.76s
# Epoch 3 - Save Best Score: 0.3769. Model is saved.
# dice_list:  [0.1968291846141396, 0.19693885798607685, 0.19793310747801376, 0.2033176687576381, 0.22516271915111266, 0.264747775404459, 0.30599040378245096, 0.3435173976799805, 0.3684456484181885, 0.37690411706184423, 0.368185764839541, 0.3452181528440644, 0.3131369231507207, 0.2730340874666112, 0.22667837127911744, 0.17823494011460986, 0.1285171874854171, 0.07608184058302728, 0.0]
# Epoch 3 - Save Best AUC: 0.7803. Model is saved.
# - epoch:4 -
# Epoch: [4][0/58] Elapsed 0m 0s (remain 0m 55s) Loss: 0.4920(0.4920)
# Epoch: [4][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.6997(0.5534)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.3791(0.3791)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3489(0.5169)
# 	 epoch:4, avg train loss:0.5534, avg valid loss:0.5169
# 	 score:0.3642(th=0.500000), auc=0.768235::: time:340.27s
# - epoch:5 -
# Epoch: [5][0/58] Elapsed 0m 0s (remain 0m 49s) Loss: 0.5572(0.5572)
# Epoch: [5][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.4513(0.5441)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.3573(0.3573)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3346(0.5076)
# 	 epoch:5, avg train loss:0.5441, avg valid loss:0.5076
# 	 score:0.3584(th=0.500000), auc=0.767957::: time:419.21s
# - epoch:6 -
# Epoch: [6][0/58] Elapsed 0m 0s (remain 0m 50s) Loss: 0.5206(0.5206)
# Epoch: [6][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.6163(0.5411)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.3754(0.3754)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3444(0.5195)
# 	 epoch:6, avg train loss:0.5411, avg valid loss:0.5195
# 	 score:0.3715(th=0.500000), auc=0.771638::: time:497.38s
# - epoch:7 -
# Epoch: [7][0/58] Elapsed 0m 0s (remain 0m 50s) Loss: 0.5545(0.5545)
# Epoch: [7][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.6994(0.5418)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 31s) Loss: 0.3747(0.3747)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3466(0.5181)
# 	 epoch:7, avg train loss:0.5418, avg valid loss:0.5181
# 	 score:0.3668(th=0.500000), auc=0.769317::: time:575.36s
# - epoch:8 -
# Epoch: [8][0/58] Elapsed 0m 0s (remain 0m 50s) Loss: 0.5328(0.5328)
# Epoch: [8][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.6037(0.5276)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.3571(0.3571)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3387(0.5134)
# 	 epoch:8, avg train loss:0.5276, avg valid loss:0.5134
# 	 score:0.3652(th=0.500000), auc=0.770214::: time:653.11s
# - epoch:9 -
# Epoch: [9][0/58] Elapsed 0m 0s (remain 0m 52s) Loss: 0.4575(0.4575)
# Epoch: [9][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.5082(0.5111)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.2843(0.2843)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2837(0.4888)
# 	 epoch:9, avg train loss:0.5111, avg valid loss:0.4888
# 	 score:0.3466(th=0.450000), auc=0.764699::: time:730.86s
# - epoch:10 -
# Epoch: [10][0/58] Elapsed 0m 0s (remain 0m 52s) Loss: 0.5256(0.5256)
# Epoch: [10][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.4298(0.5197)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.2829(0.2829)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2768(0.4860)
# 	 epoch:10, avg train loss:0.5197, avg valid loss:0.4860
# 	 score:0.3392(th=0.450000), auc=0.766258::: time:808.80s
# - epoch:11 -
# Epoch: [11][0/58] Elapsed 0m 0s (remain 0m 55s) Loss: 0.4211(0.4211)
# Epoch: [11][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.6710(0.4943)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.3320(0.3320)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3299(0.4877)
# 	 epoch:11, avg train loss:0.4943, avg valid loss:0.4877
# 	 score:0.3811(th=0.450000), auc=0.777503::: time:886.66s
# Epoch 11 - Save Best Score: 0.3811. Model is saved.
# dice_list:  [0.19682906346862608, 0.19728401188143666, 0.20164273364519053, 0.22093972006396936, 0.2674852963031408, 0.3158460586347001, 0.3593005959545039, 0.3811014931606623, 0.3738132335307713, 0.3434543452888427, 0.30142566916565133, 0.25831890357918613, 0.2206467173822542, 0.18640859706085777, 0.1557171804064272, 0.12514516917267354, 0.09301420275018865, 0.06197878520465479, 0.0003917943211032868]
# - epoch:12 -
# Epoch: [12][0/58] Elapsed 0m 0s (remain 0m 55s) Loss: 0.4080(0.4080)
# Epoch: [12][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.4029(0.4922)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.2665(0.2665)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2708(0.4751)
# 	 epoch:12, avg train loss:0.4922, avg valid loss:0.4751
# 	 score:0.3655(th=0.450000), auc=0.773687::: time:967.54s
# - epoch:13 -
# Epoch: [13][0/58] Elapsed 0m 0s (remain 0m 53s) Loss: 0.4481(0.4481)
# Epoch: [13][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.4184(0.4525)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 31s) Loss: 0.2451(0.2451)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2312(0.4566)
# 	 epoch:13, avg train loss:0.4525, avg valid loss:0.4566
# 	 score:0.3758(th=0.400000), auc=0.776461::: time:1045.45s
# - epoch:14 -
# Epoch: [14][0/58] Elapsed 0m 1s (remain 1m 1s) Loss: 0.5245(0.5245)
# Epoch: [14][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.4226(0.4725)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.2119(0.2119)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2251(0.4421)
# 	 epoch:14, avg train loss:0.4725, avg valid loss:0.4421
# 	 score:0.3759(th=0.400000), auc=0.774545::: time:1123.31s
# - epoch:15 -
# Epoch: [15][0/58] Elapsed 0m 0s (remain 0m 53s) Loss: 0.4871(0.4871)
# Epoch: [15][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3119(0.4648)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.2372(0.2372)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2613(0.4489)
# 	 epoch:15, avg train loss:0.4648, avg valid loss:0.4489
# 	 score:0.3766(th=0.400000), auc=0.771209::: time:1201.40s
# surface_list:  range(27, 37, 3)
# - epoch:16 -
# Epoch: [16][0/58] Elapsed 0m 0s (remain 0m 52s) Loss: 0.3485(0.3485)
# Epoch: [16][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.8776(0.4780)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.2444(0.2444)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2455(0.4583)
# 	 epoch:16, avg train loss:0.4780, avg valid loss:0.4583
# 	 score:0.3761(th=0.400000), auc=0.776171::: time:77.49s
# Epoch 16 - Save Best Score: 0.3761. Model is saved.
# dice_list:  [0.1969632204315847, 0.19931394270713976, 0.2194609026787147, 0.26488970551772456, 0.3123929547927804, 0.35332223693776604, 0.3760917574025288, 0.3757502322278214, 0.36176945371317826, 0.33828605235833986, 0.31105710993246555, 0.28558254544799205, 0.26004986827477994, 0.23444378835857954, 0.2081863456293308, 0.18128565299544636, 0.15226695364359824, 0.11528416069073945, 0.0020931298706166486]
# Epoch 16 - Save Best AUC: 0.7762. Model is saved.
# - epoch:17 -
# Epoch: [17][0/58] Elapsed 0m 0s (remain 0m 55s) Loss: 0.3896(0.3896)
# Epoch: [17][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3988(0.4344)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.2467(0.2467)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2652(0.4483)
# 	 epoch:17, avg train loss:0.4344, avg valid loss:0.4483
# 	 score:0.3815(th=0.400000), auc=0.777519::: time:164.09s
# Epoch 17 - Save Best Score: 0.3815. Model is saved.
# dice_list:  [0.19690541660312136, 0.1987323102568873, 0.21821295861646897, 0.26910752945100896, 0.3247943891499893, 0.36771577650648213, 0.3815220532445501, 0.3633685178564134, 0.3306076880505738, 0.2944431112918266, 0.2603198742572406, 0.22695669749282724, 0.19476536076156412, 0.16255128343856667, 0.13406247299867782, 0.1064511926687432, 0.07850812125784312, 0.05010629867178103, 0.0]
# Epoch 17 - Save Best AUC: 0.7775. Model is saved.
# - epoch:18 -
# Epoch: [18][0/58] Elapsed 0m 0s (remain 0m 50s) Loss: 0.4502(0.4502)
# Epoch: [18][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3431(0.4799)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.2406(0.2406)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2601(0.4513)
# 	 epoch:18, avg train loss:0.4799, avg valid loss:0.4513
# 	 score:0.3859(th=0.400000), auc=0.784427::: time:249.37s
# Epoch 18 - Save Best Score: 0.3859. Model is saved.
# dice_list:  [0.19689445121273252, 0.19874123757139683, 0.2207427992017134, 0.26841070190453886, 0.32018112887482425, 0.36615298818354886, 0.38593030580828364, 0.37322731067928083, 0.34440716573134766, 0.3125460296392193, 0.28416583600771467, 0.2564113113284426, 0.22966410429687495, 0.20309842596092903, 0.1765946326193344, 0.15123274487685537, 0.12456444460287731, 0.0931183701189009, 0.002344696567710902]
# Epoch 18 - Save Best AUC: 0.7844. Model is saved.
# - epoch:19 -
# Epoch: [19][0/58] Elapsed 0m 0s (remain 0m 51s) Loss: 0.5374(0.5374)
# Epoch: [19][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2754(0.4318)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.2010(0.2010)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2282(0.4459)
# 	 epoch:19, avg train loss:0.4318, avg valid loss:0.4459
# 	 score:0.3815(th=0.400000), auc=0.785766::: time:334.93s
# Epoch 19 - Save Best AUC: 0.7858. Model is saved.
# - epoch:20 -
# Epoch: [20][0/58] Elapsed 0m 0s (remain 0m 53s) Loss: 0.3750(0.3750)
# Epoch: [20][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3600(0.4784)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.2188(0.2188)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2112(0.4406)
# 	 epoch:20, avg train loss:0.4784, avg valid loss:0.4406
# 	 score:0.3694(th=0.400000), auc=0.770803::: time:416.45s
# - epoch:21 -
# Epoch: [21][0/58] Elapsed 0m 0s (remain 0m 55s) Loss: 1.2800(1.2800)
# Epoch: [21][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.5230(0.4605)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1602(0.1602)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1647(0.4234)
# 	 epoch:21, avg train loss:0.4605, avg valid loss:0.4234
# 	 score:0.3653(th=0.350000), auc=0.771565::: time:494.91s
# - epoch:22 -
# Epoch: [22][0/58] Elapsed 0m 1s (remain 1m 0s) Loss: 0.3979(0.3979)
# Epoch: [22][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.5146(0.4472)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1895(0.1895)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2005(0.4288)
# 	 epoch:22, avg train loss:0.4472, avg valid loss:0.4288
# 	 score:0.3566(th=0.350000), auc=0.766193::: time:573.24s
# - epoch:23 -
# Epoch: [23][0/58] Elapsed 0m 0s (remain 0m 51s) Loss: 0.5041(0.5041)
# Epoch: [23][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2887(0.4228)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 31s) Loss: 0.1739(0.1739)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1864(0.4274)
# 	 epoch:23, avg train loss:0.4228, avg valid loss:0.4274
# 	 score:0.3361(th=0.300000), auc=0.753229::: time:651.84s
# - epoch:24 -
# Epoch: [24][0/58] Elapsed 0m 1s (remain 0m 58s) Loss: 0.3710(0.3710)
# Epoch: [24][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2444(0.3720)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 35s) Loss: 0.1787(0.1787)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1931(0.4267)
# 	 epoch:24, avg train loss:0.3720, avg valid loss:0.4267
# 	 score:0.3714(th=0.350000), auc=0.764222::: time:728.98s
# - epoch:25 -
# Epoch: [25][0/58] Elapsed 0m 0s (remain 0m 50s) Loss: 0.3770(0.3770)
# Epoch: [25][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3577(0.3751)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1661(0.1661)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1862(0.4278)
# 	 epoch:25, avg train loss:0.3751, avg valid loss:0.4278
# 	 score:0.3775(th=0.350000), auc=0.772574::: time:807.63s
# - epoch:26 -
# Epoch: [26][0/58] Elapsed 0m 1s (remain 0m 57s) Loss: 0.9289(0.9289)
# Epoch: [26][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.4259(0.3867)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 38s) Loss: 0.1484(0.1484)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1655(0.4193)
# 	 epoch:26, avg train loss:0.3867, avg valid loss:0.4193
# 	 score:0.3635(th=0.300000), auc=0.767330::: time:885.81s
# - epoch:27 -
# Epoch: [27][0/58] Elapsed 0m 1s (remain 0m 58s) Loss: 0.9774(0.9774)
# Epoch: [27][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2753(0.3899)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.1641(0.1641)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1816(0.4186)
# 	 epoch:27, avg train loss:0.3899, avg valid loss:0.4186
# 	 score:0.3758(th=0.300000), auc=0.769274::: time:964.32s
# - epoch:28 -
# Epoch: [28][0/58] Elapsed 0m 0s (remain 0m 49s) Loss: 0.4123(0.4123)
# Epoch: [28][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.6472(0.3798)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 33s) Loss: 0.1597(0.1597)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1866(0.4180)
# 	 epoch:28, avg train loss:0.3798, avg valid loss:0.4180
# 	 score:0.3783(th=0.300000), auc=0.764360::: time:1041.66s
# - epoch:29 -
# Epoch: [29][0/58] Elapsed 0m 0s (remain 0m 52s) Loss: 0.3213(0.3213)
# Epoch: [29][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3740(0.4051)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1333(0.1333)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1567(0.4194)
# 	 epoch:29, avg train loss:0.4051, avg valid loss:0.4194
# 	 score:0.3467(th=0.300000), auc=0.764720::: time:1119.76s
# - epoch:30 -
# Epoch: [30][0/58] Elapsed 0m 0s (remain 0m 55s) Loss: 0.3138(0.3138)
# Epoch: [30][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2796(0.3324)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.1505(0.1505)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1734(0.4203)
# 	 epoch:30, avg train loss:0.3324, avg valid loss:0.4203
# 	 score:0.3515(th=0.250000), auc=0.751730::: time:1197.60s
# surface_list:  range(25, 35, 3)
# - epoch:31 -
# Epoch: [31][0/58] Elapsed 0m 1s (remain 0m 58s) Loss: 0.3352(0.3352)
# Epoch: [31][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.8949(0.4464)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1448(0.1448)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1447(0.4249)
# 	 epoch:31, avg train loss:0.4464, avg valid loss:0.4249
# 	 score:0.3577(th=0.350000), auc=0.775205::: time:78.25s
# Epoch 31 - Save Best Score: 0.3577. Model is saved.
# dice_list:  [0.20916859062381202, 0.2512425862575081, 0.29524410198115497, 0.3298785915590237, 0.3533115448207339, 0.3576730505458405, 0.3492099210433649, 0.3342403687324336, 0.3151796504644817, 0.2936270355762475, 0.26931530863352926, 0.24196088379895805, 0.21293281538111652, 0.18434143080265042, 0.15639829295586002, 0.12737860519982966, 0.09669582456448185, 0.06668973117865896, 0.002819691534153763]
# Epoch 31 - Save Best AUC: 0.7752. Model is saved.
# - epoch:32 -
# Epoch: [32][0/58] Elapsed 0m 0s (remain 0m 51s) Loss: 1.1225(1.1225)
# Epoch: [32][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2972(0.4255)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1360(0.1360)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1393(0.4248)
# 	 epoch:32, avg train loss:0.4255, avg valid loss:0.4248
# 	 score:0.3515(th=0.350000), auc=0.769717::: time:163.07s
# - epoch:33 -
# Epoch: [33][0/58] Elapsed 0m 0s (remain 0m 52s) Loss: 0.3340(0.3340)
# Epoch: [33][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 1.3558(0.4066)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.1423(0.1423)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1294(0.4293)
# 	 epoch:33, avg train loss:0.4066, avg valid loss:0.4293
# 	 score:0.3247(th=0.250000), auc=0.736441::: time:241.11s
# - epoch:34 -
# Epoch: [34][0/58] Elapsed 0m 1s (remain 0m 57s) Loss: 0.3537(0.3537)
# Epoch: [34][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2985(0.3645)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.1270(0.1270)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1264(0.4240)
# 	 epoch:34, avg train loss:0.3645, avg valid loss:0.4240
# 	 score:0.3352(th=0.250000), auc=0.750791::: time:318.38s
# - epoch:35 -
# Epoch: [35][0/58] Elapsed 0m 1s (remain 0m 57s) Loss: 0.2603(0.2603)
# Epoch: [35][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2777(0.3820)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1323(0.1323)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1271(0.4233)
# 	 epoch:35, avg train loss:0.3820, avg valid loss:0.4233
# 	 score:0.3271(th=0.300000), auc=0.751635::: time:398.82s
# - epoch:36 -
# Epoch: [36][0/58] Elapsed 0m 0s (remain 0m 49s) Loss: 0.5720(0.5720)
# Epoch: [36][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 2.1167(0.3744)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 40s) Loss: 0.1315(0.1315)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1281(0.4263)
# 	 epoch:36, avg train loss:0.3744, avg valid loss:0.4263
# 	 score:0.3272(th=0.300000), auc=0.750978::: time:476.78s
# - epoch:37 -
# Epoch: [37][0/58] Elapsed 0m 0s (remain 0m 52s) Loss: 0.2224(0.2224)
# Epoch: [37][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 1.3723(0.3955)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1286(0.1286)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1289(0.4230)
# 	 epoch:37, avg train loss:0.3955, avg valid loss:0.4230
# 	 score:0.3368(th=0.300000), auc=0.754634::: time:554.46s
# - epoch:38 -
# Epoch: [38][0/58] Elapsed 0m 0s (remain 0m 55s) Loss: 0.4372(0.4372)
# Epoch: [38][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3932(0.3501)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.1154(0.1154)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1220(0.4208)
# 	 epoch:38, avg train loss:0.3501, avg valid loss:0.4208
# 	 score:0.3413(th=0.250000), auc=0.759084::: time:631.53s
# - epoch:39 -
# Epoch: [39][0/58] Elapsed 0m 0s (remain 0m 50s) Loss: 0.2608(0.2608)
# Epoch: [39][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2725(0.3256)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0913(0.0913)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0907(0.4201)
# 	 epoch:39, avg train loss:0.3256, avg valid loss:0.4201
# 	 score:0.3403(th=0.250000), auc=0.771105::: time:708.87s
# - epoch:40 -
# Epoch: [40][0/58] Elapsed 0m 0s (remain 0m 55s) Loss: 0.2428(0.2428)
# Epoch: [40][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.1614(0.3049)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 28s) Loss: 0.0952(0.0952)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0913(0.4201)
# 	 epoch:40, avg train loss:0.3049, avg valid loss:0.4201
# 	 score:0.3363(th=0.250000), auc=0.767590::: time:786.93s
# - epoch:41 -
# Epoch: [41][0/58] Elapsed 0m 1s (remain 1m 1s) Loss: 0.3044(0.3044)
# Epoch: [41][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3180(0.3023)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.0864(0.0864)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0876(0.4354)
# 	 epoch:41, avg train loss:0.3023, avg valid loss:0.4354
# 	 score:0.3412(th=0.250000), auc=0.753660::: time:865.30s
# - epoch:42 -
# Epoch: [42][0/58] Elapsed 0m 1s (remain 0m 58s) Loss: 0.2349(0.2349)
# Epoch: [42][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.2256(0.3678)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 31s) Loss: 0.0795(0.0795)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0826(0.4318)
# 	 epoch:42, avg train loss:0.3678, avg valid loss:0.4318
# 	 score:0.3463(th=0.250000), auc=0.757681::: time:942.69s
# - epoch:43 -
# Epoch: [43][0/58] Elapsed 0m 1s (remain 1m 2s) Loss: 0.3138(0.3138)
# Epoch: [43][57/58] Elapsed 0m 17s (remain 0m 0s) Loss: 0.2170(0.3252)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.0770(0.0770)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0645(0.4387)
# 	 epoch:43, avg train loss:0.3252, avg valid loss:0.4387
# 	 score:0.3325(th=0.200000), auc=0.753726::: time:1021.25s
# - epoch:44 -
# Epoch: [44][0/58] Elapsed 0m 1s (remain 0m 59s) Loss: 0.2466(0.2466)
# Epoch: [44][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 0.3421(0.3098)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 30s) Loss: 0.0895(0.0895)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0768(0.4269)
# 	 epoch:44, avg train loss:0.3098, avg valid loss:0.4269
# 	 score:0.3550(th=0.250000), auc=0.762489::: time:1098.75s
# - epoch:45 -
# Epoch: [45][0/58] Elapsed 0m 0s (remain 0m 51s) Loss: 0.2368(0.2368)
# Epoch: [45][57/58] Elapsed 0m 16s (remain 0m 0s) Loss: 1.2699(0.3070)
# EVAL: [0/99] Elapsed 0m 0s (remain 0m 29s) Loss: 0.0872(0.0872)
# EVAL: [98/99] Elapsed 0m 16s (remain 0m 0s) Loss: 0.0759(0.4353)
# 	 epoch:45, avg train loss:0.3070, avg valid loss:0.4353
# 	 score:0.3469(th=0.200000), auc=0.753328::: time:1177.23s
# [fold1] slice ave score:0.3873(th=0.300000), auc=0.774610
# [fold1] BEST Epoch 31 - Save Best Score:0.3577. Best loss:0.4249
# [fold1] BEST AUC Epoch 31 - Save Best Score:0.7752. Best loss:0.4249
# -- fold2 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# Epoch: [1][0/125] Elapsed 0m 0s (remain 1m 57s) Loss: 0.7284(0.7284)
# Epoch: [1][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.6452(0.6801)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.5484(0.5484)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.6029(0.6723)
# 	 epoch:1, avg train loss:0.6801, avg valid loss:0.6723
# 	 score:0.4054(th=0.650000), auc=0.853884::: time:56.09s
# Epoch 1 - Save Best Score: 0.4054. Model is saved.
# ...
# Epoch 16 - Save Best AUC: 0.8514. Model is saved.
# - epoch:17 -
# Epoch: [17][0/125] Elapsed 0m 1s (remain 2m 8s) Loss: 0.4741(0.4741)
# Epoch: [17][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3665(0.5225)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.3026(0.3026)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2615(0.6229)
# 	 epoch:17, avg train loss:0.5225, avg valid loss:0.6229
# 	 score:0.4137(th=0.650000), auc=0.852368::: time:113.32s
# Epoch 17 - Save Best Score: 0.4137. Model is saved.
# dice_list:  [0.19936583938921246, 0.21981867071704553, 0.2516717489385448, 0.28261245298943694, 0.31155401071789124, 0.3396958214962417, 0.36323329961683787, 0.38091294696969735, 0.3940140828244255, 0.405447858139003, 0.4122287948277379, 0.41373869032284144, 0.41205644085183574, 0.4084316343226108, 0.4018263227859368, 0.39037595971600725, 0.3705962766013789, 0.3370898327579523, 0.08950042086297559]
# Epoch 17 - Save Best AUC: 0.8524. Model is saved.
# - epoch:18 -
# Epoch: [18][0/125] Elapsed 0m 0s (remain 2m 2s) Loss: 0.8062(0.8062)
# Epoch: [18][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.4624(0.5036)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2962(0.2962)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2728(0.6061)
# 	 epoch:18, avg train loss:0.5036, avg valid loss:0.6061
# 	 score:0.4212(th=0.600000), auc=0.858469::: time:171.07s
# Epoch 18 - Save Best Score: 0.4212. Model is saved.
# dice_list:  [0.19936895015499334, 0.21486434788901082, 0.24974104798686506, 0.28668837297681987, 0.3250156084682878, 0.3565388297142342, 0.37996364432531626, 0.3979281471561229, 0.41220550981922904, 0.41971710709882215, 0.4211993261963299, 0.4199760956542589, 0.41711235473594543, 0.41163688318869873, 0.4030190965334734, 0.39021160633089963, 0.37145889337879656, 0.33793178085201686, 0.09942962799672488]
# Epoch 18 - Save Best AUC: 0.8585. Model is saved.
# - epoch:19 -
# Epoch: [19][0/125] Elapsed 0m 1s (remain 2m 4s) Loss: 0.3219(0.3219)
# Epoch: [19][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.7675(0.5041)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.3051(0.3051)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2843(0.8860)
# 	 epoch:19, avg train loss:0.5041, avg valid loss:0.8860
# 	 score:0.4073(th=0.700000), auc=0.854783::: time:229.06s
# - epoch:20 -
# Epoch: [20][0/125] Elapsed 0m 0s (remain 1m 50s) Loss: 0.3220(0.3220)
# Epoch: [20][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.4652(0.5148)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2896(0.2896)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2582(0.6162)
# 	 epoch:20, avg train loss:0.5148, avg valid loss:0.6162
# 	 score:0.4035(th=0.600000), auc=0.852737::: time:283.66s
# - epoch:21 -
# Epoch: [21][0/125] Elapsed 0m 1s (remain 2m 11s) Loss: 0.8079(0.8079)
# Epoch: [21][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.4180(0.4666)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2468(0.2468)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2014(0.4698)
# 	 epoch:21, avg train loss:0.4666, avg valid loss:0.4698
# 	 score:0.4085(th=0.450000), auc=0.859287::: time:338.43s
# Epoch 21 - Save Best AUC: 0.8593. Model is saved.
# - epoch:22 -
# Epoch: [22][0/125] Elapsed 0m 1s (remain 2m 8s) Loss: 0.2442(0.2442)
# Epoch: [22][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 1.0155(0.5079)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.3998(0.3998)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2165(0.5985)
# 	 epoch:22, avg train loss:0.5079, avg valid loss:0.5985
# 	 score:0.4109(th=0.600000), auc=0.858513::: time:395.35s
# - epoch:23 -
# Epoch: [23][0/125] Elapsed 0m 0s (remain 1m 56s) Loss: 1.1308(1.1308)
# Epoch: [23][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3305(0.4752)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2792(0.2792)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1791(0.5835)
# 	 epoch:23, avg train loss:0.4752, avg valid loss:0.5835
# 	 score:0.4352(th=0.650000), auc=0.865808::: time:449.92s
# Epoch 23 - Save Best Score: 0.4352. Model is saved.
# dice_list:  [0.23192233405099413, 0.2787408470264888, 0.31557040450899415, 0.34607557818849316, 0.3683551383843466, 0.38597181490340865, 0.40000281768249174, 0.41239858867708695, 0.42210831834939894, 0.42903287007443647, 0.43321929658868485, 0.4352195886652435, 0.4311673157428643, 0.4238138917219391, 0.41179168657788384, 0.39342279897297233, 0.3659502467357295, 0.3286211135236835, 0.13916364708131818]
# Epoch 23 - Save Best AUC: 0.8658. Model is saved.
# - epoch:24 -
# Epoch: [24][0/125] Elapsed 0m 0s (remain 1m 54s) Loss: 0.3198(0.3198)
# Epoch: [24][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.7721(0.4042)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2600(0.2600)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1655(0.7574)
# 	 epoch:24, avg train loss:0.4042, avg valid loss:0.7574
# 	 score:0.4184(th=0.600000), auc=0.858875::: time:507.95s
# - epoch:25 -
# Epoch: [25][0/125] Elapsed 0m 0s (remain 1m 52s) Loss: 1.1971(1.1971)
# Epoch: [25][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.4641(0.3964)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2151(0.2151)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1534(0.5259)
# 	 epoch:25, avg train loss:0.3964, avg valid loss:0.5259
# 	 score:0.4267(th=0.550000), auc=0.862807::: time:562.56s
# - epoch:26 -
# Epoch: [26][0/125] Elapsed 0m 1s (remain 2m 10s) Loss: 1.2264(1.2264)
# Epoch: [26][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2545(0.3861)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2448(0.2448)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1607(0.6375)
# 	 epoch:26, avg train loss:0.3861, avg valid loss:0.6375
# 	 score:0.4251(th=0.600000), auc=0.861436::: time:617.89s
# - epoch:27 -
# Epoch: [27][0/125] Elapsed 0m 0s (remain 1m 54s) Loss: 0.2045(0.2045)
# Epoch: [27][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3014(0.3841)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2482(0.2482)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1572(0.6445)
# 	 epoch:27, avg train loss:0.3841, avg valid loss:0.6445
# 	 score:0.4243(th=0.650000), auc=0.861323::: time:672.58s
# - epoch:28 -
# Epoch: [28][0/125] Elapsed 0m 0s (remain 1m 59s) Loss: 0.3880(0.3880)
# Epoch: [28][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2188(0.4447)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2580(0.2580)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1530(0.7968)
# 	 epoch:28, avg train loss:0.4447, avg valid loss:0.7968
# 	 score:0.4388(th=0.700000), auc=0.860523::: time:727.87s
# Epoch 28 - Save Best Score: 0.4388. Model is saved.
# dice_list:  [0.25541723560007473, 0.29082713361209633, 0.32165946638205817, 0.3463789187118039, 0.36497783528982125, 0.3805410071954962, 0.3954243494249009, 0.40906492929994803, 0.41950264409322324, 0.4268926429485507, 0.43201620757787007, 0.43611392173206137, 0.4388215208633679, 0.43719047388907534, 0.42979279949805743, 0.4180346792546226, 0.4033890570324964, 0.3798186900274117, 0.24069365877096682]
# - epoch:29 -
# Epoch: [29][0/125] Elapsed 0m 0s (remain 2m 2s) Loss: 0.3454(0.3454)
# Epoch: [29][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 1.3638(0.4011)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.4028(0.4028)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1637(0.8486)
# 	 epoch:29, avg train loss:0.4011, avg valid loss:0.8486
# 	 score:0.4409(th=0.800000), auc=0.863921::: time:784.03s
# Epoch 29 - Save Best Score: 0.4409. Model is saved.
# dice_list:  [0.2543667603592847, 0.2836660445504577, 0.3088407003308178, 0.3314028743839488, 0.349013876738986, 0.3626588557699034, 0.3749193091808847, 0.3858105485556882, 0.39594898074947016, 0.40593061948949327, 0.41731489104579816, 0.4279046126010435, 0.43550575704854577, 0.4398035945955302, 0.44090097562056735, 0.43609877970356703, 0.42334331513663886, 0.39663976123036465, 0.21938873008645016]
# - epoch:30 -
# Epoch: [30][0/125] Elapsed 0m 1s (remain 2m 10s) Loss: 0.2848(0.2848)
# Epoch: [30][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2654(0.3888)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.3373(0.3373)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1328(0.7289)
# 	 epoch:30, avg train loss:0.3888, avg valid loss:0.7289
# 	 score:0.4346(th=0.750000), auc=0.860108::: time:840.28s
# surface_list:  range(25, 35, 3)
# - epoch:31 -
# Epoch: [31][0/125] Elapsed 0m 0s (remain 2m 0s) Loss: 0.3326(0.3326)
# Epoch: [31][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.4963(0.6048)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.3351(0.3351)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1826(1.1116)
# 	 epoch:31, avg train loss:0.6048, avg valid loss:1.1116
# 	 score:0.4145(th=0.750000), auc=0.853180::: time:55.09s
# Epoch 31 - Save Best Score: 0.4145. Model is saved.
# dice_list:  [0.24978081541702704, 0.2797672478700668, 0.3096029811825236, 0.33504422254916183, 0.35275614922675586, 0.3675515825597329, 0.37899576410522495, 0.3872952281680673, 0.3936643067694692, 0.4000786922253945, 0.40581628626464095, 0.4105438282205515, 0.41361235012293335, 0.4144981645617251, 0.41087689795858523, 0.4051423115050632, 0.39550626992627974, 0.38036583626715886, 0.3054145762459114]
# Epoch 31 - Save Best AUC: 0.8532. Model is saved.
# - epoch:32 -
# Epoch: [32][0/125] Elapsed 0m 0s (remain 1m 56s) Loss: 1.1337(1.1337)
# Epoch: [32][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2463(0.5314)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2429(0.2429)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1813(1.5772)
# 	 epoch:32, avg train loss:0.5314, avg valid loss:1.5772
# 	 score:0.4046(th=0.800000), auc=0.842085::: time:113.26s
# - epoch:33 -
# Epoch: [33][0/125] Elapsed 0m 0s (remain 1m 51s) Loss: 0.6729(0.6729)
# Epoch: [33][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 1.6582(0.5350)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1940(0.1940)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1281(0.4224)
# 	 epoch:33, avg train loss:0.5350, avg valid loss:0.4224
# 	 score:0.4010(th=0.450000), auc=0.851775::: time:168.74s
# - epoch:34 -
# Epoch: [34][0/125] Elapsed 0m 0s (remain 2m 3s) Loss: 0.9655(0.9655)
# Epoch: [34][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 1.0008(0.4933)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2712(0.2712)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1508(0.7138)
# 	 epoch:34, avg train loss:0.4933, avg valid loss:0.7138
# 	 score:0.4066(th=0.650000), auc=0.857941::: time:224.44s
# Epoch 34 - Save Best AUC: 0.8579. Model is saved.
# - epoch:35 -
# Epoch: [35][0/125] Elapsed 0m 0s (remain 1m 51s) Loss: 0.3260(0.3260)
# Epoch: [35][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3941(0.4473)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.3121(0.3121)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1652(0.7521)
# 	 epoch:35, avg train loss:0.4473, avg valid loss:0.7521
# 	 score:0.4085(th=0.600000), auc=0.859893::: time:281.02s
# Epoch 35 - Save Best AUC: 0.8599. Model is saved.
# - epoch:36 -
# Epoch: [36][0/125] Elapsed 0m 1s (remain 2m 4s) Loss: 1.3933(1.3933)
# Epoch: [36][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2663(0.4538)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2647(0.2647)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1528(0.5527)
# 	 epoch:36, avg train loss:0.4538, avg valid loss:0.5527
# 	 score:0.4138(th=0.600000), auc=0.859232::: time:337.88s
# - epoch:37 -
# Epoch: [37][0/125] Elapsed 0m 0s (remain 1m 59s) Loss: 0.3108(0.3108)
# Epoch: [37][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2867(0.4358)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2616(0.2616)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1531(0.6373)
# 	 epoch:37, avg train loss:0.4358, avg valid loss:0.6373
# 	 score:0.4131(th=0.600000), auc=0.861717::: time:392.59s
# Epoch 37 - Save Best AUC: 0.8617. Model is saved.
# - epoch:38 -
# Epoch: [38][0/125] Elapsed 0m 0s (remain 1m 58s) Loss: 0.4788(0.4788)
# Epoch: [38][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3817(0.4363)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2597(0.2597)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1576(0.4991)
# 	 epoch:38, avg train loss:0.4363, avg valid loss:0.4991
# 	 score:0.4080(th=0.650000), auc=0.858600::: time:449.77s
# - epoch:39 -
# Epoch: [39][0/125] Elapsed 0m 1s (remain 2m 13s) Loss: 0.7426(0.7426)
# Epoch: [39][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3744(0.4202)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 8s) Loss: 0.2492(0.2492)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1524(0.5294)
# 	 epoch:39, avg train loss:0.4202, avg valid loss:0.5294
# 	 score:0.4078(th=0.600000), auc=0.856506::: time:505.18s
# - epoch:40 -
# Epoch: [40][0/125] Elapsed 0m 1s (remain 2m 6s) Loss: 0.3368(0.3368)
# Epoch: [40][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3687(0.3885)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1407(0.1407)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1208(0.4178)
# 	 epoch:40, avg train loss:0.3885, avg valid loss:0.4178
# 	 score:0.3702(th=0.300000), auc=0.837392::: time:560.63s
# - epoch:41 -
# Epoch: [41][0/125] Elapsed 0m 1s (remain 2m 8s) Loss: 0.3322(0.3322)
# Epoch: [41][124/125] Elapsed 0m 35s (remain 0m 0s) Loss: 0.5166(0.5862)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.2603(0.2603)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.2069(0.4720)
# 	 epoch:41, avg train loss:0.5862, avg valid loss:0.4720
# 	 score:0.4144(th=0.600000), auc=0.861277::: time:616.54s
# - epoch:42 -
# Epoch: [42][0/125] Elapsed 0m 1s (remain 2m 6s) Loss: 0.3123(0.3123)
# Epoch: [42][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2848(0.4969)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.3290(0.3290)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1948(0.5672)
# 	 epoch:42, avg train loss:0.4969, avg valid loss:0.5672
# 	 score:0.4019(th=0.650000), auc=0.861734::: time:671.29s
# Epoch 42 - Save Best AUC: 0.8617. Model is saved.
# - epoch:43 -
# Epoch: [43][0/125] Elapsed 0m 0s (remain 1m 59s) Loss: 0.2462(0.2462)
# Epoch: [43][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3593(0.4497)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 1.5403(1.5403)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1764(1.0273)
# 	 epoch:43, avg train loss:0.4497, avg valid loss:1.0273
# 	 score:0.4267(th=0.700000), auc=0.867635::: time:727.81s
# Epoch 43 - Save Best Score: 0.4267. Model is saved.
# dice_list:  [0.26643521032698725, 0.29665639789184806, 0.3226247680190252, 0.3436551689953031, 0.3602525556033829, 0.37479570426025743, 0.38755046627159984, 0.3988221127430206, 0.4088161191158772, 0.4171485216395232, 0.4228952708119556, 0.4261316192566007, 0.4266733441931593, 0.4250749955529325, 0.420081866339887, 0.41109998908404666, 0.39244780496423665, 0.3501410028111513, 0.1986386210240478]
# Epoch 43 - Save Best AUC: 0.8676. Model is saved.
# - epoch:44 -
# Epoch: [44][0/125] Elapsed 0m 1s (remain 2m 5s) Loss: 0.7951(0.7951)
# Epoch: [44][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2856(0.4112)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.8628(0.8628)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1637(0.7581)
# 	 epoch:44, avg train loss:0.4112, avg valid loss:0.7581
# 	 score:0.4223(th=0.600000), auc=0.866983::: time:785.77s
# - epoch:45 -
# Epoch: [45][0/125] Elapsed 0m 0s (remain 1m 58s) Loss: 1.1253(1.1253)
# Epoch: [45][124/125] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2145(0.3963)
# EVAL: [0/31] Elapsed 0m 0s (remain 0m 9s) Loss: 0.1772(0.1772)
# EVAL: [30/31] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1790(0.5466)
# 	 epoch:45, avg train loss:0.3963, avg valid loss:0.5466
# 	 score:0.4213(th=0.600000), auc=0.866428::: time:840.72s
# [fold2] slice ave score:0.4544(th=0.650000), auc=0.875513
# [fold2] BEST Epoch 43 - Save Best Score:0.4267. Best loss:1.0273
# [fold2] BEST AUC Epoch 43 - Save Best Score:0.8676. Best loss:1.0273
# fold[0] BEST SCORE = 0.4861 thr=0.7 (epoch=43)
# fold[0] slice ave score:0.5147(th=0.650000), auc=0.882114
# fold[1] BEST SCORE = 0.3577 thr=0.35 (epoch=31)
# fold[1] slice ave score:0.3873(th=0.300000), auc=0.774610
# fold[2] BEST SCORE = 0.4267 thr=0.7 (epoch=43)
# fold[2] slice ave score:0.4544(th=0.650000), auc=0.875513
# CPU times: user 1h 53min 5s, sys: 29min 8s, total: 2h 22min 13s
# Wall time: 2h 29min 14s

# %% [markdown]
# ---
# # OOF SCORE CHECK

# %%
# %%time
slice_ave_score_list, slice_ave_score_threshold_list, slice_ave_auc_list = slide_inference(CFG)
for fold in CFG["folds"]:
    print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    wandb.log({"OOF SCORE" : {f"slice average score":slice_ave_score_list[fold],
                            f"slice average threshold":slice_ave_score_threshold_list[fold],
                            f"slice_average auc":slice_ave_auc_list[fold],
                            }})
# Out:
# -- fold0 slide inference start --
# surface_list:  range(26, 36, 3)
# slide pos: [0, 0]
# 	 score:0.4807(th=0.800000), auc=0.877635::: time:26.14s
# slide pos: [128, 0]
# 	 score:0.5237(th=0.800000), auc=0.871874::: time:44.41s
# slide pos: [0, 128]
# 	 score:0.4564(th=0.700000), auc=0.869145::: time:62.27s
# slide pos: [128, 128]
# 	 score:0.4714(th=0.800000), auc=0.864437::: time:80.34s
# surface_list:  range(27, 37, 3)
# slide pos: [0, 0]
# 	 score:0.4338(th=0.750000), auc=0.872224::: time:105.52s
# slide pos: [128, 0]
# 	 score:0.4761(th=0.800000), auc=0.866195::: time:123.53s
# slide pos: [0, 128]
# 	 score:0.4288(th=0.750000), auc=0.872407::: time:141.43s
# slide pos: [128, 128]
# 	 score:0.4460(th=0.800000), auc=0.862473::: time:159.55s
# surface_list:  range(25, 35, 3)
# slide pos: [0, 0]
# 	 score:0.4730(th=0.700000), auc=0.874363::: time:184.32s
# slide pos: [128, 0]
# 	 score:0.5076(th=0.750000), auc=0.874289::: time:202.27s
# slide pos: [0, 128]
# 	 score:0.4459(th=0.700000), auc=0.863916::: time:220.03s
# slide pos: [128, 128]
# 	 score:0.4717(th=0.750000), auc=0.856342::: time:238.32s
# [fold0] slice ave score:0.5378(th=0.650000), auc=0.895369
# -- fold1 slide inference start --
# surface_list:  range(26, 36, 3)
# slide pos: [0, 0]
# 	 score:0.3650(th=0.350000), auc=0.777887::: time:343.10s
# slide pos: [128, 0]
# 	 score:0.3657(th=0.350000), auc=0.773043::: time:409.60s
# slide pos: [0, 128]
# 	 score:0.3542(th=0.350000), auc=0.776531::: time:476.69s
# slide pos: [128, 128]
# 	 score:0.3367(th=0.350000), auc=0.770817::: time:545.09s
# surface_list:  range(27, 37, 3)
# slide pos: [0, 0]
# 	 score:0.3669(th=0.350000), auc=0.781364::: time:637.07s
# slide pos: [128, 0]
# 	 score:0.3658(th=0.350000), auc=0.776716::: time:703.52s
# slide pos: [0, 128]
# 	 score:0.3600(th=0.350000), auc=0.779020::: time:769.66s
# slide pos: [128, 128]
# 	 score:0.3495(th=0.350000), auc=0.775370::: time:839.38s
# surface_list:  range(25, 35, 3)
# slide pos: [0, 0]
# 	 score:0.3577(th=0.350000), auc=0.775205::: time:933.13s
# slide pos: [128, 0]
# 	 score:0.3566(th=0.350000), auc=0.769389::: time:1004.41s
# slide pos: [0, 128]
# 	 score:0.3416(th=0.300000), auc=0.770559::: time:1075.56s
# slide pos: [128, 128]
# 	 score:0.3334(th=0.300000), auc=0.772075::: time:1144.40s
# [fold1] slice ave score:0.4078(th=0.350000), auc=0.802983
# -- fold2 slide inference start --
# surface_list:  range(26, 36, 3)
# slide pos: [0, 0]
# 	 score:0.4128(th=0.800000), auc=0.857724::: time:1237.26s
# slide pos: [128, 0]
# 	 score:0.4285(th=0.850000), auc=0.852021::: time:1259.24s
# slide pos: [0, 128]
# 	 score:0.4136(th=0.800000), auc=0.863261::: time:1281.13s
# slide pos: [128, 128]
# 	 score:0.4174(th=0.700000), auc=0.856721::: time:1302.92s
# surface_list:  range(27, 37, 3)
# slide pos: [0, 0]
# 	 score:0.4099(th=0.800000), auc=0.856158::: time:1333.31s
# slide pos: [128, 0]
# 	 score:0.3984(th=0.800000), auc=0.850798::: time:1355.14s
# slide pos: [0, 128]
# 	 score:0.4108(th=0.750000), auc=0.858049::: time:1377.17s
# slide pos: [128, 128]
# 	 score:0.4089(th=0.700000), auc=0.855679::: time:1399.13s
# surface_list:  range(25, 35, 3)
# slide pos: [0, 0]
# 	 score:0.4267(th=0.700000), auc=0.867635::: time:1429.74s
# slide pos: [128, 0]
# 	 score:0.4281(th=0.850000), auc=0.854583::: time:1451.50s
# slide pos: [0, 128]
# 	 score:0.4206(th=0.750000), auc=0.865107::: time:1473.59s
# slide pos: [128, 128]
# 	 score:0.4224(th=0.800000), auc=0.856101::: time:1495.50s
# [fold2] slice ave score:0.4536(th=0.650000), auc=0.879701
# fold[0] slice ave score:0.5378(th=0.895369), auc=0.650000
# fold[1] slice ave score:0.4078(th=0.802983), auc=0.350000
# fold[2] slice ave score:0.4536(th=0.879701), auc=0.650000
# CPU times: user 19min 49s, sys: 3min 18s, total: 23min 7s
# Wall time: 25min 12s

# %%
import yaml
with open(os.path.join(CFG["OUTPUT_DIR"], "Config.yaml"), "w") as f:
    yaml.dump(CFG, f)

# %%
if not CFG["DEBUG"]:
    wandb.finish()
