# %% [markdown]
# # ex014
# 5-fold
# img size 512

# %%
import gc
import os
import random
import time
import math

import cv2
import numpy as np
import matplotlib.pyplot as plt

# model
import torch
import torchvision
import torch.nn as nn
import timm
from torchvision.models.feature_extraction import create_feature_extractor
import torchvision.transforms.functional as TF

# data loader
import albumentations as A
from albumentations.pytorch import ToTensorV2
from torch.utils.data import DataLoader, Dataset

# training
from torch.optim import SGD, Adam, AdamW
from torch.optim.lr_scheduler import CosineAnnealingLR, CosineAnnealingWarmRestarts, ReduceLROnPlateau, ExponentialLR

# metric
from sklearn.metrics import fbeta_score, roc_auc_score

import wandb

# %% [markdown]
# # config

# %%
BASE_DIR = "/working/"
INPUT_DIR = os.path.join(BASE_DIR, "input", "vesuvius-challenge-ink-detection")
TRAIN_DIR = os.path.join(INPUT_DIR, "train")
TEST_DIR = os.path.join(INPUT_DIR, "test")
# IMG_SIZE = [256, 256]
# IMG_SIZE = [128, 128]
IMG_SIZE = [512, 512]
SURFACE_LIST = [
                range(26, 36, 3),
                range(27, 37, 3),                
                range(25, 35, 3),
                ]
print(len(SURFACE_LIST[0]))
print(SURFACE_LIST)

SURFACE_NUM = len(SURFACE_LIST[0])
# print("Start surface idx =",START_SURFACE)

# SLIDE_POS_LIST = [[idx*(IMG_SIZE[0]//6), idx*(IMG_SIZE[1]//6)] for idx in range(0, 3)]
SLIDE_POS_LIST = [[0,0], [IMG_SIZE[0]//2, 0], [0, IMG_SIZE[1]//2], [IMG_SIZE[0]//2, IMG_SIZE[1]//2]]
print("SLIDE_POS_LIST =", SLIDE_POS_LIST)
CFG = {
    "DEBUG" : False,
    # exp setting
    "EXP_CATEGORY" : "5fold",
    "EXP_NAME" : "exp014",
    "folds" : [0, 1, 2, 3, 4],

    # model
    # "model_name" : "tf_efficientnet_b0",
    "model_name" : "tf_efficientnet_b6",
    "inp_channels" : SURFACE_NUM,
    "out_channels" : 1,
    "pretrained" : True,
    "out_indices" : [0,1,2,3,4],
 
    # data   
    "img_size": IMG_SIZE,
    # "batch_size": 32,
    #"batch_size": 16,#batch normの関係か？16の方が64より安定してそう？？
    "batch_size": 8,
    "INPUT_DIR": INPUT_DIR,
    "TRAIN_DIR": TRAIN_DIR,
    "TEST_DIR": TEST_DIR,
    "surface_num": SURFACE_NUM,
    "surface_list": SURFACE_LIST,
    "slide_pos_list": SLIDE_POS_LIST,
#     "surface_start_idx": START_SURFACE,
    # "TRAIN_DIR_LIST": [["1", "2"], ["1", "3"], ["2", "3"]],
    "TRAIN_DIR_LIST": [["1", "2_0", "2_1", "2_2"], 
                       ["1", "2_0", "2_1", "3"],
                       ["1", "2_0",  "2_2", "3"],
                       ["1", "2_1", "2_2", "3"],
                       ["2_0", "2_1", "2_2", "3"],
                       ],
#     "TRAIN_IDX_LIST" : ["1"],
    # "VALID_DIR_LIST": [["3"],["2"],["1"]],
    "VALID_DIR_LIST": [["3"], ["2_2"], ["2_1"], ["2_0"],["1"]],
    "TEST_DIR_LIST": ["a", "b"],

    # learning
    "n_epoch" : 10,
    "lr" : 1e-3,
    "T_max" : 5,
    "min_lr" : 1e-8,
    "weight_decay" : 1e-6,

    # etc
    "print_freq" : 1000,
    "random_seed" : 21,
    "num_workers": 2,
}


if CFG["model_name"]=="tf_efficientnet_b0":
    CFG["channel_nums"] = [320, 112, 40, 24, 16]
elif CFG["model_name"]=="tf_efficientnet_b4":
    CFG["channel_nums"] = [448, 160, 56, 32, 24]
elif CFG["model_name"]=="tf_efficientnet_b6":
    CFG["channel_nums"] = [576, 200, 72, 40, 32]


if CFG["DEBUG"]:
    CFG["n_epoch"] = 1
    CFG["EXP_NAME"] = "DEBUG"
    

CFG["OUTPUT_DIR"] = os.path.join(BASE_DIR, "output", CFG["EXP_NAME"])
# Out:
# 4
# [range(26, 36, 3), range(27, 37, 3), range(25, 35, 3)]
# SLIDE_POS_LIST = [[0, 0], [256, 0], [0, 256], [256, 256]]

# %%
if not CFG["DEBUG"]:
    os.makedirs(CFG["OUTPUT_DIR"])
    os.makedirs(os.path.join(CFG["OUTPUT_DIR"], "imgs"))

# %%
if not CFG["DEBUG"]:
    WANDB_CONFIG = {'competition': 'vcid', '_wandb_kernel': 'taro'}
    os.environ["WANDB_SILENT"] = "true"
    wandb.init(project=WANDB_CONFIG["competition"], config=CFG, group=CFG["EXP_CATEGORY"], name=CFG["EXP_NAME"], reinit=True)
# Out:
# 2023-04-17 11:58:43.148191: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-17 11:58:43.232056: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-17 11:58:43.853668: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-17 11:58:43.853754: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-17 11:58:43.853761: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# # utils

# %%
def logging_metrics_epoch(CFG, fold, epoch, slice_idx,train_loss_avg, valid_loss_avg, score, threshold, auc_score):
    wandb.log({f"train/fold{fold}": train_loss_avg,
                f"valid/fold{fold}": valid_loss_avg,
                f"score/fold{fold}":score,
                f"score threshold/fold{fold}":threshold,
                f"auc/fold{fold}":auc_score,
                f"epoch/fold{fold}":epoch+slice_idx*CFG["n_epoch"],
                })

#     wandb.log({f"train/fold{fold}": train_loss_avg,
#             f"valid/fold{fold}": valid_loss_avg}, step=epoch+slice_idx*CFG["n_epoch"])
#     wandb.log({f"score/fold{fold}":score,
#                 f"score threshold/fold{fold}":threshold,
#                 f"auc/fold{fold}":auc_score,
#                 }, step=epoch+slice_idx*CFG["n_epoch"])

    # wandb.log({"loss avg":{f"train/fold{fold}": train_loss_avg,
    #                         f"valid/fold{fold}": valid_loss_avg}}, step=epoch+slice_idx*CFG["n_epoch"])
    # wandb.log({"Metircs" : {f"score/fold{fold}":score,
    #                         f"score threshold/fold{fold}":threshold,
    #                         f"auc/fold{fold}":auc_score,
    #                         }}, step=epoch+slice_idx*CFG["n_epoch"])

# %%
def seed_everything(seed=CFG["random_seed"]):
    #os.environ['PYTHONSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic =True
    torch.backends.cudnn.benchmark = False
seed_everything()

# device optimization
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
def asMinutes(s):
    """Convert Seconds to Minutes."""
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    """Accessing and Converting Time Data."""
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))

class AverageMeter(object):
    """Computes and stores the average and current value."""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# # metric

# %%
def fbeta_numpy(targets, preds, beta=0.5, smooth=1e-5):
    y_true_count = targets.sum()
    ctp = preds[targets==1].sum()
    cfp = preds[targets==0].sum()
    beta_squared = beta * beta

    c_precision = ctp / (ctp + cfp + smooth)
    c_recall = ctp / (y_true_count + smooth)
    dice = (1 + beta_squared) * (c_precision * c_recall) / (beta_squared * c_precision + c_recall + smooth)

    return dice

def calc_fbeta_auc(mask, mask_pred):
    mask = mask.astype(int).flatten()
    mask_pred = mask_pred.flatten()

    best_th = 0
    best_dice = 0
    dice_list = [] 
    # for th in np.array(range(10, 50+1, 5)) / 100:
    for th in np.array(range(10, 100+1, 5)) / 100:
        # dice = fbeta_score(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice = fbeta_numpy(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice_list.append(dice)
        # print(f'\t th: {th}, fbeta: {dice}')
        if dice > best_dice:
            best_dice = dice
            best_th = th
    
    auc = roc_auc_score(mask, mask_pred)
    # Logger.info(f'best_th: {best_th}, fbeta: {best_dice}')
    return best_dice, best_th, auc, dice_list


def calc_cv(mask_gt, mask_pred):
    best_dice, best_th, auc, dice_list = calc_fbeta_auc(mask_gt, mask_pred)

    return best_dice, best_th, auc, dice_list

# %% [markdown]
# # model

# %%
class Encoder(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = timm.create_model(CFG["model_name"], in_chans=CFG["inp_channels"], features_only=True, out_indices=CFG["out_indices"], pretrained=CFG["pretrained"])
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        return skip_connection_list

class UpConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.bn1 = nn.BatchNorm2d(in_channels)
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size = 2, padding="same")
        self.bn2 = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        x = self.up(x)
        x = self.bn1(x)
        x = self.conv(x)
        x = self.bn2(x)
        return x


class Decoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.UpConv_0 = UpConv(CFG["channel_nums"][0], CFG["channel_nums"][1])
        self.UpConv_1 = UpConv(CFG["channel_nums"][1]*2, CFG["channel_nums"][2])
        self.UpConv_2 = UpConv(CFG["channel_nums"][2]*2, CFG["channel_nums"][3])
        self.UpConv_3 = UpConv(CFG["channel_nums"][3]*2, CFG["channel_nums"][4])
        self.UpConv_4 = UpConv(CFG["channel_nums"][4]*2, CFG["channel_nums"][4])
    
    def forward(self, skip_connection_list):
        emb = self.UpConv_0(skip_connection_list[4]) # emb.shape = (None, 160, 14, 14)
        emb_cat = torch.cat([skip_connection_list[3], emb], dim = 1)
        
        emb = self.UpConv_1(emb_cat)
        emb_cat = torch.cat([skip_connection_list[2], emb], dim = 1)
        
        emb = self.UpConv_2(emb_cat)
        emb_cat = torch.cat([skip_connection_list[1], emb], dim = 1)
        
        emb = self.UpConv_3(emb_cat)
        emb_cat = torch.cat([skip_connection_list[0], emb], dim = 1)

        emb_cat = self.UpConv_4(emb_cat)
        
        return emb_cat

class SegModel(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = Encoder(CFG)
        self.decoder = Decoder()
        self.head = nn.Sequential(
            nn.Conv2d(CFG["channel_nums"][-1], CFG["out_channels"], kernel_size=1, stride=1, padding=0),
            nn.Sigmoid()
        )
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        emb = self.decoder(skip_connection_list)
        output = self.head(emb)
        return output

# %% [markdown]
# # Dataset

# %%
train_transforms = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.RandomCrop(int(CFG["img_size"][0]*0.8), int(CFG["img_size"][1]*0.8), p=0.5),
    A.Blur(blur_limit=3, p=0.3),
    A.Resize(CFG["img_size"][0], CFG["img_size"][1]),
    ToTensorV2(),
])

valid_transforms = A.Compose([
    ToTensorV2(),
])

# %%
def fft_transform(img):
    eps = 1e-7
    f = np.fft.fft2(img)
    fshift = np.fft.fftshift(f)
    fshift = np.nan_to_num(fshift)+eps#nanを0埋め
    magnitude_spectrum = 20*np.log(np.abs(fshift))
    return magnitude_spectrum

def highpass_filter(img):
    frange = 1
    dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
    dft_shift = np.fft.fftshift(dft)

    rows, cols = img.shape
    crow,ccol = rows//2 , cols//2

    # create a mask first, center square is 1, remaining all zeros
    mask = np.ones((rows,cols,2),np.uint8)
    mask[crow-frange:crow+frange, ccol-frange:ccol+frange] = 0

    # apply mask and inverse DFT
    fshift = dft_shift*mask
    f_ishift = np.fft.ifftshift(fshift)
    img_back = cv2.idft(f_ishift)
    img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

    return img_back

def lowpass_filter(img):
    frange = 5
    dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
    dft_shift = np.fft.fftshift(dft)

    rows, cols = img.shape
    crow,ccol = rows//2 , cols//2

    # create a mask first, center square is 1, remaining all zeros
    mask = np.zeros((rows,cols,2),np.uint8)
    mask[crow-frange:crow+frange, ccol-frange:ccol+frange] = 1

    # apply mask and inverse DFT
    fshift = dft_shift*mask
    f_ishift = np.fft.ifftshift(fshift)
    img_back = cv2.idft(f_ishift)
    img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

    return img_back

# %%
class VCID_Dataset(Dataset):
    def __init__(self, CFG, data_dir_list, surface_list, surface_volumes=None, slide_pos=[0,0], mode="train", transform=None):
        # get config
        self.mode = mode
        self.img_size = CFG["img_size"]
        if self.mode=="train":  self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode=="valid":    self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode == "test":   self.DATADIR = CFG["TEST_DIR"]
        self.data_dir_list = data_dir_list
        self.surface_list = surface_list
        self.slide_pos = slide_pos
        self.transform = transform
        
        # get imgs
        # print("initializing dataset...")
        self.imgs = []
        for data_dir in self.data_dir_list:
            img_path = os.path.join(self.DATADIR, data_dir, "mask.png")
            # print(img_path)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            img = img.reshape(img.shape[0], img.shape[1], 1) # (h, w, channel=1)
            self.imgs.append(img)
        
        # check imgs
        for img in self.imgs:
            assert img is not None, "img is None. data path is wrong"
        # get and split surface
        if surface_volumes is None:
            self.surface_vols = self.read_surfacevols()
        else:
            # print("using loaded surface_vols")
            self.surface_vols = surface_volumes
        for surface_vol in self.surface_vols:
            assert surface_vol is not None, "surface_vol is None. data path is wrong"
       
        # split grid
        self.get_all_grid()
        self.fileter_grid()
        self.get_flatten_grid()
        # print("split grid done.") 
       
        # get label imgs
        if self.mode == "train" or self.mode == "valid":
            self.labels = []
            for data_dir in self.data_dir_list:
                label_path = os.path.join(self.DATADIR, data_dir, "inklabels.png")
                assert os.path.exists(label_path), f"{label_path} is not exist."
                
                # read label
                label = cv2.imread(label_path, cv2.IMREAD_GRAYSCALE)
                # mask erosion
                kernel_size = (img.shape[0]+img.shape[1])//2//100
                kernel = np.ones((kernel_size, kernel_size), np.uint8)
                img = cv2.erode(img, kernel,iterations = 3)
                
                label = label.reshape(label.shape[0], label.shape[1], 1) # (h, w, channel=1)
                self.labels.append(label)# 画像サイズがそれぞれ違うので単純にconcatできずlist化しているs
        # print("initializing dataset done.")

    def get_surface_volumes(self):
        return self.surface_vols

    def read_surfacevols(self):
        """ read surface volume by data_dir_list and surface_list 
            Returns:surface_vuls (list): surface volume list [array(h,w,channel=surface_num), array(), ...]
        """
        surface_vols = []
        # print("reading surface volume...")
        for data_dir in self.data_dir_list:
            surface_vol_ = None
            for read_idx, surface_idx in enumerate(self.surface_list):
                # print("\r", f"reading idx : {read_idx+1}/{len(self.surface_list)}", end="")
                surface_path = os.path.join(self.DATADIR, data_dir, "surface_volume", f"{surface_idx:02}.tif")
                surface_vol = cv2.imread(surface_path, cv2.IMREAD_GRAYSCALE)
                surface_vol = surface_vol.reshape(surface_vol.shape[0], surface_vol.shape[1], 1) # (h, w, channel=1)
                if surface_vol_ is None:
                    surface_vol_ = surface_vol
                else:
                    surface_vol_ = np.concatenate([surface_vol_, surface_vol], axis=2) # (h, w, channel=surface_num)
            surface_vols.append(surface_vol_)
            # print(f"  => read surface volume done. [{data_dir}]")
        return surface_vols


    def get_grid_img(self, img, grid_idx):
        """ crop grid img from original img"""
        img_grid = img[grid_idx[0]*self.img_size[0] + self.slide_pos[0] : (grid_idx[0]+1)*self.img_size[0] + self.slide_pos[0],
                        grid_idx[1]*self.img_size[1] + self.slide_pos[1] : (grid_idx[1]+1)*self.img_size[1] + self.slide_pos[1]]
        return img_grid
    
    
    def get_masked_img(self, img, mask):
        """ multiply mask to surface_volumes """
        masked_img = None
        for channel in range(img.shape[2]):
            img_channel = img[:,:,channel].reshape(img.shape[0], img.shape[1],1)
            masked = img_channel*mask
            if masked_img is None:
                masked_img = masked.reshape(masked.shape[0], masked.shape[1], 1)
            else:
                masked = masked.reshape(masked.shape[0], masked.shape[1], 1)
                masked_img = np.concatenate([masked_img, masked], axis=2)
        return masked_img
    
    def get_grid_hpfimg(self, img, grid_idx):
        """ crop grid img from original img and hpf filter """
        img_grid = self.get_grid_img(img, grid_idx)
        img_transformed = None
        for channel in range(img_grid.shape[2]):
            img_grid_trans = highpass_filter(img_grid[:,:,channel])
            if img_transformed is None:
                img_transformed = img_grid_trans.reshape(img_grid_trans.shape[0], img_grid_trans.shape[1], 1)
            else:
                img_transformed = np.concatenate([img_transformed, img_grid_trans.reshape(img_grid_trans.shape[0], img_grid_trans.shape[1], 1)], axis=2)
        return img_transformed
    
    def get_all_grid(self):
        """ get all grid indices by img size and grid size
        """
        self.grid_indices = []
        for img in self.imgs:
            self.x_grid_size = (img.shape[0] - self.slide_pos[0]) // self.img_size[0]
            self.y_grid_size = (img.shape[1] - self.slide_pos[1]) // self.img_size[1]
            grid_img = []
            for i in range(self.x_grid_size):
                for j in range(self.y_grid_size):
                    grid_img.append([i, j])
            self.grid_indices.append(grid_img)
        return self.grid_indices
          
    def fileter_grid(self):
        """ get grid indices which mask is not 0 by all grid indices"""
        grid_indices_all = []
        for img, grid_indices in zip(self.imgs, self.grid_indices):
            grid_indices_copy = grid_indices.copy()
            for grid_idx in grid_indices:
                img_grid = self.get_grid_img(img, grid_idx)
                if img_grid.sum() == 0:
                    grid_indices_copy.remove(grid_idx)
            grid_indices_all.append(grid_indices_copy)
        self.grid_indices = grid_indices_all
        return self.grid_indices

    def get_flatten_grid(self):
        """ get flatten index list by grid indices
            Returns:flatten_grid (list): flatten index list [[img_idx, grid_idx], [img_idx, grid_idx], ...]
        """
        flatten_grid = []
        for img_idx, grid_indices in enumerate(self.grid_indices):
            for grid_idx in grid_indices:
                grid_imgidx_list = [img_idx]
                grid_imgidx_list.extend(grid_idx)
                flatten_grid.append(grid_imgidx_list)
        self.flatten_grid = flatten_grid
        return self.flatten_grid

    def __len__(self):
        return len(self.flatten_grid)

    def __getitem__(self, idx):
        # get indices
        img_grid_idx = self.flatten_grid[idx]
        img_idx = img_grid_idx[0]
        grid_idx = img_grid_idx[1:]
        # get img & surface_vol
        img = self.imgs[img_idx]
        surface_vol = self.surface_vols[img_idx]
        img = self.get_grid_img(img, grid_idx)/255.
        surface_vol = self.get_grid_img(surface_vol, grid_idx)/255.
        
        # multiple small mask 
        surface_vol = self.get_masked_img(surface_vol, img)
        assert surface_vol.shape[0]==img.shape[0] and surface_vol.shape[1]==img.shape[1] , "surface_vol_list shape is not same as img shape"
        img = surface_vol

        # transform
        if self.mode == "test":
            if self.transform:
                img = self.transform(image=img)["image"]
            else:
                img = img.transpose(2, 0, 1)
                img = torch.tensor(img, dtype=torch.float32)
            return img, grid_idx
        elif self.mode == "train" or self.mode=="valid":
            # get label(segmentation mask)
            label = self.labels[img_idx]
            label = self.get_grid_img(label, grid_idx)
            if self.transform:
                transformed = self.transform(image=img, mask=label)
                img = transformed["image"]
                label = transformed["mask"]
                label = label.permute(2, 0, 1)/255. # (channel, h, w)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            else:
                img = img.transpose(2, 0, 1) # (channel, h, w)
                label = label.transpose(2, 0, 1)/255. # (channel, h, w){}
                img = torch.tensor(img, dtype=torch.float32)
                label = torch.tensor(label, dtype=torch.float32)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            return img, label, grid_idx

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train")
# surface_volumes = dataset_notrans.surface_vols
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 1:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos=[0,50],mode="train")
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 1:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train", transform=train_transforms)
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)


# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 0:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %% [markdown]
# # train valid fn

# %%
def train_fn(train_loader, model, criterion, epoch ,optimizer, scheduler):
    model.train()
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, _) in enumerate(train_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()     
        preds = model(images)
        
        # preds = torch.sigmoid(preds)
        loss = criterion(preds, targets)
        
        losses.update(loss.item(), CFG["batch_size"]) 
        targets = targets.detach().cpu().numpy().ravel().tolist()
        preds = preds.detach().cpu().numpy().ravel().tolist()
        loss.backward() # パラメータの勾配を計算
        optimizer.step() # モデル更新
        optimizer.zero_grad() # 勾配の初期化
                
        batch_time.update(time.time() - end)
        end = time.time()
        if batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(train_loader)-1):
            print('Epoch: [{0}][{1}/{2}] '
                    'Elapsed {remain:s} '
                    'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                    .format(
                        epoch, batch_idx, len(train_loader), batch_time=batch_time, loss=losses,
                        remain=timeSince(start, float(batch_idx+1)/len(train_loader)),
            ))
        del preds, images, targets
    gc.collect()
    torch.cuda.empty_cache()
    return losses.avg

# %%
def valid_fn(model, valid_loader, criterion=None):
    model.eval()# モデルを検証モードに設定
    test_targets = []
    test_preds = []
    test_grid_idx = []
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, grid_idx) in enumerate(valid_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()
        with torch.no_grad():
            preds = model(images)
            if not criterion is None:
                loss = criterion(preds, targets)
        if not criterion is None:
            losses.update(loss.item(), CFG["batch_size"])
        batch_time.update(time.time() - end)

        targets = targets.detach().cpu().numpy()
        preds = preds.detach().cpu().numpy()
        
        test_preds.extend([preds[idx, :,:,:].transpose(1,2,0) for idx in range(preds.shape[0])])
        test_targets.extend([targets[idx, :,:,:].transpose(1,2,0) for idx in range(targets.shape[0])])
        test_grid_idx.extend([[x_idx, y_idx] for x_idx, y_idx in zip(grid_idx[0].tolist(), grid_idx[1].tolist())])

        if (batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(valid_loader)-1)) and (not criterion is None):
            print('EVAL: [{0}/{1}] '
                'Elapsed {remain:s} '
                'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                .format(
                    batch_idx, len(valid_loader), batch_time=batch_time, loss=losses,
                    remain=timeSince(start, float(batch_idx+1)/len(valid_loader)),
                ))
        del preds, images, targets
        gc.collect()
        torch.cuda.empty_cache()
    if criterion is None:
        return test_targets, test_preds, test_grid_idx
    else:
        return test_targets, test_preds, test_grid_idx, losses.avg

# %% [markdown]
# # training loop

# %%
# def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list):
#     # concat pred img and label to original size
#     img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
#     img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
#     img = img.reshape(img.shape[0], img.shape[1], 1)
#     pred_img = np.zeros_like(img).astype(np.float32)
#     label_img = np.zeros_like(img).astype(np.float32)
#     for img_idx, grid_idx in enumerate(grid_idx_list):
#         pred_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += img_list[img_idx]
        
#         label_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += label_list[img_idx]
#     return pred_img, label_img

# %%
def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list, slide_pos=[0,0]):
    # concat pred img and label to original size
    img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    img = img.reshape(img.shape[0], img.shape[1], 1)
    pred_img = np.zeros_like(img).astype(np.float32)
    label_img = np.zeros_like(img).astype(np.float32)
    for img_idx, grid_idx in enumerate(grid_idx_list):
        pred_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += img_list[img_idx]
        
        label_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += label_list[img_idx]
    return pred_img, label_img

# %%
def save_and_plot_oof(mode, fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary):
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_pred_img.png"), valid_preds_img*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_predbin_img.png"), valid_preds_binary*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_targets_img.png"), valid_targets_img*255)
    
    # plot preds & binary preds
    # plt.figure(dpi=100)
    # plt.subplot(1,3,1)
    # plt.imshow(valid_preds_img)
    # plt.subplot(1,3,2)
    # plt.imshow(valid_preds_binary)
    # plt.subplot(1,3,3)
    # plt.imshow(valid_targets_img)
    # plt.show()

# %%
def training_loop(CFG):
    best_score_list = []
    best_threshold_list = []
    best_epoch_list = []
    slice_ave_score_list = []
    slice_ave_auc_list = []
    slice_ave_score_threshold_list = []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} training start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        model = model.to(device)
        valid_img_slice = []
        criterion = nn.BCELoss()
        optimizer = AdamW(model.parameters(), lr=CFG["lr"], weight_decay=CFG["weight_decay"], amsgrad=False)
        # scheduler = CosineAnnealingLR(optimizer, T_max=CFG["T_max"], eta_min=CFG["min_lr"], last_epoch=-1)
        scheduler = ExponentialLR(optimizer, gamma=0.60)
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            # separate train/valid data 
            train_dirs = CFG["TRAIN_DIR_LIST"][fold]
            valid_dirs = CFG["VALID_DIR_LIST"][fold]
            train_dataset = VCID_Dataset(CFG, train_dirs, surface_list, mode="train", transform=train_transforms)
            valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, mode="valid", transform=valid_transforms)
            train_loader = DataLoader(train_dataset, batch_size=CFG["batch_size"], shuffle = True,
                                        num_workers = CFG["num_workers"], pin_memory = True)
            valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                        num_workers = CFG["num_workers"], pin_memory = True)

            # training
            best_score = -np.inf
            best_auc = -np.inf
            best_valloss = np.inf
            best_auc_valloss = np.inf
            best_threshold = -1
            start_time = time.time()
            best_epoch = -1
            best_auc_epoch = -1
            for epoch in range(1, CFG["n_epoch"] + 1):
                epochs_ = epoch + CFG["n_epoch"] * slice_idx
                print(f'- epoch:{epochs_} -')
                train_loss_avg = train_fn(train_loader, model, criterion, epochs_ ,optimizer, scheduler)
                valid_targets, valid_preds, valid_grid_idx, valid_loss_avg = valid_fn(model, valid_loader, criterion)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                
                elapsed = time.time() - start_time
                print(f"\t epoch:{epochs_}, avg train loss:{train_loss_avg:.4f}, avg valid loss:{valid_loss_avg:.4f}")
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                if not CFG["DEBUG"]:
                    logging_metrics_epoch(CFG, fold, epoch, slice_idx, train_loss_avg, valid_loss_avg, valid_score, valid_threshold, auc)
                scheduler.step()
                # validationスコアがbestを更新したらモデルを保存する
                if valid_score > best_score:
                    best_epoch = epochs_
                    best_valloss = valid_loss_avg
                    best_score = valid_score
                    best_threshold = valid_threshold
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epochs_} - Save Best Score: {best_score:.4f}. Model is saved.')
                    print("dice_list: ", dice_list)
                    # save oof
                    save_and_plot_oof("score", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
                
                if auc > best_auc:
                    best_auc = auc
                    best_auc_epoch = epochs_
                    best_auc_valloss = valid_loss_avg
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_auc_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epochs_} - Save Best AUC: {best_auc:.4f}. Model is saved.')
                    # save oof
                    save_and_plot_oof("auc", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
            valid_img_slice.append(valid_preds_img)
        valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        for idx in range(len(SURFACE_LIST)):
            valid_pred_slice = valid_img_slice[idx]
            valid_slice_ave += valid_pred_slice
        valid_slice_ave /= len(CFG["folds"])
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_slice_ave)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)
 
        valid_slice_binary = (valid_slice_ave > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 999, valid_slice_ave, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
        
        print(f'[fold{fold}] BEST Epoch {best_epoch} - Save Best Score:{best_score:.4f}. Best loss:{best_valloss:.4f}')
        print(f'[fold{fold}] BEST AUC Epoch {best_auc_epoch} - Save Best Score:{best_auc:.4f}. Best loss:{best_auc_valloss:.4f}')
            
        best_score_list.append(best_score)
        best_threshold_list.append(best_threshold)
        best_epoch_list.append(best_epoch)
        del model, train_loader, train_dataset, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
        
    for fold, (best_score, best_threshold, best_epoch) in enumerate(zip(best_score_list, best_threshold_list, best_epoch_list)):
        print(f"fold[{fold}] BEST SCORE = {best_score:.4f} thr={best_threshold} (epoch={best_epoch})")
        print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    return best_score_list, best_threshold_list, best_epoch_list

# %% [markdown]
# # slice inference

# %%
def slide_inference(CFG):
    start_time = time.time()
    slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list = [], [], []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} slide inference start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        # model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_fold{fold}.pth')
        model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_auc_fold{fold}.pth')
        model.load_state_dict(torch.load(model_path))
        model = model.to(device)
        valid_img_slice = []
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            surface_volumes = None
            for slide_pos in CFG["slide_pos_list"]:
                print("slide pos:", slide_pos)
                valid_dirs = CFG["VALID_DIR_LIST"][fold]
                valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos, mode="valid", transform=valid_transforms)
                surface_volumes = valid_dataset.get_surface_volumes()
                valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                            num_workers = CFG["num_workers"], pin_memory = True)

                valid_targets, valid_preds, valid_grid_idx = valid_fn(model, valid_loader)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs, slide_pos)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                save_and_plot_oof("slide", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary) 
                
                elapsed = time.time() - start_time
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                valid_img_slice.append(valid_preds_img)
            valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        for idx in range(len(SURFACE_LIST)*len(CFG["slide_pos_list"])):
            valid_pred_slice = valid_img_slice[idx]
            valid_slice_ave += valid_pred_slice
        valid_slice_ave /= len(SURFACE_LIST)*len(CFG["slide_pos_list"])
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_slice_ave)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)

        valid_slice_binary = (valid_slice_ave > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 555, valid_slice_ave, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
         
        del model, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
    return slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list

# %% [markdown]
# # main

# %%
# %%time
best_score_list, best_threshold_list, best_epoch_list = training_loop(CFG)
# Out:
# -- fold0 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/conv.py:444: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at  ../aten/src/ATen/native/Convolution.cpp:744.)
#   self.padding, self.dilation, self.groups)
# Epoch: [1][0/65] Elapsed 0m 1s (remain 1m 34s) Loss: 0.7054(0.7054)
# Epoch: [1][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.6657(0.6169)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 1.2296(1.2296)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.8486(1.7891)
# 	 epoch:1, avg train loss:0.6169, avg valid loss:1.7891
# 	 score:0.3385(th=0.950000), auc=0.852932::: time:48.41s
# Epoch 1 - Save Best Score: 0.3385. Model is saved.
# dice_list:  [0.12918853434629296, 0.12946535667829934, 0.13364681149960894, 0.16583389653445632, 0.18874953529538746, 0.214449794698088, 0.2384512300247164, 0.25813051436668094, 0.2720464355157901, 0.28194345556501743, 0.2896798713588806, 0.2965105248978965, 0.3030747542219419, 0.30843446227147986, 0.3145322098265082, 0.32085736584564817, 0.328025240486605, 0.33847692202513113, 0.22559548432380006]
# Epoch 1 - Save Best AUC: 0.8529. Model is saved.
# - epoch:2 -
# Epoch: [2][0/65] Elapsed 0m 1s (remain 1m 29s) Loss: 0.5883(0.5883)
# Epoch: [2][64/65] Elapsed 0m 32s (remain 0m 0s) Loss: 0.4698(0.5359)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.3668(0.3668)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4164(0.4320)
# 	 epoch:2, avg train loss:0.5359, avg valid loss:0.4320
# 	 score:0.4918(th=0.500000), auc=0.872211::: time:99.35s
# Epoch 2 - Save Best Score: 0.4918. Model is saved.
# dice_list:  [0.12918066013253424, 0.12918073299783114, 0.12921690576259046, 0.15206213517370828, 0.21310811722371886, 0.3154048345160109, 0.40980209174032856, 0.4691277531314448, 0.4918075896378509, 0.4911856460939415, 0.47683284869566506, 0.45113220179478053, 0.41749224639040455, 0.3767117785378303, 0.3346454373341304, 0.2947055605998738, 0.2485614675809077, 0.16951264863146764, 0.0]
# Epoch 2 - Save Best AUC: 0.8722. Model is saved.
# - epoch:3 -
# Epoch: [3][0/65] Elapsed 0m 1s (remain 1m 29s) Loss: 0.4785(0.4785)
# Epoch: [3][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.5008(0.4760)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.3290(0.3290)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3666(0.4015)
# 	 epoch:3, avg train loss:0.4760, avg valid loss:0.4015
# 	 score:0.5112(th=0.550000), auc=0.877258::: time:149.76s
# Epoch 3 - Save Best Score: 0.5112. Model is saved.
# dice_list:  [0.12918084015282882, 0.12925442162964645, 0.14914113136124663, 0.20385466131903876, 0.2914867814445144, 0.3779636799437058, 0.44136434345746633, 0.4818923483209608, 0.5033098631891205, 0.5111967245792022, 0.5080599568353776, 0.49829293022511834, 0.4889508006625273, 0.4758601503089373, 0.45860323232409245, 0.4353471003877175, 0.4097035829107173, 0.36679807794216673, 0.0]
# Epoch 3 - Save Best AUC: 0.8773. Model is saved.
# - epoch:4 -
# Epoch: [4][0/65] Elapsed 0m 1s (remain 1m 29s) Loss: 0.4672(0.4672)
# Epoch: [4][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.3321(0.4306)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2762(0.2762)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3110(0.3517)
# 	 epoch:4, avg train loss:0.4306, avg valid loss:0.3517
# 	 score:0.5271(th=0.600000), auc=0.880220::: time:199.91s
# Epoch 4 - Save Best Score: 0.5271. Model is saved.
# dice_list:  [0.12920376162658728, 0.15509581703467026, 0.20515371904690943, 0.2858159828762385, 0.3651969553102856, 0.43447222729433455, 0.47819951210400014, 0.5065453821901794, 0.5201048012688501, 0.5259354270860043, 0.5270519918434173, 0.525582326442806, 0.519783144193648, 0.5092105479435621, 0.49684080338093517, 0.47510796407862815, 0.4457148141450098, 0.40114218323304984, 0.0]
# Epoch 4 - Save Best AUC: 0.8802. Model is saved.
# - epoch:5 -
# Epoch: [5][0/65] Elapsed 0m 1s (remain 1m 33s) Loss: 0.5193(0.5193)
# Epoch: [5][64/65] Elapsed 0m 32s (remain 0m 0s) Loss: 0.6114(0.4108)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.3009(0.3009)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3108(0.3591)
# 	 epoch:5, avg train loss:0.4108, avg valid loss:0.3591
# 	 score:0.5346(th=0.700000), auc=0.873896::: time:251.03s
# Epoch 5 - Save Best Score: 0.5346. Model is saved.
# dice_list:  [0.1292734555919863, 0.15754929907434362, 0.205756774177822, 0.27326588501817417, 0.3380032312707026, 0.39189632099673594, 0.4341269187429337, 0.46723535869097044, 0.49760870888586634, 0.5180406483297686, 0.5299130777027362, 0.5341793068349647, 0.5346367095380458, 0.5266707048259432, 0.5115074739026378, 0.48960686620048394, 0.45973910042778715, 0.41316844793569757, 0.0016063646213254359]
# - epoch:6 -
# Epoch: [6][0/65] Elapsed 0m 1s (remain 1m 32s) Loss: 0.4139(0.4139)
# Epoch: [6][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.5560(0.3955)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.3551(0.3551)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3598(0.4310)
# 	 epoch:6, avg train loss:0.3955, avg valid loss:0.4310
# 	 score:0.5423(th=0.850000), auc=0.876140::: time:299.60s
# Epoch 6 - Save Best Score: 0.5423. Model is saved.
# dice_list:  [0.1292618257657771, 0.13595174827638942, 0.1957327221138419, 0.24538858804981678, 0.2929292267165824, 0.33061111482065203, 0.36059726258517094, 0.38625448084100256, 0.4108364789324746, 0.4368501445964411, 0.4648002891853605, 0.4920782571052296, 0.5114978141080081, 0.5263519777051672, 0.5360171775275224, 0.542274789320399, 0.5348215962258195, 0.5097857760641232, 0.06797169845025985]
# - epoch:7 -
# Epoch: [7][0/65] Elapsed 0m 1s (remain 1m 36s) Loss: 0.3846(0.3846)
# Epoch: [7][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.7531(0.3817)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.3040(0.3040)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3204(0.3625)
# 	 epoch:7, avg train loss:0.3817, avg valid loss:0.3625
# 	 score:0.5329(th=0.750000), auc=0.877161::: time:348.26s
# - epoch:8 -
# Epoch: [8][0/65] Elapsed 0m 1s (remain 1m 33s) Loss: 0.3167(0.3167)
# Epoch: [8][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.6776(0.3744)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2894(0.2894)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3098(0.3549)
# 	 epoch:8, avg train loss:0.3744, avg valid loss:0.3549
# 	 score:0.5312(th=0.800000), auc=0.879731::: time:395.14s
# - epoch:9 -
# Epoch: [9][0/65] Elapsed 0m 1s (remain 1m 31s) Loss: 0.4471(0.4471)
# Epoch: [9][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.4837(0.3776)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2973(0.2973)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3086(0.3559)
# 	 epoch:9, avg train loss:0.3776, avg valid loss:0.3559
# 	 score:0.5326(th=0.750000), auc=0.878929::: time:442.33s
# - epoch:10 -
# Epoch: [10][0/65] Elapsed 0m 1s (remain 1m 28s) Loss: 0.3457(0.3457)
# Epoch: [10][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.5650(0.3644)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2983(0.2983)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3078(0.3571)
# 	 epoch:10, avg train loss:0.3644, avg valid loss:0.3571
# 	 score:0.5350(th=0.750000), auc=0.879898::: time:489.19s
# surface_list:  range(27, 37, 3)
# - epoch:11 -
# Epoch: [11][0/65] Elapsed 0m 1s (remain 1m 25s) Loss: 0.3836(0.3836)
# Epoch: [11][64/65] Elapsed 0m 30s (remain 0m 0s) Loss: 0.4224(0.3665)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2844(0.2844)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2910(0.3378)
# 	 epoch:11, avg train loss:0.3665, avg valid loss:0.3378
# 	 score:0.5389(th=0.650000), auc=0.884058::: time:46.51s
# Epoch 11 - Save Best Score: 0.5389. Model is saved.
# dice_list:  [0.12989385239134119, 0.17119416704561494, 0.23228359097292803, 0.3009009926523919, 0.3656225372005829, 0.4158800124255076, 0.44696673673987397, 0.47241593359396344, 0.4980746196657489, 0.5188729238241355, 0.5320906191430668, 0.5388511148384683, 0.5336988592163705, 0.5141516139583368, 0.48506838047274425, 0.4474126812165923, 0.3965580756077304, 0.32047929802762654, 0.006114727647468931]
# Epoch 11 - Save Best AUC: 0.8841. Model is saved.
# - epoch:12 -
# Epoch: [12][0/65] Elapsed 0m 1s (remain 1m 35s) Loss: 0.3058(0.3058)
# Epoch: [12][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.5079(0.3678)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.3099(0.3099)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2950(0.3524)
# 	 epoch:12, avg train loss:0.3678, avg valid loss:0.3524
# 	 score:0.5253(th=0.700000), auc=0.880971::: time:95.97s
# - epoch:13 -
# Epoch: [13][0/65] Elapsed 0m 1s (remain 1m 37s) Loss: 0.3594(0.3594)
# Epoch: [13][64/65] Elapsed 0m 30s (remain 0m 0s) Loss: 0.2999(0.3621)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.3320(0.3320)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2967(0.3681)
# 	 epoch:13, avg train loss:0.3621, avg valid loss:0.3681
# 	 score:0.5309(th=0.750000), auc=0.881996::: time:142.33s
# - epoch:14 -
# Epoch: [14][0/65] Elapsed 0m 1s (remain 1m 37s) Loss: 0.3810(0.3810)
# Epoch: [14][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.5547(0.3631)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.3126(0.3126)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3007(0.3591)
# 	 epoch:14, avg train loss:0.3631, avg valid loss:0.3591
# 	 score:0.5252(th=0.750000), auc=0.880976::: time:188.88s
# - epoch:15 -
# Epoch: [15][0/65] Elapsed 0m 1s (remain 1m 33s) Loss: 0.3243(0.3243)
# Epoch: [15][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.4911(0.3638)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2861(0.2861)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2980(0.3362)
# 	 epoch:15, avg train loss:0.3638, avg valid loss:0.3362
# 	 score:0.5234(th=0.650000), auc=0.879332::: time:235.45s
# - epoch:16 -
# Epoch: [16][0/65] Elapsed 0m 1s (remain 1m 32s) Loss: 0.3592(0.3592)
# Epoch: [16][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.5467(0.3717)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.3709(0.3709)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3076(0.3964)
# 	 epoch:16, avg train loss:0.3717, avg valid loss:0.3964
# 	 score:0.5286(th=0.800000), auc=0.880105::: time:282.02s
# - epoch:17 -
# Epoch: [17][0/65] Elapsed 0m 1s (remain 1m 32s) Loss: 0.3306(0.3306)
# Epoch: [17][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.5854(0.3597)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.3391(0.3391)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3147(0.3804)
# 	 epoch:17, avg train loss:0.3597, avg valid loss:0.3804
# 	 score:0.5128(th=0.750000), auc=0.875679::: time:328.57s
# - epoch:18 -
# Epoch: [18][0/65] Elapsed 0m 1s (remain 1m 35s) Loss: 0.3779(0.3779)
# Epoch: [18][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.5810(0.3657)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2959(0.2959)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2940(0.3443)
# 	 epoch:18, avg train loss:0.3657, avg valid loss:0.3443
# 	 score:0.5344(th=0.700000), auc=0.883807::: time:375.14s
# - epoch:19 -
# Epoch: [19][0/65] Elapsed 0m 1s (remain 1m 33s) Loss: 0.3672(0.3672)
# Epoch: [19][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.2710(0.3707)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.3099(0.3099)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2996(0.3544)
# 	 epoch:19, avg train loss:0.3707, avg valid loss:0.3544
# 	 score:0.5275(th=0.700000), auc=0.880856::: time:421.92s
# - epoch:20 -
# Epoch: [20][0/65] Elapsed 0m 1s (remain 1m 33s) Loss: 0.3513(0.3513)
# Epoch: [20][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.5824(0.3654)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.3449(0.3449)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3012(0.3742)
# 	 epoch:20, avg train loss:0.3654, avg valid loss:0.3742
# 	 score:0.5259(th=0.800000), auc=0.880491::: time:468.56s
# surface_list:  range(25, 35, 3)
# - epoch:21 -
# Epoch: [21][0/65] Elapsed 0m 1s (remain 1m 34s) Loss: 0.3426(0.3426)
# Epoch: [21][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.5634(0.3717)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.3210(0.3210)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3102(0.3855)
# 	 epoch:21, avg train loss:0.3717, avg valid loss:0.3855
# 	 score:0.5346(th=0.750000), auc=0.881612::: time:46.45s
# Epoch 21 - Save Best Score: 0.5346. Model is saved.
# dice_list:  [0.12946837207225767, 0.16453915044805897, 0.2129593605134851, 0.2698888221554912, 0.3175078833133961, 0.3598393879301901, 0.3934368001461798, 0.4246477680732063, 0.45461409469961683, 0.47921998203336236, 0.4998373286451771, 0.51725012659213, 0.5292499445260919, 0.5346216033779861, 0.5323773330894171, 0.5278691470174502, 0.5199979725656378, 0.48194192237257155, 0.05321355406409452]
# Epoch 21 - Save Best AUC: 0.8816. Model is saved.
# - epoch:22 -
# Epoch: [22][0/65] Elapsed 0m 1s (remain 1m 32s) Loss: 0.3962(0.3962)
# Epoch: [22][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.5628(0.3714)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.3136(0.3136)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3193(0.3783)
# 	 epoch:22, avg train loss:0.3714, avg valid loss:0.3783
# 	 score:0.5335(th=0.750000), auc=0.880032::: time:96.28s
# - epoch:23 -
# Epoch: [23][0/65] Elapsed 0m 1s (remain 1m 33s) Loss: 0.3581(0.3581)
# Epoch: [23][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.5967(0.3738)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2753(0.2753)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3003(0.3470)
# 	 epoch:23, avg train loss:0.3738, avg valid loss:0.3470
# 	 score:0.5373(th=0.650000), auc=0.883140::: time:143.11s
# Epoch 23 - Save Best Score: 0.5373. Model is saved.
# dice_list:  [0.12995549117961386, 0.16868155122791528, 0.2291845406818256, 0.296667495939039, 0.3545540750834423, 0.39821071124518637, 0.43797082736812676, 0.47231507083615215, 0.49897736373958845, 0.5201986883091991, 0.5329021866667617, 0.5372610020709156, 0.5337470365286625, 0.5277905100590028, 0.521445976574836, 0.5040051948124107, 0.4681990981947598, 0.40427219932970665, 0.013735759598329246]
# Epoch 23 - Save Best AUC: 0.8831. Model is saved.
# - epoch:24 -
# Epoch: [24][0/65] Elapsed 0m 1s (remain 1m 33s) Loss: 0.3187(0.3187)
# Epoch: [24][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.4671(0.3684)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2537(0.2537)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2948(0.3297)
# 	 epoch:24, avg train loss:0.3684, avg valid loss:0.3297
# 	 score:0.5368(th=0.600000), auc=0.884668::: time:193.23s
# Epoch 24 - Save Best AUC: 0.8847. Model is saved.
# - epoch:25 -
# Epoch: [25][0/65] Elapsed 0m 1s (remain 1m 39s) Loss: 0.3546(0.3546)
# Epoch: [25][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.5742(0.3690)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2873(0.2873)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2992(0.3555)
# 	 epoch:25, avg train loss:0.3690, avg valid loss:0.3555
# 	 score:0.5375(th=0.700000), auc=0.879870::: time:242.04s
# Epoch 25 - Save Best Score: 0.5375. Model is saved.
# dice_list:  [0.12959147964867868, 0.16907282409298469, 0.23096107044748332, 0.29478838887823733, 0.3510054227939885, 0.39605177785011775, 0.43335481994239133, 0.46373548056895963, 0.48915586482528967, 0.5113809347452467, 0.5263811435531078, 0.5346844969461199, 0.5374885354709246, 0.5337832180815681, 0.5260915978419448, 0.5139841837802579, 0.48971631664061804, 0.4437182759190539, 0.035377598472102714]
# - epoch:26 -
# Epoch: [26][0/65] Elapsed 0m 1s (remain 1m 35s) Loss: 0.2991(0.2991)
# Epoch: [26][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.5850(0.3744)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.3048(0.3048)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3137(0.3805)
# 	 epoch:26, avg train loss:0.3744, avg valid loss:0.3805
# 	 score:0.5353(th=0.750000), auc=0.880356::: time:290.37s
# - epoch:27 -
# Epoch: [27][0/65] Elapsed 0m 1s (remain 1m 34s) Loss: 0.4234(0.4234)
# Epoch: [27][64/65] Elapsed 0m 30s (remain 0m 0s) Loss: 0.5349(0.3702)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2956(0.2956)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3055(0.3648)
# 	 epoch:27, avg train loss:0.3702, avg valid loss:0.3648
# 	 score:0.5385(th=0.700000), auc=0.881065::: time:336.67s
# Epoch 27 - Save Best Score: 0.5385. Model is saved.
# dice_list:  [0.12989969205013585, 0.16846173129260214, 0.22157968664730152, 0.28131501734998576, 0.3326224200332321, 0.3794665820213943, 0.41502071439025134, 0.447915804352834, 0.4767031898319138, 0.5020581349559403, 0.52061732573583, 0.5340810696343385, 0.5384926233637215, 0.5364512288507892, 0.5298313226200665, 0.5231193390012571, 0.5056221250449277, 0.459559911932843, 0.04512168977721215]
# - epoch:28 -
# Epoch: [28][0/65] Elapsed 0m 1s (remain 1m 29s) Loss: 0.4001(0.4001)
# Epoch: [28][64/65] Elapsed 0m 30s (remain 0m 0s) Loss: 0.3379(0.3721)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2753(0.2753)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2983(0.3464)
# 	 epoch:28, avg train loss:0.3721, avg valid loss:0.3464
# 	 score:0.5374(th=0.650000), auc=0.884031::: time:384.68s
# - epoch:29 -
# Epoch: [29][0/65] Elapsed 0m 1s (remain 1m 34s) Loss: 0.4856(0.4856)
# Epoch: [29][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.5608(0.3736)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2730(0.2730)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3020(0.3470)
# 	 epoch:29, avg train loss:0.3736, avg valid loss:0.3470
# 	 score:0.5376(th=0.650000), auc=0.883561::: time:431.19s
# - epoch:30 -
# Epoch: [30][0/65] Elapsed 0m 1s (remain 1m 37s) Loss: 0.3673(0.3673)
# Epoch: [30][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.6720(0.3709)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2901(0.2901)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3058(0.3622)
# 	 epoch:30, avg train loss:0.3709, avg valid loss:0.3622
# 	 score:0.5385(th=0.750000), auc=0.882401::: time:478.11s
# Epoch 30 - Save Best Score: 0.5385. Model is saved.
# dice_list:  [0.13179223183373376, 0.16770614918418617, 0.21940371742687512, 0.2815888557130187, 0.3355521613121638, 0.37678605512542485, 0.41199120920512966, 0.44446663533067066, 0.47301226601904034, 0.4971763115288115, 0.5189399682418517, 0.5337866960911961, 0.5383620604649461, 0.5385451082065844, 0.5336882730745366, 0.5232042442408015, 0.5036465101207848, 0.45817985840174, 0.024097439445910196]
# [fold0] slice ave score:0.5451(th=0.450000), auc=0.884126
# [fold0] BEST Epoch 30 - Save Best Score:0.5385. Best loss:0.3622
# [fold0] BEST AUC Epoch 24 - Save Best Score:0.8847. Best loss:0.3297
# -- fold1 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# Epoch: [1][0/60] Elapsed 0m 1s (remain 1m 22s) Loss: 0.7509(0.7509)
# Epoch: [1][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.6350(0.6711)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.7511(0.7511)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4414(0.7070)
# 	 epoch:1, avg train loss:0.6711, avg valid loss:0.7070
# 	 score:0.4242(th=0.850000), auc=0.782710::: time:49.85s
# Epoch 1 - Save Best Score: 0.4242. Model is saved.
# dice_list:  [0.21398986340057635, 0.21398986340057635, 0.21399357362331084, 0.2142997886921236, 0.21792676356822088, 0.2489666859909114, 0.2894729811167684, 0.3328077069559807, 0.3655571987220725, 0.38732983283458877, 0.4018824441152872, 0.4098583043056437, 0.4148851983090941, 0.4173802851561781, 0.42146348482526474, 0.42424856000698413, 0.4202659569442979, 0.3849203643778318, 0.0]
# Epoch 1 - Save Best AUC: 0.7827. Model is saved.
# - epoch:2 -
# Epoch: [2][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.5995(0.5995)
# Epoch: [2][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.5269(0.5829)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.6095(0.6095)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4397(0.6280)
# 	 epoch:2, avg train loss:0.5829, avg valid loss:0.6280
# 	 score:0.4051(th=0.650000), auc=0.776265::: time:101.92s
# - epoch:3 -
# Epoch: [3][0/60] Elapsed 0m 1s (remain 1m 23s) Loss: 0.5426(0.5426)
# Epoch: [3][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.5454(0.5141)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.6934(0.6934)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3672(0.6543)
# 	 epoch:3, avg train loss:0.5141, avg valid loss:0.6543
# 	 score:0.4651(th=0.700000), auc=0.799051::: time:150.71s
# Epoch 3 - Save Best Score: 0.4651. Model is saved.
# dice_list:  [0.21398986340057635, 0.21399090347283048, 0.21438872362339884, 0.22446629940885476, 0.2755333168492204, 0.335898838780704, 0.3819646978704108, 0.41069555375089906, 0.42951330328637805, 0.4439359952072149, 0.45437311602247826, 0.4605276864033739, 0.4651406920121017, 0.4648522990246382, 0.4617173395121504, 0.45470935119924977, 0.4463516961382176, 0.42877508816873083, 0.10731927239231816]
# Epoch 3 - Save Best AUC: 0.7991. Model is saved.
# - epoch:4 -
# Epoch: [4][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.5722(0.5722)
# Epoch: [4][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.5094(0.4661)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5837(0.5837)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2897(0.5439)
# 	 epoch:4, avg train loss:0.4661, avg valid loss:0.5439
# 	 score:0.4982(th=0.650000), auc=0.815538::: time:203.23s
# Epoch 4 - Save Best Score: 0.4982. Model is saved.
# dice_list:  [0.21399122024811446, 0.21420147931636752, 0.223037382648498, 0.27450710630070235, 0.3331539353170836, 0.38716985106937957, 0.43053615454602245, 0.4573475764877043, 0.4738129864941866, 0.4867128293009425, 0.49454390524333447, 0.49817002670707033, 0.4974277764506236, 0.49191775522692177, 0.4825398581104526, 0.46937118719200766, 0.44719069116169513, 0.41961671593661903, 0.14114121679685734]
# Epoch 4 - Save Best AUC: 0.8155. Model is saved.
# - epoch:5 -
# Epoch: [5][0/60] Elapsed 0m 1s (remain 1m 25s) Loss: 0.4177(0.4177)
# Epoch: [5][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3890(0.4340)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4797(0.4797)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2791(0.4958)
# 	 epoch:5, avg train loss:0.4340, avg valid loss:0.4958
# 	 score:0.5061(th=0.650000), auc=0.822944::: time:255.90s
# Epoch 5 - Save Best Score: 0.5061. Model is saved.
# dice_list:  [0.21399072924682408, 0.214256268795002, 0.23410601690971122, 0.2805140699895963, 0.3368922135946245, 0.38646159053417684, 0.4284116362183614, 0.46066006666789183, 0.48181599242007644, 0.49513538348253733, 0.5028795268197981, 0.5060691539650687, 0.5042103571908347, 0.497683723731562, 0.48304308275584246, 0.45977244050397104, 0.42812656470696925, 0.38463588726383396, 0.06014965864257689]
# Epoch 5 - Save Best AUC: 0.8229. Model is saved.
# - epoch:6 -
# Epoch: [6][0/60] Elapsed 0m 1s (remain 1m 26s) Loss: 0.5471(0.5471)
# Epoch: [6][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.5889(0.4245)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4939(0.4939)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2587(0.5012)
# 	 epoch:6, avg train loss:0.4245, avg valid loss:0.5012
# 	 score:0.5400(th=0.750000), auc=0.833211::: time:308.49s
# Epoch 6 - Save Best Score: 0.5400. Model is saved.
# dice_list:  [0.2139954281687746, 0.2168383833808425, 0.25410367473401607, 0.30868613170645526, 0.3636406681790938, 0.40707704905560593, 0.4414454613148265, 0.46699764861563586, 0.48737384767163267, 0.5037655322323417, 0.5168461535229858, 0.5278140747924419, 0.5364821133391475, 0.5399860243637923, 0.5348882674574018, 0.518953251766512, 0.49691919688261454, 0.45729544896968916, 0.1290749730393329]
# Epoch 6 - Save Best AUC: 0.8332. Model is saved.
# - epoch:7 -
# Epoch: [7][0/60] Elapsed 0m 1s (remain 1m 29s) Loss: 0.3557(0.3557)
# Epoch: [7][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3900(0.4045)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4579(0.4579)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2353(0.4608)
# 	 epoch:7, avg train loss:0.4045, avg valid loss:0.4608
# 	 score:0.5363(th=0.650000), auc=0.833986::: time:361.30s
# Epoch 7 - Save Best AUC: 0.8340. Model is saved.
# - epoch:8 -
# Epoch: [8][0/60] Elapsed 0m 1s (remain 1m 31s) Loss: 0.3516(0.3516)
# Epoch: [8][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.8707(0.4009)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.4529(0.4529)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2200(0.4563)
# 	 epoch:8, avg train loss:0.4009, avg valid loss:0.4563
# 	 score:0.5354(th=0.650000), auc=0.827601::: time:411.90s
# - epoch:9 -
# Epoch: [9][0/60] Elapsed 0m 1s (remain 1m 33s) Loss: 0.5221(0.5221)
# Epoch: [9][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3818(0.3932)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4567(0.4567)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2227(0.4572)
# 	 epoch:9, avg train loss:0.3932, avg valid loss:0.4572
# 	 score:0.5548(th=0.650000), auc=0.835233::: time:460.63s
# Epoch 9 - Save Best Score: 0.5548. Model is saved.
# dice_list:  [0.2140857178289554, 0.2271153383209365, 0.2887038354917757, 0.3549371140782103, 0.41083074298220285, 0.455704675935405, 0.4906750235794759, 0.5150577905693556, 0.53279329831976, 0.5454522358467466, 0.5534872102686706, 0.5547857453445351, 0.5479214142670851, 0.5375046015780784, 0.5217342469204873, 0.5010951986701343, 0.47564485991896094, 0.435634635558148, 0.12948172153848536]
# Epoch 9 - Save Best AUC: 0.8352. Model is saved.
# - epoch:10 -
# Epoch: [10][0/60] Elapsed 0m 1s (remain 1m 23s) Loss: 0.3616(0.3616)
# Epoch: [10][59/60] Elapsed 0m 28s (remain 0m 0s) Loss: 0.5058(0.3915)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.4551(0.4551)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2287(0.4585)
# 	 epoch:10, avg train loss:0.3915, avg valid loss:0.4585
# 	 score:0.5506(th=0.650000), auc=0.834366::: time:512.71s
# surface_list:  range(27, 37, 3)
# - epoch:11 -
# Epoch: [11][0/60] Elapsed 0m 1s (remain 1m 22s) Loss: 0.3831(0.3831)
# Epoch: [11][59/60] Elapsed 0m 28s (remain 0m 0s) Loss: 0.4667(0.4008)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4923(0.4923)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2276(0.4882)
# 	 epoch:11, avg train loss:0.4008, avg valid loss:0.4882
# 	 score:0.5322(th=0.800000), auc=0.830828::: time:48.61s
# Epoch 11 - Save Best Score: 0.5322. Model is saved.
# dice_list:  [0.21412485452677926, 0.22943272509817764, 0.28543296238466986, 0.3393029676389461, 0.38870837699621225, 0.4279812583056835, 0.4571829988391556, 0.4762687259124331, 0.49084082768718496, 0.5025805723019802, 0.5112971098204315, 0.5196705031298823, 0.5266799871351832, 0.5311675278958858, 0.5321872109091154, 0.5271340684947384, 0.5137843224654272, 0.48260481747421785, 0.16973739372346977]
# Epoch 11 - Save Best AUC: 0.8308. Model is saved.
# - epoch:12 -
# Epoch: [12][0/60] Elapsed 0m 1s (remain 1m 31s) Loss: 0.3679(0.3679)
# Epoch: [12][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.4095(0.4098)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5074(0.5074)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2253(0.5058)
# 	 epoch:12, avg train loss:0.4098, avg valid loss:0.5058
# 	 score:0.5269(th=0.800000), auc=0.829696::: time:101.16s
# - epoch:13 -
# Epoch: [13][0/60] Elapsed 0m 1s (remain 1m 27s) Loss: 0.4030(0.4030)
# Epoch: [13][59/60] Elapsed 0m 28s (remain 0m 0s) Loss: 0.9231(0.3846)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4966(0.4966)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2435(0.4961)
# 	 epoch:13, avg train loss:0.3846, avg valid loss:0.4961
# 	 score:0.5385(th=0.800000), auc=0.838907::: time:149.55s
# Epoch 13 - Save Best Score: 0.5385. Model is saved.
# dice_list:  [0.21405308444806867, 0.22319275509404118, 0.2755655360304008, 0.33166576135388764, 0.38219020587144326, 0.4235603362591573, 0.45759989445769855, 0.48260236936910006, 0.49892589979035856, 0.5115778048252199, 0.5209858554708443, 0.5288963625991027, 0.5345373529165988, 0.5383565430905162, 0.5384624643334742, 0.5350573030769482, 0.5208087832516105, 0.489092143817043, 0.1965041573406104]
# Epoch 13 - Save Best AUC: 0.8389. Model is saved.
# - epoch:14 -
# Epoch: [14][0/60] Elapsed 0m 1s (remain 1m 28s) Loss: 0.4248(0.4248)
# Epoch: [14][59/60] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3004(0.3848)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.4594(0.4594)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2339(0.4532)
# 	 epoch:14, avg train loss:0.3848, avg valid loss:0.4532
# 	 score:0.5426(th=0.700000), auc=0.837233::: time:201.44s
# Epoch 14 - Save Best Score: 0.5426. Model is saved.
# dice_list:  [0.21404111835987025, 0.22451335441095316, 0.2790531450273481, 0.33927176866159503, 0.3936417255155025, 0.43895413932380595, 0.47265994025092, 0.4954060607871194, 0.5115078011021181, 0.5242233696681208, 0.5341016819451645, 0.5397803744392472, 0.5426324001068827, 0.5402095790990205, 0.5311581156819642, 0.5130743069595028, 0.48482722602042316, 0.4340385072119271, 0.06737109327572237]
# - epoch:15 -
# Epoch: [15][0/60] Elapsed 0m 1s (remain 1m 32s) Loss: 0.3139(0.3139)
# Epoch: [15][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.2917(0.3932)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4779(0.4779)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2266(0.4740)
# 	 epoch:15, avg train loss:0.3932, avg valid loss:0.4740
# 	 score:0.5259(th=0.750000), auc=0.831110::: time:252.34s
# - epoch:16 -
# Epoch: [16][0/60] Elapsed 0m 1s (remain 1m 30s) Loss: 0.3970(0.3970)
# Epoch: [16][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3213(0.3878)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.4580(0.4580)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2186(0.4548)
# 	 epoch:16, avg train loss:0.3878, avg valid loss:0.4548
# 	 score:0.5345(th=0.700000), auc=0.831316::: time:301.00s
# - epoch:17 -
# Epoch: [17][0/60] Elapsed 0m 1s (remain 1m 30s) Loss: 0.4044(0.4044)
# Epoch: [17][59/60] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3794(0.3868)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4731(0.4731)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2281(0.4649)
# 	 epoch:17, avg train loss:0.3868, avg valid loss:0.4649
# 	 score:0.5446(th=0.700000), auc=0.839108::: time:349.67s
# Epoch 17 - Save Best Score: 0.5446. Model is saved.
# dice_list:  [0.21415373954816383, 0.22943640692262626, 0.2899761970038241, 0.3508058690308488, 0.403487577742967, 0.4458015419766061, 0.4773262368396072, 0.5008228275060574, 0.5171238532563298, 0.5278762112395587, 0.5362965967200687, 0.5420661973143913, 0.5446014560798919, 0.5435899678413288, 0.5386091093872342, 0.5277026944388378, 0.5080647082909232, 0.46904908161253606, 0.1370002213307382]
# Epoch 17 - Save Best AUC: 0.8391. Model is saved.
# - epoch:18 -
# Epoch: [18][0/60] Elapsed 0m 1s (remain 1m 23s) Loss: 0.3169(0.3169)
# Epoch: [18][59/60] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2590(0.3972)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4866(0.4866)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2259(0.4786)
# 	 epoch:18, avg train loss:0.3972, avg valid loss:0.4786
# 	 score:0.5344(th=0.750000), auc=0.832889::: time:401.86s
# - epoch:19 -
# Epoch: [19][0/60] Elapsed 0m 1s (remain 1m 22s) Loss: 0.3146(0.3146)
# Epoch: [19][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3843(0.3967)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4782(0.4782)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2225(0.4695)
# 	 epoch:19, avg train loss:0.3967, avg valid loss:0.4695
# 	 score:0.5291(th=0.750000), auc=0.833560::: time:450.51s
# - epoch:20 -
# Epoch: [20][0/60] Elapsed 0m 1s (remain 1m 36s) Loss: 0.3568(0.3568)
# Epoch: [20][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 1.0010(0.4263)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4746(0.4746)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2310(0.4707)
# 	 epoch:20, avg train loss:0.4263, avg valid loss:0.4707
# 	 score:0.5415(th=0.750000), auc=0.837391::: time:498.95s
# surface_list:  range(25, 35, 3)
# - epoch:21 -
# Epoch: [21][0/60] Elapsed 0m 1s (remain 1m 26s) Loss: 0.3672(0.3672)
# Epoch: [21][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3818(0.4068)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4681(0.4681)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2215(0.4693)
# 	 epoch:21, avg train loss:0.4068, avg valid loss:0.4693
# 	 score:0.5214(th=0.650000), auc=0.838459::: time:49.09s
# Epoch 21 - Save Best Score: 0.5214. Model is saved.
# dice_list:  [0.2141318218140037, 0.2257771621905873, 0.288162910275907, 0.35998861791800957, 0.41597244176707604, 0.4581166572918512, 0.4846743371711396, 0.5021385835514894, 0.5120076692657437, 0.5176086142145497, 0.5198153658741732, 0.5214487772740816, 0.5175431824797465, 0.506726153523685, 0.48922738313964736, 0.47255882132029076, 0.45190064678760206, 0.4157722150135029, 0.14123090074313813]
# Epoch 21 - Save Best AUC: 0.8385. Model is saved.
# - epoch:22 -
# Epoch: [22][0/60] Elapsed 0m 1s (remain 1m 21s) Loss: 0.2870(0.2870)
# Epoch: [22][59/60] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2473(0.3918)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.4702(0.4702)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2196(0.4633)
# 	 epoch:22, avg train loss:0.3918, avg valid loss:0.4633
# 	 score:0.5238(th=0.600000), auc=0.837588::: time:101.31s
# Epoch 22 - Save Best Score: 0.5238. Model is saved.
# dice_list:  [0.21411620585586666, 0.22669281649246992, 0.28946285541159233, 0.3600755699303879, 0.41786229725338575, 0.4620115389224664, 0.48880076433454234, 0.5065203565186079, 0.5164092880529222, 0.5226261873917335, 0.5237546700581305, 0.5210541877106479, 0.513686844815241, 0.5008948998218042, 0.4853376224974453, 0.4657847725933679, 0.4396984772395746, 0.4003629678379681, 0.13466576952544396]
# - epoch:23 -
# Epoch: [23][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.3865(0.3865)
# Epoch: [23][59/60] Elapsed 0m 28s (remain 0m 0s) Loss: 0.5492(0.3953)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.4736(0.4736)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2070(0.5090)
# 	 epoch:23, avg train loss:0.3953, avg valid loss:0.5090
# 	 score:0.5197(th=0.650000), auc=0.834834::: time:151.55s
# - epoch:24 -
# Epoch: [24][0/60] Elapsed 0m 1s (remain 1m 29s) Loss: 0.3903(0.3903)
# Epoch: [24][59/60] Elapsed 0m 28s (remain 0m 0s) Loss: 0.5106(0.4051)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.4754(0.4754)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2243(0.4977)
# 	 epoch:24, avg train loss:0.4051, avg valid loss:0.4977
# 	 score:0.5276(th=0.650000), auc=0.841115::: time:200.16s
# Epoch 24 - Save Best Score: 0.5276. Model is saved.
# dice_list:  [0.2141170485959216, 0.22523685913518907, 0.28310117017937236, 0.34765345946475645, 0.4025177362446306, 0.44634928988572087, 0.47510931079892327, 0.4953688082485437, 0.509816126057325, 0.5201413525596059, 0.5264366170546314, 0.5275539763693132, 0.5234559184058906, 0.517245493978221, 0.5063187023836893, 0.48935280477240645, 0.46728973498619414, 0.43448981256563945, 0.17055953333457752]
# Epoch 24 - Save Best AUC: 0.8411. Model is saved.
# - epoch:25 -
# Epoch: [25][0/60] Elapsed 0m 1s (remain 1m 24s) Loss: 0.3266(0.3266)
# Epoch: [25][59/60] Elapsed 0m 28s (remain 0m 0s) Loss: 0.8188(0.3918)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4745(0.4745)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2145(0.5093)
# 	 epoch:25, avg train loss:0.3918, avg valid loss:0.5093
# 	 score:0.5149(th=0.650000), auc=0.833408::: time:252.61s
# - epoch:26 -
# Epoch: [26][0/60] Elapsed 0m 1s (remain 1m 32s) Loss: 0.8322(0.8322)
# Epoch: [26][59/60] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3644(0.3986)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4769(0.4769)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2232(0.4793)
# 	 epoch:26, avg train loss:0.3986, avg valid loss:0.4793
# 	 score:0.5185(th=0.650000), auc=0.834917::: time:300.96s
# - epoch:27 -
# Epoch: [27][0/60] Elapsed 0m 1s (remain 1m 26s) Loss: 0.4813(0.4813)
# Epoch: [27][59/60] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3664(0.3857)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.4669(0.4669)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2234(0.4690)
# 	 epoch:27, avg train loss:0.3857, avg valid loss:0.4690
# 	 score:0.5214(th=0.650000), auc=0.838481::: time:350.02s
# - epoch:28 -
# Epoch: [28][0/60] Elapsed 0m 1s (remain 1m 30s) Loss: 0.3571(0.3571)
# Epoch: [28][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3584(0.3877)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.4687(0.4687)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2161(0.4742)
# 	 epoch:28, avg train loss:0.3877, avg valid loss:0.4742
# 	 score:0.5178(th=0.600000), auc=0.836090::: time:398.61s
# - epoch:29 -
# Epoch: [29][0/60] Elapsed 0m 1s (remain 1m 28s) Loss: 0.4952(0.4952)
# Epoch: [29][59/60] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3566(0.3960)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4671(0.4671)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2237(0.4659)
# 	 epoch:29, avg train loss:0.3960, avg valid loss:0.4659
# 	 score:0.5164(th=0.650000), auc=0.835167::: time:447.42s
# - epoch:30 -
# Epoch: [30][0/60] Elapsed 0m 1s (remain 1m 32s) Loss: 0.4509(0.4509)
# Epoch: [30][59/60] Elapsed 0m 28s (remain 0m 0s) Loss: 0.4380(0.4011)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.4746(0.4746)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2218(0.5109)
# 	 epoch:30, avg train loss:0.4011, avg valid loss:0.5109
# 	 score:0.5207(th=0.650000), auc=0.835596::: time:495.76s
# [fold1] slice ave score:0.5542(th=0.400000), auc=0.842469
# [fold1] BEST Epoch 24 - Save Best Score:0.5276. Best loss:0.4977
# [fold1] BEST AUC Epoch 24 - Save Best Score:0.8411. Best loss:0.4977
# -- fold2 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# Epoch: [1][0/60] Elapsed 0m 1s (remain 1m 21s) Loss: 0.7067(0.7067)
# Epoch: [1][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.5636(0.6033)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.8199(0.8199)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5264(0.5737)
# 	 epoch:1, avg train loss:0.6033, avg valid loss:0.5737
# 	 score:0.3817(th=0.500000), auc=0.776592::: time:49.15s
# Epoch 1 - Save Best Score: 0.3817. Model is saved.
# dice_list:  [0.20519188017055187, 0.20520910596359027, 0.2052597412401404, 0.20595864101436145, 0.21875664088845873, 0.2616550721937474, 0.32940131795411703, 0.3697661685667918, 0.3816907753661467, 0.37284672119241036, 0.3477910463538041, 0.31999087125559555, 0.2975022889768663, 0.27859149690330215, 0.2559228251758908, 0.22401020333516267, 0.18434504733082593, 0.12458047260038199, 0.0]
# Epoch 1 - Save Best AUC: 0.7766. Model is saved.
# - epoch:2 -
# Epoch: [2][0/60] Elapsed 0m 1s (remain 1m 26s) Loss: 0.5688(0.5688)
# Epoch: [2][59/60] Elapsed 0m 30s (remain 0m 0s) Loss: 0.4767(0.5185)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.5855(0.5855)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5217(0.5077)
# 	 epoch:2, avg train loss:0.5185, avg valid loss:0.5077
# 	 score:0.4370(th=0.550000), auc=0.797582::: time:102.46s
# Epoch 2 - Save Best Score: 0.4370. Model is saved.
# dice_list:  [0.20519126931920312, 0.20520101559470982, 0.20534029447232746, 0.21206668286028316, 0.2713921369579181, 0.3266693061842862, 0.37860183154383314, 0.41504520579675436, 0.43306792517679654, 0.4369993511604032, 0.4213639509242441, 0.38975039325039407, 0.3476238927683563, 0.2955019349815916, 0.22552305966571265, 0.14432528074013198, 0.06681845945398358, 0.007279327454927255, 0.0]
# Epoch 2 - Save Best AUC: 0.7976. Model is saved.
# - epoch:3 -
# Epoch: [3][0/60] Elapsed 0m 1s (remain 1m 32s) Loss: 0.4916(0.4916)
# Epoch: [3][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.4134(0.4599)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.5394(0.5394)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.7749(0.4959)
# 	 epoch:3, avg train loss:0.4599, avg valid loss:0.4959
# 	 score:0.4918(th=0.650000), auc=0.825275::: time:155.82s
# Epoch 3 - Save Best Score: 0.4918. Model is saved.
# dice_list:  [0.20521073034600074, 0.20648343590458326, 0.2410570867047537, 0.28249250168394197, 0.3269094649958875, 0.3685717934818008, 0.40380040655016086, 0.43033012880406935, 0.4517072019201628, 0.4695068250485053, 0.48384778791859845, 0.4917791318723063, 0.4889438319065536, 0.4694414631251323, 0.43803007621302176, 0.38915217634892124, 0.30604467094502535, 0.158747728707242, 0.0]
# Epoch 3 - Save Best AUC: 0.8253. Model is saved.
# - epoch:4 -
# Epoch: [4][0/60] Elapsed 0m 1s (remain 1m 32s) Loss: 0.4032(0.4032)
# Epoch: [4][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.4365(0.4158)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.5378(0.5378)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4914(0.4319)
# 	 epoch:4, avg train loss:0.4158, avg valid loss:0.4319
# 	 score:0.5071(th=0.550000), auc=0.826818::: time:208.45s
# Epoch 4 - Save Best Score: 0.5071. Model is saved.
# dice_list:  [0.2052885125962026, 0.22624122297020183, 0.26493515670391915, 0.32745241125034386, 0.38664943492886694, 0.4321250361653216, 0.4656715167583526, 0.4912736548614425, 0.5046418677549921, 0.5071357934733564, 0.4998541636433577, 0.4836604358463715, 0.4624371519694599, 0.43424613974069526, 0.3973062051723699, 0.35247804700067936, 0.29470062851769135, 0.19975020286000697, 0.0]
# Epoch 4 - Save Best AUC: 0.8268. Model is saved.
# - epoch:5 -
# Epoch: [5][0/60] Elapsed 0m 1s (remain 1m 27s) Loss: 0.4024(0.4024)
# Epoch: [5][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.4492(0.3883)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.6476(0.6476)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5132(0.4313)
# 	 epoch:5, avg train loss:0.3883, avg valid loss:0.4313
# 	 score:0.5029(th=0.600000), auc=0.833750::: time:261.00s
# Epoch 5 - Save Best AUC: 0.8337. Model is saved.
# - epoch:6 -
# Epoch: [6][0/60] Elapsed 0m 1s (remain 1m 22s) Loss: 0.3327(0.3327)
# Epoch: [6][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3610(0.3663)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.6056(0.6056)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5403(0.4390)
# 	 epoch:6, avg train loss:0.3663, avg valid loss:0.4390
# 	 score:0.5102(th=0.600000), auc=0.836187::: time:311.74s
# Epoch 6 - Save Best Score: 0.5102. Model is saved.
# dice_list:  [0.2057932647668595, 0.24281853180801616, 0.2972133439743445, 0.3549765335824604, 0.4017833352165592, 0.4370975222201905, 0.46516794572936426, 0.4857614048344333, 0.5001678322813399, 0.507816182552944, 0.5101722536315733, 0.5075382970894363, 0.49888115005555356, 0.4872204199520683, 0.47040869489374776, 0.44968065368999355, 0.42693046476429936, 0.3904697237218542, 0.015021801386651386]
# Epoch 6 - Save Best AUC: 0.8362. Model is saved.
# - epoch:7 -
# Epoch: [7][0/60] Elapsed 0m 1s (remain 1m 22s) Loss: 0.3582(0.3582)
# Epoch: [7][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3268(0.3531)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5935(0.5935)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5665(0.4311)
# 	 epoch:7, avg train loss:0.3531, avg valid loss:0.4311
# 	 score:0.5080(th=0.650000), auc=0.828347::: time:364.12s
# - epoch:8 -
# Epoch: [8][0/60] Elapsed 0m 1s (remain 1m 34s) Loss: 0.3255(0.3255)
# Epoch: [8][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.2990(0.3535)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.6786(0.6786)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.7283(0.4543)
# 	 epoch:8, avg train loss:0.3535, avg valid loss:0.4543
# 	 score:0.5071(th=0.700000), auc=0.839346::: time:412.82s
# Epoch 8 - Save Best AUC: 0.8393. Model is saved.
# - epoch:9 -
# Epoch: [9][0/60] Elapsed 0m 1s (remain 1m 24s) Loss: 0.4086(0.4086)
# Epoch: [9][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3091(0.3487)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.6459(0.6459)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5618(0.4267)
# 	 epoch:9, avg train loss:0.3487, avg valid loss:0.4267
# 	 score:0.5148(th=0.650000), auc=0.836595::: time:463.68s
# Epoch 9 - Save Best Score: 0.5148. Model is saved.
# dice_list:  [0.2073974560221308, 0.2671332917964182, 0.34002598515333227, 0.39343348764734926, 0.4355392136864745, 0.4616929176939006, 0.47952019551339053, 0.49311040386957755, 0.5022827585968958, 0.5096583212906012, 0.5146499428282836, 0.5147540089457208, 0.5085710952350904, 0.49768715127390845, 0.48277569108840956, 0.4644318376145172, 0.4382270147025226, 0.4049437693315, 0.06497034783495519]
# - epoch:10 -
# Epoch: [10][0/60] Elapsed 0m 1s (remain 1m 28s) Loss: 0.3316(0.3316)
# Epoch: [10][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.5092(0.3472)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.6132(0.6132)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5424(0.4175)
# 	 epoch:10, avg train loss:0.3472, avg valid loss:0.4175
# 	 score:0.5136(th=0.600000), auc=0.839134::: time:513.90s
# surface_list:  range(27, 37, 3)
# - epoch:11 -
# Epoch: [11][0/60] Elapsed 0m 1s (remain 1m 27s) Loss: 0.3403(0.3403)
# Epoch: [11][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.2962(0.3444)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.7553(0.7553)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5242(0.4405)
# 	 epoch:11, avg train loss:0.3444, avg valid loss:0.4405
# 	 score:0.5225(th=0.650000), auc=0.841491::: time:48.84s
# Epoch 11 - Save Best Score: 0.5225. Model is saved.
# dice_list:  [0.2077908402629681, 0.2695115585821445, 0.34018777071073497, 0.39298672280930247, 0.4335262756685498, 0.45878416075768214, 0.47935916140805596, 0.49627805582447176, 0.5078742809486451, 0.5166602596635705, 0.5213336724362069, 0.522523566864802, 0.5191693739518946, 0.5123713920034427, 0.5030972922064364, 0.4891097190609107, 0.4655067341027891, 0.42665660918796117, 0.08384210876160582]
# Epoch 11 - Save Best AUC: 0.8415. Model is saved.
# - epoch:12 -
# Epoch: [12][0/60] Elapsed 0m 1s (remain 1m 25s) Loss: 0.2958(0.2958)
# Epoch: [12][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3171(0.3303)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.7324(0.7324)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4919(0.4269)
# 	 epoch:12, avg train loss:0.3303, avg valid loss:0.4269
# 	 score:0.5259(th=0.650000), auc=0.840973::: time:100.90s
# Epoch 12 - Save Best Score: 0.5259. Model is saved.
# dice_list:  [0.20871417529624883, 0.2763065736820863, 0.3463639686850483, 0.40117985221857083, 0.4397157536184789, 0.4633549233980193, 0.4822827022174579, 0.49851924225466804, 0.510683046294732, 0.5190621242085847, 0.5242337885153355, 0.5259146387361315, 0.5222075824429113, 0.5156600549679728, 0.49949031329856963, 0.48176072337610176, 0.45752128449377233, 0.4147642237603153, 0.06973359758022886]
# - epoch:13 -
# Epoch: [13][0/60] Elapsed 0m 1s (remain 1m 23s) Loss: 0.2742(0.2742)
# Epoch: [13][59/60] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3529(0.3425)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.5956(0.5956)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4904(0.4196)
# 	 epoch:13, avg train loss:0.3425, avg valid loss:0.4196
# 	 score:0.5259(th=0.650000), auc=0.841621::: time:150.68s
# Epoch 13 - Save Best Score: 0.5259. Model is saved.
# dice_list:  [0.20762834618850748, 0.26944999475923376, 0.33995573680467833, 0.3943145919529404, 0.4344773695111531, 0.459847359239774, 0.4804375875122908, 0.49611861731005297, 0.5084972013834789, 0.5173211117041688, 0.5233665900668226, 0.5259421992186337, 0.5226463689669195, 0.5142285929516267, 0.497445644631959, 0.47430749236104913, 0.4418140417049413, 0.39516129156917024, 0.03852325758478874]
# Epoch 13 - Save Best AUC: 0.8416. Model is saved.
# - epoch:14 -
# Epoch: [14][0/60] Elapsed 0m 1s (remain 1m 31s) Loss: 0.2790(0.2790)
# Epoch: [14][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.2884(0.3364)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.7422(0.7422)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5600(0.4375)
# 	 epoch:14, avg train loss:0.3364, avg valid loss:0.4375
# 	 score:0.5247(th=0.700000), auc=0.842895::: time:202.31s
# Epoch 14 - Save Best AUC: 0.8429. Model is saved.
# - epoch:15 -
# Epoch: [15][0/60] Elapsed 0m 1s (remain 1m 25s) Loss: 0.2941(0.2941)
# Epoch: [15][59/60] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3193(0.3416)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.6538(0.6538)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5127(0.4265)
# 	 epoch:15, avg train loss:0.3416, avg valid loss:0.4265
# 	 score:0.5243(th=0.650000), auc=0.840268::: time:252.28s
# - epoch:16 -
# Epoch: [16][0/60] Elapsed 0m 1s (remain 1m 33s) Loss: 0.2777(0.2777)
# Epoch: [16][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3333(0.3416)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.7755(0.7755)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5516(0.4396)
# 	 epoch:16, avg train loss:0.3416, avg valid loss:0.4396
# 	 score:0.5263(th=0.650000), auc=0.843266::: time:301.15s
# Epoch 16 - Save Best Score: 0.5263. Model is saved.
# ...
# Epoch: [3][61/62] Elapsed 0m 30s (remain 0m 0s) Loss: 0.5118(0.5099)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5648(0.5648)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.7346(0.9138)
# 	 epoch:3, avg train loss:0.5099, avg valid loss:0.9138
# 	 score:0.4408(th=0.950000), auc=0.876819::: time:157.83s
# Epoch 3 - Save Best Score: 0.4408. Model is saved.
# dice_list:  [0.18790408950700074, 0.19154385522378037, 0.2291776194307341, 0.2386596490834741, 0.24836309608073695, 0.2607985701300296, 0.275213977567795, 0.2888690208294066, 0.3017182735982712, 0.31331153025065134, 0.32398076063944453, 0.3360469954188977, 0.3501733228416832, 0.36683232166578067, 0.38524431183692914, 0.40629604297608923, 0.4286221215477567, 0.44077308662791886, 0.0]
# Epoch 3 - Save Best AUC: 0.8768. Model is saved.
# - epoch:4 -
# Epoch: [4][0/62] Elapsed 0m 1s (remain 1m 33s) Loss: 0.4713(0.4713)
# Epoch: [4][61/62] Elapsed 0m 31s (remain 0m 0s) Loss: 0.4567(0.4548)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.3526(0.3526)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.9840(0.8760)
# 	 epoch:4, avg train loss:0.4548, avg valid loss:0.8760
# 	 score:0.4708(th=0.950000), auc=0.882124::: time:211.89s
# Epoch 4 - Save Best Score: 0.4708. Model is saved.
# dice_list:  [0.18791699636269682, 0.2112205540451273, 0.23467309767552577, 0.2488372840183308, 0.26575260420048036, 0.28467029513524555, 0.3046123896301962, 0.32234258091618573, 0.3380733491418346, 0.3536417417273554, 0.3695677064744925, 0.3845603992117983, 0.39998702112139856, 0.41560473485838717, 0.42983495573948527, 0.4421390558082512, 0.45450495691231924, 0.470796626551372, 0.0]
# Epoch 4 - Save Best AUC: 0.8821. Model is saved.
# - epoch:5 -
# Epoch: [5][0/62] Elapsed 0m 1s (remain 1m 27s) Loss: 0.4432(0.4432)
# Epoch: [5][61/62] Elapsed 0m 30s (remain 0m 0s) Loss: 0.6215(0.4223)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.3062(0.3062)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5609(0.6583)
# 	 epoch:5, avg train loss:0.4223, avg valid loss:0.6583
# 	 score:0.4711(th=0.800000), auc=0.883275::: time:266.01s
# Epoch 5 - Save Best Score: 0.4711. Model is saved.
# dice_list:  [0.18790006178469126, 0.22219985733939487, 0.24604769131866974, 0.27290934958037844, 0.299529490402088, 0.3243469595508629, 0.3458833005573057, 0.36641623206633156, 0.3867625085615317, 0.4065431521851368, 0.42588113588363224, 0.4431851582114946, 0.457434942998277, 0.46739644065407954, 0.47110552169824, 0.4693265663460675, 0.4580697669597555, 0.4315929872652288, 0.03488358669062845]
# Epoch 5 - Save Best AUC: 0.8833. Model is saved.
# - epoch:6 -
# Epoch: [6][0/62] Elapsed 0m 1s (remain 1m 29s) Loss: 0.3358(0.3358)
# Epoch: [6][61/62] Elapsed 0m 30s (remain 0m 0s) Loss: 0.4619(0.4066)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2407(0.2407)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3913(0.5265)
# 	 epoch:6, avg train loss:0.4066, avg valid loss:0.5265
# 	 score:0.4762(th=0.750000), auc=0.888523::: time:320.27s
# Epoch 6 - Save Best Score: 0.4762. Model is saved.
# dice_list:  [0.1879088073090941, 0.20182803398707627, 0.24658587585024488, 0.2817119180987865, 0.3182416103077493, 0.35224439838961163, 0.3814895379336323, 0.4055301262725357, 0.42624578516186634, 0.440944287390301, 0.45472260578107543, 0.4647872552568042, 0.4717897661066079, 0.4762188548607247, 0.4753351550779184, 0.4695259213021819, 0.455013260712793, 0.416344318918614, 0.05544523327863857]
# Epoch 6 - Save Best AUC: 0.8885. Model is saved.
# - epoch:7 -
# Epoch: [7][0/62] Elapsed 0m 1s (remain 1m 26s) Loss: 0.3432(0.3432)
# Epoch: [7][61/62] Elapsed 0m 30s (remain 0m 0s) Loss: 0.3480(0.3912)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.3261(0.3261)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4874(1.0201)
# 	 epoch:7, avg train loss:0.3912, avg valid loss:1.0201
# 	 score:0.4640(th=0.950000), auc=0.882038::: time:373.67s
# - epoch:8 -
# Epoch: [8][0/62] Elapsed 0m 1s (remain 1m 34s) Loss: 0.3500(0.3500)
# Epoch: [8][61/62] Elapsed 0m 30s (remain 0m 0s) Loss: 0.3481(0.3975)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2678(0.2678)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4191(0.7119)
# 	 epoch:8, avg train loss:0.3975, avg valid loss:0.7119
# 	 score:0.4891(th=0.800000), auc=0.889430::: time:424.12s
# Epoch 8 - Save Best Score: 0.4891. Model is saved.
# dice_list:  [0.1896225424744111, 0.2333396830064174, 0.26507491684634205, 0.2962570166047758, 0.32504755225133913, 0.35099070152344486, 0.37536282132714344, 0.3981529533395939, 0.418053643927021, 0.43508307393420254, 0.4503782185015316, 0.46402732648245726, 0.4760303898781392, 0.48431531180999843, 0.4891188923823372, 0.48853510951963053, 0.4846754256631931, 0.47303821193592455, 0.15944276091865775]
# Epoch 8 - Save Best AUC: 0.8894. Model is saved.
# - epoch:9 -
# Epoch: [9][0/62] Elapsed 0m 1s (remain 1m 25s) Loss: 0.3059(0.3059)
# Epoch: [9][61/62] Elapsed 0m 30s (remain 0m 0s) Loss: 0.3054(0.3645)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.3429(0.3429)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4669(0.8866)
# 	 epoch:9, avg train loss:0.3645, avg valid loss:0.8866
# 	 score:0.4758(th=0.900000), auc=0.883951::: time:478.14s
# - epoch:10 -
# Epoch: [10][0/62] Elapsed 0m 1s (remain 1m 31s) Loss: 0.3075(0.3075)
# Epoch: [10][61/62] Elapsed 0m 30s (remain 0m 0s) Loss: 0.3423(0.3860)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.3096(0.3096)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4525(0.8815)
# 	 epoch:10, avg train loss:0.3860, avg valid loss:0.8815
# 	 score:0.4696(th=0.900000), auc=0.883650::: time:528.72s
# surface_list:  range(27, 37, 3)
# - epoch:11 -
# Epoch: [11][0/62] Elapsed 0m 1s (remain 1m 26s) Loss: 0.3450(0.3450)
# Epoch: [11][61/62] Elapsed 0m 30s (remain 0m 0s) Loss: 0.2775(0.3869)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.2258(0.2258)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4807(0.6862)
# 	 epoch:11, avg train loss:0.3869, avg valid loss:0.6862
# 	 score:0.4813(th=0.800000), auc=0.886647::: time:50.72s
# Epoch 11 - Save Best Score: 0.4813. Model is saved.
# dice_list:  [0.18914372617481542, 0.23543663560393738, 0.2713569453190874, 0.30802573890397134, 0.34145704259232423, 0.3707167126402398, 0.394197830822035, 0.4153821061569075, 0.43412755217794036, 0.448738242963647, 0.460642372030634, 0.4709504535467195, 0.47721954504334674, 0.4812319745095902, 0.4812924878659966, 0.4711092285554528, 0.44918001880125447, 0.40946228855990763, 0.14073992941548855]
# Epoch 11 - Save Best AUC: 0.8866. Model is saved.
# - epoch:12 -
# Epoch: [12][0/62] Elapsed 0m 1s (remain 1m 29s) Loss: 0.4399(0.4399)
# Epoch: [12][61/62] Elapsed 0m 30s (remain 0m 0s) Loss: 0.3731(0.3983)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2624(0.2624)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.6141(0.9799)
# 	 epoch:12, avg train loss:0.3983, avg valid loss:0.9799
# 	 score:0.4756(th=0.850000), auc=0.884706::: time:104.30s
# - epoch:13 -
# Epoch: [13][0/62] Elapsed 0m 1s (remain 1m 34s) Loss: 0.3284(0.3284)
# Epoch: [13][61/62] Elapsed 0m 30s (remain 0m 0s) Loss: 0.3899(0.3762)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2307(0.2307)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4790(0.8424)
# 	 epoch:13, avg train loss:0.3762, avg valid loss:0.8424
# 	 score:0.4773(th=0.800000), auc=0.885996::: time:153.86s
# - epoch:14 -
# Epoch: [14][0/62] Elapsed 0m 1s (remain 1m 36s) Loss: 0.2984(0.2984)
# Epoch: [14][61/62] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3806(0.3865)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2449(0.2449)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5741(0.9696)
# 	 epoch:14, avg train loss:0.3865, avg valid loss:0.9696
# 	 score:0.4729(th=0.800000), auc=0.884869::: time:203.85s
# - epoch:15 -
# Epoch: [15][0/62] Elapsed 0m 1s (remain 1m 34s) Loss: 0.3728(0.3728)
# Epoch: [15][61/62] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3136(0.3777)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2350(0.2350)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4806(0.6860)
# 	 epoch:15, avg train loss:0.3777, avg valid loss:0.6860
# 	 score:0.4784(th=0.750000), auc=0.886768::: time:253.32s
# Epoch 15 - Save Best AUC: 0.8868. Model is saved.
# - epoch:16 -
# Epoch: [16][0/62] Elapsed 0m 1s (remain 1m 25s) Loss: 0.3479(0.3479)
# Epoch: [16][61/62] Elapsed 0m 30s (remain 0m 0s) Loss: 0.2985(0.3959)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2812(0.2812)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5629(0.9520)
# 	 epoch:16, avg train loss:0.3959, avg valid loss:0.9520
# 	 score:0.4656(th=0.800000), auc=0.883282::: time:305.33s
# - epoch:17 -
# Epoch: [17][0/62] Elapsed 0m 1s (remain 1m 41s) Loss: 0.3869(0.3869)
# Epoch: [17][61/62] Elapsed 0m 30s (remain 0m 0s) Loss: 0.2957(0.3898)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2586(0.2586)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5282(0.8441)
# 	 epoch:17, avg train loss:0.3898, avg valid loss:0.8441
# 	 score:0.4768(th=0.800000), auc=0.885053::: time:355.45s
# - epoch:18 -
# Epoch: [18][0/62] Elapsed 0m 1s (remain 1m 31s) Loss: 0.3519(0.3519)
# Epoch: [18][61/62] Elapsed 0m 30s (remain 0m 0s) Loss: 0.3400(0.3692)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2281(0.2281)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4501(0.7035)
# 	 epoch:18, avg train loss:0.3692, avg valid loss:0.7035
# 	 score:0.4799(th=0.750000), auc=0.886118::: time:406.32s
# - epoch:19 -
# Epoch: [19][0/62] Elapsed 0m 1s (remain 1m 38s) Loss: 0.3795(0.3795)
# Epoch: [19][61/62] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3675(0.4058)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2586(0.2586)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5462(0.9339)
# 	 epoch:19, avg train loss:0.4058, avg valid loss:0.9339
# 	 score:0.4689(th=0.800000), auc=0.883773::: time:456.73s
# - epoch:20 -
# Epoch: [20][0/62] Elapsed 0m 1s (remain 1m 37s) Loss: 0.3223(0.3223)
# Epoch: [20][61/62] Elapsed 0m 30s (remain 0m 0s) Loss: 0.3951(0.3789)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.3054(0.3054)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.6961(1.1710)
# 	 epoch:20, avg train loss:0.3789, avg valid loss:1.1710
# 	 score:0.4600(th=0.850000), auc=0.882075::: time:507.12s
# surface_list:  range(25, 35, 3)
# - epoch:21 -
# Epoch: [21][0/62] Elapsed 0m 1s (remain 1m 27s) Loss: 0.8506(0.8506)
# Epoch: [21][61/62] Elapsed 0m 32s (remain 0m 0s) Loss: 0.5193(0.3980)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.3374(0.3374)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5154(1.0248)
# 	 epoch:21, avg train loss:0.3980, avg valid loss:1.0248
# 	 score:0.4612(th=0.950000), auc=0.879674::: time:53.30s
# Epoch 21 - Save Best Score: 0.4612. Model is saved.
# dice_list:  [0.18830470323342113, 0.23050880132268284, 0.2603077899180711, 0.2852274863338761, 0.30935029281607784, 0.33155145519360896, 0.3490010904211219, 0.364922910303002, 0.3793776022293678, 0.3935708165149632, 0.405480554031566, 0.41684764088497334, 0.42701333865805785, 0.4368025842502141, 0.4462344582775502, 0.45501606184214444, 0.4608311720040642, 0.46115841654033185, 0.23151769888582815]
# Epoch 21 - Save Best AUC: 0.8797. Model is saved.
# - epoch:22 -
# Epoch: [22][0/62] Elapsed 0m 1s (remain 1m 34s) Loss: 0.5089(0.5089)
# Epoch: [22][61/62] Elapsed 0m 30s (remain 0m 0s) Loss: 0.3441(0.3911)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.3996(0.3996)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5499(1.1282)
# 	 epoch:22, avg train loss:0.3911, avg valid loss:1.1282
# 	 score:0.4553(th=0.950000), auc=0.877353::: time:107.47s
# - epoch:23 -
# Epoch: [23][0/62] Elapsed 0m 1s (remain 1m 29s) Loss: 0.3552(0.3552)
# Epoch: [23][61/62] Elapsed 0m 30s (remain 0m 0s) Loss: 0.2982(0.3703)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.3258(0.3258)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4963(0.8625)
# 	 epoch:23, avg train loss:0.3703, avg valid loss:0.8625
# 	 score:0.4704(th=0.900000), auc=0.879613::: time:158.03s
# Epoch 23 - Save Best Score: 0.4704. Model is saved.
# dice_list:  [0.1885426527017855, 0.2324450280848733, 0.2600042401098396, 0.284335406081797, 0.308197392456661, 0.3301075894516957, 0.3482840916632758, 0.36352589333046353, 0.37881809112234, 0.3933780929532831, 0.4072585616226551, 0.41894792010529514, 0.4289700776355957, 0.44055039520498507, 0.45304807182662377, 0.46260372002455247, 0.47036474616592916, 0.4658130245236249, 0.17651432636903475]
# - epoch:24 -
# Epoch: [24][0/62] Elapsed 0m 1s (remain 1m 38s) Loss: 0.3500(0.3500)
# Epoch: [24][61/62] Elapsed 0m 30s (remain 0m 0s) Loss: 0.9432(0.4003)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.3639(0.3639)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5559(1.2162)
# 	 epoch:24, avg train loss:0.4003, avg valid loss:1.2162
# 	 score:0.4678(th=0.950000), auc=0.879894::: time:209.92s
# Epoch 24 - Save Best AUC: 0.8799. Model is saved.
# - epoch:25 -
# Epoch: [25][0/62] Elapsed 0m 1s (remain 1m 34s) Loss: 0.4193(0.4193)
# Epoch: [25][61/62] Elapsed 0m 30s (remain 0m 0s) Loss: 0.3397(0.3942)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.3361(0.3361)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5099(1.0141)
# 	 epoch:25, avg train loss:0.3942, avg valid loss:1.0141
# 	 score:0.4661(th=0.900000), auc=0.878484::: time:262.04s
# - epoch:26 -
# Epoch: [26][0/62] Elapsed 0m 1s (remain 1m 36s) Loss: 0.3467(0.3467)
# Epoch: [26][61/62] Elapsed 0m 30s (remain 0m 0s) Loss: 0.2907(0.3913)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2977(0.2977)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4616(0.7970)
# 	 epoch:26, avg train loss:0.3913, avg valid loss:0.7970
# 	 score:0.4627(th=0.850000), auc=0.878790::: time:312.97s
# - epoch:27 -
# Epoch: [27][0/62] Elapsed 0m 1s (remain 1m 29s) Loss: 0.3044(0.3044)
# Epoch: [27][61/62] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3658(0.3852)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2858(0.2858)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4623(0.7962)
# 	 epoch:27, avg train loss:0.3852, avg valid loss:0.7962
# 	 score:0.4682(th=0.900000), auc=0.878680::: time:363.44s
# - epoch:28 -
# Epoch: [28][0/62] Elapsed 0m 1s (remain 1m 35s) Loss: 0.3597(0.3597)
# Epoch: [28][61/62] Elapsed 0m 30s (remain 0m 0s) Loss: 0.3056(0.3839)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.3066(0.3066)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4656(0.8264)
# 	 epoch:28, avg train loss:0.3839, avg valid loss:0.8264
# 	 score:0.4657(th=0.850000), auc=0.879387::: time:414.20s
# - epoch:29 -
# Epoch: [29][0/62] Elapsed 0m 1s (remain 1m 35s) Loss: 0.3076(0.3076)
# Epoch: [29][61/62] Elapsed 0m 30s (remain 0m 0s) Loss: 0.3804(0.3859)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.2810(0.2810)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4489(0.6905)
# 	 epoch:29, avg train loss:0.3859, avg valid loss:0.6905
# 	 score:0.4702(th=0.850000), auc=0.880100::: time:464.54s
# Epoch 29 - Save Best AUC: 0.8801. Model is saved.
# - epoch:30 -
# Epoch: [30][0/62] Elapsed 0m 1s (remain 1m 36s) Loss: 0.3918(0.3918)
# Epoch: [30][61/62] Elapsed 0m 30s (remain 0m 0s) Loss: 0.2967(0.3791)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.2964(0.2964)
# EVAL: [16/17] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4616(0.7977)
# 	 epoch:30, avg train loss:0.3791, avg valid loss:0.7977
# 	 score:0.4682(th=0.900000), auc=0.878241::: time:515.66s
# [fold4] slice ave score:0.4740(th=0.500000), auc=0.884836
# [fold4] BEST Epoch 23 - Save Best Score:0.4704. Best loss:0.8625
# [fold4] BEST AUC Epoch 29 - Save Best Score:0.8801. Best loss:0.6905
# fold[0] BEST SCORE = 0.5385 thr=0.75 (epoch=30)
# fold[0] slice ave score:0.5451(th=0.450000), auc=0.884126
# fold[1] BEST SCORE = 0.5276 thr=0.65 (epoch=24)
# fold[1] slice ave score:0.5542(th=0.400000), auc=0.842469
# fold[2] BEST SCORE = 0.5107 thr=0.65 (epoch=22)
# fold[2] slice ave score:0.5271(th=0.400000), auc=0.845051
# fold[3] BEST SCORE = 0.5103 thr=0.7 (epoch=26)
# fold[3] slice ave score:0.5277(th=0.350000), auc=0.921245
# fold[4] BEST SCORE = 0.4704 thr=0.9 (epoch=23)
# fold[4] slice ave score:0.4740(th=0.500000), auc=0.884836
# CPU times: user 1h 31min 1s, sys: 35min 53s, total: 2h 6min 54s
# Wall time: 2h 14min 28s

# %% [markdown]
# ---
# # OOF SCORE INFER

# %%
# %%time
slice_ave_score_list, slice_ave_score_threshold_list, slice_ave_auc_list = slide_inference(CFG)
for fold in CFG["folds"]:
    print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    wandb.log({"OOF SCORE" : {f"slice average score":slice_ave_score_list[fold],
                            f"slice average threshold":slice_ave_score_threshold_list[fold],
                            f"slice_average auc":slice_ave_auc_list[fold],
                            }})
# Out:
# -- fold0 slide inference start --
# surface_list:  range(26, 36, 3)
# slide pos: [0, 0]
# 	 score:0.5356(th=0.700000), auc=0.883787::: time:25.36s
# slide pos: [256, 0]
# 	 score:0.5419(th=0.700000), auc=0.881473::: time:42.48s
# slide pos: [0, 256]
# 	 score:0.5199(th=0.600000), auc=0.885650::: time:59.48s
# slide pos: [256, 256]
# 	 score:0.5330(th=0.650000), auc=0.882042::: time:76.01s
# surface_list:  range(27, 37, 3)
# slide pos: [0, 0]
# 	 score:0.5371(th=0.600000), auc=0.883990::: time:99.44s
# slide pos: [256, 0]
# 	 score:0.5221(th=0.700000), auc=0.880802::: time:116.17s
# slide pos: [0, 256]
# 	 score:0.5086(th=0.550000), auc=0.885687::: time:133.19s
# slide pos: [256, 256]
# 	 score:0.5029(th=0.600000), auc=0.881744::: time:150.25s
# surface_list:  range(25, 35, 3)
# slide pos: [0, 0]
# 	 score:0.5368(th=0.600000), auc=0.884668::: time:173.23s
# slide pos: [256, 0]
# 	 score:0.5380(th=0.650000), auc=0.881470::: time:190.07s
# slide pos: [0, 256]
# 	 score:0.5150(th=0.550000), auc=0.885210::: time:206.94s
# slide pos: [256, 256]
# 	 score:0.5477(th=0.600000), auc=0.881172::: time:224.06s
# [fold0] slice ave score:0.5541(th=0.600000), auc=0.897338
# -- fold1 slide inference start --
# surface_list:  range(26, 36, 3)
# slide pos: [0, 0]
# 	 score:0.5600(th=0.650000), auc=0.845035::: time:266.25s
# slide pos: [256, 0]
# 	 score:0.5180(th=0.800000), auc=0.843468::: time:287.64s
# slide pos: [0, 256]
# 	 score:0.5609(th=0.700000), auc=0.841103::: time:310.21s
# slide pos: [256, 256]
# 	 score:0.5121(th=0.750000), auc=0.838401::: time:332.27s
# surface_list:  range(27, 37, 3)
# slide pos: [0, 0]
# 	 score:0.5571(th=0.700000), auc=0.845309::: time:359.21s
# slide pos: [256, 0]
# 	 score:0.5304(th=0.750000), auc=0.846116::: time:381.25s
# slide pos: [0, 256]
# 	 score:0.5670(th=0.750000), auc=0.845883::: time:403.20s
# slide pos: [256, 256]
# 	 score:0.5298(th=0.800000), auc=0.842561::: time:425.21s
# surface_list:  range(25, 35, 3)
# slide pos: [0, 0]
# 	 score:0.5276(th=0.650000), auc=0.841115::: time:452.41s
# slide pos: [256, 0]
# 	 score:0.4994(th=0.650000), auc=0.839535::: time:474.33s
# slide pos: [0, 256]
# 	 score:0.5408(th=0.650000), auc=0.838784::: time:496.59s
# slide pos: [256, 256]
# 	 score:0.5013(th=0.700000), auc=0.837625::: time:519.20s
# [fold1] slice ave score:0.5659(th=0.650000), auc=0.858590
# -- fold2 slide inference start --
# surface_list:  range(26, 36, 3)
# slide pos: [0, 0]
# 	 score:0.5196(th=0.700000), auc=0.843028::: time:565.87s
# slide pos: [256, 0]
# 	 score:0.5082(th=0.700000), auc=0.833428::: time:588.52s
# slide pos: [0, 256]
# 	 score:0.5172(th=0.750000), auc=0.842005::: time:610.28s
# slide pos: [256, 256]
# 	 score:0.5029(th=0.700000), auc=0.831859::: time:632.93s
# surface_list:  range(27, 37, 3)
# slide pos: [0, 0]
# 	 score:0.5196(th=0.700000), auc=0.846373::: time:658.91s
# slide pos: [256, 0]
# 	 score:0.5073(th=0.750000), auc=0.830394::: time:680.42s
# slide pos: [0, 256]
# 	 score:0.5330(th=0.800000), auc=0.843155::: time:702.15s
# slide pos: [256, 256]
# 	 score:0.5051(th=0.700000), auc=0.831860::: time:724.35s
# surface_list:  range(25, 35, 3)
# slide pos: [0, 0]
# 	 score:0.5107(th=0.650000), auc=0.835945::: time:751.20s
# slide pos: [256, 0]
# 	 score:0.5052(th=0.600000), auc=0.828096::: time:773.03s
# slide pos: [0, 256]
# 	 score:0.5020(th=0.600000), auc=0.833935::: time:795.01s
# slide pos: [256, 256]
# 	 score:0.4986(th=0.600000), auc=0.825264::: time:816.70s
# [fold2] slice ave score:0.5316(th=0.600000), auc=0.839597
# -- fold3 slide inference start --
# surface_list:  range(26, 36, 3)
# slide pos: [0, 0]
# 	 score:0.5239(th=0.700000), auc=0.922561::: time:858.34s
# slide pos: [256, 0]
# 	 score:0.5142(th=0.650000), auc=0.917446::: time:875.95s
# slide pos: [0, 256]
# 	 score:0.5069(th=0.650000), auc=0.914909::: time:894.53s
# slide pos: [256, 256]
# 	 score:0.5097(th=0.650000), auc=0.907293::: time:912.81s
# surface_list:  range(27, 37, 3)
# slide pos: [0, 0]
# 	 score:0.5298(th=0.650000), auc=0.922539::: time:933.34s
# slide pos: [256, 0]
# 	 score:0.5315(th=0.600000), auc=0.922716::: time:951.23s
# slide pos: [0, 256]
# 	 score:0.5226(th=0.700000), auc=0.915964::: time:968.81s
# slide pos: [256, 256]
# 	 score:0.5456(th=0.650000), auc=0.912725::: time:986.13s
# surface_list:  range(25, 35, 3)
# slide pos: [0, 0]
# 	 score:0.5079(th=0.650000), auc=0.918861::: time:1006.81s
# slide pos: [256, 0]
# 	 score:0.4925(th=0.600000), auc=0.910205::: time:1024.25s
# slide pos: [0, 256]
# 	 score:0.4900(th=0.650000), auc=0.911314::: time:1041.98s
# slide pos: [256, 256]
# 	 score:0.4832(th=0.650000), auc=0.899865::: time:1059.97s
# [fold3] slice ave score:0.5648(th=0.600000), auc=0.926478
# -- fold4 slide inference start --
# surface_list:  range(26, 36, 3)
# slide pos: [0, 0]
# 	 score:0.4839(th=0.800000), auc=0.886418::: time:1107.79s
# slide pos: [256, 0]
# 	 score:0.4857(th=0.800000), auc=0.881170::: time:1128.58s
# slide pos: [0, 256]
# 	 score:0.4650(th=0.800000), auc=0.884345::: time:1149.38s
# slide pos: [256, 256]
# 	 score:0.4866(th=0.800000), auc=0.882778::: time:1170.36s
# surface_list:  range(27, 37, 3)
# slide pos: [0, 0]
# 	 score:0.4880(th=0.700000), auc=0.887851::: time:1200.66s
# slide pos: [256, 0]
# 	 score:0.4812(th=0.700000), auc=0.882661::: time:1222.82s
# slide pos: [0, 256]
# 	 score:0.4744(th=0.700000), auc=0.887752::: time:1244.47s
# slide pos: [256, 256]
# 	 score:0.4961(th=0.700000), auc=0.886403::: time:1265.46s
# surface_list:  range(25, 35, 3)
# slide pos: [0, 0]
# 	 score:0.4702(th=0.850000), auc=0.880100::: time:1296.86s
# slide pos: [256, 0]
# 	 score:0.4679(th=0.900000), auc=0.873564::: time:1318.46s
# slide pos: [0, 256]
# 	 score:0.4485(th=0.850000), auc=0.875634::: time:1339.97s
# slide pos: [256, 256]
# 	 score:0.4649(th=0.850000), auc=0.873142::: time:1360.61s
# [fold4] slice ave score:0.5130(th=0.750000), auc=0.892056
# fold[0] slice ave score:0.5541(th=0.897338), auc=0.600000
# fold[1] slice ave score:0.5659(th=0.858590), auc=0.650000
# fold[2] slice ave score:0.5316(th=0.839597), auc=0.600000
# fold[3] slice ave score:0.5648(th=0.926478), auc=0.600000
# fold[4] slice ave score:0.5130(th=0.892056), auc=0.750000
# CPU times: user 17min 49s, sys: 3min 24s, total: 21min 13s
# Wall time: 22min 59s

# %%
import yaml
with open(os.path.join(CFG["OUTPUT_DIR"], "Config.yaml"), "w") as f:
    yaml.dump(CFG, f)

# %%
if not CFG["DEBUG"]:
    wandb.finish()
