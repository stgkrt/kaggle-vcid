# %% [markdown]
# # ex016
# 5-fold
# img size 512
# output shape is half of input shape

# %%
import gc
import os
import random
import time
import math

import cv2
import numpy as np
import matplotlib.pyplot as plt

# model
import torch
import torchvision
import torch.nn as nn
import timm
from torchvision.models.feature_extraction import create_feature_extractor
import torchvision.transforms.functional as TF

# data loader
import albumentations as A
from albumentations.pytorch import ToTensorV2
from torch.utils.data import DataLoader, Dataset

# training
from torch.optim import SGD, Adam, AdamW
from torch.optim.lr_scheduler import CosineAnnealingLR, CosineAnnealingWarmRestarts, ReduceLROnPlateau, ExponentialLR

# metric
from sklearn.metrics import fbeta_score, roc_auc_score

import wandb

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # config

# %%
BASE_DIR = "/working/"
INPUT_DIR = os.path.join(BASE_DIR, "input", "vesuvius-challenge-ink-detection")
TRAIN_DIR = os.path.join(INPUT_DIR, "train")
TEST_DIR = os.path.join(INPUT_DIR, "test")
# IMG_SIZE = [256, 256]
# IMG_SIZE = [128, 128]
IMG_SIZE = [512, 512]
SURFACE_LIST = [
                range(26, 36, 3),
                range(27, 37, 3),                
                range(25, 35, 3),
                ]
print(len(SURFACE_LIST[0]))
print(SURFACE_LIST)

SURFACE_NUM = len(SURFACE_LIST[0])
# print("Start surface idx =",START_SURFACE)

# SLIDE_POS_LIST = [[idx*(IMG_SIZE[0]//6), idx*(IMG_SIZE[1]//6)] for idx in range(0, 3)]
SLIDE_POS_LIST = [[0,0], [IMG_SIZE[0]//2, 0], [0, IMG_SIZE[1]//2], [IMG_SIZE[0]//2, IMG_SIZE[1]//2]]
print("SLIDE_POS_LIST =", SLIDE_POS_LIST)
CFG = {
    "DEBUG" : False,
    # exp setting
    "EXP_CATEGORY" : "5fold",
    "EXP_NAME" : "exp016_2",
    "folds" : [0, 1, 2, 3, 4],

    # model
    # "model_name" : "tf_efficientnet_b0",
    "model_name" : "tf_efficientnet_b6",
    "inp_channels" : SURFACE_NUM,
    "out_channels" : 1,
    "pretrained" : True,
    "out_indices" : [0,1,2,3,4],
 
    # data   
    "img_size": IMG_SIZE,
    # "batch_size": 32,
    # "batch_size": 16,#batch normの関係か？16の方が64より安定してそう？？
    "batch_size": 8,
    "INPUT_DIR": INPUT_DIR,
    "TRAIN_DIR": TRAIN_DIR,
    "TEST_DIR": TEST_DIR,
    "surface_num": SURFACE_NUM,
    "surface_list": list(SURFACE_LIST),
    "slide_pos_list": SLIDE_POS_LIST,
#     "surface_start_idx": START_SURFACE,
    # "TRAIN_DIR_LIST": [["1", "2"], ["1", "3"], ["2", "3"]],
    "TRAIN_DIR_LIST": [["1", "2_0", "2_1", "2_2"], 
                       ["1", "2_0", "2_1", "3"],
                       ["1", "2_0",  "2_2", "3"],
                       ["1", "2_1", "2_2", "3"],
                       ["2_0", "2_1", "2_2", "3"],
                       ],
#     "TRAIN_IDX_LIST" : ["1"],
    # "VALID_DIR_LIST": [["3"],["2"],["1"]],
    "VALID_DIR_LIST": [["3"], ["2_2"], ["2_1"], ["2_0"],["1"]],
    "TEST_DIR_LIST": ["a", "b"],

    # learning
    "n_epoch" : 10,
    "lr" : 1e-3,
    "T_max" : 5,
    "min_lr" : 1e-8,
    "weight_decay" : 1e-6,

    # etc
    "print_freq" : 1000,
    "random_seed" : 21,
    "num_workers": 2,
}


if CFG["model_name"]=="tf_efficientnet_b0":
    CFG["channel_nums"] = [320, 112, 40, 24, 16]
elif CFG["model_name"]=="tf_efficientnet_b4":
    CFG["channel_nums"] = [448, 160, 56, 32, 24]
elif CFG["model_name"]=="tf_efficientnet_b6":
    CFG["channel_nums"] = [576, 200, 72, 40, 32]


if CFG["DEBUG"]:
    CFG["n_epoch"] = 1
    CFG["EXP_NAME"] = "DEBUG"
    

CFG["OUTPUT_DIR"] = os.path.join(BASE_DIR, "output", CFG["EXP_NAME"])
# Out:
# 4
# [range(26, 36, 3), range(27, 37, 3), range(25, 35, 3)]
# SLIDE_POS_LIST = [[0, 0], [256, 0], [0, 256], [256, 256]]

# %%
if not CFG["DEBUG"]:
    os.makedirs(CFG["OUTPUT_DIR"])
    os.makedirs(os.path.join(CFG["OUTPUT_DIR"], "imgs"))

# %%
if not CFG["DEBUG"]:
    WANDB_CONFIG = {'competition': 'vcid', '_wandb_kernel': 'taro'}
    os.environ["WANDB_SILENT"] = "true"
    wandb.init(project=WANDB_CONFIG["competition"], config=CFG, group=CFG["EXP_CATEGORY"], name=CFG["EXP_NAME"], reinit=True)
# Out:
# 2023-04-18 22:13:59.312821: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-18 22:13:59.397220: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-18 22:14:00.001906: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-18 22:14:00.001993: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-18 22:14:00.002000: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# # utils

# %%
def logging_metrics_epoch(CFG, fold, epoch, slice_idx,train_loss_avg, valid_loss_avg, score, threshold, auc_score):
    wandb.log({f"train/fold{fold}": train_loss_avg,
                f"valid/fold{fold}": valid_loss_avg,
                f"score/fold{fold}":score,
                f"score threshold/fold{fold}":threshold,
                f"auc/fold{fold}":auc_score,
                f"epoch/fold{fold}":epoch+slice_idx*CFG["n_epoch"],
                })

# %%
def seed_everything(seed=CFG["random_seed"]):
    #os.environ['PYTHONSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic =True
    torch.backends.cudnn.benchmark = False
seed_everything()

# device optimization
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
def asMinutes(s):
    """Convert Seconds to Minutes."""
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    """Accessing and Converting Time Data."""
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))

class AverageMeter(object):
    """Computes and stores the average and current value."""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# # metric

# %%
def fbeta_numpy(targets, preds, beta=0.5, smooth=1e-5):
    y_true_count = targets.sum()
    ctp = preds[targets==1].sum()
    cfp = preds[targets==0].sum()
    beta_squared = beta * beta

    c_precision = ctp / (ctp + cfp + smooth)
    c_recall = ctp / (y_true_count + smooth)
    dice = (1 + beta_squared) * (c_precision * c_recall) / (beta_squared * c_precision + c_recall + smooth)

    return dice

def calc_fbeta_auc(mask, mask_pred):
    mask = mask.astype(int).flatten()
    mask_pred = mask_pred.flatten()

    best_th = 0
    best_dice = 0
    dice_list = [] 
    # for th in np.array(range(10, 50+1, 5)) / 100:
    for th in np.array(range(10, 100+1, 5)) / 100:
        # dice = fbeta_score(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice = fbeta_numpy(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice_list.append(dice)
        # print(f'\t th: {th}, fbeta: {dice}')
        if dice > best_dice:
            best_dice = dice
            best_th = th
    
    auc = roc_auc_score(mask, mask_pred)
    # Logger.info(f'best_th: {best_th}, fbeta: {best_dice}')
    return best_dice, best_th, auc, dice_list


def calc_cv(mask_gt, mask_pred):
    best_dice, best_th, auc, dice_list = calc_fbeta_auc(mask_gt, mask_pred)

    return best_dice, best_th, auc, dice_list

# %% [markdown]
# # model

# %%
class Encoder(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = timm.create_model(CFG["model_name"], in_chans=CFG["inp_channels"], features_only=True, out_indices=CFG["out_indices"], pretrained=CFG["pretrained"])
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        return skip_connection_list

class UpConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.bn1 = nn.BatchNorm2d(in_channels)
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size = 2, padding="same")
        self.bn2 = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        x = self.up(x)
        x = self.bn1(x)
        x = self.conv(x)
        x = self.bn2(x)
        return x


class Decoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.UpConv_0 = UpConv(CFG["channel_nums"][0], CFG["channel_nums"][1])
        self.UpConv_1 = UpConv(CFG["channel_nums"][1]*2, CFG["channel_nums"][2])
        self.UpConv_2 = UpConv(CFG["channel_nums"][2]*2, CFG["channel_nums"][3])
        self.UpConv_3 = UpConv(CFG["channel_nums"][3]*2, CFG["channel_nums"][4])
        # self.UpConv_4 = UpConv(CFG["channel_nums"][4]*2, CFG["channel_nums"][4])
    
    def forward(self, skip_connection_list):
        emb = self.UpConv_0(skip_connection_list[4]) # emb.shape = (None, 160, 14, 14)
        emb_cat = torch.cat([skip_connection_list[3], emb], dim = 1)
        
        emb = self.UpConv_1(emb_cat)
        emb_cat = torch.cat([skip_connection_list[2], emb], dim = 1)
        
        emb = self.UpConv_2(emb_cat)
        emb_cat = torch.cat([skip_connection_list[1], emb], dim = 1)
        
        emb = self.UpConv_3(emb_cat)
        emb_cat = torch.cat([skip_connection_list[0], emb], dim = 1)

        # emb_cat = self.UpConv_4(emb_cat)
        
        return emb_cat

class SegModel(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = Encoder(CFG)
        self.decoder = Decoder()
        self.head = nn.Sequential(
            nn.Conv2d(CFG["channel_nums"][-1]*2, CFG["out_channels"], kernel_size=1, stride=1, padding=0),
            nn.Sigmoid()
        )
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        emb = self.decoder(skip_connection_list)
        output = self.head(emb)
        return output

# %% [markdown]
# # Dataset

# %%
train_transforms = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.RandomCrop(int(CFG["img_size"][0]*0.8), int(CFG["img_size"][1]*0.8), p=0.5),
    A.Blur(blur_limit=3, p=0.3),
    A.Resize(CFG["img_size"][0], CFG["img_size"][1]),
    ToTensorV2(),
])

valid_transforms = A.Compose([
    ToTensorV2(),
])

# %%
def fft_transform(img):
    eps = 1e-7
    f = np.fft.fft2(img)
    fshift = np.fft.fftshift(f)
    fshift = np.nan_to_num(fshift)+eps#nanを0埋め
    magnitude_spectrum = 20*np.log(np.abs(fshift))
    return magnitude_spectrum

def highpass_filter(img):
    frange = 1
    dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
    dft_shift = np.fft.fftshift(dft)

    rows, cols = img.shape
    crow,ccol = rows//2 , cols//2

    # create a mask first, center square is 1, remaining all zeros
    mask = np.ones((rows,cols,2),np.uint8)
    mask[crow-frange:crow+frange, ccol-frange:ccol+frange] = 0

    # apply mask and inverse DFT
    fshift = dft_shift*mask
    f_ishift = np.fft.ifftshift(fshift)
    img_back = cv2.idft(f_ishift)
    img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

    return img_back

def lowpass_filter(img):
    frange = 5
    dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
    dft_shift = np.fft.fftshift(dft)

    rows, cols = img.shape
    crow,ccol = rows//2 , cols//2

    # create a mask first, center square is 1, remaining all zeros
    mask = np.zeros((rows,cols,2),np.uint8)
    mask[crow-frange:crow+frange, ccol-frange:ccol+frange] = 1

    # apply mask and inverse DFT
    fshift = dft_shift*mask
    f_ishift = np.fft.ifftshift(fshift)
    img_back = cv2.idft(f_ishift)
    img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

    return img_back

# %%
class VCID_Dataset(Dataset):
    def __init__(self, CFG, data_dir_list, surface_list, surface_volumes=None, slide_pos=[0,0], mode="train", transform=None):
        # get config
        self.mode = mode
        self.img_size = CFG["img_size"]
        if self.mode=="train":  self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode=="valid":    self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode == "test":   self.DATADIR = CFG["TEST_DIR"]
        self.data_dir_list = data_dir_list
        self.surface_list = surface_list
        self.slide_pos = slide_pos
        self.transform = transform
        
        # get imgs
        # print("initializing dataset...")
        self.imgs = []
        for data_dir in self.data_dir_list:
            img_path = os.path.join(self.DATADIR, data_dir, "mask.png")
            # print(img_path)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            img = img.reshape(img.shape[0], img.shape[1], 1) # (h, w, channel=1)
            self.imgs.append(img)
        
        # check imgs
        for img in self.imgs:
            assert img is not None, "img is None. data path is wrong"
        # get and split surface
        if surface_volumes is None:
            self.surface_vols = self.read_surfacevols()
        else:
            # print("using loaded surface_vols")
            self.surface_vols = surface_volumes
        for surface_vol in self.surface_vols:
            assert surface_vol is not None, "surface_vol is None. data path is wrong"
       
        # split grid
        self.get_all_grid()
        self.fileter_grid()
        self.get_flatten_grid()
        # print("split grid done.") 
       
        # get label imgs
        if self.mode == "train" or self.mode == "valid":
            self.labels = []
            for data_dir in self.data_dir_list:
                label_path = os.path.join(self.DATADIR, data_dir, "inklabels.png")
                assert os.path.exists(label_path), f"{label_path} is not exist."
                
                # read label
                label = cv2.imread(label_path, cv2.IMREAD_GRAYSCALE)
                # mask erosion
                kernel_size = (img.shape[0]+img.shape[1])//2//100
                kernel = np.ones((kernel_size, kernel_size), np.uint8)
                img = cv2.erode(img, kernel,iterations = 3)
                
                label = label.reshape(label.shape[0], label.shape[1], 1) # (h, w, channel=1)
                self.labels.append(label)# 画像サイズがそれぞれ違うので単純にconcatできずlist化しているs
        # print("initializing dataset done.")

    def get_surface_volumes(self):
        return self.surface_vols

    def read_surfacevols(self):
        """ read surface volume by data_dir_list and surface_list 
            Returns:surface_vuls (list): surface volume list [array(h,w,channel=surface_num), array(), ...]
        """
        surface_vols = []
        # print("reading surface volume...")
        for data_dir in self.data_dir_list:
            surface_vol_ = None
            for read_idx, surface_idx in enumerate(self.surface_list):
                # print("\r", f"reading idx : {read_idx+1}/{len(self.surface_list)}", end="")
                surface_path = os.path.join(self.DATADIR, data_dir, "surface_volume", f"{surface_idx:02}.tif")
                surface_vol = cv2.imread(surface_path, cv2.IMREAD_GRAYSCALE)
                surface_vol = surface_vol.reshape(surface_vol.shape[0], surface_vol.shape[1], 1) # (h, w, channel=1)
                if surface_vol_ is None:
                    surface_vol_ = surface_vol
                else:
                    surface_vol_ = np.concatenate([surface_vol_, surface_vol], axis=2) # (h, w, channel=surface_num)
            surface_vols.append(surface_vol_)
            # print(f"  => read surface volume done. [{data_dir}]")
        return surface_vols


    def get_grid_img(self, img, grid_idx):
        """ crop grid img from original img"""
        img_grid = img[grid_idx[0]*self.img_size[0] + self.slide_pos[0] : (grid_idx[0]+1)*self.img_size[0] + self.slide_pos[0],
                        grid_idx[1]*self.img_size[1] + self.slide_pos[1] : (grid_idx[1]+1)*self.img_size[1] + self.slide_pos[1]]
        return img_grid
    
    
    def get_masked_img(self, img, mask):
        """ multiply mask to surface_volumes """
        masked_img = None
        for channel in range(img.shape[2]):
            img_channel = img[:,:,channel].reshape(img.shape[0], img.shape[1],1)
            masked = img_channel*mask
            if masked_img is None:
                masked_img = masked.reshape(masked.shape[0], masked.shape[1], 1)
            else:
                masked = masked.reshape(masked.shape[0], masked.shape[1], 1)
                masked_img = np.concatenate([masked_img, masked], axis=2)
        return masked_img
    
    def get_grid_hpfimg(self, img, grid_idx):
        """ crop grid img from original img and hpf filter """
        img_grid = self.get_grid_img(img, grid_idx)
        img_transformed = None
        for channel in range(img_grid.shape[2]):
            img_grid_trans = highpass_filter(img_grid[:,:,channel])
            if img_transformed is None:
                img_transformed = img_grid_trans.reshape(img_grid_trans.shape[0], img_grid_trans.shape[1], 1)
            else:
                img_transformed = np.concatenate([img_transformed, img_grid_trans.reshape(img_grid_trans.shape[0], img_grid_trans.shape[1], 1)], axis=2)
        return img_transformed
    
    def get_all_grid(self):
        """ get all grid indices by img size and grid size
        """
        self.grid_indices = []
        for img in self.imgs:
            self.x_grid_size = (img.shape[0] - self.slide_pos[0]) // self.img_size[0]
            self.y_grid_size = (img.shape[1] - self.slide_pos[1]) // self.img_size[1]
            grid_img = []
            for i in range(self.x_grid_size):
                for j in range(self.y_grid_size):
                    grid_img.append([i, j])
            self.grid_indices.append(grid_img)
        return self.grid_indices
          
    def fileter_grid(self):
        """ get grid indices which mask is not 0 by all grid indices"""
        grid_indices_all = []
        for img, grid_indices in zip(self.imgs, self.grid_indices):
            grid_indices_copy = grid_indices.copy()
            for grid_idx in grid_indices:
                img_grid = self.get_grid_img(img, grid_idx)
                if img_grid.sum() == 0:
                    grid_indices_copy.remove(grid_idx)
            grid_indices_all.append(grid_indices_copy)
        self.grid_indices = grid_indices_all
        return self.grid_indices

    def get_flatten_grid(self):
        """ get flatten index list by grid indices
            Returns:flatten_grid (list): flatten index list [[img_idx, grid_idx], [img_idx, grid_idx], ...]
        """
        flatten_grid = []
        for img_idx, grid_indices in enumerate(self.grid_indices):
            for grid_idx in grid_indices:
                grid_imgidx_list = [img_idx]
                grid_imgidx_list.extend(grid_idx)
                flatten_grid.append(grid_imgidx_list)
        self.flatten_grid = flatten_grid
        return self.flatten_grid

    def __len__(self):
        return len(self.flatten_grid)

    def __getitem__(self, idx):
        # get indices
        img_grid_idx = self.flatten_grid[idx]
        img_idx = img_grid_idx[0]
        grid_idx = img_grid_idx[1:]
        # get img & surface_vol
        img = self.imgs[img_idx]
        surface_vol = self.surface_vols[img_idx]
        img = self.get_grid_img(img, grid_idx)/255.
        surface_vol = self.get_grid_img(surface_vol, grid_idx)/255.
        
        # multiple small mask 
        surface_vol = self.get_masked_img(surface_vol, img)
        assert surface_vol.shape[0]==img.shape[0] and surface_vol.shape[1]==img.shape[1] , "surface_vol_list shape is not same as img shape"
        img = surface_vol

        # transform
        if self.mode == "test":
            if self.transform:
                img = self.transform(image=img)["image"]
            else:
                img = img.transpose(2, 0, 1)
                img = torch.tensor(img, dtype=torch.float32)
            return img, grid_idx
        elif self.mode == "train" or self.mode=="valid":
            # get label(segmentation mask)
            label = self.labels[img_idx]
            label = self.get_grid_img(label, grid_idx)
            if self.transform:
                transformed = self.transform(image=img, mask=label)
                img = transformed["image"]
                label = transformed["mask"]
                label = label.permute(2, 0, 1)/255. # (channel, h, w)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            else:
                img = img.transpose(2, 0, 1) # (channel, h, w)
                label = label.transpose(2, 0, 1)/255. # (channel, h, w){}
                img = torch.tensor(img, dtype=torch.float32)
                label = torch.tensor(label, dtype=torch.float32)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            return img, label, grid_idx

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train")
# surface_volumes = dataset_notrans.surface_vols
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 1:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos=[0,50],mode="train")
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 1:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train", transform=train_transforms)
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)


# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 0:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %% [markdown]
# # train valid fn

# %%
def train_fn(train_loader, model, criterion, epoch ,optimizer, scheduler):
    model.train()
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, _) in enumerate(train_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()     
        preds = model(images)
        preds = TF.resize(img=preds, size=(CFG["img_size"][0], CFG["img_size"][1]))
        # preds = torch.sigmoid(preds)
        loss = criterion(preds, targets)
        
        losses.update(loss.item(), CFG["batch_size"]) 
        targets = targets.detach().cpu().numpy().ravel().tolist()
        preds = preds.detach().cpu().numpy().ravel().tolist()
        loss.backward() # パラメータの勾配を計算
        optimizer.step() # モデル更新
        optimizer.zero_grad() # 勾配の初期化
                
        batch_time.update(time.time() - end)
        end = time.time()
        if batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(train_loader)-1):
            print('Epoch: [{0}][{1}/{2}] '
                    'Elapsed {remain:s} '
                    'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                    .format(
                        epoch, batch_idx, len(train_loader), batch_time=batch_time, loss=losses,
                        remain=timeSince(start, float(batch_idx+1)/len(train_loader)),
            ))
        del preds, images, targets
    gc.collect()
    torch.cuda.empty_cache()
    return losses.avg

# %%
def valid_fn(model, valid_loader, criterion=None):
    model.eval()# モデルを検証モードに設定
    test_targets = []
    test_preds = []
    test_grid_idx = []
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, grid_idx) in enumerate(valid_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()
        with torch.no_grad():
            preds = model(images)
            preds = TF.resize(img=preds, size=(CFG["img_size"][0], CFG["img_size"][1]))
            if not criterion is None:
                loss = criterion(preds, targets)
        if not criterion is None:
            losses.update(loss.item(), CFG["batch_size"])
        batch_time.update(time.time() - end)

        targets = targets.detach().cpu().numpy()
        preds = preds.detach().cpu().numpy()
        
        test_preds.extend([preds[idx, :,:,:].transpose(1,2,0) for idx in range(preds.shape[0])])
        test_targets.extend([targets[idx, :,:,:].transpose(1,2,0) for idx in range(targets.shape[0])])
        test_grid_idx.extend([[x_idx, y_idx] for x_idx, y_idx in zip(grid_idx[0].tolist(), grid_idx[1].tolist())])

        if (batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(valid_loader)-1)) and (not criterion is None):
            print('EVAL: [{0}/{1}] '
                'Elapsed {remain:s} '
                'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                .format(
                    batch_idx, len(valid_loader), batch_time=batch_time, loss=losses,
                    remain=timeSince(start, float(batch_idx+1)/len(valid_loader)),
                ))
        del preds, images, targets
        gc.collect()
        torch.cuda.empty_cache()
    if criterion is None:
        return test_targets, test_preds, test_grid_idx
    else:
        return test_targets, test_preds, test_grid_idx, losses.avg

# %% [markdown]
# # training loop

# %%
# def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list):
#     # concat pred img and label to original size
#     img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
#     img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
#     img = img.reshape(img.shape[0], img.shape[1], 1)
#     pred_img = np.zeros_like(img).astype(np.float32)
#     label_img = np.zeros_like(img).astype(np.float32)
#     for img_idx, grid_idx in enumerate(grid_idx_list):
#         pred_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += img_list[img_idx]
        
#         label_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += label_list[img_idx]
#     return pred_img, label_img

# %%
def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list, slide_pos=[0,0]):
    # concat pred img and label to original size
    img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    img = img.reshape(img.shape[0], img.shape[1], 1)
    pred_img = np.zeros_like(img).astype(np.float32)
    label_img = np.zeros_like(img).astype(np.float32)
    for img_idx, grid_idx in enumerate(grid_idx_list):
        pred_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += img_list[img_idx]
        
        label_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += label_list[img_idx]
    return pred_img, label_img

# %%
def save_and_plot_oof(mode, fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary):
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_pred_img.png"), valid_preds_img*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_predbin_img.png"), valid_preds_binary*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_targets_img.png"), valid_targets_img*255)
    
    # plot preds & binary preds
    # plt.figure(dpi=100)
    # plt.subplot(1,3,1)
    # plt.imshow(valid_preds_img)
    # plt.subplot(1,3,2)
    # plt.imshow(valid_preds_binary)
    # plt.subplot(1,3,3)
    # plt.imshow(valid_targets_img)
    # plt.show()

# %%
def training_loop(CFG):
    best_score_list = []
    best_threshold_list = []
    best_epoch_list = []
    slice_ave_score_list = []
    slice_ave_auc_list = []
    slice_ave_score_threshold_list = []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} training start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        model = model.to(device)
        valid_img_slice = []
        criterion = nn.BCELoss()
        optimizer = AdamW(model.parameters(), lr=CFG["lr"], weight_decay=CFG["weight_decay"], amsgrad=False)
        # scheduler = CosineAnnealingLR(optimizer, T_max=CFG["T_max"], eta_min=CFG["min_lr"], last_epoch=-1)
        scheduler = ExponentialLR(optimizer, gamma=0.60)
        
        # training
        best_score = -np.inf
        best_auc = -np.inf
        best_valloss = np.inf
        best_auc_valloss = np.inf
        best_threshold = -1
        start_time = time.time()
        best_epoch = -1
        best_auc_epoch = -1
        valid_slice_ave = None       
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            # separate train/valid data 
            train_dirs = CFG["TRAIN_DIR_LIST"][fold]
            valid_dirs = CFG["VALID_DIR_LIST"][fold]
            train_dataset = VCID_Dataset(CFG, train_dirs, surface_list, mode="train", transform=train_transforms)
            valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, mode="valid", transform=valid_transforms)
            train_loader = DataLoader(train_dataset, batch_size=CFG["batch_size"], shuffle = True,
                                        num_workers = CFG["num_workers"], pin_memory = True)
            valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                        num_workers = CFG["num_workers"], pin_memory = True)
            for epoch in range(1, CFG["n_epoch"] + 1):
                epochs_ = epoch + CFG["n_epoch"] * slice_idx
                print(f'- epoch:{epochs_} -')
                train_loss_avg = train_fn(train_loader, model, criterion, epochs_ ,optimizer, scheduler)
                valid_targets, valid_preds, valid_grid_idx, valid_loss_avg = valid_fn(model, valid_loader, criterion)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                
                elapsed = time.time() - start_time
                print(f"\t epoch:{epochs_}, avg train loss:{train_loss_avg:.4f}, avg valid loss:{valid_loss_avg:.4f}")
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                if not CFG["DEBUG"]:
                    logging_metrics_epoch(CFG, fold, epoch, slice_idx, train_loss_avg, valid_loss_avg, valid_score, valid_threshold, auc)
                scheduler.step()
                # validationスコアがbestを更新したらモデルを保存する
                if valid_score > best_score:
                    best_epoch = epochs_
                    best_valloss = valid_loss_avg
                    best_score = valid_score
                    best_threshold = valid_threshold
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epochs_} - Save Best Score: {best_score:.4f}. Model is saved.')
                    print("dice_list: ", dice_list)
                    # save oof
                    save_and_plot_oof("score", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
                
                if auc > best_auc:
                    best_auc = auc
                    best_auc_epoch = epochs_
                    best_auc_valloss = valid_loss_avg
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_auc_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epochs_} - Save Best AUC: {best_auc:.4f}. Model is saved.')
                    # save oof
                    save_and_plot_oof("auc", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
            # valid_img_slice.append(valid_preds_img)
            if valid_slice_ave is None:
                valid_slice_ave = valid_preds_img
            else:
                valid_slice_ave += valid_preds_img
        # valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        # for idx in range(len(SURFACE_LIST)):
        #     valid_pred_slice = valid_img_slice[idx]
        #     valid_slice_ave += valid_pred_slice
        valid_slice_ave /= len(SURFACE_LIST)
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_slice_ave)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)
 
        valid_slice_binary = (valid_slice_ave > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 999, valid_slice_ave, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
        
        print(f'[fold{fold}] BEST Epoch {best_epoch} - Save Best Score:{best_score:.4f}. Best loss:{best_valloss:.4f}')
        print(f'[fold{fold}] BEST AUC Epoch {best_auc_epoch} - Save Best Score:{best_auc:.4f}. Best loss:{best_auc_valloss:.4f}')
            
        best_score_list.append(best_score)
        best_threshold_list.append(best_threshold)
        best_epoch_list.append(best_epoch)
        del model, train_loader, train_dataset, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
        
    for fold, (best_score, best_threshold, best_epoch) in enumerate(zip(best_score_list, best_threshold_list, best_epoch_list)):
        print(f"fold[{fold}] BEST SCORE = {best_score:.4f} thr={best_threshold} (epoch={best_epoch})")
        print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    return best_score_list, best_threshold_list, best_epoch_list

# %% [markdown]
# # slice inference

# %%
def slide_inference(CFG):
    start_time = time.time()
    slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list = [], [], []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} slide inference start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        # model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_fold{fold}.pth')
        model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_auc_fold{fold}.pth')
        model.load_state_dict(torch.load(model_path))
        model = model.to(device)
        valid_img_slice = None
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            surface_volumes = None
            for slide_pos in CFG["slide_pos_list"]:
                print("slide pos:", slide_pos)
                valid_dirs = CFG["VALID_DIR_LIST"][fold]
                valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos, mode="valid", transform=valid_transforms)
                surface_volumes = valid_dataset.get_surface_volumes()
                valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                            num_workers = CFG["num_workers"], pin_memory = True)

                valid_targets, valid_preds, valid_grid_idx = valid_fn(model, valid_loader)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs, slide_pos)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                save_and_plot_oof("slide", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary) 
                
                elapsed = time.time() - start_time
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                # valid_img_slice.append(valid_preds_img)
                if valid_img_slice is None:
                    valid_img_slice = valid_preds_img
                else:
                    valid_img_slice += valid_preds_img
            # valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        # for idx in range(len(SURFACE_LIST)*len(CFG["slide_pos_list"])):
        #     valid_pred_slice = valid_img_slice[idx]
        #     valid_slice_ave += valid_pred_slice
        valid_slice_ave /= len(SURFACE_LIST)*len(CFG["slide_pos_list"])
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_slice_ave)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)

        valid_slice_binary = (valid_slice_ave > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 555, valid_slice_ave, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
         
        del model, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
    return slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list

# %% [markdown]
# # main

# %%
# %%time
best_score_list, best_threshold_list, best_epoch_list = training_loop(CFG)
# Out:
# -- fold0 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# Epoch: [1][0/65] Elapsed 0m 1s (remain 1m 31s) Loss: 0.7855(0.7855)
# Epoch: [1][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.1729(0.4532)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1974(0.1974)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2776(0.3298)
# 	 epoch:1, avg train loss:0.4532, avg valid loss:0.3298
# 	 score:0.4193(th=0.700000), auc=0.869798::: time:74.99s
# Epoch 1 - Save Best Score: 0.4193. Model is saved.
# dice_list:  [0.23672689746097533, 0.27289545628088935, 0.2986838132015554, 0.31975525709229036, 0.33762751549465003, 0.35315913670733917, 0.3669421504740597, 0.37921730753454075, 0.3902827056585557, 0.4000941393538458, 0.408651296010114, 0.4154434774258388, 0.4193027126355165, 0.4176742395995534, 0.409033305833188, 0.3895358053641429, 0.35293599127403824, 0.26573990685611854, 0.0]
# Epoch 1 - Save Best AUC: 0.8698. Model is saved.
# - epoch:2 -
# Epoch: [2][0/65] Elapsed 0m 1s (remain 1m 27s) Loss: 0.2812(0.2812)
# Epoch: [2][64/65] Elapsed 0m 30s (remain 0m 0s) Loss: 0.3007(0.3822)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1726(0.1726)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2508(0.2702)
# 	 epoch:2, avg train loss:0.3822, avg valid loss:0.2702
# 	 score:0.4365(th=0.400000), auc=0.872369::: time:123.38s
# Epoch 2 - Save Best Score: 0.4365. Model is saved.
# dice_list:  [0.2317653857513791, 0.2849337473877688, 0.33341804861216684, 0.3744083615658985, 0.4077212773307908, 0.4300915474758361, 0.4365167283656225, 0.423629019524837, 0.39117171982281856, 0.3397296278292125, 0.27342447713715023, 0.19874092432490653, 0.12508479464058697, 0.06451056769055366, 0.024870778405049993, 0.006624744860352281, 0.0009703577357851514, 1.2841556665487404e-05, 0.0]
# Epoch 2 - Save Best AUC: 0.8724. Model is saved.
# - epoch:3 -
# Epoch: [3][0/65] Elapsed 0m 1s (remain 1m 23s) Loss: 0.2744(0.2744)
# Epoch: [3][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.7166(0.3592)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1453(0.1453)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2772(0.2659)
# 	 epoch:3, avg train loss:0.3592, avg valid loss:0.2659
# 	 score:0.5074(th=0.600000), auc=0.884533::: time:171.41s
# Epoch 3 - Save Best Score: 0.5074. Model is saved.
# dice_list:  [0.2570932738527474, 0.3050732667664495, 0.34471911085517276, 0.37792571729478236, 0.4066688645373602, 0.4330031872944633, 0.45723151538454554, 0.4787212477458939, 0.4958827202177255, 0.5061783585839744, 0.5073574314593567, 0.4971858565070772, 0.47274280639492605, 0.42724581674429446, 0.3494969029142099, 0.22914222422822128, 0.0944827740407605, 0.021198045202225964, 0.0]
# Epoch 3 - Save Best AUC: 0.8845. Model is saved.
# - epoch:4 -
# Epoch: [4][0/65] Elapsed 0m 1s (remain 1m 21s) Loss: 0.4406(0.4406)
# Epoch: [4][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.2442(0.3280)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1501(0.1501)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2542(0.2619)
# 	 epoch:4, avg train loss:0.3280, avg valid loss:0.2619
# 	 score:0.4906(th=0.500000), auc=0.878701::: time:219.68s
# - epoch:5 -
# Epoch: [5][0/65] Elapsed 0m 1s (remain 1m 22s) Loss: 0.3412(0.3412)
# Epoch: [5][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.2535(0.3158)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1807(0.1807)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2424(0.2710)
# 	 epoch:5, avg train loss:0.3158, avg valid loss:0.2710
# 	 score:0.5235(th=0.650000), auc=0.886608::: time:264.73s
# Epoch 5 - Save Best Score: 0.5235. Model is saved.
# dice_list:  [0.24837304087078227, 0.29831807079333805, 0.3411718299891543, 0.37656608806870223, 0.40681895428340437, 0.4339406602422618, 0.4580858248550413, 0.47910001743183683, 0.4964648547675318, 0.510041874508994, 0.5192843772566473, 0.5234513401272378, 0.5190037065756105, 0.5006620044449193, 0.4616316768853386, 0.3976814751051153, 0.29987657141229407, 0.1344634421836863, 0.0]
# Epoch 5 - Save Best AUC: 0.8866. Model is saved.
# - epoch:6 -
# Epoch: [6][0/65] Elapsed 0m 1s (remain 1m 30s) Loss: 0.2597(0.2597)
# Epoch: [6][64/65] Elapsed 0m 30s (remain 0m 0s) Loss: 0.2798(0.2985)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2452(0.2452)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2593(0.3330)
# 	 epoch:6, avg train loss:0.2985, avg valid loss:0.3330
# 	 score:0.5148(th=0.800000), auc=0.883296::: time:312.99s
# - epoch:7 -
# Epoch: [7][0/65] Elapsed 0m 1s (remain 1m 23s) Loss: 0.2569(0.2569)
# Epoch: [7][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3081(0.2856)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1707(0.1707)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2472(0.2873)
# 	 epoch:7, avg train loss:0.2856, avg valid loss:0.2873
# 	 score:0.5237(th=0.750000), auc=0.883846::: time:358.11s
# Epoch 7 - Save Best Score: 0.5237. Model is saved.
# dice_list:  [0.2561391983825709, 0.29483235203505953, 0.32578507440213933, 0.35155462032975704, 0.37594750850186753, 0.40016190097808535, 0.42313969154390846, 0.4439512623555027, 0.46242418138361585, 0.47961009816277433, 0.4956993901143906, 0.5104700248555096, 0.5211847167423959, 0.5236910681206366, 0.5117198062631915, 0.4746685351362411, 0.39018441899625367, 0.22205380096234786, 0.0]
# - epoch:8 -
# Epoch: [8][0/65] Elapsed 0m 1s (remain 1m 29s) Loss: 0.2343(0.2343)
# Epoch: [8][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.2278(0.2782)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1858(0.1858)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2456(0.2865)
# 	 epoch:8, avg train loss:0.2782, avg valid loss:0.2865
# 	 score:0.5287(th=0.750000), auc=0.885622::: time:404.76s
# Epoch 8 - Save Best Score: 0.5287. Model is saved.
# dice_list:  [0.24979089084894288, 0.2853366672532705, 0.31712225604111904, 0.34488241083790677, 0.37050251857930433, 0.39594137388843414, 0.42159187324666436, 0.44615301264232515, 0.4690117479679804, 0.4890100752599491, 0.5060243075037739, 0.519350054490859, 0.527718746633668, 0.5287062425796986, 0.5138782762164813, 0.47123856099573685, 0.3764726356469327, 0.19603786797583317, 0.0]
# - epoch:9 -
# Epoch: [9][0/65] Elapsed 0m 1s (remain 1m 28s) Loss: 0.3669(0.3669)
# Epoch: [9][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.2676(0.2729)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1886(0.1886)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2464(0.2920)
# 	 epoch:9, avg train loss:0.2729, avg valid loss:0.2920
# 	 score:0.5268(th=0.750000), auc=0.885612::: time:451.91s
# - epoch:10 -
# Epoch: [10][0/65] Elapsed 0m 1s (remain 1m 26s) Loss: 0.2224(0.2224)
# Epoch: [10][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3072(0.2694)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1752(0.1752)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2492(0.2858)
# 	 epoch:10, avg train loss:0.2694, avg valid loss:0.2858
# 	 score:0.5204(th=0.700000), auc=0.886585::: time:496.48s
# surface_list:  range(27, 37, 3)
# - epoch:11 -
# Epoch: [11][0/65] Elapsed 0m 1s (remain 1m 22s) Loss: 0.2220(0.2220)
# Epoch: [11][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.4726(0.2772)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1790(0.1790)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2356(0.2841)
# 	 epoch:11, avg train loss:0.2772, avg valid loss:0.2841
# 	 score:0.5289(th=0.750000), auc=0.887349::: time:570.72s
# Epoch 11 - Save Best Score: 0.5289. Model is saved.
# dice_list:  [0.26309858279316783, 0.29782080424520924, 0.3275377866284933, 0.35484901541952524, 0.38017001014518004, 0.40381335514833666, 0.42624471934425373, 0.4479081315331966, 0.46825033028111523, 0.4869186801333714, 0.503329066581426, 0.5177697351604214, 0.5279226282501915, 0.5289281304999098, 0.5132042678035759, 0.47157119888361243, 0.38632756473650676, 0.2140739367107627, 0.0]
# Epoch 11 - Save Best AUC: 0.8873. Model is saved.
# - epoch:12 -
# Epoch: [12][0/65] Elapsed 0m 1s (remain 1m 27s) Loss: 0.2096(0.2096)
# Epoch: [12][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.2488(0.2745)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1960(0.1960)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2372(0.2927)
# 	 epoch:12, avg train loss:0.2745, avg valid loss:0.2927
# 	 score:0.5290(th=0.750000), auc=0.887885::: time:618.42s
# Epoch 12 - Save Best Score: 0.5290. Model is saved.
# dice_list:  [0.2599701819345129, 0.29120739979475885, 0.31882006802260704, 0.3452733521551133, 0.3697860592301028, 0.392518188415721, 0.41327178408712856, 0.43350504244689986, 0.4534942533013609, 0.4728367172305379, 0.49098943135768464, 0.5070449564436698, 0.5207586466675402, 0.5290243051361068, 0.5248584598773386, 0.4957479925161715, 0.42123294462696914, 0.24651465129927966, 0.0]
# Epoch 12 - Save Best AUC: 0.8879. Model is saved.
# - epoch:13 -
# Epoch: [13][0/65] Elapsed 0m 1s (remain 1m 27s) Loss: 0.2955(0.2955)
# Epoch: [13][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.2142(0.2733)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1961(0.1961)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2344(0.2947)
# 	 epoch:13, avg train loss:0.2733, avg valid loss:0.2947
# 	 score:0.5241(th=0.750000), auc=0.885591::: time:665.97s
# - epoch:14 -
# Epoch: [14][0/65] Elapsed 0m 1s (remain 1m 36s) Loss: 0.2402(0.2402)
# Epoch: [14][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.4232(0.2807)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1927(0.1927)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2382(0.2921)
# 	 epoch:14, avg train loss:0.2807, avg valid loss:0.2921
# 	 score:0.5279(th=0.750000), auc=0.886281::: time:710.83s
# - epoch:15 -
# Epoch: [15][0/65] Elapsed 0m 1s (remain 1m 26s) Loss: 0.2210(0.2210)
# Epoch: [15][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.2931(0.2720)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1647(0.1647)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2377(0.2718)
# 	 epoch:15, avg train loss:0.2720, avg valid loss:0.2718
# 	 score:0.5285(th=0.700000), auc=0.885803::: time:755.38s
# - epoch:16 -
# Epoch: [16][0/65] Elapsed 0m 1s (remain 1m 27s) Loss: 0.1932(0.1932)
# Epoch: [16][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 1.1969(0.2868)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1786(0.1786)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2393(0.2845)
# 	 epoch:16, avg train loss:0.2868, avg valid loss:0.2845
# 	 score:0.5248(th=0.750000), auc=0.887450::: time:799.99s
# - epoch:17 -
# Epoch: [17][0/65] Elapsed 0m 1s (remain 1m 30s) Loss: 0.3274(0.3274)
# Epoch: [17][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2084(0.2777)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1616(0.1616)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2383(0.2723)
# 	 epoch:17, avg train loss:0.2777, avg valid loss:0.2723
# 	 score:0.5276(th=0.700000), auc=0.887641::: time:844.58s
# - epoch:18 -
# Epoch: [18][0/65] Elapsed 0m 1s (remain 1m 28s) Loss: 0.2419(0.2419)
# Epoch: [18][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2704(0.2762)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1664(0.1664)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2361(0.2704)
# 	 epoch:18, avg train loss:0.2762, avg valid loss:0.2704
# 	 score:0.5278(th=0.700000), auc=0.886098::: time:888.87s
# - epoch:19 -
# Epoch: [19][0/65] Elapsed 0m 1s (remain 1m 21s) Loss: 0.3107(0.3107)
# Epoch: [19][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 1.3720(0.2910)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1552(0.1552)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2407(0.2706)
# 	 epoch:19, avg train loss:0.2910, avg valid loss:0.2706
# 	 score:0.5252(th=0.650000), auc=0.886986::: time:933.43s
# - epoch:20 -
# Epoch: [20][0/65] Elapsed 0m 1s (remain 1m 22s) Loss: 0.2819(0.2819)
# Epoch: [20][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.2832(0.2809)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1747(0.1747)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2363(0.2807)
# 	 epoch:20, avg train loss:0.2809, avg valid loss:0.2807
# 	 score:0.5236(th=0.700000), auc=0.887485::: time:978.06s
# surface_list:  range(25, 35, 3)
# - epoch:21 -
# Epoch: [21][0/65] Elapsed 0m 1s (remain 1m 23s) Loss: 0.1959(0.1959)
# Epoch: [21][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.7042(0.2875)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1642(0.1642)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2580(0.2835)
# 	 epoch:21, avg train loss:0.2875, avg valid loss:0.2835
# 	 score:0.5167(th=0.700000), auc=0.880684::: time:1053.53s
# - epoch:22 -
# Epoch: [22][0/65] Elapsed 0m 1s (remain 1m 31s) Loss: 0.2923(0.2923)
# Epoch: [22][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.2487(0.2797)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1918(0.1918)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2573(0.3029)
# 	 epoch:22, avg train loss:0.2797, avg valid loss:0.3029
# 	 score:0.5162(th=0.750000), auc=0.879799::: time:1098.11s
# - epoch:23 -
# Epoch: [23][0/65] Elapsed 0m 1s (remain 1m 26s) Loss: 0.1851(0.1851)
# Epoch: [23][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2659(0.2779)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1846(0.1846)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2599(0.3088)
# 	 epoch:23, avg train loss:0.2779, avg valid loss:0.3088
# 	 score:0.5156(th=0.800000), auc=0.877237::: time:1142.32s
# - epoch:24 -
# Epoch: [24][0/65] Elapsed 0m 1s (remain 1m 25s) Loss: 0.2502(0.2502)
# Epoch: [24][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.5524(0.2773)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1595(0.1595)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2599(0.2859)
# 	 epoch:24, avg train loss:0.2773, avg valid loss:0.2859
# 	 score:0.5199(th=0.750000), auc=0.878703::: time:1186.45s
# - epoch:25 -
# Epoch: [25][0/65] Elapsed 0m 1s (remain 1m 31s) Loss: 0.2722(0.2722)
# Epoch: [25][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3558(0.2863)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1847(0.1847)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2628(0.2966)
# 	 epoch:25, avg train loss:0.2863, avg valid loss:0.2966
# 	 score:0.5098(th=0.750000), auc=0.879701::: time:1230.96s
# - epoch:26 -
# Epoch: [26][0/65] Elapsed 0m 1s (remain 1m 35s) Loss: 0.4629(0.4629)
# Epoch: [26][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.8653(0.2823)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1681(0.1681)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2560(0.2881)
# 	 epoch:26, avg train loss:0.2823, avg valid loss:0.2881
# 	 score:0.5196(th=0.750000), auc=0.878114::: time:1275.37s
# - epoch:27 -
# Epoch: [27][0/65] Elapsed 0m 1s (remain 1m 36s) Loss: 0.3022(0.3022)
# Epoch: [27][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.2309(0.2775)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1916(0.1916)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2659(0.3131)
# 	 epoch:27, avg train loss:0.2775, avg valid loss:0.3131
# 	 score:0.5181(th=0.800000), auc=0.875421::: time:1319.97s
# - epoch:28 -
# Epoch: [28][0/65] Elapsed 0m 1s (remain 1m 34s) Loss: 0.3153(0.3153)
# Epoch: [28][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.2533(0.2817)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1956(0.1956)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2635(0.3124)
# 	 epoch:28, avg train loss:0.2817, avg valid loss:0.3124
# 	 score:0.5134(th=0.800000), auc=0.877235::: time:1364.47s
# - epoch:29 -
# Epoch: [29][0/65] Elapsed 0m 1s (remain 1m 23s) Loss: 0.1966(0.1966)
# Epoch: [29][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.6257(0.2898)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1430(0.1430)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2589(0.2763)
# 	 epoch:29, avg train loss:0.2898, avg valid loss:0.2763
# 	 score:0.5227(th=0.700000), auc=0.878343::: time:1409.22s
# - epoch:30 -
# Epoch: [30][0/65] Elapsed 0m 1s (remain 1m 23s) Loss: 0.3882(0.3882)
# Epoch: [30][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.2487(0.2835)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1752(0.1752)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2605(0.2973)
# 	 epoch:30, avg train loss:0.2835, avg valid loss:0.2973
# 	 score:0.5228(th=0.750000), auc=0.876947::: time:1454.08s
# [fold0] slice ave score:0.5336(th=0.700000), auc=0.887016
# [fold0] BEST Epoch 12 - Save Best Score:0.5290. Best loss:0.2927
# [fold0] BEST AUC Epoch 12 - Save Best Score:0.8879. Best loss:0.2927
# -- fold1 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# Epoch: [1][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 1.0483(1.0483)
# Epoch: [1][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3329(0.4700)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5921(0.5921)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1262(0.4310)
# 	 epoch:1, avg train loss:0.4700, avg valid loss:0.4310
# 	 score:0.3941(th=0.350000), auc=0.776663::: time:79.02s
# Epoch 1 - Save Best Score: 0.3941. Model is saved.
# dice_list:  [0.28726407619834354, 0.3234200688524206, 0.3546043362558274, 0.37769128365307486, 0.3906945438638454, 0.39413161673992303, 0.38935744923381616, 0.3790369913512403, 0.36475225784852583, 0.34733054406890074, 0.3265334865285596, 0.3024714951444401, 0.2744619785970093, 0.24118291926710503, 0.20273240681097865, 0.16113337389455112, 0.11553675590868132, 0.058061752201664256, 0.0]
# Epoch 1 - Save Best AUC: 0.7767. Model is saved.
# - epoch:2 -
# Epoch: [2][0/60] Elapsed 0m 1s (remain 1m 29s) Loss: 0.2930(0.2930)
# Epoch: [2][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.5407(0.3548)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5544(0.5544)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0874(0.3935)
# 	 epoch:2, avg train loss:0.3548, avg valid loss:0.3935
# 	 score:0.4756(th=0.300000), auc=0.806351::: time:130.17s
# Epoch 2 - Save Best Score: 0.4756. Model is saved.
# dice_list:  [0.30125317966698506, 0.3782204518029211, 0.43342133389013626, 0.4646183560231119, 0.47555883337292365, 0.4690302163256454, 0.44571885119965576, 0.4069164162891117, 0.3560283055004265, 0.29669666183091375, 0.23386057685168238, 0.17132919530112864, 0.11393551418250641, 0.06629205715101133, 0.030969827885073978, 0.01004109690147829, 0.0015702113312159414, 1.3690246247721767e-05, 0.0]
# Epoch 2 - Save Best AUC: 0.8064. Model is saved.
# - epoch:3 -
# Epoch: [3][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.4070(0.4070)
# Epoch: [3][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.4783(0.3211)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5097(0.5097)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0769(0.3802)
# 	 epoch:3, avg train loss:0.3211, avg valid loss:0.3802
# 	 score:0.5076(th=0.400000), auc=0.826770::: time:181.75s
# Epoch 3 - Save Best Score: 0.5076. Model is saved.
# dice_list:  [0.35055521651690624, 0.40836136344721213, 0.44619023874703573, 0.4729348558316644, 0.49196211795584605, 0.5041597943781155, 0.5076034390561227, 0.4998940951610009, 0.4821290859037672, 0.4559925734491468, 0.42025142993183845, 0.374432419026284, 0.31803474304018475, 0.2502159983008904, 0.17544380873458967, 0.09891283554015617, 0.033775307504254275, 0.0017987726338765592, 0.0]
# Epoch 3 - Save Best AUC: 0.8268. Model is saved.
# - epoch:4 -
# Epoch: [4][0/60] Elapsed 0m 1s (remain 1m 23s) Loss: 0.4092(0.4092)
# Epoch: [4][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2249(0.2976)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4846(0.4846)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0757(0.3742)
# 	 epoch:4, avg train loss:0.2976, avg valid loss:0.3742
# 	 score:0.5454(th=0.350000), auc=0.836279::: time:232.57s
# Epoch 4 - Save Best Score: 0.5454. Model is saved.
# dice_list:  [0.3720557245748905, 0.4402478246611196, 0.489241064961122, 0.5224918808527987, 0.5406792545204523, 0.5453587064798329, 0.5379499309967787, 0.5194911401020651, 0.4930828318847232, 0.46147223413551774, 0.42683752204373165, 0.3895617857850694, 0.34686501940812964, 0.296596796391571, 0.23703891219291712, 0.16738053270488318, 0.09784626917466896, 0.03833560608997595, 0.0]
# Epoch 4 - Save Best AUC: 0.8363. Model is saved.
# - epoch:5 -
# Epoch: [5][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2874(0.2874)
# Epoch: [5][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3740(0.2827)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4651(0.4651)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0672(0.3685)
# 	 epoch:5, avg train loss:0.2827, avg valid loss:0.3685
# 	 score:0.5342(th=0.550000), auc=0.846406::: time:283.83s
# Epoch 5 - Save Best AUC: 0.8464. Model is saved.
# - epoch:6 -
# Epoch: [6][0/60] Elapsed 0m 1s (remain 1m 28s) Loss: 0.3764(0.3764)
# Epoch: [6][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3210(0.2635)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4714(0.4714)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0784(0.3790)
# 	 epoch:6, avg train loss:0.2635, avg valid loss:0.3790
# 	 score:0.5344(th=0.450000), auc=0.835644::: time:333.22s
# - epoch:7 -
# Epoch: [7][0/60] Elapsed 0m 1s (remain 1m 21s) Loss: 0.4181(0.4181)
# Epoch: [7][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2000(0.2549)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4904(0.4904)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0684(0.3797)
# 	 epoch:7, avg train loss:0.2549, avg valid loss:0.3797
# 	 score:0.5253(th=0.500000), auc=0.840803::: time:380.49s
# - epoch:8 -
# Epoch: [8][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.3288(0.3288)
# Epoch: [8][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2024(0.2308)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5047(0.5047)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0701(0.3754)
# 	 epoch:8, avg train loss:0.2308, avg valid loss:0.3754
# 	 score:0.5318(th=0.400000), auc=0.841799::: time:427.47s
# - epoch:9 -
# Epoch: [9][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2478(0.2478)
# Epoch: [9][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.1749(0.2415)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4800(0.4800)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0658(0.3731)
# 	 epoch:9, avg train loss:0.2415, avg valid loss:0.3731
# 	 score:0.5364(th=0.550000), auc=0.847822::: time:474.44s
# Epoch 9 - Save Best AUC: 0.8478. Model is saved.
# - epoch:10 -
# Epoch: [10][0/60] Elapsed 0m 1s (remain 1m 22s) Loss: 0.2958(0.2958)
# Epoch: [10][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2245(0.2400)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4903(0.4903)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0739(0.3816)
# 	 epoch:10, avg train loss:0.2400, avg valid loss:0.3816
# 	 score:0.5209(th=0.500000), auc=0.839602::: time:522.93s
# surface_list:  range(27, 37, 3)
# - epoch:11 -
# Epoch: [11][0/60] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2902(0.2902)
# Epoch: [11][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.1939(0.2483)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4856(0.4856)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0756(0.3840)
# 	 epoch:11, avg train loss:0.2483, avg valid loss:0.3840
# 	 score:0.5387(th=0.600000), auc=0.842876::: time:598.05s
# - epoch:12 -
# Epoch: [12][0/60] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2399(0.2399)
# Epoch: [12][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2508(0.2447)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4918(0.4918)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0743(0.3774)
# 	 epoch:12, avg train loss:0.2447, avg valid loss:0.3774
# 	 score:0.5417(th=0.550000), auc=0.843926::: time:644.84s
# - epoch:13 -
# Epoch: [13][0/60] Elapsed 0m 1s (remain 1m 16s) Loss: 0.1989(0.1989)
# Epoch: [13][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.4308(0.2466)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.5003(0.5003)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0731(0.3823)
# 	 epoch:13, avg train loss:0.2466, avg valid loss:0.3823
# 	 score:0.5330(th=0.550000), auc=0.841050::: time:691.92s
# - epoch:14 -
# Epoch: [14][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2308(0.2308)
# Epoch: [14][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3054(0.2420)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4814(0.4814)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0776(0.3763)
# 	 epoch:14, avg train loss:0.2420, avg valid loss:0.3763
# 	 score:0.5419(th=0.600000), auc=0.845850::: time:738.54s
# - epoch:15 -
# Epoch: [15][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.3138(0.3138)
# Epoch: [15][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2833(0.2511)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4868(0.4868)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0747(0.3787)
# 	 epoch:15, avg train loss:0.2511, avg valid loss:0.3787
# 	 score:0.5382(th=0.550000), auc=0.844609::: time:784.89s
# - epoch:16 -
# Epoch: [16][0/60] Elapsed 0m 1s (remain 1m 21s) Loss: 0.2514(0.2514)
# Epoch: [16][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2894(0.2393)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4894(0.4894)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0733(0.3757)
# 	 epoch:16, avg train loss:0.2393, avg valid loss:0.3757
# 	 score:0.5425(th=0.550000), auc=0.846812::: time:831.30s
# - epoch:17 -
# Epoch: [17][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2829(0.2829)
# Epoch: [17][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2713(0.2417)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4893(0.4893)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0758(0.3750)
# 	 epoch:17, avg train loss:0.2417, avg valid loss:0.3750
# 	 score:0.5435(th=0.550000), auc=0.845611::: time:877.41s
# - epoch:18 -
# Epoch: [18][0/60] Elapsed 0m 1s (remain 1m 23s) Loss: 0.2293(0.2293)
# Epoch: [18][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2395(0.2448)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4889(0.4889)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0724(0.3748)
# 	 epoch:18, avg train loss:0.2448, avg valid loss:0.3748
# 	 score:0.5455(th=0.550000), auc=0.845847::: time:923.65s
# Epoch 18 - Save Best Score: 0.5455. Model is saved.
# dice_list:  [0.3733971183584917, 0.4100571238652288, 0.4397210504935258, 0.46502440945306817, 0.48743217406053924, 0.5063970881713074, 0.5218417296997464, 0.5336739446054255, 0.5417144942642367, 0.545468723680368, 0.5439245254242172, 0.5360484868233408, 0.5196488246709801, 0.49418981820617136, 0.4577038664737516, 0.39999669668084065, 0.3023281022704782, 0.14877613299291606, 0.0]
# - epoch:19 -
# Epoch: [19][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2802(0.2802)
# Epoch: [19][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2322(0.2474)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5062(0.5062)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0754(0.3765)
# 	 epoch:19, avg train loss:0.2474, avg valid loss:0.3765
# 	 score:0.5533(th=0.500000), auc=0.845315::: time:972.09s
# Epoch 19 - Save Best Score: 0.5533. Model is saved.
# dice_list:  [0.4002863424268891, 0.44237507814839505, 0.4762414602138643, 0.5020518702356744, 0.5212036813441454, 0.5352610044784768, 0.5455361932348158, 0.5521350739381983, 0.5532505024569313, 0.5476641686048656, 0.5353984365552223, 0.5167283761578745, 0.4920697429292288, 0.4597068303097231, 0.4136658032402208, 0.34626752649312315, 0.24998238908655185, 0.10956403891960471, 0.0]
# - epoch:20 -
# Epoch: [20][0/60] Elapsed 0m 1s (remain 1m 26s) Loss: 0.2093(0.2093)
# Epoch: [20][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2602(0.2496)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4861(0.4861)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0754(0.3749)
# 	 epoch:20, avg train loss:0.2496, avg valid loss:0.3749
# 	 score:0.5485(th=0.550000), auc=0.846459::: time:1020.23s
# surface_list:  range(25, 35, 3)
# - epoch:21 -
# Epoch: [21][0/60] Elapsed 0m 1s (remain 1m 15s) Loss: 0.3400(0.3400)
# Epoch: [21][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3429(0.2438)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5084(0.5084)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0773(0.3877)
# 	 epoch:21, avg train loss:0.2438, avg valid loss:0.3877
# 	 score:0.5276(th=0.550000), auc=0.836292::: time:1097.71s
# - epoch:22 -
# Epoch: [22][0/60] Elapsed 0m 1s (remain 1m 16s) Loss: 0.1907(0.1907)
# Epoch: [22][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1526(0.2459)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5066(0.5066)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0688(0.3877)
# 	 epoch:22, avg train loss:0.2459, avg valid loss:0.3877
# 	 score:0.5287(th=0.600000), auc=0.837503::: time:1143.94s
# - epoch:23 -
# Epoch: [23][0/60] Elapsed 0m 1s (remain 1m 22s) Loss: 0.1923(0.1923)
# Epoch: [23][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2739(0.2475)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5022(0.5022)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0719(0.3815)
# 	 epoch:23, avg train loss:0.2475, avg valid loss:0.3815
# 	 score:0.5303(th=0.550000), auc=0.838985::: time:1190.30s
# - epoch:24 -
# Epoch: [24][0/60] Elapsed 0m 1s (remain 1m 25s) Loss: 0.1654(0.1654)
# Epoch: [24][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3312(0.2467)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5087(0.5087)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0637(0.3844)
# 	 epoch:24, avg train loss:0.2467, avg valid loss:0.3844
# 	 score:0.5367(th=0.500000), auc=0.837111::: time:1237.01s
# - epoch:25 -
# Epoch: [25][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2787(0.2787)
# Epoch: [25][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3155(0.2433)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5151(0.5151)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0654(0.3886)
# 	 epoch:25, avg train loss:0.2433, avg valid loss:0.3886
# 	 score:0.5218(th=0.600000), auc=0.836693::: time:1284.18s
# - epoch:26 -
# Epoch: [26][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.2845(0.2845)
# Epoch: [26][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2267(0.2491)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4991(0.4991)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0709(0.3862)
# 	 epoch:26, avg train loss:0.2491, avg valid loss:0.3862
# 	 score:0.5251(th=0.600000), auc=0.838951::: time:1330.69s
# - epoch:27 -
# Epoch: [27][0/60] Elapsed 0m 1s (remain 1m 22s) Loss: 0.1748(0.1748)
# Epoch: [27][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.5498(0.2509)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5054(0.5054)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0664(0.3831)
# 	 epoch:27, avg train loss:0.2509, avg valid loss:0.3831
# 	 score:0.5293(th=0.550000), auc=0.837202::: time:1377.16s
# - epoch:28 -
# Epoch: [28][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.1463(0.1463)
# Epoch: [28][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2702(0.2447)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5061(0.5061)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0676(0.3841)
# 	 epoch:28, avg train loss:0.2447, avg valid loss:0.3841
# 	 score:0.5303(th=0.550000), auc=0.836968::: time:1423.89s
# - epoch:29 -
# Epoch: [29][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.1938(0.1938)
# Epoch: [29][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3409(0.2481)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5096(0.5096)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0641(0.3864)
# 	 epoch:29, avg train loss:0.2481, avg valid loss:0.3864
# 	 score:0.5215(th=0.550000), auc=0.837538::: time:1470.60s
# - epoch:30 -
# Epoch: [30][0/60] Elapsed 0m 1s (remain 1m 23s) Loss: 0.3315(0.3315)
# Epoch: [30][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1872(0.2469)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5116(0.5116)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0674(0.3866)
# 	 epoch:30, avg train loss:0.2469, avg valid loss:0.3866
# 	 score:0.5267(th=0.550000), auc=0.837704::: time:1517.06s
# [fold1] slice ave score:0.5411(th=0.500000), auc=0.848629
# [fold1] BEST Epoch 19 - Save Best Score:0.5533. Best loss:0.3765
# [fold1] BEST AUC Epoch 9 - Save Best Score:0.8478. Best loss:0.3731
# -- fold2 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# Epoch: [1][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 1.1612(1.1612)
# Epoch: [1][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2467(0.5628)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.6436(0.6436)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3141(0.4377)
# 	 epoch:1, avg train loss:0.5628, avg valid loss:0.4377
# 	 score:0.3038(th=0.200000), auc=0.742326::: time:75.64s
# Epoch 1 - Save Best Score: 0.3038. Model is saved.
# dice_list:  [0.2699775240238392, 0.2930653409784882, 0.30375607801792387, 0.3001137358695381, 0.2829612118606464, 0.25637615284284626, 0.2234468246445682, 0.188209252454217, 0.15335182532155864, 0.12070382450006593, 0.09166158305049277, 0.06669247511809194, 0.04611350101188946, 0.02940362606268502, 0.016782955659649143, 0.00760222949873681, 0.0023237921108323423, 0.0003670788687139125, 0.0]
# Epoch 1 - Save Best AUC: 0.7423. Model is saved.
# - epoch:2 -
# Epoch: [2][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.3922(0.3922)
# Epoch: [2][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3727(0.3660)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5499(0.5499)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4041(0.4332)
# 	 epoch:2, avg train loss:0.3660, avg valid loss:0.4332
# 	 score:0.3680(th=0.450000), auc=0.769853::: time:127.15s
# Epoch 2 - Save Best Score: 0.3680. Model is saved.
# dice_list:  [0.26095790308738886, 0.28715820338033676, 0.3105378633892329, 0.32997076348192034, 0.3458822057026462, 0.3579636653138734, 0.36576978973728835, 0.3679915213848917, 0.3625394716749909, 0.3471239835357591, 0.3195090631263172, 0.2764366621719219, 0.21873432194199258, 0.15128447058349664, 0.08702234383566577, 0.04014699932389004, 0.01293316151413427, 0.001432026128796203, 0.0]
# Epoch 2 - Save Best AUC: 0.7699. Model is saved.
# - epoch:3 -
# Epoch: [3][0/60] Elapsed 0m 1s (remain 1m 26s) Loss: 0.3392(0.3392)
# Epoch: [3][59/60] Elapsed 0m 28s (remain 0m 0s) Loss: 0.4522(0.3395)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5396(0.5396)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4255(0.4152)
# 	 epoch:3, avg train loss:0.3395, avg valid loss:0.4152
# 	 score:0.4359(th=0.300000), auc=0.800461::: time:178.71s
# Epoch 3 - Save Best Score: 0.4359. Model is saved.
# dice_list:  [0.34573214930987334, 0.3968450424014394, 0.42435752950115524, 0.43554519757316135, 0.4359144777170098, 0.42773850184935946, 0.41116359305990285, 0.38643063832515057, 0.3530843906061386, 0.31125544155152574, 0.2616344187348768, 0.20572101253924496, 0.14812416615598525, 0.09449292048829307, 0.049508928361648046, 0.018053839147460678, 0.0030977369361262354, 0.0001490416985363351, 0.0]
# Epoch 3 - Save Best AUC: 0.8005. Model is saved.
# - epoch:4 -
# Epoch: [4][0/60] Elapsed 0m 1s (remain 1m 15s) Loss: 0.3388(0.3388)
# Epoch: [4][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2253(0.3068)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5423(0.5423)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4832(0.3978)
# 	 epoch:4, avg train loss:0.3068, avg valid loss:0.3978
# 	 score:0.4790(th=0.550000), auc=0.825572::: time:229.49s
# Epoch 4 - Save Best Score: 0.4790. Model is saved.
# dice_list:  [0.3057670941533767, 0.3416911182169129, 0.37291562034106907, 0.4008883905364643, 0.4241184485532066, 0.44232084269445415, 0.456677013216465, 0.4677731393943123, 0.4752960072959604, 0.4790098119281278, 0.4784420053530191, 0.4728450230604367, 0.4606351881448342, 0.4395190126883932, 0.4057875035196786, 0.3544569593115119, 0.275029060107003, 0.1414459560775805, 0.0]
# Epoch 4 - Save Best AUC: 0.8256. Model is saved.
# - epoch:5 -
# Epoch: [5][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2824(0.2824)
# Epoch: [5][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2964(0.3038)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4898(0.4898)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3329(0.3779)
# 	 epoch:5, avg train loss:0.3038, avg valid loss:0.3779
# 	 score:0.4922(th=0.450000), auc=0.830442::: time:281.80s
# Epoch 5 - Save Best Score: 0.4922. Model is saved.
# dice_list:  [0.34383739504169825, 0.3891250938294915, 0.42263099764927614, 0.44816818865924646, 0.467206466373127, 0.4806654354957992, 0.4891669135587134, 0.49222584606463377, 0.48829608849636585, 0.47701380685679357, 0.45675303427936215, 0.4253271831420841, 0.3798945395436683, 0.3182177881935291, 0.24009156229735476, 0.14982258987919433, 0.06194379181481763, 0.007828750550765021, 0.0]
# Epoch 5 - Save Best AUC: 0.8304. Model is saved.
# - epoch:6 -
# Epoch: [6][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.4819(0.4819)
# Epoch: [6][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2107(0.2846)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5009(0.5009)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3452(0.3748)
# 	 epoch:6, avg train loss:0.2846, avg valid loss:0.3748
# 	 score:0.5095(th=0.500000), auc=0.839651::: time:332.75s
# Epoch 6 - Save Best Score: 0.5095. Model is saved.
# dice_list:  [0.36242284771708544, 0.40691544093154614, 0.43803636527320955, 0.461301414503142, 0.4791607322539394, 0.49262612645342185, 0.5019950740487139, 0.5074593038359356, 0.5094715985478557, 0.5082829837567048, 0.5026237367216213, 0.49092084330894115, 0.47209640980873946, 0.4441651510951422, 0.40160997604370097, 0.33629765530276556, 0.2365475230661605, 0.09284756683763337, 0.0]
# Epoch 6 - Save Best AUC: 0.8397. Model is saved.
# - epoch:7 -
# Epoch: [7][0/60] Elapsed 0m 1s (remain 1m 16s) Loss: 0.3299(0.3299)
# Epoch: [7][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2098(0.2756)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4787(0.4787)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3998(0.3765)
# 	 epoch:7, avg train loss:0.2756, avg valid loss:0.3765
# 	 score:0.5081(th=0.500000), auc=0.839308::: time:383.88s
# - epoch:8 -
# Epoch: [8][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.3374(0.3374)
# Epoch: [8][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2700(0.2709)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4785(0.4785)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3926(0.3772)
# 	 epoch:8, avg train loss:0.2709, avg valid loss:0.3772
# 	 score:0.5064(th=0.550000), auc=0.841929::: time:430.66s
# Epoch 8 - Save Best AUC: 0.8419. Model is saved.
# - epoch:9 -
# Epoch: [9][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.3111(0.3111)
# Epoch: [9][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2624(0.2706)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4849(0.4849)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4001(0.3845)
# 	 epoch:9, avg train loss:0.2706, avg valid loss:0.3845
# 	 score:0.5020(th=0.600000), auc=0.842099::: time:479.78s
# Epoch 9 - Save Best AUC: 0.8421. Model is saved.
# - epoch:10 -
# Epoch: [10][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.2351(0.2351)
# Epoch: [10][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2487(0.2604)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4878(0.4878)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3376(0.3717)
# 	 epoch:10, avg train loss:0.2604, avg valid loss:0.3717
# 	 score:0.5188(th=0.500000), auc=0.843415::: time:528.80s
# Epoch 10 - Save Best Score: 0.5188. Model is saved.
# dice_list:  [0.3722729233467357, 0.41423035897142507, 0.4448135392808387, 0.4695009503132935, 0.48892858472001566, 0.5032850877658362, 0.5131821088633999, 0.5183204593849547, 0.5188401920330906, 0.5142689824045662, 0.5035514694079086, 0.4854832719287924, 0.45744279469297494, 0.41681817262217474, 0.35994737122234766, 0.2809119447632312, 0.17826219364657955, 0.057742482355311965, 0.0]
# Epoch 10 - Save Best AUC: 0.8434. Model is saved.
# surface_list:  range(27, 37, 3)
# - epoch:11 -
# Epoch: [11][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.2045(0.2045)
# Epoch: [11][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2510(0.2679)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4588(0.4588)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4451(0.3764)
# 	 epoch:11, avg train loss:0.2679, avg valid loss:0.3764
# 	 score:0.5279(th=0.550000), auc=0.846011::: time:608.18s
# Epoch 11 - Save Best Score: 0.5279. Model is saved.
# dice_list:  [0.3586928325812294, 0.3987175717364245, 0.4292834825679314, 0.4537995386130782, 0.47379328225237083, 0.49050552744581943, 0.5041805004305571, 0.5153778438268503, 0.5238918211838791, 0.5279098124935586, 0.5256100643909827, 0.5151171672689447, 0.4947902126426726, 0.46170564266682085, 0.41103996470347304, 0.3349961303689535, 0.2217300143129322, 0.08021138584834589, 0.0]
# Epoch 11 - Save Best AUC: 0.8460. Model is saved.
# - epoch:12 -
# Epoch: [12][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.2321(0.2321)
# Epoch: [12][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3513(0.2685)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4673(0.4673)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4509(0.3807)
# 	 epoch:12, avg train loss:0.2685, avg valid loss:0.3807
# 	 score:0.5206(th=0.600000), auc=0.845554::: time:658.57s
# - epoch:13 -
# Epoch: [13][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.3473(0.3473)
# Epoch: [13][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2245(0.2665)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4727(0.4727)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5031(0.3896)
# 	 epoch:13, avg train loss:0.2665, avg valid loss:0.3896
# 	 score:0.5222(th=0.650000), auc=0.845852::: time:704.91s
# - epoch:14 -
# Epoch: [14][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2947(0.2947)
# Epoch: [14][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3314(0.2584)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4598(0.4598)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4433(0.3780)
# 	 epoch:14, avg train loss:0.2584, avg valid loss:0.3780
# 	 score:0.5230(th=0.550000), auc=0.845014::: time:751.31s
# - epoch:15 -
# Epoch: [15][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2528(0.2528)
# Epoch: [15][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3031(0.2760)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4677(0.4677)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3942(0.3737)
# 	 epoch:15, avg train loss:0.2760, avg valid loss:0.3737
# 	 score:0.5230(th=0.550000), auc=0.845290::: time:797.56s
# - epoch:16 -
# Epoch: [16][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.3062(0.3062)
# Epoch: [16][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2035(0.2624)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4647(0.4647)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3789(0.3717)
# 	 epoch:16, avg train loss:0.2624, avg valid loss:0.3717
# 	 score:0.5248(th=0.500000), auc=0.846821::: time:844.34s
# Epoch 16 - Save Best AUC: 0.8468. Model is saved.
# - epoch:17 -
# Epoch: [17][0/60] Elapsed 0m 1s (remain 1m 23s) Loss: 0.5535(0.5535)
# Epoch: [17][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2336(0.2654)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.4653(0.4653)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4419(0.3792)
# 	 epoch:17, avg train loss:0.2654, avg valid loss:0.3792
# 	 score:0.5240(th=0.600000), auc=0.845410::: time:893.24s
# - epoch:18 -
# Epoch: [18][0/60] Elapsed 0m 1s (remain 1m 21s) Loss: 0.2950(0.2950)
# Epoch: [18][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2887(0.2677)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4629(0.4629)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4066(0.3730)
# 	 epoch:18, avg train loss:0.2677, avg valid loss:0.3730
# 	 score:0.5299(th=0.550000), auc=0.846160::: time:940.22s
# Epoch 18 - Save Best Score: 0.5299. Model is saved.
# dice_list:  [0.3596172656222764, 0.3995731534498, 0.4300307643674266, 0.4549599525294431, 0.47597650784271744, 0.4936300991809285, 0.5084380228196004, 0.5203988575819212, 0.5280864980100216, 0.5299264037602681, 0.5246354783292987, 0.5116846784875306, 0.4901310006578916, 0.4575866417128955, 0.4077982615847487, 0.33168402053984386, 0.21785416762813978, 0.07952240355368603, 0.0]
# - epoch:19 -
# Epoch: [19][0/60] Elapsed 0m 1s (remain 1m 24s) Loss: 0.2475(0.2475)
# Epoch: [19][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3154(0.2588)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4662(0.4662)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4028(0.3729)
# 	 epoch:19, avg train loss:0.2588, avg valid loss:0.3729
# 	 score:0.5259(th=0.550000), auc=0.845953::: time:988.80s
# - epoch:20 -
# Epoch: [20][0/60] Elapsed 0m 1s (remain 1m 26s) Loss: 0.2775(0.2775)
# Epoch: [20][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2519(0.2686)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4627(0.4627)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4149(0.3745)
# 	 epoch:20, avg train loss:0.2686, avg valid loss:0.3745
# 	 score:0.5266(th=0.550000), auc=0.846110::: time:1035.53s
# surface_list:  range(25, 35, 3)
# - epoch:21 -
# Epoch: [21][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.2623(0.2623)
# Epoch: [21][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1844(0.2669)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4917(0.4917)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4104(0.3842)
# 	 epoch:21, avg train loss:0.2669, avg valid loss:0.3842
# 	 score:0.5111(th=0.550000), auc=0.839084::: time:1111.21s
# - epoch:22 -
# Epoch: [22][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.3604(0.3604)
# Epoch: [22][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2750(0.2702)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4968(0.4968)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3763(0.3836)
# 	 epoch:22, avg train loss:0.2702, avg valid loss:0.3836
# 	 score:0.5119(th=0.500000), auc=0.838496::: time:1157.50s
# - epoch:23 -
# Epoch: [23][0/60] Elapsed 0m 1s (remain 1m 24s) Loss: 0.1676(0.1676)
# Epoch: [23][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.1857(0.2652)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4888(0.4888)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4416(0.3868)
# 	 epoch:23, avg train loss:0.2652, avg valid loss:0.3868
# 	 score:0.5094(th=0.550000), auc=0.839227::: time:1204.12s
# - epoch:24 -
# Epoch: [24][0/60] Elapsed 0m 1s (remain 1m 21s) Loss: 0.3348(0.3348)
# Epoch: [24][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3057(0.2726)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4937(0.4937)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3916(0.3838)
# 	 epoch:24, avg train loss:0.2726, avg valid loss:0.3838
# 	 score:0.5100(th=0.550000), auc=0.838641::: time:1250.65s
# - epoch:25 -
# Epoch: [25][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.1908(0.1908)
# Epoch: [25][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.1706(0.2620)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4965(0.4965)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3809(0.3828)
# 	 epoch:25, avg train loss:0.2620, avg valid loss:0.3828
# 	 score:0.5086(th=0.550000), auc=0.838685::: time:1297.10s
# - epoch:26 -
# Epoch: [26][0/60] Elapsed 0m 1s (remain 1m 22s) Loss: 0.2383(0.2383)
# Epoch: [26][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3256(0.2757)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4894(0.4894)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3750(0.3802)
# 	 epoch:26, avg train loss:0.2757, avg valid loss:0.3802
# 	 score:0.5092(th=0.500000), auc=0.838996::: time:1343.97s
# - epoch:27 -
# Epoch: [27][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2411(0.2411)
# Epoch: [27][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2398(0.2657)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4931(0.4931)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4355(0.3878)
# 	 epoch:27, avg train loss:0.2657, avg valid loss:0.3878
# 	 score:0.5117(th=0.550000), auc=0.837791::: time:1390.84s
# - epoch:28 -
# Epoch: [28][0/60] Elapsed 0m 1s (remain 1m 22s) Loss: 0.4451(0.4451)
# Epoch: [28][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2185(0.2785)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4923(0.4923)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3928(0.3851)
# 	 epoch:28, avg train loss:0.2785, avg valid loss:0.3851
# 	 score:0.5079(th=0.500000), auc=0.838867::: time:1437.54s
# - epoch:29 -
# Epoch: [29][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2749(0.2749)
# Epoch: [29][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3329(0.2753)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5026(0.5026)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3671(0.3829)
# 	 epoch:29, avg train loss:0.2753, avg valid loss:0.3829
# 	 score:0.5142(th=0.500000), auc=0.837608::: time:1484.65s
# - epoch:30 -
# Epoch: [30][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2201(0.2201)
# Epoch: [30][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2575(0.2713)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4925(0.4925)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3485(0.3818)
# 	 epoch:30, avg train loss:0.2713, avg valid loss:0.3818
# 	 score:0.5124(th=0.450000), auc=0.838886::: time:1531.53s
# [fold2] slice ave score:0.5290(th=0.500000), auc=0.847104
# [fold2] BEST Epoch 18 - Save Best Score:0.5299. Best loss:0.3730
# [fold2] BEST AUC Epoch 16 - Save Best Score:0.8468. Best loss:0.3717
# -- fold3 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# ...
# EVAL: [0/12] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0877(0.0877)
# EVAL: [11/12] Elapsed 0m 2s (remain 0m 0s) Loss: 0.1183(0.2811)
# 	 epoch:28, avg train loss:0.2688, avg valid loss:0.2811
# 	 score:0.4947(th=0.450000), auc=0.915280::: time:1399.76s
# - epoch:29 -
# Epoch: [29][0/67] Elapsed 0m 1s (remain 1m 31s) Loss: 0.2761(0.2761)
# Epoch: [29][66/67] Elapsed 0m 30s (remain 0m 0s) Loss: 0.3355(0.2667)
# EVAL: [0/12] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0757(0.0757)
# EVAL: [11/12] Elapsed 0m 2s (remain 0m 0s) Loss: 0.1211(0.2827)
# 	 epoch:29, avg train loss:0.2667, avg valid loss:0.2827
# 	 score:0.4965(th=0.500000), auc=0.916015::: time:1445.48s
# - epoch:30 -
# Epoch: [30][0/67] Elapsed 0m 1s (remain 1m 29s) Loss: 0.2445(0.2445)
# Epoch: [30][66/67] Elapsed 0m 30s (remain 0m 0s) Loss: 0.3129(0.2651)
# EVAL: [0/12] Elapsed 0m 0s (remain 0m 4s) Loss: 0.0918(0.0918)
# EVAL: [11/12] Elapsed 0m 2s (remain 0m 0s) Loss: 0.1200(0.2830)
# 	 epoch:30, avg train loss:0.2651, avg valid loss:0.2830
# 	 score:0.4820(th=0.500000), auc=0.915124::: time:1491.28s
# [fold3] slice ave score:0.5099(th=0.500000), auc=0.918244
# [fold3] BEST Epoch 20 - Save Best Score:0.5030. Best loss:0.2778
# [fold3] BEST AUC Epoch 17 - Save Best Score:0.9204. Best loss:0.2774
# -- fold4 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# Epoch: [1][0/62] Elapsed 0m 1s (remain 1m 19s) Loss: 0.6656(0.6656)
# Epoch: [1][61/62] Elapsed 0m 29s (remain 0m 0s) Loss: 0.2625(0.4148)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0846(0.0846)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3204(0.3850)
# 	 epoch:1, avg train loss:0.4148, avg valid loss:0.3850
# 	 score:0.3520(th=0.400000), auc=0.845078::: time:80.56s
# Epoch 1 - Save Best Score: 0.3520. Model is saved.
# dice_list:  [0.2626244021296008, 0.2857374900752624, 0.3052344145724185, 0.3209561255013378, 0.3345793799380865, 0.3454123718326847, 0.35200551749178827, 0.3506257788264073, 0.33764681143414166, 0.31012776297210015, 0.2673437594155966, 0.21425607577530856, 0.15885498876902468, 0.1084810236386409, 0.06747936285732907, 0.0358814012224003, 0.011375445612208424, 0.0003198819037192591, 0.0]
# Epoch 1 - Save Best AUC: 0.8451. Model is saved.
# - epoch:2 -
# Epoch: [2][0/62] Elapsed 0m 1s (remain 1m 23s) Loss: 0.3779(0.3779)
# Epoch: [2][61/62] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2125(0.3496)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0824(0.0824)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3422(0.3713)
# 	 epoch:2, avg train loss:0.3496, avg valid loss:0.3713
# 	 score:0.3701(th=0.350000), auc=0.858058::: time:132.58s
# Epoch 2 - Save Best Score: 0.3701. Model is saved.
# dice_list:  [0.28269723190834894, 0.30889675857046583, 0.33086985471704766, 0.34817091436507475, 0.3616636811556496, 0.3701268700501108, 0.36855331732891783, 0.3482325324016942, 0.2996613065984401, 0.21998453931472567, 0.12663727155898422, 0.052068941336768634, 0.013894148671222049, 0.002204221745521015, 0.0002056315881334288, 2.5360972665575817e-05, 9.39317829980648e-07, 0.0, 0.0]
# Epoch 2 - Save Best AUC: 0.8581. Model is saved.
# - epoch:3 -
# Epoch: [3][0/62] Elapsed 0m 1s (remain 1m 25s) Loss: 0.2426(0.2426)
# Epoch: [3][61/62] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3028(0.3244)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0881(0.0881)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3976(0.3685)
# 	 epoch:3, avg train loss:0.3244, avg valid loss:0.3685
# 	 score:0.4549(th=0.500000), auc=0.878915::: time:183.53s
# Epoch 3 - Save Best Score: 0.4549. Model is saved.
# dice_list:  [0.27993761189874816, 0.31106847410549604, 0.339468325614559, 0.3666024274027972, 0.3915885954609111, 0.41390019188160476, 0.4329623403064889, 0.4472436126980931, 0.4548553365986322, 0.4537558530827664, 0.4414551480637244, 0.413870795622315, 0.36462868817470667, 0.2888473104295623, 0.18801079809479623, 0.08283068119639132, 0.014765782739845808, 0.00018312854325694872, 0.0]
# Epoch 3 - Save Best AUC: 0.8789. Model is saved.
# - epoch:4 -
# Epoch: [4][0/62] Elapsed 0m 1s (remain 1m 24s) Loss: 0.3030(0.3030)
# Epoch: [4][61/62] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3214(0.2977)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0931(0.0931)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3030(0.3729)
# 	 epoch:4, avg train loss:0.2977, avg valid loss:0.3729
# 	 score:0.4335(th=0.550000), auc=0.870234::: time:234.50s
# - epoch:5 -
# Epoch: [5][0/62] Elapsed 0m 1s (remain 1m 29s) Loss: 0.2924(0.2924)
# Epoch: [5][61/62] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3708(0.2830)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0830(0.0830)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3263(0.3887)
# 	 epoch:5, avg train loss:0.2830, avg valid loss:0.3887
# 	 score:0.4288(th=0.650000), auc=0.867106::: time:282.29s
# - epoch:6 -
# Epoch: [6][0/62] Elapsed 0m 1s (remain 1m 26s) Loss: 0.2354(0.2354)
# Epoch: [6][61/62] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1916(0.2651)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.0912(0.0912)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3330(0.3799)
# 	 epoch:6, avg train loss:0.2651, avg valid loss:0.3799
# 	 score:0.4653(th=0.650000), auc=0.872693::: time:330.11s
# Epoch 6 - Save Best Score: 0.4653. Model is saved.
# dice_list:  [0.2856401280908262, 0.3108271417977449, 0.33241348984720076, 0.35257895138967044, 0.3719428248283827, 0.390120694994953, 0.4071497633718777, 0.423125698985795, 0.4379405487354969, 0.4511927652762848, 0.4613119275604139, 0.46533655764418524, 0.45761846535138734, 0.43197412513562466, 0.3752744182265546, 0.27804298121056287, 0.14398324571353538, 0.024378201694610444, 0.0]
# - epoch:7 -
# Epoch: [7][0/62] Elapsed 0m 1s (remain 1m 25s) Loss: 0.3685(0.3685)
# Epoch: [7][61/62] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2022(0.2541)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1013(0.1013)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3503(0.3893)
# 	 epoch:7, avg train loss:0.2541, avg valid loss:0.3893
# 	 score:0.4575(th=0.650000), auc=0.870191::: time:379.64s
# - epoch:8 -
# Epoch: [8][0/62] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2205(0.2205)
# Epoch: [8][61/62] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1384(0.2604)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0998(0.0998)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3681(0.4137)
# 	 epoch:8, avg train loss:0.2604, avg valid loss:0.4137
# 	 score:0.4477(th=0.700000), auc=0.868771::: time:427.62s
# - epoch:9 -
# Epoch: [9][0/62] Elapsed 0m 1s (remain 1m 26s) Loss: 0.2767(0.2767)
# Epoch: [9][61/62] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1455(0.2514)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1012(0.1012)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3292(0.3796)
# 	 epoch:9, avg train loss:0.2514, avg valid loss:0.3796
# 	 score:0.4593(th=0.650000), auc=0.870724::: time:475.55s
# - epoch:10 -
# Epoch: [10][0/62] Elapsed 0m 1s (remain 1m 22s) Loss: 0.3792(0.3792)
# Epoch: [10][61/62] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2421(0.2442)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1058(0.1058)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3542(0.3991)
# 	 epoch:10, avg train loss:0.2442, avg valid loss:0.3991
# 	 score:0.4573(th=0.700000), auc=0.870650::: time:523.03s
# surface_list:  range(27, 37, 3)
# - epoch:11 -
# Epoch: [11][0/62] Elapsed 0m 1s (remain 1m 24s) Loss: 0.1912(0.1912)
# Epoch: [11][61/62] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2379(0.2501)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1033(0.1033)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3797(0.4110)
# 	 epoch:11, avg train loss:0.2501, avg valid loss:0.4110
# 	 score:0.4568(th=0.700000), auc=0.871838::: time:599.20s
# - epoch:12 -
# Epoch: [12][0/62] Elapsed 0m 1s (remain 1m 26s) Loss: 0.1995(0.1995)
# Epoch: [12][61/62] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2439(0.2517)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0858(0.0858)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3461(0.3856)
# 	 epoch:12, avg train loss:0.2517, avg valid loss:0.3856
# 	 score:0.4568(th=0.600000), auc=0.871484::: time:646.11s
# - epoch:13 -
# Epoch: [13][0/62] Elapsed 0m 1s (remain 1m 22s) Loss: 0.1891(0.1891)
# Epoch: [13][61/62] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2443(0.2499)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0798(0.0798)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3373(0.3761)
# 	 epoch:13, avg train loss:0.2499, avg valid loss:0.3761
# 	 score:0.4507(th=0.600000), auc=0.868851::: time:693.47s
# - epoch:14 -
# Epoch: [14][0/62] Elapsed 0m 1s (remain 1m 26s) Loss: 0.1914(0.1914)
# Epoch: [14][61/62] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2253(0.2511)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1072(0.1072)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3793(0.4034)
# 	 epoch:14, avg train loss:0.2511, avg valid loss:0.4034
# 	 score:0.4581(th=0.700000), auc=0.869985::: time:740.64s
# - epoch:15 -
# Epoch: [15][0/62] Elapsed 0m 1s (remain 1m 26s) Loss: 0.2904(0.2904)
# Epoch: [15][61/62] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1883(0.2561)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0825(0.0825)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3312(0.3774)
# 	 epoch:15, avg train loss:0.2561, avg valid loss:0.3774
# 	 score:0.4550(th=0.600000), auc=0.870465::: time:788.03s
# - epoch:16 -
# Epoch: [16][0/62] Elapsed 0m 1s (remain 1m 24s) Loss: 0.2326(0.2326)
# Epoch: [16][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2174(0.2530)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0848(0.0848)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3490(0.3872)
# 	 epoch:16, avg train loss:0.2530, avg valid loss:0.3872
# 	 score:0.4474(th=0.600000), auc=0.867631::: time:835.05s
# - epoch:17 -
# Epoch: [17][0/62] Elapsed 0m 1s (remain 1m 23s) Loss: 0.2991(0.2991)
# Epoch: [17][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2259(0.2471)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0909(0.0909)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3455(0.3839)
# 	 epoch:17, avg train loss:0.2471, avg valid loss:0.3839
# 	 score:0.4594(th=0.650000), auc=0.871603::: time:881.99s
# - epoch:18 -
# Epoch: [18][0/62] Elapsed 0m 1s (remain 1m 22s) Loss: 0.2790(0.2790)
# Epoch: [18][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2675(0.2402)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0974(0.0974)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3741(0.4090)
# 	 epoch:18, avg train loss:0.2402, avg valid loss:0.4090
# 	 score:0.4456(th=0.650000), auc=0.868227::: time:929.02s
# - epoch:19 -
# Epoch: [19][0/62] Elapsed 0m 1s (remain 1m 24s) Loss: 0.4361(0.4361)
# Epoch: [19][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.1614(0.2568)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0988(0.0988)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3690(0.3959)
# 	 epoch:19, avg train loss:0.2568, avg valid loss:0.3959
# 	 score:0.4592(th=0.650000), auc=0.869611::: time:975.93s
# - epoch:20 -
# Epoch: [20][0/62] Elapsed 0m 1s (remain 1m 24s) Loss: 0.1958(0.1958)
# Epoch: [20][61/62] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2449(0.2563)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0913(0.0913)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3466(0.3888)
# 	 epoch:20, avg train loss:0.2563, avg valid loss:0.3888
# 	 score:0.4522(th=0.650000), auc=0.870597::: time:1023.00s
# surface_list:  range(25, 35, 3)
# - epoch:21 -
# Epoch: [21][0/62] Elapsed 0m 1s (remain 1m 24s) Loss: 0.2705(0.2705)
# Epoch: [21][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2358(0.2527)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.0833(0.0833)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3330(0.3772)
# 	 epoch:21, avg train loss:0.2527, avg valid loss:0.3772
# 	 score:0.4532(th=0.650000), auc=0.871085::: time:1101.23s
# - epoch:22 -
# Epoch: [22][0/62] Elapsed 0m 1s (remain 1m 24s) Loss: 0.2470(0.2470)
# Epoch: [22][61/62] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2160(0.2500)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0900(0.0900)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3465(0.3864)
# 	 epoch:22, avg train loss:0.2500, avg valid loss:0.3864
# 	 score:0.4506(th=0.650000), auc=0.872300::: time:1148.42s
# - epoch:23 -
# Epoch: [23][0/62] Elapsed 0m 1s (remain 1m 25s) Loss: 0.2656(0.2656)
# Epoch: [23][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3991(0.2544)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0826(0.0826)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3210(0.3686)
# 	 epoch:23, avg train loss:0.2544, avg valid loss:0.3686
# 	 score:0.4555(th=0.600000), auc=0.873371::: time:1195.95s
# - epoch:24 -
# Epoch: [24][0/62] Elapsed 0m 1s (remain 1m 27s) Loss: 0.1778(0.1778)
# Epoch: [24][61/62] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1561(0.2483)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0852(0.0852)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3404(0.3813)
# 	 epoch:24, avg train loss:0.2483, avg valid loss:0.3813
# 	 score:0.4520(th=0.650000), auc=0.872189::: time:1243.15s
# - epoch:25 -
# Epoch: [25][0/62] Elapsed 0m 1s (remain 1m 29s) Loss: 0.2594(0.2594)
# Epoch: [25][61/62] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1575(0.2521)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0903(0.0903)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3407(0.3796)
# 	 epoch:25, avg train loss:0.2521, avg valid loss:0.3796
# 	 score:0.4544(th=0.650000), auc=0.873089::: time:1290.75s
# - epoch:26 -
# Epoch: [26][0/62] Elapsed 0m 1s (remain 1m 25s) Loss: 0.1829(0.1829)
# Epoch: [26][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.1720(0.2527)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0884(0.0884)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3431(0.3838)
# 	 epoch:26, avg train loss:0.2527, avg valid loss:0.3838
# 	 score:0.4545(th=0.650000), auc=0.873093::: time:1337.86s
# - epoch:27 -
# Epoch: [27][0/62] Elapsed 0m 1s (remain 1m 34s) Loss: 0.3616(0.3616)
# Epoch: [27][61/62] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2071(0.2491)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.0897(0.0897)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3402(0.3847)
# 	 epoch:27, avg train loss:0.2491, avg valid loss:0.3847
# 	 score:0.4560(th=0.650000), auc=0.871799::: time:1385.09s
# - epoch:28 -
# Epoch: [28][0/62] Elapsed 0m 1s (remain 1m 18s) Loss: 0.3218(0.3218)
# Epoch: [28][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2187(0.2533)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0812(0.0812)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3211(0.3719)
# 	 epoch:28, avg train loss:0.2533, avg valid loss:0.3719
# 	 score:0.4486(th=0.600000), auc=0.870418::: time:1431.88s
# - epoch:29 -
# Epoch: [29][0/62] Elapsed 0m 1s (remain 1m 29s) Loss: 0.3190(0.3190)
# Epoch: [29][61/62] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3368(0.2543)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 7s) Loss: 0.0852(0.0852)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3333(0.3826)
# 	 epoch:29, avg train loss:0.2543, avg valid loss:0.3826
# 	 score:0.4519(th=0.650000), auc=0.872365::: time:1478.92s
# - epoch:30 -
# Epoch: [30][0/62] Elapsed 0m 1s (remain 1m 23s) Loss: 0.2332(0.2332)
# Epoch: [30][61/62] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1745(0.2545)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0839(0.0839)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3457(0.3894)
# 	 epoch:30, avg train loss:0.2545, avg valid loss:0.3894
# 	 score:0.4476(th=0.700000), auc=0.870330::: time:1525.96s
# [fold4] slice ave score:0.4639(th=0.650000), auc=0.874446
# [fold4] BEST Epoch 6 - Save Best Score:0.4653. Best loss:0.3799
# [fold4] BEST AUC Epoch 3 - Save Best Score:0.8789. Best loss:0.3685
# fold[0] BEST SCORE = 0.5290 thr=0.75 (epoch=12)
# fold[0] slice ave score:0.5336(th=0.700000), auc=0.887016
# fold[1] BEST SCORE = 0.5533 thr=0.5 (epoch=19)
# fold[1] slice ave score:0.5411(th=0.500000), auc=0.848629
# fold[2] BEST SCORE = 0.5299 thr=0.55 (epoch=18)
# fold[2] slice ave score:0.5290(th=0.500000), auc=0.847104
# fold[3] BEST SCORE = 0.5030 thr=0.55 (epoch=20)
# fold[3] slice ave score:0.5099(th=0.500000), auc=0.918244
# fold[4] BEST SCORE = 0.4653 thr=0.65 (epoch=6)
# fold[4] slice ave score:0.4639(th=0.650000), auc=0.874446
# CPU times: user 1h 27min 11s, sys: 33min 20s, total: 2h 32s
# Wall time: 2h 6min 40s

# %% [markdown]
# ---
# # OOF SCORE INFER

# %%
# %%time
slice_ave_score_list, slice_ave_score_threshold_list, slice_ave_auc_list = slide_inference(CFG)
for fold in CFG["folds"]:
    print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    wandb.log({"OOF SCORE" : {f"slice average score":slice_ave_score_list[fold],
                            f"slice average threshold":slice_ave_score_threshold_list[fold],
                            f"slice_average auc":slice_ave_auc_list[fold],
                            }})
# Out:
# -- fold0 slide inference start --
# surface_list:  range(26, 36, 3)
# slide pos: [0, 0]
# 	 score:0.5230(th=0.750000), auc=0.884770::: time:25.20s
# slide pos: [256, 0]
# 	 score:0.5327(th=0.800000), auc=0.879260::: time:42.29s
# slide pos: [0, 256]
# 	 score:0.4971(th=0.750000), auc=0.891090::: time:58.87s
# slide pos: [256, 256]
# 	 score:0.5255(th=0.800000), auc=0.885173::: time:75.86s
# surface_list:  range(27, 37, 3)
# slide pos: [0, 0]
# 	 score:0.5290(th=0.750000), auc=0.887885::: time:99.29s
# slide pos: [256, 0]
# 	 score:0.5204(th=0.800000), auc=0.881128::: time:116.13s
# slide pos: [0, 256]
# 	 score:0.4931(th=0.750000), auc=0.891988::: time:132.36s
# slide pos: [256, 256]
# 	 score:0.4989(th=0.750000), auc=0.887550::: time:149.10s
# surface_list:  range(25, 35, 3)
# slide pos: [0, 0]
# 	 score:0.5131(th=0.800000), auc=0.876952::: time:173.02s
# slide pos: [256, 0]
# 	 score:0.5255(th=0.800000), auc=0.875749::: time:189.92s
# slide pos: [0, 256]
# 	 score:0.5097(th=0.700000), auc=0.887035::: time:206.32s
# slide pos: [256, 256]
# 	 score:0.5254(th=0.800000), auc=0.879179::: time:223.00s
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <timed exec> in <module>
#
# /tmp/ipykernel_7452/2751629770.py in slide_inference(CFG)
#      42         #     valid_pred_slice = valid_img_slice[idx]
#      43         #     valid_slice_ave += valid_pred_slice
# ---> 44         valid_slice_ave /= len(SURFACE_LIST)*len(CFG["slide_pos_list"])
#      45         valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_slice_ave)
#      46
#
# UnboundLocalError: local variable 'valid_slice_ave' referenced before assignment
# wandb: Network error (ReadTimeout), entering retry loop.
# wandb: Network error (ReadTimeout), entering retry loop.
# wandb: ERROR Error while calling W&B API: An internal error occurred. Please contact support. (<Response [500]>)
# wandb: ERROR Error while calling W&B API: An internal error occurred. Please contact support. (<Response [500]>)
# wandb: Network error (ReadTimeout), entering retry loop.
# wandb: ERROR Error while calling W&B API: An internal error occurred. Please contact support. (<Response [500]>)
# wandb: ERROR Error while calling W&B API: An internal error occurred. Please contact support. (<Response [500]>)
# wandb: ERROR Error while calling W&B API: An internal error occurred. Please contact support. (<Response [500]>)
# wandb: ERROR Error while calling W&B API: An internal error occurred. Please contact support. (<Response [500]>)
# wandb: ERROR Error while calling W&B API: An internal error occurred. Please contact support. (<Response [500]>)
# wandb: ERROR Error while calling W&B API: An internal error occurred. Please contact support. (<Response [500]>)
# wandb: Network error (ReadTimeout), entering retry loop.
# wandb: Network error (ReadTimeout), entering retry loop.
# wandb: Network error (ReadTimeout), entering retry loop.
# wandb: Network error (ReadTimeout), entering retry loop.
# wandb: Network error (ReadTimeout), entering retry loop.
# wandb: Network error (ReadTimeout), entering retry loop.
# wandb: Network error (ReadTimeout), entering retry loop.
# wandb: Network error (ReadTimeout), entering retry loop.
# wandb: Network error (ReadTimeout), entering retry loop.
# wandb: Network error (ReadTimeout), entering retry loop.
# wandb: Network error (ReadTimeout), entering retry loop.
# wandb: Network error (ReadTimeout), entering retry loop.
# wandb: Network error (ReadTimeout), entering retry loop.
# wandb: Network error (ReadTimeout), entering retry loop.
# wandb: Network error (ConnectionError), entering retry loop.

# %%
import yaml
with open(os.path.join(CFG["OUTPUT_DIR"], "Config.yaml"), "w") as f:
    yaml.dump(CFG, f)

# %%
if not CFG["DEBUG"]:
    wandb.finish()
