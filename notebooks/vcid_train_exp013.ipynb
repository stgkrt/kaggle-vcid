# %% [markdown]
# # ex013
# 5-fold

# %%
import gc
import os
import random
import time
import math

import cv2
import numpy as np
import matplotlib.pyplot as plt

# model
import torch
import torchvision
import torch.nn as nn
import timm
from torchvision.models.feature_extraction import create_feature_extractor
import torchvision.transforms.functional as TF

# data loader
import albumentations as A
from albumentations.pytorch import ToTensorV2
from torch.utils.data import DataLoader, Dataset

# training
from torch.optim import SGD, Adam, AdamW
from torch.optim.lr_scheduler import CosineAnnealingLR, CosineAnnealingWarmRestarts, ReduceLROnPlateau, ExponentialLR

# metric
from sklearn.metrics import fbeta_score, roc_auc_score

import wandb

# %% [markdown]
# # config

# %%
BASE_DIR = "/working/"
INPUT_DIR = os.path.join(BASE_DIR, "input", "vesuvius-challenge-ink-detection")
TRAIN_DIR = os.path.join(INPUT_DIR, "train")
TEST_DIR = os.path.join(INPUT_DIR, "test")
IMG_SIZE = [256, 256]
# IMG_SIZE = [128, 128]
# IMG_SIZE = [512, 512]
SURFACE_LIST = [
                range(26, 36, 3),
                range(27, 37, 3),                
                range(25, 35, 3),
                ]
print(len(SURFACE_LIST[0]))
print(SURFACE_LIST)

SURFACE_NUM = len(SURFACE_LIST[0])
# print("Start surface idx =",START_SURFACE)

# SLIDE_POS_LIST = [[idx*(IMG_SIZE[0]//6), idx*(IMG_SIZE[1]//6)] for idx in range(0, 3)]
SLIDE_POS_LIST = [[0,0], [IMG_SIZE[0]//2, 0], [0, IMG_SIZE[1]//2], [IMG_SIZE[0]//2, IMG_SIZE[1]//2]]
print("SLIDE_POS_LIST =", SLIDE_POS_LIST)
CFG = {
    "DEBUG" : False,
    # exp setting
    "EXP_CATEGORY" : "5fold",
    "EXP_NAME" : "exp013",
    "folds" : [0, 1, 2, 3, 4],

    # model
    # "model_name" : "tf_efficientnet_b0",
    "model_name" : "tf_efficientnet_b6",
    "inp_channels" : SURFACE_NUM,
    "out_channels" : 1,
    "pretrained" : True,
    "out_indices" : [0,1,2,3,4],
 
    # data   
    "img_size": IMG_SIZE,
    "batch_size": 32,
    # "batch_size": 16,#batch normの関係か？16の方が64より安定してそう？？
    "INPUT_DIR": INPUT_DIR,
    "TRAIN_DIR": TRAIN_DIR,
    "TEST_DIR": TEST_DIR,
    "surface_num": SURFACE_NUM,
    "surface_list": SURFACE_LIST,
    "slide_pos_list": SLIDE_POS_LIST,
#     "surface_start_idx": START_SURFACE,
    # "TRAIN_DIR_LIST": [["1", "2"], ["1", "3"], ["2", "3"]],
    "TRAIN_DIR_LIST": [["1", "2_0", "2_1", "2_2"], 
                       ["1", "2_0", "2_1", "3"],
                       ["1", "2_0",  "2_2", "3"],
                       ["1", "2_1", "2_2", "3"],
                       ["2_0", "2_1", "2_2", "3"],
                       ],
#     "TRAIN_IDX_LIST" : ["1"],
    # "VALID_DIR_LIST": [["3"],["2"],["1"]],
    "VALID_DIR_LIST": [["3"], ["2_2"], ["2_1"], ["2_0"],["1"]],
    "TEST_DIR_LIST": ["a", "b"],

    # learning
    "n_epoch" : 10,
    "lr" : 1e-3,
    "T_max" : 5,
    "min_lr" : 1e-8,
    "weight_decay" : 1e-6,

    # etc
    "print_freq" : 1000,
    "random_seed" : 21,
    "num_workers": 2,
}


if CFG["model_name"]=="tf_efficientnet_b0":
    CFG["channel_nums"] = [320, 112, 40, 24, 16]
elif CFG["model_name"]=="tf_efficientnet_b4":
    CFG["channel_nums"] = [448, 160, 56, 32, 24]
elif CFG["model_name"]=="tf_efficientnet_b6":
    CFG["channel_nums"] = [576, 200, 72, 40, 32]


if CFG["DEBUG"]:
    CFG["n_epoch"] = 1
    CFG["EXP_NAME"] = "DEBUG"
    

CFG["OUTPUT_DIR"] = os.path.join(BASE_DIR, "output", CFG["EXP_NAME"])
# Out:
# 4
# [range(26, 36, 3), range(27, 37, 3), range(25, 35, 3)]
# SLIDE_POS_LIST = [[0, 0], [128, 0], [0, 128], [128, 128]]

# %%
if not CFG["DEBUG"]:
    os.makedirs(CFG["OUTPUT_DIR"])
    os.makedirs(os.path.join(CFG["OUTPUT_DIR"], "imgs"))

# %%
if not CFG["DEBUG"]:
    WANDB_CONFIG = {'competition': 'vcid', '_wandb_kernel': 'taro'}
    os.environ["WANDB_SILENT"] = "true"
    wandb.init(project=WANDB_CONFIG["competition"], config=CFG, group=CFG["EXP_CATEGORY"], name=CFG["EXP_NAME"], reinit=True)
# Out:
# 2023-04-17 08:47:23.875528: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-17 08:47:23.981295: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-17 08:47:24.602850: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-17 08:47:24.602937: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-17 08:47:24.602943: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# # utils

# %%
def logging_metrics_epoch(CFG, fold, epoch, slice_idx,train_loss_avg, valid_loss_avg, score, threshold, auc_score):
    wandb.log({f"train/fold{fold}": train_loss_avg,
                f"valid/fold{fold}": valid_loss_avg,
                f"score/fold{fold}":score,
                f"score threshold/fold{fold}":threshold,
                f"auc/fold{fold}":auc_score,
                f"epoch/fold{fold}":epoch+slice_idx*CFG["n_epoch"],
                })

#     wandb.log({f"train/fold{fold}": train_loss_avg,
#             f"valid/fold{fold}": valid_loss_avg}, step=epoch+slice_idx*CFG["n_epoch"])
#     wandb.log({f"score/fold{fold}":score,
#                 f"score threshold/fold{fold}":threshold,
#                 f"auc/fold{fold}":auc_score,
#                 }, step=epoch+slice_idx*CFG["n_epoch"])

    # wandb.log({"loss avg":{f"train/fold{fold}": train_loss_avg,
    #                         f"valid/fold{fold}": valid_loss_avg}}, step=epoch+slice_idx*CFG["n_epoch"])
    # wandb.log({"Metircs" : {f"score/fold{fold}":score,
    #                         f"score threshold/fold{fold}":threshold,
    #                         f"auc/fold{fold}":auc_score,
    #                         }}, step=epoch+slice_idx*CFG["n_epoch"])

# %%
def seed_everything(seed=CFG["random_seed"]):
    #os.environ['PYTHONSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic =True
    torch.backends.cudnn.benchmark = False
seed_everything()

# device optimization
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
def asMinutes(s):
    """Convert Seconds to Minutes."""
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    """Accessing and Converting Time Data."""
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))

class AverageMeter(object):
    """Computes and stores the average and current value."""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# # metric

# %%
def fbeta_numpy(targets, preds, beta=0.5, smooth=1e-5):
    y_true_count = targets.sum()
    ctp = preds[targets==1].sum()
    cfp = preds[targets==0].sum()
    beta_squared = beta * beta

    c_precision = ctp / (ctp + cfp + smooth)
    c_recall = ctp / (y_true_count + smooth)
    dice = (1 + beta_squared) * (c_precision * c_recall) / (beta_squared * c_precision + c_recall + smooth)

    return dice

def calc_fbeta_auc(mask, mask_pred):
    mask = mask.astype(int).flatten()
    mask_pred = mask_pred.flatten()

    best_th = 0
    best_dice = 0
    dice_list = [] 
    # for th in np.array(range(10, 50+1, 5)) / 100:
    for th in np.array(range(10, 100+1, 5)) / 100:
        # dice = fbeta_score(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice = fbeta_numpy(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice_list.append(dice)
        # print(f'\t th: {th}, fbeta: {dice}')
        if dice > best_dice:
            best_dice = dice
            best_th = th
    
    auc = roc_auc_score(mask, mask_pred)
    # Logger.info(f'best_th: {best_th}, fbeta: {best_dice}')
    return best_dice, best_th, auc, dice_list


def calc_cv(mask_gt, mask_pred):
    best_dice, best_th, auc, dice_list = calc_fbeta_auc(mask_gt, mask_pred)

    return best_dice, best_th, auc, dice_list

# %% [markdown]
# # model

# %%
class Encoder(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = timm.create_model(CFG["model_name"], in_chans=CFG["inp_channels"], features_only=True, out_indices=CFG["out_indices"], pretrained=CFG["pretrained"])
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        return skip_connection_list

class UpConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.bn1 = nn.BatchNorm2d(in_channels)
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size = 2, padding="same")
        self.bn2 = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        x = self.up(x)
        x = self.bn1(x)
        x = self.conv(x)
        x = self.bn2(x)
        return x


class Decoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.UpConv_0 = UpConv(CFG["channel_nums"][0], CFG["channel_nums"][1])
        self.UpConv_1 = UpConv(CFG["channel_nums"][1]*2, CFG["channel_nums"][2])
        self.UpConv_2 = UpConv(CFG["channel_nums"][2]*2, CFG["channel_nums"][3])
        self.UpConv_3 = UpConv(CFG["channel_nums"][3]*2, CFG["channel_nums"][4])
        self.UpConv_4 = UpConv(CFG["channel_nums"][4]*2, CFG["channel_nums"][4])
    
    def forward(self, skip_connection_list):
        emb = self.UpConv_0(skip_connection_list[4]) # emb.shape = (None, 160, 14, 14)
        emb_cat = torch.cat([skip_connection_list[3], emb], dim = 1)
        
        emb = self.UpConv_1(emb_cat)
        emb_cat = torch.cat([skip_connection_list[2], emb], dim = 1)
        
        emb = self.UpConv_2(emb_cat)
        emb_cat = torch.cat([skip_connection_list[1], emb], dim = 1)
        
        emb = self.UpConv_3(emb_cat)
        emb_cat = torch.cat([skip_connection_list[0], emb], dim = 1)

        emb_cat = self.UpConv_4(emb_cat)
        
        return emb_cat

class SegModel(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = Encoder(CFG)
        self.decoder = Decoder()
        self.head = nn.Sequential(
            nn.Conv2d(CFG["channel_nums"][-1], CFG["out_channels"], kernel_size=1, stride=1, padding=0),
            nn.Sigmoid()
        )
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        emb = self.decoder(skip_connection_list)
        output = self.head(emb)
        return output

# %% [markdown]
# # Dataset

# %%
train_transforms = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.RandomCrop(int(CFG["img_size"][0]*0.8), int(CFG["img_size"][1]*0.8), p=0.5),
    A.Blur(blur_limit=3, p=0.3),
    A.Resize(CFG["img_size"][0], CFG["img_size"][1]),
    ToTensorV2(),
])

valid_transforms = A.Compose([
    ToTensorV2(),
])

# %%
def fft_transform(img):
    eps = 1e-7
    f = np.fft.fft2(img)
    fshift = np.fft.fftshift(f)
    fshift = np.nan_to_num(fshift)+eps#nanを0埋め
    magnitude_spectrum = 20*np.log(np.abs(fshift))
    return magnitude_spectrum

def highpass_filter(img):
    frange = 1
    dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
    dft_shift = np.fft.fftshift(dft)

    rows, cols = img.shape
    crow,ccol = rows//2 , cols//2

    # create a mask first, center square is 1, remaining all zeros
    mask = np.ones((rows,cols,2),np.uint8)
    mask[crow-frange:crow+frange, ccol-frange:ccol+frange] = 0

    # apply mask and inverse DFT
    fshift = dft_shift*mask
    f_ishift = np.fft.ifftshift(fshift)
    img_back = cv2.idft(f_ishift)
    img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

    return img_back

def lowpass_filter(img):
    frange = 5
    dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
    dft_shift = np.fft.fftshift(dft)

    rows, cols = img.shape
    crow,ccol = rows//2 , cols//2

    # create a mask first, center square is 1, remaining all zeros
    mask = np.zeros((rows,cols,2),np.uint8)
    mask[crow-frange:crow+frange, ccol-frange:ccol+frange] = 1

    # apply mask and inverse DFT
    fshift = dft_shift*mask
    f_ishift = np.fft.ifftshift(fshift)
    img_back = cv2.idft(f_ishift)
    img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

    return img_back

# %%
class VCID_Dataset(Dataset):
    def __init__(self, CFG, data_dir_list, surface_list, surface_volumes=None, slide_pos=[0,0], mode="train", transform=None):
        # get config
        self.mode = mode
        self.img_size = CFG["img_size"]
        if self.mode=="train":  self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode=="valid":    self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode == "test":   self.DATADIR = CFG["TEST_DIR"]
        self.data_dir_list = data_dir_list
        self.surface_list = surface_list
        self.slide_pos = slide_pos
        self.transform = transform
        
        # get imgs
        # print("initializing dataset...")
        self.imgs = []
        for data_dir in self.data_dir_list:
            img_path = os.path.join(self.DATADIR, data_dir, "mask.png")
            # print(img_path)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            img = img.reshape(img.shape[0], img.shape[1], 1) # (h, w, channel=1)
            self.imgs.append(img)
        
        # check imgs
        for img in self.imgs:
            assert img is not None, "img is None. data path is wrong"
        # get and split surface
        if surface_volumes is None:
            self.surface_vols = self.read_surfacevols()
        else:
            # print("using loaded surface_vols")
            self.surface_vols = surface_volumes
        for surface_vol in self.surface_vols:
            assert surface_vol is not None, "surface_vol is None. data path is wrong"
       
        # split grid
        self.get_all_grid()
        self.fileter_grid()
        self.get_flatten_grid()
        # print("split grid done.") 
       
        # get label imgs
        if self.mode == "train" or self.mode == "valid":
            self.labels = []
            for data_dir in self.data_dir_list:
                label_path = os.path.join(self.DATADIR, data_dir, "inklabels.png")
                assert os.path.exists(label_path), f"{label_path} is not exist."
                
                # read label
                label = cv2.imread(label_path, cv2.IMREAD_GRAYSCALE)
                # mask erosion
                kernel_size = (img.shape[0]+img.shape[1])//2//100
                kernel = np.ones((kernel_size, kernel_size), np.uint8)
                img = cv2.erode(img, kernel,iterations = 3)
                
                label = label.reshape(label.shape[0], label.shape[1], 1) # (h, w, channel=1)
                self.labels.append(label)# 画像サイズがそれぞれ違うので単純にconcatできずlist化しているs
        # print("initializing dataset done.")

    def get_surface_volumes(self):
        return self.surface_vols

    def read_surfacevols(self):
        """ read surface volume by data_dir_list and surface_list 
            Returns:surface_vuls (list): surface volume list [array(h,w,channel=surface_num), array(), ...]
        """
        surface_vols = []
        # print("reading surface volume...")
        for data_dir in self.data_dir_list:
            surface_vol_ = None
            for read_idx, surface_idx in enumerate(self.surface_list):
                # print("\r", f"reading idx : {read_idx+1}/{len(self.surface_list)}", end="")
                surface_path = os.path.join(self.DATADIR, data_dir, "surface_volume", f"{surface_idx:02}.tif")
                surface_vol = cv2.imread(surface_path, cv2.IMREAD_GRAYSCALE)
                surface_vol = surface_vol.reshape(surface_vol.shape[0], surface_vol.shape[1], 1) # (h, w, channel=1)
                if surface_vol_ is None:
                    surface_vol_ = surface_vol
                else:
                    surface_vol_ = np.concatenate([surface_vol_, surface_vol], axis=2) # (h, w, channel=surface_num)
            surface_vols.append(surface_vol_)
            # print(f"  => read surface volume done. [{data_dir}]")
        return surface_vols


    def get_grid_img(self, img, grid_idx):
        """ crop grid img from original img"""
        img_grid = img[grid_idx[0]*self.img_size[0] + self.slide_pos[0] : (grid_idx[0]+1)*self.img_size[0] + self.slide_pos[0],
                        grid_idx[1]*self.img_size[1] + self.slide_pos[1] : (grid_idx[1]+1)*self.img_size[1] + self.slide_pos[1]]
        return img_grid
    
    
    def get_masked_img(self, img, mask):
        """ multiply mask to surface_volumes """
        masked_img = None
        for channel in range(img.shape[2]):
            img_channel = img[:,:,channel].reshape(img.shape[0], img.shape[1],1)
            masked = img_channel*mask
            if masked_img is None:
                masked_img = masked.reshape(masked.shape[0], masked.shape[1], 1)
            else:
                masked = masked.reshape(masked.shape[0], masked.shape[1], 1)
                masked_img = np.concatenate([masked_img, masked], axis=2)
        return masked_img
    
    def get_grid_hpfimg(self, img, grid_idx):
        """ crop grid img from original img and hpf filter """
        img_grid = self.get_grid_img(img, grid_idx)
        img_transformed = None
        for channel in range(img_grid.shape[2]):
            img_grid_trans = highpass_filter(img_grid[:,:,channel])
            if img_transformed is None:
                img_transformed = img_grid_trans.reshape(img_grid_trans.shape[0], img_grid_trans.shape[1], 1)
            else:
                img_transformed = np.concatenate([img_transformed, img_grid_trans.reshape(img_grid_trans.shape[0], img_grid_trans.shape[1], 1)], axis=2)
        return img_transformed
    
    def get_all_grid(self):
        """ get all grid indices by img size and grid size
        """
        self.grid_indices = []
        for img in self.imgs:
            self.x_grid_size = (img.shape[0] - self.slide_pos[0]) // self.img_size[0]
            self.y_grid_size = (img.shape[1] - self.slide_pos[1]) // self.img_size[1]
            grid_img = []
            for i in range(self.x_grid_size):
                for j in range(self.y_grid_size):
                    grid_img.append([i, j])
            self.grid_indices.append(grid_img)
        return self.grid_indices
          
    def fileter_grid(self):
        """ get grid indices which mask is not 0 by all grid indices"""
        grid_indices_all = []
        for img, grid_indices in zip(self.imgs, self.grid_indices):
            grid_indices_copy = grid_indices.copy()
            for grid_idx in grid_indices:
                img_grid = self.get_grid_img(img, grid_idx)
                if img_grid.sum() == 0:
                    grid_indices_copy.remove(grid_idx)
            grid_indices_all.append(grid_indices_copy)
        self.grid_indices = grid_indices_all
        return self.grid_indices

    def get_flatten_grid(self):
        """ get flatten index list by grid indices
            Returns:flatten_grid (list): flatten index list [[img_idx, grid_idx], [img_idx, grid_idx], ...]
        """
        flatten_grid = []
        for img_idx, grid_indices in enumerate(self.grid_indices):
            for grid_idx in grid_indices:
                grid_imgidx_list = [img_idx]
                grid_imgidx_list.extend(grid_idx)
                flatten_grid.append(grid_imgidx_list)
        self.flatten_grid = flatten_grid
        return self.flatten_grid

    def __len__(self):
        return len(self.flatten_grid)

    def __getitem__(self, idx):
        # get indices
        img_grid_idx = self.flatten_grid[idx]
        img_idx = img_grid_idx[0]
        grid_idx = img_grid_idx[1:]
        # get img & surface_vol
        img = self.imgs[img_idx]
        surface_vol = self.surface_vols[img_idx]
        img = self.get_grid_img(img, grid_idx)/255.
        surface_vol = self.get_grid_img(surface_vol, grid_idx)/255.
        
        # multiple small mask 
        surface_vol = self.get_masked_img(surface_vol, img)
        assert surface_vol.shape[0]==img.shape[0] and surface_vol.shape[1]==img.shape[1] , "surface_vol_list shape is not same as img shape"
        img = surface_vol

        # transform
        if self.mode == "test":
            if self.transform:
                img = self.transform(image=img)["image"]
            else:
                img = img.transpose(2, 0, 1)
                img = torch.tensor(img, dtype=torch.float32)
            return img, grid_idx
        elif self.mode == "train" or self.mode=="valid":
            # get label(segmentation mask)
            label = self.labels[img_idx]
            label = self.get_grid_img(label, grid_idx)
            if self.transform:
                transformed = self.transform(image=img, mask=label)
                img = transformed["image"]
                label = transformed["mask"]
                label = label.permute(2, 0, 1)/255. # (channel, h, w)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            else:
                img = img.transpose(2, 0, 1) # (channel, h, w)
                label = label.transpose(2, 0, 1)/255. # (channel, h, w){}
                img = torch.tensor(img, dtype=torch.float32)
                label = torch.tensor(label, dtype=torch.float32)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            return img, label, grid_idx

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train")
# surface_volumes = dataset_notrans.surface_vols
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 1:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos=[0,50],mode="train")
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 1:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train", transform=train_transforms)
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)


# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 0:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %% [markdown]
# # train valid fn

# %%
def train_fn(train_loader, model, criterion, epoch ,optimizer, scheduler):
    model.train()
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, _) in enumerate(train_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()     
        preds = model(images)
        
        # preds = torch.sigmoid(preds)
        loss = criterion(preds, targets)
        
        losses.update(loss.item(), CFG["batch_size"]) 
        targets = targets.detach().cpu().numpy().ravel().tolist()
        preds = preds.detach().cpu().numpy().ravel().tolist()
        loss.backward() # パラメータの勾配を計算
        optimizer.step() # モデル更新
        optimizer.zero_grad() # 勾配の初期化
                
        batch_time.update(time.time() - end)
        end = time.time()
        if batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(train_loader)-1):
            print('Epoch: [{0}][{1}/{2}] '
                    'Elapsed {remain:s} '
                    'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                    .format(
                        epoch, batch_idx, len(train_loader), batch_time=batch_time, loss=losses,
                        remain=timeSince(start, float(batch_idx+1)/len(train_loader)),
            ))
        del preds, images, targets
    gc.collect()
    torch.cuda.empty_cache()
    return losses.avg

# %%
def valid_fn(model, valid_loader, criterion=None):
    model.eval()# モデルを検証モードに設定
    test_targets = []
    test_preds = []
    test_grid_idx = []
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, grid_idx) in enumerate(valid_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()
        with torch.no_grad():
            preds = model(images)
            if not criterion is None:
                loss = criterion(preds, targets)
        if not criterion is None:
            losses.update(loss.item(), CFG["batch_size"])
        batch_time.update(time.time() - end)

        targets = targets.detach().cpu().numpy()
        preds = preds.detach().cpu().numpy()
        
        test_preds.extend([preds[idx, :,:,:].transpose(1,2,0) for idx in range(preds.shape[0])])
        test_targets.extend([targets[idx, :,:,:].transpose(1,2,0) for idx in range(targets.shape[0])])
        test_grid_idx.extend([[x_idx, y_idx] for x_idx, y_idx in zip(grid_idx[0].tolist(), grid_idx[1].tolist())])

        if (batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(valid_loader)-1)) and (not criterion is None):
            print('EVAL: [{0}/{1}] '
                'Elapsed {remain:s} '
                'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                .format(
                    batch_idx, len(valid_loader), batch_time=batch_time, loss=losses,
                    remain=timeSince(start, float(batch_idx+1)/len(valid_loader)),
                ))
        del preds, images, targets
        gc.collect()
        torch.cuda.empty_cache()
    if criterion is None:
        return test_targets, test_preds, test_grid_idx
    else:
        return test_targets, test_preds, test_grid_idx, losses.avg

# %% [markdown]
# # training loop

# %%
# def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list):
#     # concat pred img and label to original size
#     img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
#     img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
#     img = img.reshape(img.shape[0], img.shape[1], 1)
#     pred_img = np.zeros_like(img).astype(np.float32)
#     label_img = np.zeros_like(img).astype(np.float32)
#     for img_idx, grid_idx in enumerate(grid_idx_list):
#         pred_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += img_list[img_idx]
        
#         label_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += label_list[img_idx]
#     return pred_img, label_img

# %%
def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list, slide_pos=[0,0]):
    # concat pred img and label to original size
    img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    img = img.reshape(img.shape[0], img.shape[1], 1)
    pred_img = np.zeros_like(img).astype(np.float32)
    label_img = np.zeros_like(img).astype(np.float32)
    for img_idx, grid_idx in enumerate(grid_idx_list):
        pred_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += img_list[img_idx]
        
        label_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += label_list[img_idx]
    return pred_img, label_img

# %%
def save_and_plot_oof(mode, fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary):
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_pred_img.png"), valid_preds_img*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_predbin_img.png"), valid_preds_binary*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_targets_img.png"), valid_targets_img*255)
    
    # plot preds & binary preds
    # plt.figure(dpi=100)
    # plt.subplot(1,3,1)
    # plt.imshow(valid_preds_img)
    # plt.subplot(1,3,2)
    # plt.imshow(valid_preds_binary)
    # plt.subplot(1,3,3)
    # plt.imshow(valid_targets_img)
    # plt.show()

# %%
def training_loop(CFG):
    best_score_list = []
    best_threshold_list = []
    best_epoch_list = []
    slice_ave_score_list = []
    slice_ave_auc_list = []
    slice_ave_score_threshold_list = []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} training start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        model = model.to(device)
        valid_img_slice = []
        criterion = nn.BCELoss()
        optimizer = AdamW(model.parameters(), lr=CFG["lr"], weight_decay=CFG["weight_decay"], amsgrad=False)
        # scheduler = CosineAnnealingLR(optimizer, T_max=CFG["T_max"], eta_min=CFG["min_lr"], last_epoch=-1)
        scheduler = ExponentialLR(optimizer, gamma=0.60)
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            # separate train/valid data 
            train_dirs = CFG["TRAIN_DIR_LIST"][fold]
            valid_dirs = CFG["VALID_DIR_LIST"][fold]
            train_dataset = VCID_Dataset(CFG, train_dirs, surface_list, mode="train", transform=train_transforms)
            valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, mode="valid", transform=valid_transforms)
            train_loader = DataLoader(train_dataset, batch_size=CFG["batch_size"], shuffle = True,
                                        num_workers = CFG["num_workers"], pin_memory = True)
            valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                        num_workers = CFG["num_workers"], pin_memory = True)

            # training
            best_score = -np.inf
            best_auc = -np.inf
            best_valloss = np.inf
            best_auc_valloss = np.inf
            best_threshold = -1
            start_time = time.time()
            best_epoch = -1
            best_auc_epoch = -1
            for epoch in range(1, CFG["n_epoch"] + 1):
                epochs_ = epoch + CFG["n_epoch"] * slice_idx
                print(f'- epoch:{epochs_} -')
                train_loss_avg = train_fn(train_loader, model, criterion, epochs_ ,optimizer, scheduler)
                valid_targets, valid_preds, valid_grid_idx, valid_loss_avg = valid_fn(model, valid_loader, criterion)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                
                elapsed = time.time() - start_time
                print(f"\t epoch:{epochs_}, avg train loss:{train_loss_avg:.4f}, avg valid loss:{valid_loss_avg:.4f}")
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                if not CFG["DEBUG"]:
                    logging_metrics_epoch(CFG, fold, epoch, slice_idx, train_loss_avg, valid_loss_avg, valid_score, valid_threshold, auc)
                scheduler.step()
                # validationスコアがbestを更新したらモデルを保存する
                if valid_score > best_score:
                    best_epoch = epochs_
                    best_valloss = valid_loss_avg
                    best_score = valid_score
                    best_threshold = valid_threshold
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epochs_} - Save Best Score: {best_score:.4f}. Model is saved.')
                    print("dice_list: ", dice_list)
                    # save oof
                    save_and_plot_oof("score", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
                
                if auc > best_auc:
                    best_auc = auc
                    best_auc_epoch = epochs_
                    best_auc_valloss = valid_loss_avg
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_auc_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epochs_} - Save Best AUC: {best_auc:.4f}. Model is saved.')
                    # save oof
                    save_and_plot_oof("auc", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
            valid_img_slice.append(valid_preds_img)
        valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        for idx in range(len(SURFACE_LIST)):
            valid_pred_slice = valid_img_slice[idx]
            valid_slice_ave += valid_pred_slice
        valid_slice_ave /= len(CFG["folds"])
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_slice_ave)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)
 
        valid_slice_binary = (valid_slice_ave > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 999, valid_slice_ave, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
        
        print(f'[fold{fold}] BEST Epoch {best_epoch} - Save Best Score:{best_score:.4f}. Best loss:{best_valloss:.4f}')
        print(f'[fold{fold}] BEST AUC Epoch {best_auc_epoch} - Save Best Score:{best_auc:.4f}. Best loss:{best_auc_valloss:.4f}')
            
        best_score_list.append(best_score)
        best_threshold_list.append(best_threshold)
        best_epoch_list.append(best_epoch)
        del model, train_loader, train_dataset, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
        
    for fold, (best_score, best_threshold, best_epoch) in enumerate(zip(best_score_list, best_threshold_list, best_epoch_list)):
        print(f"fold[{fold}] BEST SCORE = {best_score:.4f} thr={best_threshold} (epoch={best_epoch})")
        print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    return best_score_list, best_threshold_list, best_epoch_list

# %% [markdown]
# # slice inference

# %%
def slide_inference(CFG):
    start_time = time.time()
    slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list = [], [], []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} slide inference start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        # model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_fold{fold}.pth')
        model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_auc_fold{fold}.pth')
        model.load_state_dict(torch.load(model_path))
        model = model.to(device)
        valid_img_slice = []
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            surface_volumes = None
            for slide_pos in CFG["slide_pos_list"]:
                print("slide pos:", slide_pos)
                valid_dirs = CFG["VALID_DIR_LIST"][fold]
                valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos, mode="valid", transform=valid_transforms)
                surface_volumes = valid_dataset.get_surface_volumes()
                valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                            num_workers = CFG["num_workers"], pin_memory = True)

                valid_targets, valid_preds, valid_grid_idx = valid_fn(model, valid_loader)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs, slide_pos)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                save_and_plot_oof("slide", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary) 
                
                elapsed = time.time() - start_time
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                valid_img_slice.append(valid_preds_img)
            valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        for idx in range(len(SURFACE_LIST)*len(CFG["slide_pos_list"])):
            valid_pred_slice = valid_img_slice[idx]
            valid_slice_ave += valid_pred_slice
        valid_slice_ave /= len(SURFACE_LIST)*len(CFG["slide_pos_list"])
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_slice_ave)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)

        valid_slice_binary = (valid_slice_ave > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 555, valid_slice_ave, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
         
        del model, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
    return slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list

# %% [markdown]
# # main

# %%
# %%time
best_score_list, best_threshold_list, best_epoch_list = training_loop(CFG)
# Out:
# -- fold0 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# Epoch: [1][0/65] Elapsed 0m 1s (remain 1m 29s) Loss: 0.7128(0.7128)
# Epoch: [1][64/65] Elapsed 0m 32s (remain 0m 0s) Loss: 0.5602(0.6262)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.4670(0.4670)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.5797(0.5758)
# 	 epoch:1, avg train loss:0.6262, avg valid loss:0.5758
# 	 score:0.4121(th=0.550000), auc=0.848661::: time:47.76s
# Epoch 1 - Save Best Score: 0.4121. Model is saved.
# dice_list:  [0.13807337487286492, 0.13807824179756636, 0.13815450070251759, 0.1507719129192422, 0.15693577388350596, 0.1764897030221359, 0.23804101634056826, 0.33729254380103774, 0.4019126437724326, 0.4121110444377135, 0.4071242219760514, 0.39722749576072336, 0.38947526547562145, 0.3831931661418463, 0.37891886146591625, 0.3678355763966055, 0.34824717353147383, 0.31946249359720674, 0.013062137402669972]
# Epoch 1 - Save Best AUC: 0.8487. Model is saved.
# - epoch:2 -
# Epoch: [2][0/65] Elapsed 0m 1s (remain 1m 40s) Loss: 0.6161(0.6161)
# Epoch: [2][64/65] Elapsed 0m 32s (remain 0m 0s) Loss: 0.5052(0.5429)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5207(0.5207)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4761(0.5370)
# 	 epoch:2, avg train loss:0.5429, avg valid loss:0.5370
# 	 score:0.4584(th=0.850000), auc=0.861013::: time:98.55s
# Epoch 2 - Save Best Score: 0.4584. Model is saved.
# dice_list:  [0.13809508531833478, 0.13841572605570207, 0.14309549812035988, 0.16895366072512838, 0.19680868109706812, 0.23849886253882166, 0.2830027523454678, 0.31829755683326433, 0.3454942381409683, 0.36803327074315667, 0.38856208792945346, 0.4080019302087825, 0.42625067931141314, 0.44194950643197584, 0.454095856035285, 0.45840302110439163, 0.4471568344654392, 0.339414827413731, 0.0]
# Epoch 2 - Save Best AUC: 0.8610. Model is saved.
# - epoch:3 -
# Epoch: [3][0/65] Elapsed 0m 1s (remain 1m 39s) Loss: 0.5345(0.5345)
# Epoch: [3][64/65] Elapsed 0m 32s (remain 0m 0s) Loss: 0.4548(0.4714)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2929(0.2929)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3257(0.3697)
# 	 epoch:3, avg train loss:0.4714, avg valid loss:0.3697
# 	 score:0.5086(th=0.450000), auc=0.852387::: time:149.12s
# Epoch 3 - Save Best Score: 0.5086. Model is saved.
# dice_list:  [0.13807694808548568, 0.1426935649897591, 0.17711048289508097, 0.2358442061809812, 0.3413179119442328, 0.4519156508019238, 0.5045911864687443, 0.508614231271647, 0.4873965217723693, 0.4517005005776521, 0.4087159117047429, 0.35880584528321413, 0.29795821616756135, 0.23315169385610238, 0.16735505493607614, 0.11093967945846024, 0.0747130975457579, 0.04401055005791305, 0.0]
# - epoch:4 -
# Epoch: [4][0/65] Elapsed 0m 1s (remain 1m 32s) Loss: 0.3997(0.3997)
# Epoch: [4][64/65] Elapsed 0m 32s (remain 0m 0s) Loss: 0.4186(0.4256)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.3132(0.3132)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3168(0.3804)
# 	 epoch:4, avg train loss:0.4256, avg valid loss:0.3804
# 	 score:0.5292(th=0.650000), auc=0.873851::: time:198.15s
# Epoch 4 - Save Best Score: 0.5292. Model is saved.
# dice_list:  [0.13808649950010532, 0.1429984698081411, 0.18718086047311042, 0.24465411664894648, 0.31668357207024816, 0.385848676329574, 0.43292878594423695, 0.46970434238118625, 0.49806907834578396, 0.5157512075610532, 0.5253163454890377, 0.5292232616429079, 0.5230435174420096, 0.5040458473102025, 0.4730316117013372, 0.42880902172517116, 0.35180159101095954, 0.22955633054928826, 0.0]
# Epoch 4 - Save Best AUC: 0.8739. Model is saved.
# - epoch:5 -
# Epoch: [5][0/65] Elapsed 0m 1s (remain 1m 38s) Loss: 0.4042(0.4042)
# Epoch: [5][64/65] Elapsed 0m 32s (remain 0m 0s) Loss: 0.3916(0.3972)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.3027(0.3027)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2951(0.3650)
# 	 epoch:5, avg train loss:0.3972, avg valid loss:0.3650
# 	 score:0.5524(th=0.650000), auc=0.873574::: time:248.43s
# Epoch 5 - Save Best Score: 0.5524. Model is saved.
# dice_list:  [0.13833477524126583, 0.16534406921227246, 0.21144119401222666, 0.2725905311826121, 0.3444857116834793, 0.4055264778795566, 0.4529694906265744, 0.48711140358354593, 0.5109022911186653, 0.5316138628007304, 0.5464106416048733, 0.5524200702859974, 0.551603338631417, 0.5439559552148132, 0.5271070493380275, 0.5034515562169652, 0.4707145156347506, 0.3961838260867525, 0.0]
# - epoch:6 -
# Epoch: [6][0/65] Elapsed 0m 1s (remain 1m 36s) Loss: 0.3844(0.3844)
# Epoch: [6][64/65] Elapsed 0m 32s (remain 0m 0s) Loss: 0.5036(0.3737)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2654(0.2654)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2762(0.3598)
# 	 epoch:6, avg train loss:0.3737, avg valid loss:0.3598
# 	 score:0.5348(th=0.750000), auc=0.878019::: time:297.46s
# Epoch 6 - Save Best AUC: 0.8780. Model is saved.
# - epoch:7 -
# Epoch: [7][0/65] Elapsed 0m 1s (remain 1m 36s) Loss: 0.3763(0.3763)
# Epoch: [7][64/65] Elapsed 0m 32s (remain 0m 0s) Loss: 0.3576(0.3571)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2749(0.2749)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2654(0.3594)
# 	 epoch:7, avg train loss:0.3571, avg valid loss:0.3594
# 	 score:0.5444(th=0.750000), auc=0.882084::: time:346.16s
# Epoch 7 - Save Best AUC: 0.8821. Model is saved.
# - epoch:8 -
# Epoch: [8][0/65] Elapsed 0m 1s (remain 1m 38s) Loss: 0.3119(0.3119)
# Epoch: [8][64/65] Elapsed 0m 32s (remain 0m 0s) Loss: 0.3313(0.3463)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2296(0.2296)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2524(0.3460)
# 	 epoch:8, avg train loss:0.3463, avg valid loss:0.3460
# 	 score:0.5432(th=0.750000), auc=0.883266::: time:394.72s
# Epoch 8 - Save Best AUC: 0.8833. Model is saved.
# - epoch:9 -
# Epoch: [9][0/65] Elapsed 0m 1s (remain 1m 36s) Loss: 0.3285(0.3285)
# Epoch: [9][64/65] Elapsed 0m 32s (remain 0m 0s) Loss: 0.3617(0.3440)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2497(0.2497)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2789(0.3575)
# 	 epoch:9, avg train loss:0.3440, avg valid loss:0.3575
# 	 score:0.5469(th=0.700000), auc=0.879726::: time:443.47s
# - epoch:10 -
# Epoch: [10][0/65] Elapsed 0m 1s (remain 1m 41s) Loss: 0.3591(0.3591)
# wandb: Network error (ConnectionError), entering retry loop.
# Epoch: [10][64/65] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3285(0.3278)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2587(0.2587)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2714(0.3704)
# 	 epoch:10, avg train loss:0.3278, avg valid loss:0.3704
# 	 score:0.5528(th=0.800000), auc=0.881134::: time:492.95s
# Epoch 10 - Save Best Score: 0.5528. Model is saved.
# dice_list:  [0.1468871119976103, 0.20452572305174005, 0.26044841975642036, 0.31583403226542683, 0.3646852251286619, 0.4034566027135872, 0.4330753111504969, 0.45502818022385255, 0.47308749674423906, 0.4916795137426262, 0.5092043017358054, 0.525513492422753, 0.5401654826120035, 0.5502154040899672, 0.5527760306819716, 0.5464511085890728, 0.5296018984176154, 0.491386025451637, 0.09433673949023638]
# surface_list:  range(27, 37, 3)
# - epoch:11 -
# Epoch: [11][0/65] Elapsed 0m 1s (remain 1m 34s) Loss: 0.3095(0.3095)
# Epoch: [11][64/65] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3669(0.3461)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2453(0.2453)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2691(0.3571)
# 	 epoch:11, avg train loss:0.3461, avg valid loss:0.3571
# 	 score:0.5141(th=0.700000), auc=0.873551::: time:49.73s
# Epoch 11 - Save Best Score: 0.5141. Model is saved.
# dice_list:  [0.14815021752300114, 0.200033447285256, 0.25565129552377036, 0.3127078446610876, 0.36511243056449394, 0.40773183043003824, 0.4402434535812346, 0.4692411062560686, 0.49092959973244704, 0.5052150047099657, 0.5122852010154489, 0.5132022231165679, 0.5141078898153482, 0.5112496606125719, 0.5044396645550873, 0.49027799660422855, 0.456991890813886, 0.3898538986174491, 0.023789372139255728]
# Epoch 11 - Save Best AUC: 0.8736. Model is saved.
# - epoch:12 -
# Epoch: [12][0/65] Elapsed 0m 1s (remain 1m 37s) Loss: 0.3339(0.3339)
# Epoch: [12][64/65] Elapsed 0m 33s (remain 0m 0s) Loss: 0.2996(0.3388)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2345(0.2345)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2747(0.3634)
# 	 epoch:12, avg train loss:0.3388, avg valid loss:0.3634
# 	 score:0.5190(th=0.700000), auc=0.870779::: time:101.67s
# Epoch 12 - Save Best Score: 0.5190. Model is saved.
# dice_list:  [0.14546120818271108, 0.19961171868724234, 0.25636860100359504, 0.3143928986028867, 0.36808953737648975, 0.4100962781085394, 0.44424934081129397, 0.4738909137113591, 0.4955597114750506, 0.5094528808878155, 0.5154927043727255, 0.5174607665277855, 0.5190117999155753, 0.5180244898118318, 0.5108692637878199, 0.493350185075325, 0.46023763922622046, 0.3946593553581258, 0.03202631988762861]
# - epoch:13 -
# Epoch: [13][0/65] Elapsed 0m 1s (remain 1m 34s) Loss: 0.2982(0.2982)
# Epoch: [13][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.2851(0.3431)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2397(0.2397)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2776(0.3939)
# 	 epoch:13, avg train loss:0.3431, avg valid loss:0.3939
# 	 score:0.5136(th=0.700000), auc=0.869358::: time:149.41s
# - epoch:14 -
# Epoch: [14][0/65] Elapsed 0m 1s (remain 1m 39s) Loss: 0.3086(0.3086)
# Epoch: [14][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.4721(0.3601)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2371(0.2371)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2784(0.3973)
# 	 epoch:14, avg train loss:0.3601, avg valid loss:0.3973
# 	 score:0.5223(th=0.750000), auc=0.869479::: time:196.03s
# Epoch 14 - Save Best Score: 0.5223. Model is saved.
# dice_list:  [0.1447775081544033, 0.19767856268790096, 0.2546837611426836, 0.3135222119652381, 0.36891321290248236, 0.41041702947522396, 0.44485441061144154, 0.4758105200941253, 0.49693491240570326, 0.5095245855616333, 0.5165091199073587, 0.519766292178638, 0.5217588559105197, 0.5222712951642552, 0.5178758290166677, 0.5077811821230019, 0.4853522433858611, 0.43712865208107093, 0.07780254674874175]
# - epoch:15 -
# Epoch: [15][0/65] Elapsed 0m 1s (remain 1m 36s) Loss: 0.2781(0.2781)
# Epoch: [15][64/65] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3161(0.3486)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2165(0.2165)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2712(0.3461)
# 	 epoch:15, avg train loss:0.3486, avg valid loss:0.3461
# 	 score:0.5209(th=0.650000), auc=0.871247::: time:247.41s
# - epoch:16 -
# Epoch: [16][0/65] Elapsed 0m 1s (remain 1m 37s) Loss: 0.3047(0.3047)
# Epoch: [16][64/65] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2758(0.3374)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2326(0.2326)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2693(0.3722)
# 	 epoch:16, avg train loss:0.3374, avg valid loss:0.3722
# 	 score:0.5178(th=0.700000), auc=0.872029::: time:296.74s
# - epoch:17 -
# Epoch: [17][0/65] Elapsed 0m 1s (remain 1m 39s) Loss: 0.3115(0.3115)
# Epoch: [17][64/65] Elapsed 0m 33s (remain 0m 0s) Loss: 0.3275(0.3413)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2295(0.2295)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2728(0.3657)
# 	 epoch:17, avg train loss:0.3413, avg valid loss:0.3657
# 	 score:0.5194(th=0.700000), auc=0.870392::: time:345.48s
# - epoch:18 -
# Epoch: [18][0/65] Elapsed 0m 1s (remain 1m 30s) Loss: 0.4213(0.4213)
# Epoch: [18][64/65] Elapsed 0m 30s (remain 0m 0s) Loss: 0.3218(0.3528)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2111(0.2111)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2647(0.3500)
# 	 epoch:18, avg train loss:0.3528, avg valid loss:0.3500
# 	 score:0.5263(th=0.700000), auc=0.870367::: time:391.77s
# Epoch 18 - Save Best Score: 0.5263. Model is saved.
# dice_list:  [0.15463041966927019, 0.21302399033635075, 0.27793167653942413, 0.34416414019276914, 0.40066229841797785, 0.44271454578053765, 0.47682716735060066, 0.4981582413370517, 0.5114242538618708, 0.518622181235851, 0.5217175936050992, 0.5257818482384593, 0.5263290415871168, 0.5198565253904796, 0.5065922912384275, 0.48426660132406507, 0.4478335023308499, 0.38758921758100073, 0.04075858029101683]
# - epoch:19 -
# Epoch: [19][0/65] Elapsed 0m 1s (remain 1m 33s) Loss: 0.3439(0.3439)
# Epoch: [19][64/65] Elapsed 0m 30s (remain 0m 0s) Loss: 0.4616(0.3345)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2573(0.2573)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2774(0.3985)
# 	 epoch:19, avg train loss:0.3345, avg valid loss:0.3985
# 	 score:0.5139(th=0.750000), auc=0.871552::: time:439.27s
# - epoch:20 -
# Epoch: [20][0/65] Elapsed 0m 1s (remain 1m 27s) Loss: 0.3359(0.3359)
# Epoch: [20][64/65] Elapsed 0m 30s (remain 0m 0s) Loss: 0.3154(0.3427)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2108(0.2108)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2687(0.3349)
# 	 epoch:20, avg train loss:0.3427, avg valid loss:0.3349
# 	 score:0.5179(th=0.650000), auc=0.870959::: time:485.13s
# surface_list:  range(25, 35, 3)
# - epoch:21 -
# Epoch: [21][0/65] Elapsed 0m 1s (remain 1m 35s) Loss: 0.3027(0.3027)
# Epoch: [21][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.3942(0.3431)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2362(0.2362)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2634(0.3309)
# 	 epoch:21, avg train loss:0.3431, avg valid loss:0.3309
# 	 score:0.5426(th=0.650000), auc=0.883091::: time:45.96s
# Epoch 21 - Save Best Score: 0.5426. Model is saved.
# dice_list:  [0.14845490527895105, 0.21190481232396477, 0.27848136428631104, 0.3394074376029914, 0.3998613833264469, 0.44162478479264466, 0.47484590876272964, 0.49962564840207846, 0.5159171439249631, 0.5290880620864477, 0.5380578893338844, 0.5425971560626495, 0.5391429117475742, 0.5316322662907949, 0.5228697521403881, 0.5073424035342146, 0.48155330644727473, 0.4176034561685335, 0.03360956899889428]
# Epoch 21 - Save Best AUC: 0.8831. Model is saved.
# - epoch:22 -
# Epoch: [22][0/65] Elapsed 0m 1s (remain 1m 33s) Loss: 0.3250(0.3250)
# Epoch: [22][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.4434(0.3541)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2622(0.2622)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2741(0.3545)
# 	 epoch:22, avg train loss:0.3541, avg valid loss:0.3545
# 	 score:0.5400(th=0.750000), auc=0.884002::: time:94.72s
# Epoch 22 - Save Best AUC: 0.8840. Model is saved.
# - epoch:23 -
# Epoch: [23][0/65] Elapsed 0m 1s (remain 1m 34s) Loss: 0.3493(0.3493)
# Epoch: [23][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.3869(0.3428)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2540(0.2540)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2662(0.3481)
# 	 epoch:23, avg train loss:0.3428, avg valid loss:0.3481
# 	 score:0.5392(th=0.700000), auc=0.883153::: time:142.57s
# - epoch:24 -
# Epoch: [24][0/65] Elapsed 0m 1s (remain 1m 31s) Loss: 0.3103(0.3103)
# Epoch: [24][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.2838(0.3433)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2504(0.2504)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2696(0.3460)
# 	 epoch:24, avg train loss:0.3433, avg valid loss:0.3460
# 	 score:0.5409(th=0.700000), auc=0.883207::: time:188.96s
# - epoch:25 -
# Epoch: [25][0/65] Elapsed 0m 1s (remain 1m 32s) Loss: 0.3534(0.3534)
# Epoch: [25][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.3421(0.3431)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2899(0.2899)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2819(0.3840)
# 	 epoch:25, avg train loss:0.3431, avg valid loss:0.3840
# 	 score:0.5407(th=0.800000), auc=0.884821::: time:235.41s
# Epoch 25 - Save Best AUC: 0.8848. Model is saved.
# - epoch:26 -
# Epoch: [26][0/65] Elapsed 0m 1s (remain 1m 29s) Loss: 0.2845(0.2845)
# Epoch: [26][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.3025(0.3417)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2591(0.2591)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2722(0.3498)
# 	 epoch:26, avg train loss:0.3417, avg valid loss:0.3498
# 	 score:0.5440(th=0.700000), auc=0.884664::: time:283.14s
# Epoch 26 - Save Best Score: 0.5440. Model is saved.
# dice_list:  [0.14311367641973768, 0.19728281965611755, 0.2606202055334968, 0.3174605041764465, 0.37515079906917004, 0.4183123965983675, 0.450304984638359, 0.4779943013078331, 0.5015712105747172, 0.5181974147589681, 0.5309163287664556, 0.5405377643149497, 0.5440043556606025, 0.5437405568949286, 0.5370139164135462, 0.525627918750659, 0.5046974883460814, 0.4604244934253397, 0.06610431855156686]
# - epoch:27 -
# Epoch: [27][0/65] Elapsed 0m 1s (remain 1m 38s) Loss: 0.3215(0.3215)
# Epoch: [27][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.2842(0.3567)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2502(0.2502)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2655(0.3389)
# 	 epoch:27, avg train loss:0.3567, avg valid loss:0.3389
# 	 score:0.5388(th=0.650000), auc=0.883720::: time:330.82s
# - epoch:28 -
# Epoch: [28][0/65] Elapsed 0m 1s (remain 1m 37s) Loss: 0.3052(0.3052)
# Epoch: [28][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.2976(0.3412)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2519(0.2519)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2734(0.3430)
# 	 epoch:28, avg train loss:0.3412, avg valid loss:0.3430
# 	 score:0.5405(th=0.700000), auc=0.883134::: time:377.48s
# - epoch:29 -
# Epoch: [29][0/65] Elapsed 0m 1s (remain 1m 34s) Loss: 0.3996(0.3996)
# Epoch: [29][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.3602(0.3451)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2432(0.2432)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2653(0.3343)
# 	 epoch:29, avg train loss:0.3451, avg valid loss:0.3343
# 	 score:0.5400(th=0.650000), auc=0.884357::: time:423.93s
# - epoch:30 -
# Epoch: [30][0/65] Elapsed 0m 1s (remain 1m 33s) Loss: 0.3229(0.3229)
# Epoch: [30][64/65] Elapsed 0m 31s (remain 0m 0s) Loss: 0.2839(0.3650)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2686(0.2686)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2696(0.3511)
# 	 epoch:30, avg train loss:0.3650, avg valid loss:0.3511
# 	 score:0.5379(th=0.700000), auc=0.885216::: time:470.55s
# Epoch 30 - Save Best AUC: 0.8852. Model is saved.
# [fold0] slice ave score:0.5619(th=0.400000), auc=0.884233
# [fold0] BEST Epoch 26 - Save Best Score:0.5440. Best loss:0.3498
# [fold0] BEST AUC Epoch 30 - Save Best Score:0.8852. Best loss:0.3511
# -- fold1 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# Epoch: [1][0/59] Elapsed 0m 1s (remain 1m 16s) Loss: 0.7462(0.7462)
# Epoch: [1][58/59] Elapsed 0m 29s (remain 0m 0s) Loss: 0.6487(0.6699)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 6.1012(6.1012)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3182(3.0384)
# 	 epoch:1, avg train loss:0.6699, avg valid loss:3.0384
# 	 score:0.3806(th=0.800000), auc=0.771283::: time:49.47s
# Epoch 1 - Save Best Score: 0.3806. Model is saved.
# dice_list:  [0.20485477043437425, 0.20486460146554927, 0.20589315306142666, 0.21271677318505258, 0.22959525350433196, 0.24119629522280678, 0.2570554336239645, 0.27889479631805497, 0.3055816417128212, 0.33449912386897024, 0.35758612332961476, 0.37156121052441793, 0.37809382449804946, 0.3797419953653293, 0.3806050714724732, 0.3805377243931609, 0.380410779621961, 0.38011282018995096, 0.3209615792379552]
# Epoch 1 - Save Best AUC: 0.7713. Model is saved.
# - epoch:2 -
# Epoch: [2][0/59] Elapsed 0m 1s (remain 1m 30s) Loss: 0.6441(0.6441)
# Epoch: [2][58/59] Elapsed 0m 40s (remain 0m 0s) Loss: 0.5852(0.5896)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 8s) Loss: 0.6966(0.6966)
# EVAL: [19/20] Elapsed 0m 5s (remain 0m 0s) Loss: 0.3579(0.5541)
# 	 epoch:2, avg train loss:0.5896, avg valid loss:0.5541
# 	 score:0.4625(th=0.600000), auc=0.782558::: time:113.67s
# Epoch 2 - Save Best Score: 0.4625. Model is saved.
# dice_list:  [0.20485477043437425, 0.20488317857897426, 0.2056911985976299, 0.21182129054816762, 0.2371098962395304, 0.2863421553882444, 0.32604342837730255, 0.38074556471564996, 0.4268073863995733, 0.45606852531344994, 0.462476157913178, 0.45398360388181286, 0.4357765239370559, 0.40902977699587567, 0.37616691692832943, 0.3298147187845127, 0.2817741814328641, 0.2205208184803012, 0.0]
# Epoch 2 - Save Best AUC: 0.7826. Model is saved.
# - epoch:3 -
# Epoch: [3][0/59] Elapsed 0m 1s (remain 1m 27s) Loss: 0.5408(0.5408)
# Epoch: [3][58/59] Elapsed 0m 36s (remain 0m 0s) Loss: 0.4714(0.5162)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 8s) Loss: 0.8443(0.8443)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2634(0.6343)
# 	 epoch:3, avg train loss:0.5162, avg valid loss:0.6343
# 	 score:0.4404(th=0.750000), auc=0.780161::: time:173.08s
# - epoch:4 -
# Epoch: [4][0/59] Elapsed 0m 1s (remain 1m 24s) Loss: 0.4951(0.4951)
# Epoch: [4][58/59] Elapsed 0m 34s (remain 0m 0s) Loss: 0.6174(0.4620)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.9116(0.9116)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1982(0.5432)
# 	 epoch:4, avg train loss:0.4620, avg valid loss:0.5432
# 	 score:0.4938(th=0.750000), auc=0.814724::: time:228.10s
# Epoch 4 - Save Best Score: 0.4938. Model is saved.
# dice_list:  [0.20486215204059638, 0.20806831323993857, 0.2506979273137834, 0.302056450084071, 0.34978393809670755, 0.39219158759855566, 0.4205330268875556, 0.43849238360013343, 0.45502200107965046, 0.46812370188573116, 0.4779901606711241, 0.48515729309085165, 0.48979524023551047, 0.49383805178710294, 0.49201689081729305, 0.481756388949724, 0.46447570087494094, 0.42737594631620046, 0.0820877675832367]
# Epoch 4 - Save Best AUC: 0.8147. Model is saved.
# - epoch:5 -
# Epoch: [5][0/59] Elapsed 0m 1s (remain 1m 22s) Loss: 0.4750(0.4750)
# Epoch: [5][58/59] Elapsed 0m 31s (remain 0m 0s) Loss: 0.6228(0.4406)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.8007(0.8007)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1879(0.5262)
# 	 epoch:5, avg train loss:0.4406, avg valid loss:0.5262
# 	 score:0.4882(th=0.650000), auc=0.812546::: time:282.61s
# - epoch:6 -
# Epoch: [6][0/59] Elapsed 0m 1s (remain 1m 32s) Loss: 0.3743(0.3743)
# Epoch: [6][58/59] Elapsed 0m 32s (remain 0m 0s) Loss: 0.6403(0.4325)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.6081(0.6081)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1692(0.4634)
# 	 epoch:6, avg train loss:0.4325, avg valid loss:0.4634
# 	 score:0.4979(th=0.600000), auc=0.810636::: time:334.54s
# Epoch 6 - Save Best Score: 0.4979. Model is saved.
# dice_list:  [0.2051277665310081, 0.22857495394965904, 0.29551870227984434, 0.35814271090391897, 0.41116501856316817, 0.45040060487598355, 0.472913525883368, 0.48547913352988353, 0.4933382752396615, 0.49712993158177593, 0.49793756350244645, 0.4936476558188265, 0.48582536191969283, 0.47392125109734556, 0.45885828701352366, 0.4376659988457682, 0.40829417415950076, 0.35639091496855074, 0.10106540057106832]
# - epoch:7 -
# Epoch: [7][0/59] Elapsed 0m 1s (remain 1m 27s) Loss: 0.4028(0.4028)
# Epoch: [7][58/59] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3213(0.4003)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5751(0.5751)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1483(0.4213)
# 	 epoch:7, avg train loss:0.4003, avg valid loss:0.4213
# 	 score:0.4769(th=0.500000), auc=0.807930::: time:385.39s
# - epoch:8 -
# Epoch: [8][0/59] Elapsed 0m 1s (remain 1m 26s) Loss: 0.4295(0.4295)
# Epoch: [8][58/59] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3354(0.3916)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5958(0.5958)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1693(0.4152)
# 	 epoch:8, avg train loss:0.3916, avg valid loss:0.4152
# 	 score:0.5013(th=0.500000), auc=0.809680::: time:434.21s
# Epoch 8 - Save Best Score: 0.5013. Model is saved.
# dice_list:  [0.20567769917211057, 0.2379178250410351, 0.3181018724113299, 0.3863003113014879, 0.44119480774740116, 0.4745111459929652, 0.49062160306962577, 0.4983813417248925, 0.5012733439015897, 0.4994216292414083, 0.4938062595049704, 0.48209577905256834, 0.46526421563598763, 0.4424664066194916, 0.4151531865762565, 0.38194902551837673, 0.33712347383104396, 0.27412756721266346, 0.060325761921587805]
# - epoch:9 -
# Epoch: [9][0/59] Elapsed 0m 1s (remain 1m 29s) Loss: 0.3396(0.3396)
# Epoch: [9][58/59] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3290(0.3803)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5999(0.5999)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1622(0.4213)
# 	 epoch:9, avg train loss:0.3803, avg valid loss:0.4213
# 	 score:0.4962(th=0.500000), auc=0.807111::: time:485.65s
# - epoch:10 -
# Epoch: [10][0/59] Elapsed 0m 1s (remain 1m 30s) Loss: 0.4133(0.4133)
# Epoch: [10][58/59] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3338(0.3947)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5997(0.5997)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1415(0.4140)
# 	 epoch:10, avg train loss:0.3947, avg valid loss:0.4140
# 	 score:0.5043(th=0.450000), auc=0.810753::: time:534.09s
# Epoch 10 - Save Best Score: 0.5043. Model is saved.
# dice_list:  [0.20683819515656743, 0.26134739314261907, 0.3386497119915269, 0.40396880063391094, 0.45569980926447523, 0.48575280610476174, 0.49950225715564905, 0.5042952589498281, 0.501223786910044, 0.49318390379638616, 0.4811262084511722, 0.4644501728132293, 0.4447536285710457, 0.4218147776863455, 0.3944942553840916, 0.36154216758016605, 0.3143084263839031, 0.24867945118092347, 0.06474670380446758]
# surface_list:  range(27, 37, 3)
# - epoch:11 -
# Epoch: [11][0/59] Elapsed 0m 1s (remain 1m 28s) Loss: 0.6027(0.6027)
# Epoch: [11][58/59] Elapsed 0m 33s (remain 0m 0s) Loss: 0.4163(0.4108)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 8s) Loss: 0.5596(0.5596)
# EVAL: [19/20] Elapsed 0m 5s (remain 0m 0s) Loss: 0.1487(0.4148)
# 	 epoch:11, avg train loss:0.4108, avg valid loss:0.4148
# 	 score:0.5031(th=0.500000), auc=0.806750::: time:55.18s
# Epoch 11 - Save Best Score: 0.5031. Model is saved.
# dice_list:  [0.20633544059835263, 0.25642975567859966, 0.3296427698100707, 0.38796001372501204, 0.4378981148190327, 0.4712776413026823, 0.49155139065578735, 0.5025152692136102, 0.5030731623037278, 0.49904867920591883, 0.4911386505316848, 0.4790553799034395, 0.4634448342704459, 0.4437647664567283, 0.41775021142977964, 0.38676063980451075, 0.3501870902624731, 0.29292021863794293, 0.03560559576219225]
# Epoch 11 - Save Best AUC: 0.8067. Model is saved.
# - epoch:12 -
# Epoch: [12][0/59] Elapsed 0m 1s (remain 1m 35s) Loss: 0.5131(0.5131)
# Epoch: [12][58/59] Elapsed 0m 34s (remain 0m 0s) Loss: 0.4730(0.3984)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 8s) Loss: 0.5708(0.5708)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1411(0.4253)
# 	 epoch:12, avg train loss:0.3984, avg valid loss:0.4253
# 	 score:0.5112(th=0.500000), auc=0.813226::: time:113.64s
# Epoch 12 - Save Best Score: 0.5112. Model is saved.
# dice_list:  [0.20681134892027858, 0.2601470007253361, 0.33014859181953365, 0.38722959437191196, 0.4354176316122647, 0.471868661508773, 0.4933991034420895, 0.5060125727116049, 0.5111891262910631, 0.5108388119841597, 0.5069014401268997, 0.5018224921667819, 0.49256100701352995, 0.4782455761183655, 0.45781765318078466, 0.43117374838586703, 0.3974529085611747, 0.34875639858191404, 0.08988564477671712]
# Epoch 12 - Save Best AUC: 0.8132. Model is saved.
# - epoch:13 -
# Epoch: [13][0/59] Elapsed 0m 1s (remain 1m 32s) Loss: 0.3755(0.3755)
# Epoch: [13][58/59] Elapsed 0m 30s (remain 0m 0s) Loss: 0.2982(0.3908)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5698(0.5698)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1468(0.4262)
# 	 epoch:13, avg train loss:0.3908, avg valid loss:0.4262
# 	 score:0.5061(th=0.500000), auc=0.808475::: time:167.35s
# - epoch:14 -
# Epoch: [14][0/59] Elapsed 0m 1s (remain 1m 29s) Loss: 0.5417(0.5417)
# Epoch: [14][58/59] Elapsed 0m 30s (remain 0m 0s) Loss: 0.3146(0.3910)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5705(0.5705)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1474(0.4266)
# 	 epoch:14, avg train loss:0.3910, avg valid loss:0.4266
# 	 score:0.5044(th=0.500000), auc=0.807690::: time:218.01s
# - epoch:15 -
# Epoch: [15][0/59] Elapsed 0m 1s (remain 1m 29s) Loss: 0.5119(0.5119)
# Epoch: [15][58/59] Elapsed 0m 29s (remain 0m 0s) Loss: 0.9294(0.4221)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5673(0.5673)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1440(0.4283)
# 	 epoch:15, avg train loss:0.4221, avg valid loss:0.4283
# 	 score:0.5031(th=0.500000), auc=0.807247::: time:267.67s
# - epoch:16 -
# Epoch: [16][0/59] Elapsed 0m 1s (remain 1m 35s) Loss: 0.3476(0.3476)
# Epoch: [16][58/59] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3340(0.3841)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5602(0.5602)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1449(0.4098)
# 	 epoch:16, avg train loss:0.3841, avg valid loss:0.4098
# 	 score:0.5050(th=0.450000), auc=0.808629::: time:317.78s
# - epoch:17 -
# Epoch: [17][0/59] Elapsed 0m 1s (remain 1m 31s) Loss: 0.3851(0.3851)
# Epoch: [17][58/59] Elapsed 0m 30s (remain 0m 0s) Loss: 0.3694(0.4055)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5607(0.5607)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1372(0.4150)
# 	 epoch:17, avg train loss:0.4055, avg valid loss:0.4150
# 	 score:0.5080(th=0.500000), auc=0.810942::: time:367.62s
# - epoch:18 -
# Epoch: [18][0/59] Elapsed 0m 1s (remain 1m 26s) Loss: 0.3406(0.3406)
# Epoch: [18][58/59] Elapsed 0m 30s (remain 0m 0s) Loss: 0.3527(0.3915)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5636(0.5636)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1548(0.4232)
# 	 epoch:18, avg train loss:0.3915, avg valid loss:0.4232
# 	 score:0.5069(th=0.500000), auc=0.806022::: time:418.13s
# - epoch:19 -
# Epoch: [19][0/59] Elapsed 0m 1s (remain 1m 29s) Loss: 0.3434(0.3434)
# Epoch: [19][58/59] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3310(0.4037)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5771(0.5771)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1518(0.4455)
# 	 epoch:19, avg train loss:0.4037, avg valid loss:0.4455
# 	 score:0.5065(th=0.550000), auc=0.806986::: time:467.82s
# - epoch:20 -
# Epoch: [20][0/59] Elapsed 0m 1s (remain 1m 28s) Loss: 0.3926(0.3926)
# Epoch: [20][58/59] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3797(0.4114)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5722(0.5722)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1508(0.4270)
# 	 epoch:20, avg train loss:0.4114, avg valid loss:0.4270
# 	 score:0.5121(th=0.500000), auc=0.809874::: time:517.68s
# Epoch 20 - Save Best Score: 0.5121. Model is saved.
# dice_list:  [0.2066603436807703, 0.2562239274927521, 0.327451191028624, 0.3842621021676744, 0.43193498479619463, 0.46799130185052473, 0.49122632282056944, 0.5054939768163443, 0.5121094482196704, 0.5099816486978782, 0.5043640153230112, 0.49795851053586726, 0.4864725296717377, 0.4709537619556232, 0.45048338487150497, 0.423911462691441, 0.39006933554609874, 0.3417011494583028, 0.09205894798676811]
# surface_list:  range(25, 35, 3)
# - epoch:21 -
# Epoch: [21][0/59] Elapsed 0m 1s (remain 1m 24s) Loss: 0.4202(0.4202)
# Epoch: [21][58/59] Elapsed 0m 29s (remain 0m 0s) Loss: 0.5053(0.3841)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.6636(0.6636)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1380(0.4198)
# 	 epoch:21, avg train loss:0.3841, avg valid loss:0.4198
# 	 score:0.4981(th=0.450000), auc=0.807811::: time:49.74s
# Epoch 21 - Save Best Score: 0.4981. Model is saved.
# dice_list:  [0.20634910070636597, 0.2604226375029208, 0.338471212612369, 0.40353941987894537, 0.45285817134062073, 0.48167339433165035, 0.49470613399976543, 0.4981146470314793, 0.4974852761888438, 0.49210326906324714, 0.4837017023707381, 0.47176701156210793, 0.45702689473559494, 0.4403633444895208, 0.4201871477520505, 0.3933209135434211, 0.3543636920066927, 0.3001172408561025, 0.06973555242702584]
# Epoch 21 - Save Best AUC: 0.8078. Model is saved.
# - epoch:22 -
# Epoch: [22][0/59] Elapsed 0m 1s (remain 1m 24s) Loss: 0.3209(0.3209)
# Epoch: [22][58/59] Elapsed 0m 29s (remain 0m 0s) Loss: 1.0687(0.3961)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.8907(0.8907)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1504(0.4787)
# 	 epoch:22, avg train loss:0.3961, avg valid loss:0.4787
# 	 score:0.5079(th=0.500000), auc=0.807965::: time:102.61s
# Epoch 22 - Save Best Score: 0.5079. Model is saved.
# dice_list:  [0.20634935742199867, 0.25695006035164714, 0.33331436615411547, 0.39551955370905917, 0.4428673404208357, 0.4751250263228263, 0.4948242134142324, 0.5052343164948453, 0.5079191951122555, 0.5074244625849589, 0.5033459011070833, 0.4962048136407084, 0.4866100386850662, 0.47380309573151763, 0.45861160925099415, 0.437655181209971, 0.4105463461876277, 0.36635849993394365, 0.13300473070021437]
# Epoch 22 - Save Best AUC: 0.8080. Model is saved.
# - epoch:23 -
# Epoch: [23][0/59] Elapsed 0m 1s (remain 1m 30s) Loss: 0.3750(0.3750)
# Epoch: [23][58/59] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3761(0.3852)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.7280(0.7280)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1446(0.4356)
# 	 epoch:23, avg train loss:0.3852, avg valid loss:0.4356
# 	 score:0.4993(th=0.500000), auc=0.806377::: time:156.12s
# - epoch:24 -
# Epoch: [24][0/59] Elapsed 0m 1s (remain 1m 27s) Loss: 0.4802(0.4802)
# Epoch: [24][58/59] Elapsed 0m 29s (remain 0m 0s) Loss: 0.4402(0.3943)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.7077(0.7077)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1418(0.4346)
# 	 epoch:24, avg train loss:0.3943, avg valid loss:0.4346
# 	 score:0.5030(th=0.450000), auc=0.808253::: time:205.87s
# Epoch 24 - Save Best AUC: 0.8083. Model is saved.
# - epoch:25 -
# Epoch: [25][0/59] Elapsed 0m 1s (remain 1m 23s) Loss: 0.3444(0.3444)
# Epoch: [25][58/59] Elapsed 0m 29s (remain 0m 0s) Loss: 1.1401(0.4154)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.9174(0.9174)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1424(0.4884)
# 	 epoch:25, avg train loss:0.4154, avg valid loss:0.4884
# 	 score:0.5039(th=0.550000), auc=0.808432::: time:257.00s
# Epoch 25 - Save Best AUC: 0.8084. Model is saved.
# - epoch:26 -
# Epoch: [26][0/59] Elapsed 0m 1s (remain 1m 32s) Loss: 0.6203(0.6203)
# Epoch: [26][58/59] Elapsed 0m 30s (remain 0m 0s) Loss: 0.6733(0.4065)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.7395(0.7395)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1426(0.4522)
# 	 epoch:26, avg train loss:0.4065, avg valid loss:0.4522
# 	 score:0.4988(th=0.500000), auc=0.808640::: time:308.76s
# Epoch 26 - Save Best AUC: 0.8086. Model is saved.
# - epoch:27 -
# Epoch: [27][0/59] Elapsed 0m 1s (remain 1m 34s) Loss: 0.5513(0.5513)
# Epoch: [27][58/59] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3396(0.4094)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.7382(0.7382)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1405(0.4477)
# 	 epoch:27, avg train loss:0.4094, avg valid loss:0.4477
# 	 score:0.5028(th=0.500000), auc=0.809825::: time:360.56s
# Epoch 27 - Save Best AUC: 0.8098. Model is saved.
# - epoch:28 -
# Epoch: [28][0/59] Elapsed 0m 1s (remain 1m 28s) Loss: 0.4106(0.4106)
# Epoch: [28][58/59] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3120(0.4034)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.7771(0.7771)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1454(0.4676)
# 	 epoch:28, avg train loss:0.4034, avg valid loss:0.4676
# 	 score:0.4994(th=0.500000), auc=0.808346::: time:411.75s
# - epoch:29 -
# Epoch: [29][0/59] Elapsed 0m 1s (remain 1m 31s) Loss: 0.3309(0.3309)
# Epoch: [29][58/59] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3143(0.4070)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.7458(0.7458)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1432(0.4572)
# 	 epoch:29, avg train loss:0.4070, avg valid loss:0.4572
# 	 score:0.5015(th=0.500000), auc=0.808879::: time:461.27s
# - epoch:30 -
# Epoch: [30][0/59] Elapsed 0m 1s (remain 1m 31s) Loss: 0.4352(0.4352)
# Epoch: [30][58/59] Elapsed 0m 29s (remain 0m 0s) Loss: 0.4823(0.4028)
# EVAL: [0/20] Elapsed 0m 0s (remain 0m 7s) Loss: 0.7401(0.7401)
# EVAL: [19/20] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1401(0.4422)
# 	 epoch:30, avg train loss:0.4028, avg valid loss:0.4422
# 	 score:0.5030(th=0.450000), auc=0.807781::: time:511.01s
# [fold1] slice ave score:0.5207(th=0.300000), auc=0.818857
# [fold1] BEST Epoch 22 - Save Best Score:0.5079. Best loss:0.4787
# [fold1] BEST AUC Epoch 27 - Save Best Score:0.8098. Best loss:0.4477
# -- fold2 training start --
# surface_list:  range(26, 36, 3)
# - epoch:1 -
# Epoch: [1][0/60] Elapsed 0m 1s (remain 1m 22s) Loss: 0.7143(0.7143)
# Epoch: [1][59/60] Elapsed 0m 29s (remain 0m 0s) Loss: 0.5598(0.6014)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.6088(0.6088)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.5680(0.5702)
# 	 epoch:1, avg train loss:0.6014, avg valid loss:0.5702
# 	 score:0.3710(th=0.550000), auc=0.750912::: time:49.45s
# Epoch 1 - Save Best Score: 0.3710. Model is saved.
# dice_list:  [0.20953039358675013, 0.21031712199094463, 0.21891468951903367, 0.22763668605510223, 0.2367764597571479, 0.2544338036443257, 0.2853249916878295, 0.3232778168116228, 0.3557205821839234, 0.37096116164485826, 0.3635034031641022, 0.33734188944315235, 0.29959515243417845, 0.2518142973288396, 0.19889886771728663, 0.14945705546686935, 0.09849010438580379, 0.04685661381711954, 0.0]
# Epoch 1 - Save Best AUC: 0.7509. Model is saved.
# - epoch:2 -
# Epoch: [2][0/60] Elapsed 0m 1s (remain 1m 33s) Loss: 0.5450(0.5450)
# Epoch: [2][59/60] Elapsed 0m 37s (remain 0m 0s) Loss: 0.6062(0.5149)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.6413(0.6413)
# EVAL: [18/19] Elapsed 0m 5s (remain 0m 0s) Loss: 0.4574(0.5029)
# 	 epoch:2, avg train loss:0.5149, avg valid loss:0.5029
# 	 score:0.4044(th=0.450000), auc=0.782678::: time:111.48s
# Epoch 2 - Save Best Score: 0.4044. Model is saved.
# dice_list:  [0.20949747110420053, 0.2096550194383209, 0.21464915041592172, 0.25152367749001575, 0.31194408795858714, 0.3638646698391389, 0.3962806328799671, 0.40440170261468383, 0.40103378746018736, 0.39311186218176, 0.383379291865166, 0.3718527351215243, 0.35788110321972055, 0.3427000720217919, 0.3244752610118124, 0.3024412436849069, 0.27387987342113024, 0.23173101771209859, 0.0]
# Epoch 2 - Save Best AUC: 0.7827. Model is saved.
# - epoch:3 -
# Epoch: [3][0/60] Elapsed 0m 1s (remain 1m 31s) Loss: 0.4883(0.4883)
# Epoch: [3][59/60] Elapsed 0m 37s (remain 0m 0s) Loss: 0.4427(0.4528)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.5390(0.5390)
# EVAL: [18/19] Elapsed 0m 5s (remain 0m 0s) Loss: 0.4531(0.4729)
# 	 epoch:3, avg train loss:0.4528, avg valid loss:0.4729
# 	 score:0.4456(th=0.500000), auc=0.794799::: time:173.35s
# Epoch 3 - Save Best Score: 0.4456. Model is saved.
# dice_list:  [0.20950032538316193, 0.2099195839016924, 0.22858007836652647, 0.2583916391675129, 0.31910027793828644, 0.39173788769942197, 0.4328858287243717, 0.44463213962034936, 0.44560508609937777, 0.44190756974825707, 0.43506740763047036, 0.4212956828752445, 0.40158354740058216, 0.37676015639144694, 0.34731251497533755, 0.3151436318081671, 0.28142735444766515, 0.24022107810918727, 0.003408164471299912]
# Epoch 3 - Save Best AUC: 0.7948. Model is saved.
# - epoch:4 -
# Epoch: [4][0/60] Elapsed 0m 1s (remain 1m 26s) Loss: 0.4606(0.4606)
# Epoch: [4][59/60] Elapsed 0m 36s (remain 0m 0s) Loss: 0.5244(0.4069)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.5984(0.5984)
# EVAL: [18/19] Elapsed 0m 5s (remain 0m 0s) Loss: 0.4664(0.5362)
# 	 epoch:4, avg train loss:0.4069, avg valid loss:0.5362
# 	 score:0.4103(th=0.750000), auc=0.792842::: time:234.32s
# - epoch:5 -
# Epoch: [5][0/60] Elapsed 0m 1s (remain 1m 32s) Loss: 0.3685(0.3685)
# Epoch: [5][59/60] Elapsed 0m 37s (remain 0m 0s) Loss: 0.4046(0.3702)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5305(0.5305)
# EVAL: [18/19] Elapsed 0m 5s (remain 0m 0s) Loss: 0.4435(0.4362)
# 	 epoch:5, avg train loss:0.3702, avg valid loss:0.4362
# 	 score:0.4746(th=0.550000), auc=0.809402::: time:291.94s
# Epoch 5 - Save Best Score: 0.4746. Model is saved.
# dice_list:  [0.2111496620298649, 0.24655931964601743, 0.31186259284150736, 0.3590175499784113, 0.3994104596606773, 0.430389615692746, 0.45040249868516524, 0.4640766789572131, 0.4735956169620043, 0.4745515250801245, 0.4682877846654939, 0.4572918319483767, 0.4424827666470074, 0.4244398212657268, 0.4016823709537819, 0.3723203067092977, 0.3372850838162054, 0.2892409504473574, 0.05994219293004701]
# Epoch 5 - Save Best AUC: 0.8094. Model is saved.
# - epoch:6 -
# Epoch: [6][0/60] Elapsed 0m 1s (remain 1m 30s) Loss: 0.2899(0.2899)
# Epoch: [6][59/60] Elapsed 0m 37s (remain 0m 0s) Loss: 0.3512(0.3672)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.7677(0.7677)
# EVAL: [18/19] Elapsed 0m 5s (remain 0m 0s) Loss: 0.4839(0.4746)
# 	 epoch:6, avg train loss:0.3672, avg valid loss:0.4746
# 	 score:0.4671(th=0.550000), auc=0.809081::: time:353.07s
# - epoch:7 -
# Epoch: [7][0/60] Elapsed 0m 1s (remain 1m 36s) Loss: 0.3276(0.3276)
# Epoch: [7][59/60] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2511(0.3330)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.8993(0.8993)
# EVAL: [18/19] Elapsed 0m 5s (remain 0m 0s) Loss: 0.5292(0.4930)
# 	 epoch:7, avg train loss:0.3330, avg valid loss:0.4930
# 	 score:0.4701(th=0.650000), auc=0.811302::: time:410.39s
# Epoch 7 - Save Best AUC: 0.8113. Model is saved.
# - epoch:8 -
# Epoch: [8][0/60] Elapsed 0m 1s (remain 1m 29s) Loss: 0.3357(0.3357)
# Epoch: [8][59/60] Elapsed 0m 37s (remain 0m 0s) Loss: 1.2815(0.3466)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 9s) Loss: 0.8605(0.8605)
# EVAL: [18/19] Elapsed 0m 5s (remain 0m 0s) Loss: 0.5340(0.4946)
# 	 epoch:8, avg train loss:0.3466, avg valid loss:0.4946
# 	 score:0.4801(th=0.600000), auc=0.813632::: time:469.20s
# Epoch 8 - Save Best Score: 0.4801. Model is saved.
# dice_list:  [0.22334818938760043, 0.29101343851421424, 0.34646322083329834, 0.3871960941817575, 0.42102711781168894, 0.44416822789387506, 0.46134831527062276, 0.47252492081461767, 0.4780064739071825, 0.47898199209623177, 0.4800769491718002, 0.4788372487127977, 0.4748523246783832, 0.46947501111951423, 0.4615142758381973, 0.44749340683985517, 0.42971932021792836, 0.397335366980288, 0.15850681219306453]
# Epoch 8 - Save Best AUC: 0.8136. Model is saved.
# - epoch:9 -
# Epoch: [9][0/60] Elapsed 0m 1s (remain 1m 35s) Loss: 0.2637(0.2637)
# Epoch: [9][59/60] Elapsed 0m 36s (remain 0m 0s) Loss: 0.3355(0.3348)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 1.4015(1.4015)
# EVAL: [18/19] Elapsed 0m 5s (remain 0m 0s) Loss: 0.5476(0.5724)
# 	 epoch:9, avg train loss:0.3348, avg valid loss:0.5724
# 	 score:0.4835(th=0.600000), auc=0.812041::: time:529.72s
# Epoch 9 - Save Best Score: 0.4835. Model is saved.
# dice_list:  [0.22550949145070234, 0.29410391061081387, 0.3478189811954142, 0.3860179448999636, 0.41643214441697496, 0.43906310910185925, 0.4571199066089879, 0.47045896913458196, 0.47923014210547044, 0.48348559077824943, 0.48353543457849013, 0.48283005229261344, 0.4815136251482694, 0.4792237065358595, 0.4762936792116411, 0.46917849325197214, 0.4559471879334126, 0.43318055159047486, 0.22360521242439516]
# - epoch:10 -
# Epoch: [10][0/60] Elapsed 0m 1s (remain 1m 38s) Loss: 0.2738(0.2738)
# Epoch: [10][59/60] Elapsed 0m 36s (remain 0m 0s) Loss: 0.2868(0.3163)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.7090(0.7090)
# EVAL: [18/19] Elapsed 0m 5s (remain 0m 0s) Loss: 0.5230(0.4705)
# 	 epoch:10, avg train loss:0.3163, avg valid loss:0.4705
# 	 score:0.4762(th=0.550000), auc=0.808671::: time:588.33s
# surface_list:  range(27, 37, 3)
# - epoch:11 -
# Epoch: [11][0/60] Elapsed 0m 1s (remain 1m 33s) Loss: 0.3186(0.3186)
# Epoch: [11][59/60] Elapsed 0m 36s (remain 0m 0s) Loss: 0.4098(0.3390)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 7s) Loss: 0.8992(0.8992)
# EVAL: [18/19] Elapsed 0m 5s (remain 0m 0s) Loss: 0.4551(0.4905)
# 	 epoch:11, avg train loss:0.3390, avg valid loss:0.4905
# 	 score:0.4956(th=0.550000), auc=0.814972::: time:57.20s
# Epoch 11 - Save Best Score: 0.4956. Model is saved.
# dice_list:  [0.23591347512331148, 0.3143243764979723, 0.3754623333280556, 0.42061685136104465, 0.45485226496468745, 0.47441899907059465, 0.48646925266389723, 0.49194916686926204, 0.4951799721173973, 0.4956292136591482, 0.4939509522263718, 0.49079761419460827, 0.48606305071176825, 0.4784096986666713, 0.4689716130443903, 0.459538336582845, 0.4475466156622563, 0.4298078524691761, 0.21571516474923352]
# Epoch 11 - Save Best AUC: 0.8150. Model is saved.
# - epoch:12 -
# Epoch: [12][0/60] Elapsed 0m 1s (remain 1m 39s) Loss: 0.3667(0.3667)
# Epoch: [12][59/60] Elapsed 0m 35s (remain 0m 0s) Loss: 1.1017(0.3585)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 1.1127(1.1127)
# EVAL: [18/19] Elapsed 0m 5s (remain 0m 0s) Loss: 0.4985(0.5052)
# 	 epoch:12, avg train loss:0.3585, avg valid loss:0.5052
# 	 score:0.5001(th=0.600000), auc=0.816501::: time:117.05s
# Epoch 12 - Save Best Score: 0.5001. Model is saved.
# dice_list:  [0.23455437931023781, 0.30710762898384697, 0.3621734901303081, 0.40134078548900015, 0.4356495239686701, 0.45936974194943536, 0.4762914855778873, 0.48803687119800204, 0.4954305802532657, 0.498935152774967, 0.5001136239468085, 0.49896609013966414, 0.49631063495458555, 0.49096509265812405, 0.48299531657084216, 0.4736177727681587, 0.457995305379566, 0.43445855244679377, 0.2029993923903075]
# Epoch 12 - Save Best AUC: 0.8165. Model is saved.
# - epoch:13 -
# Epoch: [13][0/60] Elapsed 0m 1s (remain 1m 32s) Loss: 0.2940(0.2940)
# Epoch: [13][59/60] Elapsed 0m 35s (remain 0m 0s) Loss: 1.0017(0.3415)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 1.1783(1.1783)
# EVAL: [18/19] Elapsed 0m 5s (remain 0m 0s) Loss: 0.4888(0.5155)
# 	 epoch:13, avg train loss:0.3415, avg valid loss:0.5155
# 	 score:0.4959(th=0.600000), auc=0.816781::: time:175.91s
# Epoch 13 - Save Best AUC: 0.8168. Model is saved.
# - epoch:14 -
# Epoch: [14][0/60] Elapsed 0m 1s (remain 1m 38s) Loss: 0.3624(0.3624)
# Epoch: [14][59/60] Elapsed 0m 35s (remain 0m 0s) Loss: 0.2247(0.3271)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.6555(0.6555)
# EVAL: [18/19] Elapsed 0m 5s (remain 0m 0s) Loss: 0.4342(0.4424)
# 	 epoch:14, avg train loss:0.3271, avg valid loss:0.4424
# 	 score:0.4979(th=0.500000), auc=0.816790::: time:233.83s
# Epoch 14 - Save Best AUC: 0.8168. Model is saved.
# - epoch:15 -
# Epoch: [15][0/60] Elapsed 0m 1s (remain 1m 30s) Loss: 0.3108(0.3108)
# Epoch: [15][59/60] Elapsed 0m 35s (remain 0m 0s) Loss: 1.3602(0.3421)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 1.7107(1.7107)
# EVAL: [18/19] Elapsed 0m 5s (remain 0m 0s) Loss: 0.5379(0.5902)
# 	 epoch:15, avg train loss:0.3421, avg valid loss:0.5902
# 	 score:0.4983(th=0.650000), auc=0.816217::: time:291.44s
# - epoch:16 -
# Epoch: [16][0/60] Elapsed 0m 1s (remain 1m 35s) Loss: 0.3230(0.3230)
# Epoch: [16][59/60] Elapsed 0m 35s (remain 0m 0s) Loss: 0.4644(0.3425)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.7774(0.7774)
# EVAL: [18/19] Elapsed 0m 5s (remain 0m 0s) Loss: 0.4731(0.4719)
# 	 epoch:16, avg train loss:0.3425, avg valid loss:0.4719
# 	 score:0.5006(th=0.550000), auc=0.818098::: time:347.97s
# Epoch 16 - Save Best Score: 0.5006. Model is saved.
# dice_list:  [0.22725597096376965, 0.30087818957300094, 0.35856992374647434, 0.3998863720156095, 0.4347711580120909, 0.4601086480967861, 0.478341335393716, 0.4902676521485157, 0.4970468126871969, 0.5006311495861121, 0.5003671830201964, 0.49761772968903845, 0.49304921690908393, 0.4862231647532956, 0.47711553089094433, 0.4647574988141697, 0.4458068213636831, 0.4191419585297457, 0.16474656190161907]
# Epoch 16 - Save Best AUC: 0.8181. Model is saved.
# - epoch:17 -
# Epoch: [17][0/60] Elapsed 0m 1s (remain 1m 39s) Loss: 0.3906(0.3906)
# Epoch: [17][59/60] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3381(0.3311)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 0.7458(0.7458)
# EVAL: [18/19] Elapsed 0m 5s (remain 0m 0s) Loss: 0.4967(0.4785)
# 	 epoch:17, avg train loss:0.3311, avg valid loss:0.4785
# 	 score:0.5000(th=0.600000), auc=0.817553::: time:406.52s
# - epoch:18 -
# Epoch: [18][0/60] Elapsed 0m 1s (remain 1m 31s) Loss: 0.2789(0.2789)
# Epoch: [18][59/60] Elapsed 0m 35s (remain 0m 0s) Loss: 1.1660(0.3464)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 8s) Loss: 1.4746(1.4746)
# EVAL: [18/19] Elapsed 0m 5s (remain 0m 0s) Loss: 0.5230(0.5699)
# 	 epoch:18, avg train loss:0.3464, avg valid loss:0.5699
# 	 score:0.5010(th=0.650000), auc=0.817480::: time:461.78s
# Epoch 18 - Save Best Score: 0.5010. Model is saved.
# ...
# Epoch 1 - Save Best Score: 0.3752. Model is saved.
# dice_list:  [0.19840918986266573, 0.2002936677773869, 0.21894493055216907, 0.2248208900162937, 0.23380441240685856, 0.24752234426670777, 0.27221542007166455, 0.31208084736850294, 0.35650756337356865, 0.3751839669472646, 0.36864004961127234, 0.3498038151605965, 0.3309009681537238, 0.3157197358622502, 0.30164366196035985, 0.2865869255115909, 0.2703988074998744, 0.24673798154157986, 0.02853911919529227]
# Epoch 1 - Save Best AUC: 0.8410. Model is saved.
# - epoch:2 -
# Epoch: [2][0/63] Elapsed 0m 1s (remain 1m 38s) Loss: 0.6457(0.6457)
# Epoch: [2][62/63] Elapsed 0m 35s (remain 0m 0s) Loss: 0.5513(0.5854)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5277(0.5277)
# EVAL: [15/16] Elapsed 0m 3s (remain 0m 0s) Loss: 0.5079(0.6345)
# 	 epoch:2, avg train loss:0.5854, avg valid loss:0.6345
# 	 score:0.3699(th=0.600000), auc=0.856632::: time:109.97s
# Epoch 2 - Save Best AUC: 0.8566. Model is saved.
# - epoch:3 -
# Epoch: [3][0/63] Elapsed 0m 1s (remain 1m 29s) Loss: 0.5661(0.5661)
# Epoch: [3][62/63] Elapsed 0m 39s (remain 0m 0s) Loss: 0.4707(0.5107)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 7s) Loss: 1.0764(1.0764)
# EVAL: [15/16] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4211(0.7455)
# 	 epoch:3, avg train loss:0.5107, avg valid loss:0.7455
# 	 score:0.4665(th=0.850000), auc=0.880516::: time:171.24s
# Epoch 3 - Save Best Score: 0.4665. Model is saved.
# dice_list:  [0.19837484399049135, 0.19837525673085352, 0.21657179646589872, 0.23135895282370084, 0.24521947716248096, 0.26843580864866556, 0.2998171082566356, 0.32860762324338355, 0.35499566767765395, 0.38078050537482677, 0.40571945819731575, 0.4298726749686708, 0.44678022058542083, 0.45867002719911765, 0.46507250940505895, 0.466500619994014, 0.4630916987110418, 0.44057842786475043, 0.09496755061838714]
# Epoch 3 - Save Best AUC: 0.8805. Model is saved.
# - epoch:4 -
# Epoch: [4][0/63] Elapsed 0m 1s (remain 1m 36s) Loss: 0.4324(0.4324)
# Epoch: [4][62/63] Elapsed 0m 36s (remain 0m 0s) Loss: 0.4972(0.4662)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5209(0.5209)
# EVAL: [15/16] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3718(0.5756)
# 	 epoch:4, avg train loss:0.4662, avg valid loss:0.5756
# 	 score:0.4463(th=0.750000), auc=0.869736::: time:229.70s
# - epoch:5 -
# Epoch: [5][0/63] Elapsed 0m 1s (remain 1m 42s) Loss: 0.4327(0.4327)
# Epoch: [5][62/63] Elapsed 0m 35s (remain 0m 0s) Loss: 0.5038(0.4321)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5829(0.5829)
# EVAL: [15/16] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4776(0.6896)
# 	 epoch:5, avg train loss:0.4321, avg valid loss:0.6896
# 	 score:0.4207(th=0.900000), auc=0.856707::: time:284.87s
# - epoch:6 -
# Epoch: [6][0/63] Elapsed 0m 1s (remain 1m 30s) Loss: 0.4437(0.4437)
# Epoch: [6][62/63] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3544(0.3969)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 6s) Loss: 0.4347(0.4347)
# EVAL: [15/16] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3097(0.5252)
# 	 epoch:6, avg train loss:0.3969, avg valid loss:0.5252
# 	 score:0.4325(th=0.800000), auc=0.858783::: time:339.74s
# - epoch:7 -
# Epoch: [7][0/63] Elapsed 0m 1s (remain 1m 40s) Loss: 0.3593(0.3593)
# Epoch: [7][62/63] Elapsed 0m 35s (remain 0m 0s) Loss: 0.4460(0.3855)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5453(0.5453)
# EVAL: [15/16] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4085(0.6899)
# 	 epoch:7, avg train loss:0.3855, avg valid loss:0.6899
# 	 score:0.4351(th=0.950000), auc=0.855294::: time:395.00s
# - epoch:8 -
# Epoch: [8][0/63] Elapsed 0m 1s (remain 1m 36s) Loss: 0.4841(0.4841)
# Epoch: [8][62/63] Elapsed 0m 38s (remain 0m 0s) Loss: 0.4661(0.3827)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 6s) Loss: 0.4979(0.4979)
# EVAL: [15/16] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3863(0.6368)
# 	 epoch:8, avg train loss:0.3827, avg valid loss:0.6368
# 	 score:0.4358(th=0.900000), auc=0.854699::: time:453.56s
# - epoch:9 -
# Epoch: [9][0/63] Elapsed 0m 1s (remain 1m 37s) Loss: 0.3744(0.3744)
# Epoch: [9][62/63] Elapsed 0m 35s (remain 0m 0s) Loss: 0.3232(0.3694)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5909(0.5909)
# EVAL: [15/16] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4281(0.7519)
# 	 epoch:9, avg train loss:0.3694, avg valid loss:0.7519
# 	 score:0.4406(th=0.950000), auc=0.853172::: time:508.56s
# - epoch:10 -
# Epoch: [10][0/63] Elapsed 0m 1s (remain 1m 38s) Loss: 0.3378(0.3378)
# Epoch: [10][62/63] Elapsed 0m 38s (remain 0m 0s) Loss: 0.3659(0.3627)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5228(0.5228)
# EVAL: [15/16] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3945(0.6678)
# 	 epoch:10, avg train loss:0.3627, avg valid loss:0.6678
# 	 score:0.4361(th=0.900000), auc=0.854964::: time:566.70s
# surface_list:  range(27, 37, 3)
# - epoch:11 -
# Epoch: [11][0/63] Elapsed 0m 1s (remain 1m 32s) Loss: 0.3631(0.3631)
# Epoch: [11][62/63] Elapsed 0m 34s (remain 0m 0s) Loss: 0.6905(0.3770)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5575(0.5575)
# EVAL: [15/16] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3136(0.6323)
# 	 epoch:11, avg train loss:0.3770, avg valid loss:0.6323
# 	 score:0.4321(th=0.900000), auc=0.853551::: time:53.70s
# Epoch 11 - Save Best Score: 0.4321. Model is saved.
# dice_list:  [0.19868696743466394, 0.22074233998825207, 0.2495509935965673, 0.27208704871184425, 0.2951817838688565, 0.315749624033755, 0.3349085962278065, 0.3530447070627536, 0.3675475300787874, 0.3799180058926738, 0.3908473625937165, 0.40191731014077714, 0.4133373563490159, 0.4238257793832471, 0.4298875529170565, 0.43115557878692334, 0.4320975376539496, 0.4214570150348882, 0.12974308365490475]
# Epoch 11 - Save Best AUC: 0.8536. Model is saved.
# - epoch:12 -
# Epoch: [12][0/63] Elapsed 0m 1s (remain 1m 36s) Loss: 0.4405(0.4405)
# Epoch: [12][62/63] Elapsed 0m 37s (remain 0m 0s) Loss: 0.3692(0.3749)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 6s) Loss: 0.6797(0.6797)
# EVAL: [15/16] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3157(0.7723)
# 	 epoch:12, avg train loss:0.3749, avg valid loss:0.7723
# 	 score:0.4390(th=0.900000), auc=0.850344::: time:113.92s
# Epoch 12 - Save Best Score: 0.4390. Model is saved.
# dice_list:  [0.19871044698734458, 0.2172809245389892, 0.24962138741375728, 0.2737102855855783, 0.29641378807136365, 0.3167989410556062, 0.33372309571995284, 0.34952674435382314, 0.3639697660850793, 0.3757969111192015, 0.386244606312577, 0.3978490822492879, 0.4093876314929801, 0.4202012711477402, 0.42830243900728254, 0.4328399217841568, 0.4389596791644316, 0.43705493086161507, 0.20623535193462128]
# - epoch:13 -
# Epoch: [13][0/63] Elapsed 0m 1s (remain 1m 33s) Loss: 0.3429(0.3429)
# Epoch: [13][62/63] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3320(0.3723)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5613(0.5613)
# EVAL: [15/16] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3289(0.6257)
# 	 epoch:13, avg train loss:0.3723, avg valid loss:0.6257
# 	 score:0.4315(th=0.850000), auc=0.852620::: time:170.27s
# - epoch:14 -
# Epoch: [14][0/63] Elapsed 0m 1s (remain 1m 42s) Loss: 0.3586(0.3586)
# Epoch: [14][62/63] Elapsed 0m 37s (remain 0m 0s) Loss: 0.3498(0.3670)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 7s) Loss: 0.4860(0.4860)
# EVAL: [15/16] Elapsed 0m 4s (remain 0m 0s) Loss: 0.2975(0.5622)
# 	 epoch:14, avg train loss:0.3670, avg valid loss:0.5622
# 	 score:0.4327(th=0.800000), auc=0.852760::: time:228.82s
# - epoch:15 -
# Epoch: [15][0/63] Elapsed 0m 1s (remain 1m 37s) Loss: 0.3694(0.3694)
# Epoch: [15][62/63] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3423(0.3665)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5629(0.5629)
# EVAL: [15/16] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3221(0.6379)
# 	 epoch:15, avg train loss:0.3665, avg valid loss:0.6379
# 	 score:0.4361(th=0.850000), auc=0.853527::: time:282.55s
# - epoch:16 -
# Epoch: [16][0/63] Elapsed 0m 1s (remain 1m 46s) Loss: 0.3331(0.3331)
# Epoch: [16][62/63] Elapsed 0m 37s (remain 0m 0s) Loss: 0.3808(0.3625)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 7s) Loss: 0.5813(0.5813)
# EVAL: [15/16] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3455(0.6468)
# 	 epoch:16, avg train loss:0.3625, avg valid loss:0.6468
# 	 score:0.4341(th=0.900000), auc=0.852128::: time:340.18s
# - epoch:17 -
# Epoch: [17][0/63] Elapsed 0m 1s (remain 1m 40s) Loss: 0.3466(0.3466)
# Epoch: [17][62/63] Elapsed 0m 33s (remain 0m 0s) Loss: 0.5492(0.3672)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5664(0.5664)
# EVAL: [15/16] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3149(0.6447)
# 	 epoch:17, avg train loss:0.3672, avg valid loss:0.6447
# 	 score:0.4334(th=0.900000), auc=0.852713::: time:393.59s
# - epoch:18 -
# Epoch: [18][0/63] Elapsed 0m 1s (remain 1m 43s) Loss: 0.3163(0.3163)
# Epoch: [18][62/63] Elapsed 0m 36s (remain 0m 0s) Loss: 0.3326(0.3740)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5583(0.5583)
# EVAL: [15/16] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3102(0.6360)
# 	 epoch:18, avg train loss:0.3740, avg valid loss:0.6360
# 	 score:0.4314(th=0.900000), auc=0.851014::: time:451.07s
# - epoch:19 -
# Epoch: [19][0/63] Elapsed 0m 1s (remain 1m 41s) Loss: 0.3548(0.3548)
# Epoch: [19][62/63] Elapsed 0m 34s (remain 0m 0s) Loss: 0.3020(0.3698)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5185(0.5185)
# EVAL: [15/16] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3166(0.5919)
# 	 epoch:19, avg train loss:0.3698, avg valid loss:0.5919
# 	 score:0.4344(th=0.850000), auc=0.853956::: time:504.88s
# Epoch 19 - Save Best AUC: 0.8540. Model is saved.
# - epoch:20 -
# Epoch: [20][0/63] Elapsed 0m 1s (remain 1m 33s) Loss: 0.3365(0.3365)
# Epoch: [20][62/63] Elapsed 0m 37s (remain 0m 0s) Loss: 0.3524(0.3661)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5300(0.5300)
# EVAL: [15/16] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3171(0.6050)
# 	 epoch:20, avg train loss:0.3661, avg valid loss:0.6050
# 	 score:0.4356(th=0.850000), auc=0.853858::: time:563.86s
# surface_list:  range(25, 35, 3)
# - epoch:21 -
# Epoch: [21][0/63] Elapsed 0m 1s (remain 1m 39s) Loss: 0.3298(0.3298)
# Epoch: [21][62/63] Elapsed 0m 34s (remain 0m 0s) Loss: 0.4291(0.3734)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 6s) Loss: 0.6590(0.6590)
# EVAL: [15/16] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4398(0.8054)
# 	 epoch:21, avg train loss:0.3734, avg valid loss:0.8054
# 	 score:0.4340(th=0.950000), auc=0.857771::: time:53.83s
# Epoch 21 - Save Best Score: 0.4340. Model is saved.
# dice_list:  [0.1984764605637247, 0.21351255138909042, 0.24068974282785574, 0.26071125112592, 0.2813645371643975, 0.3019475871141594, 0.31739564382760577, 0.32913230492801365, 0.33889918005281316, 0.3473709484556081, 0.3560334151421474, 0.36582522646863136, 0.3757573253783794, 0.38559859118520806, 0.3962733567860047, 0.4081590892122289, 0.4213711197611388, 0.4339926171441952, 0.15684033385426782]
# Epoch 21 - Save Best AUC: 0.8578. Model is saved.
# - epoch:22 -
# Epoch: [22][0/63] Elapsed 0m 1s (remain 1m 39s) Loss: 0.3336(0.3336)
# Epoch: [22][62/63] Elapsed 0m 37s (remain 0m 0s) Loss: 0.5085(0.3766)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 7s) Loss: 0.6254(0.6254)
# EVAL: [15/16] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3969(0.7400)
# 	 epoch:22, avg train loss:0.3766, avg valid loss:0.7400
# 	 score:0.4317(th=0.950000), auc=0.858660::: time:113.88s
# Epoch 22 - Save Best AUC: 0.8587. Model is saved.
# - epoch:23 -
# Epoch: [23][0/63] Elapsed 0m 1s (remain 1m 31s) Loss: 0.4302(0.4302)
# Epoch: [23][62/63] Elapsed 0m 33s (remain 0m 0s) Loss: 0.3751(0.3763)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5656(0.5656)
# EVAL: [15/16] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3871(0.6840)
# 	 epoch:23, avg train loss:0.3763, avg valid loss:0.6840
# 	 score:0.4285(th=0.900000), auc=0.858540::: time:169.09s
# - epoch:24 -
# Epoch: [24][0/63] Elapsed 0m 1s (remain 1m 38s) Loss: 0.3120(0.3120)
# Epoch: [24][62/63] Elapsed 0m 37s (remain 0m 0s) Loss: 0.4007(0.3696)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 7s) Loss: 0.6022(0.6022)
# EVAL: [15/16] Elapsed 0m 4s (remain 0m 0s) Loss: 0.3839(0.7168)
# 	 epoch:24, avg train loss:0.3696, avg valid loss:0.7168
# 	 score:0.4310(th=0.900000), auc=0.858442::: time:226.12s
# - epoch:25 -
# Epoch: [25][0/63] Elapsed 0m 1s (remain 1m 44s) Loss: 0.3683(0.3683)
# Epoch: [25][62/63] Elapsed 0m 34s (remain 0m 0s) Loss: 0.2866(0.3709)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5483(0.5483)
# EVAL: [15/16] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3855(0.6654)
# 	 epoch:25, avg train loss:0.3709, avg valid loss:0.6654
# 	 score:0.4315(th=0.900000), auc=0.859808::: time:280.42s
# Epoch 25 - Save Best AUC: 0.8598. Model is saved.
# - epoch:26 -
# Epoch: [26][0/63] Elapsed 0m 1s (remain 1m 36s) Loss: 0.4608(0.4608)
# Epoch: [26][62/63] Elapsed 0m 36s (remain 0m 0s) Loss: 0.3683(0.3669)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 7s) Loss: 0.6500(0.6500)
# EVAL: [15/16] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4370(0.7717)
# 	 epoch:26, avg train loss:0.3669, avg valid loss:0.7717
# 	 score:0.4345(th=0.950000), auc=0.858529::: time:338.59s
# Epoch 26 - Save Best Score: 0.4345. Model is saved.
# dice_list:  [0.19850442569489166, 0.2130226697046105, 0.24023974459103928, 0.2600086042205598, 0.281131222190239, 0.30195056906952833, 0.3184719095904526, 0.33055548646909333, 0.34036495369293185, 0.34977505884285987, 0.3602820975006152, 0.37081768889588845, 0.38147248173092607, 0.39143508856832915, 0.40247986476441366, 0.41231687849107335, 0.4262065813364072, 0.4345367754541412, 0.1528054212377048]
# - epoch:27 -
# Epoch: [27][0/63] Elapsed 0m 1s (remain 1m 36s) Loss: 0.3432(0.3432)
# Epoch: [27][62/63] Elapsed 0m 34s (remain 0m 0s) Loss: 0.4334(0.3679)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 6s) Loss: 0.6030(0.6030)
# EVAL: [15/16] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4314(0.7280)
# 	 epoch:27, avg train loss:0.3679, avg valid loss:0.7280
# 	 score:0.4295(th=0.950000), auc=0.858567::: time:393.92s
# - epoch:28 -
# Epoch: [28][0/63] Elapsed 0m 1s (remain 1m 41s) Loss: 0.4455(0.4455)
# Epoch: [28][62/63] Elapsed 0m 37s (remain 0m 0s) Loss: 0.3844(0.3819)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 7s) Loss: 0.7288(0.7288)
# EVAL: [15/16] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4543(0.8547)
# 	 epoch:28, avg train loss:0.3819, avg valid loss:0.8547
# 	 score:0.4331(th=0.950000), auc=0.859016::: time:451.17s
# - epoch:29 -
# Epoch: [29][0/63] Elapsed 0m 1s (remain 1m 38s) Loss: 0.4050(0.4050)
# Epoch: [29][62/63] Elapsed 0m 33s (remain 0m 0s) Loss: 0.6362(0.3747)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 6s) Loss: 0.7794(0.7794)
# EVAL: [15/16] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4398(0.9195)
# 	 epoch:29, avg train loss:0.3747, avg valid loss:0.9195
# 	 score:0.4427(th=0.950000), auc=0.859474::: time:505.30s
# Epoch 29 - Save Best Score: 0.4427. Model is saved.
# dice_list:  [0.19849608570214214, 0.21491831799764433, 0.24094566248607777, 0.2611968270440058, 0.2825460249474428, 0.3031820251216189, 0.3195437543963873, 0.3312863938091871, 0.3410237872452652, 0.3504051387528551, 0.3604652195935627, 0.37043592209695986, 0.38098420098807184, 0.3911621113507808, 0.40119726107201087, 0.41308038097231387, 0.42797702254674935, 0.44265773889090143, 0.232399900586048]
# - epoch:30 -
# Epoch: [30][0/63] Elapsed 0m 1s (remain 1m 42s) Loss: 0.4201(0.4201)
# Epoch: [30][62/63] Elapsed 0m 37s (remain 0m 0s) Loss: 0.3723(0.3825)
# EVAL: [0/16] Elapsed 0m 0s (remain 0m 6s) Loss: 0.6586(0.6586)
# EVAL: [15/16] Elapsed 0m 4s (remain 0m 0s) Loss: 0.4362(0.7700)
# 	 epoch:30, avg train loss:0.3825, avg valid loss:0.7700
# 	 score:0.4293(th=0.950000), auc=0.858592::: time:564.40s
# [fold4] slice ave score:0.4432(th=0.550000), auc=0.860314
# [fold4] BEST Epoch 29 - Save Best Score:0.4427. Best loss:0.9195
# [fold4] BEST AUC Epoch 25 - Save Best Score:0.8598. Best loss:0.6654
# fold[0] BEST SCORE = 0.5440 thr=0.7 (epoch=26)
# fold[0] slice ave score:0.5619(th=0.400000), auc=0.884233
# fold[1] BEST SCORE = 0.5079 thr=0.5 (epoch=22)
# fold[1] slice ave score:0.5207(th=0.300000), auc=0.818857
# fold[2] BEST SCORE = 0.4768 thr=0.6 (epoch=26)
# fold[2] slice ave score:0.4945(th=0.350000), auc=0.816687
# fold[3] BEST SCORE = 0.4388 thr=0.65 (epoch=23)
# fold[3] slice ave score:0.4570(th=0.350000), auc=0.892273
# fold[4] BEST SCORE = 0.4427 thr=0.95 (epoch=29)
# fold[4] slice ave score:0.4432(th=0.550000), auc=0.860314
# CPU times: user 1h 38min 54s, sys: 39min 11s, total: 2h 18min 5s
# Wall time: 2h 23min 40s

# %% [markdown]
# ---
# # OOF SCORE CHECK

# %%
# %%time
slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list = slide_inference(CFG)
for fold in CFG["folds"]:
    print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    wandb.log({"OOF SCORE" : {f"slice average score":slice_ave_score_list[fold],
                            f"slice average threshold":slice_ave_score_threshold_list[fold],
                            f"slice_average auc":slice_ave_auc_list[fold],
                            }})
# Out:
# -- fold0 slide inference start --
# surface_list:  range(26, 36, 3)
# slide pos: [0, 0]
# 	 score:0.5513(th=0.750000), auc=0.880254::: time:25.53s
# slide pos: [128, 0]
# 	 score:0.5366(th=0.800000), auc=0.868576::: time:42.60s
# slide pos: [0, 128]
# 	 score:0.5171(th=0.800000), auc=0.880429::: time:59.22s
# slide pos: [128, 128]
# 	 score:0.5267(th=0.750000), auc=0.879626::: time:76.31s
# surface_list:  range(27, 37, 3)
# slide pos: [0, 0]
# 	 score:0.5196(th=0.750000), auc=0.873830::: time:99.99s
# slide pos: [128, 0]
# 	 score:0.5016(th=0.800000), auc=0.861668::: time:116.61s
# slide pos: [0, 128]
# 	 score:0.4973(th=0.700000), auc=0.872711::: time:133.81s
# slide pos: [128, 128]
# 	 score:0.5042(th=0.750000), auc=0.872498::: time:151.11s
# surface_list:  range(25, 35, 3)
# slide pos: [0, 0]
# 	 score:0.5379(th=0.700000), auc=0.885216::: time:174.57s
# slide pos: [128, 0]
# 	 score:0.5462(th=0.800000), auc=0.867529::: time:191.53s
# slide pos: [0, 128]
# 	 score:0.5338(th=0.750000), auc=0.877156::: time:208.58s
# slide pos: [128, 128]
# 	 score:0.5255(th=0.750000), auc=0.876532::: time:226.51s
# [fold0] slice ave score:0.5677(th=0.650000), auc=0.894098
# -- fold1 slide inference start --
# surface_list:  range(26, 36, 3)
# slide pos: [0, 0]
# 	 score:0.5132(th=0.550000), auc=0.817234::: time:269.70s
# slide pos: [128, 0]
# 	 score:0.5026(th=0.500000), auc=0.819453::: time:292.00s
# slide pos: [0, 128]
# 	 score:0.4798(th=0.550000), auc=0.802272::: time:314.52s
# slide pos: [128, 128]
# 	 score:0.4812(th=0.500000), auc=0.816880::: time:336.51s
# surface_list:  range(27, 37, 3)
# slide pos: [0, 0]
# 	 score:0.5171(th=0.500000), auc=0.815461::: time:363.55s
# slide pos: [128, 0]
# 	 score:0.5024(th=0.500000), auc=0.820187::: time:385.51s
# slide pos: [0, 128]
# 	 score:0.4772(th=0.500000), auc=0.803052::: time:408.14s
# slide pos: [128, 128]
# 	 score:0.4830(th=0.550000), auc=0.817840::: time:430.43s
# surface_list:  range(25, 35, 3)
# slide pos: [0, 0]
# 	 score:0.5028(th=0.500000), auc=0.809825::: time:458.27s
# slide pos: [128, 0]
# 	 score:0.5005(th=0.550000), auc=0.816890::: time:480.15s
# slide pos: [0, 128]
# 	 score:0.4793(th=0.500000), auc=0.796210::: time:503.24s
# slide pos: [128, 128]
# 	 score:0.5035(th=0.500000), auc=0.812610::: time:525.32s
# [fold1] slice ave score:0.5523(th=0.500000), auc=0.847290
# -- fold2 slide inference start --
# surface_list:  range(26, 36, 3)
# slide pos: [0, 0]
# 	 score:0.4847(th=0.550000), auc=0.812497::: time:572.98s
# slide pos: [128, 0]
# 	 score:0.4942(th=0.550000), auc=0.820736::: time:594.25s
# slide pos: [0, 128]
# 	 score:0.4845(th=0.650000), auc=0.807251::: time:616.19s
# slide pos: [128, 128]
# 	 score:0.4801(th=0.650000), auc=0.821586::: time:637.48s
# surface_list:  range(27, 37, 3)
# slide pos: [0, 0]
# 	 score:0.5013(th=0.600000), auc=0.818902::: time:663.39s
# slide pos: [128, 0]
# 	 score:0.4955(th=0.550000), auc=0.823567::: time:684.95s
# slide pos: [0, 128]
# 	 score:0.4915(th=0.650000), auc=0.809087::: time:707.37s
# slide pos: [128, 128]
# 	 score:0.4850(th=0.600000), auc=0.822919::: time:728.73s
# surface_list:  range(25, 35, 3)
# slide pos: [0, 0]
# 	 score:0.4696(th=0.600000), auc=0.804113::: time:755.00s
# slide pos: [128, 0]
# 	 score:0.4831(th=0.550000), auc=0.812010::: time:777.95s
# slide pos: [0, 128]
# 	 score:0.4729(th=0.650000), auc=0.804293::: time:800.42s
# slide pos: [128, 128]
# 	 score:0.4737(th=0.550000), auc=0.813280::: time:823.18s
# [fold2] slice ave score:0.5225(th=0.500000), auc=0.840398
# -- fold3 slide inference start --
# surface_list:  range(26, 36, 3)
# slide pos: [0, 0]
# 	 score:0.4516(th=0.700000), auc=0.893824::: time:863.62s
# slide pos: [128, 0]
# 	 score:0.4478(th=0.700000), auc=0.901212::: time:880.67s
# slide pos: [0, 128]
# 	 score:0.4459(th=0.700000), auc=0.891481::: time:897.96s
# slide pos: [128, 128]
# 	 score:0.4821(th=0.600000), auc=0.904019::: time:914.87s
# surface_list:  range(27, 37, 3)
# slide pos: [0, 0]
# 	 score:0.4794(th=0.650000), auc=0.896738::: time:935.42s
# slide pos: [128, 0]
# 	 score:0.4629(th=0.700000), auc=0.903842::: time:952.52s
# slide pos: [0, 128]
# 	 score:0.4654(th=0.650000), auc=0.897813::: time:970.21s
# slide pos: [128, 128]
# 	 score:0.4912(th=0.650000), auc=0.903338::: time:987.80s
# surface_list:  range(25, 35, 3)
# slide pos: [0, 0]
# 	 score:0.4364(th=0.650000), auc=0.889008::: time:1009.01s
# slide pos: [128, 0]
# 	 score:0.4484(th=0.600000), auc=0.894473::: time:1026.16s
# slide pos: [0, 128]
# 	 score:0.4270(th=0.700000), auc=0.884901::: time:1043.89s
# slide pos: [128, 128]
# 	 score:0.4718(th=0.550000), auc=0.896470::: time:1062.04s
# [fold3] slice ave score:0.5134(th=0.550000), auc=0.910685
# -- fold4 slide inference start --
# surface_list:  range(26, 36, 3)
# slide pos: [0, 0]
# 	 score:0.4369(th=0.900000), auc=0.858667::: time:1107.95s
# slide pos: [128, 0]
# 	 score:0.4469(th=0.900000), auc=0.856923::: time:1129.16s
# slide pos: [0, 128]
# 	 score:0.4165(th=0.900000), auc=0.858994::: time:1149.84s
# slide pos: [128, 128]
# 	 score:0.4442(th=0.850000), auc=0.859702::: time:1170.95s
# surface_list:  range(27, 37, 3)
# slide pos: [0, 0]
# 	 score:0.4382(th=0.850000), auc=0.855857::: time:1200.74s
# slide pos: [128, 0]
# 	 score:0.4430(th=0.850000), auc=0.857045::: time:1221.59s
# slide pos: [0, 128]
# 	 score:0.4230(th=0.800000), auc=0.858764::: time:1242.42s
# slide pos: [128, 128]
# 	 score:0.4501(th=0.800000), auc=0.861494::: time:1263.46s
# surface_list:  range(25, 35, 3)
# slide pos: [0, 0]
# 	 score:0.4315(th=0.900000), auc=0.859808::: time:1293.22s
# slide pos: [128, 0]
# 	 score:0.4440(th=0.900000), auc=0.855569::: time:1314.72s
# slide pos: [0, 128]
# 	 score:0.4283(th=0.900000), auc=0.861826::: time:1336.19s
# slide pos: [128, 128]
# 	 score:0.4410(th=0.900000), auc=0.857952::: time:1357.39s
# [fold4] slice ave score:0.4666(th=0.800000), auc=0.874207
# fold[0] slice ave score:0.5677(th=0.894098), auc=0.650000
# fold[1] slice ave score:0.5523(th=0.847290), auc=0.500000
# fold[2] slice ave score:0.5225(th=0.840398), auc=0.500000
# fold[3] slice ave score:0.5134(th=0.910685), auc=0.550000
# fold[4] slice ave score:0.4666(th=0.874207), auc=0.800000
# CPU times: user 18min 3s, sys: 3min 17s, total: 21min 20s
# Wall time: 22min 56s

# %%
import yaml
with open(os.path.join(CFG["OUTPUT_DIR"], "Config.yaml"), "w") as f:
    yaml.dump(CFG, f)

# %%
if not CFG["DEBUG"]:
    wandb.finish()
