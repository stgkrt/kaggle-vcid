# %% [markdown]
# # ex022
# bug fix masked_img
# 5-fold
# img size 512
# output shape is half of input shape
# channel shuffle
# 学習時にrandom slide=False

# %%
import gc
import os
import random
import time
import math

import cv2
import numpy as np
import matplotlib.pyplot as plt

# model
import torch
import torchvision
import torch.nn as nn
import timm
from torchvision.models.feature_extraction import create_feature_extractor
import torchvision.transforms.functional as TF

# data loader
import albumentations as A
from albumentations.pytorch import ToTensorV2
from torch.utils.data import DataLoader, Dataset

# training
from torch.optim import SGD, Adam, AdamW
from torch.optim.lr_scheduler import CosineAnnealingLR, CosineAnnealingWarmRestarts, ReduceLROnPlateau, ExponentialLR

# metric
from sklearn.metrics import fbeta_score, roc_auc_score

import wandb

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # config

# %%
BASE_DIR = "/working/"
INPUT_DIR = os.path.join(BASE_DIR, "input", "vesuvius-challenge-ink-detection")
TRAIN_DIR = os.path.join(INPUT_DIR, "train")
TEST_DIR = os.path.join(INPUT_DIR, "test")
# IMG_SIZE = [256, 256]
# IMG_SIZE = [128, 128]
IMG_SIZE = [512, 512]
SURFACE_LIST = [
                list(range(26, 36, 3)),
                list(range(27, 37, 3)),                
                list(range(25, 35, 3)),
                ]
print(len(SURFACE_LIST[0]))
print(SURFACE_LIST)

SURFACE_NUM = len(SURFACE_LIST[0])
# print("Start surface idx =",START_SURFACE)

# SLIDE_POS_LIST = [[idx*(IMG_SIZE[0]//6), idx*(IMG_SIZE[1]//6)] for idx in range(0, 3)]
SLIDE_POS_LIST = [[0,0], [IMG_SIZE[0]//2, 0], [0, IMG_SIZE[1]//2], [IMG_SIZE[0]//2, IMG_SIZE[1]//2]]
print("SLIDE_POS_LIST =", SLIDE_POS_LIST)
CFG = {
    "DEBUG" : False,
    # exp setting
    "EXP_CATEGORY" : "5fold",
    "EXP_NAME" : "exp022",
    "folds" : [0, 1, 2, 3, 4],

    # model
    # "model_name" : "tf_efficientnet_b0",
    "model_name" : "tf_efficientnet_b6",
    "inp_channels" : SURFACE_NUM,
    "out_channels" : 1,
    "pretrained" : True,
    "out_indices" : [0,1,2,3,4],
 
    # data   
    "img_size": IMG_SIZE,
    # "batch_size": 32,
    # "batch_size": 16,#batch normの関係か？16の方が64より安定してそう？？
    "batch_size": 8,
    "INPUT_DIR": INPUT_DIR,
    "TRAIN_DIR": TRAIN_DIR,
    "TEST_DIR": TEST_DIR,
    "surface_num": SURFACE_NUM,
    "surface_list": list(SURFACE_LIST),
    "slide_pos_list": SLIDE_POS_LIST,
    "RANDOM_SLIDE": True,
#     "surface_start_idx": START_SURFACE,
    # "TRAIN_DIR_LIST": [["1", "2"], ["1", "3"], ["2", "3"]],
    "TRAIN_DIR_LIST": [["1", "2_0", "2_1", "2_2"], 
                       ["1", "2_0", "2_1", "3"],
                       ["1", "2_0",  "2_2", "3"],
                       ["1", "2_1", "2_2", "3"],
                       ["2_0", "2_1", "2_2", "3"],
                       ],
#     "TRAIN_IDX_LIST" : ["1"],
    # "VALID_DIR_LIST": [["3"],["2"],["1"]],
    "VALID_DIR_LIST": [["3"], ["2_2"], ["2_1"], ["2_0"],["1"]],
    "TEST_DIR_LIST": ["a", "b"],

    # learning
    "n_epoch" : 20,
    "lr" : 1e-3,
    "T_max" : 5,
    "min_lr" : 1e-8,
    "weight_decay" : 1e-6,

    # etc
    "print_freq" : 1000,
    "random_seed" : 21,
    "num_workers": 2,
}


if CFG["model_name"]=="tf_efficientnet_b0":
    CFG["channel_nums"] = [320, 112, 40, 24, 16]
elif CFG["model_name"]=="tf_efficientnet_b4":
    CFG["channel_nums"] = [448, 160, 56, 32, 24]
elif CFG["model_name"]=="tf_efficientnet_b6":
    CFG["channel_nums"] = [576, 200, 72, 40, 32]


if CFG["DEBUG"]:
    CFG["n_epoch"] = 1
    CFG["EXP_NAME"] = "DEBUG"
    

CFG["OUTPUT_DIR"] = os.path.join(BASE_DIR, "output", CFG["EXP_NAME"])
# Out:
# 4
# [[26, 29, 32, 35], [27, 30, 33, 36], [25, 28, 31, 34]]
# SLIDE_POS_LIST = [[0, 0], [256, 0], [0, 256], [256, 256]]

# %%
if not CFG["DEBUG"]:
    os.makedirs(CFG["OUTPUT_DIR"])
    os.makedirs(os.path.join(CFG["OUTPUT_DIR"], "imgs"))

# %%
if not CFG["DEBUG"]:
    WANDB_CONFIG = {'competition': 'vcid', '_wandb_kernel': 'taro'}
    os.environ["WANDB_SILENT"] = "true"
    wandb.init(project=WANDB_CONFIG["competition"], config=CFG, group=CFG["EXP_CATEGORY"], name=CFG["EXP_NAME"], reinit=True)
# Out:
# 2023-04-20 22:35:47.617976: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-20 22:35:47.699960: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-20 22:35:48.294865: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-20 22:35:48.294955: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-04-20 22:35:48.294963: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# # utils

# %%
def logging_metrics_epoch(CFG, fold, epoch, slice_idx,train_loss_avg, valid_loss_avg, score, threshold, auc_score):
    wandb.log({f"train/fold{fold}": train_loss_avg,
                f"valid/fold{fold}": valid_loss_avg,
                f"score/fold{fold}":score,
                f"score threshold/fold{fold}":threshold,
                f"auc/fold{fold}":auc_score,
                f"epoch/fold{fold}":epoch+slice_idx*CFG["n_epoch"],
                })

# %%
def seed_everything(seed=CFG["random_seed"]):
    #os.environ['PYTHONSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic =True
    torch.backends.cudnn.benchmark = False
seed_everything()

# device optimization
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
def asMinutes(s):
    """Convert Seconds to Minutes."""
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    """Accessing and Converting Time Data."""
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))

class AverageMeter(object):
    """Computes and stores the average and current value."""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# # metric

# %%
def fbeta_numpy(targets, preds, beta=0.5, smooth=1e-5):
    y_true_count = targets.sum()
    ctp = preds[targets==1].sum()
    cfp = preds[targets==0].sum()
    beta_squared = beta * beta

    c_precision = ctp / (ctp + cfp + smooth)
    c_recall = ctp / (y_true_count + smooth)
    dice = (1 + beta_squared) * (c_precision * c_recall) / (beta_squared * c_precision + c_recall + smooth)

    return dice

def calc_fbeta_auc(mask, mask_pred):
    mask = mask.astype(int).flatten()
    mask_pred = mask_pred.flatten()

    best_th = 0
    best_dice = 0
    dice_list = [] 
    # for th in np.array(range(10, 50+1, 5)) / 100:
    for th in np.array(range(10, 100+1, 5)) / 100:
        # dice = fbeta_score(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice = fbeta_numpy(mask, (mask_pred >= th).astype(int), beta=0.5)
        dice_list.append(dice)
        # print(f'\t th: {th}, fbeta: {dice}')
        if dice > best_dice:
            best_dice = dice
            best_th = th
    
    auc = roc_auc_score(mask, mask_pred)
    # Logger.info(f'best_th: {best_th}, fbeta: {best_dice}')
    return best_dice, best_th, auc, dice_list


def calc_cv(mask_gt, mask_pred):
    best_dice, best_th, auc, dice_list = calc_fbeta_auc(mask_gt, mask_pred)

    return best_dice, best_th, auc, dice_list

# %% [markdown]
# # model

# %%
class Encoder(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = timm.create_model(CFG["model_name"], in_chans=CFG["inp_channels"], features_only=True, out_indices=CFG["out_indices"], pretrained=CFG["pretrained"])
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        return skip_connection_list

class UpConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.bn1 = nn.BatchNorm2d(in_channels)
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size = 2, padding="same")
        self.bn2 = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        x = self.up(x)
        x = self.bn1(x)
        x = self.conv(x)
        x = self.bn2(x)
        return x


class Decoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.UpConv_0 = UpConv(CFG["channel_nums"][0], CFG["channel_nums"][1])
        self.UpConv_1 = UpConv(CFG["channel_nums"][1]*2, CFG["channel_nums"][2])
        self.UpConv_2 = UpConv(CFG["channel_nums"][2]*2, CFG["channel_nums"][3])
        self.UpConv_3 = UpConv(CFG["channel_nums"][3]*2, CFG["channel_nums"][4])
        # self.UpConv_4 = UpConv(CFG["channel_nums"][4]*2, CFG["channel_nums"][4])
    
    def forward(self, skip_connection_list):
        emb = self.UpConv_0(skip_connection_list[4]) # emb.shape = (None, 160, 14, 14)
        emb_cat = torch.cat([skip_connection_list[3], emb], dim = 1)
        
        emb = self.UpConv_1(emb_cat)
        emb_cat = torch.cat([skip_connection_list[2], emb], dim = 1)
        
        emb = self.UpConv_2(emb_cat)
        emb_cat = torch.cat([skip_connection_list[1], emb], dim = 1)
        
        emb = self.UpConv_3(emb_cat)
        emb_cat = torch.cat([skip_connection_list[0], emb], dim = 1)

        # emb_cat = self.UpConv_4(emb_cat)
        
        return emb_cat

class SegModel(nn.Module):
    def __init__(self, CFG):
        super().__init__()
        self.encoder = Encoder(CFG)
        self.decoder = Decoder()
        self.head = nn.Sequential(
            nn.Conv2d(CFG["channel_nums"][-1]*2, CFG["out_channels"], kernel_size=1, stride=1, padding=0),
            nn.Sigmoid()
        )
    def forward(self, img):
        skip_connection_list = self.encoder(img)
        emb = self.decoder(skip_connection_list)
        output = self.head(emb)
        return output

# %% [markdown]
# # Dataset

# %%
train_transforms = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.RandomCrop(int(CFG["img_size"][0]*0.8), int(CFG["img_size"][1]*0.8), p=0.3),
    A.Blur(blur_limit=3, p=0.3),
    A.Resize(CFG["img_size"][0], CFG["img_size"][1]),
    ToTensorV2(),
])

valid_transforms = A.Compose([
    ToTensorV2(),
])

# %%
class VCID_Dataset(Dataset):
    def __init__(self, CFG, data_dir_list, surface_list, surface_volumes=None, slide_pos=[0,0], mode="train", transform=None):
        # get config
        self.mode = mode
        self.RANDOM_SLIDE = CFG["RANDOM_SLIDE"]
        self.img_size = CFG["img_size"]
        if self.mode=="train":  self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode=="valid":    self.DATADIR = CFG["TRAIN_DIR"]
        elif self.mode == "test":   self.DATADIR = CFG["TEST_DIR"]
        self.data_dir_list = data_dir_list
        self.surface_list = surface_list
        self.slide_pos = slide_pos
        self.transform = transform
        
        # get imgs
        # print("initializing dataset...")
        self.imgs = []
        for data_dir in self.data_dir_list:
            img_path = os.path.join(self.DATADIR, data_dir, "mask.png")
            # print(img_path)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            img = img.reshape(img.shape[0], img.shape[1], 1) # (h, w, channel=1)
            assert img is not None, "img is None. data path is wrong"
        
            # mask erosion
            # kernel_size = (img.shape[0]+img.shape[1])//2//100
            # kernel = np.ones((kernel_size, kernel_size), np.uint8)
            # img = cv2.erode(img, kernel,iterations = 3)
            # self.imgs.append(img[:,:,np.newaxis])  
            self.imgs.append(img)  
        
        # get and split surface
        if surface_volumes is None:
            self.surface_vols = self.read_surfacevols()
        else:
            # print("using loaded surface_vols")
            self.surface_vols = surface_volumes
        # for surface_idx, surface_vol in enumerate(self.surface_vols):
        #     self.surface_vols[surface_idx] = self.get_masked_img(surface_vol, self.imgs[surface_idx])
       
        # split grid
        self.get_all_grid()
        self.fileter_grid()
        self.get_flatten_grid()
        # print("split grid done.") 
       
        # get label imgs
        if self.mode == "train" or self.mode == "valid":
            self.labels = []
            for data_dir in self.data_dir_list:
                label_path = os.path.join(self.DATADIR, data_dir, "inklabels.png")
                assert os.path.exists(label_path), f"{label_path} is not exist."
                # read label
                label = cv2.imread(label_path, cv2.IMREAD_GRAYSCALE)
                label = label.reshape(label.shape[0], label.shape[1], 1) # (h, w, channel=1)
                self.labels.append(label)# 画像サイズがそれぞれ違うので単純にconcatできずlist化しているs
        # print("initializing dataset done.")

    def get_surface_volumes(self):
        return self.surface_vols

    def read_surfacevols(self):
        """ read surface volume by data_dir_list and surface_list 
            Returns:surface_vuls (list): surface volume list [array(h,w,channel=surface_num), array(), ...]
        """
        surface_vols = []
        # print("reading surface volume...")
        for data_dir in self.data_dir_list:
            surface_vol_ = None
            for read_idx, surface_idx in enumerate(self.surface_list):
                # print("\r", f"reading idx : {read_idx+1}/{len(self.surface_list)}", end="")
                surface_path = os.path.join(self.DATADIR, data_dir, "surface_volume", f"{surface_idx:02}.tif")
                surface_vol = cv2.imread(surface_path, cv2.IMREAD_GRAYSCALE)
                surface_vol = surface_vol.reshape(surface_vol.shape[0], surface_vol.shape[1], 1) # (h, w, channel=1)
                if surface_vol_ is None:
                    surface_vol_ = surface_vol
                else:
                    surface_vol_ = np.concatenate([surface_vol_, surface_vol], axis=2) # (h, w, channel=surface_num)
            surface_vols.append(surface_vol_)
            # print(f"  => read surface volume done. [{data_dir}]")
        return surface_vols


    def get_grid_img(self, img, grid_idx):
        """ crop grid img from original img"""
        img_grid = img[(grid_idx[0]*self.img_size[0]) + self.slide_pos[0] : ((grid_idx[0]+1)*self.img_size[0]) + self.slide_pos[0],
                        (grid_idx[1]*self.img_size[1]) + self.slide_pos[1] : ((grid_idx[1]+1)*self.img_size[1]) + self.slide_pos[1]]
        return img_grid
    
    def get_grid_img_and_mask(self, img, mask, grid_idx):
        """ crop grid img from original img"""
        if self.RANDOM_SLIDE and self.mode=="train" and random.random() < 0.5:
            if (grid_idx[0]!=0 and grid_idx[1]!=0) and (grid_idx[0]!=img.shape[0]//self.img_size[0] and grid_idx[1]!=img.shape[1]//self.img_size[1]):
                rand_pos = [np.random.randint(0, self.img_size[0]//4) - self.img_size[0]//4, np.random.randint(0, self.img_size[1]//4)-self.img_size[1]//4]
            else:
                rand_pos = [0, 0]
        else:
            rand_pos = [0, 0]
        img_grid = img[(grid_idx[0]*self.img_size[0]) + self.slide_pos[0] + rand_pos[0] : ((grid_idx[0]+1)*self.img_size[0]) + self.slide_pos[0] + rand_pos[0],
                        (grid_idx[1]*self.img_size[1]) + self.slide_pos[1] + rand_pos[1] : ((grid_idx[1]+1)*self.img_size[1]) + self.slide_pos[1] + rand_pos[1]]
        mask_grid = mask[(grid_idx[0]*self.img_size[0]) + self.slide_pos[0] + rand_pos[0] : ((grid_idx[0]+1)*self.img_size[0]) + self.slide_pos[0] + rand_pos[0],
                         (grid_idx[1]*self.img_size[1]) + self.slide_pos[1] + rand_pos[1] : ((grid_idx[1]+1)*self.img_size[1]) + self.slide_pos[1] + rand_pos[1]]
        return img_grid/255., mask_grid/255.
    
    def get_masked_img(self, img, mask):
        """ multiply mask to surface_volumes """
        masked_img = None
        for channel in range(img.shape[2]):
            img_channel = img[:,:,channel].reshape(img.shape[0], img.shape[1],1)
            masked = img_channel*mask
            if masked_img is None:
                masked_img = masked.reshape(masked.shape[0], masked.shape[1], 1)
            else:
                masked = masked.reshape(masked.shape[0], masked.shape[1], 1)
                masked_img = np.concatenate([masked_img, masked], axis=2)
        return masked_img
    
    
    def get_all_grid(self):
        """ get all grid indices by img size and grid size
        """
        self.grid_indices = []
        for img in self.imgs:
            self.x_grid_size = (img.shape[0] - self.slide_pos[0]) // self.img_size[0]
            self.y_grid_size = (img.shape[1] - self.slide_pos[1]) // self.img_size[1]
            grid_img = []
            for i in range(self.x_grid_size):
                for j in range(self.y_grid_size):
                    grid_img.append([i, j])
            self.grid_indices.append(grid_img)
        return self.grid_indices
          
    def fileter_grid(self):
        """ get grid indices which mask is not 0 by all grid indices"""
        grid_indices_all = []
        for img, grid_indices in zip(self.imgs, self.grid_indices):
            grid_indices_copy = grid_indices.copy()
            for grid_idx in grid_indices:
                img_grid = self.get_grid_img(img, grid_idx)
                if img_grid.sum() == 0:
                    grid_indices_copy.remove(grid_idx)
            grid_indices_all.append(grid_indices_copy)
        self.grid_indices = grid_indices_all
        return self.grid_indices

    def get_flatten_grid(self):
        """ get flatten index list by grid indices
            Returns:flatten_grid (list): flatten index list [[img_idx, grid_idx], [img_idx, grid_idx], ...]
        """
        flatten_grid = []
        for img_idx, grid_indices in enumerate(self.grid_indices):
            for grid_idx in grid_indices:
                grid_imgidx_list = [img_idx]
                grid_imgidx_list.extend(grid_idx)
                flatten_grid.append(grid_imgidx_list)
        self.flatten_grid = flatten_grid
        return self.flatten_grid
    
    def channel_shuffle(self, img):
        img = img.transpose(2, 0, 1)
        np.random.shuffle(img)
        return img.transpose(1, 2, 0)

    def __len__(self):
        return len(self.flatten_grid)

    def __getitem__(self, idx):
        # get indices
        img_grid_idx = self.flatten_grid[idx]
        img_idx = img_grid_idx[0]
        grid_idx = img_grid_idx[1:]
        # get img & surface_vol
        mask = self.imgs[img_idx]
        surface_vol = self.surface_vols[img_idx]
        # mask = self.get_grid_img(mask, grid_idx)/255.
        # surface_vol = self.get_grid_img(surface_vol, grid_idx)/255.
        mask, surface_vol = self.get_grid_img_and_mask(mask, surface_vol, grid_idx)
        # multiple small mask 
        assert surface_vol.shape[0]==mask.shape[0] and surface_vol.shape[1]==mask.shape[1] , "surface_vol_list shape is not same as img shape"
        img = surface_vol
        # transform
        if self.mode == "test":
            if self.transform:
                img = self.transform(image=img)["image"]
            else:
                img = img.transpose(2, 0, 1)
                img = torch.tensor(img, dtype=torch.float32)
            return img, grid_idx
        elif self.mode == "train" or self.mode=="valid":
            # get label(segmentation mask)
            label = self.labels[img_idx]
            label = self.get_grid_img(label, grid_idx)
            if self.mode == "train":
                img = self.channel_shuffle(img)
            if self.transform:
                transformed = self.transform(image=img, mask=label)
                img = transformed["image"]
                label = transformed["mask"]
                label = label.permute(2, 0, 1)/255. # (channel, h, w)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            else:
                img = img.transpose(2, 0, 1) # (channel, h, w)
                label = label.transpose(2, 0, 1)/255. # (channel, h, w){}
                img = torch.tensor(img, dtype=torch.float32)
                label = torch.tensor(label, dtype=torch.float32)
                # label = TF.resize(img=label, size=(self.img_size[0]//2, self.img_size[1]//2))
            return img, label, grid_idx

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train")
# surface_volumes = dataset_notrans.surface_vols
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx < 2:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
        
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train")
# surface_volumes = dataset_notrans.surface_vols
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx < 2:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos=[0,50],mode="train")
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)

# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 1:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %%
# valid_dirs = CFG["VALID_DIR_LIST"][0]
# surface_list = SURFACE_LIST[0]
# print("dataset")
# dataset_notrans = VCID_Dataset(CFG, valid_dirs, surface_list, mode="train", transform=train_transforms)
# print("dataloader")
# dataloader_notrans = DataLoader(dataset_notrans, 4, shuffle=False, num_workers=0)


# imshow_batch = 10

# for batch_idx, (imgs, labels, grid_idx) in enumerate(dataloader_notrans):
#     img = imgs[0].permute(1, 2, 0)
#     if batch_idx == 0:
#         plt.figure(figsize=(20,5))
#         for channel in range(img.shape[2]):
#             plt.subplot(1, img.shape[2], channel+1)
#             plt.imshow(img[:,:,channel], cmap="gray")
#         plt.show()
#         [print(np.max(img[:,:,idx].numpy())) for idx in range(img.shape[2])]
#     if batch_idx >= imshow_batch:
#         break    

# img_hist, img_bins = np.histogram(np.array(img[:,:,0]).flatten())
# plt.figure()
# plt.plot(img_hist)
# plt.show()
# print(img[:,:,0])

# %% [markdown]
# # train valid fn

# %%
def train_fn(train_loader, model, criterion, epoch ,optimizer, scheduler):
    model.train()
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, _) in enumerate(train_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()     
        preds = model(images)
        preds = TF.resize(img=preds, size=(CFG["img_size"][0], CFG["img_size"][1]))
        # preds = torch.sigmoid(preds)
        loss = criterion(preds, targets)
        
        losses.update(loss.item(), CFG["batch_size"]) 
        targets = targets.detach().cpu().numpy().ravel().tolist()
        preds = preds.detach().cpu().numpy().ravel().tolist()
        loss.backward() # パラメータの勾配を計算
        optimizer.step() # モデル更新
        optimizer.zero_grad() # 勾配の初期化
                
        batch_time.update(time.time() - end)
        end = time.time()
        if batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(train_loader)-1):
            print('Epoch: [{0}][{1}/{2}] '
                    'Elapsed {remain:s} '
                    'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                    .format(
                        epoch, batch_idx, len(train_loader), batch_time=batch_time, loss=losses,
                        remain=timeSince(start, float(batch_idx+1)/len(train_loader)),
            ))
        del preds, images, targets
    gc.collect()
    torch.cuda.empty_cache()
    return losses.avg

# %%
def valid_fn(model, valid_loader, criterion=None):
    model.eval()# モデルを検証モードに設定
    test_targets = []
    test_preds = []
    test_grid_idx = []
    batch_time = AverageMeter()
    losses = AverageMeter()
    start = end = time.time()
    for batch_idx, (images, targets, grid_idx) in enumerate(valid_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float()
        with torch.no_grad():
            preds = model(images)
            preds = TF.resize(img=preds, size=(CFG["img_size"][0], CFG["img_size"][1]))
            if not criterion is None:
                loss = criterion(preds, targets)
        if not criterion is None:
            losses.update(loss.item(), CFG["batch_size"])
        batch_time.update(time.time() - end)

        targets = targets.detach().cpu().numpy()
        preds = preds.detach().cpu().numpy()
        
        test_preds.extend([preds[idx, :,:,:].transpose(1,2,0) for idx in range(preds.shape[0])])
        test_targets.extend([targets[idx, :,:,:].transpose(1,2,0) for idx in range(targets.shape[0])])
        test_grid_idx.extend([[x_idx, y_idx] for x_idx, y_idx in zip(grid_idx[0].tolist(), grid_idx[1].tolist())])

        if (batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(valid_loader)-1)) and (not criterion is None):
            print('EVAL: [{0}/{1}] '
                'Elapsed {remain:s} '
                'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                .format(
                    batch_idx, len(valid_loader), batch_time=batch_time, loss=losses,
                    remain=timeSince(start, float(batch_idx+1)/len(valid_loader)),
                ))
        del preds, images, targets
        gc.collect()
        torch.cuda.empty_cache()
    if criterion is None:
        return test_targets, test_preds, test_grid_idx
    else:
        return test_targets, test_preds, test_grid_idx, losses.avg

# %% [markdown]
# # training loop

# %%
# def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list):
#     # concat pred img and label to original size
#     img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
#     img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
#     img = img.reshape(img.shape[0], img.shape[1], 1)
#     pred_img = np.zeros_like(img).astype(np.float32)
#     label_img = np.zeros_like(img).astype(np.float32)
#     for img_idx, grid_idx in enumerate(grid_idx_list):
#         pred_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += img_list[img_idx]
        
#         label_img[grid_idx[0]*CFG["img_size"][0]:(grid_idx[0]+1)*CFG["img_size"][0],
#                 grid_idx[1]*CFG["img_size"][1]:(grid_idx[1]+1)*CFG["img_size"][1], :] += label_list[img_idx]
#     return pred_img, label_img

# %%
def concat_grid_img(img_list, label_list, grid_idx_list, valid_dir_list, slide_pos=[0,0]):
    # concat pred img and label to original size
    img_path = os.path.join(CFG["TRAIN_DIR"], valid_dir_list[0], "mask.png")
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    img = img.reshape(img.shape[0], img.shape[1], 1)
    pred_img = np.zeros_like(img).astype(np.float32)
    label_img = np.zeros_like(img).astype(np.float32)
    for img_idx, grid_idx in enumerate(grid_idx_list):
        pred_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += img_list[img_idx]
        
        label_img[grid_idx[0]*CFG["img_size"][0]+slide_pos[0] : (grid_idx[0]+1)*CFG["img_size"][0]+slide_pos[0],
                grid_idx[1]*CFG["img_size"][1]+slide_pos[1] : (grid_idx[1]+1)*CFG["img_size"][1]+slide_pos[1], :] += label_list[img_idx]
    return pred_img, label_img

# %%
def save_and_plot_oof(mode, fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary):
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_pred_img.png"), valid_preds_img*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_predbin_img.png"), valid_preds_binary*255)
    cv2.imwrite(os.path.join(CFG["OUTPUT_DIR"], "imgs", f"fold{fold}_{mode}_slice{slice_idx}_valid_targets_img.png"), valid_targets_img*255)
    
    # plot preds & binary preds
    # plt.figure(dpi=100)
    # plt.subplot(1,3,1)
    # plt.imshow(valid_preds_img)
    # plt.subplot(1,3,2)
    # plt.imshow(valid_preds_binary)
    # plt.subplot(1,3,3)
    # plt.imshow(valid_targets_img)
    # plt.show()

# %%
def training_loop(CFG):
    best_score_list = []
    best_threshold_list = []
    best_epoch_list = []
    slice_ave_score_list = []
    slice_ave_auc_list = []
    slice_ave_score_threshold_list = []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} training start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        model = model.to(device)
        valid_img_slice = []
        criterion = nn.BCELoss()
        optimizer = AdamW(model.parameters(), lr=CFG["lr"], weight_decay=CFG["weight_decay"], amsgrad=False)
        scheduler = CosineAnnealingLR(optimizer, T_max=CFG["T_max"], eta_min=CFG["min_lr"], last_epoch=-1)
        # scheduler = ExponentialLR(optimizer, gamma=0.60)
        
        # training
        best_score = -np.inf
        best_auc = -np.inf
        best_valloss = np.inf
        best_auc_valloss = np.inf
        best_threshold = -1
        start_time = time.time()
        best_epoch = -1
        best_auc_epoch = -1
        valid_slice_ave = None       
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            # separate train/valid data 
            train_dirs = CFG["TRAIN_DIR_LIST"][fold]
            valid_dirs = CFG["VALID_DIR_LIST"][fold]
            train_dataset = VCID_Dataset(CFG, train_dirs, surface_list, mode="train", transform=train_transforms)
            valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, mode="valid", transform=valid_transforms)
            train_loader = DataLoader(train_dataset, batch_size=CFG["batch_size"], shuffle = True,
                                        num_workers = CFG["num_workers"], pin_memory = True)
            valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                        num_workers = CFG["num_workers"], pin_memory = True)
            for epoch in range(1, CFG["n_epoch"] + 1):
                epochs_ = epoch + CFG["n_epoch"] * slice_idx
                print(f'- epoch:{epochs_} -')
                train_loss_avg = train_fn(train_loader, model, criterion, epochs_ ,optimizer, scheduler)
                valid_targets, valid_preds, valid_grid_idx, valid_loss_avg = valid_fn(model, valid_loader, criterion)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                
                elapsed = time.time() - start_time
                print(f"\t epoch:{epochs_}, avg train loss:{train_loss_avg:.4f}, avg valid loss:{valid_loss_avg:.4f}")
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                if not CFG["DEBUG"]:
                    logging_metrics_epoch(CFG, fold, epoch, slice_idx, train_loss_avg, valid_loss_avg, valid_score, valid_threshold, auc)
                scheduler.step()
                # validationスコアがbestを更新したらモデルを保存する
                if valid_score > best_score:
                    best_epoch = epochs_
                    best_valloss = valid_loss_avg
                    best_score = valid_score
                    best_threshold = valid_threshold
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epochs_} - Save Best Score: {best_score:.4f}. Model is saved.')
                    print("dice_list: ", dice_list)
                    # save oof
                    save_and_plot_oof("score", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
                
                if auc > best_auc:
                    best_auc = auc
                    best_auc_epoch = epochs_
                    best_auc_valloss = valid_loss_avg
                    model_name = CFG["model_name"]
                    model_path = os.path.join(CFG["OUTPUT_DIR"], f'{model_name}_auc_fold{fold}.pth')
                    torch.save(model.state_dict(), model_path) 
                    print(f'Epoch {epochs_} - Save Best AUC: {best_auc:.4f}. Model is saved.')
                    # save oof
                    save_and_plot_oof("auc", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary)
            # valid_img_slice.append(valid_preds_img)
            if valid_slice_ave is None:
                valid_slice_ave = valid_preds_img
            else:
                valid_slice_ave += valid_preds_img
        # valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        # for idx in range(len(SURFACE_LIST)):
        #     valid_pred_slice = valid_img_slice[idx]
        #     valid_slice_ave += valid_pred_slice
        valid_slice_ave /= len(SURFACE_LIST)
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_slice_ave)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)
 
        valid_slice_binary = (valid_slice_ave > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 999, valid_slice_ave, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
        
        print(f'[fold{fold}] BEST Epoch {best_epoch} - Save Best Score:{best_score:.4f}. Best loss:{best_valloss:.4f}')
        print(f'[fold{fold}] BEST AUC Epoch {best_auc_epoch} - Save Best Score:{best_auc:.4f}. Best loss:{best_auc_valloss:.4f}')
            
        best_score_list.append(best_score)
        best_threshold_list.append(best_threshold)
        best_epoch_list.append(best_epoch)
        del model, train_loader, train_dataset, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
        
    for fold, (best_score, best_threshold, best_epoch) in enumerate(zip(best_score_list, best_threshold_list, best_epoch_list)):
        print(f"fold[{fold}] BEST SCORE = {best_score:.4f} thr={best_threshold} (epoch={best_epoch})")
        print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    return best_score_list, best_threshold_list, best_epoch_list

# %% [markdown]
# # slice inference

# %%
def slide_inference(CFG):
    start_time = time.time()
    slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list = [], [], []
    for fold in CFG["folds"]:
        print(f"-- fold{fold} slide inference start --")
 
        # set model & learning fn
        model = SegModel(CFG)
        # model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_fold{fold}.pth')
        model_path = os.path.join(CFG["OUTPUT_DIR"], f'{CFG["model_name"]}_auc_fold{fold}.pth')
        model.load_state_dict(torch.load(model_path))
        model = model.to(device)
        valid_img_slice = None
        for slice_idx, surface_list in enumerate(SURFACE_LIST):
            print("surface_list: ", surface_list)
            surface_volumes = None
            for slide_pos in CFG["slide_pos_list"]:
                print("slide pos:", slide_pos)
                valid_dirs = CFG["VALID_DIR_LIST"][fold]
                valid_dataset = VCID_Dataset(CFG, valid_dirs, surface_list, surface_volumes, slide_pos, mode="valid", transform=valid_transforms)
                surface_volumes = valid_dataset.get_surface_volumes()
                valid_loader = DataLoader(valid_dataset, batch_size=CFG["batch_size"], shuffle = False,
                                            num_workers = CFG["num_workers"], pin_memory = True)

                valid_targets, valid_preds, valid_grid_idx = valid_fn(model, valid_loader)
                
                # target, predをconcatして元のサイズに戻す
                valid_preds_img, valid_targets_img  = concat_grid_img(valid_preds, valid_targets, valid_grid_idx, valid_dirs, slide_pos)
                valid_score, valid_threshold, auc, dice_list = calc_cv(valid_targets_img, valid_preds_img)
                valid_preds_binary = (valid_preds_img > valid_threshold).astype(np.uint8)
                save_and_plot_oof("slide", fold, slice_idx, valid_preds_img, valid_targets_img, valid_preds_binary) 
                
                elapsed = time.time() - start_time
                print(f"\t score:{valid_score:.4f}(th={valid_threshold:3f}), auc={auc:4f}::: time:{elapsed:.2f}s")
                # valid_img_slice.append(valid_preds_img)
                if valid_img_slice is None:
                    valid_img_slice = valid_preds_img
                else:
                    valid_img_slice += valid_preds_img
            # valid_slice_ave = np.zeros((valid_preds_img.shape[0], valid_preds_img.shape[1], 1))
        # for idx in range(len(SURFACE_LIST)*len(CFG["slide_pos_list"])):
        #     valid_pred_slice = valid_img_slice[idx]
        #     valid_slice_ave += valid_pred_slice
        valid_img_slice /= len(SURFACE_LIST)*len(CFG["slide_pos_list"])
        valid_sliceave_score, valid_sliceave_threshold, ave_auc, dice_list = calc_cv(valid_targets_img, valid_img_slice)
        
        slice_ave_score_list.append(valid_sliceave_score)
        slice_ave_auc_list.append(ave_auc)
        slice_ave_score_threshold_list.append(valid_sliceave_threshold)

        valid_slice_binary = (valid_img_slice > valid_sliceave_threshold).astype(np.uint8)
        save_and_plot_oof("average", fold, 555, valid_img_slice, valid_targets_img, valid_slice_binary)
        print(f'[fold{fold}] slice ave score:{valid_sliceave_score:.4f}(th={valid_sliceave_threshold:3f}), auc={ave_auc:4f}')
         
        del model, valid_loader, valid_dataset, valid_preds_img, valid_targets_img, valid_preds_binary
        gc.collect()
        torch.cuda.empty_cache()
    return slice_ave_score_list, slice_ave_auc_list, slice_ave_score_threshold_list

# %% [markdown]
# # main

# %%
# %%time
best_score_list, best_threshold_list, best_epoch_list = training_loop(CFG)
# Out:
# -- fold0 training start --
# surface_list:  [26, 29, 32, 35]
# - epoch:1 -
# Epoch: [1][0/65] Elapsed 0m 1s (remain 1m 30s) Loss: 0.7774(0.7774)
# Epoch: [1][64/65] Elapsed 0m 30s (remain 0m 0s) Loss: 0.1863(0.4637)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1150(0.1150)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3094(0.2881)
# 	 epoch:1, avg train loss:0.4637, avg valid loss:0.2881
# 	 score:0.4000(th=0.300000), auc=0.839899::: time:77.11s
# Epoch 1 - Save Best Score: 0.4000. Model is saved.
# dice_list:  [0.281463522502181, 0.3453042896882637, 0.38145203624884527, 0.39703603304921403, 0.3999860437891638, 0.3956257474768679, 0.3862506507676743, 0.3729354536787766, 0.3562958500919464, 0.3365729717407924, 0.3141328550844641, 0.28872758309433977, 0.2603719972652697, 0.22857535649254918, 0.1912732353348722, 0.14672047006524522, 0.09584779969193642, 0.04278464250082295, 0.0]
# Epoch 1 - Save Best AUC: 0.8399. Model is saved.
# - epoch:2 -
# Epoch: [2][0/65] Elapsed 0m 1s (remain 1m 25s) Loss: 0.3532(0.3532)
# Epoch: [2][64/65] Elapsed 0m 30s (remain 0m 0s) Loss: 0.2920(0.4107)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1751(0.1751)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2765(0.2962)
# 	 epoch:2, avg train loss:0.4107, avg valid loss:0.2962
# 	 score:0.2992(th=0.250000), auc=0.836248::: time:126.41s
# - epoch:3 -
# Epoch: [3][0/65] Elapsed 0m 1s (remain 1m 20s) Loss: 0.3242(0.3242)
# Epoch: [3][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.8098(0.4112)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1629(0.1629)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2757(0.2793)
# 	 epoch:3, avg train loss:0.4112, avg valid loss:0.2793
# 	 score:0.3903(th=0.350000), auc=0.859873::: time:171.73s
# Epoch 3 - Save Best AUC: 0.8599. Model is saved.
# - epoch:4 -
# Epoch: [4][0/65] Elapsed 0m 1s (remain 1m 20s) Loss: 0.5236(0.5236)
# Epoch: [4][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.2258(0.3907)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1489(0.1489)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2880(0.2696)
# 	 epoch:4, avg train loss:0.3907, avg valid loss:0.2696
# 	 score:0.4308(th=0.350000), auc=0.874332::: time:218.69s
# Epoch 4 - Save Best Score: 0.4308. Model is saved.
# dice_list:  [0.2724432318857778, 0.34554812876213914, 0.38810921203597704, 0.4102721865211999, 0.42334257142310194, 0.4307754070795591, 0.4299947251190423, 0.41872588325842747, 0.39750852364541456, 0.36450175371730054, 0.3199259522222082, 0.265433981989327, 0.20604045695410528, 0.14603528830239923, 0.08839899210829336, 0.04391877033428253, 0.016276209396338726, 0.0007363624735033145, 0.0]
# Epoch 4 - Save Best AUC: 0.8743. Model is saved.
# - epoch:5 -
# Epoch: [5][0/65] Elapsed 0m 1s (remain 1m 19s) Loss: 0.3454(0.3454)
# Epoch: [5][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.2175(0.3763)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1634(0.1634)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2711(0.2668)
# 	 epoch:5, avg train loss:0.3763, avg valid loss:0.2668
# 	 score:0.4503(th=0.400000), auc=0.878904::: time:267.00s
# Epoch 5 - Save Best Score: 0.4503. Model is saved.
# dice_list:  [0.2604015713761639, 0.3347670617508399, 0.3848401137284784, 0.41570829946339166, 0.4362795031847548, 0.4484440764685392, 0.4503448927668431, 0.4393757400451479, 0.41482849173294445, 0.376632325064477, 0.3260824362283955, 0.2594106449525565, 0.18530648961382554, 0.11688568953403082, 0.05949327022954579, 0.02675982712683374, 0.007647116458578777, 7.223077817953026e-05, 0.0]
# Epoch 5 - Save Best AUC: 0.8789. Model is saved.
# - epoch:6 -
# Epoch: [6][0/65] Elapsed 0m 1s (remain 1m 23s) Loss: 0.2719(0.2719)
# Epoch: [6][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.4366(0.3771)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1609(0.1609)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2661(0.2666)
# 	 epoch:6, avg train loss:0.3771, avg valid loss:0.2666
# 	 score:0.4534(th=0.450000), auc=0.879863::: time:315.36s
# Epoch 6 - Save Best Score: 0.4534. Model is saved.
# dice_list:  [0.25097286523728934, 0.3166178110331003, 0.3627697668925025, 0.393615595883647, 0.4162147664432387, 0.4347379614156522, 0.44809254231739104, 0.453415340478456, 0.4479519011524781, 0.4251123011467017, 0.38306772485560886, 0.32588930164467306, 0.2564145106349989, 0.17823430083960246, 0.10369701785878496, 0.04523776375756653, 0.015341077013987217, 0.0005006284188781821, 0.0]
# Epoch 6 - Save Best AUC: 0.8799. Model is saved.
# - epoch:7 -
# Epoch: [7][0/65] Elapsed 0m 1s (remain 1m 24s) Loss: 0.3719(0.3719)
# Epoch: [7][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.2968(0.3685)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1728(0.1728)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2649(0.2674)
# 	 epoch:7, avg train loss:0.3685, avg valid loss:0.2674
# 	 score:0.4665(th=0.500000), auc=0.879742::: time:363.83s
# Epoch 7 - Save Best Score: 0.4665. Model is saved.
# dice_list:  [0.25984423567550585, 0.31930081045654163, 0.3590508076502275, 0.3883729783532213, 0.41184621001127514, 0.4308901056944422, 0.44716211629452274, 0.46003408228330234, 0.46650621808591636, 0.46192228937060037, 0.44018124339134274, 0.3966695913649025, 0.33256133577684577, 0.25231864614003824, 0.16317967635364627, 0.08279492634823872, 0.0319060127106647, 0.00334593198021593, 0.0]
# - epoch:8 -
# Epoch: [8][0/65] Elapsed 0m 1s (remain 1m 26s) Loss: 0.3617(0.3617)
# Epoch: [8][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.1799(0.3744)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1732(0.1732)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2687(0.2714)
# 	 epoch:8, avg train loss:0.3744, avg valid loss:0.2714
# 	 score:0.4559(th=0.450000), auc=0.881343::: time:410.54s
# Epoch 8 - Save Best AUC: 0.8813. Model is saved.
# - epoch:9 -
# Epoch: [9][0/65] Elapsed 0m 1s (remain 1m 17s) Loss: 0.4412(0.4412)
# Epoch: [9][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.3008(0.3833)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1352(0.1352)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2838(0.2706)
# 	 epoch:9, avg train loss:0.3833, avg valid loss:0.2706
# 	 score:0.4270(th=0.300000), auc=0.868974::: time:456.45s
# - epoch:10 -
# Epoch: [10][0/65] Elapsed 0m 1s (remain 1m 31s) Loss: 0.3578(0.3578)
# Epoch: [10][64/65] Elapsed 0m 29s (remain 0m 0s) Loss: 0.4590(0.3884)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2109(0.2109)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2942(0.3150)
# 	 epoch:10, avg train loss:0.3884, avg valid loss:0.3150
# 	 score:0.4162(th=0.650000), auc=0.858444::: time:501.04s
# - epoch:11 -
# Epoch: [11][0/65] Elapsed 0m 1s (remain 1m 26s) Loss: 0.3860(0.3860)
# Epoch: [11][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.4907(0.3825)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1941(0.1941)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3345(0.3086)
# 	 epoch:11, avg train loss:0.3825, avg valid loss:0.3086
# 	 score:0.4043(th=0.600000), auc=0.848371::: time:545.23s
# - epoch:12 -
# Epoch: [12][0/65] Elapsed 0m 1s (remain 1m 29s) Loss: 0.2897(0.2897)
# Epoch: [12][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1747(0.3817)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1507(0.1507)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2789(0.2890)
# 	 epoch:12, avg train loss:0.3817, avg valid loss:0.2890
# 	 score:0.4314(th=0.550000), auc=0.869470::: time:589.14s
# - epoch:13 -
# Epoch: [13][0/65] Elapsed 0m 1s (remain 1m 20s) Loss: 0.4591(0.4591)
# Epoch: [13][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.4242(0.3669)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1323(0.1323)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2741(0.2582)
# 	 epoch:13, avg train loss:0.3669, avg valid loss:0.2582
# 	 score:0.5052(th=0.550000), auc=0.886208::: time:632.72s
# Epoch 13 - Save Best Score: 0.5052. Model is saved.
# dice_list:  [0.30474453979341054, 0.3547868033498872, 0.3867521140185831, 0.4191764964097324, 0.44717182605911876, 0.4675255130099838, 0.484853305146919, 0.4967175194997394, 0.5033988360972658, 0.5051739697843024, 0.5024401221859018, 0.4933432239805844, 0.46930365460104034, 0.4289865426851486, 0.3705897619293769, 0.29830054595504774, 0.21843009266535915, 0.12259944973880454, 0.0]
# Epoch 13 - Save Best AUC: 0.8862. Model is saved.
# - epoch:14 -
# Epoch: [14][0/65] Elapsed 0m 1s (remain 1m 21s) Loss: 0.3403(0.3403)
# Epoch: [14][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3453(0.3595)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1613(0.1613)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2583(0.2592)
# 	 epoch:14, avg train loss:0.3595, avg valid loss:0.2592
# 	 score:0.5199(th=0.500000), auc=0.881695::: time:678.84s
# Epoch 14 - Save Best Score: 0.5199. Model is saved.
# dice_list:  [0.24455269916795208, 0.29849928257642255, 0.3545627567003855, 0.4014495032488262, 0.44214455698717847, 0.4778101981502752, 0.5014517676491571, 0.5166534826378589, 0.5198940191818275, 0.5107951167895225, 0.4857776032410731, 0.4343604175609737, 0.35230923621078214, 0.24768777004078002, 0.14670996614082613, 0.07313899099772928, 0.02196463229184896, 6.420851661730559e-06, 0.0]
# - epoch:15 -
# Epoch: [15][0/65] Elapsed 0m 1s (remain 1m 31s) Loss: 0.3072(0.3072)
# Epoch: [15][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2011(0.3420)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1413(0.1413)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2721(0.2543)
# 	 epoch:15, avg train loss:0.3420, avg valid loss:0.2543
# 	 score:0.5184(th=0.500000), auc=0.880376::: time:723.83s
# - epoch:16 -
# Epoch: [16][0/65] Elapsed 0m 1s (remain 1m 22s) Loss: 0.2888(0.2888)
# Epoch: [16][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 1.8590(0.3640)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1387(0.1387)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2767(0.2546)
# 	 epoch:16, avg train loss:0.3640, avg valid loss:0.2546
# 	 score:0.5151(th=0.500000), auc=0.879900::: time:767.28s
# - epoch:17 -
# Epoch: [17][0/65] Elapsed 0m 1s (remain 1m 19s) Loss: 0.4441(0.4441)
# Epoch: [17][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1917(0.3402)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1397(0.1397)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2803(0.2560)
# 	 epoch:17, avg train loss:0.3402, avg valid loss:0.2560
# 	 score:0.5087(th=0.450000), auc=0.879096::: time:810.88s
# - epoch:18 -
# Epoch: [18][0/65] Elapsed 0m 1s (remain 1m 33s) Loss: 0.3012(0.3012)
# Epoch: [18][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1999(0.3449)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1585(0.1585)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2749(0.2612)
# 	 epoch:18, avg train loss:0.3449, avg valid loss:0.2612
# 	 score:0.4842(th=0.450000), auc=0.877940::: time:854.62s
# - epoch:19 -
# Epoch: [19][0/65] Elapsed 0m 1s (remain 1m 23s) Loss: 0.3952(0.3952)
# Epoch: [19][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 1.6775(0.3734)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2122(0.2122)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2404(0.2737)
# 	 epoch:19, avg train loss:0.3734, avg valid loss:0.2737
# 	 score:0.4394(th=0.500000), auc=0.873225::: time:898.17s
# - epoch:20 -
# Epoch: [20][0/65] Elapsed 0m 1s (remain 1m 23s) Loss: 0.3191(0.3191)
# Epoch: [20][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2984(0.3689)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1892(0.1892)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2676(0.2629)
# 	 epoch:20, avg train loss:0.3689, avg valid loss:0.2629
# 	 score:0.4820(th=0.450000), auc=0.877373::: time:941.50s
# surface_list:  [27, 30, 33, 36]
# - epoch:21 -
# Epoch: [21][0/65] Elapsed 0m 1s (remain 1m 23s) Loss: 0.3160(0.3160)
# Epoch: [21][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.6932(0.3675)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1195(0.1195)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2896(0.2751)
# 	 epoch:21, avg train loss:0.3675, avg valid loss:0.2751
# 	 score:0.4477(th=0.250000), auc=0.859782::: time:1015.55s
# - epoch:22 -
# Epoch: [22][0/65] Elapsed 0m 1s (remain 1m 24s) Loss: 0.3154(0.3154)
# Epoch: [22][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2446(0.3653)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1194(0.1194)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2624(0.2587)
# 	 epoch:22, avg train loss:0.3653, avg valid loss:0.2587
# 	 score:0.5204(th=0.350000), auc=0.875826::: time:1059.37s
# Epoch 22 - Save Best Score: 0.5204. Model is saved.
# dice_list:  [0.28053064188097676, 0.35875151507817316, 0.42334067377700474, 0.48481122544187477, 0.5176615515626045, 0.5203909759825776, 0.5044145295164633, 0.4679513530374012, 0.3917408055474806, 0.29095198228568947, 0.18410295251069728, 0.09199337782275986, 0.03608402361018334, 0.014139300838785672, 0.002137694533634264, 2.086752672494036e-05, 0.0, 0.0, 0.0]
# - epoch:23 -
# Epoch: [23][0/65] Elapsed 0m 1s (remain 1m 19s) Loss: 0.2557(0.2557)
# Epoch: [23][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2979(0.3442)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1214(0.1214)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2822(0.2586)
# 	 epoch:23, avg train loss:0.3442, avg valid loss:0.2586
# 	 score:0.5274(th=0.350000), auc=0.873898::: time:1104.64s
# Epoch 23 - Save Best Score: 0.5274. Model is saved.
# dice_list:  [0.3179698122637713, 0.3936470360131418, 0.4483308060214143, 0.4819871952567792, 0.5105423799118316, 0.5274121541213671, 0.5251335930437273, 0.5040219962841644, 0.45923013821028147, 0.3947953315765662, 0.3166221382808595, 0.23879820581756614, 0.1641642713611977, 0.09799877749379222, 0.04896264207192082, 0.016444016636952934, 0.001452640276859091, 0.0, 0.0]
# - epoch:24 -
# Epoch: [24][0/65] Elapsed 0m 1s (remain 1m 22s) Loss: 0.3262(0.3262)
# Epoch: [24][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.6699(0.3415)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1216(0.1216)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2674(0.2564)
# 	 epoch:24, avg train loss:0.3415, avg valid loss:0.2564
# 	 score:0.5117(th=0.400000), auc=0.879314::: time:1149.82s
# - epoch:25 -
# Epoch: [25][0/65] Elapsed 0m 1s (remain 1m 27s) Loss: 0.3208(0.3208)
# Epoch: [25][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.6340(0.3267)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1294(0.1294)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2649(0.2585)
# 	 epoch:25, avg train loss:0.3267, avg valid loss:0.2585
# 	 score:0.5020(th=0.450000), auc=0.877102::: time:1193.42s
# - epoch:26 -
# Epoch: [26][0/65] Elapsed 0m 1s (remain 1m 26s) Loss: 0.4545(0.4545)
# Epoch: [26][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.9262(0.3222)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1217(0.1217)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2614(0.2557)
# 	 epoch:26, avg train loss:0.3222, avg valid loss:0.2557
# 	 score:0.5082(th=0.400000), auc=0.879643::: time:1237.02s
# - epoch:27 -
# Epoch: [27][0/65] Elapsed 0m 1s (remain 1m 25s) Loss: 0.3722(0.3722)
# Epoch: [27][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1750(0.3194)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1088(0.1088)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2686(0.2599)
# 	 epoch:27, avg train loss:0.3194, avg valid loss:0.2599
# 	 score:0.5225(th=0.350000), auc=0.874114::: time:1280.56s
# - epoch:28 -
# Epoch: [28][0/65] Elapsed 0m 1s (remain 1m 30s) Loss: 0.3283(0.3283)
# Epoch: [28][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.5601(0.3274)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1099(0.1099)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2770(0.2604)
# 	 epoch:28, avg train loss:0.3274, avg valid loss:0.2604
# 	 score:0.5096(th=0.300000), auc=0.878121::: time:1324.15s
# - epoch:29 -
# Epoch: [29][0/65] Elapsed 0m 1s (remain 1m 26s) Loss: 0.2447(0.2447)
# Epoch: [29][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 1.1521(0.3529)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1296(0.1296)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2824(0.2654)
# 	 epoch:29, avg train loss:0.3529, avg valid loss:0.2654
# 	 score:0.5006(th=0.500000), auc=0.874905::: time:1367.86s
# - epoch:30 -
# Epoch: [30][0/65] Elapsed 0m 1s (remain 1m 20s) Loss: 0.4243(0.4243)
# Epoch: [30][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2537(0.3522)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2091(0.2091)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2796(0.2945)
# 	 epoch:30, avg train loss:0.3522, avg valid loss:0.2945
# 	 score:0.4574(th=0.550000), auc=0.876228::: time:1411.06s
# - epoch:31 -
# Epoch: [31][0/65] Elapsed 0m 1s (remain 1m 21s) Loss: 0.2098(0.2098)
# Epoch: [31][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3577(0.3482)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1714(0.1714)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2609(0.2685)
# 	 epoch:31, avg train loss:0.3482, avg valid loss:0.2685
# 	 score:0.4952(th=0.400000), auc=0.873845::: time:1454.51s
# - epoch:32 -
# Epoch: [32][0/65] Elapsed 0m 1s (remain 1m 27s) Loss: 0.3741(0.3741)
# Epoch: [32][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.7410(0.3533)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1539(0.1539)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3580(0.2866)
# 	 epoch:32, avg train loss:0.3533, avg valid loss:0.2866
# 	 score:0.4843(th=0.250000), auc=0.824824::: time:1498.17s
# - epoch:33 -
# Epoch: [33][0/65] Elapsed 0m 1s (remain 1m 22s) Loss: 0.3702(0.3702)
# Epoch: [33][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 1.1920(0.3445)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1419(0.1419)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2875(0.2576)
# 	 epoch:33, avg train loss:0.3445, avg valid loss:0.2576
# 	 score:0.4952(th=0.400000), auc=0.879874::: time:1541.93s
# - epoch:34 -
# Epoch: [34][0/65] Elapsed 0m 1s (remain 1m 22s) Loss: 0.2265(0.2265)
# Epoch: [34][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2856(0.3238)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1599(0.1599)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2859(0.2638)
# 	 epoch:34, avg train loss:0.3238, avg valid loss:0.2638
# 	 score:0.4977(th=0.450000), auc=0.875371::: time:1585.76s
# - epoch:35 -
# Epoch: [35][0/65] Elapsed 0m 1s (remain 1m 23s) Loss: 0.2975(0.2975)
# Epoch: [35][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2960(0.3166)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1158(0.1158)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3112(0.2554)
# 	 epoch:35, avg train loss:0.3166, avg valid loss:0.2554
# 	 score:0.5103(th=0.350000), auc=0.881398::: time:1629.28s
# - epoch:36 -
# Epoch: [36][0/65] Elapsed 0m 1s (remain 1m 24s) Loss: 0.3113(0.3113)
# Epoch: [36][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.5653(0.3201)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1242(0.1242)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3047(0.2554)
# 	 epoch:36, avg train loss:0.3201, avg valid loss:0.2554
# 	 score:0.5132(th=0.400000), auc=0.882017::: time:1673.00s
# - epoch:37 -
# Epoch: [37][0/65] Elapsed 0m 1s (remain 1m 29s) Loss: 0.2201(0.2201)
# Epoch: [37][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3773(0.3040)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1148(0.1148)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3035(0.2535)
# 	 epoch:37, avg train loss:0.3040, avg valid loss:0.2535
# 	 score:0.5129(th=0.350000), auc=0.884606::: time:1716.87s
# - epoch:38 -
# Epoch: [38][0/65] Elapsed 0m 1s (remain 1m 23s) Loss: 0.3147(0.3147)
# Epoch: [38][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1955(0.3079)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1261(0.1261)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2829(0.2597)
# 	 epoch:38, avg train loss:0.3079, avg valid loss:0.2597
# 	 score:0.5068(th=0.400000), auc=0.875780::: time:1760.40s
# - epoch:39 -
# Epoch: [39][0/65] Elapsed 0m 1s (remain 1m 27s) Loss: 0.2557(0.2557)
# Epoch: [39][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1820(0.3262)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1616(0.1616)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2535(0.2643)
# 	 epoch:39, avg train loss:0.3262, avg valid loss:0.2643
# 	 score:0.5004(th=0.400000), auc=0.883932::: time:1804.19s
# - epoch:40 -
# Epoch: [40][0/65] Elapsed 0m 1s (remain 1m 27s) Loss: 0.2246(0.2246)
# Epoch: [40][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1881(0.3207)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1210(0.1210)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2829(0.2817)
# 	 epoch:40, avg train loss:0.3207, avg valid loss:0.2817
# 	 score:0.4440(th=0.250000), auc=0.866490::: time:1847.87s
# surface_list:  [25, 28, 31, 34]
# - epoch:41 -
# Epoch: [41][0/65] Elapsed 0m 1s (remain 1m 20s) Loss: 0.3919(0.3919)
# Epoch: [41][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1801(0.3442)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1613(0.1613)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2504(0.2627)
# 	 epoch:41, avg train loss:0.3442, avg valid loss:0.2627
# 	 score:0.4852(th=0.400000), auc=0.878255::: time:1920.84s
# - epoch:42 -
# Epoch: [42][0/65] Elapsed 0m 1s (remain 1m 23s) Loss: 0.3246(0.3246)
# Epoch: [42][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.6357(0.3446)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1388(0.1388)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3136(0.2701)
# 	 epoch:42, avg train loss:0.3446, avg valid loss:0.2701
# 	 score:0.4894(th=0.500000), auc=0.874085::: time:1964.10s
# - epoch:43 -
# Epoch: [43][0/65] Elapsed 0m 1s (remain 1m 30s) Loss: 0.2874(0.2874)
# Epoch: [43][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2367(0.3395)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2207(0.2207)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2807(0.2901)
# 	 epoch:43, avg train loss:0.3395, avg valid loss:0.2901
# 	 score:0.4654(th=0.550000), auc=0.875777::: time:2007.48s
# - epoch:44 -
# Epoch: [44][0/65] Elapsed 0m 1s (remain 1m 30s) Loss: 0.3219(0.3219)
# Epoch: [44][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1757(0.3287)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1511(0.1511)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2908(0.2675)
# 	 epoch:44, avg train loss:0.3287, avg valid loss:0.2675
# 	 score:0.4975(th=0.450000), auc=0.864380::: time:2050.69s
# - epoch:45 -
# Epoch: [45][0/65] Elapsed 0m 1s (remain 1m 28s) Loss: 0.3174(0.3174)
# Epoch: [45][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1798(0.3134)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1674(0.1674)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2733(0.2649)
# 	 epoch:45, avg train loss:0.3134, avg valid loss:0.2649
# 	 score:0.5067(th=0.500000), auc=0.871239::: time:2094.07s
# - epoch:46 -
# Epoch: [46][0/65] Elapsed 0m 1s (remain 1m 29s) Loss: 0.3398(0.3398)
# Epoch: [46][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1823(0.3076)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1677(0.1677)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2788(0.2630)
# 	 epoch:46, avg train loss:0.3076, avg valid loss:0.2630
# 	 score:0.5011(th=0.500000), auc=0.872985::: time:2137.32s
# - epoch:47 -
# Epoch: [47][0/65] Elapsed 0m 1s (remain 1m 23s) Loss: 0.2473(0.2473)
# Epoch: [47][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1693(0.3060)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1624(0.1624)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2792(0.2618)
# 	 epoch:47, avg train loss:0.3060, avg valid loss:0.2618
# 	 score:0.5085(th=0.500000), auc=0.873853::: time:2180.84s
# - epoch:48 -
# Epoch: [48][0/65] Elapsed 0m 1s (remain 1m 27s) Loss: 0.2410(0.2410)
# Epoch: [48][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2277(0.3132)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1973(0.1973)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2786(0.2715)
# 	 epoch:48, avg train loss:0.3132, avg valid loss:0.2715
# 	 score:0.5276(th=0.700000), auc=0.881285::: time:2224.08s
# Epoch 48 - Save Best Score: 0.5276. Model is saved.
# dice_list:  [0.2628427744272211, 0.30541661678579024, 0.34374634048713254, 0.3751804475251453, 0.40024274278450944, 0.4229978054289473, 0.44380328272416236, 0.46174208631177904, 0.4803357884022712, 0.49589258540510034, 0.5125116037169778, 0.5262709469337382, 0.5275965628423471, 0.5102286288811779, 0.4607110511481225, 0.3514702877309249, 0.2040811136480135, 0.06077866747561545, 0.0]
# - epoch:49 -
# Epoch: [49][0/65] Elapsed 0m 1s (remain 1m 30s) Loss: 0.2672(0.2672)
# Epoch: [49][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2303(0.3101)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.2367(0.2367)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2591(0.2919)
# 	 epoch:49, avg train loss:0.3101, avg valid loss:0.2919
# 	 score:0.5239(th=0.700000), auc=0.873059::: time:2269.23s
# - epoch:50 -
# Epoch: [50][0/65] Elapsed 0m 1s (remain 1m 31s) Loss: 0.2714(0.2714)
# Epoch: [50][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2209(0.3191)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1840(0.1840)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2629(0.2692)
# 	 epoch:50, avg train loss:0.3191, avg valid loss:0.2692
# 	 score:0.5103(th=0.550000), auc=0.876449::: time:2312.88s
# - epoch:51 -
# Epoch: [51][0/65] Elapsed 0m 1s (remain 1m 23s) Loss: 0.2822(0.2822)
# Epoch: [51][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1679(0.3191)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1429(0.1429)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3025(0.2613)
# 	 epoch:51, avg train loss:0.3191, avg valid loss:0.2613
# 	 score:0.5252(th=0.500000), auc=0.876749::: time:2356.45s
# - epoch:52 -
# Epoch: [52][0/65] Elapsed 0m 1s (remain 1m 24s) Loss: 0.3907(0.3907)
# Epoch: [52][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2017(0.3273)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1466(0.1466)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3232(0.2612)
# 	 epoch:52, avg train loss:0.3273, avg valid loss:0.2612
# 	 score:0.4919(th=0.450000), auc=0.877172::: time:2399.68s
# - epoch:53 -
# Epoch: [53][0/65] Elapsed 0m 1s (remain 1m 22s) Loss: 0.3252(0.3252)
# Epoch: [53][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2858(0.3117)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1444(0.1444)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2997(0.2584)
# 	 epoch:53, avg train loss:0.3117, avg valid loss:0.2584
# 	 score:0.5219(th=0.500000), auc=0.879782::: time:2443.15s
# - epoch:54 -
# Epoch: [54][0/65] Elapsed 0m 1s (remain 1m 30s) Loss: 0.1796(0.1796)
# Epoch: [54][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2433(0.3027)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1540(0.1540)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2907(0.2608)
# 	 epoch:54, avg train loss:0.3027, avg valid loss:0.2608
# 	 score:0.5033(th=0.500000), auc=0.881221::: time:2486.54s
# - epoch:55 -
# Epoch: [55][0/65] Elapsed 0m 1s (remain 1m 29s) Loss: 0.3582(0.3582)
# Epoch: [55][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.5900(0.2900)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1662(0.1662)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2965(0.2639)
# 	 epoch:55, avg train loss:0.2900, avg valid loss:0.2639
# 	 score:0.5077(th=0.500000), auc=0.876803::: time:2530.17s
# - epoch:56 -
# Epoch: [56][0/65] Elapsed 0m 1s (remain 1m 24s) Loss: 0.2861(0.2861)
# Epoch: [56][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.1747(0.2919)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1811(0.1811)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2880(0.2683)
# 	 epoch:56, avg train loss:0.2919, avg valid loss:0.2683
# 	 score:0.5153(th=0.600000), auc=0.880935::: time:2573.87s
# - epoch:57 -
# Epoch: [57][0/65] Elapsed 0m 1s (remain 1m 31s) Loss: 0.1936(0.1936)
# Epoch: [57][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.2773(0.2884)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1385(0.1385)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3085(0.2543)
# 	 epoch:57, avg train loss:0.2884, avg valid loss:0.2543
# 	 score:0.5315(th=0.500000), auc=0.884899::: time:2617.57s
# Epoch 57 - Save Best Score: 0.5315. Model is saved.
# dice_list:  [0.2958818151215532, 0.33631531155232064, 0.3748110317240976, 0.41264077154268775, 0.44885050192683623, 0.47860504174146196, 0.5047281214372553, 0.5233275080695399, 0.531545202974905, 0.5308184242352464, 0.5194125152221835, 0.4869735780547396, 0.4311628186392369, 0.3455853294366537, 0.24219924285247066, 0.09786021703444556, 0.012320331832540972, 0.0, 0.0]
# - epoch:58 -
# Epoch: [58][0/65] Elapsed 0m 1s (remain 1m 24s) Loss: 0.2506(0.2506)
# Epoch: [58][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.6886(0.3040)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1277(0.1277)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3016(0.2579)
# 	 epoch:58, avg train loss:0.3040, avg valid loss:0.2579
# 	 score:0.5240(th=0.450000), auc=0.877839::: time:2663.18s
# - epoch:59 -
# Epoch: [59][0/65] Elapsed 0m 1s (remain 1m 23s) Loss: 0.2192(0.2192)
# Epoch: [59][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3161(0.3001)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1910(0.1910)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3042(0.2768)
# 	 epoch:59, avg train loss:0.3001, avg valid loss:0.2768
# 	 score:0.4575(th=0.550000), auc=0.866786::: time:2706.73s
# - epoch:60 -
# Epoch: [60][0/65] Elapsed 0m 1s (remain 1m 23s) Loss: 0.3323(0.3323)
# Epoch: [60][64/65] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3938(0.3018)
# EVAL: [0/14] Elapsed 0m 0s (remain 0m 4s) Loss: 0.1631(0.1631)
# EVAL: [13/14] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2734(0.2749)
# 	 epoch:60, avg train loss:0.3018, avg valid loss:0.2749
# 	 score:0.4686(th=0.500000), auc=0.864279::: time:2750.33s
# [fold0] slice ave score:0.5118(th=0.350000), auc=0.882019
# [fold0] BEST Epoch 57 - Save Best Score:0.5315. Best loss:0.2543
# [fold0] BEST AUC Epoch 13 - Save Best Score:0.8862. Best loss:0.2582
# -- fold1 training start --
# surface_list:  [26, 29, 32, 35]
# - epoch:1 -
# Epoch: [1][0/60] Elapsed 0m 1s (remain 1m 15s) Loss: 1.7912(1.7912)
# Epoch: [1][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3770(0.8077)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5610(0.5610)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1678(0.4669)
# 	 epoch:1, avg train loss:0.8077, avg valid loss:0.4669
# 	 score:0.3111(th=0.400000), auc=0.717339::: time:78.67s
# Epoch 1 - Save Best Score: 0.3111. Model is saved.
# dice_list:  [0.24162722367171038, 0.2605572754843652, 0.27853887577904846, 0.2931428987878683, 0.3034950332251289, 0.3094580863211071, 0.31113610750918647, 0.30809328985409035, 0.29988851229182, 0.28642424481700746, 0.2670961141687793, 0.24151489272059926, 0.20940947624387293, 0.17156843121088824, 0.12935581104239446, 0.08802519336664044, 0.049881851290724775, 0.016843409779337192, 0.0]
# Epoch 1 - Save Best AUC: 0.7173. Model is saved.
# - epoch:2 -
# Epoch: [2][0/60] Elapsed 0m 1s (remain 1m 16s) Loss: 0.4264(0.4264)
# Epoch: [2][59/60] Elapsed 0m 28s (remain 0m 0s) Loss: 0.6932(0.4010)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6207(0.6207)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0994(0.4305)
# 	 epoch:2, avg train loss:0.4010, avg valid loss:0.4305
# 	 score:0.3512(th=0.250000), auc=0.759069::: time:131.16s
# Epoch 2 - Save Best Score: 0.3512. Model is saved.
# dice_list:  [0.28325891720715995, 0.31957775799348065, 0.34709634551913415, 0.3512293751318427, 0.32393232378425596, 0.26804098706554647, 0.19788314476526314, 0.13162801367711424, 0.08026726280599841, 0.045657118652694895, 0.02463981238252725, 0.012547872945667518, 0.005916596850046178, 0.0023620920489987826, 0.0008336885357122648, 0.0002743616019769232, 8.284178297780884e-05, 3.746329538569217e-05, 0.0]
# Epoch 2 - Save Best AUC: 0.7591. Model is saved.
# - epoch:3 -
# Epoch: [3][0/60] Elapsed 0m 1s (remain 1m 16s) Loss: 0.3099(0.3099)
# Epoch: [3][59/60] Elapsed 0m 28s (remain 0m 0s) Loss: 0.3814(0.3766)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6170(0.6170)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1140(0.4368)
# 	 epoch:3, avg train loss:0.3766, avg valid loss:0.4368
# 	 score:0.3611(th=0.200000), auc=0.752223::: time:183.64s
# Epoch 3 - Save Best Score: 0.3611. Model is saved.
# dice_list:  [0.2826537163618034, 0.3341586160984502, 0.36113099057587744, 0.34772173729004596, 0.29847718415700014, 0.2318378712171668, 0.1659436310509037, 0.11182896426959826, 0.07200319129138444, 0.04442067313808523, 0.025864516278707995, 0.013926843248094664, 0.006525976317696807, 0.002274048336205167, 0.0006349819222102713, 0.00016927448260885218, 6.051533647659947e-05, 2.233400938261678e-05, 0.0]
# - epoch:4 -
# Epoch: [4][0/60] Elapsed 0m 1s (remain 1m 14s) Loss: 0.3842(0.3842)
# Epoch: [4][59/60] Elapsed 0m 28s (remain 0m 0s) Loss: 0.4784(0.3582)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5447(0.5447)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1076(0.4035)
# 	 epoch:4, avg train loss:0.3582, avg valid loss:0.4035
# 	 score:0.4499(th=0.300000), auc=0.788790::: time:233.82s
# Epoch 4 - Save Best Score: 0.4499. Model is saved.
# dice_list:  [0.2766343221760641, 0.33381206010754844, 0.3894959431659621, 0.43067290950951914, 0.4498922884937676, 0.4423469782168669, 0.40743263340155755, 0.3510463048331935, 0.2836616276655611, 0.2166005414568674, 0.15725737360574568, 0.10649957277820013, 0.06362543383717409, 0.031149014198103165, 0.01073497743245418, 0.002042015691859085, 0.0001642530730070541, 2.2335718609456665e-05, 0.0]
# Epoch 4 - Save Best AUC: 0.7888. Model is saved.
# - epoch:5 -
# Epoch: [5][0/60] Elapsed 0m 1s (remain 1m 11s) Loss: 0.3732(0.3732)
# Epoch: [5][59/60] Elapsed 0m 28s (remain 0m 0s) Loss: 0.4669(0.3608)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5049(0.5049)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1046(0.3991)
# 	 epoch:5, avg train loss:0.3608, avg valid loss:0.3991
# 	 score:0.4506(th=0.350000), auc=0.795150::: time:286.18s
# Epoch 5 - Save Best Score: 0.4506. Model is saved.
# dice_list:  [0.2721260935027835, 0.32248347684893924, 0.37546984152186824, 0.4177232560830869, 0.44369378657650593, 0.4505680636432682, 0.4346606916109216, 0.3916537573318519, 0.32390525520602803, 0.24303060025565762, 0.16514891283416314, 0.10190913652264125, 0.054756474478949005, 0.023082177627039544, 0.006060156217736867, 0.0008215028019525027, 0.00010086258904561847, 1.5130793921574964e-05, 0.0]
# Epoch 5 - Save Best AUC: 0.7952. Model is saved.
# - epoch:6 -
# Epoch: [6][0/60] Elapsed 0m 1s (remain 1m 22s) Loss: 0.3828(0.3828)
# Epoch: [6][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.4279(0.3470)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5061(0.5061)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1033(0.3991)
# 	 epoch:6, avg train loss:0.3470, avg valid loss:0.3991
# 	 score:0.4526(th=0.350000), auc=0.795033::: time:338.15s
# Epoch 6 - Save Best Score: 0.4526. Model is saved.
# dice_list:  [0.28060334402778464, 0.3346056448034746, 0.38767026262950854, 0.4271974640554122, 0.449287591413119, 0.4526075443638273, 0.4346286865418299, 0.39288826734666404, 0.32962833270686565, 0.254069618420971, 0.17980714087294816, 0.11780357852361956, 0.06953595407418373, 0.033813571489444624, 0.010780323240275407, 0.0016526799525689974, 0.00015921209914288774, 1.8012828778110874e-05, 0.0]
# - epoch:7 -
# Epoch: [7][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.5955(0.5955)
# Epoch: [7][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.5644(0.3488)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5095(0.5095)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1021(0.3951)
# 	 epoch:7, avg train loss:0.3488, avg valid loss:0.3951
# 	 score:0.4634(th=0.350000), auc=0.802916::: time:387.41s
# Epoch 7 - Save Best Score: 0.4634. Model is saved.
# dice_list:  [0.2893656770718332, 0.3412683479146571, 0.3891207551667835, 0.4270332967554801, 0.45288176769095617, 0.46343927249418737, 0.45319652804361654, 0.4167362625466955, 0.3515382872223542, 0.26538031492709874, 0.17708550315528637, 0.10440814733611235, 0.053002257604666536, 0.021777307040251558, 0.00620279620189495, 0.0009373417335887853, 0.0001051863480350367, 1.441033777886381e-05, 0.0]
# Epoch 7 - Save Best AUC: 0.8029. Model is saved.
# - epoch:8 -
# Epoch: [8][0/60] Elapsed 0m 1s (remain 1m 14s) Loss: 0.2498(0.2498)
# Epoch: [8][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.5717(0.3504)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.4913(0.4913)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1174(0.3905)
# 	 epoch:8, avg train loss:0.3504, avg valid loss:0.3905
# 	 score:0.4742(th=0.400000), auc=0.811577::: time:439.16s
# Epoch 8 - Save Best Score: 0.4742. Model is saved.
# dice_list:  [0.27545218852061915, 0.3253751173457294, 0.37255945333091306, 0.41383496914163875, 0.44592108747331666, 0.46645971838784284, 0.47417838818002034, 0.4689695375423892, 0.4498535208194273, 0.4167138225380024, 0.36971571302036504, 0.31053680724258587, 0.24145821770543555, 0.16773898718402253, 0.10015076891796558, 0.04874942642826044, 0.013319535359501554, 0.00030687814747609466, 0.0]
# Epoch 8 - Save Best AUC: 0.8116. Model is saved.
# - epoch:9 -
# Epoch: [9][0/60] Elapsed 0m 1s (remain 1m 15s) Loss: 0.3829(0.3829)
# Epoch: [9][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3898(0.3473)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5095(0.5095)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1032(0.4019)
# 	 epoch:9, avg train loss:0.3473, avg valid loss:0.4019
# 	 score:0.4433(th=0.400000), auc=0.794854::: time:490.47s
# - epoch:10 -
# Epoch: [10][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.4486(0.4486)
# Epoch: [10][59/60] Elapsed 0m 27s (remain 0m 0s) Loss: 0.4680(0.3582)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.4756(0.4756)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1420(0.4289)
# 	 epoch:10, avg train loss:0.3582, avg valid loss:0.4289
# 	 score:0.3993(th=0.450000), auc=0.771159::: time:536.96s
# - epoch:11 -
# Epoch: [11][0/60] Elapsed 0m 1s (remain 1m 16s) Loss: 0.2104(0.2104)
# Epoch: [11][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3428(0.3549)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.6305(0.6305)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1131(0.4217)
# 	 epoch:11, avg train loss:0.3549, avg valid loss:0.4217
# 	 score:0.4162(th=0.200000), auc=0.788160::: time:583.47s
# - epoch:12 -
# Epoch: [12][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.3682(0.3682)
# Epoch: [12][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4631(0.3526)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.4539(0.4539)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0824(0.4094)
# 	 epoch:12, avg train loss:0.3526, avg valid loss:0.4094
# 	 score:0.4408(th=0.500000), auc=0.797403::: time:629.91s
# - epoch:13 -
# Epoch: [13][0/60] Elapsed 0m 1s (remain 1m 16s) Loss: 0.4044(0.4044)
# Epoch: [13][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.5518(0.3423)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.4867(0.4867)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1195(0.4305)
# 	 epoch:13, avg train loss:0.3423, avg valid loss:0.4305
# 	 score:0.4478(th=0.600000), auc=0.806000::: time:676.25s
# - epoch:14 -
# Epoch: [14][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2135(0.2135)
# Epoch: [14][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2506(0.3342)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.4670(0.4670)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0883(0.3782)
# 	 epoch:14, avg train loss:0.3342, avg valid loss:0.3782
# 	 score:0.5076(th=0.450000), auc=0.825506::: time:722.19s
# Epoch 14 - Save Best Score: 0.5076. Model is saved.
# dice_list:  [0.2962531797748995, 0.36474159506301984, 0.41721545963965767, 0.45421045099244584, 0.4795091110757625, 0.4968745459946346, 0.5068177835677874, 0.5075665263589421, 0.4975549711175903, 0.47732217773445745, 0.4484967707286259, 0.41174259998461216, 0.36380462203718633, 0.30019265209403984, 0.2159618895524431, 0.12652579702192707, 0.04592964983313038, 0.004350634090944597, 0.0]
# Epoch 14 - Save Best AUC: 0.8255. Model is saved.
# - epoch:15 -
# Epoch: [15][0/60] Elapsed 0m 1s (remain 1m 20s) Loss: 0.4171(0.4171)
# Epoch: [15][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3403(0.3224)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.4503(0.4503)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0871(0.3670)
# 	 epoch:15, avg train loss:0.3224, avg valid loss:0.3670
# 	 score:0.5322(th=0.400000), auc=0.842217::: time:771.21s
# Epoch 15 - Save Best Score: 0.5322. Model is saved.
# dice_list:  [0.2866169092129368, 0.35717815490880017, 0.4150228779835275, 0.46215371361023616, 0.4993320459897961, 0.5225198693006247, 0.532201726562776, 0.5293432577371924, 0.516944008618512, 0.49339136651181004, 0.4566472127613559, 0.40289794885678115, 0.32672497016360424, 0.2296976056105275, 0.124142820767474, 0.047029842118132194, 0.009743075444034896, 1.5852006696299202e-05, 0.0]
# Epoch 15 - Save Best AUC: 0.8422. Model is saved.
# - epoch:16 -
# Epoch: [16][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2796(0.2796)
# Epoch: [16][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4010(0.3175)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.4507(0.4507)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0772(0.3649)
# 	 epoch:16, avg train loss:0.3175, avg valid loss:0.3649
# 	 score:0.5314(th=0.400000), auc=0.842559::: time:820.59s
# Epoch 16 - Save Best AUC: 0.8426. Model is saved.
# - epoch:17 -
# Epoch: [17][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.1989(0.1989)
# Epoch: [17][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3977(0.3095)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.4532(0.4532)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0651(0.3638)
# 	 epoch:17, avg train loss:0.3095, avg valid loss:0.3638
# 	 score:0.5340(th=0.450000), auc=0.842276::: time:868.73s
# Epoch 17 - Save Best Score: 0.5340. Model is saved.
# dice_list:  [0.33039028585818214, 0.39721869057912385, 0.4479249584111539, 0.4838296496848037, 0.5065693166004804, 0.5207253714225278, 0.5302343844636026, 0.5339878381865351, 0.5267341200590338, 0.5053673133302556, 0.47196248372846344, 0.4272725484303042, 0.36849428458187994, 0.28808803509008396, 0.18802839225098408, 0.08324626540439226, 0.013677973185621414, 5.043863924279443e-06, 0.0]
# - epoch:18 -
# Epoch: [18][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.2025(0.2025)
# Epoch: [18][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.4502(0.3216)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.4508(0.4508)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0750(0.3741)
# 	 epoch:18, avg train loss:0.3216, avg valid loss:0.3741
# 	 score:0.5113(th=0.450000), auc=0.835395::: time:916.69s
# - epoch:19 -
# Epoch: [19][0/60] Elapsed 0m 1s (remain 1m 21s) Loss: 0.4321(0.4321)
# Epoch: [19][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3217(0.3290)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5006(0.5006)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0972(0.3899)
# 	 epoch:19, avg train loss:0.3290, avg valid loss:0.3899
# 	 score:0.4868(th=0.400000), auc=0.811095::: time:962.51s
# - epoch:20 -
# Epoch: [20][0/60] Elapsed 0m 1s (remain 1m 27s) Loss: 0.3050(0.3050)
# Epoch: [20][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3005(0.3351)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.4509(0.4509)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0927(0.4063)
# 	 epoch:20, avg train loss:0.3351, avg valid loss:0.4063
# 	 score:0.4726(th=0.600000), auc=0.794087::: time:1008.66s
# surface_list:  [27, 30, 33, 36]
# - epoch:21 -
# Epoch: [21][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.3860(0.3860)
# Epoch: [21][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3083(0.3377)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.4707(0.4707)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0816(0.3808)
# 	 epoch:21, avg train loss:0.3377, avg valid loss:0.3808
# 	 score:0.5119(th=0.350000), auc=0.823457::: time:1088.47s
# - epoch:22 -
# Epoch: [22][0/60] Elapsed 0m 1s (remain 1m 15s) Loss: 0.3489(0.3489)
# Epoch: [22][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3840(0.3391)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.4697(0.4697)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1664(0.4198)
# 	 epoch:22, avg train loss:0.3391, avg valid loss:0.4198
# 	 score:0.4774(th=0.600000), auc=0.823062::: time:1134.40s
# - epoch:23 -
# Epoch: [23][0/60] Elapsed 0m 1s (remain 1m 21s) Loss: 0.3606(0.3606)
# Epoch: [23][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2876(0.3248)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5804(0.5804)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0850(0.3927)
# 	 epoch:23, avg train loss:0.3248, avg valid loss:0.3927
# 	 score:0.5276(th=0.250000), auc=0.822278::: time:1180.21s
# - epoch:24 -
# Epoch: [24][0/60] Elapsed 0m 1s (remain 1m 19s) Loss: 0.1915(0.1915)
# Epoch: [24][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2801(0.3135)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.4904(0.4904)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0951(0.3721)
# 	 epoch:24, avg train loss:0.3135, avg valid loss:0.3721
# 	 score:0.5473(th=0.400000), auc=0.829572::: time:1226.41s
# Epoch 24 - Save Best Score: 0.5473. Model is saved.
# dice_list:  [0.3032274172540084, 0.36236890838242036, 0.41952613199513006, 0.4673638055852454, 0.5082044909558453, 0.5388958623449878, 0.5473176799593378, 0.5375679559557054, 0.5124771816997997, 0.46698149184704246, 0.40509558443566673, 0.32767060511696, 0.24629869298052862, 0.15767791464841663, 0.07476619351434423, 0.024402876193127292, 0.00437211279449479, 0.0, 0.0]
# - epoch:25 -
# Epoch: [25][0/60] Elapsed 0m 1s (remain 1m 23s) Loss: 0.2761(0.2761)
# Epoch: [25][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3816(0.2989)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.4824(0.4824)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0754(0.3687)
# 	 epoch:25, avg train loss:0.2989, avg valid loss:0.3687
# 	 score:0.5477(th=0.400000), auc=0.835546::: time:1274.66s
# Epoch 25 - Save Best Score: 0.5477. Model is saved.
# dice_list:  [0.3401499892185142, 0.397594757412163, 0.4473300580248327, 0.48720929956170855, 0.5196988960619673, 0.5405392718700914, 0.5477443021460154, 0.5417757915525825, 0.5256155053470458, 0.4983391424726879, 0.4549329488987767, 0.3930222077446329, 0.31986742093035125, 0.2344765940744104, 0.13796153866737718, 0.059642008955612905, 0.018103939529111737, 0.0001232027430106274, 0.0]
# - epoch:26 -
# Epoch: [26][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2986(0.2986)
# Epoch: [26][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2220(0.2984)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.4683(0.4683)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0840(0.3724)
# 	 epoch:26, avg train loss:0.2984, avg valid loss:0.3724
# 	 score:0.5393(th=0.500000), auc=0.832931::: time:1322.86s
# - epoch:27 -
# Epoch: [27][0/60] Elapsed 0m 1s (remain 1m 15s) Loss: 0.2499(0.2499)
# Epoch: [27][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.5617(0.3018)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5009(0.5009)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0679(0.3741)
# 	 epoch:27, avg train loss:0.3018, avg valid loss:0.3741
# 	 score:0.5349(th=0.350000), auc=0.835844::: time:1369.01s
# - epoch:28 -
# Epoch: [28][0/60] Elapsed 0m 1s (remain 1m 17s) Loss: 0.3907(0.3907)
# Epoch: [28][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3332(0.3069)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5228(0.5228)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0678(0.3727)
# 	 epoch:28, avg train loss:0.3069, avg valid loss:0.3727
# 	 score:0.5309(th=0.400000), auc=0.840109::: time:1414.99s
# - epoch:29 -
# Epoch: [29][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2663(0.2663)
# Epoch: [29][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.2975(0.3028)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.4664(0.4664)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.1049(0.3805)
# 	 epoch:29, avg train loss:0.3028, avg valid loss:0.3805
# 	 score:0.5049(th=0.400000), auc=0.825931::: time:1461.21s
# - epoch:30 -
# Epoch: [30][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.3254(0.3254)
# Epoch: [30][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.1727(0.3192)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.4724(0.4724)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0960(0.4088)
# 	 epoch:30, avg train loss:0.3192, avg valid loss:0.4088
# 	 score:0.4949(th=0.450000), auc=0.794194::: time:1507.20s
# - epoch:31 -
# Epoch: [31][0/60] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2514(0.2514)
# Epoch: [31][59/60] Elapsed 0m 26s (remain 0m 0s) Loss: 0.3894(0.3221)
# EVAL: [0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.4763(0.4763)
# EVAL: [18/19] Elapsed 0m 4s (remain 0m 0s) Loss: 0.0936(0.3800)
# 	 epoch:31, avg train loss:0.3221, avg valid loss:0.3800
# 	 score:0.4966(th=0.400000), auc=0.820497::: time:1553.06s
# - epoch:32 -
# ...
# Epoch 23 - Save Best AUC: 0.8876. Model is saved.
# - epoch:24 -
# Epoch: [24][0/62] Elapsed 0m 1s (remain 1m 24s) Loss: 0.3456(0.3456)
# Epoch: [24][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.4097(0.3047)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1257(0.1257)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3247(0.3624)
# 	 epoch:24, avg train loss:0.3047, avg valid loss:0.3624
# 	 score:0.4609(th=0.550000), auc=0.875669::: time:1228.04s
# - epoch:25 -
# Epoch: [25][0/62] Elapsed 0m 1s (remain 1m 27s) Loss: 0.2193(0.2193)
# Epoch: [25][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3702(0.3037)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1394(0.1394)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3752(0.3872)
# 	 epoch:25, avg train loss:0.3037, avg valid loss:0.3872
# 	 score:0.4642(th=0.650000), auc=0.882138::: time:1275.51s
# - epoch:26 -
# Epoch: [26][0/62] Elapsed 0m 1s (remain 1m 22s) Loss: 0.2192(0.2192)
# Epoch: [26][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3522(0.2936)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1232(0.1232)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3487(0.3656)
# 	 epoch:26, avg train loss:0.2936, avg valid loss:0.3656
# 	 score:0.4670(th=0.600000), auc=0.879462::: time:1322.75s
# - epoch:27 -
# Epoch: [27][0/62] Elapsed 0m 1s (remain 1m 19s) Loss: 0.2899(0.2899)
# Epoch: [27][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.4526(0.3020)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1248(0.1248)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3176(0.3621)
# 	 epoch:27, avg train loss:0.3020, avg valid loss:0.3621
# 	 score:0.4553(th=0.550000), auc=0.878425::: time:1369.83s
# - epoch:28 -
# Epoch: [28][0/62] Elapsed 0m 1s (remain 1m 26s) Loss: 0.3893(0.3893)
# Epoch: [28][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.1771(0.3022)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1383(0.1383)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3057(0.3728)
# 	 epoch:28, avg train loss:0.3022, avg valid loss:0.3728
# 	 score:0.4522(th=0.550000), auc=0.880142::: time:1417.32s
# - epoch:29 -
# Epoch: [29][0/62] Elapsed 0m 1s (remain 1m 19s) Loss: 0.2989(0.2989)
# Epoch: [29][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.5734(0.3038)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0936(0.0936)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2755(0.3526)
# 	 epoch:29, avg train loss:0.3038, avg valid loss:0.3526
# 	 score:0.4627(th=0.500000), auc=0.878364::: time:1463.53s
# - epoch:30 -
# Epoch: [30][0/62] Elapsed 0m 1s (remain 1m 19s) Loss: 0.2965(0.2965)
# Epoch: [30][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2808(0.3139)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1636(0.1636)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3902(0.4531)
# 	 epoch:30, avg train loss:0.3139, avg valid loss:0.4531
# 	 score:0.4630(th=0.750000), auc=0.882323::: time:1510.54s
# - epoch:31 -
# Epoch: [31][0/62] Elapsed 0m 1s (remain 1m 19s) Loss: 0.1907(0.1907)
# Epoch: [31][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2227(0.3217)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1578(0.1578)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2994(0.3738)
# 	 epoch:31, avg train loss:0.3217, avg valid loss:0.3738
# 	 score:0.3949(th=0.450000), auc=0.865024::: time:1557.61s
# - epoch:32 -
# Epoch: [32][0/62] Elapsed 0m 1s (remain 1m 23s) Loss: 0.4241(0.4241)
# Epoch: [32][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2996(0.3191)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2705(0.2705)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4099(0.4948)
# 	 epoch:32, avg train loss:0.3191, avg valid loss:0.4948
# 	 score:0.4078(th=0.750000), auc=0.871107::: time:1604.21s
# - epoch:33 -
# Epoch: [33][0/62] Elapsed 0m 1s (remain 1m 21s) Loss: 0.3179(0.3179)
# Epoch: [33][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3178(0.3025)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1874(0.1874)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3126(0.4021)
# 	 epoch:33, avg train loss:0.3025, avg valid loss:0.4021
# 	 score:0.3415(th=0.400000), auc=0.848293::: time:1650.66s
# - epoch:34 -
# Epoch: [34][0/62] Elapsed 0m 1s (remain 1m 18s) Loss: 0.3144(0.3144)
# Epoch: [34][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.1985(0.3018)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2471(0.2471)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.4240(0.4674)
# 	 epoch:34, avg train loss:0.3018, avg valid loss:0.4674
# 	 score:0.4380(th=0.750000), auc=0.879311::: time:1697.11s
# - epoch:35 -
# Epoch: [35][0/62] Elapsed 0m 1s (remain 1m 25s) Loss: 0.3066(0.3066)
# Epoch: [35][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2275(0.2886)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2047(0.2047)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3411(0.4042)
# 	 epoch:35, avg train loss:0.2886, avg valid loss:0.4042
# 	 score:0.4373(th=0.700000), auc=0.878820::: time:1743.86s
# - epoch:36 -
# Epoch: [36][0/62] Elapsed 0m 1s (remain 1m 17s) Loss: 0.2028(0.2028)
# Epoch: [36][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2070(0.2823)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2203(0.2203)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3609(0.4221)
# 	 epoch:36, avg train loss:0.2823, avg valid loss:0.4221
# 	 score:0.4352(th=0.700000), auc=0.878129::: time:1791.27s
# - epoch:37 -
# Epoch: [37][0/62] Elapsed 0m 1s (remain 1m 25s) Loss: 0.2290(0.2290)
# Epoch: [37][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.1945(0.2799)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2341(0.2341)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3551(0.4431)
# 	 epoch:37, avg train loss:0.2799, avg valid loss:0.4431
# 	 score:0.4220(th=0.750000), auc=0.874821::: time:1838.10s
# - epoch:38 -
# Epoch: [38][0/62] Elapsed 0m 1s (remain 1m 24s) Loss: 0.2051(0.2051)
# Epoch: [38][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3041(0.2896)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1469(0.1469)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3289(0.3616)
# 	 epoch:38, avg train loss:0.2896, avg valid loss:0.3616
# 	 score:0.4509(th=0.550000), auc=0.884782::: time:1885.71s
# - epoch:39 -
# Epoch: [39][0/62] Elapsed 0m 1s (remain 1m 21s) Loss: 0.2666(0.2666)
# Epoch: [39][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3281(0.2903)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1827(0.1827)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3425(0.3837)
# 	 epoch:39, avg train loss:0.2903, avg valid loss:0.3837
# 	 score:0.4299(th=0.700000), auc=0.880668::: time:1932.96s
# - epoch:40 -
# Epoch: [40][0/62] Elapsed 0m 1s (remain 1m 19s) Loss: 0.1828(0.1828)
# Epoch: [40][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3348(0.2984)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1087(0.1087)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3145(0.3606)
# 	 epoch:40, avg train loss:0.2984, avg valid loss:0.3606
# 	 score:0.4059(th=0.450000), auc=0.872374::: time:1979.77s
# surface_list:  [25, 28, 31, 34]
# - epoch:41 -
# Epoch: [41][0/62] Elapsed 0m 1s (remain 1m 20s) Loss: 0.3109(0.3109)
# Epoch: [41][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3305(0.3118)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2612(0.2612)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3260(0.5297)
# 	 epoch:41, avg train loss:0.3118, avg valid loss:0.5297
# 	 score:0.3658(th=0.800000), auc=0.862310::: time:2055.77s
# - epoch:42 -
# Epoch: [42][0/62] Elapsed 0m 1s (remain 1m 27s) Loss: 0.2547(0.2547)
# Epoch: [42][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3377(0.3190)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1266(0.1266)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2748(0.3519)
# 	 epoch:42, avg train loss:0.3190, avg valid loss:0.3519
# 	 score:0.4318(th=0.450000), auc=0.874703::: time:2102.39s
# - epoch:43 -
# Epoch: [43][0/62] Elapsed 0m 1s (remain 1m 24s) Loss: 0.4053(0.4053)
# Epoch: [43][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3426(0.3010)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2063(0.2063)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3915(0.4870)
# 	 epoch:43, avg train loss:0.3010, avg valid loss:0.4870
# 	 score:0.4067(th=0.700000), auc=0.862192::: time:2148.90s
# - epoch:44 -
# Epoch: [44][0/62] Elapsed 0m 1s (remain 1m 28s) Loss: 0.2743(0.2743)
# Epoch: [44][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2072(0.2923)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1342(0.1342)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2913(0.3725)
# 	 epoch:44, avg train loss:0.2923, avg valid loss:0.3725
# 	 score:0.4337(th=0.550000), auc=0.870218::: time:2195.48s
# - epoch:45 -
# Epoch: [45][0/62] Elapsed 0m 1s (remain 1m 19s) Loss: 0.2140(0.2140)
# Epoch: [45][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.4119(0.2779)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1264(0.1264)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2591(0.3646)
# 	 epoch:45, avg train loss:0.2779, avg valid loss:0.3646
# 	 score:0.4231(th=0.450000), auc=0.868569::: time:2241.78s
# - epoch:46 -
# Epoch: [46][0/62] Elapsed 0m 1s (remain 1m 22s) Loss: 0.3256(0.3256)
# Epoch: [46][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3349(0.2784)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1329(0.1329)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2549(0.3659)
# 	 epoch:46, avg train loss:0.2784, avg valid loss:0.3659
# 	 score:0.4289(th=0.500000), auc=0.870201::: time:2288.65s
# - epoch:47 -
# Epoch: [47][0/62] Elapsed 0m 1s (remain 1m 19s) Loss: 0.2798(0.2798)
# Epoch: [47][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.1641(0.2755)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1591(0.1591)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2708(0.3767)
# 	 epoch:47, avg train loss:0.2755, avg valid loss:0.3767
# 	 score:0.4350(th=0.550000), auc=0.872045::: time:2335.19s
# - epoch:48 -
# Epoch: [48][0/62] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2072(0.2072)
# Epoch: [48][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.1663(0.2792)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1265(0.1265)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2454(0.3622)
# 	 epoch:48, avg train loss:0.2792, avg valid loss:0.3622
# 	 score:0.4438(th=0.550000), auc=0.875005::: time:2381.51s
# - epoch:49 -
# Epoch: [49][0/62] Elapsed 0m 1s (remain 1m 23s) Loss: 0.1903(0.1903)
# Epoch: [49][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.5113(0.2909)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0966(0.0966)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2798(0.3718)
# 	 epoch:49, avg train loss:0.2909, avg valid loss:0.3718
# 	 score:0.4158(th=0.450000), auc=0.864883::: time:2427.87s
# - epoch:50 -
# Epoch: [50][0/62] Elapsed 0m 1s (remain 1m 23s) Loss: 0.2162(0.2162)
# Epoch: [50][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3155(0.2929)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0975(0.0975)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3017(0.3749)
# 	 epoch:50, avg train loss:0.2929, avg valid loss:0.3749
# 	 score:0.4350(th=0.550000), auc=0.871021::: time:2473.95s
# - epoch:51 -
# Epoch: [51][0/62] Elapsed 0m 1s (remain 1m 20s) Loss: 0.3540(0.3540)
# Epoch: [51][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.4185(0.2985)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1222(0.1222)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2457(0.3666)
# 	 epoch:51, avg train loss:0.2985, avg valid loss:0.3666
# 	 score:0.4281(th=0.450000), auc=0.866890::: time:2519.96s
# - epoch:52 -
# Epoch: [52][0/62] Elapsed 0m 1s (remain 1m 18s) Loss: 0.2805(0.2805)
# Epoch: [52][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2842(0.2918)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1029(0.1029)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2929(0.3690)
# 	 epoch:52, avg train loss:0.2918, avg valid loss:0.3690
# 	 score:0.4282(th=0.600000), auc=0.878032::: time:2565.90s
# - epoch:53 -
# Epoch: [53][0/62] Elapsed 0m 1s (remain 1m 21s) Loss: 0.2851(0.2851)
# Epoch: [53][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.1995(0.2819)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1263(0.1263)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2789(0.3497)
# 	 epoch:53, avg train loss:0.2819, avg valid loss:0.3497
# 	 score:0.4320(th=0.450000), auc=0.876855::: time:2611.82s
# - epoch:54 -
# Epoch: [54][0/62] Elapsed 0m 1s (remain 1m 29s) Loss: 0.2631(0.2631)
# Epoch: [54][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3395(0.2816)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1322(0.1322)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2957(0.3651)
# 	 epoch:54, avg train loss:0.2816, avg valid loss:0.3651
# 	 score:0.4360(th=0.550000), auc=0.879533::: time:2657.79s
# - epoch:55 -
# Epoch: [55][0/62] Elapsed 0m 1s (remain 1m 24s) Loss: 0.3477(0.3477)
# Epoch: [55][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2563(0.2693)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1217(0.1217)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2738(0.3547)
# 	 epoch:55, avg train loss:0.2693, avg valid loss:0.3547
# 	 score:0.4401(th=0.500000), auc=0.877132::: time:2704.23s
# - epoch:56 -
# Epoch: [56][0/62] Elapsed 0m 1s (remain 1m 20s) Loss: 0.2557(0.2557)
# Epoch: [56][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2352(0.2728)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1216(0.1216)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2697(0.3531)
# 	 epoch:56, avg train loss:0.2728, avg valid loss:0.3531
# 	 score:0.4384(th=0.500000), auc=0.877549::: time:2750.53s
# - epoch:57 -
# Epoch: [57][0/62] Elapsed 0m 1s (remain 1m 26s) Loss: 0.2383(0.2383)
# Epoch: [57][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2909(0.2706)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1578(0.1578)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3001(0.3753)
# 	 epoch:57, avg train loss:0.2706, avg valid loss:0.3753
# 	 score:0.4352(th=0.600000), auc=0.876506::: time:2796.97s
# - epoch:58 -
# Epoch: [58][0/62] Elapsed 0m 1s (remain 1m 21s) Loss: 0.2151(0.2151)
# Epoch: [58][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.3800(0.2682)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1406(0.1406)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.2761(0.3580)
# 	 epoch:58, avg train loss:0.2682, avg valid loss:0.3580
# 	 score:0.4473(th=0.550000), auc=0.879166::: time:2843.40s
# - epoch:59 -
# Epoch: [59][0/62] Elapsed 0m 1s (remain 1m 19s) Loss: 0.1375(0.1375)
# Epoch: [59][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2852(0.2595)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1331(0.1331)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3512(0.3662)
# 	 epoch:59, avg train loss:0.2595, avg valid loss:0.3662
# 	 score:0.4386(th=0.500000), auc=0.874267::: time:2889.28s
# - epoch:60 -
# Epoch: [60][0/62] Elapsed 0m 1s (remain 1m 24s) Loss: 0.1809(0.1809)
# Epoch: [60][61/62] Elapsed 0m 27s (remain 0m 0s) Loss: 0.2439(0.2797)
# EVAL: [0/17] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1591(0.1591)
# EVAL: [16/17] Elapsed 0m 3s (remain 0m 0s) Loss: 0.3196(0.3852)
# 	 epoch:60, avg train loss:0.2797, avg valid loss:0.3852
# 	 score:0.3832(th=0.450000), auc=0.858924::: time:2935.49s
# [fold4] slice ave score:0.4607(th=0.550000), auc=0.882532
# [fold4] BEST Epoch 23 - Save Best Score:0.4833. Best loss:0.3361
# [fold4] BEST AUC Epoch 23 - Save Best Score:0.8876. Best loss:0.3361
# fold[0] BEST SCORE = 0.5315 thr=0.5 (epoch=57)
# fold[0] slice ave score:0.5118(th=0.350000), auc=0.882019
# fold[1] BEST SCORE = 0.5477 thr=0.4 (epoch=25)
# fold[1] slice ave score:0.5300(th=0.450000), auc=0.840322
# fold[2] BEST SCORE = 0.5535 thr=0.45 (epoch=46)
# fold[2] slice ave score:0.5134(th=0.400000), auc=0.848122
# fold[3] BEST SCORE = 0.5308 thr=0.45 (epoch=39)
# fold[3] slice ave score:0.4755(th=0.400000), auc=0.926165
# fold[4] BEST SCORE = 0.4833 thr=0.45 (epoch=23)
# fold[4] slice ave score:0.4607(th=0.550000), auc=0.882532
# CPU times: user 2h 50min 4s, sys: 1h 3min 14s, total: 3h 53min 19s
# Wall time: 4h 23s

# %% [markdown]
# ---
# # OOF SCORE INFER

# %%
# %%time
slice_ave_score_list, slice_ave_score_threshold_list, slice_ave_auc_list = slide_inference(CFG)
for fold in CFG["folds"]:
    print(f"fold[{fold}] slice ave score:{slice_ave_score_list[fold]:.4f}(th={slice_ave_score_threshold_list[fold]:3f}), auc={slice_ave_auc_list[fold]:4f}")
    wandb.log({"OOF SCORE" : {f"slice average score":slice_ave_score_list[fold],
                            f"slice average threshold":slice_ave_score_threshold_list[fold],
                            f"slice_average auc":slice_ave_auc_list[fold],
                            }})
# Out:
# -- fold0 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.5052(th=0.550000), auc=0.886208::: time:26.42s
# slide pos: [256, 0]
# 	 score:0.4828(th=0.500000), auc=0.888551::: time:42.95s
# slide pos: [0, 256]
# 	 score:0.4773(th=0.600000), auc=0.888786::: time:59.36s
# slide pos: [256, 256]
# 	 score:0.4643(th=0.550000), auc=0.887700::: time:75.43s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.4956(th=0.550000), auc=0.887241::: time:99.07s
# slide pos: [256, 0]
# 	 score:0.4825(th=0.550000), auc=0.887636::: time:116.39s
# slide pos: [0, 256]
# 	 score:0.4722(th=0.550000), auc=0.889390::: time:132.49s
# slide pos: [256, 256]
# 	 score:0.4631(th=0.600000), auc=0.885404::: time:148.99s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.4914(th=0.550000), auc=0.883920::: time:172.88s
# slide pos: [256, 0]
# 	 score:0.4750(th=0.550000), auc=0.886029::: time:189.04s
# slide pos: [0, 256]
# 	 score:0.4564(th=0.500000), auc=0.884954::: time:205.63s
# slide pos: [256, 256]
# 	 score:0.4603(th=0.450000), auc=0.886543::: time:221.84s
# [fold0] slice ave score:0.4866(th=0.450000), auc=0.896810
# -- fold1 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.5391(th=0.400000), auc=0.847206::: time:261.96s
# slide pos: [256, 0]
# 	 score:0.5243(th=0.450000), auc=0.847368::: time:282.66s
# slide pos: [0, 256]
# 	 score:0.5364(th=0.450000), auc=0.841167::: time:304.78s
# slide pos: [256, 256]
# 	 score:0.5074(th=0.450000), auc=0.835835::: time:326.00s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.5360(th=0.400000), auc=0.850440::: time:351.55s
# slide pos: [256, 0]
# 	 score:0.5218(th=0.450000), auc=0.848765::: time:373.03s
# slide pos: [0, 256]
# 	 score:0.5352(th=0.450000), auc=0.840116::: time:394.66s
# slide pos: [256, 256]
# 	 score:0.5117(th=0.500000), auc=0.833389::: time:416.38s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.5361(th=0.450000), auc=0.839092::: time:442.62s
# slide pos: [256, 0]
# 	 score:0.5168(th=0.450000), auc=0.837687::: time:464.14s
# slide pos: [0, 256]
# 	 score:0.5304(th=0.450000), auc=0.833274::: time:486.07s
# slide pos: [256, 256]
# 	 score:0.5023(th=0.500000), auc=0.829633::: time:507.91s
# [fold1] slice ave score:0.5518(th=0.400000), auc=0.849848
# -- fold2 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.5488(th=0.450000), auc=0.848721::: time:551.92s
# slide pos: [256, 0]
# 	 score:0.5381(th=0.450000), auc=0.852578::: time:573.30s
# slide pos: [0, 256]
# 	 score:0.5487(th=0.450000), auc=0.854074::: time:594.87s
# slide pos: [256, 256]
# 	 score:0.5606(th=0.450000), auc=0.851620::: time:616.42s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.5501(th=0.450000), auc=0.852558::: time:642.66s
# slide pos: [256, 0]
# 	 score:0.5415(th=0.500000), auc=0.853430::: time:663.68s
# slide pos: [0, 256]
# 	 score:0.5556(th=0.500000), auc=0.855597::: time:684.77s
# slide pos: [256, 256]
# 	 score:0.5520(th=0.450000), auc=0.853364::: time:706.12s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.5499(th=0.450000), auc=0.840104::: time:731.56s
# slide pos: [256, 0]
# 	 score:0.5210(th=0.450000), auc=0.843268::: time:752.54s
# slide pos: [0, 256]
# 	 score:0.5345(th=0.450000), auc=0.849780::: time:773.45s
# slide pos: [256, 256]
# 	 score:0.5415(th=0.450000), auc=0.847167::: time:795.00s
# [fold2] slice ave score:0.5617(th=0.400000), auc=0.855728
# -- fold3 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.4988(th=0.450000), auc=0.924927::: time:833.11s
# slide pos: [256, 0]
# 	 score:0.4675(th=0.450000), auc=0.919291::: time:850.60s
# slide pos: [0, 256]
# 	 score:0.5130(th=0.400000), auc=0.923085::: time:867.79s
# slide pos: [256, 256]
# 	 score:0.4663(th=0.450000), auc=0.913939::: time:884.92s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.5062(th=0.450000), auc=0.928315::: time:904.88s
# slide pos: [256, 0]
# 	 score:0.4851(th=0.450000), auc=0.921687::: time:921.95s
# slide pos: [0, 256]
# 	 score:0.5224(th=0.450000), auc=0.929236::: time:939.28s
# slide pos: [256, 256]
# 	 score:0.4807(th=0.450000), auc=0.919915::: time:956.21s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.4777(th=0.450000), auc=0.919160::: time:976.78s
# slide pos: [256, 0]
# 	 score:0.4275(th=0.450000), auc=0.914985::: time:993.88s
# slide pos: [0, 256]
# 	 score:0.4837(th=0.400000), auc=0.917849::: time:1010.81s
# slide pos: [256, 256]
# 	 score:0.4397(th=0.450000), auc=0.908356::: time:1027.67s
# [fold3] slice ave score:0.5333(th=0.450000), auc=0.927572
# -- fold4 slide inference start --
# surface_list:  [26, 29, 32, 35]
# slide pos: [0, 0]
# 	 score:0.4830(th=0.450000), auc=0.887329::: time:1074.25s
# slide pos: [256, 0]
# 	 score:0.4880(th=0.400000), auc=0.890022::: time:1095.70s
# slide pos: [0, 256]
# 	 score:0.5047(th=0.400000), auc=0.889659::: time:1115.87s
# slide pos: [256, 256]
# 	 score:0.5093(th=0.450000), auc=0.888527::: time:1136.92s
# surface_list:  [27, 30, 33, 36]
# slide pos: [0, 0]
# 	 score:0.4833(th=0.450000), auc=0.887636::: time:1166.92s
# slide pos: [256, 0]
# 	 score:0.4935(th=0.400000), auc=0.891991::: time:1188.20s
# slide pos: [0, 256]
# 	 score:0.5045(th=0.450000), auc=0.888696::: time:1208.74s
# slide pos: [256, 256]
# 	 score:0.5117(th=0.450000), auc=0.887837::: time:1229.21s
# surface_list:  [25, 28, 31, 34]
# slide pos: [0, 0]
# 	 score:0.4871(th=0.400000), auc=0.885530::: time:1259.87s
# slide pos: [256, 0]
# 	 score:0.4869(th=0.400000), auc=0.888723::: time:1280.81s
# slide pos: [0, 256]
# 	 score:0.5032(th=0.450000), auc=0.888223::: time:1301.60s
# slide pos: [256, 256]
# 	 score:0.5141(th=0.400000), auc=0.889617::: time:1322.32s
# [fold4] slice ave score:0.5146(th=0.400000), auc=0.898117
# fold[0] slice ave score:0.4866(th=0.896810), auc=0.450000
# fold[1] slice ave score:0.5518(th=0.849848), auc=0.400000
# fold[2] slice ave score:0.5617(th=0.855728), auc=0.400000
# fold[3] slice ave score:0.5333(th=0.927572), auc=0.450000
# fold[4] slice ave score:0.5146(th=0.898117), auc=0.400000
# CPU times: user 17min 33s, sys: 3min 22s, total: 20min 56s
# Wall time: 22min 18s

# %%
import yaml
with open(os.path.join(CFG["OUTPUT_DIR"], "Config.yaml"), "w") as f:
    yaml.dump(CFG, f)

# %%
if not CFG["DEBUG"]:
    wandb.finish()
